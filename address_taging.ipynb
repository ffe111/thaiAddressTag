# %% [markdown]
# <a href="https://colab.research.google.com/github/ffe111/thaiAddressTag/blob/main/address_taging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pythainlp==5.0.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 54.1 MB/s eta 0:00:00
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pythainlp

pythainlp.__version__
# Out:
# '5.0.3'

# %% [markdown]
# # Hashmap

# %%
hashmap = {
  "กกกุง": "DISTRICT",
  "กกดู่": "DISTRICT",
  "กกตูม": "DISTRICT",
  "กกทอง": "DISTRICT",
  "กกปลาซิว": "DISTRICT",
  "กกสะทอน": "DISTRICT",
  "กกแก้วบูรพา": "DISTRICT",
  "กกแดง": "DISTRICT",
  "กกแรต": "DISTRICT",
  "กกโก": "DISTRICT",
  "กกโพธิ์": "DISTRICT",
  "กง": "DISTRICT",
  "กงรถ": "DISTRICT",
  "กงหรา": "DISTRICT",
  "กบินทร์": "DISTRICT",
  "กบเจา": "DISTRICT",
  "กมลา": "DISTRICT",
  "กมลาไสย": "DISTRICT",
  "กรงปินัง": "DISTRICT",
  "กรอกสมบูรณ์": "DISTRICT",
  "กระจัน": "DISTRICT",
  "กระจาย": "DISTRICT",
  "กระจิว": "DISTRICT",
  "กระชอน": "DISTRICT",
  "กระดังงา": "DISTRICT",
  "กระตีบ": "DISTRICT",
  "กระทุ่มราย": "DISTRICT",
  "กระทุ่มล้ม": "DISTRICT",
  "กระทุ่มแพ้ว": "DISTRICT",
  "กระนวน": "DISTRICT",
  "กระบี่น้อย": "DISTRICT",
  "กระบี่ใหญ่": "DISTRICT",
  "กระสัง": "DISTRICT",
  "กระหวะ": "DISTRICT",
  "กระหวัน": "DISTRICT",
  "กระหาด": "DISTRICT",
  "กระออม": "DISTRICT",
  "กระเดียน": "DISTRICT",
  "กระเทียม": "DISTRICT",
  "กระเบื้อง": "DISTRICT",
  "กระเบื้องนอก": "DISTRICT",
  "กระเบื้องใหญ่": "DISTRICT",
  "กระเสาะ": "DISTRICT",
  "กระเสียว": "DISTRICT",
  "กระแจะ": "DISTRICT",
  "กระแชง": "DISTRICT",
  "กระแสบน": "DISTRICT",
  "กระแสสินธุ์": "DISTRICT",
  "กระโด": "DISTRICT",
  "กระโทก": "DISTRICT",
  "กระโพ": "DISTRICT",
  "กระโสบ": "DISTRICT",
  "กระโสม": "DISTRICT",
  "กรับใหญ่": "DISTRICT",
  "กรุงชิง": "DISTRICT",
  "กรุงหยัน": "DISTRICT",
  "กรูด": "DISTRICT",
  "กร่ำ": "DISTRICT",
  "กฤษณา": "DISTRICT",
  "กลอนโด": "DISTRICT",
  "กลัดหลวง": "DISTRICT",
  "กลันทา": "DISTRICT",
  "กลาง": "DISTRICT",
  "กลางดง": "DISTRICT",
  "กลางหมื่น": "DISTRICT",
  "กลางเวียง": "DISTRICT",
  "กลางแดด": "DISTRICT",
  "กลางใหญ่": "DISTRICT",
  "กลาย": "DISTRICT",
  "กล้วยกว้าง": "DISTRICT",
  "กล้วยแพะ": "DISTRICT",
  "กวนวัน": "DISTRICT",
  "กวางโจน": "DISTRICT",
  "กองก๋อย": "DISTRICT",
  "กองควาย": "DISTRICT",
  "กองดิน": "DISTRICT",
  "กองทูล": "DISTRICT",
  "กองนาง": "DISTRICT",
  "กองแขก": "DISTRICT",
  "กองโพน": "DISTRICT",
  "กอตอตือร๊ะ": "DISTRICT",
  "กอลำ": "DISTRICT",
  "กะดุนง": "DISTRICT",
  "กะทุ่ม": "DISTRICT",
  "กะทูน": "DISTRICT",
  "กะทู้": "DISTRICT",
  "กะบกเตี้ย": "DISTRICT",
  "กะปง": "DISTRICT",
  "กะปาง": "DISTRICT",
  "กะมัง": "DISTRICT",
  "กะมิยอ": "DISTRICT",
  "กะรน": "DISTRICT",
  "กะรุบี": "DISTRICT",
  "กะลาเส": "DISTRICT",
  "กะลุวอ": "DISTRICT",
  "กะลุวอเหนือ": "DISTRICT",
  "กะหรอ": "DISTRICT",
  "กะฮาด": "DISTRICT",
  "กะเฉด": "DISTRICT",
  "กะเปอร์": "DISTRICT",
  "กะเปา": "DISTRICT",
  "กะเปียด": "DISTRICT",
  "กะแดะ": "DISTRICT",
  "กะไหล": "DISTRICT",
  "กังแอน": "DISTRICT",
  "กันจุ": "DISTRICT",
  "กันตวจระมวล": "DISTRICT",
  "กันตัง": "DISTRICT",
  "กันตังใต้": "DISTRICT",
  "กันทรอม": "DISTRICT",
  "กันทรารมย์": "DISTRICT",
  "กาญจนา": "DISTRICT",
  "กาตอง": "DISTRICT",
  "กาบัง": "DISTRICT",
  "กาบิน": "DISTRICT",
  "กาบเชิง": "DISTRICT",
  "กายูคละ": "DISTRICT",
  "กายูบอเกาะ": "DISTRICT",
  "การะเกด": "DISTRICT",
  "กาลอ": "DISTRICT",
  "กาลิซา": "DISTRICT",
  "กาลูปัง": "DISTRICT",
  "กาวะ": "DISTRICT",
  "กาหลง": "DISTRICT",
  "กาฬสินธุ์": "DISTRICT",
  "กาเกาะ": "DISTRICT",
  "กาเยาะมาตี": "DISTRICT",
  "กำปัง": "DISTRICT",
  "กำพวน": "DISTRICT",
  "กำพี้": "DISTRICT",
  "กำเนิดนพคุณ": "DISTRICT",
  "กำแพง": "DISTRICT",
  "กำแพงดิน": "DISTRICT",
  "กำแพงเซา": "DISTRICT",
  "กำแพงเพชร": "DISTRICT",
  "กำแพงแสน": "DISTRICT",
  "กำแมด": "DISTRICT",
  "กำโลน": "DISTRICT",
  "กื้ดช้าง": "DISTRICT",
  "กุง": "DISTRICT",
  "กุงเก่า": "DISTRICT",
  "กุฎี": "DISTRICT",
  "กุฎโง้ง": "DISTRICT",
  "กุดกว้าง": "DISTRICT",
  "กุดกุง": "DISTRICT",
  "กุดขอนแก่น": "DISTRICT",
  "กุดขาคีม": "DISTRICT",
  "กุดค้าว": "DISTRICT",
  "กุดจอก": "DISTRICT",
  "กุดจับ": "DISTRICT",
  "กุดจิก": "DISTRICT",
  "กุดฉิม": "DISTRICT",
  "กุดชมภู": "DISTRICT",
  "กุดชุม": "DISTRICT",
  "กุดชุมแสง": "DISTRICT",
  "กุดดินจี่": "DISTRICT",
  "กุดดู่": "DISTRICT",
  "กุดตาเพชร": "DISTRICT",
  "กุดตุ้ม": "DISTRICT",
  "กุดธาตุ": "DISTRICT",
  "กุดนกเปล้า": "DISTRICT",
  "กุดน้อย": "DISTRICT",
  "กุดน้ำใส": "DISTRICT",
  "กุดบง": "DISTRICT",
  "กุดบาก": "DISTRICT",
  "กุดประทาย": "DISTRICT",
  "กุดปลาค้าว": "DISTRICT",
  "กุดปลาดุก": "DISTRICT",
  "กุดป่อง": "DISTRICT",
  "กุดผึ้ง": "DISTRICT",
  "กุดพิมาน": "DISTRICT",
  "กุดยม": "DISTRICT",
  "กุดยาลวน": "DISTRICT",
  "กุดรัง": "DISTRICT",
  "กุดลาด": "DISTRICT",
  "กุดสระ": "DISTRICT",
  "กุดสะเทียน": "DISTRICT",
  "กุดสิมคุ้มใหม่": "DISTRICT",
  "กุดหมากไฟ": "DISTRICT",
  "กุดหวาย": "DISTRICT",
  "กุดหว้า": "DISTRICT",
  "กุดเค้า": "DISTRICT",
  "กุดเชียงหมี": "DISTRICT",
  "กุดเพียขอม": "DISTRICT",
  "กุดเมืองฮาม": "DISTRICT",
  "กุดเรือ": "DISTRICT",
  "กุดเรือคำ": "DISTRICT",
  "กุดเลาะ": "DISTRICT",
  "กุดเสลา": "DISTRICT",
  "กุดแข้": "DISTRICT",
  "กุดแห่": "DISTRICT",
  "กุดโดน": "DISTRICT",
  "กุดโบสถ์": "DISTRICT",
  "กุดใส้จ่อ": "DISTRICT",
  "กุดไห": "DISTRICT",
  "กุตาไก้": "DISTRICT",
  "กุมภวาปี": "DISTRICT",
  "กุยบุรี": "DISTRICT",
  "กุยเหนือ": "DISTRICT",
  "กุรุคุ": "DISTRICT",
  "กุศกร": "DISTRICT",
  "กุสุมาลย์": "DISTRICT",
  "กุแหระ": "DISTRICT",
  "กุ่มหัก": "DISTRICT",
  "กู่": "DISTRICT",
  "กู่กาสิงห์": "DISTRICT",
  "กู่จาน": "DISTRICT",
  "กู่ทอง": "DISTRICT",
  "กู่สวนแตง": "DISTRICT",
  "กู่สันตรัตน์": "DISTRICT",
  "ก่อเอ้": "DISTRICT",
  "ก้อ": "DISTRICT",
  "ก้อนแก้ว": "DISTRICT",
  "ก้านเหลือง": "DISTRICT",
  "ก้ามปู": "DISTRICT",
  "ขนงพระ": "DISTRICT",
  "ขนวน": "DISTRICT",
  "ขนอนหลวง": "DISTRICT",
  "ขนอม": "DISTRICT",
  "ขนาบนาก": "DISTRICT",
  "ขนุน": "DISTRICT",
  "ขมิ้น": "DISTRICT",
  "ขยาย": "DISTRICT",
  "ขลุง": "DISTRICT",
  "ขวัญเมือง": "DISTRICT",
  "ขวาว": "DISTRICT",
  "ขวาวใหญ่": "DISTRICT",
  "ขอนคลาน": "DISTRICT",
  "ขอนยูง": "DISTRICT",
  "ขอนหาด": "DISTRICT",
  "ขอนแก่น": "DISTRICT",
  "ขอนแตก": "DISTRICT",
  "ขะยูง": "DISTRICT",
  "ขะเนจื้อ": "DISTRICT",
  "ขันเงิน": "DISTRICT",
  "ขัวก่าย": "DISTRICT",
  "ขัวมุง": "DISTRICT",
  "ขัวเรียง": "DISTRICT",
  "ขั้นไดใหญ่": "DISTRICT",
  "ขามทะเลสอ": "DISTRICT",
  "ขามป้อม": "DISTRICT",
  "ขามสมบูรณ์": "DISTRICT",
  "ขามสะแกแสง": "DISTRICT",
  "ขามเฒ่า": "DISTRICT",
  "ขามเฒ่าพัฒนา": "DISTRICT",
  "ขามเปี้ย": "DISTRICT",
  "ขามเรียง": "DISTRICT",
  "ขามเรียน": "DISTRICT",
  "ขามใหญ่": "DISTRICT",
  "ขี้เหล็ก": "DISTRICT",
  "ขึ่ง": "DISTRICT",
  "ขุนกระทิง": "DISTRICT",
  "ขุนคง": "DISTRICT",
  "ขุนควร": "DISTRICT",
  "ขุนซ่อง": "DISTRICT",
  "ขุนตัดหวาย": "DISTRICT",
  "ขุนทอง": "DISTRICT",
  "ขุนทะเล": "DISTRICT",
  "ขุนน่าน": "DISTRICT",
  "ขุนฝาง": "DISTRICT",
  "ขุนพิทักษ์": "DISTRICT",
  "ขุนยวม": "DISTRICT",
  "ขุนศรี": "DISTRICT",
  "ขุนหาญ": "DISTRICT",
  "ขุนแก้ว": "DISTRICT",
  "ขุนแม่ลาน้อย": "DISTRICT",
  "ขุนโขลน": "DISTRICT",
  "ขุมทอง": "DISTRICT",
  "ขุมเงิน": "DISTRICT",
  "ขุย": "DISTRICT",
  "ขุหลุ": "DISTRICT",
  "ข่วงเปา": "DISTRICT",
  "ข่อยสูง": "DISTRICT",
  "ข้าวงาม": "DISTRICT",
  "ข้าวปุ้น": "DISTRICT",
  "ข้าวสาร": "DISTRICT",
  "ข้าวเม่า": "DISTRICT",
  "คชสิทธิ์": "DISTRICT",
  "คณฑี": "DISTRICT",
  "คมบาง": "DISTRICT",
  "ครน": "DISTRICT",
  "ครบุรี": "DISTRICT",
  "ครบุรีใต้": "DISTRICT",
  "ครึ่ง": "DISTRICT",
  "คลองกระจง": "DISTRICT",
  "คลองกระจัง": "DISTRICT",
  "คลองกระบือ": "DISTRICT",
  "คลองกระแชง": "DISTRICT",
  "คลองกวาง": "DISTRICT",
  "คลองกิ่ว": "DISTRICT",
  "คลองกุ่ม": "DISTRICT",
  "คลองขนาก": "DISTRICT",
  "คลองขนาน": "DISTRICT",
  "คลองขลุง": "DISTRICT",
  "คลองขวาง": "DISTRICT",
  "คลองขาม": "DISTRICT",
  "คลองขุด": "DISTRICT",
  "คลองข่อย": "DISTRICT",
  "คลองควาย": "DISTRICT",
  "คลองคะเชนทร์": "DISTRICT",
  "คลองคูณ": "DISTRICT",
  "คลองจั่น": "DISTRICT",
  "คลองจิก": "DISTRICT",
  "คลองจินดา": "DISTRICT",
  "คลองจุกกระเฌอ": "DISTRICT",
  "คลองฉนวน": "DISTRICT",
  "คลองฉนาก": "DISTRICT",
  "คลองชะอุ่น": "DISTRICT",
  "คลองชักพระ": "DISTRICT",
  "คลองชีล้อม": "DISTRICT",
  "คลองด่าน": "DISTRICT",
  "คลองตะเกรา": "DISTRICT",
  "คลองตะเคียน": "DISTRICT",
  "คลองตัน": "DISTRICT",
  "คลองตันเหนือ": "DISTRICT",
  "คลองตาคต": "DISTRICT",
  "คลองตาล": "DISTRICT",
  "คลองตำหรุ": "DISTRICT",
  "คลองต้นไทร": "DISTRICT",
  "คลองถนน": "DISTRICT",
  "คลองทราย": "DISTRICT",
  "คลองทรายขาว": "DISTRICT",
  "คลองทับจันทร์": "DISTRICT",
  "คลองท่อมเหนือ": "DISTRICT",
  "คลองท่อมใต้": "DISTRICT",
  "คลองนกกระทุง": "DISTRICT",
  "คลองนครเนื่องเขต": "DISTRICT",
  "คลองนา": "DISTRICT",
  "คลองนารายณ์": "DISTRICT",
  "คลองนิยมยาตรา": "DISTRICT",
  "คลองน้อย": "DISTRICT",
  "คลองน้ำเค็ม": "DISTRICT",
  "คลองน้ำใส": "DISTRICT",
  "คลองน้ำไหล": "DISTRICT",
  "คลองบางบอน": "DISTRICT",
  "คลองบางพราน": "DISTRICT",
  "คลองบ้านโพธิ์": "DISTRICT",
  "คลองประสงค์": "DISTRICT",
  "คลองประเวศ": "DISTRICT",
  "คลองปราบ": "DISTRICT",
  "คลองปาง": "DISTRICT",
  "คลองปูน": "DISTRICT",
  "คลองพน": "DISTRICT",
  "คลองพระยาบันลือ": "DISTRICT",
  "คลองพระอุดม": "DISTRICT",
  "คลองพลู": "DISTRICT",
  "คลองพา": "DISTRICT",
  "คลองพิไกร": "DISTRICT",
  "คลองมหานาค": "DISTRICT",
  "คลองมะพลับ": "DISTRICT",
  "คลองมะเดื่อ": "DISTRICT",
  "คลองมานิง": "DISTRICT",
  "คลองม่วง": "DISTRICT",
  "คลองยา": "DISTRICT",
  "คลองยาง": "DISTRICT",
  "คลองรี": "DISTRICT",
  "คลองลานพัฒนา": "DISTRICT",
  "คลองลุ": "DISTRICT",
  "คลองวัว": "DISTRICT",
  "คลองวาฬ": "DISTRICT",
  "คลองศก": "DISTRICT",
  "คลองสมบูรณ์": "DISTRICT",
  "คลองสระ": "DISTRICT",
  "คลองสระบัว": "DISTRICT",
  "คลองสวน": "DISTRICT",
  "คลองสวนพลู": "DISTRICT",
  "คลองสอง": "DISTRICT",
  "คลองสองต้นนุ่น": "DISTRICT",
  "คลองสะแก": "DISTRICT",
  "คลองสาน": "DISTRICT",
  "คลองสาม": "DISTRICT",
  "คลองสามประเวศ": "DISTRICT",
  "คลองสิบ": "DISTRICT",
  "คลองสิบสอง": "DISTRICT",
  "คลองสี่": "DISTRICT",
  "คลองหก": "DISTRICT",
  "คลองหนึ่ง": "DISTRICT",
  "คลองหรัง": "DISTRICT",
  "คลองหลวงแพ่ง": "DISTRICT",
  "คลองหลา": "DISTRICT",
  "คลองหอยโข่ง": "DISTRICT",
  "คลองหาด": "DISTRICT",
  "คลองหิน": "DISTRICT",
  "คลองหินปูน": "DISTRICT",
  "คลองห้า": "DISTRICT",
  "คลองอุดมชลจร": "DISTRICT",
  "คลองอู่ตะเภา": "DISTRICT",
  "คลองเกตุ": "DISTRICT",
  "คลองเกลือ": "DISTRICT",
  "คลองเขม้า": "DISTRICT",
  "คลองเขิน": "DISTRICT",
  "คลองเขื่อน": "DISTRICT",
  "คลองเคียน": "DISTRICT",
  "คลองเจ็ด": "DISTRICT",
  "คลองเจ้าคุณสิงห์": "DISTRICT",
  "คลองเฉลิม": "DISTRICT",
  "คลองเตย": "DISTRICT",
  "คลองเตยเหนือ": "DISTRICT",
  "คลองเปรง": "DISTRICT",
  "คลองเปียะ": "DISTRICT",
  "คลองเมือง": "DISTRICT",
  "คลองเรือ": "DISTRICT",
  "คลองเส": "DISTRICT",
  "คลองแดน": "DISTRICT",
  "คลองแม่ลาย": "DISTRICT",
  "คลองแห": "DISTRICT",
  "คลองโคน": "DISTRICT",
  "คลองโยง": "DISTRICT",
  "คลองใหญ่": "DISTRICT",
  "คลองใหม่": "DISTRICT",
  "คลองไก่เถื่อน": "DISTRICT",
  "คลองไทร": "DISTRICT",
  "คลองไผ่": "DISTRICT",
  "คลัง": "DISTRICT",
  "คลีกลิ้ง": "DISTRICT",
  "ควน": "DISTRICT",
  "ควนกรด": "DISTRICT",
  "ควนกลาง": "DISTRICT",
  "ควนกาหลง": "DISTRICT",
  "ควนขนุน": "DISTRICT",
  "ควนขัน": "DISTRICT",
  "ควนชะลิก": "DISTRICT",
  "ควนชุม": "DISTRICT",
  "ควนทอง": "DISTRICT",
  "ควนธานี": "DISTRICT",
  "ควนปริง": "DISTRICT",
  "ควนพัง": "DISTRICT",
  "ควนมะพร้าว": "DISTRICT",
  "ควนรู": "DISTRICT",
  "ควนลัง": "DISTRICT",
  "ควนศรี": "DISTRICT",
  "ควนสตอ": "DISTRICT",
  "ควนสุบรรณ": "DISTRICT",
  "ควนหนองคว้า": "DISTRICT",
  "ควนหนองหงษ์": "DISTRICT",
  "ควนเกย": "DISTRICT",
  "ควนเมา": "DISTRICT",
  "ควนโดน": "DISTRICT",
  "ควนโนรี": "DISTRICT",
  "ควนโพธิ์": "DISTRICT",
  "ควนโส": "DISTRICT",
  "ควร": "DISTRICT",
  "คอกกระบือ": "DISTRICT",
  "คอกควาย": "DISTRICT",
  "คอกช้าง": "DISTRICT",
  "คอทราย": "DISTRICT",
  "คอนกาม": "DISTRICT",
  "คอนฉิม": "DISTRICT",
  "คอนสวรรค์": "DISTRICT",
  "คอนสาย": "DISTRICT",
  "คอนสาร": "DISTRICT",
  "คอรุม": "DISTRICT",
  "คอลอตันหยง": "DISTRICT",
  "คอหงส์": "DISTRICT",
  "คอแลน": "DISTRICT",
  "คอโค": "DISTRICT",
  "คันธารราษฎร์": "DISTRICT",
  "คันธุลี": "DISTRICT",
  "คันนายาว": "DISTRICT",
  "คันโช้ง": "DISTRICT",
  "คันไร่": "DISTRICT",
  "คานหาม": "DISTRICT",
  "คาละแมะ": "DISTRICT",
  "คำขวาง": "DISTRICT",
  "คำครั่ง": "DISTRICT",
  "คำชะอี": "DISTRICT",
  "คำด้วง": "DISTRICT",
  "คำตากล้า": "DISTRICT",
  "คำนาดี": "DISTRICT",
  "คำน้ำสร้าง": "DISTRICT",
  "คำน้ำแซบ": "DISTRICT",
  "คำบก": "DISTRICT",
  "คำบง": "DISTRICT",
  "คำบ่อ": "DISTRICT",
  "คำป่าหลาย": "DISTRICT",
  "คำผง": "DISTRICT",
  "คำพระ": "DISTRICT",
  "คำพราน": "DISTRICT",
  "คำพอุง": "DISTRICT",
  "คำพี้": "DISTRICT",
  "คำม่วง": "DISTRICT",
  "คำสร้างเที่ยง": "DISTRICT",
  "คำสะอาด": "DISTRICT",
  "คำหยาด": "DISTRICT",
  "คำหว้า": "DISTRICT",
  "คำอาฮวน": "DISTRICT",
  "คำเขื่อนแก้ว": "DISTRICT",
  "คำเจริญ": "DISTRICT",
  "คำเตย": "DISTRICT",
  "คำเนียม": "DISTRICT",
  "คำเลาะ": "DISTRICT",
  "คำเหมือดแก้ว": "DISTRICT",
  "คำแก้ว": "DISTRICT",
  "คำแคน": "DISTRICT",
  "คำแมด": "DISTRICT",
  "คำโคกสูง": "DISTRICT",
  "คำโตนด": "DISTRICT",
  "คำโพน": "DISTRICT",
  "คำใหญ่": "DISTRICT",
  "คำไผ่": "DISTRICT",
  "คำไหล": "DISTRICT",
  "คำไฮ": "DISTRICT",
  "คำไฮใหญ่": "DISTRICT",
  "คีรีราษฎร์": "DISTRICT",
  "คีรีวง": "DISTRICT",
  "คีรีเขต": "DISTRICT",
  "คึกคัก": "DISTRICT",
  "คึมชาด": "DISTRICT",
  "คึมใหญ่": "DISTRICT",
  "คือเวียง": "DISTRICT",
  "คุยบ้านโอง": "DISTRICT",
  "คุยม่วง": "DISTRICT",
  "คุระ": "DISTRICT",
  "คุริง": "DISTRICT",
  "คุ้งกระถิน": "DISTRICT",
  "คุ้งตะเภา": "DISTRICT",
  "คุ้งน้ำวน": "DISTRICT",
  "คุ้งพยอม": "DISTRICT",
  "คุ้งลาน": "DISTRICT",
  "คุ้งสำเภา": "DISTRICT",
  "คุ้มเก่า": "DISTRICT",
  "คู": "DISTRICT",
  "คูขวาง": "DISTRICT",
  "คูขาด": "DISTRICT",
  "คูขุด": "DISTRICT",
  "คูคต": "DISTRICT",
  "คูคำ": "DISTRICT",
  "คูซอด": "DISTRICT",
  "คูตัน": "DISTRICT",
  "คูบ": "DISTRICT",
  "คูบัว": "DISTRICT",
  "คูบางหลวง": "DISTRICT",
  "คูสะคาม": "DISTRICT",
  "คูหา": "DISTRICT",
  "คูหาสวรรค์": "DISTRICT",
  "คูหาใต้": "DISTRICT",
  "คูเต่า": "DISTRICT",
  "คูเมือง": "DISTRICT",
  "คู้ฝั่งเหนือ": "DISTRICT",
  "คู้ยายหมี": "DISTRICT",
  "คู้ลำพัน": "DISTRICT",
  "คู้สลอด": "DISTRICT",
  "ค่ายบกหวาน": "DISTRICT",
  "ค้อทอง": "DISTRICT",
  "ค้อน้อย": "DISTRICT",
  "ค้อวัง": "DISTRICT",
  "ค้อเขียว": "DISTRICT",
  "ค้อเหนือ": "DISTRICT",
  "ค้อใต้": "DISTRICT",
  "ค้อใหญ่": "DISTRICT",
  "ค้างพลู": "DISTRICT",
  "ฆอเลาะ": "DISTRICT",
  "ฆะมัง": "DISTRICT",
  "ฆ้องชัยพัฒนา": "DISTRICT",
  "งอบ": "DISTRICT",
  "งัวบา": "DISTRICT",
  "งิม": "DISTRICT",
  "งิ้ว": "DISTRICT",
  "งิ้วงาม": "DISTRICT",
  "งิ้วด่อน": "DISTRICT",
  "งิ้วราย": "DISTRICT",
  "จ.ป.ร.": "DISTRICT",
  "จตุจักร": "DISTRICT",
  "จระเข้": "DISTRICT",
  "จระเข้หิน": "DISTRICT",
  "จรัส": "DISTRICT",
  "จริม": "DISTRICT",
  "จรเข้บัว": "DISTRICT",
  "จรเข้มาก": "DISTRICT",
  "จรเข้ร้อง": "DISTRICT",
  "จรเข้สามพัน": "DISTRICT",
  "จรเข้เผือก": "DISTRICT",
  "จรเข้ใหญ่": "DISTRICT",
  "จวบ": "DISTRICT",
  "จองคำ": "DISTRICT",
  "จองถนน": "DISTRICT",
  "จอมจันทร์": "DISTRICT",
  "จอมทอง": "DISTRICT",
  "จอมบึง": "DISTRICT",
  "จอมประทัด": "DISTRICT",
  "จอมปลวก": "DISTRICT",
  "จอมพระ": "DISTRICT",
  "จอมพล": "DISTRICT",
  "จอมศรี": "DISTRICT",
  "จอมสวรรค์": "DISTRICT",
  "จอมหมอกแก้ว": "DISTRICT",
  "จอหอ": "DISTRICT",
  "จอเบาะ": "DISTRICT",
  "จะกง": "DISTRICT",
  "จะกว๊ะ": "DISTRICT",
  "จะทิ้งพระ": "DISTRICT",
  "จะบังติกอ": "DISTRICT",
  "จะรัง": "DISTRICT",
  "จะแนะ": "DISTRICT",
  "จะแหน": "DISTRICT",
  "จะโหนง": "DISTRICT",
  "จักรวรรดิ์": "DISTRICT",
  "จักรสีห์": "DISTRICT",
  "จักราช": "DISTRICT",
  "จังหาร": "DISTRICT",
  "จันจว้า": "DISTRICT",
  "จันจว้าใต้": "DISTRICT",
  "จันดี": "DISTRICT",
  "จันดุม": "DISTRICT",
  "จันทนิมิต": "DISTRICT",
  "จันทบเพชร": "DISTRICT",
  "จันทรเกษม": "DISTRICT",
  "จันทร์เพ็ญ": "DISTRICT",
  "จันทิมา": "DISTRICT",
  "จันทึก": "DISTRICT",
  "จันทเขลม": "DISTRICT",
  "จันอัด": "DISTRICT",
  "จันเสน": "DISTRICT",
  "จางเหนือ": "DISTRICT",
  "จาน": "DISTRICT",
  "จานลาน": "DISTRICT",
  "จานแสนไชย": "DISTRICT",
  "จานใหญ่": "DISTRICT",
  "จารพัต": "DISTRICT",
  "จำปา": "DISTRICT",
  "จำปาขัน": "DISTRICT",
  "จำปาหล่อ": "DISTRICT",
  "จำปาโมง": "DISTRICT",
  "จำปี": "DISTRICT",
  "จำป่าหวาย": "DISTRICT",
  "จำลอง": "DISTRICT",
  "จิกดู่": "DISTRICT",
  "จิกสังข์ทอง": "DISTRICT",
  "จิกเทิง": "DISTRICT",
  "จีกแดก": "DISTRICT",
  "จุน": "DISTRICT",
  "จุมจัง": "DISTRICT",
  "จุมพล": "DISTRICT",
  "ฉมัน": "DISTRICT",
  "ฉลอง": "DISTRICT",
  "ฉลุง": "DISTRICT",
  "ฉวาง": "DISTRICT",
  "ฉาง": "DISTRICT",
  "ฉิมพลี": "DISTRICT",
  "ชนบท": "DISTRICT",
  "ชนะสงคราม": "DISTRICT",
  "ชนแดน": "DISTRICT",
  "ชมพู": "DISTRICT",
  "ชมภู": "DISTRICT",
  "ชมสะอาด": "DISTRICT",
  "ชมเจริญ": "DISTRICT",
  "ชลคราม": "DISTRICT",
  "ชอนน้อย": "DISTRICT",
  "ชอนม่วง": "DISTRICT",
  "ชอนสมบูรณ์": "DISTRICT",
  "ชอนสารเดช": "DISTRICT",
  "ชอนไพร": "DISTRICT",
  "ชะมวง": "DISTRICT",
  "ชะมาย": "DISTRICT",
  "ชะรัด": "DISTRICT",
  "ชะอม": "DISTRICT",
  "ชะอวด": "DISTRICT",
  "ชะอำ": "DISTRICT",
  "ชะเมา": "DISTRICT",
  "ชะแมบ": "DISTRICT",
  "ชะแล": "DISTRICT",
  "ชะแล้": "DISTRICT",
  "ชะโนด": "DISTRICT",
  "ชะโนดน้อย": "DISTRICT",
  "ชะไว": "DISTRICT",
  "ชัยจุมพล": "DISTRICT",
  "ชัยนาท": "DISTRICT",
  "ชัยนาม": "DISTRICT",
  "ชัยนารายณ์": "DISTRICT",
  "ชัยบาดาล": "DISTRICT",
  "ชัยบุรี": "DISTRICT",
  "ชัยพร": "DISTRICT",
  "ชัยพฤกษ์": "DISTRICT",
  "ชัยมงคล": "DISTRICT",
  "ชัยฤทธิ์": "DISTRICT",
  "ชัยเกษม": "DISTRICT",
  "ชากบก": "DISTRICT",
  "ชากพง": "DISTRICT",
  "ชากโดน": "DISTRICT",
  "ชากไทย": "DISTRICT",
  "ชาติตระการ": "DISTRICT",
  "ชานุมาน": "DISTRICT",
  "ชานุวรรณ": "DISTRICT",
  "ชายนา": "DISTRICT",
  "ชำ": "DISTRICT",
  "ชำฆ้อ": "DISTRICT",
  "ชำนิ": "DISTRICT",
  "ชำผักแพว": "DISTRICT",
  "ชำราก": "DISTRICT",
  "ชำแระ": "DISTRICT",
  "ชิงโค": "DISTRICT",
  "ชีทวน": "DISTRICT",
  "ชีน้ำร้าย": "DISTRICT",
  "ชีบน": "DISTRICT",
  "ชีลอง": "DISTRICT",
  "ชีวาน": "DISTRICT",
  "ชีวึก": "DISTRICT",
  "ชื่นชม": "DISTRICT",
  "ชุมช้าง": "DISTRICT",
  "ชุมตาบง": "DISTRICT",
  "ชุมพร": "DISTRICT",
  "ชุมพล": "DISTRICT",
  "ชุมพลบุรี": "DISTRICT",
  "ชุมพวง": "DISTRICT",
  "ชุมภูพร": "DISTRICT",
  "ชุมเห็ด": "DISTRICT",
  "ชุมแพ": "DISTRICT",
  "ชุมแสง": "DISTRICT",
  "ชุมแสงสงคราม": "DISTRICT",
  "ชุมโค": "DISTRICT",
  "ช่อง": "DISTRICT",
  "ช่องกุ่ม": "DISTRICT",
  "ช่องด่าน": "DISTRICT",
  "ช่องนนทรี": "DISTRICT",
  "ช่องลม": "DISTRICT",
  "ช่องสะเดา": "DISTRICT",
  "ช่องสะแก": "DISTRICT",
  "ช่องสามหมอ": "DISTRICT",
  "ช่องสาริกา": "DISTRICT",
  "ช่องเม็ก": "DISTRICT",
  "ช่องแค": "DISTRICT",
  "ช่องแคบ": "DISTRICT",
  "ช่องแมว": "DISTRICT",
  "ช่องไม้แก้ว": "DISTRICT",
  "ช่อผกา": "DISTRICT",
  "ช่อระกา": "DISTRICT",
  "ช่อแล": "DISTRICT",
  "ช่อแฮ": "DISTRICT",
  "ช่างปี่": "DISTRICT",
  "ช่างเคิ่ง": "DISTRICT",
  "ช่างเหล็ก": "DISTRICT",
  "ช้างกลาง": "DISTRICT",
  "ช้างขวา": "DISTRICT",
  "ช้างข้าม": "DISTRICT",
  "ช้างคลาน": "DISTRICT",
  "ช้างซ้าย": "DISTRICT",
  "ช้างตะลูด": "DISTRICT",
  "ช้างทอง": "DISTRICT",
  "ช้างทูน": "DISTRICT",
  "ช้างน้อย": "DISTRICT",
  "ช้างมิ่ง": "DISTRICT",
  "ช้างม่อย": "DISTRICT",
  "ช้างเผือก": "DISTRICT",
  "ช้างแรก": "DISTRICT",
  "ช้างใหญ่": "DISTRICT",
  "ช้างให้ตก": "DISTRICT",
  "ซับจำปา": "DISTRICT",
  "ซับตะเคียน": "DISTRICT",
  "ซับน้อย": "DISTRICT",
  "ซับพุทรา": "DISTRICT",
  "ซับมะกรูด": "DISTRICT",
  "ซับสนุ่น": "DISTRICT",
  "ซับสมบูรณ์": "DISTRICT",
  "ซับสมอทอด": "DISTRICT",
  "ซับสีทอง": "DISTRICT",
  "ซับเปิบ": "DISTRICT",
  "ซับใหญ่": "DISTRICT",
  "ซับไม้แดง": "DISTRICT",
  "ซากอ": "DISTRICT",
  "ซาง": "DISTRICT",
  "ซำ": "DISTRICT",
  "ซำยาง": "DISTRICT",
  "ซึ้ง": "DISTRICT",
  "ณรงค์": "DISTRICT",
  "ดงกระทงยาม": "DISTRICT",
  "ดงกลาง": "DISTRICT",
  "ดงขวาง": "DISTRICT",
  "ดงขี้เหล็ก": "DISTRICT",
  "ดงขุย": "DISTRICT",
  "ดงครั่งน้อย": "DISTRICT",
  "ดงครั่งใหญ่": "DISTRICT",
  "ดงคอน": "DISTRICT",
  "ดงคู่": "DISTRICT",
  "ดงชน": "DISTRICT",
  "ดงดวน": "DISTRICT",
  "ดงดำ": "DISTRICT",
  "ดงดินแดง": "DISTRICT",
  "ดงตะขบ": "DISTRICT",
  "ดงตะงาว": "DISTRICT",
  "ดงน้อย": "DISTRICT",
  "ดงบัง": "DISTRICT",
  "ดงประคำ": "DISTRICT",
  "ดงป่าคำ": "DISTRICT",
  "ดงพญา": "DISTRICT",
  "ดงพยุง": "DISTRICT",
  "ดงพระราม": "DISTRICT",
  "ดงพลอง": "DISTRICT",
  "ดงพลับ": "DISTRICT",
  "ดงมหาวัน": "DISTRICT",
  "ดงมอน": "DISTRICT",
  "ดงมะดะ": "DISTRICT",
  "ดงมะยาง": "DISTRICT",
  "ดงมะรุม": "DISTRICT",
  "ดงมะไฟ": "DISTRICT",
  "ดงมูล": "DISTRICT",
  "ดงมูลเหล็ก": "DISTRICT",
  "ดงยาง": "DISTRICT",
  "ดงรัก": "DISTRICT",
  "ดงละคร": "DISTRICT",
  "ดงลาน": "DISTRICT",
  "ดงลิง": "DISTRICT",
  "ดงสมบูรณ์": "DISTRICT",
  "ดงสวรรค์": "DISTRICT",
  "ดงสิงห์": "DISTRICT",
  "ดงสุวรรณ": "DISTRICT",
  "ดงหมู": "DISTRICT",
  "ดงหม้อทอง": "DISTRICT",
  "ดงหม้อทองใต้": "DISTRICT",
  "ดงหลวง": "DISTRICT",
  "ดงอีจาน": "DISTRICT",
  "ดงเค็ง": "DISTRICT",
  "ดงเจน": "DISTRICT",
  "ดงเจริญ": "DISTRICT",
  "ดงเดือย": "DISTRICT",
  "ดงเมือง": "DISTRICT",
  "ดงเมืองแอม": "DISTRICT",
  "ดงเย็น": "DISTRICT",
  "ดงเสือเหลือง": "DISTRICT",
  "ดงเหนือ": "DISTRICT",
  "ดงแคนใหญ่": "DISTRICT",
  "ดงแดง": "DISTRICT",
  "ดงใหญ่": "DISTRICT",
  "ดม": "DISTRICT",
  "ดวนใหญ่": "DISTRICT",
  "ดอกคำใต้": "DISTRICT",
  "ดอกล้ำ": "DISTRICT",
  "ดอกไม้": "DISTRICT",
  "ดองกำเม็ด": "DISTRICT",
  "ดอน": "DISTRICT",
  "ดอนกรวย": "DISTRICT",
  "ดอนกระเบื้อง": "DISTRICT",
  "ดอนกลอย": "DISTRICT",
  "ดอนกลาง": "DISTRICT",
  "ดอนกอก": "DISTRICT",
  "ดอนกำ": "DISTRICT",
  "ดอนกำยาน": "DISTRICT",
  "ดอนขมิ้น": "DISTRICT",
  "ดอนขวาง": "DISTRICT",
  "ดอนขุนห้วย": "DISTRICT",
  "ดอนข่อย": "DISTRICT",
  "ดอนคลัง": "DISTRICT",
  "ดอนคา": "DISTRICT",
  "ดอนงัว": "DISTRICT",
  "ดอนจาน": "DISTRICT",
  "ดอนจิก": "DISTRICT",
  "ดอนฉิมพลี": "DISTRICT",
  "ดอนชมพู": "DISTRICT",
  "ดอนชะเอม": "DISTRICT",
  "ดอนช้าง": "DISTRICT",
  "ดอนดั่ง": "DISTRICT",
  "ดอนดึง": "DISTRICT",
  "ดอนดู่": "DISTRICT",
  "ดอนตรอ": "DISTRICT",
  "ดอนตะหนิน": "DISTRICT",
  "ดอนตะโก": "DISTRICT",
  "ดอนตาล": "DISTRICT",
  "ดอนตาเพชร": "DISTRICT",
  "ดอนตูม": "DISTRICT",
  "ดอนทราย": "DISTRICT",
  "ดอนทอง": "DISTRICT",
  "ดอนนางหงส์": "DISTRICT",
  "ดอนประดู่": "DISTRICT",
  "ดอนปรู": "DISTRICT",
  "ดอนพุด": "DISTRICT",
  "ดอนพุทรา": "DISTRICT",
  "ดอนมดแดง": "DISTRICT",
  "ดอนมนต์": "DISTRICT",
  "ดอนมะนาว": "DISTRICT",
  "ดอนมะสังข์": "DISTRICT",
  "ดอนมะเกลือ": "DISTRICT",
  "ดอนมะโนรา": "DISTRICT",
  "ดอนมัน": "DISTRICT",
  "ดอนมูล": "DISTRICT",
  "ดอนยอ": "DISTRICT",
  "ดอนยาง": "DISTRICT",
  "ดอนยายหนู": "DISTRICT",
  "ดอนยายหอม": "DISTRICT",
  "ดอนยาวใหญ่": "DISTRICT",
  "ดอนรวก": "DISTRICT",
  "ดอนรัก": "DISTRICT",
  "ดอนลาน": "DISTRICT",
  "ดอนศรีชุม": "DISTRICT",
  "ดอนศิลา": "DISTRICT",
  "ดอนสมบูรณ์": "DISTRICT",
  "ดอนสัก": "DISTRICT",
  "ดอนหญ้านาง": "DISTRICT",
  "ดอนหวาย": "DISTRICT",
  "ดอนหว่าน": "DISTRICT",
  "ดอนหัน": "DISTRICT",
  "ดอนหัวฬ่อ": "DISTRICT",
  "ดอนหายโศก": "DISTRICT",
  "ดอนอะราง": "DISTRICT",
  "ดอนเกาะกา": "DISTRICT",
  "ดอนเงิน": "DISTRICT",
  "ดอนเจดีย์": "DISTRICT",
  "ดอนเตย": "DISTRICT",
  "ดอนเปา": "DISTRICT",
  "ดอนเมย": "DISTRICT",
  "ดอนเมือง": "DISTRICT",
  "ดอนแก้ว": "DISTRICT",
  "ดอนแตง": "DISTRICT",
  "ดอนแฝก": "DISTRICT",
  "ดอนแรด": "DISTRICT",
  "ดอนแร่": "DISTRICT",
  "ดอนแสลบ": "DISTRICT",
  "ดอนโพธิ์": "DISTRICT",
  "ดอนโพธิ์ทอง": "DISTRICT",
  "ดอนโอง": "DISTRICT",
  "ดอนใหญ่": "DISTRICT",
  "ดอนไก่ดี": "DISTRICT",
  "ดอนไผ่": "DISTRICT",
  "ดอนไฟ": "DISTRICT",
  "ดอยงาม": "DISTRICT",
  "ดอยลาน": "DISTRICT",
  "ดอยหล่อ": "DISTRICT",
  "ดอยฮาง": "DISTRICT",
  "ดอยเต่า": "DISTRICT",
  "ดอยแก้ว": "DISTRICT",
  "ดาวคะนอง": "DISTRICT",
  "ดาวเรือง": "DISTRICT",
  "ดาโต๊ะ": "DISTRICT",
  "ดำเนินสะดวก": "DISTRICT",
  "ดินจี่": "DISTRICT",
  "ดินดำ": "DISTRICT",
  "ดินทอง": "DISTRICT",
  "ดินอุดม": "DISTRICT",
  "ดินแดง": "DISTRICT",
  "ดีลัง": "DISTRICT",
  "ดีหลวง": "DISTRICT",
  "ดุซงญอ": "DISTRICT",
  "ดุมใหญ่": "DISTRICT",
  "ดุสิต": "DISTRICT",
  "ดูกอึ่ง": "DISTRICT",
  "ดูน": "DISTRICT",
  "ดูนสาด": "DISTRICT",
  "ดู่": "DISTRICT",
  "ดู่ทุ่ง": "DISTRICT",
  "ดู่น้อย": "DISTRICT",
  "ดู่พงษ์": "DISTRICT",
  "ดู่ลาด": "DISTRICT",
  "ดู่ใต้": "DISTRICT",
  "ด่าน": "DISTRICT",
  "ด่านขุนทด": "DISTRICT",
  "ด่านคล้า": "DISTRICT",
  "ด่านจาก": "DISTRICT",
  "ด่านชุมพล": "DISTRICT",
  "ด่านช้าง": "DISTRICT",
  "ด่านซ้าย": "DISTRICT",
  "ด่านทับตะโก": "DISTRICT",
  "ด่านนอก": "DISTRICT",
  "ด่านมะขามเตี้ย": "DISTRICT",
  "ด่านม่วงคำ": "DISTRICT",
  "ด่านศรีสุข": "DISTRICT",
  "ด่านสวี": "DISTRICT",
  "ด่านเกวียน": "DISTRICT",
  "ด่านแม่คำมัน": "DISTRICT",
  "ด่านแม่ละเมา": "DISTRICT",
  "ด่านแม่แฉลบ": "DISTRICT",
  "ด่านใน": "DISTRICT",
  "ตกพรม": "DISTRICT",
  "ตบหู": "DISTRICT",
  "ตรมไพร": "DISTRICT",
  "ตรวจ": "DISTRICT",
  "ตรอกนอง": "DISTRICT",
  "ตระกาจ": "DISTRICT",
  "ตระการ": "DISTRICT",
  "ตระเปียงเตีย": "DISTRICT",
  "ตระแสง": "DISTRICT",
  "ตรัง": "DISTRICT",
  "ตรำดม": "DISTRICT",
  "ตรีณรงค์": "DISTRICT",
  "ตรึม": "DISTRICT",
  "ตลาด": "DISTRICT",
  "ตลาดกรวด": "DISTRICT",
  "ตลาดกระทุ่มแบน": "DISTRICT",
  "ตลาดขวัญ": "DISTRICT",
  "ตลาดจินดา": "DISTRICT",
  "ตลาดน้อย": "DISTRICT",
  "ตลาดบางเขน": "DISTRICT",
  "ตลาดพลู": "DISTRICT",
  "ตลาดยอด": "DISTRICT",
  "ตลาดหลวง": "DISTRICT",
  "ตลาดเกรียบ": "DISTRICT",
  "ตลาดเหนือ": "DISTRICT",
  "ตลาดแร้ง": "DISTRICT",
  "ตลาดโพธิ์": "DISTRICT",
  "ตลาดใหญ่": "DISTRICT",
  "ตลาดใหม่": "DISTRICT",
  "ตลาดไชยา": "DISTRICT",
  "ตลาดไทร": "DISTRICT",
  "ตลิ่งงาม": "DISTRICT",
  "ตลิ่งชัน": "DISTRICT",
  "ตลุก": "DISTRICT",
  "ตลุกกลางทุ่ง": "DISTRICT",
  "ตลุกดู่": "DISTRICT",
  "ตลุกเทียม": "DISTRICT",
  "ตองปิด": "DISTRICT",
  "ตองโขบ": "DISTRICT",
  "ตอหลัง": "DISTRICT",
  "ตะกรบ": "DISTRICT",
  "ตะกั่วป่า": "DISTRICT",
  "ตะกาง": "DISTRICT",
  "ตะกาดเง้า": "DISTRICT",
  "ตะกุกเหนือ": "DISTRICT",
  "ตะกุกใต้": "DISTRICT",
  "ตะกุด": "DISTRICT",
  "ตะกุดไร": "DISTRICT",
  "ตะขบ": "DISTRICT",
  "ตะคร้อ": "DISTRICT",
  "ตะคร้ำเอน": "DISTRICT",
  "ตะคุ": "DISTRICT",
  "ตะค่า": "DISTRICT",
  "ตะดอบ": "DISTRICT",
  "ตะนาวศรี": "DISTRICT",
  "ตะบิ้ง": "DISTRICT",
  "ตะบ่าย": "DISTRICT",
  "ตะปอน": "DISTRICT",
  "ตะปอเยาะ": "DISTRICT",
  "ตะปาน": "DISTRICT",
  "ตะพง": "DISTRICT",
  "ตะพานหิน": "DISTRICT",
  "ตะมะยูง": "DISTRICT",
  "ตะลุง": "DISTRICT",
  "ตะลุบัน": "DISTRICT",
  "ตะลุโบะ": "DISTRICT",
  "ตะเครียะ": "DISTRICT",
  "ตะเคียน": "DISTRICT",
  "ตะเคียนทอง": "DISTRICT",
  "ตะเคียนปม": "DISTRICT",
  "ตะเคียนราม": "DISTRICT",
  "ตะเคียนเตี้ย": "DISTRICT",
  "ตะเคียนเลื่อน": "DISTRICT",
  "ตะเบาะ": "DISTRICT",
  "ตะเสะ": "DISTRICT",
  "ตะแบกบาน": "DISTRICT",
  "ตะแพน": "DISTRICT",
  "ตะโก": "DISTRICT",
  "ตะโกตาพิ": "DISTRICT",
  "ตะโกทอง": "DISTRICT",
  "ตะโละ": "DISTRICT",
  "ตะโละกาโปร์": "DISTRICT",
  "ตะโละดือรามัน": "DISTRICT",
  "ตะโละแมะนา": "DISTRICT",
  "ตะโละไกรทอง": "DISTRICT",
  "ตะโล๊ะหะลอ": "DISTRICT",
  "ตะโหมด": "DISTRICT",
  "ตันหยงจึงงา": "DISTRICT",
  "ตันหยงดาลอ": "DISTRICT",
  "ตันหยงมัส": "DISTRICT",
  "ตันหยงลิมอ": "DISTRICT",
  "ตันหยงลุโละ": "DISTRICT",
  "ตันหยงโป": "DISTRICT",
  "ตับเต่า": "DISTRICT",
  "ตั้งใจ": "DISTRICT",
  "ตากตก": "DISTRICT",
  "ตากฟ้า": "DISTRICT",
  "ตากออก": "DISTRICT",
  "ตากูก": "DISTRICT",
  "ตากแดด": "DISTRICT",
  "ตาก้อง": "DISTRICT",
  "ตาขัน": "DISTRICT",
  "ตาขีด": "DISTRICT",
  "ตาคง": "DISTRICT",
  "ตาคลี": "DISTRICT",
  "ตาจง": "DISTRICT",
  "ตาจั่น": "DISTRICT",
  "ตาชี": "DISTRICT",
  "ตาดกลอย": "DISTRICT",
  "ตาดข่า": "DISTRICT",
  "ตาดควัน": "DISTRICT",
  "ตาดทอง": "DISTRICT",
  "ตาตุม": "DISTRICT",
  "ตานิม": "DISTRICT",
  "ตานี": "DISTRICT",
  "ตาพระยา": "DISTRICT",
  "ตาลชุม": "DISTRICT",
  "ตาลสุม": "DISTRICT",
  "ตาลาน": "DISTRICT",
  "ตาลีอายร์": "DISTRICT",
  "ตาลเดี่ยว": "DISTRICT",
  "ตาลเตี้ย": "DISTRICT",
  "ตาลเนิ้ง": "DISTRICT",
  "ตาลเลียน": "DISTRICT",
  "ตาลเอน": "DISTRICT",
  "ตาลโกน": "DISTRICT",
  "ตาวัง": "DISTRICT",
  "ตาสัง": "DISTRICT",
  "ตาสิทธิ์": "DISTRICT",
  "ตาหลวง": "DISTRICT",
  "ตาหลังใน": "DISTRICT",
  "ตาอุด": "DISTRICT",
  "ตาอ็อง": "DISTRICT",
  "ตาเกษ": "DISTRICT",
  "ตาเกา": "DISTRICT",
  "ตาเซะ": "DISTRICT",
  "ตาเนาะปูเต๊ะ": "DISTRICT",
  "ตาเนาะแมเราะ": "DISTRICT",
  "ตาเนิน": "DISTRICT",
  "ตาเบา": "DISTRICT",
  "ตาเป๊ก": "DISTRICT",
  "ตาเมียง": "DISTRICT",
  "ตาเสา": "DISTRICT",
  "ตาแกะ": "DISTRICT",
  "ตาโกน": "DISTRICT",
  "ตำตัว": "DISTRICT",
  "ตำนาน": "DISTRICT",
  "ตำมะลัง": "DISTRICT",
  "ตำหนักธรรม": "DISTRICT",
  "ตำหรุ": "DISTRICT",
  "ตำแย": "DISTRICT",
  "ตุยง": "DISTRICT",
  "ตูม": "DISTRICT",
  "ตูมใต้": "DISTRICT",
  "ตูมใหญ่": "DISTRICT",
  "ต้นตาล": "DISTRICT",
  "ต้นธง": "DISTRICT",
  "ต้นธงชัย": "DISTRICT",
  "ต้นผึ้ง": "DISTRICT",
  "ต้นมะพร้าว": "DISTRICT",
  "ต้นมะม่วง": "DISTRICT",
  "ต้นยวน": "DISTRICT",
  "ต้นเปา": "DISTRICT",
  "ต้นโพธิ์": "DISTRICT",
  "ต้า": "DISTRICT",
  "ต้าผามอก": "DISTRICT",
  "ถนน": "DISTRICT",
  "ถนนขาด": "DISTRICT",
  "ถนนนครไชยศรี": "DISTRICT",
  "ถนนพญาไท": "DISTRICT",
  "ถนนหัก": "DISTRICT",
  "ถนนเพชรบุรี": "DISTRICT",
  "ถนนโพธิ์": "DISTRICT",
  "ถนนใหญ่": "DISTRICT",
  "ถลุงเหล็ก": "DISTRICT",
  "ถอนสมอ": "DISTRICT",
  "ถาวร": "DISTRICT",
  "ถาวรวัฒนา": "DISTRICT",
  "ถืมตอง": "DISTRICT",
  "ถ่อนนาลับ": "DISTRICT",
  "ถ้ำ": "DISTRICT",
  "ถ้ำกระต่ายทอง": "DISTRICT",
  "ถ้ำฉลอง": "DISTRICT",
  "ถ้ำทองหลาง": "DISTRICT",
  "ถ้ำทะลุ": "DISTRICT",
  "ถ้ำน้ำผุด": "DISTRICT",
  "ถ้ำพรรณรา": "DISTRICT",
  "ถ้ำรงค์": "DISTRICT",
  "ถ้ำลอด": "DISTRICT",
  "ถ้ำวัวแดง": "DISTRICT",
  "ถ้ำสิงขร": "DISTRICT",
  "ถ้ำสิงห์": "DISTRICT",
  "ถ้ำเจริญ": "DISTRICT",
  "ถ้ำแข้": "DISTRICT",
  "ถ้ำใหญ่": "DISTRICT",
  "ทมนางาม": "DISTRICT",
  "ทมอ": "DISTRICT",
  "ทรงคนอง": "DISTRICT",
  "ทรงธรรม": "DISTRICT",
  "ทรัพย์ทวี": "DISTRICT",
  "ทรัพย์พระยา": "DISTRICT",
  "ทรัพย์อนันต์": "DISTRICT",
  "ทรัพย์ไพวัลย์": "DISTRICT",
  "ทรายกองดิน": "DISTRICT",
  "ทรายกองดินใต้": "DISTRICT",
  "ทรายขาว": "DISTRICT",
  "ทรายทอง": "DISTRICT",
  "ทรายมูล": "DISTRICT",
  "ทรายแดง": "DISTRICT",
  "ทวีวัฒนา": "DISTRICT",
  "ทองมงคล": "DISTRICT",
  "ทองหลาง": "DISTRICT",
  "ทองเอน": "DISTRICT",
  "ทอนหงส์": "DISTRICT",
  "ทะนง": "DISTRICT",
  "ทะเมนชัย": "DISTRICT",
  "ทะเลชุบศร": "DISTRICT",
  "ทะเลทรัพย์": "DISTRICT",
  "ทะเลน้อย": "DISTRICT",
  "ทะเลบก": "DISTRICT",
  "ทะเลวังวัด": "DISTRICT",
  "ทับกฤช": "DISTRICT",
  "ทับกฤชใต้": "DISTRICT",
  "ทับกวาง": "DISTRICT",
  "ทับกุง": "DISTRICT",
  "ทับคล้อ": "DISTRICT",
  "ทับคาง": "DISTRICT",
  "ทับช้าง": "DISTRICT",
  "ทับตีเหล็ก": "DISTRICT",
  "ทับทัน": "DISTRICT",
  "ทับน้ำ": "DISTRICT",
  "ทับปริก": "DISTRICT",
  "ทับปุด": "DISTRICT",
  "ทับผึ้ง": "DISTRICT",
  "ทับพริก": "DISTRICT",
  "ทับมา": "DISTRICT",
  "ทับยา": "DISTRICT",
  "ทับยายเชียง": "DISTRICT",
  "ทับยาว": "DISTRICT",
  "ทับสวาย": "DISTRICT",
  "ทับสะแก": "DISTRICT",
  "ทับหมัน": "DISTRICT",
  "ทับเที่ยง": "DISTRICT",
  "ทับใต้": "DISTRICT",
  "ทับใหญ่": "DISTRICT",
  "ทับไทร": "DISTRICT",
  "ทัพทัน": "DISTRICT",
  "ทัพรั้ง": "DISTRICT",
  "ทัพราช": "DISTRICT",
  "ทัพหลวง": "DISTRICT",
  "ทัพเสด็จ": "DISTRICT",
  "ทัพไทย": "DISTRICT",
  "ทากาศ": "DISTRICT",
  "ทาขุมเงิน": "DISTRICT",
  "ทางกลาง": "DISTRICT",
  "ทางขวาง": "DISTRICT",
  "ทางช้าง": "DISTRICT",
  "ทางพระ": "DISTRICT",
  "ทางพูน": "DISTRICT",
  "ทางเกวียน": "DISTRICT",
  "ทาทุ่งหลวง": "DISTRICT",
  "ทานตะวัน": "DISTRICT",
  "ทาปลาดุก": "DISTRICT",
  "ทาม": "DISTRICT",
  "ทาสบเส้า": "DISTRICT",
  "ทาเหนือ": "DISTRICT",
  "ทาแม่ลอบ": "DISTRICT",
  "ทำนบ": "DISTRICT",
  "ที่วัง": "DISTRICT",
  "ทุ่ง": "DISTRICT",
  "ทุ่งกง": "DISTRICT",
  "ทุ่งกระตาดพัฒนา": "DISTRICT",
  "ทุ่งกระบือ": "DISTRICT",
  "ทุ่งกระบ่ำ": "DISTRICT",
  "ทุ่งกระพังโหม": "DISTRICT",
  "ทุ่งกระเชาะ": "DISTRICT",
  "ทุ่งกระเต็น": "DISTRICT",
  "ทุ่งกล้วย": "DISTRICT",
  "ทุ่งกวาว": "DISTRICT",
  "ทุ่งกว๋าว": "DISTRICT",
  "ทุ่งกุลา": "DISTRICT",
  "ทุ่งก่อ": "DISTRICT",
  "ทุ่งขนาน": "DISTRICT",
  "ทุ่งขมิ้น": "DISTRICT",
  "ทุ่งขวาง": "DISTRICT",
  "ทุ่งข้าวพวง": "DISTRICT",
  "ทุ่งครุ": "DISTRICT",
  "ทุ่งคลอง": "DISTRICT",
  "ทุ่งคลี": "DISTRICT",
  "ทุ่งคล้า": "DISTRICT",
  "ทุ่งควายกิน": "DISTRICT",
  "ทุ่งคอก": "DISTRICT",
  "ทุ่งคา": "DISTRICT",
  "ทุ่งคาวัด": "DISTRICT",
  "ทุ่งคาโงก": "DISTRICT",
  "ทุ่งค่าย": "DISTRICT",
  "ทุ่งงาม": "DISTRICT",
  "ทุ่งจังหัน": "DISTRICT",
  "ทุ่งชมพู": "DISTRICT",
  "ทุ่งช้าง": "DISTRICT",
  "ทุ่งตะไคร": "DISTRICT",
  "ทุ่งตำเสา": "DISTRICT",
  "ทุ่งต่อ": "DISTRICT",
  "ทุ่งต้อม": "DISTRICT",
  "ทุ่งทราย": "DISTRICT",
  "ทุ่งทอง": "DISTRICT",
  "ทุ่งท่าช้าง": "DISTRICT",
  "ทุ่งนนทรี": "DISTRICT",
  "ทุ่งนางาม": "DISTRICT",
  "ทุ่งนางโอก": "DISTRICT",
  "ทุ่งนารี": "DISTRICT",
  "ทุ่งนาเลา": "DISTRICT",
  "ทุ่งนาไทย": "DISTRICT",
  "ทุ่งนุ้ย": "DISTRICT",
  "ทุ่งน้อย": "DISTRICT",
  "ทุ่งน้าว": "DISTRICT",
  "ทุ่งบัว": "DISTRICT",
  "ทุ่งบุหลัง": "DISTRICT",
  "ทุ่งปรัง": "DISTRICT",
  "ทุ่งปี้": "DISTRICT",
  "ทุ่งผาสุข": "DISTRICT",
  "ทุ่งผึ้ง": "DISTRICT",
  "ทุ่งฝน": "DISTRICT",
  "ทุ่งฝาย": "DISTRICT",
  "ทุ่งพง": "DISTRICT",
  "ทุ่งพญาไท": "DISTRICT",
  "ทุ่งพระ": "DISTRICT",
  "ทุ่งพระยา": "DISTRICT",
  "ทุ่งพลา": "DISTRICT",
  "ทุ่งพอ": "DISTRICT",
  "ทุ่งพึ่ง": "DISTRICT",
  "ทุ่งมน": "DISTRICT",
  "ทุ่งมหาเจริญ": "DISTRICT",
  "ทุ่งมหาเมฆ": "DISTRICT",
  "ทุ่งมะพร้าว": "DISTRICT",
  "ทุ่งยั้ง": "DISTRICT",
  "ทุ่งยางเมือง": "DISTRICT",
  "ทุ่งยาว": "DISTRICT",
  "ทุ่งรวงทอง": "DISTRICT",
  "ทุ่งระยะ": "DISTRICT",
  "ทุ่งรัง": "DISTRICT",
  "ทุ่งลาน": "DISTRICT",
  "ทุ่งลุยลาย": "DISTRICT",
  "ทุ่งลูกนก": "DISTRICT",
  "ทุ่งวัง": "DISTRICT",
  "ทุ่งวัดดอน": "DISTRICT",
  "ทุ่งศรี": "DISTRICT",
  "ทุ่งศรีทอง": "DISTRICT",
  "ทุ่งศรีเมือง": "DISTRICT",
  "ทุ่งสง": "DISTRICT",
  "ทุ่งสมอ": "DISTRICT",
  "ทุ่งสว่าง": "DISTRICT",
  "ทุ่งสองห้อง": "DISTRICT",
  "ทุ่งสะโตก": "DISTRICT",
  "ทุ่งสัง": "DISTRICT",
  "ทุ่งสุขลา": "DISTRICT",
  "ทุ่งหมอ": "DISTRICT",
  "ทุ่งหลวง": "DISTRICT",
  "ทุ่งหวัง": "DISTRICT",
  "ทุ่งหว้า": "DISTRICT",
  "ทุ่งหัวช้าง": "DISTRICT",
  "ทุ่งอรุณ": "DISTRICT",
  "ทุ่งฮั้ว": "DISTRICT",
  "ทุ่งเขาหลวง": "DISTRICT",
  "ทุ่งเตา": "DISTRICT",
  "ทุ่งเตาใหม่": "DISTRICT",
  "ทุ่งเทิง": "DISTRICT",
  "ทุ่งเบญจา": "DISTRICT",
  "ทุ่งเสลี่ยม": "DISTRICT",
  "ทุ่งแก": "DISTRICT",
  "ทุ่งแค้ว": "DISTRICT",
  "ทุ่งแต้": "DISTRICT",
  "ทุ่งแล้ง": "DISTRICT",
  "ทุ่งแสงทอง": "DISTRICT",
  "ทุ่งโป่ง": "DISTRICT",
  "ทุ่งโพ": "DISTRICT",
  "ทุ่งโพธิ์": "DISTRICT",
  "ทุ่งโฮ้ง": "DISTRICT",
  "ทุ่งใส": "DISTRICT",
  "ทุ่งใหญ่": "DISTRICT",
  "ทุ่งไชย": "DISTRICT",
  "ทุ่งไทรทอง": "DISTRICT",
  "ทุ่ม": "DISTRICT",
  "ท่ากกแดง": "DISTRICT",
  "ท่ากระชับ": "DISTRICT",
  "ท่ากระดาน": "DISTRICT",
  "ท่ากระเสริม": "DISTRICT",
  "ท่ากว้าง": "DISTRICT",
  "ท่ากำชำ": "DISTRICT",
  "ท่ากุ่ม": "DISTRICT",
  "ท่ากูบ": "DISTRICT",
  "ท่าก้อน": "DISTRICT",
  "ท่าก๊อ": "DISTRICT",
  "ท่าขนอน": "DISTRICT",
  "ท่าขนาน": "DISTRICT",
  "ท่าขนุน": "DISTRICT",
  "ท่าขมิ้น": "DISTRICT",
  "ท่าขอนยาง": "DISTRICT",
  "ท่าขึ้น": "DISTRICT",
  "ท่าขุนราม": "DISTRICT",
  "ท่าข้าม": "DISTRICT",
  "ท่าข้าวเปลือก": "DISTRICT",
  "ท่าคล้อ": "DISTRICT",
  "ท่าคอย": "DISTRICT",
  "ท่าคันโท": "DISTRICT",
  "ท่าคา": "DISTRICT",
  "ท่าค้อ": "DISTRICT",
  "ท่างาม": "DISTRICT",
  "ท่างิ้ว": "DISTRICT",
  "ท่าจะหลุง": "DISTRICT",
  "ท่าจำปา": "DISTRICT",
  "ท่าจำปี": "DISTRICT",
  "ท่าจีน": "DISTRICT",
  "ท่าฉนวน": "DISTRICT",
  "ท่าฉลอม": "DISTRICT",
  "ท่าฉาง": "DISTRICT",
  "ท่าชนะ": "DISTRICT",
  "ท่าชะมวง": "DISTRICT",
  "ท่าชัย": "DISTRICT",
  "ท่าชี": "DISTRICT",
  "ท่าชุมพล": "DISTRICT",
  "ท่าช้าง": "DISTRICT",
  "ท่าช้างคล้อง": "DISTRICT",
  "ท่าซอม": "DISTRICT",
  "ท่าซัก": "DISTRICT",
  "ท่าซุง": "DISTRICT",
  "ท่าดอกคำ": "DISTRICT",
  "ท่าดินดำ": "DISTRICT",
  "ท่าดินแดง": "DISTRICT",
  "ท่าดี": "DISTRICT",
  "ท่าด้วง": "DISTRICT",
  "ท่าตลาด": "DISTRICT",
  "ท่าตอ": "DISTRICT",
  "ท่าตอน": "DISTRICT",
  "ท่าตะคร้อ": "DISTRICT",
  "ท่าตะเกียบ": "DISTRICT",
  "ท่าตะเภา": "DISTRICT",
  "ท่าตะโก": "DISTRICT",
  "ท่าตาล": "DISTRICT",
  "ท่าตำหนัก": "DISTRICT",
  "ท่าตุ้ม": "DISTRICT",
  "ท่าตูม": "DISTRICT",
  "ท่าถ่าน": "DISTRICT",
  "ท่าทราย": "DISTRICT",
  "ท่าทอง": "DISTRICT",
  "ท่าทองหลาง": "DISTRICT",
  "ท่าทองใหม่": "DISTRICT",
  "ท่าธง": "DISTRICT",
  "ท่านัด": "DISTRICT",
  "ท่านั่ง": "DISTRICT",
  "ท่านา": "DISTRICT",
  "ท่านางงาม": "DISTRICT",
  "ท่านางแนว": "DISTRICT",
  "ท่าน้าว": "DISTRICT",
  "ท่าน้ำ": "DISTRICT",
  "ท่าน้ำอ้อย": "DISTRICT",
  "ท่าบอน": "DISTRICT",
  "ท่าบัว": "DISTRICT",
  "ท่าบุญมี": "DISTRICT",
  "ท่าบ่อ": "DISTRICT",
  "ท่าบ่อสงคราม": "DISTRICT",
  "ท่าประจะ": "DISTRICT",
  "ท่าประดู่": "DISTRICT",
  "ท่าปลา": "DISTRICT",
  "ท่าผา": "DISTRICT",
  "ท่าผาปุ้ม": "DISTRICT",
  "ท่าพญา": "DISTRICT",
  "ท่าพยา": "DISTRICT",
  "ท่าพระ": "DISTRICT",
  "ท่าพระยา": "DISTRICT",
  "ท่าพริก": "DISTRICT",
  "ท่าพล": "DISTRICT",
  "ท่าพลับ": "DISTRICT",
  "ท่าพี่เลี้ยง": "DISTRICT",
  "ท่าพุทรา": "DISTRICT",
  "ท่ามะกา": "DISTRICT",
  "ท่ามะขาม": "DISTRICT",
  "ท่ามะนาว": "DISTRICT",
  "ท่ามะปราง": "DISTRICT",
  "ท่ามะพลา": "DISTRICT",
  "ท่ามะเขือ": "DISTRICT",
  "ท่ามะเดื่อ": "DISTRICT",
  "ท่ามะเฟือง": "DISTRICT",
  "ท่ามะไฟหวาน": "DISTRICT",
  "ท่ามิหรำ": "DISTRICT",
  "ท่าม่วง": "DISTRICT",
  "ท่ายาง": "DISTRICT",
  "ท่าระหัด": "DISTRICT",
  "ท่าราบ": "DISTRICT",
  "ท่าลาด": "DISTRICT",
  "ท่าลาดขาว": "DISTRICT",
  "ท่าลี่": "DISTRICT",
  "ท่าล้อ": "DISTRICT",
  "ท่าวัง": "DISTRICT",
  "ท่าวังตาล": "DISTRICT",
  "ท่าวังทอง": "DISTRICT",
  "ท่าวังผา": "DISTRICT",
  "ท่าวังพร้าว": "DISTRICT",
  "ท่าวัด": "DISTRICT",
  "ท่าวาสุกรี": "DISTRICT",
  "ท่าวุ้ง": "DISTRICT",
  "ท่าศาลา": "DISTRICT",
  "ท่าศิลา": "DISTRICT",
  "ท่าสวรรค์": "DISTRICT",
  "ท่าสว่าง": "DISTRICT",
  "ท่าสองคอน": "DISTRICT",
  "ท่าสองยาง": "DISTRICT",
  "ท่าสะท้อน": "DISTRICT",
  "ท่าสะบ้า": "DISTRICT",
  "ท่าสะอาด": "DISTRICT",
  "ท่าสะอ้าน": "DISTRICT",
  "ท่าสะแก": "DISTRICT",
  "ท่าสัก": "DISTRICT",
  "ท่าสาป": "DISTRICT",
  "ท่าสาย": "DISTRICT",
  "ท่าสายลวด": "DISTRICT",
  "ท่าสีดา": "DISTRICT",
  "ท่าสุด": "DISTRICT",
  "ท่าหมอไทร": "DISTRICT",
  "ท่าหมื่นราม": "DISTRICT",
  "ท่าหลวง": "DISTRICT",
  "ท่าหาดยาว": "DISTRICT",
  "ท่าหิน": "DISTRICT",
  "ท่าหินโงม": "DISTRICT",
  "ท่าฬ่อ": "DISTRICT",
  "ท่าอยู่": "DISTRICT",
  "ท่าอิฐ": "DISTRICT",
  "ท่าอิบุญ": "DISTRICT",
  "ท่าอุเทน": "DISTRICT",
  "ท่าอุแท": "DISTRICT",
  "ท่าอ่าง": "DISTRICT",
  "ท่าเกวียน": "DISTRICT",
  "ท่าเกษม": "DISTRICT",
  "ท่าเคย": "DISTRICT",
  "ท่าเจ้าสนุก": "DISTRICT",
  "ท่าเดื่อ": "DISTRICT",
  "ท่าเทววงษ์": "DISTRICT",
  "ท่าเมือง": "DISTRICT",
  "ท่าเยี่ยม": "DISTRICT",
  "ท่าเรือ": "DISTRICT",
  "ท่าเสน": "DISTRICT",
  "ท่าเสม็ด": "DISTRICT",
  "ท่าเสา": "DISTRICT",
  "ท่าแค": "DISTRICT",
  "ท่าแซะ": "DISTRICT",
  "ท่าแดง": "DISTRICT",
  "ท่าแฝก": "DISTRICT",
  "ท่าแพ": "DISTRICT",
  "ท่าแยก": "DISTRICT",
  "ท่าแร่": "DISTRICT",
  "ท่าแร้ง": "DISTRICT",
  "ท่าแร้งออก": "DISTRICT",
  "ท่าแลง": "DISTRICT",
  "ท่าโพ": "DISTRICT",
  "ท่าโพธิ์": "DISTRICT",
  "ท่าโพธิ์ชัย": "DISTRICT",
  "ท่าโพธิ์ศรี": "DISTRICT",
  "ท่าโรง": "DISTRICT",
  "ท่าโรงช้าง": "DISTRICT",
  "ท่าโสม": "DISTRICT",
  "ท่าใหญ่": "DISTRICT",
  "ท่าใหม่": "DISTRICT",
  "ท่าไข่": "DISTRICT",
  "ท่าไม้": "DISTRICT",
  "ท่าไม้รวก": "DISTRICT",
  "ท่าไร่": "DISTRICT",
  "ท่าไห": "DISTRICT",
  "ท้องฟ้า": "DISTRICT",
  "ท้องลำเจียก": "DISTRICT",
  "ท้องเนียน": "DISTRICT",
  "ท้อแท้": "DISTRICT",
  "ท้ายช้าง": "DISTRICT",
  "ท้ายดง": "DISTRICT",
  "ท้ายตลาด": "DISTRICT",
  "ท้ายทุ่ง": "DISTRICT",
  "ท้ายน้ำ": "DISTRICT",
  "ท้ายบ้าน": "DISTRICT",
  "ท้ายบ้านใหม่": "DISTRICT",
  "ท้ายสำเภา": "DISTRICT",
  "ท้ายหาด": "DISTRICT",
  "ท้ายเกาะ": "DISTRICT",
  "ท้ายเหมือง": "DISTRICT",
  "ธงชัย": "DISTRICT",
  "ธงชัยเหนือ": "DISTRICT",
  "ธงธานี": "DISTRICT",
  "ธนู": "DISTRICT",
  "ธรรมศาลา": "DISTRICT",
  "ธรรมามูล": "DISTRICT",
  "ธรรมเสน": "DISTRICT",
  "ธวัชบุรี": "DISTRICT",
  "ธัญญา": "DISTRICT",
  "ธาตุ": "DISTRICT",
  "ธาตุทอง": "DISTRICT",
  "ธาตุนาเวง": "DISTRICT",
  "ธาตุน้อย": "DISTRICT",
  "ธาตุพนม": "DISTRICT",
  "ธาตุพนมเหนือ": "DISTRICT",
  "ธาตุเชิงชุม": "DISTRICT",
  "ธานี": "DISTRICT",
  "ธารคีรี": "DISTRICT",
  "ธารทหาร": "DISTRICT",
  "ธารทอง": "DISTRICT",
  "ธารน้ำทิพย์": "DISTRICT",
  "ธารปราสาท": "DISTRICT",
  "ธารละหลอด": "DISTRICT",
  "ธารเกษม": "DISTRICT",
  "ธารโต": "DISTRICT",
  "ธำมรงค์": "DISTRICT",
  "นกออก": "DISTRICT",
  "นครชัยศรี": "DISTRICT",
  "นครชุม": "DISTRICT",
  "นครชุมน์": "DISTRICT",
  "นครนายก": "DISTRICT",
  "นครปฐม": "DISTRICT",
  "นครป่าหมาก": "DISTRICT",
  "นครสวรรค์ตก": "DISTRICT",
  "นครสวรรค์ออก": "DISTRICT",
  "นครหลวง": "DISTRICT",
  "นครเจดีย์": "DISTRICT",
  "นครเดิฐ": "DISTRICT",
  "นครไทย": "DISTRICT",
  "นนทรี": "DISTRICT",
  "นนทรีย์": "DISTRICT",
  "นบปริง": "DISTRICT",
  "นบพิตำ": "DISTRICT",
  "นพรัตน์": "DISTRICT",
  "นรสิงห์": "DISTRICT",
  "นราภิรมย์": "DISTRICT",
  "นวมินทร์": "DISTRICT",
  "นวลจันทร์": "DISTRICT",
  "นอกเมือง": "DISTRICT",
  "นากระตาม": "DISTRICT",
  "นากระแซง": "DISTRICT",
  "นากลาง": "DISTRICT",
  "นากว้าง": "DISTRICT",
  "นากอก": "DISTRICT",
  "นากะชะ": "DISTRICT",
  "นากั้ง": "DISTRICT",
  "นาขมิ้น": "DISTRICT",
  "นาขยาด": "DISTRICT",
  "นาขอม": "DISTRICT",
  "นาขา": "DISTRICT",
  "นาขาม": "DISTRICT",
  "นาขุนไกร": "DISTRICT",
  "นาขุม": "DISTRICT",
  "นาข่า": "DISTRICT",
  "นาข้าวเสีย": "DISTRICT",
  "นาครัว": "DISTRICT",
  "นาคอเรือ": "DISTRICT",
  "นาคา": "DISTRICT",
  "นาคาย": "DISTRICT",
  "นาคำ": "DISTRICT",
  "นาคำใหญ่": "DISTRICT",
  "นาคำไฮ": "DISTRICT",
  "นาคู": "DISTRICT",
  "นาคูณใหญ่": "DISTRICT",
  "นาคู่": "DISTRICT",
  "นางตะเคียน": "DISTRICT",
  "นางบวช": "DISTRICT",
  "นางพญา": "DISTRICT",
  "นางรอง": "DISTRICT",
  "นางรำ": "DISTRICT",
  "นางลือ": "DISTRICT",
  "นางหลง": "DISTRICT",
  "นางัว": "DISTRICT",
  "นางั่ว": "DISTRICT",
  "นางาม": "DISTRICT",
  "นางิ้ว": "DISTRICT",
  "นางแก้ว": "DISTRICT",
  "นางแดด": "DISTRICT",
  "นางแล": "DISTRICT",
  "นาจอมเทียน": "DISTRICT",
  "นาจะหลวย": "DISTRICT",
  "นาจักร": "DISTRICT",
  "นาจาน": "DISTRICT",
  "นาจารย์": "DISTRICT",
  "นาจำปา": "DISTRICT",
  "นาจิก": "DISTRICT",
  "นาชะอัง": "DISTRICT",
  "นาชุมเห็ด": "DISTRICT",
  "นาชุมแสง": "DISTRICT",
  "นาซอ": "DISTRICT",
  "นาซาว": "DISTRICT",
  "นาซำ": "DISTRICT",
  "นาซ่าว": "DISTRICT",
  "นาดง": "DISTRICT",
  "นาดอกคำ": "DISTRICT",
  "นาดินดำ": "DISTRICT",
  "นาดี": "DISTRICT",
  "นาดูน": "DISTRICT",
  "นาด่าน": "DISTRICT",
  "นาด้วง": "DISTRICT",
  "นาตงวัฒนา": "DISTRICT",
  "นาตาขวัญ": "DISTRICT",
  "นาตาล": "DISTRICT",
  "นาตาล่วง": "DISTRICT",
  "นาถ่อน": "DISTRICT",
  "นาทม": "DISTRICT",
  "นาทราย": "DISTRICT",
  "นาทวี": "DISTRICT",
  "นาทอง": "DISTRICT",
  "นาทอน": "DISTRICT",
  "นาทะนุง": "DISTRICT",
  "นาทัน": "DISTRICT",
  "นาทับ": "DISTRICT",
  "นาทับไฮ": "DISTRICT",
  "นาทุ่ง": "DISTRICT",
  "นาท่อม": "DISTRICT",
  "นาท่ามเหนือ": "DISTRICT",
  "นาท่ามใต้": "DISTRICT",
  "นานกกก": "DISTRICT",
  "นานวน": "DISTRICT",
  "นานวล": "DISTRICT",
  "นานาค": "DISTRICT",
  "นาน้อย": "DISTRICT",
  "นาบอน": "DISTRICT",
  "นาบัว": "DISTRICT",
  "นาบินหลา": "DISTRICT",
  "นาบ่อคำ": "DISTRICT",
  "นาประดู่": "DISTRICT",
  "นาปรัง": "DISTRICT",
  "นาปะขอ": "DISTRICT",
  "นาปัง": "DISTRICT",
  "นาปู่ป้อม": "DISTRICT",
  "นาป่า": "DISTRICT",
  "นาป่าแซง": "DISTRICT",
  "นาผือ": "DISTRICT",
  "นาฝาย": "DISTRICT",
  "นาพญา": "DISTRICT",
  "นาพรุ": "DISTRICT",
  "นาพละ": "DISTRICT",
  "นาพันสาม": "DISTRICT",
  "นาพิน": "DISTRICT",
  "นาพึง": "DISTRICT",
  "นาพูน": "DISTRICT",
  "นาพู่": "DISTRICT",
  "นาภู": "DISTRICT",
  "นามน": "DISTRICT",
  "นามะตูม": "DISTRICT",
  "นามะเขือ": "DISTRICT",
  "นามะเฟือง": "DISTRICT",
  "นามาลา": "DISTRICT",
  "นาม่วง": "DISTRICT",
  "นาม่อง": "DISTRICT",
  "นายม": "DISTRICT",
  "นายาง": "DISTRICT",
  "นายางกลัก": "DISTRICT",
  "นายายอาม": "DISTRICT",
  "นายาว": "DISTRICT",
  "นายูง": "DISTRICT",
  "นาราชควาย": "DISTRICT",
  "นารุ่ง": "DISTRICT",
  "นาวง": "DISTRICT",
  "นาวัง": "DISTRICT",
  "นาวังหิน": "DISTRICT",
  "นาวุ้ง": "DISTRICT",
  "นาสนุ่น": "DISTRICT",
  "นาสวน": "DISTRICT",
  "นาสวรรค์": "DISTRICT",
  "นาสะอาด": "DISTRICT",
  "นาสะเม็ง": "DISTRICT",
  "นาสะแบง": "DISTRICT",
  "นาสะไม": "DISTRICT",
  "นาสะไมย์": "DISTRICT",
  "นาสัก": "DISTRICT",
  "นาสาร": "DISTRICT",
  "นาสิงห์": "DISTRICT",
  "นาสี": "DISTRICT",
  "นาสีนวน": "DISTRICT",
  "นาสีนวล": "DISTRICT",
  "นาส่วง": "DISTRICT",
  "นาหนองทุ่ม": "DISTRICT",
  "นาหนองไผ่": "DISTRICT",
  "นาหนัง": "DISTRICT",
  "นาหนาด": "DISTRICT",
  "นาหมอบุญ": "DISTRICT",
  "นาหมอม้า": "DISTRICT",
  "นาหมอศรี": "DISTRICT",
  "นาหมื่นศรี": "DISTRICT",
  "นาหม่อม": "DISTRICT",
  "นาหลวงเสน": "DISTRICT",
  "นาหว้า": "DISTRICT",
  "นาหอ": "DISTRICT",
  "นาหัวบ่อ": "DISTRICT",
  "นาหินลาด": "DISTRICT",
  "นาหูกวาง": "DISTRICT",
  "นาห่อม": "DISTRICT",
  "นาอาน": "DISTRICT",
  "นาอิน": "DISTRICT",
  "นาอุดม": "DISTRICT",
  "นาอ้อ": "DISTRICT",
  "นาฮี": "DISTRICT",
  "นาเกตุ": "DISTRICT",
  "นาเกลือ": "DISTRICT",
  "นาเกษม": "DISTRICT",
  "นาเกาะ": "DISTRICT",
  "นาเกียน": "DISTRICT",
  "นาเข": "DISTRICT",
  "นาเขลียง": "DISTRICT",
  "นาเคียน": "DISTRICT",
  "นาเจริญ": "DISTRICT",
  "นาเฉลียง": "DISTRICT",
  "นาเชิงคีรี": "DISTRICT",
  "นาเชือก": "DISTRICT",
  "นาเดื่อ": "DISTRICT",
  "นาเตย": "DISTRICT",
  "นาเพียง": "DISTRICT",
  "นาเมือง": "DISTRICT",
  "นาเมืองเพชร": "DISTRICT",
  "นาเยีย": "DISTRICT",
  "นาเริก": "DISTRICT",
  "นาเรียง": "DISTRICT",
  "นาเรือง": "DISTRICT",
  "นาเลิง": "DISTRICT",
  "นาเลิน": "DISTRICT",
  "นาเลียง": "DISTRICT",
  "นาเวียง": "DISTRICT",
  "นาเสียว": "DISTRICT",
  "นาเหนือ": "DISTRICT",
  "นาเหรง": "DISTRICT",
  "นาเหลือง": "DISTRICT",
  "นาเหล่า": "DISTRICT",
  "นาแก": "DISTRICT",
  "นาแก้ว": "DISTRICT",
  "นาแขม": "DISTRICT",
  "นาแค": "DISTRICT",
  "นาแซง": "DISTRICT",
  "นาแต้": "DISTRICT",
  "นาแพง": "DISTRICT",
  "นาแว": "DISTRICT",
  "นาแวง": "DISTRICT",
  "นาแสง": "DISTRICT",
  "นาแส่ง": "DISTRICT",
  "นาแห้ว": "DISTRICT",
  "นาโก": "DISTRICT",
  "นาโคก": "DISTRICT",
  "นาโฉง": "DISTRICT",
  "นาโต๊ะหมิง": "DISTRICT",
  "นาโบสถ์": "DISTRICT",
  "นาโป่ง": "DISTRICT",
  "นาโพธิ์": "DISTRICT",
  "นาโพธิ์กลาง": "DISTRICT",
  "นาโยงเหนือ": "DISTRICT",
  "นาโยงใต้": "DISTRICT",
  "นาโสก": "DISTRICT",
  "นาโสม": "DISTRICT",
  "นาโส่": "DISTRICT",
  "นาโหนด": "DISTRICT",
  "นาใต้": "DISTRICT",
  "นาใน": "DISTRICT",
  "นาใหญ่": "DISTRICT",
  "นาไม้ไผ่": "DISTRICT",
  "นาไร่หลวง": "DISTRICT",
  "นาไหม": "DISTRICT",
  "นิคม": "DISTRICT",
  "นิคมกระเสียว": "DISTRICT",
  "นิคมคำสร้อย": "DISTRICT",
  "นิคมทุ่งโพธิ์ทะเล": "DISTRICT",
  "นิคมน้ำอูน": "DISTRICT",
  "นิคมพัฒนา": "DISTRICT",
  "นิคมลำนารายณ์": "DISTRICT",
  "นิคมลำโดมน้อย": "DISTRICT",
  "นิคมสงเคราะห์": "DISTRICT",
  "นิคมสร้างตนเอง": "DISTRICT",
  "นิคมสร้างตนเองลำโดมน้อย": "DISTRICT",
  "นิคมห้วยผึ้ง": "DISTRICT",
  "นิคมเขาบ่อแก้ว": "DISTRICT",
  "นิยมชัย": "DISTRICT",
  "นิลเพชร": "DISTRICT",
  "นิเวศน์": "DISTRICT",
  "น้ำกุ่ม": "DISTRICT",
  "น้ำก่ำ": "DISTRICT",
  "น้ำก้อ": "DISTRICT",
  "น้ำขาว": "DISTRICT",
  "น้ำขุม": "DISTRICT",
  "น้ำคอก": "DISTRICT",
  "น้ำคำ": "DISTRICT",
  "น้ำคำใหญ่": "DISTRICT",
  "น้ำจั้น": "DISTRICT",
  "น้ำจืด": "DISTRICT",
  "น้ำจืดน้อย": "DISTRICT",
  "น้ำชำ": "DISTRICT",
  "น้ำชุน": "DISTRICT",
  "น้ำซึม": "DISTRICT",
  "น้ำดำ": "DISTRICT",
  "น้ำดิบ": "DISTRICT",
  "น้ำตก": "DISTRICT",
  "น้ำตาล": "DISTRICT",
  "น้ำทรง": "DISTRICT",
  "น้ำทูน": "DISTRICT",
  "น้ำน้อย": "DISTRICT",
  "น้ำบ่อหลวง": "DISTRICT",
  "น้ำปลีก": "DISTRICT",
  "น้ำปั้ว": "DISTRICT",
  "น้ำปาย": "DISTRICT",
  "น้ำผุด": "DISTRICT",
  "น้ำพอง": "DISTRICT",
  "น้ำพาง": "DISTRICT",
  "น้ำพี้": "DISTRICT",
  "น้ำพุ": "DISTRICT",
  "น้ำพ่น": "DISTRICT",
  "น้ำมวบ": "DISTRICT",
  "น้ำรอบ": "DISTRICT",
  "น้ำรัด": "DISTRICT",
  "น้ำริด": "DISTRICT",
  "น้ำรึม": "DISTRICT",
  "น้ำร้อน": "DISTRICT",
  "น้ำสวย": "DISTRICT",
  "น้ำสุด": "DISTRICT",
  "น้ำหนาว": "DISTRICT",
  "น้ำหมัน": "DISTRICT",
  "น้ำหมาน": "DISTRICT",
  "น้ำหัก": "DISTRICT",
  "น้ำอ่าง": "DISTRICT",
  "น้ำอ้อม": "DISTRICT",
  "น้ำเกลี้ยง": "DISTRICT",
  "น้ำเกี๋ยน": "DISTRICT",
  "น้ำเขียว": "DISTRICT",
  "น้ำเชี่ยว": "DISTRICT",
  "น้ำเต้า": "DISTRICT",
  "น้ำเที่ยง": "DISTRICT",
  "น้ำเป็น": "DISTRICT",
  "น้ำเลา": "DISTRICT",
  "น้ำเฮี้ย": "DISTRICT",
  "น้ำแก่น": "DISTRICT",
  "น้ำแคม": "DISTRICT",
  "น้ำแพร่": "DISTRICT",
  "น้ำแวน": "DISTRICT",
  "น้ำโจ้": "DISTRICT",
  "น้ำโมง": "DISTRICT",
  "น้ำโสม": "DISTRICT",
  "น้ำใส": "DISTRICT",
  "น้ำไคร้": "DISTRICT",
  "น้ำไผ่": "DISTRICT",
  "บก": "DISTRICT",
  "บงตัน": "DISTRICT",
  "บงเหนือ": "DISTRICT",
  "บงใต้": "DISTRICT",
  "บรบือ": "DISTRICT",
  "บริบูรณ์": "DISTRICT",
  "บวกค้าง": "DISTRICT",
  "บวรนิเวศ": "DISTRICT",
  "บองอ": "DISTRICT",
  "บอน": "DISTRICT",
  "บะ": "DISTRICT",
  "บะยาว": "DISTRICT",
  "บะหว้า": "DISTRICT",
  "บะฮี": "DISTRICT",
  "บักดอง": "DISTRICT",
  "บักได": "DISTRICT",
  "บันนังสตา": "DISTRICT",
  "บันนังสาเรง": "DISTRICT",
  "บัลลังก์": "DISTRICT",
  "บัวขาว": "DISTRICT",
  "บัวคำ": "DISTRICT",
  "บัวค้อ": "DISTRICT",
  "บัวงาม": "DISTRICT",
  "บัวชุม": "DISTRICT",
  "บัวตูม": "DISTRICT",
  "บัวทอง": "DISTRICT",
  "บัวน้อย": "DISTRICT",
  "บัวบาน": "DISTRICT",
  "บัวปากท่า": "DISTRICT",
  "บัวมาศ": "DISTRICT",
  "บัวลอย": "DISTRICT",
  "บัวลาย": "DISTRICT",
  "บัววัฒนา": "DISTRICT",
  "บัวสลี": "DISTRICT",
  "บัวหุ่ง": "DISTRICT",
  "บัวเงิน": "DISTRICT",
  "บัวเชด": "DISTRICT",
  "บัวแดง": "DISTRICT",
  "บัวโคก": "DISTRICT",
  "บัวใหญ่": "DISTRICT",
  "บากเรือ": "DISTRICT",
  "บางกรวย": "DISTRICT",
  "บางกระทึก": "DISTRICT",
  "บางกระทุ่ม": "DISTRICT",
  "บางกระบือ": "DISTRICT",
  "บางกระสอ": "DISTRICT",
  "บางกระสอบ": "DISTRICT",
  "บางกระสั้น": "DISTRICT",
  "บางกระเจ็ด": "DISTRICT",
  "บางกระเจ้า": "DISTRICT",
  "บางกระเบา": "DISTRICT",
  "บางกรูด": "DISTRICT",
  "บางกร่าง": "DISTRICT",
  "บางกล่ำ": "DISTRICT",
  "บางกอบัว": "DISTRICT",
  "บางกะจะ": "DISTRICT",
  "บางกะดี": "DISTRICT",
  "บางกะปิ": "DISTRICT",
  "บางกะพี้": "DISTRICT",
  "บางกะเจ้า": "DISTRICT",
  "บางกะไชย": "DISTRICT",
  "บางกะไห": "DISTRICT",
  "บางกุ้ง": "DISTRICT",
  "บางขนาก": "DISTRICT",
  "บางขนุน": "DISTRICT",
  "บางขวัญ": "DISTRICT",
  "บางขะแยง": "DISTRICT",
  "บางขัน": "DISTRICT",
  "บางขันหมาก": "DISTRICT",
  "บางขันแตก": "DISTRICT",
  "บางขาม": "DISTRICT",
  "บางขุด": "DISTRICT",
  "บางขุนกอง": "DISTRICT",
  "บางขุนทอง": "DISTRICT",
  "บางขุนนนท์": "DISTRICT",
  "บางขุนพรหม": "DISTRICT",
  "บางขุนศรี": "DISTRICT",
  "บางขุนเทียน": "DISTRICT",
  "บางขุนไทร": "DISTRICT",
  "บางคนที": "DISTRICT",
  "บางครก": "DISTRICT",
  "บางครุ": "DISTRICT",
  "บางคลาน": "DISTRICT",
  "บางคล้า": "DISTRICT",
  "บางคอแหลม": "DISTRICT",
  "บางคา": "DISTRICT",
  "บางคูรัด": "DISTRICT",
  "บางคูวัด": "DISTRICT",
  "บางคูเวียง": "DISTRICT",
  "บางคู้": "DISTRICT",
  "บางค้อ": "DISTRICT",
  "บางงอน": "DISTRICT",
  "บางงา": "DISTRICT",
  "บางงาม": "DISTRICT",
  "บางจะเกร็ง": "DISTRICT",
  "บางจัก": "DISTRICT",
  "บางจาก": "DISTRICT",
  "บางจาน": "DISTRICT",
  "บางชนะ": "DISTRICT",
  "บางชะนี": "DISTRICT",
  "บางชัน": "DISTRICT",
  "บางช้าง": "DISTRICT",
  "บางซื่อ": "DISTRICT",
  "บางซ่อน": "DISTRICT",
  "บางซ้าย": "DISTRICT",
  "บางดี": "DISTRICT",
  "บางด้วน": "DISTRICT",
  "บางตลาด": "DISTRICT",
  "บางตะบูน": "DISTRICT",
  "บางตะบูนออก": "DISTRICT",
  "บางตะพง": "DISTRICT",
  "บางตะเคียน": "DISTRICT",
  "บางตะไนย์": "DISTRICT",
  "บางตาวา": "DISTRICT",
  "บางตาหงาย": "DISTRICT",
  "บางตาเถร": "DISTRICT",
  "บางตีนเป็ด": "DISTRICT",
  "บางทราย": "DISTRICT",
  "บางทรายน้อย": "DISTRICT",
  "บางทรายใหญ่": "DISTRICT",
  "บางทอง": "DISTRICT",
  "บางนกแขวก": "DISTRICT",
  "บางนบ": "DISTRICT",
  "บางนมโค": "DISTRICT",
  "บางนอน": "DISTRICT",
  "บางนา": "DISTRICT",
  "บางนาค": "DISTRICT",
  "บางนาง": "DISTRICT",
  "บางนางร้า": "DISTRICT",
  "บางนางลี่": "DISTRICT",
  "บางนายสี": "DISTRICT",
  "บางนาเหนือ": "DISTRICT",
  "บางนาใต้": "DISTRICT",
  "บางน้ำจืด": "DISTRICT",
  "บางน้ำผึ้ง": "DISTRICT",
  "บางน้ำเชี่ยว": "DISTRICT",
  "บางน้ำเปรี้ยว": "DISTRICT",
  "บางบริบูรณ์": "DISTRICT",
  "บางบอน": "DISTRICT",
  "บางบอนเหนือ": "DISTRICT",
  "บางบอนใต้": "DISTRICT",
  "บางบัวทอง": "DISTRICT",
  "บางบาล": "DISTRICT",
  "บางบำหรุ": "DISTRICT",
  "บางบุตร": "DISTRICT",
  "บางบ่อ": "DISTRICT",
  "บางปรอก": "DISTRICT",
  "บางประมุง": "DISTRICT",
  "บางประแดง": "DISTRICT",
  "บางปลา": "DISTRICT",
  "บางปลากด": "DISTRICT",
  "บางปลาม้า": "DISTRICT",
  "บางปลาร้า": "DISTRICT",
  "บางปลาสร้อย": "DISTRICT",
  "บางปอ": "DISTRICT",
  "บางปะกง": "DISTRICT",
  "บางปะกอก": "DISTRICT",
  "บางปะหัน": "DISTRICT",
  "บางปิด": "DISTRICT",
  "บางปู": "DISTRICT",
  "บางปูใหม่": "DISTRICT",
  "บางป่า": "DISTRICT",
  "บางผึ้ง": "DISTRICT",
  "บางพรม": "DISTRICT",
  "บางพระ": "DISTRICT",
  "บางพระครู": "DISTRICT",
  "บางพระหลวง": "DISTRICT",
  "บางพระเหนือ": "DISTRICT",
  "บางพระใต้": "DISTRICT",
  "บางพลวง": "DISTRICT",
  "บางพลัด": "DISTRICT",
  "บางพลับ": "DISTRICT",
  "บางพลี": "DISTRICT",
  "บางพลีน้อย": "DISTRICT",
  "บางพลีใหญ่": "DISTRICT",
  "บางพึ่ง": "DISTRICT",
  "บางพุทรา": "DISTRICT",
  "บางพูด": "DISTRICT",
  "บางพูน": "DISTRICT",
  "บางภาษี": "DISTRICT",
  "บางมด": "DISTRICT",
  "บางมะฝ่อ": "DISTRICT",
  "บางมะพร้าว": "DISTRICT",
  "บางมะเดื่อ": "DISTRICT",
  "บางมัญ": "DISTRICT",
  "บางมูลนาก": "DISTRICT",
  "บางม่วง": "DISTRICT",
  "บางยอ": "DISTRICT",
  "บางยาง": "DISTRICT",
  "บางยี่ขัน": "DISTRICT",
  "บางยี่รงค์": "DISTRICT",
  "บางยี่เรือ": "DISTRICT",
  "บางยี่โท": "DISTRICT",
  "บางระกำ": "DISTRICT",
  "บางระจัน": "DISTRICT",
  "บางระมาด": "DISTRICT",
  "บางรัก": "DISTRICT",
  "บางรักน้อย": "DISTRICT",
  "บางรักพัฒนา": "DISTRICT",
  "บางรักใหญ่": "DISTRICT",
  "บางริ้น": "DISTRICT",
  "บางรูป": "DISTRICT",
  "บางละมุง": "DISTRICT",
  "บางลาย": "DISTRICT",
  "บางลำภูล่าง": "DISTRICT",
  "บางลี่": "DISTRICT",
  "บางลึก": "DISTRICT",
  "บางลูกเสือ": "DISTRICT",
  "บางวัน": "DISTRICT",
  "บางวัว": "DISTRICT",
  "บางศรีเมือง": "DISTRICT",
  "บางศาลา": "DISTRICT",
  "บางสน": "DISTRICT",
  "บางสมบูรณ์": "DISTRICT",
  "บางสมัคร": "DISTRICT",
  "บางสระเก้า": "DISTRICT",
  "บางสวน": "DISTRICT",
  "บางสวรรค์": "DISTRICT",
  "บางสะพาน": "DISTRICT",
  "บางสะแก": "DISTRICT",
  "บางสัก": "DISTRICT",
  "บางสีทอง": "DISTRICT",
  "บางหญ้าแพรก": "DISTRICT",
  "บางหมาก": "DISTRICT",
  "บางหลวง": "DISTRICT",
  "บางหลวงโดด": "DISTRICT",
  "บางหว้า": "DISTRICT",
  "บางหัก": "DISTRICT",
  "บางหัวเสือ": "DISTRICT",
  "บางหิน": "DISTRICT",
  "บางอ้อ": "DISTRICT",
  "บางเกลือ": "DISTRICT",
  "บางเก่า": "DISTRICT",
  "บางเขน": "DISTRICT",
  "บางเขา": "DISTRICT",
  "บางเขียด": "DISTRICT",
  "บางเคียน": "DISTRICT",
  "บางเค็ม": "DISTRICT",
  "บางเจ้าฉ่า": "DISTRICT",
  "บางเชือกหนัง": "DISTRICT",
  "บางเดชะ": "DISTRICT",
  "บางเดือน": "DISTRICT",
  "บางเดื่อ": "DISTRICT",
  "บางเตย": "DISTRICT",
  "บางเป้า": "DISTRICT",
  "บางเพรียง": "DISTRICT",
  "บางเพลิง": "DISTRICT",
  "บางเมือง": "DISTRICT",
  "บางเมืองใหม่": "DISTRICT",
  "บางเลน": "DISTRICT",
  "บางเล่า": "DISTRICT",
  "บางเสด็จ": "DISTRICT",
  "บางเสร่": "DISTRICT",
  "บางเสาธง": "DISTRICT",
  "บางเหรียง": "DISTRICT",
  "บางแก้ว": "DISTRICT",
  "บางแก้วฟ้า": "DISTRICT",
  "บางแขม": "DISTRICT",
  "บางแค": "DISTRICT",
  "บางแคเหนือ": "DISTRICT",
  "บางแตน": "DISTRICT",
  "บางแพ": "DISTRICT",
  "บางแม่นาง": "DISTRICT",
  "บางแวก": "DISTRICT",
  "บางโกระ": "DISTRICT",
  "บางโขมด": "DISTRICT",
  "บางโคล่": "DISTRICT",
  "บางโฉลง": "DISTRICT",
  "บางโตนด": "DISTRICT",
  "บางโทรัด": "DISTRICT",
  "บางโปรง": "DISTRICT",
  "บางโพงพาง": "DISTRICT",
  "บางโพธิ์": "DISTRICT",
  "บางโพธิ์เหนือ": "DISTRICT",
  "บางโรง": "DISTRICT",
  "บางใบไม้": "DISTRICT",
  "บางใหญ่": "DISTRICT",
  "บางไทร": "DISTRICT",
  "บางไทรป่า": "DISTRICT",
  "บางไผ่": "DISTRICT",
  "บาตง": "DISTRICT",
  "บานา": "DISTRICT",
  "บาราเฮาะ": "DISTRICT",
  "บาราโหม": "DISTRICT",
  "บาลอ": "DISTRICT",
  "บาละ": "DISTRICT",
  "บาเจาะ": "DISTRICT",
  "บาเระเหนือ": "DISTRICT",
  "บาเระใต้": "DISTRICT",
  "บาโงย": "DISTRICT",
  "บาโงยซิแน": "DISTRICT",
  "บาโงสะโต": "DISTRICT",
  "บาโร๊ะ": "DISTRICT",
  "บาโลย": "DISTRICT",
  "บาโหย": "DISTRICT",
  "บิง": "DISTRICT",
  "บึง": "DISTRICT",
  "บึงกระจับ": "DISTRICT",
  "บึงกอก": "DISTRICT",
  "บึงกาสาม": "DISTRICT",
  "บึงกาฬ": "DISTRICT",
  "บึงคอไห": "DISTRICT",
  "บึงคำพร้อย": "DISTRICT",
  "บึงงาม": "DISTRICT",
  "บึงชำอ้อ": "DISTRICT",
  "บึงทวาย": "DISTRICT",
  "บึงทองหลาง": "DISTRICT",
  "บึงทับแรต": "DISTRICT",
  "บึงนคร": "DISTRICT",
  "บึงนาราง": "DISTRICT",
  "บึงนาเรียง": "DISTRICT",
  "บึงน้ำรักษ์": "DISTRICT",
  "บึงบอน": "DISTRICT",
  "บึงบัว": "DISTRICT",
  "บึงบา": "DISTRICT",
  "บึงบูรพ์": "DISTRICT",
  "บึงปรือ": "DISTRICT",
  "บึงปลาทู": "DISTRICT",
  "บึงพระ": "DISTRICT",
  "บึงพะไล": "DISTRICT",
  "บึงมะลู": "DISTRICT",
  "บึงยี่โถ": "DISTRICT",
  "บึงวิชัย": "DISTRICT",
  "บึงศาล": "DISTRICT",
  "บึงสนั่น": "DISTRICT",
  "บึงสามพัน": "DISTRICT",
  "บึงสามัคคี": "DISTRICT",
  "บึงสำโรง": "DISTRICT",
  "บึงอ้อ": "DISTRICT",
  "บึงเกลือ": "DISTRICT",
  "บึงเจริญ": "DISTRICT",
  "บึงเนียม": "DISTRICT",
  "บึงเสนาท": "DISTRICT",
  "บึงแก": "DISTRICT",
  "บึงโขงหลง": "DISTRICT",
  "บือมัง": "DISTRICT",
  "บือเระ": "DISTRICT",
  "บุกระสัง": "DISTRICT",
  "บุคคโล": "DISTRICT",
  "บุญทัน": "DISTRICT",
  "บุญนาคพัฒนา": "DISTRICT",
  "บุญเกิด": "DISTRICT",
  "บุญเรือง": "DISTRICT",
  "บุดี": "DISTRICT",
  "บุฝ้าย": "DISTRICT",
  "บุพราหมณ์": "DISTRICT",
  "บุฤาษี": "DISTRICT",
  "บุสูง": "DISTRICT",
  "บุฮม": "DISTRICT",
  "บุเปือย": "DISTRICT",
  "บุแกรง": "DISTRICT",
  "บุโพธิ์": "DISTRICT",
  "บุ่ง": "DISTRICT",
  "บุ่งขี้เหล็ก": "DISTRICT",
  "บุ่งคล้า": "DISTRICT",
  "บุ่งค้า": "DISTRICT",
  "บุ่งน้ำเต้า": "DISTRICT",
  "บุ่งมะแลง": "DISTRICT",
  "บุ่งหวาย": "DISTRICT",
  "บุ่งเลิศ": "DISTRICT",
  "บุ่งแก้ว": "DISTRICT",
  "บุ่งไหม": "DISTRICT",
  "บูกิต": "DISTRICT",
  "บ่อ": "DISTRICT",
  "บ่อกระดาน": "DISTRICT",
  "บ่อกรุ": "DISTRICT",
  "บ่อกวางทอง": "DISTRICT",
  "บ่อดาน": "DISTRICT",
  "บ่อตรุ": "DISTRICT",
  "บ่อตาโล่": "DISTRICT",
  "บ่อถ้ำ": "DISTRICT",
  "บ่อทอง": "DISTRICT",
  "บ่อนอก": "DISTRICT",
  "บ่อน้ำร้อน": "DISTRICT",
  "บ่อปลาทอง": "DISTRICT",
  "บ่อผุด": "DISTRICT",
  "บ่อพลอย": "DISTRICT",
  "บ่อพลับ": "DISTRICT",
  "บ่อพันขัน": "DISTRICT",
  "บ่อพุ": "DISTRICT",
  "บ่อภาค": "DISTRICT",
  "บ่อยาง": "DISTRICT",
  "บ่อรัง": "DISTRICT",
  "บ่อวิน": "DISTRICT",
  "บ่อสลี": "DISTRICT",
  "บ่อสวก": "DISTRICT",
  "บ่อสุพรรณ": "DISTRICT",
  "บ่อหลวง": "DISTRICT",
  "บ่อหิน": "DISTRICT",
  "บ่อเกลือเหนือ": "DISTRICT",
  "บ่อเกลือใต้": "DISTRICT",
  "บ่อเงิน": "DISTRICT",
  "บ่อเบี้ย": "DISTRICT",
  "บ่อเวฬุ": "DISTRICT",
  "บ่อเหล็กลอง": "DISTRICT",
  "บ่อแก้ว": "DISTRICT",
  "บ่อแดง": "DISTRICT",
  "บ่อแร่": "DISTRICT",
  "บ่อแสน": "DISTRICT",
  "บ่อแฮ้ว": "DISTRICT",
  "บ่อโพง": "DISTRICT",
  "บ่อโพธิ์": "DISTRICT",
  "บ่อใหญ่": "DISTRICT",
  "บ่อไทย": "DISTRICT",
  "บ้องตี้": "DISTRICT",
  "บ้านกง": "DISTRICT",
  "บ้านกรด": "DISTRICT",
  "บ้านกรวด": "DISTRICT",
  "บ้านกระทุ่ม": "DISTRICT",
  "บ้านกระแชง": "DISTRICT",
  "บ้านกร่าง": "DISTRICT",
  "บ้านกลับ": "DISTRICT",
  "บ้านกลาง": "DISTRICT",
  "บ้านกลึง": "DISTRICT",
  "บ้านกล้วย": "DISTRICT",
  "บ้านกวาง": "DISTRICT",
  "บ้านกอก": "DISTRICT",
  "บ้านกาด": "DISTRICT",
  "บ้านกาศ": "DISTRICT",
  "บ้านกิ่ว": "DISTRICT",
  "บ้านกุ่ม": "DISTRICT",
  "บ้านกู่": "DISTRICT",
  "บ้านก้อง": "DISTRICT",
  "บ้านขล้อ": "DISTRICT",
  "บ้านขวาง": "DISTRICT",
  "บ้านขอ": "DISTRICT",
  "บ้านขาม": "DISTRICT",
  "บ้านขาว": "DISTRICT",
  "บ้านข่อย": "DISTRICT",
  "บ้านข่า": "DISTRICT",
  "บ้านครัว": "DISTRICT",
  "บ้านคลอง": "DISTRICT",
  "บ้านคลองสวน": "DISTRICT",
  "บ้านคลัง": "DISTRICT",
  "บ้านควน": "DISTRICT",
  "บ้านควนมุด": "DISTRICT",
  "บ้านคา": "DISTRICT",
  "บ้านคู": "DISTRICT",
  "บ้านค่า": "DISTRICT",
  "บ้านค่าย": "DISTRICT",
  "บ้านค้อ": "DISTRICT",
  "บ้านฆ้อง": "DISTRICT",
  "บ้านงิ้ว": "DISTRICT",
  "บ้านจันทน์": "DISTRICT",
  "บ้านจันทร์": "DISTRICT",
  "บ้านจั่น": "DISTRICT",
  "บ้านจาน": "DISTRICT",
  "บ้านจารย์": "DISTRICT",
  "บ้านจีต": "DISTRICT",
  "บ้านจ่า": "DISTRICT",
  "บ้านฉาง": "DISTRICT",
  "บ้านชบ": "DISTRICT",
  "บ้านชวน": "DISTRICT",
  "บ้านชะอวด": "DISTRICT",
  "บ้านชัย": "DISTRICT",
  "บ้านชี": "DISTRICT",
  "บ้านชุ้ง": "DISTRICT",
  "บ้านช่างหล่อ": "DISTRICT",
  "บ้านช้าง": "DISTRICT",
  "บ้านซ่ง": "DISTRICT",
  "บ้านซ่อง": "DISTRICT",
  "บ้านซ่าน": "DISTRICT",
  "บ้านดง": "DISTRICT",
  "บ้านดอน": "DISTRICT",
  "บ้านดารา": "DISTRICT",
  "บ้านดุง": "DISTRICT",
  "บ้านดู่": "DISTRICT",
  "บ้านด่าน": "DISTRICT",
  "บ้านด่านนาขาม": "DISTRICT",
  "บ้านด้าย": "DISTRICT",
  "บ้านตะโก": "DISTRICT",
  "บ้านตาด": "DISTRICT",
  "บ้านตาล": "DISTRICT",
  "บ้านติ้ว": "DISTRICT",
  "บ้านตึก": "DISTRICT",
  "บ้านตุ่น": "DISTRICT",
  "บ้านตูม": "DISTRICT",
  "บ้านตูล": "DISTRICT",
  "บ้านต้อง": "DISTRICT",
  "บ้านต้อน": "DISTRICT",
  "บ้านต้าย": "DISTRICT",
  "บ้านต๊ำ": "DISTRICT",
  "บ้านต๋อม": "DISTRICT",
  "บ้านถิ่น": "DISTRICT",
  "บ้านถ่อน": "DISTRICT",
  "บ้านถ้ำ": "DISTRICT",
  "บ้านทราย": "DISTRICT",
  "บ้านทับ": "DISTRICT",
  "บ้านทาน": "DISTRICT",
  "บ้านทาม": "DISTRICT",
  "บ้านทำเนียบ": "DISTRICT",
  "บ้านทุ่ม": "DISTRICT",
  "บ้านธาตุ": "DISTRICT",
  "บ้านธิ": "DISTRICT",
  "บ้านนอก": "DISTRICT",
  "บ้านนา": "DISTRICT",
  "บ้านนิคม": "DISTRICT",
  "บ้านน้อย": "DISTRICT",
  "บ้านน้อยซุ้มขี้เหล็ก": "DISTRICT",
  "บ้านน้ำบ่อ": "DISTRICT",
  "บ้านน้ำพุ": "DISTRICT",
  "บ้านบอม": "DISTRICT",
  "บ้านบัว": "DISTRICT",
  "บ้านบาก": "DISTRICT",
  "บ้านบาตร": "DISTRICT",
  "บ้านบึง": "DISTRICT",
  "บ้านบุ่ง": "DISTRICT",
  "บ้านบ่อ": "DISTRICT",
  "บ้านปง": "DISTRICT",
  "บ้านปทุม": "DISTRICT",
  "บ้านปรก": "DISTRICT",
  "บ้านปรางค์": "DISTRICT",
  "บ้านปราโมทย์": "DISTRICT",
  "บ้านปรือ": "DISTRICT",
  "บ้านปวง": "DISTRICT",
  "บ้านปิน": "DISTRICT",
  "บ้านปึก": "DISTRICT",
  "บ้านป่า": "DISTRICT",
  "บ้านป้อม": "DISTRICT",
  "บ้านผึ้ง": "DISTRICT",
  "บ้านผือ": "DISTRICT",
  "บ้านฝาง": "DISTRICT",
  "บ้านฝาย": "DISTRICT",
  "บ้านพระ": "DISTRICT",
  "บ้านพราน": "DISTRICT",
  "บ้านพริก": "DISTRICT",
  "บ้านพรุ": "DISTRICT",
  "บ้านพร้าว": "DISTRICT",
  "บ้านพลวง": "DISTRICT",
  "บ้านพลับ": "DISTRICT",
  "บ้านพานถม": "DISTRICT",
  "บ้านพี้": "DISTRICT",
  "บ้านฟ้า": "DISTRICT",
  "บ้านมะเกลือ": "DISTRICT",
  "บ้านมาง": "DISTRICT",
  "บ้านมุง": "DISTRICT",
  "บ้านม่วง": "DISTRICT",
  "บ้านม้า": "DISTRICT",
  "บ้านยวด": "DISTRICT",
  "บ้านยา": "DISTRICT",
  "บ้านยาง": "DISTRICT",
  "บ้านระกาศ": "DISTRICT",
  "บ้านราม": "DISTRICT",
  "บ้านราษฎร์": "DISTRICT",
  "บ้านรี": "DISTRICT",
  "บ้านรุน": "DISTRICT",
  "บ้านร่อม": "DISTRICT",
  "บ้านร้อง": "DISTRICT",
  "บ้านลาด": "DISTRICT",
  "บ้านลาน": "DISTRICT",
  "บ้านลำ": "DISTRICT",
  "บ้านลำนาว": "DISTRICT",
  "บ้านลี่": "DISTRICT",
  "บ้านวัง": "DISTRICT",
  "บ้านว่าน": "DISTRICT",
  "บ้านสระ": "DISTRICT",
  "บ้านสร้าง": "DISTRICT",
  "บ้านสวน": "DISTRICT",
  "บ้านสหกรณ์": "DISTRICT",
  "บ้านสา": "DISTRICT",
  "บ้านสาง": "DISTRICT",
  "บ้านสิงห์": "DISTRICT",
  "บ้านส้อง": "DISTRICT",
  "บ้านหนุน": "DISTRICT",
  "บ้านหมอ": "DISTRICT",
  "บ้านหมี่": "DISTRICT",
  "บ้านหม้อ": "DISTRICT",
  "บ้านหยวก": "DISTRICT",
  "บ้านหลวง": "DISTRICT",
  "บ้านหลุม": "DISTRICT",
  "บ้านหวด": "DISTRICT",
  "บ้านหวาย": "DISTRICT",
  "บ้านหว้า": "DISTRICT",
  "บ้านหอย": "DISTRICT",
  "บ้านหัน": "DISTRICT",
  "บ้านหาด": "DISTRICT",
  "บ้านหาร": "DISTRICT",
  "บ้านหินโงม": "DISTRICT",
  "บ้านหีบ": "DISTRICT",
  "บ้านอิฐ": "DISTRICT",
  "บ้านอ้อน": "DISTRICT",
  "บ้านเกาะ": "DISTRICT",
  "บ้านเก่า": "DISTRICT",
  "บ้านเขว้า": "DISTRICT",
  "บ้านเขือง": "DISTRICT",
  "บ้านเจียง": "DISTRICT",
  "บ้านเชียง": "DISTRICT",
  "บ้านเชี่ยน": "DISTRICT",
  "บ้านเซิด": "DISTRICT",
  "บ้านเดื่อ": "DISTRICT",
  "บ้านเต่า": "DISTRICT",
  "บ้านเนิน": "DISTRICT",
  "บ้านเบิก": "DISTRICT",
  "บ้านเป็ด": "DISTRICT",
  "บ้านเป้า": "DISTRICT",
  "บ้านเพชร": "DISTRICT",
  "บ้านเพิง": "DISTRICT",
  "บ้านเพิ่ม": "DISTRICT",
  "บ้านเม็ง": "DISTRICT",
  "บ้านเรือ": "DISTRICT",
  "บ้านเรือน": "DISTRICT",
  "บ้านเลน": "DISTRICT",
  "บ้านเลือก": "DISTRICT",
  "บ้านเลื่อม": "DISTRICT",
  "บ้านเล่า": "DISTRICT",
  "บ้านเวียง": "DISTRICT",
  "บ้านเสด็จ": "DISTRICT",
  "บ้านเสียว": "DISTRICT",
  "บ้านเสี้ยว": "DISTRICT",
  "บ้านเหนือ": "DISTRICT",
  "บ้านเหลื่อม": "DISTRICT",
  "บ้านเหล่า": "DISTRICT",
  "บ้านเอื้อง": "DISTRICT",
  "บ้านเอื้อม": "DISTRICT",
  "บ้านแก่ง": "DISTRICT",
  "บ้านแก้ง": "DISTRICT",
  "บ้านแขม": "DISTRICT",
  "บ้านแค": "DISTRICT",
  "บ้านแจ้ง": "DISTRICT",
  "บ้านแซว": "DISTRICT",
  "บ้านแดง": "DISTRICT",
  "บ้านแดน": "DISTRICT",
  "บ้านแถว": "DISTRICT",
  "บ้านแท่น": "DISTRICT",
  "บ้านแปรง": "DISTRICT",
  "บ้านแปะ": "DISTRICT",
  "บ้านแป้ง": "DISTRICT",
  "บ้านแป้น": "DISTRICT",
  "บ้านแพ": "DISTRICT",
  "บ้านแพง": "DISTRICT",
  "บ้านแพน": "DISTRICT",
  "บ้านแพรก": "DISTRICT",
  "บ้านแพ้ว": "DISTRICT",
  "บ้านแม": "DISTRICT",
  "บ้านแมด": "DISTRICT",
  "บ้านแยง": "DISTRICT",
  "บ้านแร่": "DISTRICT",
  "บ้านแลง": "DISTRICT",
  "บ้านแวง": "DISTRICT",
  "บ้านแห": "DISTRICT",
  "บ้านแหง": "DISTRICT",
  "บ้านแหร": "DISTRICT",
  "บ้านแหลม": "DISTRICT",
  "บ้านแหวน": "DISTRICT",
  "บ้านแอ่น": "DISTRICT",
  "บ้านแฮด": "DISTRICT",
  "บ้านโขด": "DISTRICT",
  "บ้านโข้ง": "DISTRICT",
  "บ้านโคก": "DISTRICT",
  "บ้านโคน": "DISTRICT",
  "บ้านโตก": "DISTRICT",
  "บ้านโต้น": "DISTRICT",
  "บ้านโนน": "DISTRICT",
  "บ้านโปร่ง": "DISTRICT",
  "บ้านโป่ง": "DISTRICT",
  "บ้านโพ": "DISTRICT",
  "บ้านโพธิ์": "DISTRICT",
  "บ้านโพน": "DISTRICT",
  "บ้านโภชน์": "DISTRICT",
  "บ้านโสก": "DISTRICT",
  "บ้านโหนด": "DISTRICT",
  "บ้านโฮ่ง": "DISTRICT",
  "บ้านใต้": "DISTRICT",
  "บ้านในดง": "DISTRICT",
  "บ้านใหญ่": "DISTRICT",
  "บ้านใหม่": "DISTRICT",
  "บ้านใหม่คลองเคียน": "DISTRICT",
  "บ้านใหม่สามัคคี": "DISTRICT",
  "บ้านใหม่สุขเกษม": "DISTRICT",
  "บ้านใหม่หนองไทร": "DISTRICT",
  "บ้านใหม่ไชยมงคล": "DISTRICT",
  "บ้านไทย": "DISTRICT",
  "บ้านไทร": "DISTRICT",
  "บ้านไผ่": "DISTRICT",
  "บ้านไร่": "DISTRICT",
  "บ้าหวี": "DISTRICT",
  "ปกาสัย": "DISTRICT",
  "ปง": "DISTRICT",
  "ปงดอน": "DISTRICT",
  "ปงตำ": "DISTRICT",
  "ปงน้อย": "DISTRICT",
  "ปงป่าหวาย": "DISTRICT",
  "ปงยางคก": "DISTRICT",
  "ปงสนุก": "DISTRICT",
  "ปงเตา": "DISTRICT",
  "ปงแสนทอง": "DISTRICT",
  "ปทุม": "DISTRICT",
  "ปทุมวัน": "DISTRICT",
  "ปทุมวาปี": "DISTRICT",
  "ประกอบ": "DISTRICT",
  "ประจวบคีรีขันธ์": "DISTRICT",
  "ประจัน": "DISTRICT",
  "ประจันตคาม": "DISTRICT",
  "ประชาธิปัตย์": "DISTRICT",
  "ประชาพัฒนา": "DISTRICT",
  "ประชาสุขสันต์": "DISTRICT",
  "ประณีต": "DISTRICT",
  "ประดาง": "DISTRICT",
  "ประดู่": "DISTRICT",
  "ประดู่งาม": "DISTRICT",
  "ประดู่ยืน": "DISTRICT",
  "ประตูชัย": "DISTRICT",
  "ประตูป่า": "DISTRICT",
  "ประทัดบุ": "DISTRICT",
  "ประทาย": "DISTRICT",
  "ประศุก": "DISTRICT",
  "ประสงค์": "DISTRICT",
  "ประสาทสิทธิ์": "DISTRICT",
  "ประสุข": "DISTRICT",
  "ประเวศ": "DISTRICT",
  "ประโคนชัย": "DISTRICT",
  "ปรังเผล": "DISTRICT",
  "ปรางหมู่": "DISTRICT",
  "ปราณบุรี": "DISTRICT",
  "ปราสาท": "DISTRICT",
  "ปราสาททนง": "DISTRICT",
  "ปราสาททอง": "DISTRICT",
  "ปราสาทเยอ": "DISTRICT",
  "ปริก": "DISTRICT",
  "ปรือ": "DISTRICT",
  "ปรือใหญ่": "DISTRICT",
  "ปรุใหญ่": "DISTRICT",
  "ปลวกแดง": "DISTRICT",
  "ปลักหนู": "DISTRICT",
  "ปลักแรด": "DISTRICT",
  "ปลาค้าว": "DISTRICT",
  "ปลาบ่า": "DISTRICT",
  "ปลาปาก": "DISTRICT",
  "ปลายกลัด": "DISTRICT",
  "ปลายนา": "DISTRICT",
  "ปลายบาง": "DISTRICT",
  "ปลายพระยา": "DISTRICT",
  "ปลายโพงพาง": "DISTRICT",
  "ปลาโหล": "DISTRICT",
  "ปล่องหอย": "DISTRICT",
  "ปล้อง": "DISTRICT",
  "ปวนพุ": "DISTRICT",
  "ปอ": "DISTRICT",
  "ปอน": "DISTRICT",
  "ปอพาน": "DISTRICT",
  "ปอภาร (ปอพาน)": "DISTRICT",
  "ปอแดง": "DISTRICT",
  "ปะกาฮะรัง": "DISTRICT",
  "ปะคำ": "DISTRICT",
  "ปะตง": "DISTRICT",
  "ปะนาเระ": "DISTRICT",
  "ปะลุกาสาเมาะ": "DISTRICT",
  "ปะลุรู": "DISTRICT",
  "ปะหลาน": "DISTRICT",
  "ปะอาว": "DISTRICT",
  "ปะเคียบ": "DISTRICT",
  "ปะเสยะวอ": "DISTRICT",
  "ปะเหลียน": "DISTRICT",
  "ปะแต": "DISTRICT",
  "ปะโค": "DISTRICT",
  "ปะโด": "DISTRICT",
  "ปังกู": "DISTRICT",
  "ปังหวาน": "DISTRICT",
  "ปัถวี": "DISTRICT",
  "ปันแต": "DISTRICT",
  "ปัว": "DISTRICT",
  "ปากกราน": "DISTRICT",
  "ปากกาง": "DISTRICT",
  "ปากข้าวสาร": "DISTRICT",
  "ปากคม": "DISTRICT",
  "ปากคลอง": "DISTRICT",
  "ปากคลองบางปลากด": "DISTRICT",
  "ปากคลองภาษีเจริญ": "DISTRICT",
  "ปากคาด": "DISTRICT",
  "ปากจั่น": "DISTRICT",
  "ปากฉลุย": "DISTRICT",
  "ปากชม": "DISTRICT",
  "ปากช่อง": "DISTRICT",
  "ปากดุก": "DISTRICT",
  "ปากตม": "DISTRICT",
  "ปากตะโก": "DISTRICT",
  "ปากทรง": "DISTRICT",
  "ปากทะเล": "DISTRICT",
  "ปากทาง": "DISTRICT",
  "ปากท่อ": "DISTRICT",
  "ปากท่า": "DISTRICT",
  "ปากนคร": "DISTRICT",
  "ปากน้ำ": "DISTRICT",
  "ปากน้ำกระแส": "DISTRICT",
  "ปากน้ำปราณ": "DISTRICT",
  "ปากน้ำแหลมสิงห์": "DISTRICT",
  "ปากน้ำโพ": "DISTRICT",
  "ปากบาง": "DISTRICT",
  "ปากบ่อง": "DISTRICT",
  "ปากปวน": "DISTRICT",
  "ปากพนัง": "DISTRICT",
  "ปากพนังฝั่งตะวันตก": "DISTRICT",
  "ปากพนังฝั่งตะวันออก": "DISTRICT",
  "ปากพระ": "DISTRICT",
  "ปากพลี": "DISTRICT",
  "ปากพะยูน": "DISTRICT",
  "ปากพูน": "DISTRICT",
  "ปากรอ": "DISTRICT",
  "ปากล่อ": "DISTRICT",
  "ปากหมัน": "DISTRICT",
  "ปากหมาก": "DISTRICT",
  "ปากู": "DISTRICT",
  "ปากเกร็ด": "DISTRICT",
  "ปากเพรียว": "DISTRICT",
  "ปากแคว": "DISTRICT",
  "ปากแจ่ม": "DISTRICT",
  "ปากแตระ": "DISTRICT",
  "ปากแพรก": "DISTRICT",
  "ปากแรต": "DISTRICT",
  "ปากโทก": "DISTRICT",
  "ปางกู่": "DISTRICT",
  "ปางตาไว": "DISTRICT",
  "ปางมะค่า": "DISTRICT",
  "ปางมะผ้า": "DISTRICT",
  "ปางสวรรค์": "DISTRICT",
  "ปางหมู": "DISTRICT",
  "ปางหินฝน": "DISTRICT",
  "ปาดังเบซาร์": "DISTRICT",
  "ปานัน": "DISTRICT",
  "ปาฝา": "DISTRICT",
  "ปาล์มพัฒนา": "DISTRICT",
  "ปาเสมัส": "DISTRICT",
  "ปิงหลวง": "DISTRICT",
  "ปิงโค้ง": "DISTRICT",
  "ปิตูมุดี": "DISTRICT",
  "ปิยามุมัง": "DISTRICT",
  "ปิล๊อก": "DISTRICT",
  "ปึกเตียน": "DISTRICT",
  "ปุยุด": "DISTRICT",
  "ปุลากง": "DISTRICT",
  "ปุโรง": "DISTRICT",
  "ปุโละปุโย": "DISTRICT",
  "ปูยู": "DISTRICT",
  "ปูโยะ": "DISTRICT",
  "ป่งขาม": "DISTRICT",
  "ป่งไฮ": "DISTRICT",
  "ป่ากลาง": "DISTRICT",
  "ป่ากอ": "DISTRICT",
  "ป่ากุมเกาะ": "DISTRICT",
  "ป่าก่อ": "DISTRICT",
  "ป่าก่อดำ": "DISTRICT",
  "ป่าขะ": "DISTRICT",
  "ป่าขาด": "DISTRICT",
  "ป่าคลอก": "DISTRICT",
  "ป่าคา": "DISTRICT",
  "ป่าคาย": "DISTRICT",
  "ป่าคาหลวง": "DISTRICT",
  "ป่างิ้ว": "DISTRICT",
  "ป่าชัน": "DISTRICT",
  "ป่าชิง": "DISTRICT",
  "ป่าซาง": "DISTRICT",
  "ป่าตอง": "DISTRICT",
  "ป่าตัน": "DISTRICT",
  "ป่าตาล": "DISTRICT",
  "ป่าตึง": "DISTRICT",
  "ป่าตุ้ม": "DISTRICT",
  "ป่าบง": "DISTRICT",
  "ป่าบอน": "DISTRICT",
  "ป่าปอ": "DISTRICT",
  "ป่าป้อง": "DISTRICT",
  "ป่าพลู": "DISTRICT",
  "ป่าพะยอม": "DISTRICT",
  "ป่าพุทรา": "DISTRICT",
  "ป่ามะคาบ": "DISTRICT",
  "ป่ามะนาว": "DISTRICT",
  "ป่ามะม่วง": "DISTRICT",
  "ป่ายุบใน": "DISTRICT",
  "ป่าระกำ": "DISTRICT",
  "ป่าร่อน": "DISTRICT",
  "ป่าลาน": "DISTRICT",
  "ป่าสะแก": "DISTRICT",
  "ป่าสัก": "DISTRICT",
  "ป่าสังข์": "DISTRICT",
  "ป่าหวาย": "DISTRICT",
  "ป่าหวายนั่ง": "DISTRICT",
  "ป่าหุ่ง": "DISTRICT",
  "ป่าอ้อ": "DISTRICT",
  "ป่าอ้อดอนชัย": "DISTRICT",
  "ป่าเซ่า": "DISTRICT",
  "ป่าเด็ง": "DISTRICT",
  "ป่าเมี่ยง": "DISTRICT",
  "ป่าเลา": "DISTRICT",
  "ป่าเว": "DISTRICT",
  "ป่าแก่บ่อหิน": "DISTRICT",
  "ป่าแงะ": "DISTRICT",
  "ป่าแดง": "DISTRICT",
  "ป่าแดด": "DISTRICT",
  "ป่าแป๋": "DISTRICT",
  "ป่าแฝก": "DISTRICT",
  "ป่าแมต": "DISTRICT",
  "ป่าแลวหลวง": "DISTRICT",
  "ป่าโปง": "DISTRICT",
  "ป่าโมก": "DISTRICT",
  "ป่าโมง": "DISTRICT",
  "ป่าไก่": "DISTRICT",
  "ป่าไผ่": "DISTRICT",
  "ป่าไม้งาม": "DISTRICT",
  "ป่าไร่": "DISTRICT",
  "ป่าไหน่": "DISTRICT",
  "ป้อมปราบ": "DISTRICT",
  "ผดุงมาตร": "DISTRICT",
  "ผักขวง": "DISTRICT",
  "ผักขะ": "DISTRICT",
  "ผักตบ": "DISTRICT",
  "ผักปัง": "DISTRICT",
  "ผักแพว": "DISTRICT",
  "ผักแว่น": "DISTRICT",
  "ผักไหม": "DISTRICT",
  "ผักไห่": "DISTRICT",
  "ผาขาว": "DISTRICT",
  "ผางาม": "DISTRICT",
  "ผาจุก": "DISTRICT",
  "ผาช้างน้อย": "DISTRICT",
  "ผาตอ": "DISTRICT",
  "ผาตั้ง": "DISTRICT",
  "ผาทอง": "DISTRICT",
  "ผานกเค้า": "DISTRICT",
  "ผาน้อย": "DISTRICT",
  "ผาน้ำย้อย": "DISTRICT",
  "ผาบิ้ง": "DISTRICT",
  "ผาบ่อง": "DISTRICT",
  "ผาปัง": "DISTRICT",
  "ผาสามยอด": "DISTRICT",
  "ผาสิงห์": "DISTRICT",
  "ผาสุก": "DISTRICT",
  "ผาอินทร์แปลง": "DISTRICT",
  "ผาเลือด": "DISTRICT",
  "ผาเสวย": "DISTRICT",
  "ผึ่งแดด": "DISTRICT",
  "ผึ้งรวง": "DISTRICT",
  "ผือฮี": "DISTRICT",
  "ผือใหญ่": "DISTRICT",
  "ผไทรินทร์": "DISTRICT",
  "ผ่านศึก": "DISTRICT",
  "ฝั่งแดง": "DISTRICT",
  "ฝางคำ": "DISTRICT",
  "ฝายกวาง": "DISTRICT",
  "ฝายนาแซง": "DISTRICT",
  "ฝายหลวง": "DISTRICT",
  "ฝายแก้ว": "DISTRICT",
  "ฝาละมี": "DISTRICT",
  "พงตึก": "DISTRICT",
  "พงศ์ประศาสน์": "DISTRICT",
  "พงษ์": "DISTRICT",
  "พงสวาย": "DISTRICT",
  "พญาขัน": "DISTRICT",
  "พญาวัง": "DISTRICT",
  "พญาเย็น": "DISTRICT",
  "พญาแก้ว": "DISTRICT",
  "พญาแมน": "DISTRICT",
  "พญาไท": "DISTRICT",
  "พนม": "DISTRICT",
  "พนมทวน": "DISTRICT",
  "พนมรอก": "DISTRICT",
  "พนมวังก์": "DISTRICT",
  "พนมสารคาม": "DISTRICT",
  "พนมเศษ": "DISTRICT",
  "พนมไพร": "DISTRICT",
  "พนอม": "DISTRICT",
  "พนัสนิคม": "DISTRICT",
  "พนา": "DISTRICT",
  "พนางตุง": "DISTRICT",
  "พนานิคม": "DISTRICT",
  "พบพระ": "DISTRICT",
  "พยอม": "DISTRICT",
  "พยุหะ": "DISTRICT",
  "พยุห์": "DISTRICT",
  "พรมสวรรค์": "DISTRICT",
  "พรมเทพ": "DISTRICT",
  "พรรณา": "DISTRICT",
  "พรสวรรค์": "DISTRICT",
  "พรสำราญ": "DISTRICT",
  "พรหมณี": "DISTRICT",
  "พรหมนิมิต": "DISTRICT",
  "พรหมบุรี": "DISTRICT",
  "พรหมพิราม": "DISTRICT",
  "พรหมมาสตร์": "DISTRICT",
  "พรหมสวัสดิ์": "DISTRICT",
  "พรหมโลก": "DISTRICT",
  "พระกลางทุ่ง": "DISTRICT",
  "พระขาว": "DISTRICT",
  "พระครู": "DISTRICT",
  "พระงาม": "DISTRICT",
  "พระซอง": "DISTRICT",
  "พระธาตุ": "DISTRICT",
  "พระธาตุขิงแกง": "DISTRICT",
  "พระธาตุบังพวน": "DISTRICT",
  "พระธาตุผาแดง": "DISTRICT",
  "พระนอน": "DISTRICT",
  "พระบรมมหาราชวัง": "DISTRICT",
  "พระบาท": "DISTRICT",
  "พระบาทนาสิงห์": "DISTRICT",
  "พระบาทวังตวง": "DISTRICT",
  "พระบุ": "DISTRICT",
  "พระปฐมเจดีย์": "DISTRICT",
  "พระประโทน": "DISTRICT",
  "พระพุทธ": "DISTRICT",
  "พระพุทธบาท": "DISTRICT",
  "พระยาทด": "DISTRICT",
  "พระยาบันลือ": "DISTRICT",
  "พระยืน": "DISTRICT",
  "พระรักษ์": "DISTRICT",
  "พระลับ": "DISTRICT",
  "พระสิงห์": "DISTRICT",
  "พระหลวง": "DISTRICT",
  "พระอาจารย์": "DISTRICT",
  "พระเจ้า": "DISTRICT",
  "พระเพลิง": "DISTRICT",
  "พระเสาร์": "DISTRICT",
  "พระเหลา": "DISTRICT",
  "พระแก้ว": "DISTRICT",
  "พระแท่น": "DISTRICT",
  "พระโขนง": "DISTRICT",
  "พระโขนงเหนือ": "DISTRICT",
  "พราน": "DISTRICT",
  "พรานกระต่าย": "DISTRICT",
  "พรุดินนา": "DISTRICT",
  "พรุพี": "DISTRICT",
  "พรุเตียว": "DISTRICT",
  "พรุใน": "DISTRICT",
  "พรุไทย": "DISTRICT",
  "พรเจริญ": "DISTRICT",
  "พร่อน": "DISTRICT",
  "พลกรัง": "DISTRICT",
  "พลงตาเอี่ยม": "DISTRICT",
  "พลวง": "DISTRICT",
  "พลวงทอง": "DISTRICT",
  "พลวงสองนาง": "DISTRICT",
  "พลสงคราม": "DISTRICT",
  "พลอยแหวน": "DISTRICT",
  "พลับพลา": "DISTRICT",
  "พลับพลาไชย": "DISTRICT",
  "พลา": "DISTRICT",
  "พลายชุมพล": "DISTRICT",
  "พลายวาส": "DISTRICT",
  "พลิ้ว": "DISTRICT",
  "พลูตาหลวง": "DISTRICT",
  "พลูเถื่อน": "DISTRICT",
  "พวา": "DISTRICT",
  "พอกน้อย": "DISTRICT",
  "พะงาด": "DISTRICT",
  "พะตง": "DISTRICT",
  "พะทาย": "DISTRICT",
  "พะลาน": "DISTRICT",
  "พะวง": "DISTRICT",
  "พะวอ": "DISTRICT",
  "พะเนา": "DISTRICT",
  "พะเนียด": "DISTRICT",
  "พะแสง": "DISTRICT",
  "พะโต๊ะ": "DISTRICT",
  "พักทัน": "DISTRICT",
  "พังกาญจน์": "DISTRICT",
  "พังขว้าง": "DISTRICT",
  "พังงู": "DISTRICT",
  "พังตรุ": "DISTRICT",
  "พังทุย": "DISTRICT",
  "พังยาง": "DISTRICT",
  "พังราด": "DISTRICT",
  "พังลา": "DISTRICT",
  "พังเคน": "DISTRICT",
  "พังเทียม": "DISTRICT",
  "พังแดง": "DISTRICT",
  "พังโคน": "DISTRICT",
  "พัฒนาการ": "DISTRICT",
  "พัฒนานิคม": "DISTRICT",
  "พันชนะ": "DISTRICT",
  "พันชาลี": "DISTRICT",
  "พันดอน": "DISTRICT",
  "พันดุง": "DISTRICT",
  "พันท้ายนรสิงห์": "DISTRICT",
  "พันนา": "DISTRICT",
  "พันลาน": "DISTRICT",
  "พันเสา": "DISTRICT",
  "พานทอง": "DISTRICT",
  "พานพร้าว": "DISTRICT",
  "พิกุล": "DISTRICT",
  "พิกุลทอง": "DISTRICT",
  "พิกุลออก": "DISTRICT",
  "พิงพวย": "DISTRICT",
  "พิจิตร": "DISTRICT",
  "พิชัย": "DISTRICT",
  "พิตเพียน": "DISTRICT",
  "พิบูล": "DISTRICT",
  "พิปูน": "DISTRICT",
  "พิมพา": "DISTRICT",
  "พิมลราช": "DISTRICT",
  "พิมาน": "DISTRICT",
  "พิมาย": "DISTRICT",
  "พิมายเหนือ": "DISTRICT",
  "พิมูล": "DISTRICT",
  "พิหารแดง": "DISTRICT",
  "พิเทน": "DISTRICT",
  "พืชอุดม": "DISTRICT",
  "พุกร่าง": "DISTRICT",
  "พุขาม": "DISTRICT",
  "พุคา": "DISTRICT",
  "พุคำจาน": "DISTRICT",
  "พุดซา": "DISTRICT",
  "พุทธบาท": "DISTRICT",
  "พุทเลา": "DISTRICT",
  "พุทไธสง": "DISTRICT",
  "พุนกยูง": "DISTRICT",
  "พุนพิน": "DISTRICT",
  "พุมเรียง": "DISTRICT",
  "พุสวรรค์": "DISTRICT",
  "พุเตย": "DISTRICT",
  "พุแค": "DISTRICT",
  "พุ่มแก": "DISTRICT",
  "พ่วงพรมคร": "DISTRICT",
  "พ่อมิ่ง": "DISTRICT",
  "พ้อแดง": "DISTRICT",
  "ฟากท่า": "DISTRICT",
  "ฟากห้วย": "DISTRICT",
  "ฟ้าหยาด": "DISTRICT",
  "ฟ้าห่วน": "DISTRICT",
  "ฟ้าฮ่าม": "DISTRICT",
  "ภาชี": "DISTRICT",
  "ภารแอ่น": "DISTRICT",
  "ภูกระดึง": "DISTRICT",
  "ภูคา": "DISTRICT",
  "ภูซาง": "DISTRICT",
  "ภูดิน": "DISTRICT",
  "ภูน้ำหยด": "DISTRICT",
  "ภูปอ": "DISTRICT",
  "ภูผาม่าน": "DISTRICT",
  "ภูผาหมอก": "DISTRICT",
  "ภูฝ้าย": "DISTRICT",
  "ภูฟ้า": "DISTRICT",
  "ภูมิ": "DISTRICT",
  "ภูวง": "DISTRICT",
  "ภูสิงห์": "DISTRICT",
  "ภูหลวง": "DISTRICT",
  "ภูหอ": "DISTRICT",
  "ภูห่าน": "DISTRICT",
  "ภูเขาทอง": "DISTRICT",
  "ภูเงิน": "DISTRICT",
  "ภูเวียง": "DISTRICT",
  "ภูเหล็ก": "DISTRICT",
  "ภูแลนคา": "DISTRICT",
  "ภูแล่นช้าง": "DISTRICT",
  "มงคลธรรมนิมิต": "DISTRICT",
  "มดแดง": "DISTRICT",
  "มวกเหล็ก": "DISTRICT",
  "มหาชัย": "DISTRICT",
  "มหาดไทย": "DISTRICT",
  "มหาพราหมณ์": "DISTRICT",
  "มหาพฤฒาราม": "DISTRICT",
  "มหาราช": "DISTRICT",
  "มหาวัน": "DISTRICT",
  "มหาสวัสดิ์": "DISTRICT",
  "มหาสอน": "DISTRICT",
  "มหาโพธิ": "DISTRICT",
  "มหาไชย": "DISTRICT",
  "มะกรูด": "DISTRICT",
  "มะกอก": "DISTRICT",
  "มะกอกหวาน": "DISTRICT",
  "มะกอกเหนือ": "DISTRICT",
  "มะขาม": "DISTRICT",
  "มะขามคู่": "DISTRICT",
  "มะขามล้ม": "DISTRICT",
  "มะขามสูง": "DISTRICT",
  "มะขามหย่ง": "DISTRICT",
  "มะขามหลวง": "DISTRICT",
  "มะขามเฒ่า": "DISTRICT",
  "มะขามเตี้ย": "DISTRICT",
  "มะขุนหวาน": "DISTRICT",
  "มะค่า": "DISTRICT",
  "มะตูม": "DISTRICT",
  "มะต้อง": "DISTRICT",
  "มะนังดาลำ": "DISTRICT",
  "มะนังตายอ": "DISTRICT",
  "มะนังยง": "DISTRICT",
  "มะนาวหวาน": "DISTRICT",
  "มะบ้า": "DISTRICT",
  "มะมุ": "DISTRICT",
  "มะม่วงสองต้น": "DISTRICT",
  "มะรือโบตก": "DISTRICT",
  "มะรือโบออก": "DISTRICT",
  "มะรุ่ย": "DISTRICT",
  "มะลวน": "DISTRICT",
  "มะลิกา": "DISTRICT",
  "มะอึ": "DISTRICT",
  "มะเกลือเก่า": "DISTRICT",
  "มะเกลือใหม่": "DISTRICT",
  "มะเขือแจ้": "DISTRICT",
  "มะเฟือง": "DISTRICT",
  "มะเริง": "DISTRICT",
  "มะเร็ต": "DISTRICT",
  "มักกะสัน": "DISTRICT",
  "มาบกราด": "DISTRICT",
  "มาบข่า": "DISTRICT",
  "มาบตะโกเอน": "DISTRICT",
  "มาบตาพุด": "DISTRICT",
  "มาบปลาเค้า": "DISTRICT",
  "มาบยางพร": "DISTRICT",
  "มาบแก": "DISTRICT",
  "มาบแค": "DISTRICT",
  "มาบโป่ง": "DISTRICT",
  "มาบไผ่": "DISTRICT",
  "มาบไพ": "DISTRICT",
  "มาย": "DISTRICT",
  "มายอ": "DISTRICT",
  "มารวิชัย": "DISTRICT",
  "มาโมง": "DISTRICT",
  "มิตรภาพ": "DISTRICT",
  "มีชัย": "DISTRICT",
  "มีนบุรี": "DISTRICT",
  "มืดกา": "DISTRICT",
  "มุกดาหาร": "DISTRICT",
  "มุจลินท์": "DISTRICT",
  "มูโนะ": "DISTRICT",
  "ม่วง": "DISTRICT",
  "ม่วงกลวง": "DISTRICT",
  "ม่วงคำ": "DISTRICT",
  "ม่วงค่อม": "DISTRICT",
  "ม่วงงาม": "DISTRICT",
  "ม่วงชุม": "DISTRICT",
  "ม่วงตึ๊ด": "DISTRICT",
  "ม่วงนา": "DISTRICT",
  "ม่วงน้อย": "DISTRICT",
  "ม่วงยาย": "DISTRICT",
  "ม่วงลาด": "DISTRICT",
  "ม่วงลาย": "DISTRICT",
  "ม่วงสามสิบ": "DISTRICT",
  "ม่วงหมู่": "DISTRICT",
  "ม่วงหวาน": "DISTRICT",
  "ม่วงหัก": "DISTRICT",
  "ม่วงเจ็ดต้น": "DISTRICT",
  "ม่วงเตี้ย": "DISTRICT",
  "ม่วงใหญ่": "DISTRICT",
  "ม่วงไข่": "DISTRICT",
  "ม่อนจอง": "DISTRICT",
  "ม่อนปิ่น": "DISTRICT",
  "ยกกระบัตร": "DISTRICT",
  "ยม": "DISTRICT",
  "ยอด": "DISTRICT",
  "ยอดชาด": "DISTRICT",
  "ยอดแกง": "DISTRICT",
  "ยะต๊ะ": "DISTRICT",
  "ยะรม": "DISTRICT",
  "ยะรัง": "DISTRICT",
  "ยะลา": "DISTRICT",
  "ยะวึก": "DISTRICT",
  "ยะหา": "DISTRICT",
  "ยั้งเมิน": "DISTRICT",
  "ยาง": "DISTRICT",
  "ยางขาว": "DISTRICT",
  "ยางขี้นก": "DISTRICT",
  "ยางคราม": "DISTRICT",
  "ยางคำ": "DISTRICT",
  "ยางค้อม": "DISTRICT",
  "ยางงาม": "DISTRICT",
  "ยางชุมน้อย": "DISTRICT",
  "ยางชุมใหญ่": "DISTRICT",
  "ยางช้าย": "DISTRICT",
  "ยางซ้าย": "DISTRICT",
  "ยางตลาด": "DISTRICT",
  "ยางตาล": "DISTRICT",
  "ยางท่าแจ้ง": "DISTRICT",
  "ยางนอน": "DISTRICT",
  "ยางน้อย": "DISTRICT",
  "ยางน้ำกลัดเหนือ": "DISTRICT",
  "ยางน้ำกลัดใต้": "DISTRICT",
  "ยางม่วง": "DISTRICT",
  "ยางราก": "DISTRICT",
  "ยางสว่าง": "DISTRICT",
  "ยางสักกระโพหลุ่ม": "DISTRICT",
  "ยางสาว": "DISTRICT",
  "ยางสีสุราช": "DISTRICT",
  "ยางสูง": "DISTRICT",
  "ยางหย่อง": "DISTRICT",
  "ยางหล่อ": "DISTRICT",
  "ยางหวาย": "DISTRICT",
  "ยางหัก": "DISTRICT",
  "ยางอู้ม": "DISTRICT",
  "ยางฮอม": "DISTRICT",
  "ยางเนิ้ง": "DISTRICT",
  "ยางเปียง": "DISTRICT",
  "ยางโกลน": "DISTRICT",
  "ยางโทน": "DISTRICT",
  "ยางโยภาพ": "DISTRICT",
  "ยางใหญ่": "DISTRICT",
  "ยานนาวา": "DISTRICT",
  "ยาบหัวนา": "DISTRICT",
  "ยาบี": "DISTRICT",
  "ยามู": "DISTRICT",
  "ยายชา": "DISTRICT",
  "ยายร้า": "DISTRICT",
  "ยายแพง": "DISTRICT",
  "ยายแย้มวัฒนา": "DISTRICT",
  "ยี่งอ": "DISTRICT",
  "ยี่ล้น": "DISTRICT",
  "ยี่สาร": "DISTRICT",
  "ยุหว่า": "DISTRICT",
  "ยุโป": "DISTRICT",
  "ยุ้งทะลาย": "DISTRICT",
  "ย่อ": "DISTRICT",
  "ย่านซื่อ": "DISTRICT",
  "ย่านตาขาว": "DISTRICT",
  "ย่านมัทรี": "DISTRICT",
  "ย่านยาว": "DISTRICT",
  "ย่านรี": "DISTRICT",
  "รมณีย์": "DISTRICT",
  "รวมไทยพัฒนา": "DISTRICT",
  "รองเมือง": "DISTRICT",
  "รอบเมือง": "DISTRICT",
  "รอบเวียง": "DISTRICT",
  "ระบำ": "DISTRICT",
  "ระวะ": "DISTRICT",
  "ระวิง": "DISTRICT",
  "ระหาน": "DISTRICT",
  "ระเริง": "DISTRICT",
  "ระเว": "DISTRICT",
  "ระเวียง": "DISTRICT",
  "ระแงง": "DISTRICT",
  "ระแว้ง": "DISTRICT",
  "ระแหง": "DISTRICT",
  "ระโนด": "DISTRICT",
  "ระโสม": "DISTRICT",
  "รังกาใหญ่": "DISTRICT",
  "รังงาม": "DISTRICT",
  "รังนก": "DISTRICT",
  "รังสิต": "DISTRICT",
  "รังแร้ง": "DISTRICT",
  "รัชดาภิเษก": "DISTRICT",
  "รัตนบุรี": "DISTRICT",
  "รัตนวาปี": "DISTRICT",
  "รัตนวารี": "DISTRICT",
  "รัตภูมิ": "DISTRICT",
  "รับร่อ": "DISTRICT",
  "รัษฎา": "DISTRICT",
  "รั้วใหญ่": "DISTRICT",
  "รางจรเข้": "DISTRICT",
  "รางบัว": "DISTRICT",
  "รางพิกุล": "DISTRICT",
  "รางสาลี่": "DISTRICT",
  "รางหวาย": "DISTRICT",
  "ราชกรูด": "DISTRICT",
  "ราชคราม": "DISTRICT",
  "ราชธานี": "DISTRICT",
  "ราชสถิตย์": "DISTRICT",
  "ราชาเทวะ": "DISTRICT",
  "ราตาปันยัง": "DISTRICT",
  "ราม": "DISTRICT",
  "รามราช": "DISTRICT",
  "รามอินทรา": "DISTRICT",
  "รามแก้ว": "DISTRICT",
  "ราวต้นจันทร์": "DISTRICT",
  "ราษฎรพัฒนา": "DISTRICT",
  "ราษฎร์นิยม": "DISTRICT",
  "ราษฎร์บูรณะ": "DISTRICT",
  "ราษฎร์พัฒนา": "DISTRICT",
  "ราษฎร์เจริญ": "DISTRICT",
  "ราไวย์": "DISTRICT",
  "รำพัน": "DISTRICT",
  "รำมะสัก": "DISTRICT",
  "รำแดง": "DISTRICT",
  "ริม": "DISTRICT",
  "ริมกก": "DISTRICT",
  "ริมปิง": "DISTRICT",
  "ริมสีม่วง": "DISTRICT",
  "ริมเหนือ": "DISTRICT",
  "ริมโขง": "DISTRICT",
  "ริมใต้": "DISTRICT",
  "ริโก๋": "DISTRICT",
  "รือเสาะ": "DISTRICT",
  "รือเสาะออก": "DISTRICT",
  "รุง": "DISTRICT",
  "รุ่งระวี": "DISTRICT",
  "รูสะมิแล": "DISTRICT",
  "ร่มเกล้า": "DISTRICT",
  "ร่มเมือง": "DISTRICT",
  "ร่มเย็น": "DISTRICT",
  "ร่มไทร": "DISTRICT",
  "ร่วมจิต": "DISTRICT",
  "ร่องกาศ": "DISTRICT",
  "ร่องคำ": "DISTRICT",
  "ร่องจิก": "DISTRICT",
  "ร่องฟอง": "DISTRICT",
  "ร่องเคาะ": "DISTRICT",
  "ร่อนทอง": "DISTRICT",
  "ร่อนพิบูลย์": "DISTRICT",
  "ร้องกวาง": "DISTRICT",
  "ร้องวัวแดง": "DISTRICT",
  "ร้องเข็ม": "DISTRICT",
  "ลมศักดิ์": "DISTRICT",
  "ลวงเหนือ": "DISTRICT",
  "ลอ": "DISTRICT",
  "ลอมคอม": "DISTRICT",
  "ละงู": "DISTRICT",
  "ละทาย": "DISTRICT",
  "ละมอ": "DISTRICT",
  "ละลม": "DISTRICT",
  "ละลมใหม่พัฒนา": "DISTRICT",
  "ละลวด": "DISTRICT",
  "ละลาย": "DISTRICT",
  "ละหาน": "DISTRICT",
  "ละหานทราย": "DISTRICT",
  "ละหานนา": "DISTRICT",
  "ละหานปลาค้าว": "DISTRICT",
  "ละหาร": "DISTRICT",
  "ละอาย": "DISTRICT",
  "ละอุ่นเหนือ": "DISTRICT",
  "ละอุ่นใต้": "DISTRICT",
  "ละเวี้ย": "DISTRICT",
  "ละเอาะ": "DISTRICT",
  "ละแม": "DISTRICT",
  "ละแอ": "DISTRICT",
  "ลางา": "DISTRICT",
  "ลาดกระทิง": "DISTRICT",
  "ลาดกระบัง": "DISTRICT",
  "ลาดขวาง": "DISTRICT",
  "ลาดควาย": "DISTRICT",
  "ลาดค่าง": "DISTRICT",
  "ลาดงา": "DISTRICT",
  "ลาดชิด": "DISTRICT",
  "ลาดตะเคียน": "DISTRICT",
  "ลาดทิพรส": "DISTRICT",
  "ลาดน้ำเค็ม": "DISTRICT",
  "ลาดบัวขาว": "DISTRICT",
  "ลาดบัวหลวง": "DISTRICT",
  "ลาดพร้าว": "DISTRICT",
  "ลาดพัฒนา": "DISTRICT",
  "ลาดยาว": "DISTRICT",
  "ลาดสวาย": "DISTRICT",
  "ลาดสาลี่": "DISTRICT",
  "ลาดหญ้า": "DISTRICT",
  "ลาดหลุมแก้ว": "DISTRICT",
  "ลาดแค": "DISTRICT",
  "ลาดโพธิ์": "DISTRICT",
  "ลาดใหญ่": "DISTRICT",
  "ลานกระบือ": "DISTRICT",
  "ลานข่อย": "DISTRICT",
  "ลานดอกไม้": "DISTRICT",
  "ลานดอกไม้ตก": "DISTRICT",
  "ลานตากฟ้า": "DISTRICT",
  "ลานบ่า": "DISTRICT",
  "ลานสกา": "DISTRICT",
  "ลานสะแก": "DISTRICT",
  "ลานสัก": "DISTRICT",
  "ลานหอย": "DISTRICT",
  "ลาโละ": "DISTRICT",
  "ลำคลอง": "DISTRICT",
  "ลำคอหงษ์": "DISTRICT",
  "ลำชี": "DISTRICT",
  "ลำดวน": "DISTRICT",
  "ลำตะเคียน": "DISTRICT",
  "ลำตาเสา": "DISTRICT",
  "ลำต้อยติ่ง": "DISTRICT",
  "ลำทับ": "DISTRICT",
  "ลำนางรอง": "DISTRICT",
  "ลำนางแก้ว": "DISTRICT",
  "ลำนารายณ์": "DISTRICT",
  "ลำประดา": "DISTRICT",
  "ลำปลาทิว": "DISTRICT",
  "ลำปลายมาศ": "DISTRICT",
  "ลำปางหลวง": "DISTRICT",
  "ลำปาว": "DISTRICT",
  "ลำปำ": "DISTRICT",
  "ลำผักกูด": "DISTRICT",
  "ลำผักชี": "DISTRICT",
  "ลำพญา": "DISTRICT",
  "ลำพญากลาง": "DISTRICT",
  "ลำพยนต์": "DISTRICT",
  "ลำพยา": "DISTRICT",
  "ลำพะยา": "DISTRICT",
  "ลำพาน": "DISTRICT",
  "ลำพูน": "DISTRICT",
  "ลำภี": "DISTRICT",
  "ลำภู": "DISTRICT",
  "ลำภูรา": "DISTRICT",
  "ลำมูล": "DISTRICT",
  "ลำลูกกา": "DISTRICT",
  "ลำลูกบัว": "DISTRICT",
  "ลำสนธิ": "DISTRICT",
  "ลำสมพุง": "DISTRICT",
  "ลำสินธุ์": "DISTRICT",
  "ลำหนองแสน": "DISTRICT",
  "ลำห้วยหลัว": "DISTRICT",
  "ลำเพียก": "DISTRICT",
  "ลำเลียง": "DISTRICT",
  "ลำเหย": "DISTRICT",
  "ลำแก่น": "DISTRICT",
  "ลำโพ": "DISTRICT",
  "ลำใหม่": "DISTRICT",
  "ลำไทร": "DISTRICT",
  "ลำไทรโยง": "DISTRICT",
  "ลำไพล": "DISTRICT",
  "ลิดล": "DISTRICT",
  "ลิปะน้อย": "DISTRICT",
  "ลิปะสะโง": "DISTRICT",
  "ลิพัง": "DISTRICT",
  "ลิ่นถิ่น": "DISTRICT",
  "ลิ้นฟ้า": "DISTRICT",
  "ลีเล็ด": "DISTRICT",
  "ลี้": "DISTRICT",
  "ลือ": "DISTRICT",
  "ลุงเขว้า": "DISTRICT",
  "ลุมปุ๊ก": "DISTRICT",
  "ลุมพลี": "DISTRICT",
  "ลุมพินี": "DISTRICT",
  "ลุมพุก": "DISTRICT",
  "ลุโบะบายะ": "DISTRICT",
  "ลุโบะบือซา": "DISTRICT",
  "ลุโบะยิไร": "DISTRICT",
  "ลุโบะสาวอ": "DISTRICT",
  "ลุ่มระวี": "DISTRICT",
  "ลุ่มลำชี": "DISTRICT",
  "ลุ่มสุ่ม": "DISTRICT",
  "ล้อมแรด": "DISTRICT",
  "วงฆ้อง": "DISTRICT",
  "วงศ์สว่าง": "DISTRICT",
  "วชิรพยาบาล": "DISTRICT",
  "วรนคร": "DISTRICT",
  "วอแก้ว": "DISTRICT",
  "วะตะแบก": "DISTRICT",
  "วัง": "DISTRICT",
  "วังกรด": "DISTRICT",
  "วังกระแจะ": "DISTRICT",
  "วังกระโจม": "DISTRICT",
  "วังกวาง": "DISTRICT",
  "วังกะทะ": "DISTRICT",
  "วังกะพี้": "DISTRICT",
  "วังก์พง": "DISTRICT",
  "วังขนาย": "DISTRICT",
  "วังขอนขว้าง": "DISTRICT",
  "วังข่อย": "DISTRICT",
  "วังควง": "DISTRICT",
  "วังคัน": "DISTRICT",
  "วังคีรี": "DISTRICT",
  "วังงิ้ว": "DISTRICT",
  "วังงิ้วใต้": "DISTRICT",
  "วังจันทร์": "DISTRICT",
  "วังจั่น": "DISTRICT",
  "วังจิก": "DISTRICT",
  "วังจุฬา": "DISTRICT",
  "วังชมภู": "DISTRICT",
  "วังชะพลู": "DISTRICT",
  "วังชะโอน": "DISTRICT",
  "วังชัย": "DISTRICT",
  "วังชิ้น": "DISTRICT",
  "วังซ่าน": "DISTRICT",
  "วังซ้าย": "DISTRICT",
  "วังดาล": "DISTRICT",
  "วังดิน": "DISTRICT",
  "วังด้ง": "DISTRICT",
  "วังตะกอ": "DISTRICT",
  "วังตะกู": "DISTRICT",
  "วังตะคร้อ": "DISTRICT",
  "วังตะเคียน": "DISTRICT",
  "วังตะเฆ่": "DISTRICT",
  "วังตะแบก": "DISTRICT",
  "วังตะโก": "DISTRICT",
  "วังตามัว": "DISTRICT",
  "วังทรายคำ": "DISTRICT",
  "วังทรายพูน": "DISTRICT",
  "วังทอง": "DISTRICT",
  "วังทองหลาง": "DISTRICT",
  "วังทองแดง": "DISTRICT",
  "วังทับไทร": "DISTRICT",
  "วังท่าช้าง": "DISTRICT",
  "วังท่าดี": "DISTRICT",
  "วังธง": "DISTRICT",
  "วังนกแอ่น": "DISTRICT",
  "วังน้อย": "DISTRICT",
  "วังน้ำขาว": "DISTRICT",
  "วังน้ำคู้": "DISTRICT",
  "วังน้ำซับ": "DISTRICT",
  "วังน้ำลัด": "DISTRICT",
  "วังน้ำเขียว": "DISTRICT",
  "วังน้ำเย็น": "DISTRICT",
  "วังบัว": "DISTRICT",
  "วังบาล": "DISTRICT",
  "วังบูรพาภิรมย์": "DISTRICT",
  "วังบ่อ": "DISTRICT",
  "วังประจบ": "DISTRICT",
  "วังประจัน": "DISTRICT",
  "วังปลาป้อม": "DISTRICT",
  "วังผาง": "DISTRICT",
  "วังพญา": "DISTRICT",
  "วังพร้าว": "DISTRICT",
  "วังพัฒนา": "DISTRICT",
  "วังพิกุล": "DISTRICT",
  "วังพิณพาทย์": "DISTRICT",
  "วังมหากร": "DISTRICT",
  "วังมะนาว": "DISTRICT",
  "วังมะปราง": "DISTRICT",
  "วังมะปรางเหนือ": "DISTRICT",
  "วังม่วง": "DISTRICT",
  "วังม้า": "DISTRICT",
  "วังยาง": "DISTRICT",
  "วังยายทอง": "DISTRICT",
  "วังยาว": "DISTRICT",
  "วังลึก": "DISTRICT",
  "วังวน": "DISTRICT",
  "วังศรีราช": "DISTRICT",
  "วังศาล": "DISTRICT",
  "วังศาลา": "DISTRICT",
  "วังสมบูรณ์": "DISTRICT",
  "วังสรรพรส": "DISTRICT",
  "วังสวาบ": "DISTRICT",
  "วังสะพุง": "DISTRICT",
  "วังสามหมอ": "DISTRICT",
  "วังสามัคคี": "DISTRICT",
  "วังสำโรง": "DISTRICT",
  "วังหงษ์": "DISTRICT",
  "วังหมัน": "DISTRICT",
  "วังหมี": "DISTRICT",
  "วังหลวง": "DISTRICT",
  "วังหลุม": "DISTRICT",
  "วังหว้า": "DISTRICT",
  "วังหามแห": "DISTRICT",
  "วังหิน": "DISTRICT",
  "วังหินลาด": "DISTRICT",
  "วังอิทก": "DISTRICT",
  "วังอ่าง": "DISTRICT",
  "วังเงิน": "DISTRICT",
  "วังเพลิง": "DISTRICT",
  "วังเพิ่ม": "DISTRICT",
  "วังเมือง": "DISTRICT",
  "วังเย็น": "DISTRICT",
  "วังเหนือ": "DISTRICT",
  "วังแก้ว": "DISTRICT",
  "วังแขม": "DISTRICT",
  "วังแซ้ม": "DISTRICT",
  "วังแดง": "DISTRICT",
  "วังแสง": "DISTRICT",
  "วังโตนด": "DISTRICT",
  "วังโบสถ์": "DISTRICT",
  "วังโป่ง": "DISTRICT",
  "วังโพธิ์": "DISTRICT",
  "วังโพรง": "DISTRICT",
  "วังโมกข์": "DISTRICT",
  "วังโรงใหญ่": "DISTRICT",
  "วังใต้": "DISTRICT",
  "วังใหญ่": "DISTRICT",
  "วังใหม่": "DISTRICT",
  "วังไก่เถื่อน": "DISTRICT",
  "วังไคร้": "DISTRICT",
  "วังไชย": "DISTRICT",
  "วังไทร": "DISTRICT",
  "วังไผ่": "DISTRICT",
  "วังไม้ขอน": "DISTRICT",
  "วังไม้แดง": "DISTRICT",
  "วัฒนา": "DISTRICT",
  "วัฒนานคร": "DISTRICT",
  "วัด": "DISTRICT",
  "วัดกัลยาณ์": "DISTRICT",
  "วัดขนุน": "DISTRICT",
  "วัดขวาง": "DISTRICT",
  "วัดจันทร์": "DISTRICT",
  "วัดชลอ": "DISTRICT",
  "วัดดาว": "DISTRICT",
  "วัดตะกู": "DISTRICT",
  "วัดตายม": "DISTRICT",
  "วัดตูม": "DISTRICT",
  "วัดท่าพระ": "DISTRICT",
  "วัดธาตุ": "DISTRICT",
  "วัดประดู่": "DISTRICT",
  "วัดป่า": "DISTRICT",
  "วัดพระยาไกร": "DISTRICT",
  "วัดพริก": "DISTRICT",
  "วัดยม": "DISTRICT",
  "วัดยางงาม": "DISTRICT",
  "วัดราชบพิธ": "DISTRICT",
  "วัดละมุด": "DISTRICT",
  "วัดสน": "DISTRICT",
  "วัดสามพระยา": "DISTRICT",
  "วัดสำโรง": "DISTRICT",
  "วัดสิงห์": "DISTRICT",
  "วัดสุวรรณ": "DISTRICT",
  "วัดหลวง": "DISTRICT",
  "วัดอรุณ": "DISTRICT",
  "วัดเกต": "DISTRICT",
  "วัดเกาะ": "DISTRICT",
  "วัดเทพศิรินทร์": "DISTRICT",
  "วัดเพลง": "DISTRICT",
  "วัดแก้ว": "DISTRICT",
  "วัดแค": "DISTRICT",
  "วัดโคก": "DISTRICT",
  "วัดโบสถ์": "DISTRICT",
  "วัดโสมนัส": "DISTRICT",
  "วัดใหม่": "DISTRICT",
  "วัดไทร": "DISTRICT",
  "วัดไทรย์": "DISTRICT",
  "วันดาว": "DISTRICT",
  "วันยาว": "DISTRICT",
  "วานรนิวาส": "DISTRICT",
  "วาริชภูมิ": "DISTRICT",
  "วาริน": "DISTRICT",
  "วารินชำราบ": "DISTRICT",
  "วารีสวัสดิ์": "DISTRICT",
  "วาวี": "DISTRICT",
  "วาเล่ย์": "DISTRICT",
  "วาใหญ่": "DISTRICT",
  "วิชิต": "DISTRICT",
  "วิศิษฐ์": "DISTRICT",
  "วิสัยเหนือ": "DISTRICT",
  "วิสัยใต้": "DISTRICT",
  "วิหารขาว": "DISTRICT",
  "วิหารแดง": "DISTRICT",
  "วิเชตนคร": "DISTRICT",
  "ศรีกะอาง": "DISTRICT",
  "ศรีคีรีมาศ": "DISTRICT",
  "ศรีค้ำ": "DISTRICT",
  "ศรีจุฬา": "DISTRICT",
  "ศรีชมภู": "DISTRICT",
  "ศรีฐาน": "DISTRICT",
  "ศรีณรงค์": "DISTRICT",
  "ศรีดงเย็น": "DISTRICT",
  "ศรีดอนชัย": "DISTRICT",
  "ศรีดอนมูล": "DISTRICT",
  "ศรีดอนไชย": "DISTRICT",
  "ศรีตระกูล": "DISTRICT",
  "ศรีถ้อย": "DISTRICT",
  "ศรีธาตุ": "DISTRICT",
  "ศรีนคร": "DISTRICT",
  "ศรีนาวา": "DISTRICT",
  "ศรีบรรพต": "DISTRICT",
  "ศรีบัวบาน": "DISTRICT",
  "ศรีบุญเรือง": "DISTRICT",
  "ศรีประจันต์": "DISTRICT",
  "ศรีพนมมาศ": "DISTRICT",
  "ศรีพราน": "DISTRICT",
  "ศรีภิรมย์": "DISTRICT",
  "ศรีภูมิ": "DISTRICT",
  "ศรีมงคล": "DISTRICT",
  "ศรีมหาโพธิ": "DISTRICT",
  "ศรีมหาโพธิ์": "DISTRICT",
  "ศรีราชา": "DISTRICT",
  "ศรีละกอ": "DISTRICT",
  "ศรีวิชัย": "DISTRICT",
  "ศรีวิลัย": "DISTRICT",
  "ศรีวิไล": "DISTRICT",
  "ศรีษะทอง": "DISTRICT",
  "ศรีษะเกษ": "DISTRICT",
  "ศรีสงคราม": "DISTRICT",
  "ศรีสมเด็จ": "DISTRICT",
  "ศรีสว่าง": "DISTRICT",
  "ศรีสองรัก": "DISTRICT",
  "ศรีสะอาด": "DISTRICT",
  "ศรีสัชนาลัย": "DISTRICT",
  "ศรีสาคร": "DISTRICT",
  "ศรีสำราญ": "DISTRICT",
  "ศรีสุข": "DISTRICT",
  "ศรีสุขสำราญ": "DISTRICT",
  "ศรีสุทโธ": "DISTRICT",
  "ศรีสุนทร": "DISTRICT",
  "ศรีสุราษฎร์": "DISTRICT",
  "ศรีเตี้ย": "DISTRICT",
  "ศรีเทพ": "DISTRICT",
  "ศรีเมืองชุม": "DISTRICT",
  "ศรีแก้ว": "DISTRICT",
  "ศรีโคตร": "DISTRICT",
  "ศรีโนนงาม": "DISTRICT",
  "ศรีโพธิ์เงิน": "DISTRICT",
  "ศาลา": "DISTRICT",
  "ศาลากลาง": "DISTRICT",
  "ศาลาขาว": "DISTRICT",
  "ศาลาครุ": "DISTRICT",
  "ศาลาด่าน": "DISTRICT",
  "ศาลาธรรมสพน์": "DISTRICT",
  "ศาลายา": "DISTRICT",
  "ศาลารีไทย": "DISTRICT",
  "ศาลาลอย": "DISTRICT",
  "ศาลาลัย": "DISTRICT",
  "ศาลาลาย": "DISTRICT",
  "ศาลาลำดวน": "DISTRICT",
  "ศาลาแดง": "DISTRICT",
  "ศาลาใหม่": "DISTRICT",
  "ศาลเจ้าพ่อเสือ": "DISTRICT",
  "ศาลเจ้าโรงทอง": "DISTRICT",
  "ศาลเจ้าไก่ต่อ": "DISTRICT",
  "ศิริราช": "DISTRICT",
  "ศิลา": "DISTRICT",
  "ศิลาดาน": "DISTRICT",
  "ศิลาทิพย์": "DISTRICT",
  "ศิลาลอย": "DISTRICT",
  "ศิลาเพชร": "DISTRICT",
  "ศิลาแลง": "DISTRICT",
  "ศีรษะกระบือ": "DISTRICT",
  "ศีรษะจรเข้น้อย": "DISTRICT",
  "ศีรษะจรเข้ใหญ่": "DISTRICT",
  "สกาด": "DISTRICT",
  "สงยาง": "DISTRICT",
  "สงเปลือย": "DISTRICT",
  "สงเปือย": "DISTRICT",
  "สง่าบ้าน": "DISTRICT",
  "สตึก": "DISTRICT",
  "สถาน": "DISTRICT",
  "สทิงหม้อ": "DISTRICT",
  "สนม": "DISTRICT",
  "สนวน": "DISTRICT",
  "สนับทึบ": "DISTRICT",
  "สนามคลี": "DISTRICT",
  "สนามจันทร์": "DISTRICT",
  "สนามชัย": "DISTRICT",
  "สนามบิน": "DISTRICT",
  "สนามแจง": "DISTRICT",
  "สนามแย้": "DISTRICT",
  "สนามไชย": "DISTRICT",
  "สบตุ๋ย": "DISTRICT",
  "สบบง": "DISTRICT",
  "สบปราบ": "DISTRICT",
  "สบป่อง": "DISTRICT",
  "สบป้าด": "DISTRICT",
  "สบสาย": "DISTRICT",
  "สบเตี๊ยะ": "DISTRICT",
  "สบเปิง": "DISTRICT",
  "สบเมย": "DISTRICT",
  "สบแม่ข่า": "DISTRICT",
  "สบโขง": "DISTRICT",
  "สมสนุก": "DISTRICT",
  "สมสะอาด": "DISTRICT",
  "สมหวัง": "DISTRICT",
  "สมอ": "DISTRICT",
  "สมอทอง": "DISTRICT",
  "สมอพลือ": "DISTRICT",
  "สมอแข": "DISTRICT",
  "สมอโคน": "DISTRICT",
  "สมัย": "DISTRICT",
  "สมุด": "DISTRICT",
  "สมเด็จ": "DISTRICT",
  "สมเด็จเจริญ": "DISTRICT",
  "สมเด็จเจ้าพระยา": "DISTRICT",
  "สรรพยา": "DISTRICT",
  "สรอย": "DISTRICT",
  "สระ": "DISTRICT",
  "สระกรวด": "DISTRICT",
  "สระกระโจม": "DISTRICT",
  "สระกะเทียม": "DISTRICT",
  "สระกำแพงใหญ่": "DISTRICT",
  "สระขวัญ": "DISTRICT",
  "สระขุด": "DISTRICT",
  "สระคู": "DISTRICT",
  "สระจรเข้": "DISTRICT",
  "สระตะเคียน": "DISTRICT",
  "สระทอง": "DISTRICT",
  "สระทะเล": "DISTRICT",
  "สระนกแก้ว": "DISTRICT",
  "สระบัว": "DISTRICT",
  "สระประดู่": "DISTRICT",
  "สระพระ": "DISTRICT",
  "สระพัง": "DISTRICT",
  "สระพังทอง": "DISTRICT",
  "สระพังลาน": "DISTRICT",
  "สระพัฒนา": "DISTRICT",
  "สระยายโสม": "DISTRICT",
  "สระลงเรือ": "DISTRICT",
  "สระว่านพระยา": "DISTRICT",
  "สระสมิง": "DISTRICT",
  "สระสี่มุม": "DISTRICT",
  "สระสี่เหลี่ยม": "DISTRICT",
  "สระเยาว์": "DISTRICT",
  "สระแก้ว": "DISTRICT",
  "สระแจง": "DISTRICT",
  "สระโบสถ์": "DISTRICT",
  "สระโพนทอง": "DISTRICT",
  "สระใคร": "DISTRICT",
  "สร่างโศก": "DISTRICT",
  "สร้อยทอง": "DISTRICT",
  "สร้อยพร้าว": "DISTRICT",
  "สร้อยฟ้า": "DISTRICT",
  "สร้อยละคร": "DISTRICT",
  "สร้างก่อ": "DISTRICT",
  "สร้างคอม": "DISTRICT",
  "สร้างค้อ": "DISTRICT",
  "สร้างถ่อ": "DISTRICT",
  "สร้างถ่อน้อย": "DISTRICT",
  "สร้างนกทา": "DISTRICT",
  "สร้างนางขาว": "DISTRICT",
  "สร้างปี่": "DISTRICT",
  "สร้างมิ่ง": "DISTRICT",
  "สร้างแซ่ง": "DISTRICT",
  "สร้างแป้น": "DISTRICT",
  "สลกบาตร": "DISTRICT",
  "สลักได": "DISTRICT",
  "สลุย": "DISTRICT",
  "สวก": "DISTRICT",
  "สวด": "DISTRICT",
  "สวนกล้วย": "DISTRICT",
  "สวนขัน": "DISTRICT",
  "สวนจิก": "DISTRICT",
  "สวนจิตรลดา": "DISTRICT",
  "สวนดอก": "DISTRICT",
  "สวนดอกไม้": "DISTRICT",
  "สวนป่าน": "DISTRICT",
  "สวนผึ้ง": "DISTRICT",
  "สวนพริก": "DISTRICT",
  "สวนพริกไทย": "DISTRICT",
  "สวนส้ม": "DISTRICT",
  "สวนหม่อน": "DISTRICT",
  "สวนหลวง": "DISTRICT",
  "สวนเขื่อน": "DISTRICT",
  "สวนเมี่ยง": "DISTRICT",
  "สวนแตง": "DISTRICT",
  "สวนใหญ่": "DISTRICT",
  "สวาท": "DISTRICT",
  "สวาย": "DISTRICT",
  "สวายจีก": "DISTRICT",
  "สวี": "DISTRICT",
  "สว่าง": "DISTRICT",
  "สว่างอารมณ์": "DISTRICT",
  "สว่างแดนดิน": "DISTRICT",
  "สหกรณ์นิคม": "DISTRICT",
  "สหธาตุ": "DISTRICT",
  "สหัสขันธ์": "DISTRICT",
  "สองคลอง": "DISTRICT",
  "สองคอน": "DISTRICT",
  "สองชั้น": "DISTRICT",
  "สองพี่น้อง": "DISTRICT",
  "สองสลึง": "DISTRICT",
  "สองห้อง": "DISTRICT",
  "สองแคว": "DISTRICT",
  "สองแพรก": "DISTRICT",
  "สะกอม": "DISTRICT",
  "สะกาด": "DISTRICT",
  "สะกำ": "DISTRICT",
  "สะดาวา": "DISTRICT",
  "สะตอ": "DISTRICT",
  "สะตอน": "DISTRICT",
  "สะท้อน": "DISTRICT",
  "สะนอ": "DISTRICT",
  "สะบารัง": "DISTRICT",
  "สะบ้าย้อย": "DISTRICT",
  "สะพลี": "DISTRICT",
  "สะพานสอง": "DISTRICT",
  "สะพานสูง": "DISTRICT",
  "สะพานหิน": "DISTRICT",
  "สะพานไกร": "DISTRICT",
  "สะพานไทย": "DISTRICT",
  "สะพานไม้แก่น": "DISTRICT",
  "สะพือ": "DISTRICT",
  "สะพุง": "DISTRICT",
  "สะลวง": "DISTRICT",
  "สะอาด": "DISTRICT",
  "สะอาดสมบูรณ์": "DISTRICT",
  "สะอาดไชยศรี": "DISTRICT",
  "สะเดา": "DISTRICT",
  "สะเดาะพง": "DISTRICT",
  "สะเดาใหญ่": "DISTRICT",
  "สะเดียง": "DISTRICT",
  "สะเตง": "DISTRICT",
  "สะเตงนอก": "DISTRICT",
  "สะเนียน": "DISTRICT",
  "สะเมิงเหนือ": "DISTRICT",
  "สะเมิงใต้": "DISTRICT",
  "สะเอะ": "DISTRICT",
  "สะเอียบ": "DISTRICT",
  "สะแก": "DISTRICT",
  "สะแกกรัง": "DISTRICT",
  "สะแกซำ": "DISTRICT",
  "สะแกราช": "DISTRICT",
  "สะแกราบ": "DISTRICT",
  "สะแกโพรง": "DISTRICT",
  "สะแบง": "DISTRICT",
  "สะโน": "DISTRICT",
  "สักงาม": "DISTRICT",
  "สักหลง": "DISTRICT",
  "สังขะ": "DISTRICT",
  "สังคม": "DISTRICT",
  "สังเม็ก": "DISTRICT",
  "สัตหีบ": "DISTRICT",
  "สันกลาง": "DISTRICT",
  "สันกำแพง": "DISTRICT",
  "สันดอนแก้ว": "DISTRICT",
  "สันติคีรี": "DISTRICT",
  "สันติสุข": "DISTRICT",
  "สันต้นหมื้อ": "DISTRICT",
  "สันทราย": "DISTRICT",
  "สันทรายงาม": "DISTRICT",
  "สันทรายน้อย": "DISTRICT",
  "สันทรายหลวง": "DISTRICT",
  "สันทะ": "DISTRICT",
  "สันนาเม็ง": "DISTRICT",
  "สันปูเลย": "DISTRICT",
  "สันป่าตอง": "DISTRICT",
  "สันป่าม่วง": "DISTRICT",
  "สันป่ายาง": "DISTRICT",
  "สันป่าเปา": "DISTRICT",
  "สันผักหวาน": "DISTRICT",
  "สันผีเสื้อ": "DISTRICT",
  "สันพระเนตร": "DISTRICT",
  "สันมหาพน": "DISTRICT",
  "สันมะค่า": "DISTRICT",
  "สันมะเค็ด": "DISTRICT",
  "สันสลี": "DISTRICT",
  "สันโค้ง": "DISTRICT",
  "สันโป่ง": "DISTRICT",
  "สัมปทวน": "DISTRICT",
  "สัมพันธวงศ์": "DISTRICT",
  "สัมพันธ์": "DISTRICT",
  "สัมฤทธิ์": "DISTRICT",
  "สากอ": "DISTRICT",
  "สากเหล็ก": "DISTRICT",
  "สาคร": "DISTRICT",
  "สาคอบน": "DISTRICT",
  "สาคอใต้": "DISTRICT",
  "สาคู": "DISTRICT",
  "สานตม": "DISTRICT",
  "สาบัน": "DISTRICT",
  "สามกระทาย": "DISTRICT",
  "สามกอ": "DISTRICT",
  "สามขา": "DISTRICT",
  "สามควายเผือก": "DISTRICT",
  "สามง่าม": "DISTRICT",
  "สามง่ามท่าโบสถ์": "DISTRICT",
  "สามชุก": "DISTRICT",
  "สามตำบล": "DISTRICT",
  "สามตุ่ม": "DISTRICT",
  "สามบัณฑิต": "DISTRICT",
  "สามผง": "DISTRICT",
  "สามพระยา": "DISTRICT",
  "สามพราน": "DISTRICT",
  "สามพร้าว": "DISTRICT",
  "สามพวง": "DISTRICT",
  "สามพี่น้อง": "DISTRICT",
  "สามร้อยยอด": "DISTRICT",
  "สามวาตะวันตก": "DISTRICT",
  "สามวาตะวันออก": "DISTRICT",
  "สามสวน": "DISTRICT",
  "สามหมื่น": "DISTRICT",
  "สามัคคี": "DISTRICT",
  "สามัคคีพัฒนา": "DISTRICT",
  "สามเงา": "DISTRICT",
  "สามเมือง": "DISTRICT",
  "สามเรือน": "DISTRICT",
  "สามเสนนอก": "DISTRICT",
  "สามเสนใน": "DISTRICT",
  "สามแยก": "DISTRICT",
  "สามแวง": "DISTRICT",
  "สามโก้": "DISTRICT",
  "สามโคก": "DISTRICT",
  "สามไถ": "DISTRICT",
  "สายคำโห้": "DISTRICT",
  "สายตะกู": "DISTRICT",
  "สายทอง": "DISTRICT",
  "สายนาวัง": "DISTRICT",
  "สายลำโพง": "DISTRICT",
  "สายห้วยแก้ว": "DISTRICT",
  "สายออ": "DISTRICT",
  "สายไหม": "DISTRICT",
  "สารจิตร": "DISTRICT",
  "สารภี": "DISTRICT",
  "สาริกา": "DISTRICT",
  "สาลี": "DISTRICT",
  "สาวชะโงก": "DISTRICT",
  "สาวร้องไห้": "DISTRICT",
  "สาวอ": "DISTRICT",
  "สาวะถี": "DISTRICT",
  "สาวแห": "DISTRICT",
  "สาหร่าย": "DISTRICT",
  "สำนักขาม": "DISTRICT",
  "สำนักขุนเณร": "DISTRICT",
  "สำนักตะคร้อ": "DISTRICT",
  "สำนักทอง": "DISTRICT",
  "สำนักท้อน": "DISTRICT",
  "สำนักบก": "DISTRICT",
  "สำนักแต้ว": "DISTRICT",
  "สำพะเนียง": "DISTRICT",
  "สำพันตา": "DISTRICT",
  "สำมะโรง": "DISTRICT",
  "สำราญ": "DISTRICT",
  "สำราญราษฎร์": "DISTRICT",
  "สำราญใต้": "DISTRICT",
  "สำเภาลูน": "DISTRICT",
  "สำเภาล่ม": "DISTRICT",
  "สำเหร่": "DISTRICT",
  "สำโรง": "DISTRICT",
  "สำโรงกลาง": "DISTRICT",
  "สำโรงชัย": "DISTRICT",
  "สำโรงตาเจ็น": "DISTRICT",
  "สำโรงทาบ": "DISTRICT",
  "สำโรงปราสาท": "DISTRICT",
  "สำโรงพลัน": "DISTRICT",
  "สำโรงเหนือ": "DISTRICT",
  "สำโรงใต้": "DISTRICT",
  "สำโรงใหม่": "DISTRICT",
  "สิ": "DISTRICT",
  "สิงหนาท": "DISTRICT",
  "สิงห์": "DISTRICT",
  "สิงห์โคก": "DISTRICT",
  "สิงโตทอง": "DISTRICT",
  "สิชล": "DISTRICT",
  "สินปุน": "DISTRICT",
  "สินเจริญ": "DISTRICT",
  "สิบเอ็ดศอก": "DISTRICT",
  "สีกัน": "DISTRICT",
  "สีกาย": "DISTRICT",
  "สีคิ้ว": "DISTRICT",
  "สีชมพู": "DISTRICT",
  "สีดา": "DISTRICT",
  "สีบัวทอง": "DISTRICT",
  "สีพยา": "DISTRICT",
  "สีมุม": "DISTRICT",
  "สีลม": "DISTRICT",
  "สีวิเชียร": "DISTRICT",
  "สีสุก": "DISTRICT",
  "สีออ": "DISTRICT",
  "สีแก้ว": "DISTRICT",
  "สี่ขีด": "DISTRICT",
  "สี่คลอง": "DISTRICT",
  "สี่พระยา": "DISTRICT",
  "สี่ร้อย": "DISTRICT",
  "สี่หมื่น": "DISTRICT",
  "สี่เหลี่ยม": "DISTRICT",
  "สี่แยกมหานาค": "DISTRICT",
  "สุขฤทัย": "DISTRICT",
  "สุขสวัสดิ์": "DISTRICT",
  "สุขสำราญ": "DISTRICT",
  "สุขเกษม": "DISTRICT",
  "สุขเดือนห้า": "DISTRICT",
  "สุขไพบูลย์": "DISTRICT",
  "สุคิริน": "DISTRICT",
  "สุมเส้า": "DISTRICT",
  "สุรนารี": "DISTRICT",
  "สุรศักดิ์": "DISTRICT",
  "สุริยวงศ์": "DISTRICT",
  "สุวรรณคาม": "DISTRICT",
  "สุวรรณคูหา": "DISTRICT",
  "สุวารี": "DISTRICT",
  "สุเทพ": "DISTRICT",
  "สุโสะ": "DISTRICT",
  "สุไหงปาดี": "DISTRICT",
  "สุไหงโก-ลก": "DISTRICT",
  "สูงเนิน": "DISTRICT",
  "สูงเม่น": "DISTRICT",
  "ส่องดาว": "DISTRICT",
  "ส้มป่อย": "DISTRICT",
  "ส้มผ่อ": "DISTRICT",
  "ส้าน": "DISTRICT",
  "ส้านนาหนองใหม่": "DISTRICT",
  "หงษ์เจริญ": "DISTRICT",
  "หงส์หิน": "DISTRICT",
  "หงาว": "DISTRICT",
  "หญ้าปล้อง": "DISTRICT",
  "หนองกง": "DISTRICT",
  "หนองกบ": "DISTRICT",
  "หนองกรด": "DISTRICT",
  "หนองกระดิ่ง": "DISTRICT",
  "หนองกระทุ่ม": "DISTRICT",
  "หนองกระเจา": "DISTRICT",
  "หนองกระเจ็ด": "DISTRICT",
  "หนองกระเบียน": "DISTRICT",
  "หนองกระโดน": "DISTRICT",
  "หนองกราด": "DISTRICT",
  "หนองกร่าง": "DISTRICT",
  "หนองกลับ": "DISTRICT",
  "หนองกลางดง": "DISTRICT",
  "หนองกลางนา": "DISTRICT",
  "หนองกวั่ง": "DISTRICT",
  "หนองกวาง": "DISTRICT",
  "หนองกอมเกาะ": "DISTRICT",
  "หนองกะขะ": "DISTRICT",
  "หนองกะทิง": "DISTRICT",
  "หนองกะท้าว": "DISTRICT",
  "หนองกะปุ": "DISTRICT",
  "หนองกินเพล": "DISTRICT",
  "หนองกี่": "DISTRICT",
  "หนองกุง": "DISTRICT",
  "หนองกุงทับม้า": "DISTRICT",
  "หนองกุงธนสาร": "DISTRICT",
  "หนองกุงศรี": "DISTRICT",
  "หนองกุงสวรรค์": "DISTRICT",
  "หนองกุงเซิน": "DISTRICT",
  "หนองกุงแก้ว": "DISTRICT",
  "หนองกุงใหญ่": "DISTRICT",
  "หนองกุลา": "DISTRICT",
  "หนองกุ่ม": "DISTRICT",
  "หนองขนาก": "DISTRICT",
  "หนองขนาน": "DISTRICT",
  "หนองขมาร": "DISTRICT",
  "หนองขยาด": "DISTRICT",
  "หนองขวาว": "DISTRICT",
  "หนองขอน": "DISTRICT",
  "หนองขอนกว้าง": "DISTRICT",
  "หนองขาม": "DISTRICT",
  "หนองขาว": "DISTRICT",
  "หนองขาหย่าง": "DISTRICT",
  "หนองขุ่น": "DISTRICT",
  "หนองขุ่นใหญ่": "DISTRICT",
  "หนองข่า": "DISTRICT",
  "หนองข้างคอก": "DISTRICT",
  "หนองครก": "DISTRICT",
  "หนองคล้า": "DISTRICT",
  "หนองควาย": "DISTRICT",
  "หนองควายโซ": "DISTRICT",
  "หนองคอนไทย": "DISTRICT",
  "หนองคัน": "DISTRICT",
  "หนองคันทรง": "DISTRICT",
  "หนองคู": "DISTRICT",
  "หนองคูขาด": "DISTRICT",
  "หนองค่าย": "DISTRICT",
  "หนองค้า": "DISTRICT",
  "หนองค้างพลู": "DISTRICT",
  "หนองงิ้ว": "DISTRICT",
  "หนองงูเหลือม": "DISTRICT",
  "หนองจรเข้": "DISTRICT",
  "หนองจอก": "DISTRICT",
  "หนองจะบก": "DISTRICT",
  "หนองจิก": "DISTRICT",
  "หนองจ๊อม": "DISTRICT",
  "หนองฉลอง": "DISTRICT",
  "หนองฉาง": "DISTRICT",
  "หนองฉิม": "DISTRICT",
  "หนองชัยศรี": "DISTRICT",
  "หนองชาก": "DISTRICT",
  "หนองชิ่ม": "DISTRICT",
  "หนองชุมพล": "DISTRICT",
  "หนองชุมพลเหนือ": "DISTRICT",
  "หนองช้าง": "DISTRICT",
  "หนองช้างคืน": "DISTRICT",
  "หนองช้างแล่น": "DISTRICT",
  "หนองช้างใหญ่": "DISTRICT",
  "หนองซน": "DISTRICT",
  "หนองซอน": "DISTRICT",
  "หนองซ้ำซาก": "DISTRICT",
  "หนองญาติ": "DISTRICT",
  "หนองดินแดง": "DISTRICT",
  "หนองตรุด": "DISTRICT",
  "หนองตอกแป้น": "DISTRICT",
  "หนองตอง": "DISTRICT",
  "หนองตะครอง": "DISTRICT",
  "หนองตะพาน": "DISTRICT",
  "หนองตะเคียนบอน": "DISTRICT",
  "หนองตะไก้": "DISTRICT",
  "หนองตากยา": "DISTRICT",
  "หนองตาคง": "DISTRICT",
  "หนองตางู": "DISTRICT",
  "หนองตาด": "DISTRICT",
  "หนองตาดใหญ่": "DISTRICT",
  "หนองตาแต้ม": "DISTRICT",
  "หนองตาไก้": "DISTRICT",
  "หนองตำลึง": "DISTRICT",
  "หนองตีนนก": "DISTRICT",
  "หนองตูม": "DISTRICT",
  "หนองทรายขาว": "DISTRICT",
  "หนองทอง": "DISTRICT",
  "หนองทะเล": "DISTRICT",
  "หนองทันน้ำ": "DISTRICT",
  "หนองทัพไทย": "DISTRICT",
  "หนองทุ่ม": "DISTRICT",
  "หนองธง": "DISTRICT",
  "หนองนกทา": "DISTRICT",
  "หนองนกเขียน": "DISTRICT",
  "หนองนกแก้ว": "DISTRICT",
  "หนองนกไข่": "DISTRICT",
  "หนองนมวัว": "DISTRICT",
  "หนองนาก": "DISTRICT",
  "หนองนาคำ": "DISTRICT",
  "หนองนาง": "DISTRICT",
  "หนองนางนวล": "DISTRICT",
  "หนองนาแซง": "DISTRICT",
  "หนองน้อย": "DISTRICT",
  "หนองน้ำส้ม": "DISTRICT",
  "หนองน้ำแดง": "DISTRICT",
  "หนองน้ำใส": "DISTRICT",
  "หนองน้ำใหญ่": "DISTRICT",
  "หนองบก": "DISTRICT",
  "หนองบอน": "DISTRICT",
  "หนองบอนแดง": "DISTRICT",
  "หนองบัว": "DISTRICT",
  "หนองบัวดง": "DISTRICT",
  "หนองบัวตะเกียด": "DISTRICT",
  "หนองบัวทอง": "DISTRICT",
  "หนองบัวน้อย": "DISTRICT",
  "หนองบัวบาน": "DISTRICT",
  "หนองบัวระเหว": "DISTRICT",
  "หนองบัวละคร": "DISTRICT",
  "หนองบัวศาลา": "DISTRICT",
  "หนองบัวสะอาด": "DISTRICT",
  "หนองบัวสันตุ": "DISTRICT",
  "หนองบัวสิม": "DISTRICT",
  "หนองบัวฮี": "DISTRICT",
  "หนองบัวเหนือ": "DISTRICT",
  "หนองบัวแก้ว": "DISTRICT",
  "หนองบัวแดง": "DISTRICT",
  "หนองบัวโคก": "DISTRICT",
  "หนองบัวใต้": "DISTRICT",
  "หนองบัวใหญ่": "DISTRICT",
  "หนองบุนนาก": "DISTRICT",
  "หนองบ่มกล้วย": "DISTRICT",
  "หนองบ่อ": "DISTRICT",
  "หนองปรง": "DISTRICT",
  "หนองประดู่": "DISTRICT",
  "หนองปรือ": "DISTRICT",
  "หนองปลาปาก": "DISTRICT",
  "หนองปลาสะวาย": "DISTRICT",
  "หนองปลาหมอ": "DISTRICT",
  "หนองปลาไหล": "DISTRICT",
  "หนองปลิง": "DISTRICT",
  "หนองปล่อง": "DISTRICT",
  "หนองปล้อง": "DISTRICT",
  "หนองปากโลง": "DISTRICT",
  "หนองป่าก่อ": "DISTRICT",
  "หนองป่าครั่ง": "DISTRICT",
  "หนองผักนาก": "DISTRICT",
  "หนองผักแว่น": "DISTRICT",
  "หนองผึ้ง": "DISTRICT",
  "หนองผือ": "DISTRICT",
  "หนองฝ้าย": "DISTRICT",
  "หนองพยอม": "DISTRICT",
  "หนองพระ": "DISTRICT",
  "หนองพลวง": "DISTRICT",
  "หนองพลับ": "DISTRICT",
  "หนองพอก": "DISTRICT",
  "หนองพังค่า": "DISTRICT",
  "หนองพันจันทร์": "DISTRICT",
  "หนองพันทา": "DISTRICT",
  "หนองพิกุล": "DISTRICT",
  "หนองภัยศูนย์": "DISTRICT",
  "หนองมะค่า": "DISTRICT",
  "หนองมะค่าโมง": "DISTRICT",
  "หนองมะนาว": "DISTRICT",
  "หนองมะเขือ": "DISTRICT",
  "หนองมะแซว": "DISTRICT",
  "หนองมะโมง": "DISTRICT",
  "หนองม่วง": "DISTRICT",
  "หนองม่วงไข่": "DISTRICT",
  "หนองม้า": "DISTRICT",
  "หนองยวง": "DISTRICT",
  "หนองยอง": "DISTRICT",
  "หนองยาง": "DISTRICT",
  "หนองยายดา": "DISTRICT",
  "หนองยายพิมพ์": "DISTRICT",
  "หนองยายโต๊ะ": "DISTRICT",
  "หนองยาว": "DISTRICT",
  "หนองย่างชิ้น": "DISTRICT",
  "หนองย่างทอย": "DISTRICT",
  "หนองย่างเสือ": "DISTRICT",
  "หนองระฆัง": "DISTRICT",
  "หนองระเวียง": "DISTRICT",
  "หนองราชวัตร": "DISTRICT",
  "หนองรี": "DISTRICT",
  "หนองละลอก": "DISTRICT",
  "หนองลาด": "DISTRICT",
  "หนองลาน": "DISTRICT",
  "หนองลู": "DISTRICT",
  "หนองล่อง": "DISTRICT",
  "หนองวัวซอ": "DISTRICT",
  "หนองศาลา": "DISTRICT",
  "หนองสนม": "DISTRICT",
  "หนองสนิท": "DISTRICT",
  "หนองสรวง": "DISTRICT",
  "หนองสระ": "DISTRICT",
  "หนองสระปลา": "DISTRICT",
  "หนองสวรรค์": "DISTRICT",
  "หนองสว่าง": "DISTRICT",
  "หนองสองห้อง": "DISTRICT",
  "หนองสะเดา": "DISTRICT",
  "หนองสะโน": "DISTRICT",
  "หนองสังข์": "DISTRICT",
  "หนองสามวัง": "DISTRICT",
  "หนองสามสี": "DISTRICT",
  "หนองสาหร่าย": "DISTRICT",
  "หนองสิม": "DISTRICT",
  "หนองสีดา": "DISTRICT",
  "หนองสูง": "DISTRICT",
  "หนองสูงเหนือ": "DISTRICT",
  "หนองสูงใต้": "DISTRICT",
  "หนองหงษ์": "DISTRICT",
  "หนองหงส์": "DISTRICT",
  "หนองหญ้า": "DISTRICT",
  "หนองหญ้าขาว": "DISTRICT",
  "หนองหญ้าปล้อง": "DISTRICT",
  "หนองหญ้าลาด": "DISTRICT",
  "หนองหญ้าไซ": "DISTRICT",
  "หนองหญ้าไทร": "DISTRICT",
  "หนองหนาม": "DISTRICT",
  "หนองหมากฝ้าย": "DISTRICT",
  "หนองหมี": "DISTRICT",
  "หนองหมื่นถ่าน": "DISTRICT",
  "หนองหมู": "DISTRICT",
  "หนองหม้อ": "DISTRICT",
  "หนองหลวง": "DISTRICT",
  "หนองหลัก": "DISTRICT",
  "หนองหลุม": "DISTRICT",
  "หนองหล่ม": "DISTRICT",
  "หนองหว้า": "DISTRICT",
  "หนองหอย": "DISTRICT",
  "หนองหัวคู": "DISTRICT",
  "หนองหัวช้าง": "DISTRICT",
  "หนองหัวฟาน": "DISTRICT",
  "หนองหัววัว": "DISTRICT",
  "หนองหัวแรต": "DISTRICT",
  "หนองหัวโพ": "DISTRICT",
  "หนองหาน": "DISTRICT",
  "หนองหาร": "DISTRICT",
  "หนองหิน": "DISTRICT",
  "หนองห้าง": "DISTRICT",
  "หนองอิรุณ": "DISTRICT",
  "หนองอิเฒ่า": "DISTRICT",
  "หนองอีบุตร": "DISTRICT",
  "หนองอียอ": "DISTRICT",
  "หนองอึ่ง": "DISTRICT",
  "หนองอ้ม": "DISTRICT",
  "หนองอ้อ": "DISTRICT",
  "หนองฮะ": "DISTRICT",
  "หนองฮาง": "DISTRICT",
  "หนองฮี": "DISTRICT",
  "หนองเขียด": "DISTRICT",
  "หนองเข็ง": "DISTRICT",
  "หนองเชียงทูน": "DISTRICT",
  "หนองเดิ่น": "DISTRICT",
  "หนองเต็ง": "DISTRICT",
  "หนองเต่า": "DISTRICT",
  "หนองเทพ": "DISTRICT",
  "หนองเทา": "DISTRICT",
  "หนองเทาใหญ่": "DISTRICT",
  "หนองเป็ด": "DISTRICT",
  "หนองเพรางาย": "DISTRICT",
  "หนองเมธี": "DISTRICT",
  "หนองเมือง": "DISTRICT",
  "หนองเม็ก": "DISTRICT",
  "หนองเยือง": "DISTRICT",
  "หนองเรือ": "DISTRICT",
  "หนองเลิง": "DISTRICT",
  "หนองเสม็ด": "DISTRICT",
  "หนองเสาเล้า": "DISTRICT",
  "หนองเสือช้าง": "DISTRICT",
  "หนองเหล็ก": "DISTRICT",
  "หนองเหล่า": "DISTRICT",
  "หนองเหียง": "DISTRICT",
  "หนองเอี่ยน": "DISTRICT",
  "หนองแก": "DISTRICT",
  "หนองแก้ว": "DISTRICT",
  "หนองแก๋ว": "DISTRICT",
  "หนองแขม": "DISTRICT",
  "หนองแค": "DISTRICT",
  "หนองแคน": "DISTRICT",
  "หนองแจง": "DISTRICT",
  "หนองแจ้งใหญ่": "DISTRICT",
  "หนองแซง": "DISTRICT",
  "หนองแดง": "DISTRICT",
  "หนองแปน": "DISTRICT",
  "หนองแฝก": "DISTRICT",
  "หนองแม่นา": "DISTRICT",
  "หนองแม่แตง": "DISTRICT",
  "หนองแม่ไก่": "DISTRICT",
  "หนองแรด": "DISTRICT",
  "หนองแรต": "DISTRICT",
  "หนองแวง": "DISTRICT",
  "หนองแวงควง": "DISTRICT",
  "หนองแวงนางเบ้า": "DISTRICT",
  "หนองแวงโสกพระ": "DISTRICT",
  "หนองแวงใต้": "DISTRICT",
  "หนองแสง": "DISTRICT",
  "หนองแสงใหญ่": "DISTRICT",
  "หนองแสน": "DISTRICT",
  "หนองแหน": "DISTRICT",
  "หนองแหย่ง": "DISTRICT",
  "หนองโก": "DISTRICT",
  "หนองโดน": "DISTRICT",
  "หนองโน": "DISTRICT",
  "หนองโบสถ์": "DISTRICT",
  "หนองโพ": "DISTRICT",
  "หนองโพธิ์": "DISTRICT",
  "หนองโพนงาม": "DISTRICT",
  "หนองโพรง": "DISTRICT",
  "หนองโรง": "DISTRICT",
  "หนองโสน": "DISTRICT",
  "หนองโอ่ง": "DISTRICT",
  "หนองใหญ่": "DISTRICT",
  "หนองไขว่": "DISTRICT",
  "หนองไข่นก": "DISTRICT",
  "หนองไข่น้ำ": "DISTRICT",
  "หนองไทร": "DISTRICT",
  "หนองไผ่": "DISTRICT",
  "หนองไผ่ล้อม": "DISTRICT",
  "หนองไผ่แก้ว": "DISTRICT",
  "หนองไผ่แบน": "DISTRICT",
  "หนองไม้กอง": "DISTRICT",
  "หนองไม้งาม": "DISTRICT",
  "หนองไม้ซุง": "DISTRICT",
  "หนองไม้แก่น": "DISTRICT",
  "หนองไม้แดง": "DISTRICT",
  "หนองไม้ไผ่": "DISTRICT",
  "หนองไร่": "DISTRICT",
  "หนองไฮ": "DISTRICT",
  "หนามแดง": "DISTRICT",
  "หนามแท่ง": "DISTRICT",
  "หน่อม": "DISTRICT",
  "หน้าถ้ำ": "DISTRICT",
  "หน้าประดู่": "DISTRICT",
  "หน้าพระธาตุ": "DISTRICT",
  "หน้าพระลาน": "DISTRICT",
  "หน้าสตน": "DISTRICT",
  "หน้าเขา": "DISTRICT",
  "หน้าเมือง": "DISTRICT",
  "หน้าโคก": "DISTRICT",
  "หน้าไม้": "DISTRICT",
  "หมกแถว": "DISTRICT",
  "หมอกจำแป่": "DISTRICT",
  "หมอนทอง": "DISTRICT",
  "หมอนนาง": "DISTRICT",
  "หมอเมือง": "DISTRICT",
  "หมากหญ้า": "DISTRICT",
  "หมากเขียบ": "DISTRICT",
  "หมากแข้ง": "DISTRICT",
  "หมื่นศรี": "DISTRICT",
  "หมื่นไวย": "DISTRICT",
  "หมูม่น": "DISTRICT",
  "หมูม้น": "DISTRICT",
  "หมูสี": "DISTRICT",
  "หย่วน": "DISTRICT",
  "หรเทพ": "DISTRICT",
  "หลวงเหนือ": "DISTRICT",
  "หลวงใต้": "DISTRICT",
  "หลักชัย": "DISTRICT",
  "หลักช้าง": "DISTRICT",
  "หลักด่าน": "DISTRICT",
  "หลักฟ้า": "DISTRICT",
  "หลักสอง": "DISTRICT",
  "หลักสาม": "DISTRICT",
  "หลักหก": "DISTRICT",
  "หลักเขต": "DISTRICT",
  "หลักเมือง": "DISTRICT",
  "หลักเหลี่ยม": "DISTRICT",
  "หลักแก้ว": "DISTRICT",
  "หลังสวน": "DISTRICT",
  "หลุบ": "DISTRICT",
  "หลุบคา": "DISTRICT",
  "หลุบเลา": "DISTRICT",
  "หลุมข้าว": "DISTRICT",
  "หลุมดิน": "DISTRICT",
  "หลุมรัง": "DISTRICT",
  "หลุมเข้า": "DISTRICT",
  "หลุ่งตะเคียน": "DISTRICT",
  "หลุ่งประดู่": "DISTRICT",
  "หล่มสัก": "DISTRICT",
  "หล่มเก่า": "DISTRICT",
  "หล่อยูง": "DISTRICT",
  "หล่ายงาว": "DISTRICT",
  "หวายเหนียว": "DISTRICT",
  "หว้าทอง": "DISTRICT",
  "หว้านคำ": "DISTRICT",
  "หว้านใหญ่": "DISTRICT",
  "หอกลอง": "DISTRICT",
  "หอคำ": "DISTRICT",
  "หอมศีล": "DISTRICT",
  "หอมเกร็ด": "DISTRICT",
  "หอรัตนไชย": "DISTRICT",
  "หอไกร": "DISTRICT",
  "หันคา": "DISTRICT",
  "หันตรา": "DISTRICT",
  "หันตะเภา": "DISTRICT",
  "หันทราย": "DISTRICT",
  "หันนางาม": "DISTRICT",
  "หันสัง": "DISTRICT",
  "หันห้วยทราย": "DISTRICT",
  "หันโจด": "DISTRICT",
  "หัวขวาง": "DISTRICT",
  "หัวงัว": "DISTRICT",
  "หัวง้ม": "DISTRICT",
  "หัวช้าง": "DISTRICT",
  "หัวดง": "DISTRICT",
  "หัวดอน": "DISTRICT",
  "หัวตะพาน": "DISTRICT",
  "หัวถนน": "DISTRICT",
  "หัวทะเล": "DISTRICT",
  "หัวทุ่ง": "DISTRICT",
  "หัวนา": "DISTRICT",
  "หัวนาคำ": "DISTRICT",
  "หัวปลวก": "DISTRICT",
  "หัวป่า": "DISTRICT",
  "หัวฝาย": "DISTRICT",
  "หัวรอ": "DISTRICT",
  "หัวลำ": "DISTRICT",
  "หัวสะพาน": "DISTRICT",
  "หัวสำโรง": "DISTRICT",
  "หัวหนอง": "DISTRICT",
  "หัวหมาก": "DISTRICT",
  "หัวหวาย": "DISTRICT",
  "หัวหว้า": "DISTRICT",
  "หัวหิน": "DISTRICT",
  "หัวเขา": "DISTRICT",
  "หัวเดียด": "DISTRICT",
  "หัวเตย": "DISTRICT",
  "หัวเมือง": "DISTRICT",
  "หัวเรือ": "DISTRICT",
  "หัวเวียง": "DISTRICT",
  "หัวเสือ": "DISTRICT",
  "หัวโทน": "DISTRICT",
  "หัวโพ": "DISTRICT",
  "หัวโพธิ์": "DISTRICT",
  "หัวไทร": "DISTRICT",
  "หัวไผ่": "DISTRICT",
  "หางดง": "DISTRICT",
  "หางน้ำสาคร": "DISTRICT",
  "หาดกรวด": "DISTRICT",
  "หาดขาม": "DISTRICT",
  "หาดคัมภีร์": "DISTRICT",
  "หาดคำ": "DISTRICT",
  "หาดงิ้ว": "DISTRICT",
  "หาดทนง": "DISTRICT",
  "หาดทรายขาว": "DISTRICT",
  "หาดทรายรี": "DISTRICT",
  "หาดท่าเสา": "DISTRICT",
  "หาดนางแก้ว": "DISTRICT",
  "หาดพันไกร": "DISTRICT",
  "หาดยาง": "DISTRICT",
  "หาดยาย": "DISTRICT",
  "หาดล้า": "DISTRICT",
  "หาดสองแคว": "DISTRICT",
  "หาดสำราญ": "DISTRICT",
  "หาดสูง": "DISTRICT",
  "หาดส้มแป้น": "DISTRICT",
  "หาดอาษา": "DISTRICT",
  "หาดเจ้าสำราญ": "DISTRICT",
  "หาดเล็ก": "DISTRICT",
  "หาดเสี้ยว": "DISTRICT",
  "หาดแพง": "DISTRICT",
  "หาดใหญ่": "DISTRICT",
  "หานโพธิ์": "DISTRICT",
  "หายยา": "DISTRICT",
  "หายโศก": "DISTRICT",
  "หารเทา": "DISTRICT",
  "หารแก้ว": "DISTRICT",
  "หินกอง": "DISTRICT",
  "หินซ้อน": "DISTRICT",
  "หินดาด": "DISTRICT",
  "หินดาต": "DISTRICT",
  "หินตก": "DISTRICT",
  "หินตั้ง": "DISTRICT",
  "หินปัก": "DISTRICT",
  "หินมูล": "DISTRICT",
  "หินลาด": "DISTRICT",
  "หินฮาว": "DISTRICT",
  "หินเหล็กไฟ": "DISTRICT",
  "หินแก้ว": "DISTRICT",
  "หินโคน": "DISTRICT",
  "หินโงม": "DISTRICT",
  "หิรัญรูจี": "DISTRICT",
  "หูกวาง": "DISTRICT",
  "หูช้าง": "DISTRICT",
  "หูทำนบ": "DISTRICT",
  "หูล่อง": "DISTRICT",
  "ห่อหมก": "DISTRICT",
  "ห้วงน้ำขาว": "DISTRICT",
  "ห้วย": "DISTRICT",
  "ห้วยกรด": "DISTRICT",
  "ห้วยกรดพัฒนา": "DISTRICT",
  "ห้วยกระทิง": "DISTRICT",
  "ห้วยกระเจา": "DISTRICT",
  "ห้วยกะปิ": "DISTRICT",
  "ห้วยขมิ้น": "DISTRICT",
  "ห้วยขวาง": "DISTRICT",
  "ห้วยขะยุง": "DISTRICT",
  "ห้วยขุนราม": "DISTRICT",
  "ห้วยข่า": "DISTRICT",
  "ห้วยข้อง": "DISTRICT",
  "ห้วยข้าวก่ำ": "DISTRICT",
  "ห้วยคต": "DISTRICT",
  "ห้วยคันแหลน": "DISTRICT",
  "ห้วยงู": "DISTRICT",
  "ห้วยจรเข้": "DISTRICT",
  "ห้วยจันทร์": "DISTRICT",
  "ห้วยชมภู": "DISTRICT",
  "ห้วยชัน": "DISTRICT",
  "ห้วยซ้อ": "DISTRICT",
  "ห้วยด้วน": "DISTRICT",
  "ห้วยตามอญ": "DISTRICT",
  "ห้วยตึ๊กชู": "DISTRICT",
  "ห้วยต้อน": "DISTRICT",
  "ห้วยถั่วเหนือ": "DISTRICT",
  "ห้วยถั่วใต้": "DISTRICT",
  "ห้วยทราย": "DISTRICT",
  "ห้วยทรายเหนือ": "DISTRICT",
  "ห้วยทับทัน": "DISTRICT",
  "ห้วยทับมอญ": "DISTRICT",
  "ห้วยท่าช้าง": "DISTRICT",
  "ห้วยนาง": "DISTRICT",
  "ห้วยน้ำขาว": "DISTRICT",
  "ห้วยน้ำหอม": "DISTRICT",
  "ห้วยบง": "DISTRICT",
  "ห้วยบ่อซืน": "DISTRICT",
  "ห้วยปริก": "DISTRICT",
  "ห้วยปูลิง": "DISTRICT",
  "ห้วยป่าหวาย": "DISTRICT",
  "ห้วยผา": "DISTRICT",
  "ห้วยฝ้ายพัฒนา": "DISTRICT",
  "ห้วยพระ": "DISTRICT",
  "ห้วยพลู": "DISTRICT",
  "ห้วยพิชัย": "DISTRICT",
  "ห้วยพุก": "DISTRICT",
  "ห้วยมุ่น": "DISTRICT",
  "ห้วยม่วง": "DISTRICT",
  "ห้วยม้า": "DISTRICT",
  "ห้วยยอด": "DISTRICT",
  "ห้วยยั้ง": "DISTRICT",
  "ห้วยยาง": "DISTRICT",
  "ห้วยยางขาม": "DISTRICT",
  "ห้วยยางโทน": "DISTRICT",
  "ห้วยยาบ": "DISTRICT",
  "ห้วยยายจิ๋ว": "DISTRICT",
  "ห้วยยูง": "DISTRICT",
  "ห้วยรอบ": "DISTRICT",
  "ห้วยราช": "DISTRICT",
  "ห้วยราชา": "DISTRICT",
  "ห้วยร่วม": "DISTRICT",
  "ห้วยลาน": "DISTRICT",
  "ห้วยลึก": "DISTRICT",
  "ห้วยสะแก": "DISTRICT",
  "ห้วยสัก": "DISTRICT",
  "ห้วยสัตว์ใหญ่": "DISTRICT",
  "ห้วยสามพาด": "DISTRICT",
  "ห้วยสำราญ": "DISTRICT",
  "ห้วยสีเสียด": "DISTRICT",
  "ห้วยส้ม": "DISTRICT",
  "ห้วยหมอนทอง": "DISTRICT",
  "ห้วยหม้าย": "DISTRICT",
  "ห้วยหลัว": "DISTRICT",
  "ห้วยหอม": "DISTRICT",
  "ห้วยหิน": "DISTRICT",
  "ห้วยหินลาด": "DISTRICT",
  "ห้วยห้อม": "DISTRICT",
  "ห้วยอ้อ": "DISTRICT",
  "ห้วยเกตุ": "DISTRICT",
  "ห้วยเกิ้ง": "DISTRICT",
  "ห้วยเขน": "DISTRICT",
  "ห้วยเขย่ง": "DISTRICT",
  "ห้วยเตย": "DISTRICT",
  "ห้วยเม็ก": "DISTRICT",
  "ห้วยเหนือ": "DISTRICT",
  "ห้วยเฮี้ย": "DISTRICT",
  "ห้วยแก": "DISTRICT",
  "ห้วยแก้ง": "DISTRICT",
  "ห้วยแก้ว": "DISTRICT",
  "ห้วยแคน": "DISTRICT",
  "ห้วยแถลง": "DISTRICT",
  "ห้วยแม่เพรียง": "DISTRICT",
  "ห้วยแย้": "DISTRICT",
  "ห้วยแร้ง": "DISTRICT",
  "ห้วยแห้ง": "DISTRICT",
  "ห้วยแอ่ง": "DISTRICT",
  "ห้วยโก๋น": "DISTRICT",
  "ห้วยโจด": "DISTRICT",
  "ห้วยโป่ง": "DISTRICT",
  "ห้วยโพธิ์": "DISTRICT",
  "ห้วยโรง": "DISTRICT",
  "ห้วยใต้": "DISTRICT",
  "ห้วยใหญ่": "DISTRICT",
  "ห้วยไคร้": "DISTRICT",
  "ห้วยไผ่": "DISTRICT",
  "ห้วยไร่": "DISTRICT",
  "ห้องแซง": "DISTRICT",
  "ห้างฉัตร": "DISTRICT",
  "ห้างสูง": "DISTRICT",
  "องครักษ์": "DISTRICT",
  "องค์พระ": "DISTRICT",
  "อนุสาวรีย์": "DISTRICT",
  "อบทม": "DISTRICT",
  "อมก๋อย": "DISTRICT",
  "อมฤต": "DISTRICT",
  "อรพิมพ์": "DISTRICT",
  "อรัญคามวารี": "DISTRICT",
  "อรัญญิก": "DISTRICT",
  "อรัญประเทศ": "DISTRICT",
  "อรุณอมรินทร์": "DISTRICT",
  "อวน": "DISTRICT",
  "ออนกลาง": "DISTRICT",
  "ออนเหนือ": "DISTRICT",
  "ออนใต้": "DISTRICT",
  "ออย": "DISTRICT",
  "ออเงิน": "DISTRICT",
  "อัคคะคำ": "DISTRICT",
  "อัมพวา": "DISTRICT",
  "อัยเยอร์เวง": "DISTRICT",
  "อากาศ": "DISTRICT",
  "อาจสามารถ": "DISTRICT",
  "อาซ่อง": "DISTRICT",
  "อาษา": "DISTRICT",
  "อาฮี": "DISTRICT",
  "อาเนาะรู": "DISTRICT",
  "อาโพน": "DISTRICT",
  "อำนาจ": "DISTRICT",
  "อำแพง": "DISTRICT",
  "อิตื้อ": "DISTRICT",
  "อินคีรี": "DISTRICT",
  "อินทขิล": "DISTRICT",
  "อินทประมูล": "DISTRICT",
  "อินทร์บุรี": "DISTRICT",
  "อินทร์แปลง": "DISTRICT",
  "อิปัน": "DISTRICT",
  "อิปุ่ม": "DISTRICT",
  "อิสาณ": "DISTRICT",
  "อีง่อง": "DISTRICT",
  "อีปาด": "DISTRICT",
  "อีสานเขต": "DISTRICT",
  "อีเซ": "DISTRICT",
  "อี่หล่ำ": "DISTRICT",
  "อุดมทรัพย์": "DISTRICT",
  "อุดมธัญญา": "DISTRICT",
  "อุดมพร": "DISTRICT",
  "อุทัย": "DISTRICT",
  "อุทัยสวรรค์": "DISTRICT",
  "อุทัยเก่า": "DISTRICT",
  "อุทัยใหม่": "DISTRICT",
  "อุโมงค์": "DISTRICT",
  "อุโลกสี่หมื่น": "DISTRICT",
  "อุใดเจริญ": "DISTRICT",
  "อุ่มจาน": "DISTRICT",
  "อุ่มเม่า": "DISTRICT",
  "อุ่มเม้า": "DISTRICT",
  "อุ่มเหม้า": "DISTRICT",
  "อุ้มผาง": "DISTRICT",
  "อูบมุง": "DISTRICT",
  "อู่ตะเภา": "DISTRICT",
  "อู่ทอง": "DISTRICT",
  "อู่โลก": "DISTRICT",
  "อ่อนนุช": "DISTRICT",
  "อ่างคีรี": "DISTRICT",
  "อ่างทอง": "DISTRICT",
  "อ่างศิลา": "DISTRICT",
  "อ่างหิน": "DISTRICT",
  "อ่างแก้ว": "DISTRICT",
  "อ่ายนาไลย": "DISTRICT",
  "อ่าวตง": "DISTRICT",
  "อ่าวนาง": "DISTRICT",
  "อ่าวน้อย": "DISTRICT",
  "อ่าวลึกน้อย": "DISTRICT",
  "อ่าวลึกเหนือ": "DISTRICT",
  "อ่าวลึกใต้": "DISTRICT",
  "อ่าวใหญ่": "DISTRICT",
  "อ้อมกอ": "DISTRICT",
  "อ้อมน้อย": "DISTRICT",
  "อ้อมเกร็ด": "DISTRICT",
  "อ้อมใหญ่": "DISTRICT",
  "ฮอด": "DISTRICT",
  "ฮางโฮง": "DISTRICT",
  "เกตรี": "DISTRICT",
  "เกยไชย": "DISTRICT",
  "เกรียงไกร": "DISTRICT",
  "เกวียนหัก": "DISTRICT",
  "เกษตรพัฒนา": "DISTRICT",
  "เกษตรวิสัย": "DISTRICT",
  "เกษตรสุวรรณ": "DISTRICT",
  "เกษม": "DISTRICT",
  "เกษมทรัพย์": "DISTRICT",
  "เกะรอ": "DISTRICT",
  "เกาะกลาง": "DISTRICT",
  "เกาะกูด": "DISTRICT",
  "เกาะขนุน": "DISTRICT",
  "เกาะขวาง": "DISTRICT",
  "เกาะขันธ์": "DISTRICT",
  "เกาะคอเขา": "DISTRICT",
  "เกาะคา": "DISTRICT",
  "เกาะจัน": "DISTRICT",
  "เกาะจันทร์": "DISTRICT",
  "เกาะช้าง": "DISTRICT",
  "เกาะช้างใต้": "DISTRICT",
  "เกาะตะเภา": "DISTRICT",
  "เกาะตาล": "DISTRICT",
  "เกาะตาเลี้ยง": "DISTRICT",
  "เกาะทวด": "DISTRICT",
  "เกาะนางคำ": "DISTRICT",
  "เกาะปันหยี": "DISTRICT",
  "เกาะพยาม": "DISTRICT",
  "เกาะพระทอง": "DISTRICT",
  "เกาะพลับพลา": "DISTRICT",
  "เกาะพะงัน": "DISTRICT",
  "เกาะมะนาว": "DISTRICT",
  "เกาะยอ": "DISTRICT",
  "เกาะยาวน้อย": "DISTRICT",
  "เกาะยาวใหญ่": "DISTRICT",
  "เกาะรัง": "DISTRICT",
  "เกาะลอย": "DISTRICT",
  "เกาะลันตาน้อย": "DISTRICT",
  "เกาะลันตาใหญ่": "DISTRICT",
  "เกาะลิบง": "DISTRICT",
  "เกาะศรีบอยา": "DISTRICT",
  "เกาะศาลพระ": "DISTRICT",
  "เกาะสะท้อน": "DISTRICT",
  "เกาะสะบ้า": "DISTRICT",
  "เกาะสาหร่าย": "DISTRICT",
  "เกาะสำโรง": "DISTRICT",
  "เกาะสุกร": "DISTRICT",
  "เกาะหมาก": "DISTRICT",
  "เกาะหลัก": "DISTRICT",
  "เกาะหวาย": "DISTRICT",
  "เกาะเกร็ด": "DISTRICT",
  "เกาะเกิด": "DISTRICT",
  "เกาะเต่า": "DISTRICT",
  "เกาะเทโพ": "DISTRICT",
  "เกาะเปริด": "DISTRICT",
  "เกาะเปาะ": "DISTRICT",
  "เกาะเปียะ": "DISTRICT",
  "เกาะเพชร": "DISTRICT",
  "เกาะเรียน": "DISTRICT",
  "เกาะแก้ว": "DISTRICT",
  "เกาะแต้ว": "DISTRICT",
  "เกาะโพธิ์": "DISTRICT",
  "เกาะใหญ่": "DISTRICT",
  "เกาะไร่": "DISTRICT",
  "เกิ้ง": "DISTRICT",
  "เกียร์": "DISTRICT",
  "เก่ากลอย": "DISTRICT",
  "เก่าขาม": "DISTRICT",
  "เก่างิ้ว": "DISTRICT",
  "เก่าย่าดี": "DISTRICT",
  "เก้าเลี้ยว": "DISTRICT",
  "เขมราฐ": "DISTRICT",
  "เขวา": "DISTRICT",
  "เขวาทุ่ง": "DISTRICT",
  "เขวาสินรินทร์": "DISTRICT",
  "เขวาใหญ่": "DISTRICT",
  "เขวาไร่": "DISTRICT",
  "เขากระปุก": "DISTRICT",
  "เขากวางทอง": "DISTRICT",
  "เขากอบ": "DISTRICT",
  "เขากะลา": "DISTRICT",
  "เขาขลุง": "DISTRICT",
  "เขาขาว": "DISTRICT",
  "เขาขี้ฝอย": "DISTRICT",
  "เขาคราม": "DISTRICT",
  "เขาคอก": "DISTRICT",
  "เขาคันทรง": "DISTRICT",
  "เขาคีริส": "DISTRICT",
  "เขาค่าย": "DISTRICT",
  "เขาค้อ": "DISTRICT",
  "เขาจ้าว": "DISTRICT",
  "เขาฉกรรจ์": "DISTRICT",
  "เขาชนกัน": "DISTRICT",
  "เขาชะงุ้ม": "DISTRICT",
  "เขาชัยสน": "DISTRICT",
  "เขาชายธง": "DISTRICT",
  "เขาซก": "DISTRICT",
  "เขาดิน": "DISTRICT",
  "เขาดินพัฒนา": "DISTRICT",
  "เขาดินเหนือ": "DISTRICT",
  "เขาตอก": "DISTRICT",
  "เขาตูม": "DISTRICT",
  "เขาต่อ": "DISTRICT",
  "เขาถ่าน": "DISTRICT",
  "เขาทราย": "DISTRICT",
  "เขาทอง": "DISTRICT",
  "เขาทะลุ": "DISTRICT",
  "เขาท่าพระ": "DISTRICT",
  "เขานิพันธ์": "DISTRICT",
  "เขานิเวศน์": "DISTRICT",
  "เขาน้อย": "DISTRICT",
  "เขาบางแกรก": "DISTRICT",
  "เขาบายศรี": "DISTRICT",
  "เขาปูน": "DISTRICT",
  "เขาปู่": "DISTRICT",
  "เขาพนม": "DISTRICT",
  "เขาพระ": "DISTRICT",
  "เขาพระงาม": "DISTRICT",
  "เขาพระทอง": "DISTRICT",
  "เขาพระนอน": "DISTRICT",
  "เขาพระบาท": "DISTRICT",
  "เขาพัง": "DISTRICT",
  "เขาพังไกร": "DISTRICT",
  "เขามีเกียรติ": "DISTRICT",
  "เขาย่า": "DISTRICT",
  "เขาย้อย": "DISTRICT",
  "เขารวก": "DISTRICT",
  "เขารูปช้าง": "DISTRICT",
  "เขาล้าน": "DISTRICT",
  "เขาวง": "DISTRICT",
  "เขาวงกต": "DISTRICT",
  "เขาวัว": "DISTRICT",
  "เขาวิเศษ": "DISTRICT",
  "เขาสมอคอน": "DISTRICT",
  "เขาสมิง": "DISTRICT",
  "เขาสวนกวาง": "DISTRICT",
  "เขาสามยอด": "DISTRICT",
  "เขาสามสิบ": "DISTRICT",
  "เขาสามสิบหาบ": "DISTRICT",
  "เขาหลวง": "DISTRICT",
  "เขาหัวควาย": "DISTRICT",
  "เขาหินซ้อน": "DISTRICT",
  "เขาเขน": "DISTRICT",
  "เขาเจียก": "DISTRICT",
  "เขาเจ็ดลูก": "DISTRICT",
  "เขาเพิ่ม": "DISTRICT",
  "เขาแก้ว": "DISTRICT",
  "เขาแก้วศรีสมบูรณ์": "DISTRICT",
  "เขาแดง": "DISTRICT",
  "เขาแร้ง": "DISTRICT",
  "เขาแหลม": "DISTRICT",
  "เขาโจด": "DISTRICT",
  "เขาโร": "DISTRICT",
  "เขาใหญ่": "DISTRICT",
  "เขาไชยราช": "DISTRICT",
  "เขาไพร": "DISTRICT",
  "เขาไม้แก้ว": "DISTRICT",
  "เขิน": "DISTRICT",
  "เขือน้ำ": "DISTRICT",
  "เขื่องคำ": "DISTRICT",
  "เขื่องใน": "DISTRICT",
  "เขื่อน": "DISTRICT",
  "เขื่อนบางลาง": "DISTRICT",
  "เขื่อนผาก": "DISTRICT",
  "เขื่อนอุบลรัตน์": "DISTRICT",
  "เข็กน้อย": "DISTRICT",
  "เคร็ง": "DISTRICT",
  "เคียนซา": "DISTRICT",
  "เค็งใหญ่": "DISTRICT",
  "เจดีย์": "DISTRICT",
  "เจดีย์คำ": "DISTRICT",
  "เจดีย์ชัย": "DISTRICT",
  "เจดีย์หลวง": "DISTRICT",
  "เจดีย์หัก": "DISTRICT",
  "เจริญธรรม": "DISTRICT",
  "เจริญผล": "DISTRICT",
  "เจริญราษฎร์": "DISTRICT",
  "เจริญศิลป์": "DISTRICT",
  "เจริญสุข": "DISTRICT",
  "เจริญเมือง": "DISTRICT",
  "เจาทอง": "DISTRICT",
  "เจียด": "DISTRICT",
  "เจ็ดริ้ว": "DISTRICT",
  "เจ็ดเสมียน": "DISTRICT",
  "เจ้าท่า": "DISTRICT",
  "เจ้าปลุก": "DISTRICT",
  "เจ้าวัด": "DISTRICT",
  "เจ้าเจ็ด": "DISTRICT",
  "เจ้าเสด็จ": "DISTRICT",
  "เจ๊ะบิลัง": "DISTRICT",
  "เจ๊ะเห": "DISTRICT",
  "เฉนียง": "DISTRICT",
  "เฉลิม": "DISTRICT",
  "เฉลียง": "DISTRICT",
  "เชิงกลัด": "DISTRICT",
  "เชิงคีรี": "DISTRICT",
  "เชิงชุม": "DISTRICT",
  "เชิงดอย": "DISTRICT",
  "เชิงทะเล": "DISTRICT",
  "เชิงเนิน": "DISTRICT",
  "เชิงแส": "DISTRICT",
  "เชียงกลม": "DISTRICT",
  "เชียงกลาง": "DISTRICT",
  "เชียงขวัญ": "DISTRICT",
  "เชียงของ": "DISTRICT",
  "เชียงคาน": "DISTRICT",
  "เชียงงา": "DISTRICT",
  "เชียงดา": "DISTRICT",
  "เชียงดาว": "DISTRICT",
  "เชียงทอง": "DISTRICT",
  "เชียงบาน": "DISTRICT",
  "เชียงพิณ": "DISTRICT",
  "เชียงม่วน": "DISTRICT",
  "เชียงยืน": "DISTRICT",
  "เชียงรากน้อย": "DISTRICT",
  "เชียงรากใหญ่": "DISTRICT",
  "เชียงสือ": "DISTRICT",
  "เชียงหวาง": "DISTRICT",
  "เชียงเครือ": "DISTRICT",
  "เชียงเคี่ยน": "DISTRICT",
  "เชียงเงิน": "DISTRICT",
  "เชียงเพ็ง": "DISTRICT",
  "เชียงแรง": "DISTRICT",
  "เชียงแหว": "DISTRICT",
  "เชียงใหม่": "DISTRICT",
  "เชียรเขา": "DISTRICT",
  "เชียรใหญ่": "DISTRICT",
  "เชี่ยวเหลียง": "DISTRICT",
  "เชื้อเพลิง": "DISTRICT",
  "เซกา": "DISTRICT",
  "เซิม": "DISTRICT",
  "เซเป็ด": "DISTRICT",
  "เดิด": "DISTRICT",
  "เดิมบาง": "DISTRICT",
  "เดื่อศรีคันไชย": "DISTRICT",
  "เด่นชัย": "DISTRICT",
  "เด่นราษฎร์": "DISTRICT",
  "เด่นเหล็ก": "DISTRICT",
  "เด่นใหญ่": "DISTRICT",
  "เตย": "DISTRICT",
  "เตราะบอน": "DISTRICT",
  "เตาปูน": "DISTRICT",
  "เตาไห": "DISTRICT",
  "เต่างอย": "DISTRICT",
  "เต่าเล่า": "DISTRICT",
  "เถินบุรี": "DISTRICT",
  "เทนมีย์": "DISTRICT",
  "เทพกระษัตรี": "DISTRICT",
  "เทพคีรี": "DISTRICT",
  "เทพนคร": "DISTRICT",
  "เทพนิมิต": "DISTRICT",
  "เทพมงคล": "DISTRICT",
  "เทพรักษา": "DISTRICT",
  "เทพราช": "DISTRICT",
  "เทพา": "DISTRICT",
  "เทพารักษ์": "DISTRICT",
  "เทพาลัย": "DISTRICT",
  "เทพเสด็จ": "DISTRICT",
  "เทวราช": "DISTRICT",
  "เทอดไทย": "DISTRICT",
  "เที่ยงแท้": "DISTRICT",
  "เนินกว้าว": "DISTRICT",
  "เนินกุ่ม": "DISTRICT",
  "เนินขาม": "DISTRICT",
  "เนินขี้เหล็ก": "DISTRICT",
  "เนินฆ้อ": "DISTRICT",
  "เนินงาม": "DISTRICT",
  "เนินทราย": "DISTRICT",
  "เนินปอ": "DISTRICT",
  "เนินพระ": "DISTRICT",
  "เนินพระปรางค์": "DISTRICT",
  "เนินมะกอก": "DISTRICT",
  "เนินมะปราง": "DISTRICT",
  "เนินยาง": "DISTRICT",
  "เนินศาลา": "DISTRICT",
  "เนินสว่าง": "DISTRICT",
  "เนินหอม": "DISTRICT",
  "เนินเพิ่ม": "DISTRICT",
  "เนินแจง": "DISTRICT",
  "เบญจขร": "DISTRICT",
  "เบตง": "DISTRICT",
  "เบิกไพร": "DISTRICT",
  "เบิด": "DISTRICT",
  "เปร็ง": "DISTRICT",
  "เปลี่ยน": "DISTRICT",
  "เปาะเส้ง": "DISTRICT",
  "เปียงหลวง": "DISTRICT",
  "เปียน": "DISTRICT",
  "เปือ": "DISTRICT",
  "เปือย": "DISTRICT",
  "เปือยน้อย": "DISTRICT",
  "เปือยใหญ่": "DISTRICT",
  "เป็นสุข": "DISTRICT",
  "เป้า": "DISTRICT",
  "เป๊าะ": "DISTRICT",
  "เฝ้าไร่": "DISTRICT",
  "เพ": "DISTRICT",
  "เพชรชมภู": "DISTRICT",
  "เพชรละคร": "DISTRICT",
  "เพนียด": "DISTRICT",
  "เพหลา": "DISTRICT",
  "เพิ่มพูนทรัพย์": "DISTRICT",
  "เพี้ยราม": "DISTRICT",
  "เพ็กใหญ่": "DISTRICT",
  "เพ็ญ": "DISTRICT",
  "เมยวดี": "DISTRICT",
  "เมาะมาวี": "DISTRICT",
  "เมือง": "DISTRICT",
  "เมืองการุ้ง": "DISTRICT",
  "เมืองก๋าย": "DISTRICT",
  "เมืองคง": "DISTRICT",
  "เมืองคอง": "DISTRICT",
  "เมืองงาย": "DISTRICT",
  "เมืองจัง": "DISTRICT",
  "เมืองจันทร์": "DISTRICT",
  "เมืองชุม": "DISTRICT",
  "เมืองทอง": "DISTRICT",
  "เมืองที": "DISTRICT",
  "เมืองทุ่ง": "DISTRICT",
  "เมืองนะ": "DISTRICT",
  "เมืองนาท": "DISTRICT",
  "เมืองน้อย": "DISTRICT",
  "เมืองบัว": "DISTRICT",
  "เมืองบางขลัง": "DISTRICT",
  "เมืองบางยม": "DISTRICT",
  "เมืองปราสาท": "DISTRICT",
  "เมืองปอน": "DISTRICT",
  "เมืองปัก": "DISTRICT",
  "เมืองปาน": "DISTRICT",
  "เมืองฝาง": "DISTRICT",
  "เมืองฝ้าย": "DISTRICT",
  "เมืองพล": "DISTRICT",
  "เมืองพลับพลา": "DISTRICT",
  "เมืองพะไล": "DISTRICT",
  "เมืองพาน": "DISTRICT",
  "เมืองมาย": "DISTRICT",
  "เมืองยาง": "DISTRICT",
  "เมืองยาว": "DISTRICT",
  "เมืองลี": "DISTRICT",
  "เมืองลีง": "DISTRICT",
  "เมืองศรีไค": "DISTRICT",
  "เมืองสรวง": "DISTRICT",
  "เมืองสวรรคโลก": "DISTRICT",
  "เมืองหงส์": "DISTRICT",
  "เมืองหมี": "DISTRICT",
  "เมืองหลวง": "DISTRICT",
  "เมืองเกษตร": "DISTRICT",
  "เมืองเก่า": "DISTRICT",
  "เมืองเก่าพัฒนา": "DISTRICT",
  "เมืองเดช": "DISTRICT",
  "เมืองเตา": "DISTRICT",
  "เมืองเปลือย": "DISTRICT",
  "เมืองเพีย": "DISTRICT",
  "เมืองเล็น": "DISTRICT",
  "เมืองเสือ": "DISTRICT",
  "เมืองเหนือ": "DISTRICT",
  "เมืองแก": "DISTRICT",
  "เมืองแคน": "DISTRICT",
  "เมืองแปง": "DISTRICT",
  "เมืองแฝก": "DISTRICT",
  "เมืองแหง": "DISTRICT",
  "เมืองโดน": "DISTRICT",
  "เมืองโพธิ์": "DISTRICT",
  "เมืองใต้": "DISTRICT",
  "เมืองใหม่": "DISTRICT",
  "เมืองไผ่": "DISTRICT",
  "เมืองไพร": "DISTRICT",
  "เม็กดำ": "DISTRICT",
  "เม็งราย": "DISTRICT",
  "เย้ยปราสาท": "DISTRICT",
  "เรณู": "DISTRICT",
  "เรณูใต้": "DISTRICT",
  "เริงราง": "DISTRICT",
  "เรียง": "DISTRICT",
  "เรือง": "DISTRICT",
  "เลม็ด": "DISTRICT",
  "เลยวังไสย์": "DISTRICT",
  "เลาขวัญ": "DISTRICT",
  "เลิงแฝก": "DISTRICT",
  "เลิงใต้": "DISTRICT",
  "เวินพระบาท": "DISTRICT",
  "เวียง": "DISTRICT",
  "เวียงกาหลง": "DISTRICT",
  "เวียงคอย": "DISTRICT",
  "เวียงคำ": "DISTRICT",
  "เวียงคุก": "DISTRICT",
  "เวียงชัย": "DISTRICT",
  "เวียงตาล": "DISTRICT",
  "เวียงต้า": "DISTRICT",
  "เวียงทอง": "DISTRICT",
  "เวียงพางคำ": "DISTRICT",
  "เวียงมอก": "DISTRICT",
  "เวียงยอง": "DISTRICT",
  "เวียงสระ": "DISTRICT",
  "เวียงสะอาด": "DISTRICT",
  "เวียงห้าว": "DISTRICT",
  "เวียงเหนือ": "DISTRICT",
  "เวียงใต้": "DISTRICT",
  "เว่อ": "DISTRICT",
  "เสนา": "DISTRICT",
  "เสนางคนิคม": "DISTRICT",
  "เสนานิคม": "DISTRICT",
  "เสมา": "DISTRICT",
  "เสมาใหญ่": "DISTRICT",
  "เสม็จ": "DISTRICT",
  "เสม็ด": "DISTRICT",
  "เสม็ดเหนือ": "DISTRICT",
  "เสม็ดใต้": "DISTRICT",
  "เสริมกลาง": "DISTRICT",
  "เสริมขวา": "DISTRICT",
  "เสริมซ้าย": "DISTRICT",
  "เสวียด": "DISTRICT",
  "เสอเพลอ": "DISTRICT",
  "เสาชิงช้า": "DISTRICT",
  "เสาธง": "DISTRICT",
  "เสาธงชัย": "DISTRICT",
  "เสาธงหิน": "DISTRICT",
  "เสาหิน": "DISTRICT",
  "เสาเดียว": "DISTRICT",
  "เสาเภา": "DISTRICT",
  "เสาเล้า": "DISTRICT",
  "เสาไห้": "DISTRICT",
  "เสิงสาง": "DISTRICT",
  "เสียว": "DISTRICT",
  "เสี้ยว": "DISTRICT",
  "เสือหึง": "DISTRICT",
  "เสือเฒ่า": "DISTRICT",
  "เสือโก้ก": "DISTRICT",
  "เสือโฮก": "DISTRICT",
  "เสื่องข้าว": "DISTRICT",
  "เหนือ": "DISTRICT",
  "เหนือคลอง": "DISTRICT",
  "เหนือเมือง": "DISTRICT",
  "เหมาะ": "DISTRICT",
  "เหมือง": "DISTRICT",
  "เหมืองง่า": "DISTRICT",
  "เหมืองจี้": "DISTRICT",
  "เหมืองหม้อ": "DISTRICT",
  "เหมืองแก้ว": "DISTRICT",
  "เหมืองใหม่": "DISTRICT",
  "เหล": "DISTRICT",
  "เหล่า": "DISTRICT",
  "เหล่ากลาง": "DISTRICT",
  "เหล่ากวาง": "DISTRICT",
  "เหล่ากอหก": "DISTRICT",
  "เหล่างาม": "DISTRICT",
  "เหล่าดอกไม้": "DISTRICT",
  "เหล่าต่างคำ": "DISTRICT",
  "เหล่าทอง": "DISTRICT",
  "เหล่าน้อย": "DISTRICT",
  "เหล่าบก": "DISTRICT",
  "เหล่าบัวบาน": "DISTRICT",
  "เหล่าปอแดง": "DISTRICT",
  "เหล่าพรวน": "DISTRICT",
  "เหล่าพัฒนา": "DISTRICT",
  "เหล่ายาว": "DISTRICT",
  "เหล่าสร้างถ่อ": "DISTRICT",
  "เหล่าหมี": "DISTRICT",
  "เหล่าหลวง": "DISTRICT",
  "เหล่าอ้อย": "DISTRICT",
  "เหล่าเสือโก้ก": "DISTRICT",
  "เหล่าแดง": "DISTRICT",
  "เหล่าโพนค้อ": "DISTRICT",
  "เหล่าใหญ่": "DISTRICT",
  "เหล่าไฮ": "DISTRICT",
  "เหล่าไฮงาม": "DISTRICT",
  "เอกราช": "DISTRICT",
  "เอราวัณ": "DISTRICT",
  "เอือดใหญ่": "DISTRICT",
  "แก": "DISTRICT",
  "แกดำ": "DISTRICT",
  "แกลง": "DISTRICT",
  "แกใหญ่": "DISTRICT",
  "แก่งกระจาน": "DISTRICT",
  "แก่งคอย": "DISTRICT",
  "แก่งดินสอ": "DISTRICT",
  "แก่งผักกูด": "DISTRICT",
  "แก่งศรีภูมิ": "DISTRICT",
  "แก่งหางแมว": "DISTRICT",
  "แก่งเค็ง": "DISTRICT",
  "แก่งเลิงจาน": "DISTRICT",
  "แก่งเสี้ยน": "DISTRICT",
  "แก่งโดม": "DISTRICT",
  "แก่งโสภา": "DISTRICT",
  "แก่นมะกรูด": "DISTRICT",
  "แก้ง": "DISTRICT",
  "แก้งกอก": "DISTRICT",
  "แก้งสนามนาง": "DISTRICT",
  "แก้งเหนือ": "DISTRICT",
  "แก้งแก": "DISTRICT",
  "แก้งไก่": "DISTRICT",
  "แก้มอ้น": "DISTRICT",
  "แก้วฟ้า": "DISTRICT",
  "แก้วแสน": "DISTRICT",
  "แขม": "DISTRICT",
  "แข้": "DISTRICT",
  "แค": "DISTRICT",
  "แคตก": "DISTRICT",
  "แคน": "DISTRICT",
  "แคนดง": "DISTRICT",
  "แคนน้อย": "DISTRICT",
  "แคนเหนือ": "DISTRICT",
  "แคนใหญ่": "DISTRICT",
  "แคมป์สน": "DISTRICT",
  "แคราย": "DISTRICT",
  "แควอ้อม": "DISTRICT",
  "แควใหญ่": "DISTRICT",
  "แคออก": "DISTRICT",
  "แงง": "DISTRICT",
  "แจงงาม": "DISTRICT",
  "แจนแลน": "DISTRICT",
  "แจนแวน": "DISTRICT",
  "แจระแม": "DISTRICT",
  "แจ่มหลวง": "DISTRICT",
  "แจ้ซ้อน": "DISTRICT",
  "แจ้ห่ม": "DISTRICT",
  "แชะ": "DISTRICT",
  "แชแล": "DISTRICT",
  "แช่ช้าง": "DISTRICT",
  "แซงบาดาล": "DISTRICT",
  "แซร์ออ": "DISTRICT",
  "แดงหม้อ": "DISTRICT",
  "แดงใหญ่": "DISTRICT",
  "แดนชุมพล": "DISTRICT",
  "แดนสงวน": "DISTRICT",
  "แตล": "DISTRICT",
  "แต้": "DISTRICT",
  "แนงมุด": "DISTRICT",
  "แป-ระ": "DISTRICT",
  "แปลงยาว": "DISTRICT",
  "แป้น": "DISTRICT",
  "แพง": "DISTRICT",
  "แพงพวย": "DISTRICT",
  "แพงใหญ่": "DISTRICT",
  "แพด": "DISTRICT",
  "แพรกศรีราชา": "DISTRICT",
  "แพรกษา": "DISTRICT",
  "แพรกษาใหม่": "DISTRICT",
  "แพรกหนามแดง": "DISTRICT",
  "แพรกหา": "DISTRICT",
  "แมด": "DISTRICT",
  "แมดนาท่ม": "DISTRICT",
  "แม่กรณ์": "DISTRICT",
  "แม่กระบุง": "DISTRICT",
  "แม่กลอง": "DISTRICT",
  "แม่กัวะ": "DISTRICT",
  "แม่กา": "DISTRICT",
  "แม่กาษา": "DISTRICT",
  "แม่กิ๊": "DISTRICT",
  "แม่กุ": "DISTRICT",
  "แม่ก๊า": "DISTRICT",
  "แม่ขรี": "DISTRICT",
  "แม่ขะนิง": "DISTRICT",
  "แม่ข่า": "DISTRICT",
  "แม่ข้าวต้ม": "DISTRICT",
  "แม่คง": "DISTRICT",
  "แม่คะ": "DISTRICT",
  "แม่คะตวน": "DISTRICT",
  "แม่คำ": "DISTRICT",
  "แม่คำมี": "DISTRICT",
  "แม่คือ": "DISTRICT",
  "แม่งอน": "DISTRICT",
  "แม่จริม": "DISTRICT",
  "แม่จะเรา": "DISTRICT",
  "แม่จัน": "DISTRICT",
  "แม่จั๊วะ": "DISTRICT",
  "แม่ดง": "DISTRICT",
  "แม่ตาว": "DISTRICT",
  "แม่ตีบ": "DISTRICT",
  "แม่ตืน": "DISTRICT",
  "แม่ตื่น": "DISTRICT",
  "แม่ต้าน": "DISTRICT",
  "แม่ต๋ำ": "DISTRICT",
  "แม่ถอด": "DISTRICT",
  "แม่ทราย": "DISTRICT",
  "แม่ทอม": "DISTRICT",
  "แม่ทะ": "DISTRICT",
  "แม่ทะลบ": "DISTRICT",
  "แม่ทา": "DISTRICT",
  "แม่ท้อ": "DISTRICT",
  "แม่นะ": "DISTRICT",
  "แม่นางขาว": "DISTRICT",
  "แม่นาจร": "DISTRICT",
  "แม่นาจาง": "DISTRICT",
  "แม่นาวาง": "DISTRICT",
  "แม่นาเติง": "DISTRICT",
  "แม่นาเรือ": "DISTRICT",
  "แม่น้ำ": "DISTRICT",
  "แม่น้ำคู้": "DISTRICT",
  "แม่ปะ": "DISTRICT",
  "แม่ปั๋ง": "DISTRICT",
  "แม่ปาน": "DISTRICT",
  "แม่ปืม": "DISTRICT",
  "แม่ปุ": "DISTRICT",
  "แม่ปูคา": "DISTRICT",
  "แม่ป้าก": "DISTRICT",
  "แม่พริก": "DISTRICT",
  "แม่พุง": "DISTRICT",
  "แม่พูล": "DISTRICT",
  "แม่ฟ้าหลวง": "DISTRICT",
  "แม่มอก": "DISTRICT",
  "แม่ยม": "DISTRICT",
  "แม่ยวม": "DISTRICT",
  "แม่ยวมน้อย": "DISTRICT",
  "แม่ยางตาล": "DISTRICT",
  "แม่ยางร้อง": "DISTRICT",
  "แม่ยางฮ่อ": "DISTRICT",
  "แม่ยาว": "DISTRICT",
  "แม่ระกา": "DISTRICT",
  "แม่ระมาด": "DISTRICT",
  "แม่รำพึง": "DISTRICT",
  "แม่ลอย": "DISTRICT",
  "แม่ละมุ้ง": "DISTRICT",
  "แม่ลา": "DISTRICT",
  "แม่ลาด": "DISTRICT",
  "แม่ลาน": "DISTRICT",
  "แม่ลาน้อย": "DISTRICT",
  "แม่ลาว": "DISTRICT",
  "แม่ลาหลวง": "DISTRICT",
  "แม่วงก์": "DISTRICT",
  "แม่วะ": "DISTRICT",
  "แม่วะหลวง": "DISTRICT",
  "แม่วิน": "DISTRICT",
  "แม่ศึก": "DISTRICT",
  "แม่สรวย": "DISTRICT",
  "แม่สลองนอก": "DISTRICT",
  "แม่สลองใน": "DISTRICT",
  "แม่สลิด": "DISTRICT",
  "แม่สวด": "DISTRICT",
  "แม่สอง": "DISTRICT",
  "แม่สอด": "DISTRICT",
  "แม่สอย": "DISTRICT",
  "แม่สะเรียง": "DISTRICT",
  "แม่สัน": "DISTRICT",
  "แม่สา": "DISTRICT",
  "แม่สาคร": "DISTRICT",
  "แม่สาบ": "DISTRICT",
  "แม่สามแลบ": "DISTRICT",
  "แม่สาย": "DISTRICT",
  "แม่สาว": "DISTRICT",
  "แม่สำ": "DISTRICT",
  "แม่สิน": "DISTRICT",
  "แม่สุก": "DISTRICT",
  "แม่สูน": "DISTRICT",
  "แม่หลอง": "DISTRICT",
  "แม่หละ": "DISTRICT",
  "แม่หล่าย": "DISTRICT",
  "แม่หวาด": "DISTRICT",
  "แม่หอพระ": "DISTRICT",
  "แม่อาย": "DISTRICT",
  "แม่อิง": "DISTRICT",
  "แม่อุสุ": "DISTRICT",
  "แม่อูคอ": "DISTRICT",
  "แม่อ้อ": "DISTRICT",
  "แม่ฮี้": "DISTRICT",
  "แม่ฮ้อยเงิน": "DISTRICT",
  "แม่เกิ๋ง": "DISTRICT",
  "แม่เงา": "DISTRICT",
  "แม่เงิน": "DISTRICT",
  "แม่เจดีย์": "DISTRICT",
  "แม่เจดีย์ใหม่": "DISTRICT",
  "แม่เจ้าอยู่หัว": "DISTRICT",
  "แม่เปา": "DISTRICT",
  "แม่เปิน": "DISTRICT",
  "แม่เมาะ": "DISTRICT",
  "แม่เย็น": "DISTRICT",
  "แม่เล่ย์": "DISTRICT",
  "แม่เหาะ": "DISTRICT",
  "แม่เหียะ": "DISTRICT",
  "แม่แดด": "DISTRICT",
  "แม่แตง": "DISTRICT",
  "แม่แฝก": "DISTRICT",
  "แม่แฝกใหม่": "DISTRICT",
  "แม่แรง": "DISTRICT",
  "แม่แรม": "DISTRICT",
  "แม่แวน": "DISTRICT",
  "แม่โถ": "DISTRICT",
  "แม่โป่ง": "DISTRICT",
  "แม่ใจ": "DISTRICT",
  "แม่ใส": "DISTRICT",
  "แม่ไร่": "DISTRICT",
  "แร่": "DISTRICT",
  "และ": "DISTRICT",
  "แวง": "DISTRICT",
  "แวงดง": "DISTRICT",
  "แวงน่าง": "DISTRICT",
  "แวงน้อย": "DISTRICT",
  "แวงใหญ่": "DISTRICT",
  "แว้ง": "DISTRICT",
  "แสงภา": "DISTRICT",
  "แสงสว่าง": "DISTRICT",
  "แสงอรุณ": "DISTRICT",
  "แสนชาติ": "DISTRICT",
  "แสนตอ": "DISTRICT",
  "แสนตุ้ง": "DISTRICT",
  "แสนทอง": "DISTRICT",
  "แสนพัน": "DISTRICT",
  "แสนภูดาษ": "DISTRICT",
  "แสนสุข": "DISTRICT",
  "แสนแสบ": "DISTRICT",
  "แสนไห": "DISTRICT",
  "แสมดำ": "DISTRICT",
  "แสมสาร": "DISTRICT",
  "แสลง": "DISTRICT",
  "แสลงพัน": "DISTRICT",
  "แสลงพันธ์": "DISTRICT",
  "แสลงโทน": "DISTRICT",
  "แสวงหา": "DISTRICT",
  "แหลม": "DISTRICT",
  "แหลมกลัด": "DISTRICT",
  "แหลมงอบ": "DISTRICT",
  "แหลมตะลุมพุก": "DISTRICT",
  "แหลมทราย": "DISTRICT",
  "แหลมทอง": "DISTRICT",
  "แหลมบัว": "DISTRICT",
  "แหลมประดู่": "DISTRICT",
  "แหลมผักเบี้ย": "DISTRICT",
  "แหลมฟ้าผ่า": "DISTRICT",
  "แหลมรัง": "DISTRICT",
  "แหลมสน": "DISTRICT",
  "แหลมสอม": "DISTRICT",
  "แหลมสัก": "DISTRICT",
  "แหลมโตนด": "DISTRICT",
  "แหลมโพธิ์": "DISTRICT",
  "แหลมใหญ่": "DISTRICT",
  "แห่ใต้": "DISTRICT",
  "โกตาบารู": "DISTRICT",
  "โกรกกราก": "DISTRICT",
  "โกรกพระ": "DISTRICT",
  "โกรกแก้ว": "DISTRICT",
  "โกสัมพี": "DISTRICT",
  "โก่งธนู": "DISTRICT",
  "โขงเจียม": "DISTRICT",
  "โขมง": "DISTRICT",
  "โคกกกม่วง": "DISTRICT",
  "โคกกรวด": "DISTRICT",
  "โคกกระชาย": "DISTRICT",
  "โคกกระเบื้อง": "DISTRICT",
  "โคกกลอย": "DISTRICT",
  "โคกกลาง": "DISTRICT",
  "โคกกว้าง": "DISTRICT",
  "โคกกะเทียม": "DISTRICT",
  "โคกกุง": "DISTRICT",
  "โคกก่ง": "DISTRICT",
  "โคกก่อ": "DISTRICT",
  "โคกก่อง": "DISTRICT",
  "โคกขมิ้น": "DISTRICT",
  "โคกขาม": "DISTRICT",
  "โคกขี้หนอน": "DISTRICT",
  "โคกคราม": "DISTRICT",
  "โคกคอน": "DISTRICT",
  "โคกงาม": "DISTRICT",
  "โคกจาน": "DISTRICT",
  "โคกชะงาย": "DISTRICT",
  "โคกชำแระ": "DISTRICT",
  "โคกช้าง": "DISTRICT",
  "โคกตะบอง": "DISTRICT",
  "โคกตะเคียน": "DISTRICT",
  "โคกตาล": "DISTRICT",
  "โคกตูม": "DISTRICT",
  "โคกทราย": "DISTRICT",
  "โคกนาโก": "DISTRICT",
  "โคกปรง": "DISTRICT",
  "โคกปีบ": "DISTRICT",
  "โคกปี่ฆ้อง": "DISTRICT",
  "โคกพระ": "DISTRICT",
  "โคกพระเจดีย์": "DISTRICT",
  "โคกพุทรา": "DISTRICT",
  "โคกภู": "DISTRICT",
  "โคกมน": "DISTRICT",
  "โคกมะขาม": "DISTRICT",
  "โคกมะม่วง": "DISTRICT",
  "โคกมั่งงอย": "DISTRICT",
  "โคกม่วง": "DISTRICT",
  "โคกม้า": "DISTRICT",
  "โคกยาง": "DISTRICT",
  "โคกย่าง": "DISTRICT",
  "โคกลำพาน": "DISTRICT",
  "โคกล่าม": "DISTRICT",
  "โคกว่าน": "DISTRICT",
  "โคกศิลา": "DISTRICT",
  "โคกสง่า": "DISTRICT",
  "โคกสนวน": "DISTRICT",
  "โคกสมบูรณ์": "DISTRICT",
  "โคกสลุง": "DISTRICT",
  "โคกสลุด": "DISTRICT",
  "โคกสว่าง": "DISTRICT",
  "โคกสะตอ": "DISTRICT",
  "โคกสะบ้า": "DISTRICT",
  "โคกสะอาด": "DISTRICT",
  "โคกสัก": "DISTRICT",
  "โคกสาร": "DISTRICT",
  "โคกสำราญ": "DISTRICT",
  "โคกสำโรง": "DISTRICT",
  "โคกสี": "DISTRICT",
  "โคกสีทองหลาง": "DISTRICT",
  "โคกสูง": "DISTRICT",
  "โคกหม้อ": "DISTRICT",
  "โคกหล่อ": "DISTRICT",
  "โคกหล่าม": "DISTRICT",
  "โคกหาร": "DISTRICT",
  "โคกหินแฮ่": "DISTRICT",
  "โคกเครือ": "DISTRICT",
  "โคกเคียน": "DISTRICT",
  "โคกเจริญ": "DISTRICT",
  "โคกเดื่อ": "DISTRICT",
  "โคกเพชร": "DISTRICT",
  "โคกเพชรพัฒนา": "DISTRICT",
  "โคกเพลาะ": "DISTRICT",
  "โคกเริงรมย์": "DISTRICT",
  "โคกเหล็ก": "DISTRICT",
  "โคกแฝด": "DISTRICT",
  "โคกแย้": "DISTRICT",
  "โคกแสมสาร": "DISTRICT",
  "โคกโคเฒ่า": "DISTRICT",
  "โคกโพธิ์": "DISTRICT",
  "โคกใหญ่": "DISTRICT",
  "โคกไทย": "DISTRICT",
  "โคกไม้ลาย": "DISTRICT",
  "โคคลาน": "DISTRICT",
  "โคราช": "DISTRICT",
  "โค้งยาง": "DISTRICT",
  "โค้งไผ่": "DISTRICT",
  "โฆษิต": "DISTRICT",
  "โจดม่วง": "DISTRICT",
  "โจดหนองแก": "DISTRICT",
  "โชคชัย": "DISTRICT",
  "โชคนาสาม": "DISTRICT",
  "โชคเหนือ": "DISTRICT",
  "โซง": "DISTRICT",
  "โซ่": "DISTRICT",
  "โดด": "DISTRICT",
  "โดมประดิษฐ์": "DISTRICT",
  "โตนด": "DISTRICT",
  "โตนดด้วน": "DISTRICT",
  "โต๊ะเด็ง": "DISTRICT",
  "โนน": "DISTRICT",
  "โนนกลาง": "DISTRICT",
  "โนนกอก": "DISTRICT",
  "โนนกาหลง": "DISTRICT",
  "โนนกาเล็น": "DISTRICT",
  "โนนกุง": "DISTRICT",
  "โนนก่อ": "DISTRICT",
  "โนนขมิ้น": "DISTRICT",
  "โนนขวาง": "DISTRICT",
  "โนนข่า": "DISTRICT",
  "โนนคอม": "DISTRICT",
  "โนนคูณ": "DISTRICT",
  "โนนค่า": "DISTRICT",
  "โนนค้อ": "DISTRICT",
  "โนนฆ้อง": "DISTRICT",
  "โนนงาม": "DISTRICT",
  "โนนจาน": "DISTRICT",
  "โนนชัยศรี": "DISTRICT",
  "โนนดินแดง": "DISTRICT",
  "โนนตาล": "DISTRICT",
  "โนนตาเถร": "DISTRICT",
  "โนนตูม": "DISTRICT",
  "โนนทราย": "DISTRICT",
  "โนนทอง": "DISTRICT",
  "โนนทองหลาง": "DISTRICT",
  "โนนทองอินทร์": "DISTRICT",
  "โนนทัน": "DISTRICT",
  "โนนท่อน": "DISTRICT",
  "โนนธาตุ": "DISTRICT",
  "โนนนาจาน": "DISTRICT",
  "โนนน้ำเกลี้ยง": "DISTRICT",
  "โนนบุรี": "DISTRICT",
  "โนนประดู่": "DISTRICT",
  "โนนปอแดง": "DISTRICT",
  "โนนปูน": "DISTRICT",
  "โนนป่าซาง": "DISTRICT",
  "โนนผึ้ง": "DISTRICT",
  "โนนพลวง": "DISTRICT",
  "โนนพะยอม": "DISTRICT",
  "โนนภิบาล": "DISTRICT",
  "โนนม่วง": "DISTRICT",
  "โนนยอ": "DISTRICT",
  "โนนยาง": "DISTRICT",
  "โนนรัง": "DISTRICT",
  "โนนราษี": "DISTRICT",
  "โนนศิลา": "DISTRICT",
  "โนนศิลาเลิง": "DISTRICT",
  "โนนสง่า": "DISTRICT",
  "โนนสมบูรณ์": "DISTRICT",
  "โนนสวรรค์": "DISTRICT",
  "โนนสวาง": "DISTRICT",
  "โนนสว่าง": "DISTRICT",
  "โนนสะอาด": "DISTRICT",
  "โนนสัง": "DISTRICT",
  "โนนสำราญ": "DISTRICT",
  "โนนสุวรรณ": "DISTRICT",
  "โนนสูง": "DISTRICT",
  "โนนหนามแท่ง": "DISTRICT",
  "โนนหมากมุ่น": "DISTRICT",
  "โนนหมากเค็ง": "DISTRICT",
  "โนนหวาย": "DISTRICT",
  "โนนหอม": "DISTRICT",
  "โนนหัน": "DISTRICT",
  "โนนห้อม": "DISTRICT",
  "โนนอุดม": "DISTRICT",
  "โนนเจริญ": "DISTRICT",
  "โนนเต็ง": "DISTRICT",
  "โนนเปือย": "DISTRICT",
  "โนนเพ็ก": "DISTRICT",
  "โนนเพ็ด": "DISTRICT",
  "โนนเมือง": "DISTRICT",
  "โนนเมืองพัฒนา": "DISTRICT",
  "โนนเหล็ก": "DISTRICT",
  "โนนแดง": "DISTRICT",
  "โนนแหลมทอง": "DISTRICT",
  "โนนโพธิ์": "DISTRICT",
  "โนนโหนน": "DISTRICT",
  "โนนไทย": "DISTRICT",
  "โบสถ์": "DISTRICT",
  "โปงทุ่ง": "DISTRICT",
  "โป่ง": "DISTRICT",
  "โป่งงาม": "DISTRICT",
  "โป่งตาลอง": "DISTRICT",
  "โป่งนก": "DISTRICT",
  "โป่งน้ำร้อน": "DISTRICT",
  "โป่งผา": "DISTRICT",
  "โป่งสา": "DISTRICT",
  "โป่งเปือย": "DISTRICT",
  "โป่งแดง": "DISTRICT",
  "โป่งแพร่": "DISTRICT",
  "โป่งแยง": "DISTRICT",
  "โผงเผง": "DISTRICT",
  "โพกรวม": "DISTRICT",
  "โพงาม": "DISTRICT",
  "โพชนไก่": "DISTRICT",
  "โพตลาดแก้ว": "DISTRICT",
  "โพทะเล": "DISTRICT",
  "โพธาราม": "DISTRICT",
  "โพธิไพศาล": "DISTRICT",
  "โพธิ์": "DISTRICT",
  "โพธิ์กระสังข์": "DISTRICT",
  "โพธิ์กลาง": "DISTRICT",
  "โพธิ์งาม": "DISTRICT",
  "โพธิ์ชัย": "DISTRICT",
  "โพธิ์ตรุ": "DISTRICT",
  "โพธิ์ตาก": "DISTRICT",
  "โพธิ์ทอง": "DISTRICT",
  "โพธิ์ประทับช้าง": "DISTRICT",
  "โพธิ์ประสาท": "DISTRICT",
  "โพธิ์พระยา": "DISTRICT",
  "โพธิ์ม่วงพันธ์": "DISTRICT",
  "โพธิ์รังนก": "DISTRICT",
  "โพธิ์วงศ์": "DISTRICT",
  "โพธิ์ศรี": "DISTRICT",
  "โพธิ์ศรีสว่าง": "DISTRICT",
  "โพธิ์ศรีสำราญ": "DISTRICT",
  "โพธิ์สัย": "DISTRICT",
  "โพธิ์สามต้น": "DISTRICT",
  "โพธิ์หมากแข้ง": "DISTRICT",
  "โพธิ์เก้าต้น": "DISTRICT",
  "โพธิ์เสด็จ": "DISTRICT",
  "โพธิ์เอน": "DISTRICT",
  "โพธิ์แทน": "DISTRICT",
  "โพธิ์ใหญ่": "DISTRICT",
  "โพธิ์ไชย": "DISTRICT",
  "โพธิ์ไทร": "DISTRICT",
  "โพธิ์ไทรงาม": "DISTRICT",
  "โพน": "DISTRICT",
  "โพนข่า": "DISTRICT",
  "โพนครก": "DISTRICT",
  "โพนค้อ": "DISTRICT",
  "โพนงาม": "DISTRICT",
  "โพนจาน": "DISTRICT",
  "โพนทราย": "DISTRICT",
  "โพนทอง": "DISTRICT",
  "โพนทัน": "DISTRICT",
  "โพนบก": "DISTRICT",
  "โพนยาง": "DISTRICT",
  "โพนสวรรค์": "DISTRICT",
  "โพนสว่าง": "DISTRICT",
  "โพนสา": "DISTRICT",
  "โพนสูง": "DISTRICT",
  "โพนางดำตก": "DISTRICT",
  "โพนางดำออก": "DISTRICT",
  "โพนเขวา": "DISTRICT",
  "โพนเพ็ก": "DISTRICT",
  "โพนเมือง": "DISTRICT",
  "โพนเมืองน้อย": "DISTRICT",
  "โพนแพง": "DISTRICT",
  "โพนโก": "DISTRICT",
  "โพประจักษ์": "DISTRICT",
  "โพพระ": "DISTRICT",
  "โพรงจระเข้": "DISTRICT",
  "โพรงมะเดื่อ": "DISTRICT",
  "โพรงอากาศ": "DISTRICT",
  "โพสะ": "DISTRICT",
  "โพสังโฆ": "DISTRICT",
  "โพสาวหาญ": "DISTRICT",
  "โพหัก": "DISTRICT",
  "โพแตง": "DISTRICT",
  "โพไร่หวาน": "DISTRICT",
  "โมคลาน": "DISTRICT",
  "โมถ่าย": "DISTRICT",
  "โมโกร": "DISTRICT",
  "โยธะกา": "DISTRICT",
  "โยนก": "DISTRICT",
  "โรง": "DISTRICT",
  "โรงช้าง": "DISTRICT",
  "โรงหีบ": "DISTRICT",
  "โรงเข้": "DISTRICT",
  "โละจูด": "DISTRICT",
  "โสกก่าม": "DISTRICT",
  "โสกนกเต็น": "DISTRICT",
  "โสกปลาดุก": "DISTRICT",
  "โสกแสง": "DISTRICT",
  "โสธร": "DISTRICT",
  "โสน": "DISTRICT",
  "โสนลอย": "DISTRICT",
  "โสมเยี่ยม": "DISTRICT",
  "โหรา": "DISTRICT",
  "โหล่งขอด": "DISTRICT",
  "โอโล": "DISTRICT",
  "ใจดี": "DISTRICT",
  "ในคลองบางปลากด": "DISTRICT",
  "ในควน": "DISTRICT",
  "ในวงเหนือ": "DISTRICT",
  "ในวงใต้": "DISTRICT",
  "ในเตา": "DISTRICT",
  "ในเมือง": "DISTRICT",
  "ในเวียง": "DISTRICT",
  "ใหม่": "DISTRICT",
  "ใหม่นาเพียง": "DISTRICT",
  "ใหม่พัฒนา": "DISTRICT",
  "ไกรกลาง": "DISTRICT",
  "ไกรนอก": "DISTRICT",
  "ไกรใน": "DISTRICT",
  "ไก่คำ": "DISTRICT",
  "ไก่เส่า": "DISTRICT",
  "ไคสี": "DISTRICT",
  "ไค้นุ่น": "DISTRICT",
  "ไชยคราม": "DISTRICT",
  "ไชยบุรี": "DISTRICT",
  "ไชยภูมิ": "DISTRICT",
  "ไชยมงคล": "DISTRICT",
  "ไชยมนตรี": "DISTRICT",
  "ไชยราช": "DISTRICT",
  "ไชยวัฒนา": "DISTRICT",
  "ไชยวาน": "DISTRICT",
  "ไชยสถาน": "DISTRICT",
  "ไชยสอ": "DISTRICT",
  "ไชโย": "DISTRICT",
  "ไตรตรึงษ์": "DISTRICT",
  "ไทยชนะศึก": "DISTRICT",
  "ไทยบุรี": "DISTRICT",
  "ไทยสามัคคี": "DISTRICT",
  "ไทยอุดม": "DISTRICT",
  "ไทยาวาส": "DISTRICT",
  "ไทยเจริญ": "DISTRICT",
  "ไทรขึง": "DISTRICT",
  "ไทรงาม": "DISTRICT",
  "ไทรทอง": "DISTRICT",
  "ไทรน้อย": "DISTRICT",
  "ไทรม้า": "DISTRICT",
  "ไทรย้อย": "DISTRICT",
  "ไทรเดี่ยว": "DISTRICT",
  "ไทรโยค": "DISTRICT",
  "ไทรโรงโขน": "DISTRICT",
  "ไทรโสภา": "DISTRICT",
  "ไทรใหญ่": "DISTRICT",
  "ไผ่": "DISTRICT",
  "ไผ่กองดิน": "DISTRICT",
  "ไผ่ขวาง": "DISTRICT",
  "ไผ่ขอดอน": "DISTRICT",
  "ไผ่จำศีล": "DISTRICT",
  "ไผ่ชะเลือด": "DISTRICT",
  "ไผ่ดำพัฒนา": "DISTRICT",
  "ไผ่ต่ำ": "DISTRICT",
  "ไผ่ท่าโพ": "DISTRICT",
  "ไผ่พระ": "DISTRICT",
  "ไผ่รอบ": "DISTRICT",
  "ไผ่ลิง": "DISTRICT",
  "ไผ่ล้อม": "DISTRICT",
  "ไผ่วง": "DISTRICT",
  "ไผ่สิงห์": "DISTRICT",
  "ไผ่หลวง": "DISTRICT",
  "ไผ่หลิ่ว": "DISTRICT",
  "ไผ่หูช้าง": "DISTRICT",
  "ไผ่เขียว": "DISTRICT",
  "ไผ่โทน": "DISTRICT",
  "ไผ่ใหญ่": "DISTRICT",
  "ไพบูลย์": "DISTRICT",
  "ไพร": "DISTRICT",
  "ไพรขลา": "DISTRICT",
  "ไพรนกยูง": "DISTRICT",
  "ไพรบึง": "DISTRICT",
  "ไพรพัฒนา": "DISTRICT",
  "ไพรวัน": "DISTRICT",
  "ไพล": "DISTRICT",
  "ไพศาล": "DISTRICT",
  "ไพศาลี": "DISTRICT",
  "ไม้กลอน": "DISTRICT",
  "ไม้ขาว": "DISTRICT",
  "ไม้งาม": "DISTRICT",
  "ไม้ดัด": "DISTRICT",
  "ไม้ตรา": "DISTRICT",
  "ไม้ฝาด": "DISTRICT",
  "ไม้ยา": "DISTRICT",
  "ไม้รูด": "DISTRICT",
  "ไม้เค็ด": "DISTRICT",
  "ไม้เรียง": "DISTRICT",
  "ไม้แก่น": "DISTRICT",
  "ไร่": "DISTRICT",
  "ไร่ขิง": "DISTRICT",
  "ไร่ขี": "DISTRICT",
  "ไร่น้อย": "DISTRICT",
  "ไร่พัฒนา": "DISTRICT",
  "ไร่มะขาม": "DISTRICT",
  "ไร่รถ": "DISTRICT",
  "ไร่สะท้อน": "DISTRICT",
  "ไร่สีสุก": "DISTRICT",
  "ไร่ส้ม": "DISTRICT",
  "ไร่หลักทอง": "DISTRICT",
  "ไร่อ้อย": "DISTRICT",
  "ไร่เก่า": "DISTRICT",
  "ไร่โคก": "DISTRICT",
  "ไร่ใต้": "DISTRICT",
  "ไร่ใหม่": "DISTRICT",
  "ไร่ใหม่พัฒนา": "DISTRICT",
  "ไล่โว่": "DISTRICT",
  "ไสหมาก": "DISTRICT",
  "ไสหร้า": "DISTRICT",
  "ไสไทย": "DISTRICT",
  "ไหล่ทุ่ง": "DISTRICT",
  "ไหล่น่าน": "DISTRICT",
  "ไหล่หิน": "DISTRICT",
  "ไฮหย่อง": "DISTRICT",

  "กงหรา": "AMPHOE",
  "กงไกรลาศ": "AMPHOE",
  "กบินทร์บุรี": "AMPHOE",
  "กมลาไสย": "AMPHOE",
  "กรงปินัง": "AMPHOE",
  "กระทุ่มแบน": "AMPHOE",
  "กระนวน": "AMPHOE",
  "กระบุรี": "AMPHOE",
  "กระสัง": "AMPHOE",
  "กระแสสินธุ์": "AMPHOE",
  "กะทู้": "AMPHOE",
  "กะปง": "AMPHOE",
  "กะพ้อ": "AMPHOE",
  "กะเปอร์": "AMPHOE",
  "กันตัง": "AMPHOE",
  "กันทรลักษ์": "AMPHOE",
  "กันทรวิชัย": "AMPHOE",
  "กันทรารมย์": "AMPHOE",
  "กัลยาณิวัฒนา": "AMPHOE",
  "กาญจนดิษฐ์": "AMPHOE",
  "กาบัง": "AMPHOE",
  "กาบเชิง": "AMPHOE",
  "กำแพงแสน": "AMPHOE",
  "กุฉินารายณ์": "AMPHOE",
  "กุดข้าวปุ้น": "AMPHOE",
  "กุดจับ": "AMPHOE",
  "กุดชุม": "AMPHOE",
  "กุดบาก": "AMPHOE",
  "กุดรัง": "AMPHOE",
  "กุมภวาปี": "AMPHOE",
  "กุยบุรี": "AMPHOE",
  "กุสุมาลย์": "AMPHOE",
  "กู่แก้ว": "AMPHOE",
  "ขนอม": "AMPHOE",
  "ขลุง": "AMPHOE",
  "ขาณุวรลักษบุรี": "AMPHOE",
  "ขามทะเลสอ": "AMPHOE",
  "ขามสะแกแสง": "AMPHOE",
  "ขุขันธ์": "AMPHOE",
  "ขุนตาล": "AMPHOE",
  "ขุนยวม": "AMPHOE",
  "ขุนหาญ": "AMPHOE",
  "คง": "AMPHOE",
  "ครบุรี": "AMPHOE",
  "คลองขลุง": "AMPHOE",
  "คลองท่อม": "AMPHOE",
  "คลองลาน": "AMPHOE",
  "คลองสาน": "AMPHOE",
  "คลองสามวา": "AMPHOE",
  "คลองหลวง": "AMPHOE",
  "คลองหอยโข่ง": "AMPHOE",
  "คลองหาด": "AMPHOE",
  "คลองเขื่อน": "AMPHOE",
  "คลองเตย": "AMPHOE",
  "คลองใหญ่": "AMPHOE",
  "ควนกาหลง": "AMPHOE",
  "ควนขนุน": "AMPHOE",
  "ควนเนียง": "AMPHOE",
  "ควนโดน": "AMPHOE",
  "คอนสวรรค์": "AMPHOE",
  "คอนสาร": "AMPHOE",
  "คันนายาว": "AMPHOE",
  "คำชะอี": "AMPHOE",
  "คำตากล้า": "AMPHOE",
  "คำม่วง": "AMPHOE",
  "คำเขื่อนแก้ว": "AMPHOE",
  "คีรีมาศ": "AMPHOE",
  "คีรีรัฐนิคม": "AMPHOE",
  "คุระบุรี": "AMPHOE",
  "คูเมือง": "AMPHOE",
  "ค่ายบางระจัน": "AMPHOE",
  "ค้อวัง": "AMPHOE",
  "ฆ้องชัย": "AMPHOE",
  "งาว": "AMPHOE",
  "จตุจักร": "AMPHOE",
  "จตุรพักตรพิมาน": "AMPHOE",
  "จอมทอง": "AMPHOE",
  "จอมบึง": "AMPHOE",
  "จอมพระ": "AMPHOE",
  "จะนะ": "AMPHOE",
  "จะแนะ": "AMPHOE",
  "จักราช": "AMPHOE",
  "จังหาร": "AMPHOE",
  "จัตุรัส": "AMPHOE",
  "จุน": "AMPHOE",
  "จุฬาภรณ์": "AMPHOE",
  "ฉวาง": "AMPHOE",
  "ชนบท": "AMPHOE",
  "ชนแดน": "AMPHOE",
  "ชะอวด": "AMPHOE",
  "ชะอำ": "AMPHOE",
  "ชัยบาดาล": "AMPHOE",
  "ชัยบุรี": "AMPHOE",
  "ชาติตระการ": "AMPHOE",
  "ชานุมาน": "AMPHOE",
  "ชำนิ": "AMPHOE",
  "ชื่นชม": "AMPHOE",
  "ชุมตาบง": "AMPHOE",
  "ชุมพลบุรี": "AMPHOE",
  "ชุมพวง": "AMPHOE",
  "ชุมแพ": "AMPHOE",
  "ชุมแสง": "AMPHOE",
  "ช้างกลาง": "AMPHOE",
  "ซับใหญ่": "AMPHOE",
  "ซำสูง": "AMPHOE",
  "ดงหลวง": "AMPHOE",
  "ดงเจริญ": "AMPHOE",
  "ดอกคำใต้": "AMPHOE",
  "ดอนจาน": "AMPHOE",
  "ดอนตาล": "AMPHOE",
  "ดอนตูม": "AMPHOE",
  "ดอนพุด": "AMPHOE",
  "ดอนมดแดง": "AMPHOE",
  "ดอนสัก": "AMPHOE",
  "ดอนเจดีย์": "AMPHOE",
  "ดอนเมือง": "AMPHOE",
  "ดอยสะเก็ด": "AMPHOE",
  "ดอยหลวง": "AMPHOE",
  "ดอยหล่อ": "AMPHOE",
  "ดอยเต่า": "AMPHOE",
  "ดำเนินสะดวก": "AMPHOE",
  "ดินแดง": "AMPHOE",
  "ดุสิต": "AMPHOE",
  "ด่านขุนทด": "AMPHOE",
  "ด่านช้าง": "AMPHOE",
  "ด่านซ้าย": "AMPHOE",
  "ด่านมะขามเตี้ย": "AMPHOE",
  "ตรอน": "AMPHOE",
  "ตระการพืชผล": "AMPHOE",
  "ตลิ่งชัน": "AMPHOE",
  "ตะกั่วทุ่ง": "AMPHOE",
  "ตะกั่วป่า": "AMPHOE",
  "ตะพานหิน": "AMPHOE",
  "ตะโหมด": "AMPHOE",
  "ตากฟ้า": "AMPHOE",
  "ตากใบ": "AMPHOE",
  "ตาคลี": "AMPHOE",
  "ตาพระยา": "AMPHOE",
  "ตาลสุม": "AMPHOE",
  "ถลาง": "AMPHOE",
  "ถ้ำพรรณรา": "AMPHOE",
  "ทรายทองวัฒนา": "AMPHOE",
  "ทรายมูล": "AMPHOE",
  "ทวีวัฒนา": "AMPHOE",
  "ทองผาภูมิ": "AMPHOE",
  "ทองแสนขัน": "AMPHOE",
  "ทับคล้อ": "AMPHOE",
  "ทับปุด": "AMPHOE",
  "ทับสะแก": "AMPHOE",
  "ทัพทัน": "AMPHOE",
  "ทุ่งครุ": "AMPHOE",
  "ทุ่งช้าง": "AMPHOE",
  "ทุ่งตะโก": "AMPHOE",
  "ทุ่งฝน": "AMPHOE",
  "ทุ่งยางแดง": "AMPHOE",
  "ทุ่งศรีอุดม": "AMPHOE",
  "ทุ่งสง": "AMPHOE",
  "ทุ่งหว้า": "AMPHOE",
  "ทุ่งหัวช้าง": "AMPHOE",
  "ทุ่งเขาหลวง": "AMPHOE",
  "ทุ่งเสลี่ยม": "AMPHOE",
  "ทุ่งใหญ่": "AMPHOE",
  "ท่าคันโท": "AMPHOE",
  "ท่าฉาง": "AMPHOE",
  "ท่าชนะ": "AMPHOE",
  "ท่าช้าง": "AMPHOE",
  "ท่าตะเกียบ": "AMPHOE",
  "ท่าตะโก": "AMPHOE",
  "ท่าตูม": "AMPHOE",
  "ท่าบ่อ": "AMPHOE",
  "ท่าปลา": "AMPHOE",
  "ท่ามะกา": "AMPHOE",
  "ท่าม่วง": "AMPHOE",
  "ท่ายาง": "AMPHOE",
  "ท่าลี่": "AMPHOE",
  "ท่าวังผา": "AMPHOE",
  "ท่าวุ้ง": "AMPHOE",
  "ท่าศาลา": "AMPHOE",
  "ท่าสองยาง": "AMPHOE",
  "ท่าหลวง": "AMPHOE",
  "ท่าอุเทน": "AMPHOE",
  "ท่าเรือ": "AMPHOE",
  "ท่าแซะ": "AMPHOE",
  "ท่าแพ": "AMPHOE",
  "ท่าใหม่": "AMPHOE",
  "ท้ายเหมือง": "AMPHOE",
  "ธนบุรี": "AMPHOE",
  "ธวัชบุรี": "AMPHOE",
  "ธัญบุรี": "AMPHOE",
  "ธาตุพนม": "AMPHOE",
  "ธารโต": "AMPHOE",
  "นครชัยศรี": "AMPHOE",
  "นครหลวง": "AMPHOE",
  "นครไทย": "AMPHOE",
  "นบพิตำ": "AMPHOE",
  "นากลาง": "AMPHOE",
  "นาคู": "AMPHOE",
  "นางรอง": "AMPHOE",
  "นาจะหลวย": "AMPHOE",
  "นาดี": "AMPHOE",
  "นาดูน": "AMPHOE",
  "นาด้วง": "AMPHOE",
  "นาตาล": "AMPHOE",
  "นาทม": "AMPHOE",
  "นาทวี": "AMPHOE",
  "นาน้อย": "AMPHOE",
  "นาบอน": "AMPHOE",
  "นามน": "AMPHOE",
  "นายายอาม": "AMPHOE",
  "นายูง": "AMPHOE",
  "นาวัง": "AMPHOE",
  "นาหมื่น": "AMPHOE",
  "นาหม่อม": "AMPHOE",
  "นาหว้า": "AMPHOE",
  "นาเชือก": "AMPHOE",
  "นาเยีย": "AMPHOE",
  "นาแก": "AMPHOE",
  "นาแห้ว": "AMPHOE",
  "นาโพธิ์": "AMPHOE",
  "นาโยง": "AMPHOE",
  "นิคมคำสร้อย": "AMPHOE",
  "นิคมน้ำอูน": "AMPHOE",
  "นิคมพัฒนา": "AMPHOE",
  "น้ำขุ่น": "AMPHOE",
  "น้ำปาด": "AMPHOE",
  "น้ำพอง": "AMPHOE",
  "น้ำยืน": "AMPHOE",
  "น้ำหนาว": "AMPHOE",
  "น้ำเกลี้ยง": "AMPHOE",
  "น้ำโสม": "AMPHOE",
  "บรบือ": "AMPHOE",
  "บรรพตพิสัย": "AMPHOE",
  "บันนังสตา": "AMPHOE",
  "บัวลาย": "AMPHOE",
  "บัวเชด": "AMPHOE",
  "บัวใหญ่": "AMPHOE",
  "บางกรวย": "AMPHOE",
  "บางกระทุ่ม": "AMPHOE",
  "บางกล่ำ": "AMPHOE",
  "บางกอกน้อย": "AMPHOE",
  "บางกอกใหญ่": "AMPHOE",
  "บางกะปิ": "AMPHOE",
  "บางขัน": "AMPHOE",
  "บางขุนเทียน": "AMPHOE",
  "บางคนที": "AMPHOE",
  "บางคล้า": "AMPHOE",
  "บางคอแหลม": "AMPHOE",
  "บางซื่อ": "AMPHOE",
  "บางซ้าย": "AMPHOE",
  "บางนา": "AMPHOE",
  "บางน้ำเปรี้ยว": "AMPHOE",
  "บางบอน": "AMPHOE",
  "บางบัวทอง": "AMPHOE",
  "บางบาล": "AMPHOE",
  "บางบ่อ": "AMPHOE",
  "บางปลาม้า": "AMPHOE",
  "บางปะกง": "AMPHOE",
  "บางปะหัน": "AMPHOE",
  "บางปะอิน": "AMPHOE",
  "บางพลัด": "AMPHOE",
  "บางพลี": "AMPHOE",
  "บางมูลนาก": "AMPHOE",
  "บางระกำ": "AMPHOE",
  "บางระจัน": "AMPHOE",
  "บางรัก": "AMPHOE",
  "บางละมุง": "AMPHOE",
  "บางสะพาน": "AMPHOE",
  "บางสะพานน้อย": "AMPHOE",
  "บางเขน": "AMPHOE",
  "บางเลน": "AMPHOE",
  "บางเสาธง": "AMPHOE",
  "บางแก้ว": "AMPHOE",
  "บางแค": "AMPHOE",
  "บางแพ": "AMPHOE",
  "บางใหญ่": "AMPHOE",
  "บางไทร": "AMPHOE",
  "บาเจาะ": "AMPHOE",
  "บำเหน็จณรงค์": "AMPHOE",
  "บึงกุ่ม": "AMPHOE",
  "บึงนาราง": "AMPHOE",
  "บึงบูรพ์": "AMPHOE",
  "บึงสามพัน": "AMPHOE",
  "บึงสามัคคี": "AMPHOE",
  "บึงโขงหลง": "AMPHOE",
  "บุณฑริก": "AMPHOE",
  "บุ่งคล้า": "AMPHOE",
  "บ่อทอง": "AMPHOE",
  "บ่อพลอย": "AMPHOE",
  "บ่อเกลือ": "AMPHOE",
  "บ่อไร่": "AMPHOE",
  "บ้านกรวด": "AMPHOE",
  "บ้านคา": "AMPHOE",
  "บ้านค่าย": "AMPHOE",
  "บ้านฉาง": "AMPHOE",
  "บ้านดุง": "AMPHOE",
  "บ้านด่าน": "AMPHOE",
  "บ้านด่านลานหอย": "AMPHOE",
  "บ้านตาก": "AMPHOE",
  "บ้านตาขุน": "AMPHOE",
  "บ้านธิ": "AMPHOE",
  "บ้านนา": "AMPHOE",
  "บ้านนาสาร": "AMPHOE",
  "บ้านนาเดิม": "AMPHOE",
  "บ้านบึง": "AMPHOE",
  "บ้านผือ": "AMPHOE",
  "บ้านฝาง": "AMPHOE",
  "บ้านม่วง": "AMPHOE",
  "บ้านลาด": "AMPHOE",
  "บ้านสร้าง": "AMPHOE",
  "บ้านหมอ": "AMPHOE",
  "บ้านหมี่": "AMPHOE",
  "บ้านหลวง": "AMPHOE",
  "บ้านเขว้า": "AMPHOE",
  "บ้านเหลื่อม": "AMPHOE",
  "บ้านแท่น": "AMPHOE",
  "บ้านแพง": "AMPHOE",
  "บ้านแพรก": "AMPHOE",
  "บ้านแพ้ว": "AMPHOE",
  "บ้านแหลม": "AMPHOE",
  "บ้านแฮด": "AMPHOE",
  "บ้านโคก": "AMPHOE",
  "บ้านโป่ง": "AMPHOE",
  "บ้านโพธิ์": "AMPHOE",
  "บ้านโฮ่ง": "AMPHOE",
  "บ้านใหม่ไชยพจน์": "AMPHOE",
  "บ้านไผ่": "AMPHOE",
  "บ้านไร่": "AMPHOE",
  "ปง": "AMPHOE",
  "ปทุมรัตน์": "AMPHOE",
  "ปทุมราชวงศา": "AMPHOE",
  "ปทุมวัน": "AMPHOE",
  "ประจักษ์ศิลปาคม": "AMPHOE",
  "ประจันตคาม": "AMPHOE",
  "ประทาย": "AMPHOE",
  "ประเวศ": "AMPHOE",
  "ประโคนชัย": "AMPHOE",
  "ปรางค์กู่": "AMPHOE",
  "ปราณบุรี": "AMPHOE",
  "ปราสาท": "AMPHOE",
  "ปลวกแดง": "AMPHOE",
  "ปลาปาก": "AMPHOE",
  "ปลายพระยา": "AMPHOE",
  "ปะคำ": "AMPHOE",
  "ปะทิว": "AMPHOE",
  "ปะนาเระ": "AMPHOE",
  "ปะเหลียน": "AMPHOE",
  "ปักธงชัย": "AMPHOE",
  "ปัว": "AMPHOE",
  "ปากคาด": "AMPHOE",
  "ปากชม": "AMPHOE",
  "ปากช่อง": "AMPHOE",
  "ปากท่อ": "AMPHOE",
  "ปากพนัง": "AMPHOE",
  "ปากพลี": "AMPHOE",
  "ปากพะยูน": "AMPHOE",
  "ปากเกร็ด": "AMPHOE",
  "ปางมะผ้า": "AMPHOE",
  "ปางศิลาทอง": "AMPHOE",
  "ปาย": "AMPHOE",
  "ป่าซาง": "AMPHOE",
  "ป่าติ้ว": "AMPHOE",
  "ป่าบอน": "AMPHOE",
  "ป่าพะยอม": "AMPHOE",
  "ป่าแดด": "AMPHOE",
  "ป่าโมก": "AMPHOE",
  "ป้อมปราบศัตรูพ่าย": "AMPHOE",
  "ผักไห่": "AMPHOE",
  "ผาขาว": "AMPHOE",
  "ฝาง": "AMPHOE",
  "พญาเม็งราย": "AMPHOE",
  "พญาไท": "AMPHOE",
  "พนม": "AMPHOE",
  "พนมดงรัก": "AMPHOE",
  "พนมทวน": "AMPHOE",
  "พนมสารคาม": "AMPHOE",
  "พนมไพร": "AMPHOE",
  "พนัสนิคม": "AMPHOE",
  "พนา": "AMPHOE",
  "พบพระ": "AMPHOE",
  "พยัคฆภูมิพิสัย": "AMPHOE",
  "พยุหะคีรี": "AMPHOE",
  "พยุห์": "AMPHOE",
  "พรรณานิคม": "AMPHOE",
  "พรหมคีรี": "AMPHOE",
  "พรหมบุรี": "AMPHOE",
  "พรหมพิราม": "AMPHOE",
  "พระทองคำ": "AMPHOE",
  "พระนคร": "AMPHOE",
  "พระนครศรีอยุธยา": "AMPHOE",
  "พระประแดง": "AMPHOE",
  "พระพรหม": "AMPHOE",
  "พระพุทธบาท": "AMPHOE",
  "พระยืน": "AMPHOE",
  "พระสมุทรเจดีย์": "AMPHOE",
  "พระแสง": "AMPHOE",
  "พระโขนง": "AMPHOE",
  "พรานกระต่าย": "AMPHOE",
  "พรเจริญ": "AMPHOE",
  "พร้าว": "AMPHOE",
  "พล": "AMPHOE",
  "พลับพลาชัย": "AMPHOE",
  "พะโต๊ะ": "AMPHOE",
  "พังโคน": "AMPHOE",
  "พัฒนานิคม": "AMPHOE",
  "พาน": "AMPHOE",
  "พานทอง": "AMPHOE",
  "พิชัย": "AMPHOE",
  "พิบูลมังสาหาร": "AMPHOE",
  "พิบูลย์รักษ์": "AMPHOE",
  "พิปูน": "AMPHOE",
  "พิมาย": "AMPHOE",
  "พุทธมณฑล": "AMPHOE",
  "พุทไธสง": "AMPHOE",
  "พุนพิน": "AMPHOE",
  "ฟากท่า": "AMPHOE",
  "ภักดีชุมพล": "AMPHOE",
  "ภาชี": "AMPHOE",
  "ภาษีเจริญ": "AMPHOE",
  "ภูกระดึง": "AMPHOE",
  "ภูกามยาว": "AMPHOE",
  "ภูซาง": "AMPHOE",
  "ภูผาม่าน": "AMPHOE",
  "ภูพาน": "AMPHOE",
  "ภูสิงห์": "AMPHOE",
  "ภูหลวง": "AMPHOE",
  "ภูเขียว": "AMPHOE",
  "ภูเพียง": "AMPHOE",
  "ภูเรือ": "AMPHOE",
  "ภูเวียง": "AMPHOE",
  "มวกเหล็ก": "AMPHOE",
  "มหาชนะชัย": "AMPHOE",
  "มหาราช": "AMPHOE",
  "มะขาม": "AMPHOE",
  "มะนัง": "AMPHOE",
  "มัญจาคีรี": "AMPHOE",
  "มายอ": "AMPHOE",
  "มีนบุรี": "AMPHOE",
  "มโนรมย์": "AMPHOE",
  "ม่วงสามสิบ": "AMPHOE",
  "ยะรัง": "AMPHOE",
  "ยะหริ่ง": "AMPHOE",
  "ยะหา": "AMPHOE",
  "ยางชุมน้อย": "AMPHOE",
  "ยางตลาด": "AMPHOE",
  "ยางสีสุราช": "AMPHOE",
  "ยานนาวา": "AMPHOE",
  "ยี่งอ": "AMPHOE",
  "ย่านตาขาว": "AMPHOE",
  "ระแงะ": "AMPHOE",
  "ระโนด": "AMPHOE",
  "รัตนบุรี": "AMPHOE",
  "รัตนวาปี": "AMPHOE",
  "รัตภูมิ": "AMPHOE",
  "รัษฎา": "AMPHOE",
  "ราชสาส์น": "AMPHOE",
  "ราชเทวี": "AMPHOE",
  "รามัน": "AMPHOE",
  "ราษฎร์บูรณะ": "AMPHOE",
  "ราษีไศล": "AMPHOE",
  "รือเสาะ": "AMPHOE",
  "ร่องคำ": "AMPHOE",
  "ร่อนพิบูลย์": "AMPHOE",
  "ร้องกวาง": "AMPHOE",
  "ลอง": "AMPHOE",
  "ละงู": "AMPHOE",
  "ละหานทราย": "AMPHOE",
  "ละอุ่น": "AMPHOE",
  "ละแม": "AMPHOE",
  "ลับแล": "AMPHOE",
  "ลาดกระบัง": "AMPHOE",
  "ลาดบัวหลวง": "AMPHOE",
  "ลาดพร้าว": "AMPHOE",
  "ลาดยาว": "AMPHOE",
  "ลาดหลุมแก้ว": "AMPHOE",
  "ลานกระบือ": "AMPHOE",
  "ลานสกา": "AMPHOE",
  "ลานสัก": "AMPHOE",
  "ลำดวน": "AMPHOE",
  "ลำทะเมนชัย": "AMPHOE",
  "ลำทับ": "AMPHOE",
  "ลำปลายมาศ": "AMPHOE",
  "ลำลูกกา": "AMPHOE",
  "ลำสนธิ": "AMPHOE",
  "ลี้": "AMPHOE",
  "ลืออำนาจ": "AMPHOE",
  "วชิรบารมี": "AMPHOE",
  "วังจันทร์": "AMPHOE",
  "วังชิ้น": "AMPHOE",
  "วังทรายพูน": "AMPHOE",
  "วังทอง": "AMPHOE",
  "วังทองหลาง": "AMPHOE",
  "วังน้อย": "AMPHOE",
  "วังน้ำเขียว": "AMPHOE",
  "วังน้ำเย็น": "AMPHOE",
  "วังม่วง": "AMPHOE",
  "วังยาง": "AMPHOE",
  "วังวิเศษ": "AMPHOE",
  "วังสมบูรณ์": "AMPHOE",
  "วังสะพุง": "AMPHOE",
  "วังสามหมอ": "AMPHOE",
  "วังหิน": "AMPHOE",
  "วังเจ้า": "AMPHOE",
  "วังเหนือ": "AMPHOE",
  "วังโป่ง": "AMPHOE",
  "วัฒนา": "AMPHOE",
  "วัฒนานคร": "AMPHOE",
  "วัดสิงห์": "AMPHOE",
  "วัดเพลง": "AMPHOE",
  "วัดโบสถ์": "AMPHOE",
  "วานรนิวาส": "AMPHOE",
  "วาปีปทุม": "AMPHOE",
  "วาริชภูมิ": "AMPHOE",
  "วารินชำราบ": "AMPHOE",
  "วิภาวดี": "AMPHOE",
  "วิหารแดง": "AMPHOE",
  "วิเชียรบุรี": "AMPHOE",
  "วิเศษชัยชาญ": "AMPHOE",
  "ศรีณรงค์": "AMPHOE",
  "ศรีธาตุ": "AMPHOE",
  "ศรีนคร": "AMPHOE",
  "ศรีนครินทร์": "AMPHOE",
  "ศรีบรรพต": "AMPHOE",
  "ศรีบุญเรือง": "AMPHOE",
  "ศรีประจันต์": "AMPHOE",
  "ศรีมหาโพธิ": "AMPHOE",
  "ศรีมโหสถ": "AMPHOE",
  "ศรีรัตนะ": "AMPHOE",
  "ศรีราชา": "AMPHOE",
  "ศรีวิไล": "AMPHOE",
  "ศรีสงคราม": "AMPHOE",
  "ศรีสมเด็จ": "AMPHOE",
  "ศรีสวัสดิ์": "AMPHOE",
  "ศรีสัชนาลัย": "AMPHOE",
  "ศรีสาคร": "AMPHOE",
  "ศรีสำโรง": "AMPHOE",
  "ศรีเชียงใหม่": "AMPHOE",
  "ศรีเทพ": "AMPHOE",
  "ศรีเมืองใหม่": "AMPHOE",
  "ศิลาลาด": "AMPHOE",
  "ศีขรภูมิ": "AMPHOE",
  "สตึก": "AMPHOE",
  "สทิงพระ": "AMPHOE",
  "สนม": "AMPHOE",
  "สนามชัยเขต": "AMPHOE",
  "สบปราบ": "AMPHOE",
  "สบเมย": "AMPHOE",
  "สมเด็จ": "AMPHOE",
  "สรรคบุรี": "AMPHOE",
  "สรรพยา": "AMPHOE",
  "สระโบสถ์": "AMPHOE",
  "สระใคร": "AMPHOE",
  "สร้างคอม": "AMPHOE",
  "สวนผึ้ง": "AMPHOE",
  "สวนหลวง": "AMPHOE",
  "สวรรคโลก": "AMPHOE",
  "สวี": "AMPHOE",
  "สว่างวีระวงศ์": "AMPHOE",
  "สว่างอารมณ์": "AMPHOE",
  "สว่างแดนดิน": "AMPHOE",
  "สหัสขันธ์": "AMPHOE",
  "สอง": "AMPHOE",
  "สองพี่น้อง": "AMPHOE",
  "สองแคว": "AMPHOE",
  "สอยดาว": "AMPHOE",
  "สะบ้าย้อย": "AMPHOE",
  "สะพานสูง": "AMPHOE",
  "สะเดา": "AMPHOE",
  "สะเมิง": "AMPHOE",
  "สังขละบุรี": "AMPHOE",
  "สังขะ": "AMPHOE",
  "สังคม": "AMPHOE",
  "สัตหีบ": "AMPHOE",
  "สันกำแพง": "AMPHOE",
  "สันติสุข": "AMPHOE",
  "สันทราย": "AMPHOE",
  "สันป่าตอง": "AMPHOE",
  "สัมพันธวงศ์": "AMPHOE",
  "สากเหล็ก": "AMPHOE",
  "สาทร": "AMPHOE",
  "สามง่าม": "AMPHOE",
  "สามชัย": "AMPHOE",
  "สามชุก": "AMPHOE",
  "สามพราน": "AMPHOE",
  "สามร้อยยอด": "AMPHOE",
  "สามเงา": "AMPHOE",
  "สามโก้": "AMPHOE",
  "สามโคก": "AMPHOE",
  "สายบุรี": "AMPHOE",
  "สายไหม": "AMPHOE",
  "สารภี": "AMPHOE",
  "สำโรง": "AMPHOE",
  "สำโรงทาบ": "AMPHOE",
  "สิงหนคร": "AMPHOE",
  "สิชล": "AMPHOE",
  "สิรินธร": "AMPHOE",
  "สิเกา": "AMPHOE",
  "สีคิ้ว": "AMPHOE",
  "สีชมพู": "AMPHOE",
  "สีดา": "AMPHOE",
  "สุขสำราญ": "AMPHOE",
  "สุคิริน": "AMPHOE",
  "สุวรรณคูหา": "AMPHOE",
  "สุวรรณภูมิ": "AMPHOE",
  "สุไหงปาดี": "AMPHOE",
  "สุไหงโก-ลก": "AMPHOE",
  "สูงเนิน": "AMPHOE",
  "สูงเม่น": "AMPHOE",
  "ส่องดาว": "AMPHOE",
  "หนองกี่": "AMPHOE",
  "หนองกุงศรี": "AMPHOE",
  "หนองขาหย่าง": "AMPHOE",
  "หนองจอก": "AMPHOE",
  "หนองจิก": "AMPHOE",
  "หนองฉาง": "AMPHOE",
  "หนองนาคำ": "AMPHOE",
  "หนองบัว": "AMPHOE",
  "หนองบัวระเหว": "AMPHOE",
  "หนองบัวแดง": "AMPHOE",
  "หนองบุญมาก": "AMPHOE",
  "หนองปรือ": "AMPHOE",
  "หนองพอก": "AMPHOE",
  "หนองมะโมง": "AMPHOE",
  "หนองม่วง": "AMPHOE",
  "หนองม่วงไข่": "AMPHOE",
  "หนองวัวซอ": "AMPHOE",
  "หนองสองห้อง": "AMPHOE",
  "หนองสูง": "AMPHOE",
  "หนองหงส์": "AMPHOE",
  "หนองหญ้าปล้อง": "AMPHOE",
  "หนองหญ้าไซ": "AMPHOE",
  "หนองหาน": "AMPHOE",
  "หนองหิน": "AMPHOE",
  "หนองฮี": "AMPHOE",
  "หนองเรือ": "AMPHOE",
  "หนองเสือ": "AMPHOE",
  "หนองแขม": "AMPHOE",
  "หนองแค": "AMPHOE",
  "หนองแซง": "AMPHOE",
  "หนองแสง": "AMPHOE",
  "หนองโดน": "AMPHOE",
  "หนองใหญ่": "AMPHOE",
  "หนองไผ่": "AMPHOE",
  "หลักสี่": "AMPHOE",
  "หลังสวน": "AMPHOE",
  "หล่มสัก": "AMPHOE",
  "หล่มเก่า": "AMPHOE",
  "หว้านใหญ่": "AMPHOE",
  "หันคา": "AMPHOE",
  "หัวตะพาน": "AMPHOE",
  "หัวหิน": "AMPHOE",
  "หัวไทร": "AMPHOE",
  "หางดง": "AMPHOE",
  "หาดสำราญ": "AMPHOE",
  "หาดใหญ่": "AMPHOE",
  "ห้วยกระเจา": "AMPHOE",
  "ห้วยขวาง": "AMPHOE",
  "ห้วยคต": "AMPHOE",
  "ห้วยทับทัน": "AMPHOE",
  "ห้วยผึ้ง": "AMPHOE",
  "ห้วยยอด": "AMPHOE",
  "ห้วยราช": "AMPHOE",
  "ห้วยเม็ก": "AMPHOE",
  "ห้วยแถลง": "AMPHOE",
  "ห้างฉัตร": "AMPHOE",
  "องครักษ์": "AMPHOE",
  "อมก๋อย": "AMPHOE",
  "อรัญประเทศ": "AMPHOE",
  "อัมพวา": "AMPHOE",
  "อากาศอำนวย": "AMPHOE",
  "อาจสามารถ": "AMPHOE",
  "อินทร์บุรี": "AMPHOE",
  "อุทัย": "AMPHOE",
  "อุทุมพรพิสัย": "AMPHOE",
  "อุบลรัตน์": "AMPHOE",
  "อุ้มผาง": "AMPHOE",
  "อู่ทอง": "AMPHOE",
  "อ่าวลึก": "AMPHOE",
  "ฮอด": "AMPHOE",
  "เกษตรวิสัย": "AMPHOE",
  "เกษตรสมบูรณ์": "AMPHOE",
  "เกาะกูด": "AMPHOE",
  "เกาะคา": "AMPHOE",
  "เกาะจันทร์": "AMPHOE",
  "เกาะช้าง": "AMPHOE",
  "เกาะพะงัน": "AMPHOE",
  "เกาะยาว": "AMPHOE",
  "เกาะลันตา": "AMPHOE",
  "เกาะสมุย": "AMPHOE",
  "เกาะสีชัง": "AMPHOE",
  "เก้าเลี้ยว": "AMPHOE",
  "เขมราฐ": "AMPHOE",
  "เขวาสินรินทร์": "AMPHOE",
  "เขาคิชฌกูฏ": "AMPHOE",
  "เขาค้อ": "AMPHOE",
  "เขาฉกรรจ์": "AMPHOE",
  "เขาชะเมา": "AMPHOE",
  "เขาชัยสน": "AMPHOE",
  "เขาพนม": "AMPHOE",
  "เขาย้อย": "AMPHOE",
  "เขาวง": "AMPHOE",
  "เขาสมิง": "AMPHOE",
  "เขาสวนกวาง": "AMPHOE",
  "เขื่องใน": "AMPHOE",
  "เคียนซา": "AMPHOE",
  "เจริญศิลป์": "AMPHOE",
  "เจาะไอร้อง": "AMPHOE",
  "เฉลิมพระเกียรติ": "AMPHOE",
  "เชียงกลาง": "AMPHOE",
  "เชียงขวัญ": "AMPHOE",
  "เชียงของ": "AMPHOE",
  "เชียงคาน": "AMPHOE",
  "เชียงคำ": "AMPHOE",
  "เชียงดาว": "AMPHOE",
  "เชียงม่วน": "AMPHOE",
  "เชียงยืน": "AMPHOE",
  "เชียงแสน": "AMPHOE",
  "เชียรใหญ่": "AMPHOE",
  "เซกา": "AMPHOE",
  "เดชอุดม": "AMPHOE",
  "เดิมบางนางบวช": "AMPHOE",
  "เด่นชัย": "AMPHOE",
  "เต่างอย": "AMPHOE",
  "เถิน": "AMPHOE",
  "เทพสถิต": "AMPHOE",
  "เทพา": "AMPHOE",
  "เทพารักษ์": "AMPHOE",
  "เทิง": "AMPHOE",
  "เนินขาม": "AMPHOE",
  "เนินมะปราง": "AMPHOE",
  "เนินสง่า": "AMPHOE",
  "เบญจลักษ์": "AMPHOE",
  "เบตง": "AMPHOE",
  "เปือยน้อย": "AMPHOE",
  "เฝ้าไร่": "AMPHOE",
  "เพ็ญ": "AMPHOE",
  "เมยวดี": "AMPHOE",
  "เมือง": "AMPHOE",
  "เมืองกระบี่": "AMPHOE",
  "เมืองกาญจนบุรี": "AMPHOE",
  "เมืองกาฬสินธุ์": "AMPHOE",
  "เมืองกำแพงเพชร": "AMPHOE",
  "เมืองขอนแก่น": "AMPHOE",
  "เมืองจันทบุรี": "AMPHOE",
  "เมืองจันทร์": "AMPHOE",
  "เมืองฉะเชิงเทรา": "AMPHOE",
  "เมืองชลบุรี": "AMPHOE",
  "เมืองชัยนาท": "AMPHOE",
  "เมืองชัยภูมิ": "AMPHOE",
  "เมืองชุมพร": "AMPHOE",
  "เมืองตรัง": "AMPHOE",
  "เมืองตราด": "AMPHOE",
  "เมืองตาก": "AMPHOE",
  "เมืองนครนายก": "AMPHOE",
  "เมืองนครปฐม": "AMPHOE",
  "เมืองนครพนม": "AMPHOE",
  "เมืองนครราชสีมา": "AMPHOE",
  "เมืองนครศรีธรรมราช": "AMPHOE",
  "เมืองนครสวรรค์": "AMPHOE",
  "เมืองนนทบุรี": "AMPHOE",
  "เมืองนราธิวาส": "AMPHOE",
  "เมืองน่าน": "AMPHOE",
  "เมืองบึงกาฬ": "AMPHOE",
  "เมืองบุรีรัมย์": "AMPHOE",
  "เมืองปทุมธานี": "AMPHOE",
  "เมืองประจวบคีรีขันธ์": "AMPHOE",
  "เมืองปราจีนบุรี": "AMPHOE",
  "เมืองปัตตานี": "AMPHOE",
  "เมืองปาน": "AMPHOE",
  "เมืองพะเยา": "AMPHOE",
  "เมืองพังงา": "AMPHOE",
  "เมืองพัทลุง": "AMPHOE",
  "เมืองพิจิตร": "AMPHOE",
  "เมืองพิษณุโลก": "AMPHOE",
  "เมืองภูเก็ต": "AMPHOE",
  "เมืองมหาสารคาม": "AMPHOE",
  "เมืองมุกดาหาร": "AMPHOE",
  "เมืองยะลา": "AMPHOE",
  "เมืองยาง": "AMPHOE",
  "เมืองยโสธร": "AMPHOE",
  "เมืองระนอง": "AMPHOE",
  "เมืองระยอง": "AMPHOE",
  "เมืองราชบุรี": "AMPHOE",
  "เมืองร้อยเอ็ด": "AMPHOE",
  "เมืองลพบุรี": "AMPHOE",
  "เมืองลำปาง": "AMPHOE",
  "เมืองลำพูน": "AMPHOE",
  "เมืองศรีสะเกษ": "AMPHOE",
  "เมืองสกลนคร": "AMPHOE",
  "เมืองสงขลา": "AMPHOE",
  "เมืองสตูล": "AMPHOE",
  "เมืองสมุทรปราการ": "AMPHOE",
  "เมืองสมุทรสงคราม": "AMPHOE",
  "เมืองสมุทรสาคร": "AMPHOE",
  "เมืองสรวง": "AMPHOE",
  "เมืองสระบุรี": "AMPHOE",
  "เมืองสระแก้ว": "AMPHOE",
  "เมืองสิงห์บุรี": "AMPHOE",
  "เมืองสุพรรณบุรี": "AMPHOE",
  "เมืองสุราษฎร์ธานี": "AMPHOE",
  "เมืองสุรินทร์": "AMPHOE",
  "เมืองสุโขทัย": "AMPHOE",
  "เมืองหนองคาย": "AMPHOE",
  "เมืองหนองบัวลำภู": "AMPHOE",
  "เมืองอำนาจเจริญ": "AMPHOE",
  "เมืองอุดรธานี": "AMPHOE",
  "เมืองอุตรดิตถ์": "AMPHOE",
  "เมืองอุทัยธานี": "AMPHOE",
  "เมืองอุบลราชธานี": "AMPHOE",
  "เมืองอ่างทอง": "AMPHOE",
  "เมืองเชียงราย": "AMPHOE",
  "เมืองเชียงใหม่": "AMPHOE",
  "เมืองเพชรบุรี": "AMPHOE",
  "เมืองเพชรบูรณ์": "AMPHOE",
  "เมืองเลย": "AMPHOE",
  "เมืองแพร่": "AMPHOE",
  "เมืองแม่ฮ่องสอน": "AMPHOE",
  "เรณูนคร": "AMPHOE",
  "เลาขวัญ": "AMPHOE",
  "เลิงนกทา": "AMPHOE",
  "เวียงชัย": "AMPHOE",
  "เวียงป่าเป้า": "AMPHOE",
  "เวียงสระ": "AMPHOE",
  "เวียงสา": "AMPHOE",
  "เวียงหนองล่อง": "AMPHOE",
  "เวียงเก่า": "AMPHOE",
  "เวียงเชียงรุ้ง": "AMPHOE",
  "เวียงแก่น": "AMPHOE",
  "เวียงแหง": "AMPHOE",
  "เสนา": "AMPHOE",
  "เสนางคนิคม": "AMPHOE",
  "เสริมงาม": "AMPHOE",
  "เสลภูมิ": "AMPHOE",
  "เสาไห้": "AMPHOE",
  "เสิงสาง": "AMPHOE",
  "เหนือคลอง": "AMPHOE",
  "เหล่าเสือโก้ก": "AMPHOE",
  "เอราวัณ": "AMPHOE",
  "แกดำ": "AMPHOE",
  "แกลง": "AMPHOE",
  "แก่งกระจาน": "AMPHOE",
  "แก่งคอย": "AMPHOE",
  "แก่งหางแมว": "AMPHOE",
  "แก้งคร้อ": "AMPHOE",
  "แก้งสนามนาง": "AMPHOE",
  "แคนดง": "AMPHOE",
  "แจ้ห่ม": "AMPHOE",
  "แปลงยาว": "AMPHOE",
  "แม่จริม": "AMPHOE",
  "แม่จัน": "AMPHOE",
  "แม่ทะ": "AMPHOE",
  "แม่ทา": "AMPHOE",
  "แม่พริก": "AMPHOE",
  "แม่ฟ้าหลวง": "AMPHOE",
  "แม่ระมาด": "AMPHOE",
  "แม่ริม": "AMPHOE",
  "แม่ลาน": "AMPHOE",
  "แม่ลาน้อย": "AMPHOE",
  "แม่ลาว": "AMPHOE",
  "แม่วงก์": "AMPHOE",
  "แม่วาง": "AMPHOE",
  "แม่สรวย": "AMPHOE",
  "แม่สอด": "AMPHOE",
  "แม่สะเรียง": "AMPHOE",
  "แม่สาย": "AMPHOE",
  "แม่ออน": "AMPHOE",
  "แม่อาย": "AMPHOE",
  "แม่เปิน": "AMPHOE",
  "แม่เมาะ": "AMPHOE",
  "แม่แจ่ม": "AMPHOE",
  "แม่แตง": "AMPHOE",
  "แม่ใจ": "AMPHOE",
  "แวงน้อย": "AMPHOE",
  "แวงใหญ่": "AMPHOE",
  "แว้ง": "AMPHOE",
  "แสวงหา": "AMPHOE",
  "แหลมงอบ": "AMPHOE",
  "แหลมสิงห์": "AMPHOE",
  "โกรกพระ": "AMPHOE",
  "โกสัมพีนคร": "AMPHOE",
  "โกสุมพิสัย": "AMPHOE",
  "โขงเจียม": "AMPHOE",
  "โคกศรีสุพรรณ": "AMPHOE",
  "โคกสำโรง": "AMPHOE",
  "โคกสูง": "AMPHOE",
  "โคกเจริญ": "AMPHOE",
  "โคกโพธิ์": "AMPHOE",
  "โคกโพธิ์ไชย": "AMPHOE",
  "โชคชัย": "AMPHOE",
  "โซ่พิสัย": "AMPHOE",
  "โนนคูณ": "AMPHOE",
  "โนนดินแดง": "AMPHOE",
  "โนนนารายณ์": "AMPHOE",
  "โนนศิลา": "AMPHOE",
  "โนนสะอาด": "AMPHOE",
  "โนนสัง": "AMPHOE",
  "โนนสุวรรณ": "AMPHOE",
  "โนนสูง": "AMPHOE",
  "โนนแดง": "AMPHOE",
  "โนนไทย": "AMPHOE",
  "โป่งน้ำร้อน": "AMPHOE",
  "โพทะเล": "AMPHOE",
  "โพธาราม": "AMPHOE",
  "โพธิ์ชัย": "AMPHOE",
  "โพธิ์ตาก": "AMPHOE",
  "โพธิ์ทอง": "AMPHOE",
  "โพธิ์ประทับช้าง": "AMPHOE",
  "โพธิ์ศรีสุวรรณ": "AMPHOE",
  "โพธิ์ไทร": "AMPHOE",
  "โพนทราย": "AMPHOE",
  "โพนทอง": "AMPHOE",
  "โพนนาแก้ว": "AMPHOE",
  "โพนพิสัย": "AMPHOE",
  "โพนสวรรค์": "AMPHOE",
  "ไชยปราการ": "AMPHOE",
  "ไชยวาน": "AMPHOE",
  "ไชยา": "AMPHOE",
  "ไชโย": "AMPHOE",
  "ไทยเจริญ": "AMPHOE",
  "ไทรงาม": "AMPHOE",
  "ไทรน้อย": "AMPHOE",
  "ไทรโยค": "AMPHOE",
  "ไพรบึง": "AMPHOE",
  "ไพศาลี": "AMPHOE",
  "ไม้แก่น": "AMPHOE",

    "กระบี่": "PROVINCE",
  "กรุงเทพ": "PROVINCE",
  "กาญจนบุรี": "PROVINCE",
  "กาฬสินธุ์": "PROVINCE",
  "กำแพงเพชร": "PROVINCE",
  "ขอนแก่น": "PROVINCE",
  "จันทบุรี": "PROVINCE",
  "ฉะเชิงเทรา": "PROVINCE",
  "ชลบุรี": "PROVINCE",
  "ชัยนาท": "PROVINCE",
  "ชัยภูมิ": "PROVINCE",
  "ชุมพร": "PROVINCE",
  "ตรัง": "PROVINCE",
  "ตราด": "PROVINCE",
  "ตาก": "PROVINCE",
  "นครนายก": "PROVINCE",
  "นครปฐม": "PROVINCE",
  "นครพนม": "PROVINCE",
  "นครราชสีมา": "PROVINCE",
  "นครศรีธรรมราช": "PROVINCE",
  "นครสวรรค์": "PROVINCE",
  "นนทบุรี": "PROVINCE",
  "นราธิวาส": "PROVINCE",
  "น่าน": "PROVINCE",
  "บึงกาฬ": "PROVINCE",
  "บุรีรัมย์": "PROVINCE",
  "ปทุมธานี": "PROVINCE",
  "ประจวบคีรีขันธ์": "PROVINCE",
  "ปราจีนบุรี": "PROVINCE",
  "ปัตตานี": "PROVINCE",
  "พระนครศรีอยุธยา": "PROVINCE",
  "พะเยา": "PROVINCE",
  "พังงา": "PROVINCE",
  "พัทลุง": "PROVINCE",
  "พิจิตร": "PROVINCE",
  "พิษณุโลก": "PROVINCE",
  "ภูเก็ต": "PROVINCE",
  "มหาสารคาม": "PROVINCE",
  "มุกดาหาร": "PROVINCE",
  "ยะลา": "PROVINCE",
  "ยโสธร": "PROVINCE",
  "ระนอง": "PROVINCE",
  "ระยอง": "PROVINCE",
  "ราชบุรี": "PROVINCE",
  "ร้อยเอ็ด": "PROVINCE",
  "ลพบุรี": "PROVINCE",
  "ลำปาง": "PROVINCE",
  "ลำพูน": "PROVINCE",
  "ศรีสะเกษ": "PROVINCE",
  "สกลนคร": "PROVINCE",
  "สงขลา": "PROVINCE",
  "สตูล": "PROVINCE",
  "สมุทรปราการ": "PROVINCE",
  "สมุทรสงคราม": "PROVINCE",
  "สมุทรสาคร": "PROVINCE",
  "สระบุรี": "PROVINCE",
  "สระแก้ว": "PROVINCE",
  "สิงห์บุรี": "PROVINCE",
  "สุพรรณบุรี": "PROVINCE",
  "สุราษฎร์ธานี": "PROVINCE",
  "สุรินทร์": "PROVINCE",
  "สุโขทัย": "PROVINCE",
  "หนองคาย": "PROVINCE",
  "หนองบัวลำภู": "PROVINCE",
  "อำนาจเจริญ": "PROVINCE",
  "อุดรธานี": "PROVINCE",
  "อุตรดิตถ์": "PROVINCE",
  "อุทัยธานี": "PROVINCE",
  "อุบลราชธานี": "PROVINCE",
  "อ่างทอง": "PROVINCE",
  "เชียงราย": "PROVINCE",
  "เชียงใหม่": "PROVINCE",
  "เพชรบุรี": "PROVINCE",
  "เพชรบูรณ์": "PROVINCE",
  "เลย": "PROVINCE",
  "แพร่": "PROVINCE",
  "แม่ฮ่องสอน": "PROVINCE",

    "10010": "ZIPCODE",
  "10020": "ZIPCODE",
  "10100": "ZIPCODE",
  "10110": "ZIPCODE",
  "10120": "ZIPCODE",
  "10130": "ZIPCODE",
  "10140": "ZIPCODE",
  "10150": "ZIPCODE",
  "10160": "ZIPCODE",
  "10170": "ZIPCODE",
  "10200": "ZIPCODE",
  "10210": "ZIPCODE",
  "10220": "ZIPCODE",
  "10230": "ZIPCODE",
  "10240": "ZIPCODE",
  "10243": "ZIPCODE",
  "10250": "ZIPCODE",
  "10260": "ZIPCODE",
  "10270": "ZIPCODE",
  "10280": "ZIPCODE",
  "10290": "ZIPCODE",
  "10300": "ZIPCODE",
  "10303": "ZIPCODE",
  "10310": "ZIPCODE",
  "10320": "ZIPCODE",
  "10330": "ZIPCODE",
  "10400": "ZIPCODE",
  "10500": "ZIPCODE",
  "10501": "ZIPCODE",
  "10510": "ZIPCODE",
  "10520": "ZIPCODE",
  "10530": "ZIPCODE",
  "10540": "ZIPCODE",
  "10541": "ZIPCODE",
  "10550": "ZIPCODE",
  "10560": "ZIPCODE",
  "10570": "ZIPCODE",
  "10600": "ZIPCODE",
  "10700": "ZIPCODE",
  "10702": "ZIPCODE",
  "10800": "ZIPCODE",
  "10900": "ZIPCODE",
  "11000": "ZIPCODE",
  "11110": "ZIPCODE",
  "11120": "ZIPCODE",
  "11130": "ZIPCODE",
  "11140": "ZIPCODE",
  "11150": "ZIPCODE",
  "12000": "ZIPCODE",
  "12110": "ZIPCODE",
  "12120": "ZIPCODE",
  "12130": "ZIPCODE",
  "12140": "ZIPCODE",
  "12150": "ZIPCODE",
  "12160": "ZIPCODE",
  "12170": "ZIPCODE",
  "13000": "ZIPCODE",
  "13110": "ZIPCODE",
  "13120": "ZIPCODE",
  "13130": "ZIPCODE",
  "13140": "ZIPCODE",
  "13150": "ZIPCODE",
  "13160": "ZIPCODE",
  "13170": "ZIPCODE",
  "13180": "ZIPCODE",
  "13190": "ZIPCODE",
  "13210": "ZIPCODE",
  "13220": "ZIPCODE",
  "13230": "ZIPCODE",
  "13240": "ZIPCODE",
  "13250": "ZIPCODE",
  "13260": "ZIPCODE",
  "13270": "ZIPCODE",
  "13280": "ZIPCODE",
  "13290": "ZIPCODE",
  "14000": "ZIPCODE",
  "14110": "ZIPCODE",
  "14120": "ZIPCODE",
  "14130": "ZIPCODE",
  "14140": "ZIPCODE",
  "14150": "ZIPCODE",
  "14160": "ZIPCODE",
  "15000": "ZIPCODE",
  "15110": "ZIPCODE",
  "15120": "ZIPCODE",
  "15130": "ZIPCODE",
  "15140": "ZIPCODE",
  "15150": "ZIPCODE",
  "15160": "ZIPCODE",
  "15170": "ZIPCODE",
  "15180": "ZIPCODE",
  "15190": "ZIPCODE",
  "15210": "ZIPCODE",
  "15220": "ZIPCODE",
  "15230": "ZIPCODE",
  "15240": "ZIPCODE",
  "15250": "ZIPCODE",
  "16000": "ZIPCODE",
  "16110": "ZIPCODE",
  "16120": "ZIPCODE",
  "16130": "ZIPCODE",
  "16140": "ZIPCODE",
  "16150": "ZIPCODE",
  "16160": "ZIPCODE",
  "17000": "ZIPCODE",
  "17110": "ZIPCODE",
  "17120": "ZIPCODE",
  "17130": "ZIPCODE",
  "17140": "ZIPCODE",
  "17150": "ZIPCODE",
  "17160": "ZIPCODE",
  "17170": "ZIPCODE",
  "18000": "ZIPCODE",
  "18110": "ZIPCODE",
  "18120": "ZIPCODE",
  "18130": "ZIPCODE",
  "18140": "ZIPCODE",
  "18150": "ZIPCODE",
  "18160": "ZIPCODE",
  "18170": "ZIPCODE",
  "18180": "ZIPCODE",
  "18190": "ZIPCODE",
  "18210": "ZIPCODE",
  "18220": "ZIPCODE",
  "18230": "ZIPCODE",
  "18240": "ZIPCODE",
  "18250": "ZIPCODE",
  "18260": "ZIPCODE",
  "18270": "ZIPCODE",
  "20000": "ZIPCODE",
  "20110": "ZIPCODE",
  "20120": "ZIPCODE",
  "20130": "ZIPCODE",
  "20131": "ZIPCODE",
  "20140": "ZIPCODE",
  "20150": "ZIPCODE",
  "20160": "ZIPCODE",
  "20170": "ZIPCODE",
  "20180": "ZIPCODE",
  "20182": "ZIPCODE",
  "20190": "ZIPCODE",
  "20220": "ZIPCODE",
  "20230": "ZIPCODE",
  "20240": "ZIPCODE",
  "20250": "ZIPCODE",
  "20251": "ZIPCODE",
  "20260": "ZIPCODE",
  "20270": "ZIPCODE",
  "21000": "ZIPCODE",
  "21100": "ZIPCODE",
  "21110": "ZIPCODE",
  "21120": "ZIPCODE",
  "21130": "ZIPCODE",
  "21140": "ZIPCODE",
  "21150": "ZIPCODE",
  "21160": "ZIPCODE",
  "21170": "ZIPCODE",
  "21180": "ZIPCODE",
  "21190": "ZIPCODE",
  "21210": "ZIPCODE",
  "22000": "ZIPCODE",
  "22110": "ZIPCODE",
  "22120": "ZIPCODE",
  "22130": "ZIPCODE",
  "22140": "ZIPCODE",
  "22150": "ZIPCODE",
  "22160": "ZIPCODE",
  "22170": "ZIPCODE",
  "22180": "ZIPCODE",
  "22190": "ZIPCODE",
  "22210": "ZIPCODE",
  "23000": "ZIPCODE",
  "23110": "ZIPCODE",
  "23120": "ZIPCODE",
  "23130": "ZIPCODE",
  "23140": "ZIPCODE",
  "23150": "ZIPCODE",
  "23170": "ZIPCODE",
  "24000": "ZIPCODE",
  "24110": "ZIPCODE",
  "24120": "ZIPCODE",
  "24130": "ZIPCODE",
  "24140": "ZIPCODE",
  "24150": "ZIPCODE",
  "24160": "ZIPCODE",
  "24170": "ZIPCODE",
  "24180": "ZIPCODE",
  "24190": "ZIPCODE",
  "25000": "ZIPCODE",
  "25110": "ZIPCODE",
  "25130": "ZIPCODE",
  "25140": "ZIPCODE",
  "25150": "ZIPCODE",
  "25190": "ZIPCODE",
  "25220": "ZIPCODE",
  "25230": "ZIPCODE",
  "25240": "ZIPCODE",
  "26000": "ZIPCODE",
  "26001": "ZIPCODE",
  "26110": "ZIPCODE",
  "26120": "ZIPCODE",
  "26130": "ZIPCODE",
  "27000": "ZIPCODE",
  "27120": "ZIPCODE",
  "27160": "ZIPCODE",
  "27180": "ZIPCODE",
  "27210": "ZIPCODE",
  "27250": "ZIPCODE",
  "27260": "ZIPCODE",
  "30000": "ZIPCODE",
  "30110": "ZIPCODE",
  "30120": "ZIPCODE",
  "30130": "ZIPCODE",
  "30140": "ZIPCODE",
  "30150": "ZIPCODE",
  "30160": "ZIPCODE",
  "30170": "ZIPCODE",
  "30180": "ZIPCODE",
  "30190": "ZIPCODE",
  "30210": "ZIPCODE",
  "30220": "ZIPCODE",
  "30230": "ZIPCODE",
  "30240": "ZIPCODE",
  "30250": "ZIPCODE",
  "30260": "ZIPCODE",
  "30270": "ZIPCODE",
  "30280": "ZIPCODE",
  "30290": "ZIPCODE",
  "30310": "ZIPCODE",
  "30320": "ZIPCODE",
  "30330": "ZIPCODE",
  "30340": "ZIPCODE",
  "30350": "ZIPCODE",
  "30360": "ZIPCODE",
  "30370": "ZIPCODE",
  "30380": "ZIPCODE",
  "30410": "ZIPCODE",
  "30420": "ZIPCODE",
  "30430": "ZIPCODE",
  "30440": "ZIPCODE",
  "30450": "ZIPCODE",
  "31000": "ZIPCODE",
  "31110": "ZIPCODE",
  "31120": "ZIPCODE",
  "31130": "ZIPCODE",
  "31140": "ZIPCODE",
  "31150": "ZIPCODE",
  "31160": "ZIPCODE",
  "31170": "ZIPCODE",
  "31180": "ZIPCODE",
  "31190": "ZIPCODE",
  "31210": "ZIPCODE",
  "31220": "ZIPCODE",
  "31230": "ZIPCODE",
  "31240": "ZIPCODE",
  "31250": "ZIPCODE",
  "31260": "ZIPCODE",
  "32000": "ZIPCODE",
  "32110": "ZIPCODE",
  "32120": "ZIPCODE",
  "32130": "ZIPCODE",
  "32140": "ZIPCODE",
  "32150": "ZIPCODE",
  "32160": "ZIPCODE",
  "32170": "ZIPCODE",
  "32180": "ZIPCODE",
  "32190": "ZIPCODE",
  "32210": "ZIPCODE",
  "32220": "ZIPCODE",
  "32230": "ZIPCODE",
  "33000": "ZIPCODE",
  "33110": "ZIPCODE",
  "33120": "ZIPCODE",
  "33130": "ZIPCODE",
  "33140": "ZIPCODE",
  "33150": "ZIPCODE",
  "33160": "ZIPCODE",
  "33170": "ZIPCODE",
  "33180": "ZIPCODE",
  "33190": "ZIPCODE",
  "33210": "ZIPCODE",
  "33220": "ZIPCODE",
  "33230": "ZIPCODE",
  "33240": "ZIPCODE",
  "33250": "ZIPCODE",
  "33270": "ZIPCODE",
  "34000": "ZIPCODE",
  "34002": "ZIPCODE",
  "34110": "ZIPCODE",
  "34130": "ZIPCODE",
  "34140": "ZIPCODE",
  "34150": "ZIPCODE",
  "34160": "ZIPCODE",
  "34170": "ZIPCODE",
  "34190": "ZIPCODE",
  "34220": "ZIPCODE",
  "34230": "ZIPCODE",
  "34250": "ZIPCODE",
  "34260": "ZIPCODE",
  "34270": "ZIPCODE",
  "34280": "ZIPCODE",
  "34310": "ZIPCODE",
  "34320": "ZIPCODE",
  "34330": "ZIPCODE",
  "34340": "ZIPCODE",
  "34350": "ZIPCODE",
  "34360": "ZIPCODE",
  "35000": "ZIPCODE",
  "35110": "ZIPCODE",
  "35120": "ZIPCODE",
  "35130": "ZIPCODE",
  "35140": "ZIPCODE",
  "35150": "ZIPCODE",
  "35160": "ZIPCODE",
  "35170": "ZIPCODE",
  "35180": "ZIPCODE",
  "36000": "ZIPCODE",
  "36110": "ZIPCODE",
  "36120": "ZIPCODE",
  "36130": "ZIPCODE",
  "36140": "ZIPCODE",
  "36150": "ZIPCODE",
  "36160": "ZIPCODE",
  "36170": "ZIPCODE",
  "36180": "ZIPCODE",
  "36190": "ZIPCODE",
  "36210": "ZIPCODE",
  "36220": "ZIPCODE",
  "36230": "ZIPCODE",
  "36240": "ZIPCODE",
  "36250": "ZIPCODE",
  "36260": "ZIPCODE",
  "37000": "ZIPCODE",
  "37110": "ZIPCODE",
  "37120": "ZIPCODE",
  "37180": "ZIPCODE",
  "37210": "ZIPCODE",
  "37240": "ZIPCODE",
  "37290": "ZIPCODE",
  "38000": "ZIPCODE",
  "38150": "ZIPCODE",
  "38170": "ZIPCODE",
  "38180": "ZIPCODE",
  "38190": "ZIPCODE",
  "38210": "ZIPCODE",
  "38220": "ZIPCODE",
  "39000": "ZIPCODE",
  "39140": "ZIPCODE",
  "39170": "ZIPCODE",
  "39180": "ZIPCODE",
  "39270": "ZIPCODE",
  "39350": "ZIPCODE",
  "40000": "ZIPCODE",
  "40002": "ZIPCODE",
  "40110": "ZIPCODE",
  "40120": "ZIPCODE",
  "40130": "ZIPCODE",
  "40140": "ZIPCODE",
  "40150": "ZIPCODE",
  "40160": "ZIPCODE",
  "40170": "ZIPCODE",
  "40180": "ZIPCODE",
  "40190": "ZIPCODE",
  "40210": "ZIPCODE",
  "40220": "ZIPCODE",
  "40230": "ZIPCODE",
  "40240": "ZIPCODE",
  "40250": "ZIPCODE",
  "40260": "ZIPCODE",
  "40270": "ZIPCODE",
  "40280": "ZIPCODE",
  "40290": "ZIPCODE",
  "40310": "ZIPCODE",
  "40320": "ZIPCODE",
  "40330": "ZIPCODE",
  "40340": "ZIPCODE",
  "40350": "ZIPCODE",
  "41000": "ZIPCODE",
  "41110": "ZIPCODE",
  "41130": "ZIPCODE",
  "41150": "ZIPCODE",
  "41160": "ZIPCODE",
  "41190": "ZIPCODE",
  "41210": "ZIPCODE",
  "41220": "ZIPCODE",
  "41230": "ZIPCODE",
  "41240": "ZIPCODE",
  "41250": "ZIPCODE",
  "41260": "ZIPCODE",
  "41280": "ZIPCODE",
  "41290": "ZIPCODE",
  "41310": "ZIPCODE",
  "41320": "ZIPCODE",
  "41330": "ZIPCODE",
  "41340": "ZIPCODE",
  "41360": "ZIPCODE",
  "41370": "ZIPCODE",
  "41380": "ZIPCODE",
  "42000": "ZIPCODE",
  "42100": "ZIPCODE",
  "42110": "ZIPCODE",
  "42120": "ZIPCODE",
  "42130": "ZIPCODE",
  "42140": "ZIPCODE",
  "42150": "ZIPCODE",
  "42160": "ZIPCODE",
  "42170": "ZIPCODE",
  "42180": "ZIPCODE",
  "42190": "ZIPCODE",
  "42210": "ZIPCODE",
  "42220": "ZIPCODE",
  "42230": "ZIPCODE",
  "42240": "ZIPCODE",
  "43000": "ZIPCODE",
  "43100": "ZIPCODE",
  "43110": "ZIPCODE",
  "43120": "ZIPCODE",
  "43130": "ZIPCODE",
  "43160": "ZIPCODE",
  "43230": "ZIPCODE",
  "44000": "ZIPCODE",
  "44110": "ZIPCODE",
  "44120": "ZIPCODE",
  "44130": "ZIPCODE",
  "44140": "ZIPCODE",
  "44150": "ZIPCODE",
  "44160": "ZIPCODE",
  "44170": "ZIPCODE",
  "44180": "ZIPCODE",
  "44190": "ZIPCODE",
  "44210": "ZIPCODE",
  "45000": "ZIPCODE",
  "45110": "ZIPCODE",
  "45120": "ZIPCODE",
  "45130": "ZIPCODE",
  "45140": "ZIPCODE",
  "45150": "ZIPCODE",
  "45160": "ZIPCODE",
  "45170": "ZIPCODE",
  "45180": "ZIPCODE",
  "45190": "ZIPCODE",
  "45210": "ZIPCODE",
  "45220": "ZIPCODE",
  "45230": "ZIPCODE",
  "45240": "ZIPCODE",
  "45250": "ZIPCODE",
  "45280": "ZIPCODE",
  "46000": "ZIPCODE",
  "46110": "ZIPCODE",
  "46120": "ZIPCODE",
  "46130": "ZIPCODE",
  "46140": "ZIPCODE",
  "46150": "ZIPCODE",
  "46160": "ZIPCODE",
  "46170": "ZIPCODE",
  "46180": "ZIPCODE",
  "46190": "ZIPCODE",
  "46210": "ZIPCODE",
  "46220": "ZIPCODE",
  "46230": "ZIPCODE",
  "46240": "ZIPCODE",
  "47000": "ZIPCODE",
  "47110": "ZIPCODE",
  "47120": "ZIPCODE",
  "47130": "ZIPCODE",
  "47140": "ZIPCODE",
  "47150": "ZIPCODE",
  "47160": "ZIPCODE",
  "47170": "ZIPCODE",
  "47180": "ZIPCODE",
  "47190": "ZIPCODE",
  "47210": "ZIPCODE",
  "47220": "ZIPCODE",
  "47230": "ZIPCODE",
  "47240": "ZIPCODE",
  "47250": "ZIPCODE",
  "47260": "ZIPCODE",
  "47270": "ZIPCODE",
  "47280": "ZIPCODE",
  "47290": "ZIPCODE",
  "48000": "ZIPCODE",
  "48110": "ZIPCODE",
  "48120": "ZIPCODE",
  "48130": "ZIPCODE",
  "48140": "ZIPCODE",
  "48150": "ZIPCODE",
  "48160": "ZIPCODE",
  "48170": "ZIPCODE",
  "48180": "ZIPCODE",
  "48190": "ZIPCODE",
  "49000": "ZIPCODE",
  "49110": "ZIPCODE",
  "49120": "ZIPCODE",
  "49130": "ZIPCODE",
  "49140": "ZIPCODE",
  "49150": "ZIPCODE",
  "49160": "ZIPCODE",
  "50000": "ZIPCODE",
  "50100": "ZIPCODE",
  "50110": "ZIPCODE",
  "50120": "ZIPCODE",
  "50130": "ZIPCODE",
  "50140": "ZIPCODE",
  "50150": "ZIPCODE",
  "50160": "ZIPCODE",
  "50170": "ZIPCODE",
  "50180": "ZIPCODE",
  "50190": "ZIPCODE",
  "50200": "ZIPCODE",
  "50210": "ZIPCODE",
  "50220": "ZIPCODE",
  "50230": "ZIPCODE",
  "50240": "ZIPCODE",
  "50250": "ZIPCODE",
  "50260": "ZIPCODE",
  "50270": "ZIPCODE",
  "50280": "ZIPCODE",
  "50290": "ZIPCODE",
  "50300": "ZIPCODE",
  "50310": "ZIPCODE",
  "50320": "ZIPCODE",
  "50330": "ZIPCODE",
  "50340": "ZIPCODE",
  "50350": "ZIPCODE",
  "50360": "ZIPCODE",
  "51000": "ZIPCODE",
  "51110": "ZIPCODE",
  "51120": "ZIPCODE",
  "51130": "ZIPCODE",
  "51140": "ZIPCODE",
  "51150": "ZIPCODE",
  "51160": "ZIPCODE",
  "51170": "ZIPCODE",
  "51180": "ZIPCODE",
  "52000": "ZIPCODE",
  "52100": "ZIPCODE",
  "52110": "ZIPCODE",
  "52120": "ZIPCODE",
  "52130": "ZIPCODE",
  "52140": "ZIPCODE",
  "52150": "ZIPCODE",
  "52160": "ZIPCODE",
  "52170": "ZIPCODE",
  "52180": "ZIPCODE",
  "52190": "ZIPCODE",
  "52210": "ZIPCODE",
  "52220": "ZIPCODE",
  "52230": "ZIPCODE",
  "52240": "ZIPCODE",
  "53000": "ZIPCODE",
  "53110": "ZIPCODE",
  "53120": "ZIPCODE",
  "53130": "ZIPCODE",
  "53140": "ZIPCODE",
  "53150": "ZIPCODE",
  "53160": "ZIPCODE",
  "53170": "ZIPCODE",
  "53180": "ZIPCODE",
  "53190": "ZIPCODE",
  "53210": "ZIPCODE",
  "53220": "ZIPCODE",
  "53230": "ZIPCODE",
  "54000": "ZIPCODE",
  "54110": "ZIPCODE",
  "54120": "ZIPCODE",
  "54130": "ZIPCODE",
  "54140": "ZIPCODE",
  "54150": "ZIPCODE",
  "54160": "ZIPCODE",
  "54170": "ZIPCODE",
  "55000": "ZIPCODE",
  "55110": "ZIPCODE",
  "55120": "ZIPCODE",
  "55130": "ZIPCODE",
  "55140": "ZIPCODE",
  "55150": "ZIPCODE",
  "55160": "ZIPCODE",
  "55170": "ZIPCODE",
  "55180": "ZIPCODE",
  "55190": "ZIPCODE",
  "55210": "ZIPCODE",
  "55220": "ZIPCODE",
  "56000": "ZIPCODE",
  "56110": "ZIPCODE",
  "56120": "ZIPCODE",
  "56130": "ZIPCODE",
  "56140": "ZIPCODE",
  "56150": "ZIPCODE",
  "56160": "ZIPCODE",
  "57000": "ZIPCODE",
  "57100": "ZIPCODE",
  "57110": "ZIPCODE",
  "57120": "ZIPCODE",
  "57130": "ZIPCODE",
  "57140": "ZIPCODE",
  "57150": "ZIPCODE",
  "57160": "ZIPCODE",
  "57170": "ZIPCODE",
  "57180": "ZIPCODE",
  "57190": "ZIPCODE",
  "57210": "ZIPCODE",
  "57220": "ZIPCODE",
  "57230": "ZIPCODE",
  "57240": "ZIPCODE",
  "57250": "ZIPCODE",
  "57260": "ZIPCODE",
  "57270": "ZIPCODE",
  "57280": "ZIPCODE",
  "57290": "ZIPCODE",
  "57310": "ZIPCODE",
  "57340": "ZIPCODE",
  "58000": "ZIPCODE",
  "58110": "ZIPCODE",
  "58120": "ZIPCODE",
  "58130": "ZIPCODE",
  "58140": "ZIPCODE",
  "58150": "ZIPCODE",
  "60000": "ZIPCODE",
  "60110": "ZIPCODE",
  "60120": "ZIPCODE",
  "60130": "ZIPCODE",
  "60140": "ZIPCODE",
  "60150": "ZIPCODE",
  "60160": "ZIPCODE",
  "60170": "ZIPCODE",
  "60180": "ZIPCODE",
  "60190": "ZIPCODE",
  "60210": "ZIPCODE",
  "60220": "ZIPCODE",
  "60230": "ZIPCODE",
  "60240": "ZIPCODE",
  "60250": "ZIPCODE",
  "60260": "ZIPCODE",
  "61000": "ZIPCODE",
  "61110": "ZIPCODE",
  "61120": "ZIPCODE",
  "61130": "ZIPCODE",
  "61140": "ZIPCODE",
  "61150": "ZIPCODE",
  "61160": "ZIPCODE",
  "61170": "ZIPCODE",
  "61180": "ZIPCODE",
  "62000": "ZIPCODE",
  "62110": "ZIPCODE",
  "62120": "ZIPCODE",
  "62130": "ZIPCODE",
  "62140": "ZIPCODE",
  "62150": "ZIPCODE",
  "62160": "ZIPCODE",
  "62170": "ZIPCODE",
  "62180": "ZIPCODE",
  "62190": "ZIPCODE",
  "62210": "ZIPCODE",
  "63000": "ZIPCODE",
  "63110": "ZIPCODE",
  "63120": "ZIPCODE",
  "63130": "ZIPCODE",
  "63140": "ZIPCODE",
  "63150": "ZIPCODE",
  "63160": "ZIPCODE",
  "63170": "ZIPCODE",
  "63180": "ZIPCODE",
  "64000": "ZIPCODE",
  "64110": "ZIPCODE",
  "64120": "ZIPCODE",
  "64130": "ZIPCODE",
  "64140": "ZIPCODE",
  "64150": "ZIPCODE",
  "64160": "ZIPCODE",
  "64170": "ZIPCODE",
  "64180": "ZIPCODE",
  "64190": "ZIPCODE",
  "64210": "ZIPCODE",
  "64220": "ZIPCODE",
  "64230": "ZIPCODE",
  "65000": "ZIPCODE",
  "65110": "ZIPCODE",
  "65120": "ZIPCODE",
  "65130": "ZIPCODE",
  "65140": "ZIPCODE",
  "65150": "ZIPCODE",
  "65160": "ZIPCODE",
  "65170": "ZIPCODE",
  "65180": "ZIPCODE",
  "65190": "ZIPCODE",
  "65210": "ZIPCODE",
  "65220": "ZIPCODE",
  "65230": "ZIPCODE",
  "65240": "ZIPCODE",
  "66000": "ZIPCODE",
  "66110": "ZIPCODE",
  "66120": "ZIPCODE",
  "66130": "ZIPCODE",
  "66140": "ZIPCODE",
  "66150": "ZIPCODE",
  "66160": "ZIPCODE",
  "66170": "ZIPCODE",
  "66180": "ZIPCODE",
  "66190": "ZIPCODE",
  "66210": "ZIPCODE",
  "66220": "ZIPCODE",
  "66230": "ZIPCODE",
  "67000": "ZIPCODE",
  "67110": "ZIPCODE",
  "67120": "ZIPCODE",
  "67130": "ZIPCODE",
  "67140": "ZIPCODE",
  "67150": "ZIPCODE",
  "67160": "ZIPCODE",
  "67170": "ZIPCODE",
  "67180": "ZIPCODE",
  "67190": "ZIPCODE",
  "67210": "ZIPCODE",
  "67220": "ZIPCODE",
  "67230": "ZIPCODE",
  "67240": "ZIPCODE",
  "67250": "ZIPCODE",
  "67260": "ZIPCODE",
  "67270": "ZIPCODE",
  "67280": "ZIPCODE",
  "70000": "ZIPCODE",
  "70110": "ZIPCODE",
  "70120": "ZIPCODE",
  "70130": "ZIPCODE",
  "70140": "ZIPCODE",
  "70150": "ZIPCODE",
  "70160": "ZIPCODE",
  "70170": "ZIPCODE",
  "70180": "ZIPCODE",
  "70190": "ZIPCODE",
  "70210": "ZIPCODE",
  "71000": "ZIPCODE",
  "71110": "ZIPCODE",
  "71120": "ZIPCODE",
  "71130": "ZIPCODE",
  "71140": "ZIPCODE",
  "71150": "ZIPCODE",
  "71160": "ZIPCODE",
  "71170": "ZIPCODE",
  "71180": "ZIPCODE",
  "71190": "ZIPCODE",
  "71210": "ZIPCODE",
  "71220": "ZIPCODE",
  "71240": "ZIPCODE",
  "71250": "ZIPCODE",
  "71260": "ZIPCODE",
  "72000": "ZIPCODE",
  "72110": "ZIPCODE",
  "72120": "ZIPCODE",
  "72130": "ZIPCODE",
  "72140": "ZIPCODE",
  "72150": "ZIPCODE",
  "72160": "ZIPCODE",
  "72170": "ZIPCODE",
  "72180": "ZIPCODE",
  "72190": "ZIPCODE",
  "72210": "ZIPCODE",
  "72220": "ZIPCODE",
  "72230": "ZIPCODE",
  "72240": "ZIPCODE",
  "72250": "ZIPCODE",
  "73000": "ZIPCODE",
  "73110": "ZIPCODE",
  "73120": "ZIPCODE",
  "73130": "ZIPCODE",
  "73140": "ZIPCODE",
  "73150": "ZIPCODE",
  "73160": "ZIPCODE",
  "73170": "ZIPCODE",
  "73180": "ZIPCODE",
  "73190": "ZIPCODE",
  "73210": "ZIPCODE",
  "73220": "ZIPCODE",
  "74000": "ZIPCODE",
  "74110": "ZIPCODE",
  "74120": "ZIPCODE",
  "74130": "ZIPCODE",
  "75000": "ZIPCODE",
  "75110": "ZIPCODE",
  "75120": "ZIPCODE",
  "76000": "ZIPCODE",
  "76100": "ZIPCODE",
  "76110": "ZIPCODE",
  "76120": "ZIPCODE",
  "76130": "ZIPCODE",
  "76140": "ZIPCODE",
  "76150": "ZIPCODE",
  "76160": "ZIPCODE",
  "76170": "ZIPCODE",
  "77000": "ZIPCODE",
  "77110": "ZIPCODE",
  "77120": "ZIPCODE",
  "77130": "ZIPCODE",
  "77140": "ZIPCODE",
  "77150": "ZIPCODE",
  "77160": "ZIPCODE",
  "77170": "ZIPCODE",
  "77180": "ZIPCODE",
  "77190": "ZIPCODE",
  "77210": "ZIPCODE",
  "77220": "ZIPCODE",
  "77230": "ZIPCODE",
  "80000": "ZIPCODE",
  "80110": "ZIPCODE",
  "80120": "ZIPCODE",
  "80130": "ZIPCODE",
  "80140": "ZIPCODE",
  "80150": "ZIPCODE",
  "80160": "ZIPCODE",
  "80170": "ZIPCODE",
  "80180": "ZIPCODE",
  "80190": "ZIPCODE",
  "80210": "ZIPCODE",
  "80220": "ZIPCODE",
  "80230": "ZIPCODE",
  "80240": "ZIPCODE",
  "80250": "ZIPCODE",
  "80260": "ZIPCODE",
  "80270": "ZIPCODE",
  "80280": "ZIPCODE",
  "80290": "ZIPCODE",
  "80310": "ZIPCODE",
  "80320": "ZIPCODE",
  "80330": "ZIPCODE",
  "80340": "ZIPCODE",
  "80350": "ZIPCODE",
  "80360": "ZIPCODE",
  "80370": "ZIPCODE",
  "81000": "ZIPCODE",
  "81110": "ZIPCODE",
  "81120": "ZIPCODE",
  "81130": "ZIPCODE",
  "81140": "ZIPCODE",
  "81150": "ZIPCODE",
  "81160": "ZIPCODE",
  "81170": "ZIPCODE",
  "81180": "ZIPCODE",
  "81190": "ZIPCODE",
  "81210": "ZIPCODE",
  "82000": "ZIPCODE",
  "82110": "ZIPCODE",
  "82120": "ZIPCODE",
  "82130": "ZIPCODE",
  "82140": "ZIPCODE",
  "82150": "ZIPCODE",
  "82160": "ZIPCODE",
  "82170": "ZIPCODE",
  "82180": "ZIPCODE",
  "82190": "ZIPCODE",
  "82210": "ZIPCODE",
  "82220": "ZIPCODE",
  "83000": "ZIPCODE",
  "83100": "ZIPCODE",
  "83110": "ZIPCODE",
  "83120": "ZIPCODE",
  "83130": "ZIPCODE",
  "83150": "ZIPCODE",
  "83151": "ZIPCODE",
  "84000": "ZIPCODE",
  "84100": "ZIPCODE",
  "84110": "ZIPCODE",
  "84120": "ZIPCODE",
  "84130": "ZIPCODE",
  "84140": "ZIPCODE",
  "84150": "ZIPCODE",
  "84160": "ZIPCODE",
  "84170": "ZIPCODE",
  "84180": "ZIPCODE",
  "84190": "ZIPCODE",
  "84210": "ZIPCODE",
  "84220": "ZIPCODE",
  "84230": "ZIPCODE",
  "84240": "ZIPCODE",
  "84250": "ZIPCODE",
  "84260": "ZIPCODE",
  "84270": "ZIPCODE",
  "84280": "ZIPCODE",
  "84290": "ZIPCODE",
  "84310": "ZIPCODE",
  "84320": "ZIPCODE",
  "84330": "ZIPCODE",
  "84340": "ZIPCODE",
  "84350": "ZIPCODE",
  "84360": "ZIPCODE",
  "84370": "ZIPCODE",
  "85000": "ZIPCODE",
  "85110": "ZIPCODE",
  "85120": "ZIPCODE",
  "85130": "ZIPCODE",
  "86000": "ZIPCODE",
  "86010": "ZIPCODE",
  "86100": "ZIPCODE",
  "86110": "ZIPCODE",
  "86120": "ZIPCODE",
  "86130": "ZIPCODE",
  "86140": "ZIPCODE",
  "86150": "ZIPCODE",
  "86160": "ZIPCODE",
  "86170": "ZIPCODE",
  "86180": "ZIPCODE",
  "86190": "ZIPCODE",
  "86210": "ZIPCODE",
  "86220": "ZIPCODE",
  "86230": "ZIPCODE",
  "90000": "ZIPCODE",
  "90100": "ZIPCODE",
  "90110": "ZIPCODE",
  "90115": "ZIPCODE",
  "90120": "ZIPCODE",
  "90130": "ZIPCODE",
  "90140": "ZIPCODE",
  "90150": "ZIPCODE",
  "90160": "ZIPCODE",
  "90170": "ZIPCODE",
  "90180": "ZIPCODE",
  "90190": "ZIPCODE",
  "90210": "ZIPCODE",
  "90220": "ZIPCODE",
  "90230": "ZIPCODE",
  "90240": "ZIPCODE",
  "90250": "ZIPCODE",
  "90260": "ZIPCODE",
  "90270": "ZIPCODE",
  "90280": "ZIPCODE",
  "90310": "ZIPCODE",
  "90320": "ZIPCODE",
  "90330": "ZIPCODE",
  "91000": "ZIPCODE",
  "91110": "ZIPCODE",
  "91120": "ZIPCODE",
  "91130": "ZIPCODE",
  "91140": "ZIPCODE",
  "91150": "ZIPCODE",
  "91160": "ZIPCODE",
  "92000": "ZIPCODE",
  "92110": "ZIPCODE",
  "92120": "ZIPCODE",
  "92130": "ZIPCODE",
  "92140": "ZIPCODE",
  "92150": "ZIPCODE",
  "92160": "ZIPCODE",
  "92170": "ZIPCODE",
  "92180": "ZIPCODE",
  "92190": "ZIPCODE",
  "92210": "ZIPCODE",
  "92220": "ZIPCODE",
  "93000": "ZIPCODE",
  "93110": "ZIPCODE",
  "93120": "ZIPCODE",
  "93130": "ZIPCODE",
  "93140": "ZIPCODE",
  "93150": "ZIPCODE",
  "93160": "ZIPCODE",
  "93170": "ZIPCODE",
  "93180": "ZIPCODE",
  "93190": "ZIPCODE",
  "93210": "ZIPCODE",
  "94000": "ZIPCODE",
  "94110": "ZIPCODE",
  "94120": "ZIPCODE",
  "94130": "ZIPCODE",
  "94140": "ZIPCODE",
  "94150": "ZIPCODE",
  "94160": "ZIPCODE",
  "94170": "ZIPCODE",
  "94180": "ZIPCODE",
  "94190": "ZIPCODE",
  "94220": "ZIPCODE",
  "94230": "ZIPCODE",
  "95000": "ZIPCODE",
  "95110": "ZIPCODE",
  "95120": "ZIPCODE",
  "95130": "ZIPCODE",
  "95140": "ZIPCODE",
  "95150": "ZIPCODE",
  "95160": "ZIPCODE",
  "95170": "ZIPCODE",
  "96000": "ZIPCODE",
  "96110": "ZIPCODE",
  "96120": "ZIPCODE",
  "96130": "ZIPCODE",
  "96140": "ZIPCODE",
  "96150": "ZIPCODE",
  "96160": "ZIPCODE",
  "96170": "ZIPCODE",
  "96180": "ZIPCODE",
  "96190": "ZIPCODE",
  "96210": "ZIPCODE",
  "96220": "ZIPCODE",
  }

# %% [markdown]
# # Address List

# %%
address_list = {
    "กระบี่": {
        "เมืองกระบี่": [
            ("กระบี่น้อย", "81000"),
            ("เขาทอง", "81000"),
            ("ทับปริก", "81000"),
            ("อ่าวนาง", "81000"),
            ("หนองทะเล", "81000"),
            ("หนองทะเล", "81180"),
        ],
        "เขาพนม": [
            ("เขาพนม", "81140"),
            ("พรุเตียว", "81140"),
            ("หน้าเขา", "81140"),
            ("โคกหาร", "80240"),
        ],
        "เกาะลันตา": [
            ("เกาะกลาง", "81120"),
            ("ศาลาด่าน", "81150"),
        ],
        "คลองท่อม": [
            ("คลองท่อมเหนือ", "81120"),
            ("คลองพน", "81170"),
            ("ห้วยน้ำขาว", "81120"),
            ("เพหลา", "81120"),
        ],
        "อ่าวลึก": [
            ("แหลมสัก", "81110"),
            ("นาเหนือ", "81110"),
        ],
        "ปลายพระยา": [
            ("ปลายพระยา", "81160"),
            ("เขาเขน", "81160"),
            ("เขาต่อ", "81160"),
            ("คีรีวง", "81160"),
        ],
        "ลำทับ": [
            ("ลำทับ", "81190"),
            ("ดินอุดม", "81120"),
            ("ดินแดง", "81120"),
        ],
        "เหนือคลอง": [
            ("เหนือคลอง", "81130"),
            ("คลองเขม้า", "81130"),
            ("โคกยาง", "81130"),
            ("ห้วยยูง", "81130"),
        ],
        "เมืองกระบี่": [
            ("ปากน้ำ", "81000"),
            ("กระบี่ใหญ่", "81000"),
            ("เขาคราม", "81000"),
            ("ไสไทย", "81000"),
            ("อ่าวนาง", "81180"),
            ("อ่าวนาง", "81210"),
            ("คลองประสงค์", "81000"),
        ],
        "เขาพนม": [
            ("เขาดิน", "81140"),
            ("สินปุน", "80240"),
            ("พรุเตียว", "80240"),
            ("หน้าเขา", "80240"),
        ],
        "เกาะลันตา": [
            ("เกาะลันตาใหญ่", "81150"),
            ("เกาะลันตาน้อย", "81150"),
            ("คลองยาง", "81120"),
        ],
        "คลองท่อม": [
            ("คลองท่อมใต้", "81120"),
            ("ทรายขาว", "81170"),
            ("พรุดินนา", "81120"),
        ],
        "อ่าวลึก": [
            ("อ่าวลึกใต้", "81110"),
            ("คลองหิน", "81110"),
            ("อ่าวลึกน้อย", "81110"),
            ("อ่าวลึกเหนือ", "81110"),
            ("เขาใหญ่", "81110"),
            ("คลองยา", "81110"),
            ("บ้านกลาง", "81110"),
        ],
        "ลำทับ": [
            ("ทุ่งไทรทอง", "81120"),
        ],
        "เหนือคลอง": [
            ("เกาะศรีบอยา", "81130"),
            ("คลองขนาน", "81130"),
            ("ตลิ่งชัน", "81130"),
            ("ปกาสัย", "81130"),
        ]},
    "กรุงเทพ": {
        "คลองเตย": [
            ("คลองเตย", "10110"),
            ("พระโขนง", "10260"),
        ],
        "คลองสาน": [
            ("คลองสาน", "10600"),
            ("บางลำภูล่าง", "10600"),
            ("สมเด็จเจ้าพระยา", "10600"),
        ],
        "คลองสามวา": [
            ("ทรายกองดิน", "10510"),
            ("ทรายกองดินใต้", "10510"),
            ("บางชัน", "10510"),
            ("สามวาตะวันตก", "10510"),
            ("สามวาตะวันออก", "10510"),
        ],
        "คันนายาว": [
            ("รามอินทรา", "10230"),
        ],
        "จตุจักร": [
            ("จตุจักร", "10900"),
            ("จอมพล", "10900"),
            ("เสนานิคม", "10900"),
        ],
        "จอมทอง": [
            ("จอมทอง", "10150"),
            ("บางค้อ", "10150"),
        ],
        "ดอนเมือง": [
            ("สีกัน", "10210"),
        ],
        "ดินแดง": [
            ("ดินแดง", "10400"),
            ("รัชดาภิเษก", "10400"),
        ],
        "ดุสิต": [
            ("ถนนนครไชยศรี", "10300"),
            ("สวนจิตรลดา", "10303"),
        ],
        "ตลิ่งชัน": [
            ("คลองชักพระ", "10170"),
            ("ฉิมพลี", "10170"),
            ("ตลิ่งชัน", "10170"),
            ("บางเชือกหนัง", "10170"),
            ("บางพรม", "10170"),
        ],
        "ทวีวัฒนา": [
            ("ทวีวัฒนา", "10170"),
            ("ศาลาธรรมสพน์", "10170"),
        ],
        "ธนบุรี": [
            ("บางยี่เรือ", "10600"),
            ("บุคคโล", "10600"),
        ],
        "บางกอกน้อย": [
            ("บางขุนนนท์", "10700"),
            ("บ้านช่างหล่อ", "10700"),
        ],
        "บางกะปิ": [
            ("คลองจั่น", "10240"),
            ("หัวหมาก", "10243"),
        ],
        "บางขุนเทียน": [
            ("แสมดำ", "10150"),
        ],
        "บางเขน": [
            ("อนุสาวรีย์", "10220"),
        ],
        "บางคอแหลม": [
            ("บางคอแหลม", "10120"),
        ],
        "บางแค": [
            ("บางไผ่", "10160"),
            ("หลักสอง", "10160"),
        ],
        "บางซื่อ": [
            ("บางซื่อ", "10800"),
        ],
        "บางนา": [
            ("บางนา", "10260"),
            ("บางนาใต้", "10260"),
        ],
        "บางบอน": [
            ("บางบอน", "10150"),
            ("บางบอนเหนือ", "10150"),
            ("คลองบางบอน", "10150"),
        ],
        "บางพลัด": [
            ("บางยี่ขัน", "10700"),
            ("บางอ้อ", "10700"),
        ],
        "บางรัก": [
            ("สี่พระยา", "10500"),
            ("สีลม", "10500"),
            ("สุริยวงศ์", "10500"),
        ],
        "บึงกุ่ม": [
            ("คลองกุ่ม", "10240"),
            ("นวลจันทร์", "10230"),
            ("นวมินทร์", "10240"),
        ],
        "ปทุมวัน": [
            ("ปทุมวัน", "10330"),
            ("วังใหม่", "10120"),
            ("วังใหม่", "10330"),
            ("วังใหม่", "10400"),
        ],
        "ประเวศ": [
            ("ดอกไม้", "10250"),
            ("ประเวศ", "10250"),
            ("หนองบอน", "10250"),
        ],
        "ป้อมปราบศัตรูพ่าย": [
            ("คลองมหานาค", "10100"),
            ("บ้านบาตร", "10100"),
            ("วัดเทพศิรินทร์", "10100"),
            ("วัดโสมนัส", "10100"),
        ],
        "พญาไท": [
            ("พญาไท", "10400"),
        ],
        "พระนคร": [
            ("พระบรมมหาราชวัง", "10200"),
            ("วัดราชบพิธ", "10200"),
            ("สำราญราษฎร์", "10200"),
        ],
        "ภาษีเจริญ": [
            ("ปากคลองภาษีเจริญ", "10160"),
        ],
        "มีนบุรี": [
            ("แสนแสบ", "10510"),
        ],
        "ราชเทวี": [
            ("ถนนพญาไท", "10400"),
        ],
        "ราษฎร์บูรณะ": [
            ("ราษฎร์บูรณะ", "10140"),
        ],
        "ลาดกระบัง": [
            ("ขุมทอง", "10520"),
            ("คลองสองต้นนุ่น", "10520"),
            ("ทับยาว", "10520"),
            ("คลองสามประเวศ", "10520"),
        ],
        "ลาดพร้าว": [
            ("จรเข้บัว", "10230"),
            ("ลาดพร้าว", "10230"),
        ],
        "วังทองหลาง": [
            ("คลองเจ้าคุณสิงห์", "10310"),
            ("สะพานสอง", "10310"),
        ],
        "วัฒนา": [
            ("คลองเตยเหนือ", "10110"),
            ("พระโขนงเหนือ", "10260"),
        ],
        "สวนหลวง": [
            ("พัฒนาการ", "10250"),
            ("อ่อนนุช", "10250"),
        ],
        "สะพานสูง": [
            ("สะพานสูง", "10240"),
            ("ทับช้าง", "10250"),
        ],
        "สัมพันธวงศ์": [
            ("จักรวรรดิ์", "10100"),
            ("ตลาดน้อย", "10100"),
            ("สัมพันธวงศ์", "10100"),
        ],
        "สาทร": [
            ("ยานนาวา", "10120"),
        ],
        "สายไหม": [
            ("ออเงิน", "10220"),
        ],
        "หนองแขม": [
            ("หนองแขม", "10160"),
        ],
        "หนองจอก": [
            ("คลองสิบ", "10530"),
            ("คลองสิบสอง", "10530"),
            ("คู้ฝั่งเหนือ", "10530"),
            ("โคกแฝด", "10530"),
            ("ลำต้อยติ่ง", "10530"),
        ],
        "หลักสี่": [
            ("ตลาดบางเขน", "10210"),
            ("ทุ่งสองห้อง", "10020"),
        ],
        "ห้วยขวาง": [
            ("บางกะปิ", "10310"),
            ("สามเสนนอก", "10310"),
        ],
        "คลองเตย": [
            ("คลองตัน", "10110"),
            ("พระโขนง", "10110"),
        ],
        "คลองสาน": [
            ("คลองต้นไทร", "10600"),
        ],
        "คันนายาว": [
            ("คันนายาว", "10230"),
        ],
        "จตุจักร": [
            ("จันทรเกษม", "10900"),
            ("ลาดยาว", "10900"),
        ],
        "จอมทอง": [
            ("บางขุนเทียน", "10150"),
            ("บางมด", "10150"),
        ],
        "ดอนเมือง": [
            ("ดอนเมือง", "10210"),
            ("สนามบิน", "10210"),
        ],
        "ดุสิต": [
            ("ดุสิต", "10300"),
            ("วชิรพยาบาล", "10300"),
            ("สวนจิตรลดา", "10300"),
            ("สี่แยกมหานาค", "10300"),
        ],
        "ตลิ่งชัน": [
            ("บางระมาด", "10170"),
        ],
        "ทุ่งครุ": [
            ("ทุ่งครุ", "10140"),
            ("บางมด", "10140"),
        ],
        "ธนบุรี": [
            ("ดาวคะนอง", "10600"),
            ("ตลาดพลู", "10600"),
            ("วัดกัลยาณ์", "10600"),
            ("สำเหร่", "10600"),
            ("หิรัญรูจี", "10600"),
        ],
        "บางกอกน้อย": [
            ("บางขุนศรี", "10700"),
            ("ศิริราช", "10700"),
            ("ศิริราช", "10702"),
            ("อรุณอมรินทร์", "10700"),
        ],
        "บางกอกใหญ่": [
            ("วัดท่าพระ", "10600"),
            ("วัดอรุณ", "10600"),
        ],
        "บางกะปิ": [
            ("หัวหมาก", "10240"),
            ("หัวหมาก", "10250"),
        ],
        "บางขุนเทียน": [
            ("ท่าข้าม", "10150"),
        ],
        "บางเขน": [
            ("ท่าแร้ง", "10220"),
            ("ท่าแร้ง", "10230"),
        ],
        "บางคอแหลม": [
            ("บางโคล่", "10120"),
            ("วัดพระยาไกร", "10120"),
        ],
        "บางแค": [
            ("บางแค", "10160"),
            ("บางแคเหนือ", "10160"),
        ],
        "บางซื่อ": [
            ("วงศ์สว่าง", "10800"),
        ],
        "บางนา": [
            ("บางนาเหนือ", "10260"),
        ],
        "บางบอน": [
            ("คลองบางพราน", "10150"),
            ("บางบอนใต้", "10150"),
        ],
        "บางพลัด": [
            ("บางบำหรุ", "10700"),
            ("บางพลัด", "10700"),
        ],
        "บางรัก": [
            ("บางรัก", "10500"),
            ("บางรัก", "10501"),
            ("มหาพฤฒาราม", "10500"),
        ],
        "บึงกุ่ม": [
            ("คลองกุ่ม", "10230"),
            ("นวมินทร์", "10230"),
        ],
        "ปทุมวัน": [
            ("รองเมือง", "10330"),
            ("ลุมพินี", "10330"),
            ("วังใหม่", "10110"),
            ("วังใหม่", "10500"),
        ],
        "ป้อมปราบศัตรูพ่าย": [
            ("ป้อมปราบ", "10100"),
        ],
        "พญาไท": [
            ("สามเสนใน", "10400"),
        ],
        "พระโขนง": [
            ("บางจาก", "10260"),
        ],
        "พระนคร": [
            ("ชนะสงคราม", "10200"),
            ("ตลาดยอด", "10200"),
            ("บวรนิเวศ", "10200"),
            ("บางขุนพรหม", "10200"),
            ("บ้านพานถม", "10200"),
            ("วังบูรพาภิรมย์", "10200"),
            ("วัดสามพระยา", "10200"),
            ("ศาลเจ้าพ่อเสือ", "10200"),
            ("เสาชิงช้า", "10200"),
        ],
        "ภาษีเจริญ": [
            ("คลองขวาง", "10160"),
            ("คูหาสวรรค์", "10160"),
            ("บางจาก", "10160"),
            ("บางด้วน", "10160"),
            ("บางแวก", "10160"),
            ("บางหว้า", "10160"),
        ],
        "มีนบุรี": [
            ("มีนบุรี", "10510"),
        ],
        "ยานนาวา": [
            ("ช่องนนทรี", "10120"),
            ("บางโพงพาง", "10120"),
        ],
        "ราชเทวี": [
            ("ถนนเพชรบุรี", "10400"),
            ("ทุ่งพญาไท", "10400"),
            ("มักกะสัน", "10400"),
        ],
        "ราษฎร์บูรณะ": [
            ("บางปะกอก", "10140"),
        ],
        "ลาดกระบัง": [
            ("ลาดกระบัง", "10520"),
            ("ลำปลาทิว", "10520"),
        ],
        "วังทองหลาง": [
            ("พลับพลา", "10310"),
            ("วังทองหลาง", "10310"),
        ],
        "วัฒนา": [
            ("คลองตันเหนือ", "10110"),
            ("พระโขนงเหนือ", "10110"),
        ],
        "สวนหลวง": [
            ("สวนหลวง", "10250"),
        ],
        "สะพานสูง": [
            ("สะพานสูง", "10250"),
            ("ราษฎร์พัฒนา", "10240"),
        ],
        "สาทร": [
            ("ทุ่งมหาเมฆ", "10120"),
            ("ทุ่งวัดดอน", "10120"),
        ],
        "สายไหม": [
            ("คลองถนน", "10220"),
            ("สายไหม", "10220"),
        ],
        "หนองแขม": [
            ("หนองค้างพลู", "10160"),
        ],
        "หนองจอก": [
            ("กระทุ่มราย", "10530"),
            ("ลำผักชี", "10530"),
            ("หนองจอก", "10530"),
        ],
        "หลักสี่": [
            ("ทุ่งสองห้อง", "10010"),
            ("ทุ่งสองห้อง", "10210"),
        ],
        "ห้วยขวาง": [
            ("ห้วยขวาง", "10310"),
            ("ห้วยขวาง", "10320"),
        ]},
    "กาญจนบุรี": {
        "ด่านมะขามเตี้ย": [
            ("กลอนโด", "71260"),
        ],
        "ทองผาภูมิ": [
            ("ชะแล", "71180"),
            ("ท่าขนุน", "71180"),
            ("หินดาด", "71180"),
        ],
        "ท่าม่วง": [
            ("ท่าตะคร้อ", "71130"),
            ("ท่าล้อ", "71000"),
            ("บ้านใหม่", "71110"),
            ("หนองขาว", "71110"),
            ("หนองตากยา", "71110"),
        ],
        "ท่ามะกา": [
            ("โคกตะบอง", "71120"),
            ("ตะคร้ำเอน", "71130"),
            ("ท่าไม้", "71120"),
            ("ท่าเสา", "71120"),
            ("พงตึก", "71120"),
            ("สนามแย้", "70190"),
            ("แสนตอ", "71130"),
            ("หวายเหนียว", "71120"),
        ],
        "ไทรโยค": [
            ("ไทรโยค", "71150"),
            ("วังกระแจะ", "71150"),
        ],
        "บ่อพลอย": [
            ("ช่องด่าน", "71160"),
            ("บ่อพลอย", "71160"),
            ("หนองกร่าง", "71220"),
            ("หลุมรัง", "71160"),
        ],
        "พนมทวน": [
            ("ดอนเจดีย์", "71140"),
            ("ทุ่งสมอ", "71140"),
        ],
        "เมืองกาญจนบุรี": [
            ("แก่งเสี้ยน", "71000"),
            ("บ้านใต้", "71000"),
            ("บ้านเหนือ", "71000"),
            ("ลาดหญ้า", "71190"),
            ("วังเย็น", "71000"),
            ("หนองบัว", "71190"),
        ],
        "เลาขวัญ": [
            ("ทุ่งกระบ่ำ", "71210"),
            ("หนองนกแก้ว", "71210"),
            ("หนองฝ้าย", "71210"),
            ("หนองโสน", "71210"),
        ],
        "ศรีสวัสดิ์": [
            ("ท่ากระดาน", "71250"),
            ("แม่กระบุง", "71250"),
            ("หนองเป็ด", "71250"),
        ],
        "สังขละบุรี": [
            ("ปรังเผล", "71240"),
            ("ไล่โว่", "71240"),
        ],
        "หนองปรือ": [
            ("สมเด็จเจริญ", "71220"),
            ("หนองปรือ", "71220"),
        ],
        "ห้วยกระเจา": [
            ("ดอนแสลบ", "71170"),
            ("วังไผ่", "71170"),
            ("สระลงเรือ", "71170"),
        ],
        "ด่านมะขามเตี้ย": [
            ("จรเข้เผือก", "71260"),
            ("ด่านมะขามเตี้ย", "71260"),
            ("หนองไผ่", "71260"),
        ],
        "ทองผาภูมิ": [
            ("ปิล๊อก", "71180"),
            ("ลิ่นถิ่น", "71180"),
            ("สหกรณ์นิคม", "71180"),
            ("ห้วยเขย่ง", "71180"),
        ],
        "ท่าม่วง": [
            ("เขาน้อย", "71110"),
            ("ท่าม่วง", "71110"),
            ("ท่าล้อ", "71110"),
            ("ทุ่งทอง", "71110"),
            ("พังตรุ", "71110"),
            ("ม่วงชุม", "71110"),
            ("รางสาลี่", "71110"),
            ("วังขนาย", "71110"),
            ("วังศาลา", "71110"),
            ("วังศาลา", "71130"),
        ],
        "ท่ามะกา": [
            ("เขาสามสิบหาบ", "71120"),
            ("ดอนขมิ้น", "71120"),
            ("ดอนชะเอม", "71130"),
            ("ท่ามะกา", "71120"),
            ("ท่าเรือ", "71130"),
            ("พระแท่น", "71130"),
            ("ยางม่วง", "71120"),
            ("หนองลาน", "71130"),
            ("อุโลกสี่หมื่น", "71130"),
        ],
        "ไทรโยค": [
            ("ท่าเสา", "71150"),
            ("บ้องตี้", "71150"),
            ("ลุ่มสุ่ม", "71150"),
            ("ศรีมงคล", "71150"),
            ("สิงห์", "71150"),
        ],
        "บ่อพลอย": [
            ("หนองกุ่ม", "71160"),
            ("หนองรี", "71220"),
        ],
        "พนมทวน": [
            ("ดอนตาเพชร", "71140"),
            ("พนมทวน", "71140"),
            ("พังตรุ", "71140"),
            ("รางหวาย", "71170"),
            ("หนองโรง", "71140"),
            ("หนองสาหร่าย", "71140"),
        ],
        "เมืองกาญจนบุรี": [
            ("เกาะสำโรง", "71000"),
            ("ช่องสะเดา", "71190"),
            ("ท่ามะขาม", "71000"),
            ("บ้านเก่า", "71000"),
            ("ปากแพรก", "71000"),
            ("วังด้ง", "71190"),
            ("หนองหญ้า", "71000"),
        ],
        "เลาขวัญ": [
            ("เลาขวัญ", "71210"),
            ("หนองประดู่", "71210"),
            ("หนองปลิง", "71210"),
        ],
        "ศรีสวัสดิ์": [
            ("เขาโจด", "71220"),
            ("ด่านแม่แฉลบ", "71250"),
            ("นาสวน", "71250"),
        ],
        "สังขละบุรี": [
            ("หนองลู", "71240"),
        ],
        "หนองปรือ": [
            ("หนองปลาไหล", "71220"),
        ],
        "ห้วยกระเจา": [
            ("ห้วยกระเจา", "71170"),
        ]},
    "กาฬสินธุ์": {
        "เมืองกาฬสินธุ์": [
            ("กาฬสินธุ์", "46000"),
            ("หลุบ", "46000"),
            ("ไผ่", "46000"),
            ("ลำปาว", "46000"),
            ("ห้วยโพธิ์", "46000"),
            ("ภูปอ", "46000"),
            ("กลางหมื่น", "46000"),
            ("ลำคลอง", "46000"),
        ],
        "นามน": [
            ("ยอดแกง", "46230"),
            ("สงเปลือย", "46230"),
            ("หลักเหลี่ยม", "46230"),
        ],
        "กมลาไสย": [
            ("กมลาไสย", "46130"),
            ("โพนงาม", "46130"),
            ("ดงลิง", "46130"),
            ("ธัญญา", "46130"),
            ("หนองแปน", "46130"),
            ("เจ้าท่า", "46130"),
            ("โคกสมบูรณ์", "46130"),
        ],
        "ร่องคำ": [
            ("ร่องคำ", "46210"),
            ("สามัคคี", "46210"),
        ],
        "กุฉินารายณ์": [
            ("บัวขาว", "46110"),
            ("จุมจัง", "46110"),
            ("เหล่าไฮงาม", "46110"),
            ("กุดหว้า", "46110"),
            ("สามขา", "46110"),
            ("นาขาม", "46110"),
            ("หนองห้าง", "46110"),
            ("นาโก", "46110"),
            ("สมสะอาด", "46110"),
            ("กุดค้าว", "46110"),
        ],
        "เขาวง": [
            ("คุ้มเก่า", "46160"),
            ("สงเปลือย", "46160"),
            ("หนองผือ", "46160"),
        ],
        "ยางตลาด": [
            ("ยางตลาด", "46120"),
            ("บัวบาน", "46120"),
            ("หนองอิเฒ่า", "46120"),
            ("นาเชือก", "46120"),
            ("นาดี", "46120"),
        ],
        "ห้วยเม็ก": [
            ("ห้วยเม็ก", "46170"),
            ("คำใหญ่", "46170"),
            ("กุดโดน", "46170"),
            ("หัวหิน", "46170"),
            ("โนนสะอาด", "46170"),
            ("ทรายทอง", "46170"),
        ],
        "สหัสขันธ์": [
            ("โนนศิลา", "46140"),
            ("นิคม", "46140"),
            ("โนนบุรี", "46140"),
        ],
        "คำม่วง": [
            ("ทุ่งคลอง", "46180"),
            ("ดินจี่", "46180"),
            ("นาบอน", "46180"),
            ("นาทัน", "46180"),
        ],
        "ท่าคันโท": [
            ("กุดจิก", "46190"),
        ],
        "หนองกุงศรี": [
            ("หนองกุงศรี", "46220"),
            ("เสาเล้า", "46220"),
        ],
        "สมเด็จ": [
            ("สมเด็จ", "46150"),
            ("มหาไชย", "46150"),
            ("ผาเสวย", "46150"),
            ("ศรีสมเด็จ", "46150"),
            ("ลำห้วยหลัว", "46150"),
        ],
        "ห้วยผึ้ง": [
            ("คำบง", "46240"),
            ("ไค้นุ่น", "46240"),
            ("นิคมห้วยผึ้ง", "46240"),
            ("หนองอีบุตร", "46240"),
        ],
        "สามชัย": [
            ("สำราญ", "46180"),
            ("คำสร้างเที่ยง", "46180"),
        ],
        "นาคู": [
            ("นาคู", "46160"),
            ("โนนนาจาน", "46160"),
            ("ภูแล่นช้าง", "46160"),
        ],
        "ดอนจาน": [
            ("ดอนจาน", "46000"),
            ("นาจำปา", "46000"),
        ],
        "ฆ้องชัย": [
            ("ฆ้องชัยพัฒนา", "46130"),
            ("โนนศิลาเลิง", "46130"),
        ],
        "เมืองกาฬสินธุ์": [
            ("เหนือ", "46000"),
            ("ลำพาน", "46000"),
            ("เชียงเครือ", "46000"),
            ("บึงวิชัย", "46000"),
            ("ภูดิน", "46000"),
            ("หนองกุง", "46000"),
            ("ขมิ้น", "46000"),
            ("โพนทอง", "46000"),
            ("นาจารย์", "46000"),
        ],
        "นามน": [
            ("นามน", "46230"),
            ("หนองบัว", "46230"),
        ],
        "กมลาไสย": [
            ("หลักเมือง", "46130"),
        ],
        "ร่องคำ": [
            ("เหล่าอ้อย", "46210"),
        ],
        "กุฉินารายณ์": [
            ("แจนแลน", "46110"),
            ("เหล่าใหญ่", "46110"),
        ],
        "เขาวง": [
            ("กุดสิมคุ้มใหม่", "46160"),
            ("สระพังทอง", "46160"),
            ("กุดปลาค้าว", "46160"),
        ],
        "ยางตลาด": [
            ("หัวงัว", "46120"),
            ("อุ่มเม่า", "46120"),
            ("เว่อ", "46120"),
            ("อิตื้อ", "46120"),
            ("หัวนาคำ", "46120"),
            ("ดอนสมบูรณ์", "46120"),
            ("คลองขาม", "46120"),
            ("เขาพระนอน", "46120"),
            ("โนนสูง", "46120"),
            ("หนองตอกแป้น", "46120"),
        ],
        "ห้วยเม็ก": [
            ("บึงนาเรียง", "46170"),
            ("พิมูล", "46170"),
            ("คำเหมือดแก้ว", "46170"),
        ],
        "สหัสขันธ์": [
            ("ภูสิงห์", "46140"),
            ("สหัสขันธ์", "46140"),
            ("นามะเขือ", "46140"),
            ("โนนแหลมทอง", "46140"),
            ("โนนน้ำเกลี้ยง", "46140"),
        ],
        "คำม่วง": [
            ("โพน", "46180"),
            ("เนินยาง", "46180"),
        ],
        "ท่าคันโท": [
            ("ท่าคันโท", "46190"),
            ("กุงเก่า", "46190"),
            ("ยางอู้ม", "46190"),
            ("นาตาล", "46190"),
            ("ดงสมบูรณ์", "46190"),
        ],
        "หนองกุงศรี": [
            ("หนองบัว", "46220"),
            ("โคกเครือ", "46220"),
            ("หนองสรวง", "46220"),
            ("หนองใหญ่", "46220"),
            ("ดงมูล", "46220"),
            ("ลำหนองแสน", "46220"),
            ("หนองหิน", "46220"),
        ],
        "สมเด็จ": [
            ("หนองแวง", "46150"),
            ("แซงบาดาล", "46150"),
            ("หมูม่น", "46150"),
        ],
        "สามชัย": [
            ("สำราญใต้", "46180"),
            ("หนองช้าง", "46180"),
        ],
        "นาคู": [
            ("สายนาวัง", "46160"),
            ("บ่อแก้ว", "46160"),
        ],
        "ดอนจาน": [
            ("สะอาดไชยศรี", "46000"),
            ("ดงพยุง", "46000"),
            ("ม่วงนา", "46000"),
        ],
        "ฆ้องชัย": [
            ("เหล่ากลาง", "46130"),
            ("โคกสะอาด", "46130"),
            ("ลำชี", "46130"),
        ]},
    "กำแพงเพชร": {
        "เมืองกำแพงเพชร": [
            ("ในเมือง", "62000"),
            ("ไตรตรึงษ์", "62160"),
            ("อ่างทอง", "62000"),
            ("ลานดอกไม้", "62000"),
            ("คณฑี", "62000"),
            ("เทพนคร", "62000"),
            ("นาบ่อคำ", "62000"),
            ("นครชุม", "62000"),
            ("ทรงธรรม", "62000"),
            ("หนองปลิง", "62000"),
            ("นิคมทุ่งโพธิ์ทะเล", "62000"),
            ("วังทอง", "62000"),
            ("ท่าขุนราม", "62000"),
            ("คลองแม่ลาย", "62000"),
            ("ธำมรงค์", "62160"),
            ("สระแก้ว", "62000"),
        ],
        "ไทรงาม": [
            ("ไทรงาม", "62150"),
            ("หนองทอง", "62150"),
            ("หนองไม้กอง", "62150"),
            ("มหาชัย", "62150"),
        ],
        "คลองลาน": [
            ("โป่งน้ำร้อน", "62180"),
            ("คลองลานพัฒนา", "62180"),
        ],
        "ขาณุวรลักษบุรี": [
            ("ดอนแตง", "62140"),
            ("วังชะพลู", "62140"),
            ("โค้งไผ่", "62140"),
            ("ปางมะค่า", "62140"),
            ("วังหามแห", "62140"),
            ("เกาะตาล", "62130"),
        ],
        "คลองขลุง": [
            ("คลองขลุง", "62120"),
            ("ท่ามะเขือ", "62120"),
        ],
        "พรานกระต่าย": [
            ("พรานกระต่าย", "62110"),
            ("พรานกระต่าย", "62120"),
            ("เขาคีริส", "62110"),
            ("ถ้ำกระต่ายทอง", "62110"),
        ],
        "ลานกระบือ": [
            ("ช่องลม", "62170"),
            ("หนองหลวง", "62170"),
            ("ประชาสุขสันต์", "62170"),
        ],
        "ทรายทองวัฒนา": [
            ("ถาวรวัฒนา", "62190"),
        ],
        "ปางศิลาทอง": [
            ("หินดาต", "62120"),
            ("ปางตาไว", "62120"),
        ],
        "บึงสามัคคี": [
            ("บึงสามัคคี", "62210"),
            ("วังชะโอน", "62210"),
            ("เทพนิมิต", "62210"),
        ],
        "โกสัมพีนคร": [
            ("โกสัมพี", "62000"),
            ("เพชรชมภู", "62000"),
            ("ลานดอกไม้ตก", "62000"),
        ],
        "ไทรงาม": [
            ("หนองคล้า", "62150"),
            ("พานทอง", "62150"),
            ("หนองแม่แตง", "62150"),
        ],
        "คลองลาน": [
            ("คลองน้ำไหล", "62180"),
            ("สักงาม", "62180"),
        ],
        "ขาณุวรลักษบุรี": [
            ("ยางสูง", "62130"),
            ("ป่าพุทรา", "62130"),
            ("แสนตอ", "62130"),
            ("สลกบาตร", "62140"),
            ("บ่อถ้ำ", "62140"),
        ],
        "คลองขลุง": [
            ("ท่าพุทรา", "62120"),
            ("แม่ลาด", "62120"),
            ("วังยาง", "62120"),
            ("วังแขม", "62120"),
            ("หัวถนน", "62120"),
            ("วังไทร", "62120"),
            ("วังบัว", "62120"),
            ("คลองสมบูรณ์", "62120"),
        ],
        "พรานกระต่าย": [
            ("หนองหัววัว", "62110"),
            ("ท่าไม้", "62110"),
            ("วังควง", "62110"),
            ("วังตะแบก", "62110"),
            ("คุยบ้านโอง", "62110"),
            ("คลองพิไกร", "62110"),
            ("ห้วยยั้ง", "62110"),
        ],
        "ลานกระบือ": [
            ("ลานกระบือ", "62170"),
            ("โนนพลวง", "62170"),
            ("บึงทับแรต", "62170"),
            ("จันทิมา", "62170"),
        ],
        "ทรายทองวัฒนา": [
            ("ทุ่งทราย", "62190"),
            ("ทุ่งทอง", "62190"),
        ],
        "ปางศิลาทอง": [
            ("โพธิ์ทอง", "62120"),
        ],
        "บึงสามัคคี": [
            ("ระหาน", "62210"),
        ]},
    "ขอนแก่น": {
        "เมืองขอนแก่น": [
            ("ในเมือง", "40000"),
            ("โคกสี", "40000"),
            ("เมืองเก่า", "40000"),
            ("บ้านหว้า", "40000"),
            ("แดงใหญ่", "40000"),
            ("ดอนช้าง", "40000"),
            ("ดอนหัน", "40260"),
        ],
        "บ้านฝาง": [
            ("ป่าหวายนั่ง", "40270"),
            ("ป่ามะนาว", "40270"),
            ("บ้านฝาง", "40270"),
        ],
        "พระยืน": [
            ("พระยืน", "40320"),
            ("พระบุ", "40320"),
            ("บ้านโต้น", "40320"),
            ("หนองแวง", "40320"),
        ],
        "หนองเรือ": [
            ("หนองเรือ", "40210"),
            ("บ้านกง", "40240"),
            ("ยางคำ", "40240"),
            ("โนนทอง", "40210"),
            ("กุดกว้าง", "40210"),
            ("โนนสะอาด", "40210"),
        ],
        "ชุมแพ": [
            ("โนนหัน", "40290"),
            ("โนนอุดม", "40130"),
            ("ขัวเรียง", "40130"),
            ("ไชยสอ", "40130"),
            ("วังหินลาด", "40130"),
            ("นาเพียง", "40130"),
            ("โนนสะอาด", "40290"),
        ],
        "สีชมพู": [
            ("ศรีสุข", "40220"),
            ("นาจาน", "40220"),
            ("ซำยาง", "40220"),
            ("ดงลาน", "40220"),
            ("บริบูรณ์", "40220"),
        ],
        "น้ำพอง": [
            ("น้ำพอง", "40140"),
            ("วังชัย", "40140"),
            ("หนองกุง", "40140"),
            ("บัวใหญ่", "40140"),
            ("บ้านขาม", "40140"),
            ("บัวเงิน", "40140"),
            ("ทรายมูล", "40140"),
            ("พังทุย", "40140"),
            ("กุดน้ำใส", "40140"),
            ("กุดน้ำใส", "40310"),
        ],
        "อุบลรัตน์": [
            ("โคกสูง", "40250"),
            ("บ้านดง", "40250"),
            ("นาคำ", "40250"),
        ],
        "กระนวน": [
            ("หนองโก", "40170"),
            ("บ้านฝาง", "40170"),
            ("น้ำอ้อม", "40170"),
            ("หัวนาคำ", "40170"),
        ],
        "บ้านไผ่": [
            ("บ้านลาน", "40110"),
            ("หนองน้ำใส", "40110"),
        ],
        "พล": [
            ("เก่างิ้ว", "40120"),
            ("หนองมะเขือ", "40120"),
            ("หนองแวงโสกพระ", "40120"),
            ("หนองแวงนางเบ้า", "40120"),
            ("ลอมคอม", "40120"),
        ],
        "แวงใหญ่": [
            ("คอนฉิม", "40330"),
            ("ใหม่นาเพียง", "40330"),
        ],
        "แวงน้อย": [
            ("แวงน้อย", "40230"),
            ("ก้านเหลือง", "40230"),
            ("ท่านางแนว", "40230"),
            ("ท่าวัด", "40230"),
            ("ทางขวาง", "40230"),
        ],
        "หนองสองห้อง": [
            ("หนองสองห้อง", "40190"),
            ("สำโรง", "40190"),
            ("หันโจด", "40190"),
            ("ดอนดั่ง", "40190"),
            ("วังหิน", "40190"),
            ("หนองไผ่ล้อม", "40190"),
        ],
        "ภูเวียง": [
            ("บ้านเรือ", "40150"),
            ("นาหว้า", "40150"),
            ("หนองกุงธนสาร", "40150"),
            ("หนองกุงเซิน", "40150"),
            ("ดินดำ", "40150"),
            ("ภูเวียง", "40150"),
        ],
        "มัญจาคีรี": [
            ("กุดเค้า", "40160"),
            ("สวนหม่อน", "40160"),
            ("หนองแปน", "40160"),
        ],
        "ชนบท": [
            ("กุดเพียขอม", "40180"),
            ("วังแสง", "40180"),
            ("ห้วยแก", "40180"),
            ("บ้านแท่น", "40180"),
            ("ศรีบุญเรือง", "40180"),
            ("โนนพะยอม", "40180"),
            ("ปอแดง", "40180"),
        ],
        "เขาสวนกวาง": [
            ("ดงเมืองแอม", "40280"),
            ("คำม่วง", "40280"),
        ],
        "ภูผาม่าน": [
            ("โนนคอม", "40350"),
            ("นาฝาย", "40350"),
            ("ห้วยม่วง", "40350"),
        ],
        "ซำสูง": [
            ("กระนวน", "40170"),
            ("คูคำ", "40170"),
            ("ห้วยเตย", "40170"),
        ],
        "โคกโพธิ์ไชย": [
            ("บ้านโคก", "40160"),
        ],
        "บ้านแฮด": [
            ("บ้านแฮด", "40110"),
            ("โคกสำราญ", "40110"),
            ("โนนสมบูรณ์", "40110"),
            ("หนองแซง", "40110"),
        ],
        "โนนศิลา": [
            ("โนนศิลา", "40110"),
            ("หนองปลาหมอ", "40110"),
            ("โนนแดง", "40110"),
        ],
        "เวียงเก่า": [
            ("เมืองเก่าพัฒนา", "40150"),
            ("เขาน้อย", "40150"),
        ],
        "เมืองขอนแก่น": [
            ("ในเมือง", "40002"),
            ("สำราญ", "40000"),
            ("ท่าพระ", "40260"),
            ("บ้านทุ่ม", "40000"),
            ("พระลับ", "40000"),
            ("สาวะถี", "40000"),
            ("บ้านค้อ", "40000"),
            ("ศิลา", "40000"),
            ("บ้านเป็ด", "40000"),
            ("หนองตูม", "40000"),
            ("บึงเนียม", "40000"),
            ("โนนท่อน", "40000"),
        ],
        "บ้านฝาง": [
            ("หนองบัว", "40270"),
            ("โนนฆ้อง", "40270"),
            ("บ้านเหล่า", "40270"),
            ("โคกงาม", "40270"),
        ],
        "พระยืน": [
            ("ขามป้อม", "40320"),
        ],
        "หนองเรือ": [
            ("บ้านเม็ง", "40210"),
            ("จระเข้", "40240"),
            ("โนนทัน", "40210"),
            ("บ้านผือ", "40240"),
        ],
        "ชุมแพ": [
            ("ชุมแพ", "40130"),
            ("นาหนองทุ่ม", "40290"),
            ("หนองไผ่", "40130"),
            ("หนองเขียด", "40290"),
            ("หนองเสาเล้า", "40130"),
        ],
        "สีชมพู": [
            ("สีชมพู", "40220"),
            ("วังเพิ่ม", "40220"),
            ("หนองแดง", "40220"),
            ("บ้านใหม่", "40220"),
            ("ภูห่าน", "40220"),
        ],
        "น้ำพอง": [
            ("สะอาด", "40310"),
            ("ม่วงหวาน", "40310"),
            ("ท่ากระเสริม", "40140"),
        ],
        "อุบลรัตน์": [
            ("เขื่อนอุบลรัตน์", "40250"),
            ("ศรีสุขสำราญ", "40250"),
            ("ทุ่งโป่ง", "40250"),
        ],
        "กระนวน": [
            ("หนองกุงใหญ่", "40170"),
            ("ห้วยโจด", "40170"),
            ("ห้วยยาง", "40170"),
            ("ดูนสาด", "40170"),
            ("หนองโน", "40170"),
        ],
        "บ้านไผ่": [
            ("บ้านไผ่", "40110"),
            ("ในเมือง", "40110"),
            ("เมืองเพีย", "40110"),
            ("แคนเหนือ", "40110"),
            ("ภูเหล็ก", "40110"),
            ("ป่าปอ", "40110"),
            ("หินตั้ง", "40110"),
            ("หัวหนอง", "40110"),
        ],
        "เปือยน้อย": [
            ("เปือยน้อย", "40340"),
            ("วังม่วง", "40340"),
            ("ขามป้อม", "40340"),
            ("สระแก้ว", "40340"),
        ],
        "พล": [
            ("เมืองพล", "40120"),
            ("โจดหนองแก", "40120"),
            ("เพ็กใหญ่", "40120"),
            ("โคกสง่า", "40120"),
            ("โนนข่า", "40120"),
            ("โสกนกเต็น", "40120"),
            ("หัวทุ่ง", "40120"),
        ],
        "แวงใหญ่": [
            ("โนนทอง", "40330"),
            ("แวงใหญ่", "40330"),
            ("โนนสะอาด", "40330"),
        ],
        "แวงน้อย": [
            ("ละหานนา", "40230"),
        ],
        "หนองสองห้อง": [
            ("คึมชาด", "40190"),
            ("โนนธาตุ", "40190"),
            ("ตะกั่วป่า", "40190"),
            ("หนองเม็ก", "40190"),
            ("ดอนดู่", "40190"),
            ("ดงเค็ง", "40190"),
        ],
        "ภูเวียง": [
            ("หว้าทอง", "40150"),
            ("กุดขอนแก่น", "40150"),
            ("นาชุมแสง", "40150"),
            ("สงเปือย", "40150"),
            ("ทุ่งชมพู", "40150"),
        ],
        "มัญจาคีรี": [
            ("โพนเพ็ก", "40160"),
            ("คำแคน", "40160"),
            ("นาข่า", "40160"),
            ("นางาม", "40160"),
            ("ท่าศาลา", "40160"),
        ],
        "ชนบท": [
            ("ชนบท", "40180"),
        ],
        "เขาสวนกวาง": [
            ("เขาสวนกวาง", "40280"),
            ("นางิ้ว", "40280"),
            ("โนนสมบูรณ์", "40280"),
        ],
        "ภูผาม่าน": [
            ("ภูผาม่าน", "40350"),
            ("วังสวาบ", "40350"),
        ],
        "ซำสูง": [
            ("คำแมด", "40170"),
            ("บ้านโนน", "40170"),
        ],
        "โคกโพธิ์ไชย": [
            ("โพธิ์ไชย", "40160"),
            ("ซับสมบูรณ์", "40160"),
            ("นาแพง", "40160"),
        ],
        "หนองนาคำ": [
            ("กุดธาตุ", "40150"),
            ("บ้านโคก", "40150"),
            ("ขนวน", "40150"),
        ],
        "โนนศิลา": [
            ("บ้านหัน", "40110"),
            ("เปือยใหญ่", "40110"),
        ],
        "เวียงเก่า": [
            ("ในเมือง", "40150"),
        ]},
    "จันทบุรี": {
        "เมืองจันทบุรี": [
            ("ตลาด", "22000"),
            ("วัดใหม่", "22000"),
            ("เกาะขวาง", "22000"),
            ("บางกะจะ", "22000"),
            ("หนองบัว", "22000"),
            ("พลับพลา", "22000"),
        ],
        "ขลุง": [
            ("ขลุง", "22110"),
            ("บ่อ", "22110"),
            ("ซึ้ง", "22110"),
            ("มาบไพ", "22110"),
            ("ตรอกนอง", "22110"),
        ],
        "ท่าใหม่": [
            ("ท่าใหม่", "22120"),
            ("บ่อพุ", "22120"),
            ("พลอยแหวน", "22120"),
            ("เขาบายศรี", "22120"),
            ("คลองขุด", "22120"),
        ],
        "มะขาม": [
            ("ท่าหลวง", "22150"),
            ("วังแซ้ม", "22150"),
            ("ฉมัน", "22150"),
            ("อ่างคีรี", "22150"),
        ],
        "แหลมสิงห์": [
            ("ปากน้ำแหลมสิงห์", "22130"),
            ("เกาะเปริด", "22130"),
            ("หนองชิ่ม", "22130"),
        ],
        "สอยดาว": [
            ("ทุ่งขนาน", "22180"),
        ],
        "แก่งหางแมว": [
            ("แก่งหางแมว", "22160"),
            ("ขุนซ่อง", "22160"),
            ("สามพี่น้อง", "22160"),
        ],
        "นายายอาม": [
            ("นายายอาม", "22160"),
            ("สนามไชย", "22170"),
        ],
        "เขาคิชฌกูฏ": [
            ("คลองพลู", "22210"),
            ("จันทเขลม", "22210"),
        ],
        "เมืองจันทบุรี": [
            ("คลองนารายณ์", "22000"),
            ("คมบาง", "22000"),
            ("ท่าช้าง", "22000"),
            ("จันทนิมิต", "22000"),
            ("แสลง", "22000"),
        ],
        "ขลุง": [
            ("เกวียนหัก", "22110"),
            ("ตะปอน", "22110"),
            ("บางชัน", "22110"),
            ("วันยาว", "22110"),
            ("วังสรรพรส", "22110"),
            ("ตกพรม", "22110"),
            ("บ่อเวฬุ", "22150"),
        ],
        "ท่าใหม่": [
            ("ยายร้า", "22120"),
            ("สีพยา", "22120"),
            ("เขาวัว", "22120"),
            ("สองพี่น้อง", "22120"),
            ("ทุ่งเบญจา", "22170"),
            ("รำพัน", "22170"),
            ("โขมง", "22170"),
            ("ตะกาดเง้า", "22120"),
            ("เขาแก้ว", "22170"),
        ],
        "โป่งน้ำร้อน": [
            ("ทับไทร", "22140"),
            ("โป่งน้ำร้อน", "22140"),
            ("หนองตาคง", "22140"),
            ("เทพนิมิต", "22140"),
            ("คลองใหญ่", "22140"),
        ],
        "มะขาม": [
            ("มะขาม", "22150"),
            ("ปัถวี", "22150"),
        ],
        "แหลมสิงห์": [
            ("พลิ้ว", "22190"),
            ("คลองน้ำเค็ม", "22190"),
            ("บางสระเก้า", "22190"),
            ("บางกะไชย", "22120"),
        ],
        "สอยดาว": [
            ("ปะตง", "22180"),
            ("ทับช้าง", "22180"),
            ("ทรายขาว", "22180"),
            ("สะตอน", "22180"),
        ],
        "แก่งหางแมว": [
            ("พวา", "22160"),
            ("เขาวงกต", "22160"),
        ],
        "นายายอาม": [
            ("วังโตนด", "22170"),
            ("กระแจะ", "22170"),
            ("ช้างข้าม", "22160"),
            ("วังใหม่", "22170"),
        ],
        "เขาคิชฌกูฏ": [
            ("ชากไทย", "22210"),
            ("พลวง", "22210"),
            ("ตะเคียนทอง", "22210"),
        ]},
    "ฉะเชิงเทรา": {
        "เมืองฉะเชิงเทรา": [
            ("บ้านใหม่", "24000"),
            ("บางตีนเป็ด", "24000"),
            ("บางไผ่", "24000"),
            ("บางขวัญ", "24000"),
            ("วังตะเคียน", "24000"),
            ("โสธร", "24000"),
            ("บางพระ", "24000"),
            ("หนามแดง", "24000"),
            ("หน้าเมือง", "24000"),
            ("ท่าไข่", "24000"),
            ("คลองนา", "24000"),
            ("คลองจุกกระเฌอ", "24000"),
            ("บางแก้ว", "24000"),
            ("คลองนครเนื่องเขต", "24000"),
            ("บางกะไห", "24000"),
            ("คลองเปรง", "24000"),
            ("คลองอุดมชลจร", "24000"),
            ("คลองหลวงแพ่ง", "24000"),
        ],
        "บางคล้า": [
            ("ปากน้ำ", "24110"),
            ("เสม็ดใต้", "24110"),
        ],
        "บางน้ำเปรี้ยว": [
            ("บางขนาก", "24150"),
            ("บึงน้ำรักษ์", "24170"),
            ("ดอนฉิมพลี", "24170"),
            ("ศาลาแดง", "24000"),
        ],
        "บางปะกง": [
            ("บางปะกง", "24130"),
            ("บางวัว", "24180"),
            ("บางสมัคร", "24180"),
            ("บางผึ้ง", "24130"),
            ("บางเกลือ", "24130"),
            ("สองคลอง", "24130"),
            ("หนองจอก", "24130"),
            ("พิมพา", "24180"),
            ("หอมศีล", "24180"),
            ("หอมศีล", "24130"),
            ("เขาดิน", "24130"),
        ],
        "บ้านโพธิ์": [
            ("เกาะไร่", "24140"),
            ("คลองประเวศ", "24140"),
            ("ดอนทราย", "24140"),
            ("แหลมประดู่", "24140"),
            ("ลาดขวาง", "24140"),
            ("สนามจันทร์", "24140"),
            ("แสนภูดาษ", "24140"),
        ],
        "พนมสารคาม": [
            ("เกาะขนุน", "24120"),
            ("บ้านซ่อง", "24120"),
            ("พนมสารคาม", "24120"),
            ("เขาหินซ้อน", "24120"),
        ],
        "ราชสาส์น": [
            ("บางคา", "24120"),
            ("เมืองใหม่", "24120"),
            ("ดงน้อย", "24120"),
        ],
        "สนามชัยเขต": [
            ("ทุ่งพระยา", "24160"),
        ],
        "ท่าตะเกียบ": [
            ("ท่าตะเกียบ", "24160"),
            ("คลองตะเกรา", "24160"),
        ],
        "คลองเขื่อน": [
            ("ก้อนแก้ว", "24000"),
            ("คลองเขื่อน", "24110"),
            ("บางเล่า", "24110"),
            ("บางเล่า", "24000"),
            ("บางโรง", "24000"),
        ],
        "เมืองฉะเชิงเทรา": [
            ("บางเตย", "24000"),
        ],
        "บางคล้า": [
            ("บางคล้า", "24110"),
            ("บางสวน", "24110"),
            ("บางกระเจ็ด", "24110"),
            ("ท่าทองหลาง", "24110"),
            ("สาวชะโงก", "24110"),
            ("เสม็ดเหนือ", "24110"),
            ("หัวไทร", "24110"),
        ],
        "บางน้ำเปรี้ยว": [
            ("บางน้ำเปรี้ยว", "24150"),
            ("สิงโตทอง", "24150"),
            ("หมอนทอง", "24150"),
            ("ดอนเกาะกา", "24170"),
            ("โยธะกา", "24150"),
            ("โพรงอากาศ", "24150"),
        ],
        "บางปะกง": [
            ("ท่าสะอ้าน", "24130"),
            ("บางวัว", "24130"),
            ("บางสมัคร", "24130"),
            ("บางเกลือ", "24180"),
            ("พิมพา", "24130"),
            ("ท่าข้าม", "24130"),
        ],
        "บ้านโพธิ์": [
            ("บ้านโพธิ์", "24140"),
            ("คลองขุด", "24140"),
            ("คลองบ้านโพธิ์", "24140"),
            ("เทพราช", "24140"),
            ("ท่าพลับ", "24140"),
            ("หนองตีนนก", "24140"),
            ("หนองบัว", "24140"),
            ("บางซ่อน", "24140"),
            ("บางกรูด", "24140"),
            ("สิบเอ็ดศอก", "24140"),
        ],
        "พนมสารคาม": [
            ("เมืองเก่า", "24120"),
            ("หนองยาว", "24120"),
            ("ท่าถ่าน", "24120"),
            ("หนองแหน", "24120"),
        ],
        "สนามชัยเขต": [
            ("คู้ยายหมี", "24160"),
            ("ท่ากระดาน", "24160"),
            ("ลาดกระทิง", "24160"),
        ],
        "แปลงยาว": [
            ("แปลงยาว", "24190"),
            ("วังเย็น", "24190"),
            ("หัวสำโรง", "24190"),
            ("หนองไม้แก่น", "24190"),
        ],
        "คลองเขื่อน": [
            ("คลองเขื่อน", "24000"),
            ("บางโรง", "24110"),
            ("บางตลาด", "24110"),
        ]},
    "ชลบุรี": {
        "เมืองชลบุรี": [
            ("บ้านโขด", "20000"),
            ("แสนสุข", "20130"),
            ("แสนสุข", "20131"),
            ("นาป่า", "20000"),
            ("ดอนหัวฬ่อ", "20000"),
            ("เหมือง", "20130"),
            ("ห้วยกะปิ", "20130"),
            ("เสม็ด", "20130"),
            ("เสม็ด", "20000"),
            ("สำนักบก", "20000"),
        ],
        "บ้านบึง": [
            ("คลองกิ่ว", "20220"),
            ("หนองชาก", "20170"),
            ("หนองไผ่แก้ว", "20220"),
        ],
        "หนองใหญ่": [
            ("หนองใหญ่", "20190"),
            ("คลองพลู", "20190"),
        ],
        "บางละมุง": [
            ("บางละมุง", "20150"),
            ("หนองปลาไหล", "20150"),
            ("เขาไม้แก้ว", "20150"),
            ("ห้วยใหญ่", "20150"),
            ("ตะเคียนเตี้ย", "20150"),
            ("นาเกลือ", "20150"),
        ],
        "พานทอง": [
            ("มาบโป่ง", "20160"),
            ("บ้านเก่า", "20160"),
            ("บ้านเก่า", "20000"),
            ("บางนาง", "20160"),
            ("เกาะลอย", "20160"),
            ("บางหัก", "20160"),
        ],
        "พนัสนิคม": [
            ("พนัสนิคม", "20140"),
            ("บ้านเซิด", "20140"),
            ("นาเริก", "20140"),
            ("หมอนนาง", "20140"),
            ("วัดโบสถ์", "20140"),
            ("หนองปรือ", "20140"),
            ("บ้านช้าง", "20140"),
            ("โคกเพลาะ", "20140"),
            ("ไร่หลักทอง", "20140"),
            ("นามะตูม", "20140"),
        ],
        "ศรีราชา": [
            ("ทุ่งสุขลา", "20230"),
            ("หนองขาม", "20110"),
            ("หนองขาม", "20230"),
            ("บางพระ", "20110"),
            ("บ่อวิน", "20230"),
        ],
        "สัตหีบ": [
            ("สัตหีบ", "20182"),
            ("แสมสาร", "20180"),
        ],
        "บ่อทอง": [
            ("วัดสุวรรณ", "20270"),
            ("บ่อกวางทอง", "20270"),
            ("ธาตุทอง", "20270"),
            ("เกษตรสุวรรณ", "20270"),
            ("พลวงทอง", "20270"),
        ],
        "เกาะจันทร์": [
            ("เกาะจันทร์", "20240"),
        ],
        "เกาะสีชัง": [
            ("ท่าเทววงษ์", "20120"),
        ],
        "เมืองชลบุรี": [
            ("บางปลาสร้อย", "20000"),
            ("มะขามหย่ง", "20000"),
            ("แสนสุข", "20000"),
            ("บ้านสวน", "20000"),
            ("หนองรี", "20000"),
            ("หนองข้างคอก", "20000"),
            ("หนองไม้แดง", "20000"),
            ("บางทราย", "20000"),
            ("คลองตำหรุ", "20000"),
            ("บ้านปึก", "20130"),
            ("ห้วยกะปิ", "20000"),
            ("อ่างศิลา", "20000"),
        ],
        "บ้านบึง": [
            ("บ้านบึง", "20170"),
            ("มาบไผ่", "20170"),
            ("หนองซ้ำซาก", "20170"),
            ("หนองบอนแดง", "20170"),
            ("หนองอิรุณ", "20220"),
        ],
        "หนองใหญ่": [
            ("หนองเสือช้าง", "20190"),
            ("ห้างสูง", "20190"),
            ("เขาซก", "20190"),
        ],
        "บางละมุง": [
            ("หนองปรือ", "20150"),
            ("หนองปรือ", "20260"),
            ("โป่ง", "20150"),
            ("นาเกลือ", "20260"),
        ],
        "พานทอง": [
            ("พานทอง", "20160"),
            ("หนองตำลึง", "20160"),
            ("หนองกะขะ", "20160"),
            ("หนองหงษ์", "20160"),
            ("โคกขี้หนอน", "20160"),
            ("หน้าประดู่", "20160"),
        ],
        "พนัสนิคม": [
            ("หน้าพระธาตุ", "20140"),
            ("วัดหลวง", "20140"),
            ("สระสี่เหลี่ยม", "20140"),
            ("กุฎโง้ง", "20140"),
            ("หัวถนน", "20140"),
            ("ท่าข้าม", "20140"),
            ("หนองขยาด", "20140"),
            ("ทุ่งขวาง", "20140"),
            ("หนองเหียง", "20140"),
            ("นาวังหิน", "20240"),
        ],
        "ศรีราชา": [
            ("ศรีราชา", "20110"),
            ("สุรศักดิ์", "20110"),
            ("บึง", "20230"),
            ("เขาคันทรง", "20110"),
        ],
        "สัตหีบ": [
            ("สัตหีบ", "20180"),
            ("นาจอมเทียน", "20250"),
            ("พลูตาหลวง", "20180"),
            ("บางเสร่", "20250"),
            ("บางเสร่", "20251"),
        ],
        "บ่อทอง": [
            ("บ่อทอง", "20270"),
        ],
        "เกาะจันทร์": [
            ("ท่าบุญมี", "20240"),
        ],
        "พนัสนิคม": [
            ("นาวังหิน", "20140"),
        ]},
    "ชัยนาท": {
        "เมืองชัยนาท": [
            ("ในเมือง", "17000"),
            ("บ้านกล้วย", "17000"),
            ("ท่าชัย", "17000"),
            ("ชัยนาท", "17000"),
            ("หาดท่าเสา", "17120"),
            ("เสือโฮก", "17000"),
            ("นางลือ", "17000"),
        ],
        "มโนรมย์": [
            ("คุ้งสำเภา", "17110"),
            ("ศิลาดาน", "17110"),
            ("ท่าฉนวน", "17110"),
        ],
        "วัดสิงห์": [
            ("วัดสิงห์", "17120"),
            ("หนองขุ่น", "17120"),
            ("วังหมัน", "17120"),
        ],
        "สรรพยา": [
            ("เขาแก้ว", "17150"),
            ("โพนางดำออก", "17150"),
        ],
        "สรรคบุรี": [
            ("แพรกศรีราชา", "17140"),
            ("เที่ยงแท้", "17140"),
            ("ห้วยกรด", "17140"),
            ("โพงาม", "17140"),
            ("บางขุด", "17140"),
            ("ดงคอน", "17140"),
            ("ดอนกำ", "17140"),
        ],
        "หันคา": [
            ("หันคา", "17130"),
            ("บ้านเชี่ยน", "17130"),
            ("ไพรนกยูง", "17130"),
            ("ห้วยงู", "17160"),
            ("วังไก่เถื่อน", "17130"),
            ("เด่นใหญ่", "17130"),
        ],
        "หนองมะโมง": [
            ("หนองมะโมง", "17120"),
            ("กุดจอก", "17120"),
        ],
        "เนินขาม": [
            ("สุขเดือนห้า", "17130"),
        ],
        "เมืองชัยนาท": [
            ("เขาท่าพระ", "17000"),
            ("หาดท่าเสา", "17000"),
            ("ธรรมามูล", "17000"),
        ],
        "มโนรมย์": [
            ("วัดโคก", "17110"),
            ("วัดโคก", "17170"),
            ("หางน้ำสาคร", "17170"),
            ("ไร่พัฒนา", "17170"),
            ("อู่ตะเภา", "17170"),
        ],
        "วัดสิงห์": [
            ("มะขามเฒ่า", "17120"),
            ("หนองน้อย", "17120"),
            ("หนองบัว", "17120"),
            ("บ่อแร่", "17120"),
        ],
        "สรรพยา": [
            ("สรรพยา", "17150"),
            ("ตลุก", "17150"),
            ("โพนางดำตก", "17150"),
            ("บางหลวง", "17150"),
            ("หาดอาษา", "17150"),
        ],
        "สรรคบุรี": [
            ("ห้วยกรดพัฒนา", "17140"),
        ],
        "หันคา": [
            ("หนองแซง", "17160"),
            ("สามง่ามท่าโบสถ์", "17160"),
        ],
        "หนองมะโมง": [
            ("วังตะเคียน", "17120"),
            ("สะพานหิน", "17120"),
        ],
        "เนินขาม": [
            ("กะบกเตี้ย", "17130"),
            ("เนินขาม", "17130"),
        ]},
    "ชัยภูมิ": {
        "เมืองชัยภูมิ": [
            ("บ้านค่าย", "36240"),
            ("ชีลอง", "36000"),
            ("บ้านเล่า", "36000"),
            ("ลาดใหญ่", "36000"),
            ("ท่าหินโงม", "36000"),
            ("ห้วยต้อน", "36000"),
            ("ห้วยบง", "36000"),
            ("โนนสำราญ", "36240"),
        ],
        "บ้านเขว้า": [
            ("บ้านเขว้า", "36170"),
            ("ตลาดแร้ง", "36170"),
            ("ชีบน", "36170"),
        ],
        "คอนสวรรค์": [
            ("คอนสวรรค์", "36140"),
            ("ยางหวาย", "36140"),
            ("ช่องสามหมอ", "36140"),
            ("บ้านโสก", "36140"),
            ("โคกมั่งงอย", "36140"),
        ],
        "เกษตรสมบูรณ์": [
            ("บ้านหัน", "36120"),
            ("บ้านเดื่อ", "36120"),
            ("โนนกอก", "36120"),
            ("สระโพนทอง", "36120"),
            ("หนองข่า", "36120"),
            ("บ้านบัว", "36120"),
            ("โนนทอง", "36120"),
        ],
        "หนองบัวแดง": [
            ("ถ้ำวัวแดง", "36210"),
            ("คูเมือง", "36210"),
        ],
        "จัตุรัส": [
            ("บ้านกอก", "36130"),
            ("หนองโดน", "36130"),
            ("หนองบัวใหญ่", "36130"),
        ],
        "บำเหน็จณรงค์": [
            ("บ้านชวน", "36160"),
            ("บ้านเพชร", "36160"),
            ("หัวทะเล", "36220"),
            ("เกาะมะนาว", "36160"),
            ("โคกเพชรพัฒนา", "36160"),
        ],
        "หนองบัวระเหว": [
            ("หนองบัวระเหว", "36250"),
            ("วังตะเฆ่", "36250"),
            ("ห้วยแย้", "36250"),
            ("โคกสะอาด", "36250"),
            ("โสกปลาดุก", "36250"),
        ],
        "เทพสถิต": [
            ("วะตะแบก", "36230"),
            ("นายางกลัก", "36230"),
        ],
        "ภูเขียว": [
            ("ผักปัง", "36110"),
            ("กวางโจน", "36110"),
            ("หนองคอนไทย", "36110"),
            ("กุดยม", "36110"),
            ("โคกสะอาด", "36110"),
            ("หนองตูม", "36110"),
            ("บ้านดอน", "36110"),
        ],
        "บ้านแท่น": [
            ("สามสวน", "36190"),
            ("สระพัง", "36190"),
            ("บ้านเต่า", "36190"),
            ("หนองคู", "36190"),
        ],
        "แก้งคร้อ": [
            ("บ้านแก้ง", "36150"),
            ("หนองสังข์", "36150"),
            ("ท่ามะไฟหวาน", "36150"),
            ("หนองไผ่", "36150"),
        ],
        "คอนสาร": [
            ("คอนสาร", "36180"),
            ("ทุ่งพระ", "36180"),
            ("โนนคูณ", "36180"),
            ("ห้วยยาง", "36180"),
            ("ดงบัง", "36180"),
            ("ทุ่งนาเลา", "36180"),
            ("ดงกลาง", "36180"),
        ],
        "ภักดีชุมพล": [
            ("บ้านเจียง", "36260"),
            ("เจาทอง", "36260"),
            ("แหลมทอง", "36260"),
        ],
        "เนินสง่า": [
            ("ตาเนิน", "36130"),
            ("กะฮาด", "36130"),
            ("รังงาม", "36130"),
        ],
        "ซับใหญ่": [
            ("ซับใหญ่", "36130"),
            ("ท่ากูบ", "36130"),
        ],
        "เมืองชัยภูมิ": [
            ("ในเมือง", "36000"),
            ("รอบเมือง", "36000"),
            ("โพนทอง", "36000"),
            ("นาฝาย", "36000"),
            ("กุดตุ้ม", "36000"),
            ("นาเสียว", "36000"),
            ("หนองนาแซง", "36000"),
            ("หนองไผ่", "36240"),
            ("โคกสูง", "36000"),
            ("บุ่งคล้า", "36000"),
            ("ซับสีทอง", "36000"),
        ],
        "บ้านเขว้า": [
            ("ลุ่มลำชี", "36170"),
            ("ภูแลนคา", "36170"),
            ("โนนแดง", "36170"),
        ],
        "คอนสวรรค์": [
            ("โนนสะอาด", "36140"),
            ("ห้วยไร่", "36140"),
            ("หนองขาม", "36140"),
            ("ศรีสำราญ", "36140"),
        ],
        "เกษตรสมบูรณ์": [
            ("บ้านยาง", "36120"),
            ("บ้านเป้า", "36120"),
            ("กุดเลาะ", "36120"),
            ("หนองโพนงาม", "36120"),
        ],
        "หนองบัวแดง": [
            ("หนองบัวแดง", "36210"),
            ("กุดชุมแสง", "36210"),
            ("นางแดด", "36210"),
            ("หนองแวง", "36210"),
            ("ท่าใหญ่", "36210"),
            ("วังชมภู", "36210"),
        ],
        "จัตุรัส": [
            ("หนองบัวบาน", "36130"),
            ("บ้านขาม", "36130"),
            ("กุดน้ำใส", "36130"),
            ("ละหาน", "36130"),
            ("หนองบัวโคก", "36220"),
            ("ส้มป่อย", "36130"),
        ],
        "บำเหน็จณรงค์": [
            ("บ้านตาล", "36220"),
            ("โคกเริงรมย์", "36160"),
        ],
        "เทพสถิต": [
            ("ห้วยยายจิ๋ว", "36230"),
            ("บ้านไร่", "36230"),
            ("โป่งนก", "36230"),
        ],
        "ภูเขียว": [
            ("บ้านแก้ง", "36110"),
            ("บ้านเพชร", "36110"),
            ("โอโล", "36110"),
            ("ธาตุทอง", "36110"),
        ],
        "บ้านแท่น": [
            ("บ้านแท่น", "36190"),
        ],
        "แก้งคร้อ": [
            ("ช่องสามหมอ", "36150"),
            ("หนองขาม", "36150"),
            ("นาหนองทุ่ม", "36150"),
            ("หลุบคา", "36150"),
            ("โคกกุง", "36150"),
            ("เก่าย่าดี", "36150"),
        ],
        "คอนสาร": [
            ("ทุ่งลุยลาย", "36180"),
        ],
        "ภักดีชุมพล": [
            ("วังทอง", "36260"),
        ],
        "เนินสง่า": [
            ("หนองฉิม", "36130"),
        ],
        "ซับใหญ่": [
            ("ตะโกทอง", "36130"),
        ]},
    "ชุมพร": {
        "เมืองชุมพร": [
            ("ท่าตะเภา", "86000"),
            ("ท่ายาง", "86000"),
            ("ท่ายาง", "86120"),
            ("ปากน้ำ", "86120"),
            ("บางหมาก", "86000"),
            ("นาทุ่ง", "86000"),
            ("นาชะอัง", "86000"),
            ("ตากแดด", "86000"),
            ("ตากแดด", "86190"),
            ("วังไผ่", "86190"),
            ("ขุนกระทิง", "86000"),
            ("ขุนกระทิง", "86010"),
            ("ทุ่งคา", "86100"),
            ("วิสัยเหนือ", "86120"),
            ("หาดทรายรี", "86100"),
            ("ถ้ำสิงห์", "86100"),
        ],
        "ท่าแซะ": [
            ("ท่าแซะ", "86140"),
            ("คุริง", "86140"),
            ("นากระตาม", "86140"),
            ("รับร่อ", "86140"),
            ("ท่าข้าม", "86140"),
            ("หินแก้ว", "86190"),
        ],
        "ปะทิว": [
            ("บางสน", "86160"),
            ("ทะเลทรัพย์", "86160"),
        ],
        "หลังสวน": [
            ("ขันเงิน", "86110"),
            ("ท่ามะพลา", "86110"),
            ("นาขา", "86110"),
            ("บ้านควน", "86110"),
            ("บางน้ำจืด", "86150"),
            ("วังตะกอ", "86110"),
        ],
        "ละแม": [
            ("ละแม", "86170"),
            ("สวนแตง", "86170"),
            ("ทุ่งคาวัด", "86170"),
        ],
        "สวี": [
            ("นาโพธิ์", "86130"),
            ("สวี", "86130"),
            ("ท่าหิน", "86130"),
            ("ปากแพรก", "86130"),
            ("เขาค่าย", "86130"),
        ],
        "ทุ่งตะโก": [
            ("ปากตะโก", "86220"),
            ("ทุ่งตะไคร", "86220"),
        ],
        "เมืองชุมพร": [
            ("บางลึก", "86000"),
            ("หาดพันไกร", "86000"),
            ("วังไผ่", "86000"),
            ("วังใหม่", "86190"),
            ("บ้านนา", "86190"),
            ("ขุนกระทิง", "86190"),
            ("วิสัยเหนือ", "86100"),
            ("หาดทรายรี", "86120"),
        ],
        "ท่าแซะ": [
            ("สลุย", "86140"),
            ("รับร่อ", "86190"),
            ("หงษ์เจริญ", "86140"),
            ("ทรัพย์อนันต์", "86140"),
            ("สองพี่น้อง", "86140"),
        ],
        "ปะทิว": [
            ("สะพลี", "86230"),
            ("ชุมโค", "86160"),
            ("ดอนยาง", "86210"),
            ("ปากคลอง", "86210"),
            ("เขาไชยราช", "86210"),
        ],
        "หลังสวน": [
            ("หลังสวน", "86110"),
            ("นาพญา", "86110"),
            ("บางมะพร้าว", "86110"),
            ("บางมะพร้าว", "86150"),
            ("ปากน้ำ", "86150"),
            ("พ้อแดง", "86110"),
            ("แหลมทราย", "86110"),
            ("หาดยาย", "86110"),
        ],
        "ละแม": [
            ("ทุ่งหลวง", "86170"),
        ],
        "พะโต๊ะ": [
            ("พะโต๊ะ", "86180"),
            ("ปากทรง", "86180"),
            ("ปังหวาน", "86180"),
            ("พระรักษ์", "86180"),
        ],
        "สวี": [
            ("ทุ่งระยะ", "86130"),
            ("ด่านสวี", "86130"),
            ("ครน", "86130"),
            ("วิสัยใต้", "86130"),
            ("นาสัก", "86130"),
            ("เขาทะลุ", "86130"),
        ],
        "ทุ่งตะโก": [
            ("ตะโก", "86220"),
            ("ช่องไม้แก้ว", "86220"),
        ]},
    "ตรัง": {
        "เมืองตรัง": [
            ("นาพละ", "92000"),
            ("นาบินหลา", "92000"),
            ("นาบินหลา", "92170"),
            ("บางรัก", "92000"),
            ("นาโต๊ะหมิง", "92000"),
            ("หนองตรุด", "92000"),
            ("นาท่ามเหนือ", "92190"),
            ("นาท่ามใต้", "92190"),
        ],
        "กันตัง": [
            ("กันตัง", "92110"),
            ("ควนธานี", "92110"),
            ("บางหมาก", "92110"),
            ("บางเป้า", "92110"),
            ("กันตังใต้", "92110"),
            ("โคกยาง", "92110"),
            ("บ่อน้ำร้อน", "92110"),
        ],
        "ย่านตาขาว": [
            ("หนองบ่อ", "92140"),
            ("ในควน", "92140"),
            ("ทุ่งกระบือ", "92140"),
            ("เกาะเปียะ", "92140"),
        ],
        "ปะเหลียน": [
            ("ท่าข้าม", "92120"),
            ("ทุ่งยาว", "92180"),
            ("เกาะสุกร", "92120"),
            ("แหลมสอม", "92180"),
        ],
        "สิเกา": [
            ("บ่อหิน", "92150"),
            ("กะลาเส", "92150"),
        ],
        "ห้วยยอด": [
            ("บางกุ้ง", "92210"),
            ("เขาขาว", "92130"),
            ("ปากแจ่ม", "92190"),
            ("ปากคม", "92130"),
            ("ท่างิ้ว", "92130"),
            ("ลำภูรา", "92190"),
            ("นาวง", "92210"),
            ("ทุ่งต่อ", "92130"),
        ],
        "วังวิเศษ": [
            ("วังมะปราง", "92220"),
            ("อ่าวตง", "92220"),
            ("ท่าสะบ้า", "92220"),
        ],
        "นาโยง": [
            ("นาโยงเหนือ", "92170"),
            ("ละมอ", "92170"),
            ("โคกสะบ้า", "92170"),
            ("นาหมื่นศรี", "92170"),
        ],
        "รัษฎา": [
            ("ควนเมา", "92160"),
            ("คลองปาง", "92160"),
            ("หนองปรือ", "92130"),
        ],
        "หาดสำราญ": [
            ("บ้าหวี", "92120"),
            ("หาดสำราญ", "92120"),
        ],
        "เมืองตรัง": [
            ("ทับเที่ยง", "92000"),
            ("บ้านควน", "92000"),
            ("ควนปริง", "92000"),
            ("นาโยงใต้", "92170"),
            ("โคกหล่อ", "92000"),
            ("น้ำผุด", "92000"),
            ("นาตาล่วง", "92000"),
            ("บ้านโพธิ์", "92000"),
        ],
        "กันตัง": [
            ("วังวน", "92110"),
            ("คลองลุ", "92110"),
            ("ย่านซื่อ", "92110"),
            ("บางสัก", "92110"),
            ("นาเกลือ", "92110"),
            ("เกาะลิบง", "92110"),
            ("คลองชีล้อม", "92110"),
        ],
        "ย่านตาขาว": [
            ("ย่านตาขาว", "92140"),
            ("นาชุมเห็ด", "92140"),
            ("โพรงจระเข้", "92140"),
            ("ทุ่งค่าย", "92140"),
        ],
        "ปะเหลียน": [
            ("ปะเหลียน", "92180"),
            ("บางด้วน", "92140"),
            ("บ้านนา", "92140"),
            ("สุโสะ", "92120"),
            ("ลิพัง", "92180"),
            ("ท่าพญา", "92140"),
        ],
        "สิเกา": [
            ("เขาไม้แก้ว", "92150"),
            ("ไม้ฝาด", "92150"),
            ("นาเมืองเพชร", "92000"),
        ],
        "ห้วยยอด": [
            ("ห้วยยอด", "92130"),
            ("หนองช้างแล่น", "92130"),
            ("บางดี", "92210"),
            ("เขากอบ", "92130"),
            ("เขาปูน", "92130"),
            ("ห้วยนาง", "92130"),
            ("ในเตา", "92130"),
            ("วังคีรี", "92210"),
        ],
        "วังวิเศษ": [
            ("เขาวิเศษ", "92220"),
            ("ท่าสะบ้า", "92000"),
            ("วังมะปรางเหนือ", "92220"),
        ],
        "นาโยง": [
            ("ช่อง", "92170"),
            ("นาข้าวเสีย", "92170"),
        ],
        "รัษฎา": [
            ("หนองบัว", "92160"),
            ("เขาไพร", "92160"),
        ],
        "หาดสำราญ": [
            ("ตะเสะ", "92120"),
        ]},
    "ตราด": {
        "เมืองตราด": [
            ("บางพระ", "23000"),
            ("หนองเสม็ด", "23000"),
            ("หนองโสน", "23000"),
            ("หนองคันทรง", "23000"),
            ("ห้วงน้ำขาว", "23000"),
            ("วังกระแจะ", "23000"),
            ("ห้วยแร้ง", "23000"),
            ("เนินทราย", "23000"),
            ("ท่ากุ่ม", "23000"),
        ],
        "คลองใหญ่": [
            ("คลองใหญ่", "23110"),
            ("ไม้รูด", "23110"),
        ],
        "เขาสมิง": [
            ("เขาสมิง", "23130"),
        ],
        "บ่อไร่": [
            ("บ่อพลอย", "23140"),
            ("ช้างทูน", "23140"),
            ("ด่านชุมพล", "23140"),
            ("นนทรีย์", "23140"),
        ],
        "แหลมงอบ": [
            ("แหลมงอบ", "23120"),
            ("น้ำเชี่ยว", "23120"),
        ],
        "เกาะช้าง": [
            ("เกาะช้าง", "23170"),
            ("เกาะช้างใต้", "23170"),
        ],
        "เมืองตราด": [
            ("อ่าวใหญ่", "23000"),
            ("ท่าพริก", "23000"),
            ("ตะกาง", "23000"),
            ("ชำราก", "23000"),
            ("แหลมกลัด", "23000"),
        ],
        "คลองใหญ่": [
            ("หาดเล็ก", "23110"),
        ],
        "เขาสมิง": [
            ("แสนตุ้ง", "23150"),
            ("วังตะเคียน", "23130"),
            ("ท่าโสม", "23150"),
            ("สะตอ", "23150"),
            ("ประณีต", "23150"),
            ("เทพนิมิต", "23150"),
            ("ทุ่งนนทรี", "23130"),
        ],
        "บ่อไร่": [
            ("หนองบอน", "23140"),
        ],
        "แหลมงอบ": [
            ("บางปิด", "23120"),
            ("คลองใหญ่", "23120"),
        ],
        "เกาะกูด": [
            ("เกาะหมาก", "23000"),
            ("เกาะกูด", "23000"),
        ]},
    "ตาก": {
        "เมืองตาก": [
            ("เชียงเงิน", "63000"),
            ("ไม้งาม", "63000"),
            ("น้ำรึม", "63000"),
            ("วังหิน", "63000"),
        ],
        "บ้านตาก": [
            ("ตากออก", "63120"),
            ("สมอโคน", "63120"),
            ("ตากตก", "63120"),
            ("เกาะตะเภา", "63120"),
            ("ทุ่งกระเชาะ", "63120"),
        ],
        "สามเงา": [
            ("ยกกระบัตร", "63130"),
            ("ย่านรี", "63130"),
            ("บ้านนา", "63130"),
        ],
        "แม่ระมาด": [
            ("แม่จะเรา", "63140"),
            ("ขะเนจื้อ", "63140"),
            ("แม่ตื่น", "63140"),
            ("พระธาตุ", "63140"),
        ],
        "ท่าสองยาง": [
            ("แม่สอง", "63150"),
            ("แม่หละ", "63150"),
            ("แม่วะหลวง", "63150"),
            ("แม่อุสุ", "63150"),
        ],
        "แม่สอด": [
            ("แม่กุ", "63110"),
            ("พะวอ", "63110"),
            ("ด่านแม่ละเมา", "63110"),
        ],
        "พบพระ": [
            ("คีรีราษฎร์", "63160"),
            ("รวมไทยพัฒนา", "63160"),
        ],
        "อุ้มผาง": [
            ("อุ้มผาง", "63170"),
            ("หนองหลวง", "63170"),
            ("แม่ละมุ้ง", "63170"),
        ],
        "วังเจ้า": [
            ("นาโบสถ์", "63000"),
            ("นาโบสถ์", "63180"),
        ],
        "เมืองตาก": [
            ("ระแหง", "63000"),
            ("หนองหลวง", "63000"),
            ("หัวเดียด", "63000"),
            ("หนองบัวเหนือ", "63000"),
            ("โป่งแดง", "63000"),
            ("แม่ท้อ", "63000"),
            ("ป่ามะม่วง", "63000"),
            ("หนองบัวใต้", "63000"),
            ("วังประจบ", "63000"),
            ("ตลุกกลางทุ่ง", "63000"),
        ],
        "บ้านตาก": [
            ("แม่สลิด", "63120"),
            ("ท้องฟ้า", "63120"),
        ],
        "สามเงา": [
            ("สามเงา", "63130"),
            ("วังหมัน", "63130"),
            ("วังจันทร์", "63130"),
        ],
        "แม่ระมาด": [
            ("แม่ระมาด", "63140"),
            ("สามหมื่น", "63140"),
        ],
        "ท่าสองยาง": [
            ("ท่าสองยาง", "63150"),
            ("แม่ต้าน", "63150"),
        ],
        "แม่สอด": [
            ("แม่สอด", "63110"),
            ("แม่ตาว", "63110"),
            ("แม่กาษา", "63110"),
            ("ท่าสายลวด", "63110"),
            ("แม่ปะ", "63110"),
            ("มหาวัน", "63110"),
            ("พระธาตุผาแดง", "63110"),
        ],
        "พบพระ": [
            ("พบพระ", "63160"),
            ("ช่องแคบ", "63160"),
            ("วาเล่ย์", "63160"),
        ],
        "อุ้มผาง": [
            ("โมโกร", "63170"),
            ("แม่จัน", "63170"),
            ("แม่กลอง", "63170"),
        ],
        "วังเจ้า": [
            ("เชียงทอง", "63000"),
            ("เชียงทอง", "63180"),
            ("ประดาง", "63000"),
            ("ประดาง", "63180"),
        ]},
    "นครนายก": {
        "เมืองนครนายก": [
            ("วังกระโจม", "26000"),
            ("ท่าทราย", "26000"),
            ("ศรีจุฬา", "26000"),
            ("ศรีนาวา", "26000"),
            ("สาริกา", "26000"),
            ("หินตั้ง", "26000"),
            ("พรหมณี", "26000"),
            ("พรหมณี", "26001"),
        ],
        "ปากพลี": [
            ("เกาะหวาย", "26130"),
            ("ปากพลี", "26130"),
            ("หนองแสง", "26130"),
        ],
        "บ้านนา": [
            ("อาษา", "26110"),
            ("ทองหลาง", "26110"),
            ("บางอ้อ", "26110"),
            ("เขาเพิ่ม", "26110"),
            ("ศรีกะอาง", "26110"),
        ],
        "องครักษ์": [
            ("บางสมบูรณ์", "26120"),
            ("บางปลากด", "26120"),
            ("ชุมพล", "26120"),
        ],
        "เมืองนครนายก": [
            ("นครนายก", "26000"),
            ("ท่าช้าง", "26000"),
            ("บ้านใหญ่", "26000"),
            ("ดอนยอ", "26000"),
            ("ดงละคร", "26000"),
            ("เขาพระ", "26000"),
        ],
        "ปากพลี": [
            ("เกาะโพธิ์", "26130"),
            ("โคกกรวด", "26130"),
            ("ท่าเรือ", "26130"),
            ("นาหินลาด", "26130"),
        ],
        "บ้านนา": [
            ("บ้านนา", "26110"),
            ("บ้านพร้าว", "26110"),
            ("บ้านพริก", "26110"),
            ("พิกุลออก", "26110"),
            ("ป่าขะ", "26110"),
        ],
        "องครักษ์": [
            ("พระอาจารย์", "26120"),
            ("บึงศาล", "26120"),
            ("ศีรษะกระบือ", "26120"),
            ("โพธิ์แทน", "26120"),
            ("ทรายมูล", "26120"),
            ("บางลูกเสือ", "26120"),
            ("องครักษ์", "26120"),
            ("คลองใหญ่", "26120"),
        ]},
    "นครปฐม": {
        "เมืองนครปฐม": [
            ("ตาก้อง", "73000"),
            ("มาบแค", "73000"),
            ("สนามจันทร์", "73000"),
            ("ถนนขาด", "73000"),
            ("นครปฐม", "73000"),
            ("วังตะกู", "73000"),
            ("หนองปากโลง", "73000"),
            ("หนองดินแดง", "73000"),
            ("วังเย็น", "73000"),
            ("โพรงมะเดื่อ", "73000"),
            ("ลำพยา", "73000"),
            ("ทัพหลวง", "73000"),
            ("หนองงูเหลือม", "73000"),
            ("บ้านยาง", "73000"),
        ],
        "กำแพงแสน": [
            ("ทุ่งกระพังโหม", "73140"),
            ("กระตีบ", "73180"),
            ("ทุ่งขวาง", "73140"),
            ("สระพัฒนา", "73180"),
            ("ห้วยหมอนทอง", "73140"),
            ("ห้วยม่วง", "73180"),
            ("กำแพงแสน", "73140"),
            ("รางพิกุล", "73140"),
            ("หนองกระทุ่ม", "73140"),
            ("วังน้ำเขียว", "73140"),
        ],
        "นครชัยศรี": [
            ("ท่ากระชับ", "73120"),
            ("ท่าพระยา", "73120"),
            ("พะเนียด", "73120"),
            ("บางระกำ", "73120"),
            ("โคกพระเจดีย์", "73120"),
            ("แหลมบัว", "73120"),
            ("ศรีมหาโพธิ์", "73120"),
            ("สัมปทวน", "73120"),
            ("วัดสำโรง", "73120"),
            ("ดอนแฝก", "73120"),
            ("วัดละมุด", "73120"),
            ("บางแก้วฟ้า", "73120"),
            ("ไทยาวาส", "73120"),
        ],
        "ดอนตูม": [
            ("ห้วยพระ", "73150"),
            ("ลำเหย", "73150"),
            ("ดอนรวก", "73150"),
            ("ห้วยด้วน", "73150"),
            ("ลำลูกบัว", "73150"),
        ],
        "บางเลน": [
            ("บางหลวง", "73190"),
            ("บางภาษี", "73130"),
            ("หินมูล", "73190"),
            ("ดอนตูม", "73130"),
            ("คลองนกกระทุง", "73130"),
            ("นราภิรมย์", "73130"),
            ("ไผ่หูช้าง", "73130"),
        ],
        "สามพราน": [
            ("ทรงคนอง", "73110"),
            ("บางเตย", "73110"),
            ("สามพราน", "73110"),
            ("ไร่ขิง", "73110"),
            ("ไร่ขิง", "73210"),
            ("ท่าตลาด", "73110"),
            ("คลองจินดา", "73110"),
            ("อ้อมใหญ่", "73160"),
        ],
        "เมืองนครปฐม": [
            ("พระปฐมเจดีย์", "73000"),
            ("บางแขม", "73000"),
            ("พระประโทน", "73000"),
            ("ธรรมศาลา", "73000"),
            ("ดอนยายหอม", "73000"),
            ("บ่อพลับ", "73000"),
            ("สามควายเผือก", "73000"),
            ("ทุ่งน้อย", "73000"),
            ("สระกะเทียม", "73000"),
            ("สวนป่าน", "73000"),
            ("ห้วยจรเข้", "73000"),
        ],
        "กำแพงแสน": [
            ("ทุ่งลูกนก", "73140"),
            ("ห้วยขวาง", "73140"),
            ("สระสี่มุม", "73140"),
            ("ทุ่งบัว", "73140"),
            ("ดอนข่อย", "73140"),
        ],
        "นครชัยศรี": [
            ("นครชัยศรี", "73120"),
            ("บางกระเบา", "73120"),
            ("วัดแค", "73120"),
            ("ท่าตำหนัก", "73120"),
            ("บางแก้ว", "73120"),
            ("ขุนแก้ว", "73120"),
            ("ศรีษะทอง", "73120"),
            ("ห้วยพลู", "73120"),
            ("บางพระ", "73120"),
            ("ลานตากฟ้า", "73120"),
            ("งิ้วราย", "73120"),
        ],
        "ดอนตูม": [
            ("สามง่าม", "73150"),
            ("ดอนพุทรา", "73150"),
            ("บ้านหลวง", "73150"),
        ],
        "บางเลน": [
            ("บางเลน", "73130"),
            ("บางปลา", "73130"),
            ("บางระกำ", "73130"),
            ("บางไทรป่า", "73130"),
            ("ไทรงาม", "73130"),
            ("นิลเพชร", "73130"),
            ("บัวปากท่า", "73130"),
            ("ลำพญา", "73130"),
        ],
        "สามพราน": [
            ("ท่าข้าม", "73110"),
            ("ทรงคนอง", "73210"),
            ("หอมเกร็ด", "73110"),
            ("บางกระทึก", "73110"),
            ("บางกระทึก", "73210"),
            ("บางเตย", "73210"),
            ("บางช้าง", "73110"),
            ("กระทุ่มล้ม", "73220"),
            ("คลองใหม่", "73110"),
            ("ตลาดจินดา", "73110"),
            ("ยายชา", "73110"),
            ("บ้านใหม่", "73110"),
        ],
        "พุทธมณฑล": [
            ("ศาลายา", "73170"),
            ("คลองโยง", "73170"),
            ("มหาสวัสดิ์", "73170"),
        ],
        "เมือง": [
            ("บ่อพลับ", "73000"),
        ]},
    "นครพนม": {
        "เมืองนครพนม": [
            ("ในเมือง", "48000"),
            ("นาทราย", "48000"),
            ("นาราชควาย", "48000"),
            ("กุรุคุ", "48000"),
            ("บ้านผึ้ง", "48000"),
            ("อาจสามารถ", "48000"),
            ("ท่าค้อ", "48000"),
            ("หนองญาติ", "48000"),
            ("วังตามัว", "48000"),
        ],
        "ปลาปาก": [
            ("หนองฮี", "48160"),
            ("โคกสว่าง", "48160"),
            ("มหาชัย", "48160"),
        ],
        "ท่าอุเทน": [
            ("ท่าอุเทน", "48120"),
            ("โนนตาล", "48120"),
            ("พนอม", "48120"),
            ("หนองเทา", "48120"),
        ],
        "บ้านแพง": [
            ("โพนทอง", "48140"),
            ("หนองแวง", "48140"),
            ("นางัว", "48140"),
        ],
        "ธาตุพนม": [
            ("ธาตุพนม", "48110"),
            ("ฝั่งแดง", "48110"),
            ("โพนแพง", "48110"),
            ("นาถ่อน", "48110"),
            ("ดอนนางหงส์", "48110"),
            ("น้ำก่ำ", "48110"),
        ],
        "เรณูนคร": [
            ("เรณู", "48170"),
            ("หนองย่างชิ้น", "48170"),
            ("นาขาม", "48170"),
        ],
        "นาแก": [
            ("นาคู่", "48130"),
            ("พิมาน", "48130"),
            ("พุ่มแก", "48130"),
            ("หนองบ่อ", "48130"),
            ("บ้านแก้ง", "48130"),
            ("สีชมพู", "48130"),
        ],
        "ศรีสงคราม": [
            ("ศรีสงคราม", "48150"),
            ("สามผง", "48150"),
            ("บ้านข่า", "48150"),
            ("โพนสว่าง", "48150"),
            ("หาดแพง", "48150"),
        ],
        "นาหว้า": [
            ("นาหว้า", "48180"),
            ("ท่าเรือ", "48180"),
        ],
        "โพนสวรรค์": [
            ("โพนสวรรค์", "48190"),
            ("นาหัวบ่อ", "48190"),
            ("บ้านค้อ", "48190"),
            ("โพนจาน", "48190"),
        ],
        "นาทม": [
            ("หนองซน", "48140"),
        ],
        "วังยาง": [
            ("ยอดชาด", "48130"),
        ],
        "เมืองนครพนม": [
            ("หนองแสง", "48000"),
            ("ขามเฒ่า", "48000"),
            ("บ้านกลาง", "48000"),
            ("คำเตย", "48000"),
            ("ดงขวาง", "48000"),
            ("โพธิ์ตาก", "48000"),
        ],
        "ปลาปาก": [
            ("ปลาปาก", "48160"),
            ("กุตาไก้", "48160"),
            ("โคกสูง", "48160"),
            ("นามะเขือ", "48160"),
            ("หนองเทาใหญ่", "48160"),
        ],
        "ท่าอุเทน": [
            ("ท่าจำปา", "48120"),
            ("ไชยบุรี", "48120"),
            ("พะทาย", "48120"),
            ("เวินพระบาท", "48120"),
            ("รามราช", "48120"),
        ],
        "บ้านแพง": [
            ("บ้านแพง", "48140"),
            ("ไผ่ล้อม", "48140"),
            ("นาเข", "48140"),
        ],
        "ธาตุพนม": [
            ("พระกลางทุ่ง", "48110"),
            ("แสนพัน", "48110"),
            ("อุ่มเหม้า", "48110"),
            ("นาหนาด", "48110"),
            ("กุดฉิม", "48110"),
            ("ธาตุพนมเหนือ", "48110"),
        ],
        "เรณูนคร": [
            ("โพนทอง", "48170"),
            ("ท่าลาด", "48170"),
            ("นางาม", "48170"),
            ("โคกหินแฮ่", "48170"),
            ("เรณูใต้", "48170"),
        ],
        "นาแก": [
            ("นาแก", "48130"),
            ("พระซอง", "48130"),
            ("หนองสังข์", "48130"),
            ("ก้านเหลือง", "48130"),
            ("นาเลียง", "48130"),
            ("คำพี้", "48130"),
        ],
        "ศรีสงคราม": [
            ("นาเดื่อ", "48150"),
            ("บ้านเอื้อง", "48150"),
            ("ท่าบ่อสงคราม", "48150"),
            ("นาคำ", "48150"),
        ],
        "นาหว้า": [
            ("นางัว", "48180"),
            ("บ้านเสียว", "48180"),
            ("นาคูณใหญ่", "48180"),
            ("เหล่าพัฒนา", "48180"),
        ],
        "โพนสวรรค์": [
            ("นาขมิ้น", "48190"),
            ("โพนบก", "48190"),
            ("นาใน", "48190"),
        ],
        "นาทม": [
            ("นาทม", "48140"),
            ("ดอนเตย", "48140"),
        ],
        "วังยาง": [
            ("วังยาง", "48130"),
            ("โคกสี", "48130"),
            ("หนองโพธิ์", "48130"),
        ]},
    "นครราชสีมา": {
        "เมืองนครราชสีมา": [
            ("ในเมือง", "30000"),
            ("หนองระเวียง", "30000"),
            ("ปรุใหญ่", "30000"),
            ("หัวทะเล", "30000"),
            ("บ้านเกาะ", "30000"),
            ("บ้านใหม่", "30000"),
            ("บ้านโพธิ์", "30310"),
            ("จอหอ", "30310"),
            ("จอหอ", "30000"),
            ("หนองบัวศาลา", "30000"),
            ("สุรนารี", "30000"),
            ("ตลาด", "30310"),
            ("ตลาด", "30000"),
            ("พะเนา", "30000"),
        ],
        "ครบุรี": [
            ("แชะ", "30250"),
            ("เฉลียง", "30250"),
            ("ครบุรี", "30250"),
            ("มาบตะโกเอน", "30250"),
            ("บ้านใหม่", "30250"),
            ("ครบุรีใต้", "30250"),
            ("ตะแบกบาน", "30250"),
            ("สระว่านพระยา", "30250"),
        ],
        "เสิงสาง": [
            ("เสิงสาง", "30330"),
            ("สุขไพบูลย์", "30330"),
            ("บ้านราษฎร์", "30330"),
        ],
        "คง": [
            ("หนองบัว", "30260"),
            ("โนนเต็ง", "30260"),
        ],
        "บ้านเหลื่อม": [
            ("วังโพธิ์", "30350"),
            ("โคกกระเบื้อง", "30350"),
        ],
        "จักราช": [
            ("จักราช", "30230"),
            ("หนองพลวง", "30230"),
            ("ศรีละกอ", "30230"),
        ],
        "โชคชัย": [
            ("กระโทก", "30190"),
            ("พลับพลา", "30190"),
            ("ท่าอ่าง", "30190"),
            ("ท่าลาดขาว", "30190"),
            ("ด่านเกวียน", "30190"),
        ],
        "ด่านขุนทด": [
            ("ด่านขุนทด", "30210"),
            ("บ้านแปรง", "36220"),
            ("หนองกราด", "30210"),
            ("หนองบัวตะเกียด", "30210"),
            ("หนองบัวละคร", "30210"),
            ("หนองไทร", "36220"),
        ],
        "โนนไทย": [
            ("โนนไทย", "30220"),
            ("กำปัง", "30220"),
            ("ถนนโพธิ์", "30220"),
            ("มะค่า", "30220"),
        ],
        "โนนสูง": [
            ("โนนสูง", "30160"),
            ("โตนด", "30160"),
            ("บิง", "30160"),
            ("ธารปราสาท", "30240"),
            ("ธารปราสาท", "30420"),
            ("หลุมข้าว", "30160"),
            ("มะค่า", "30160"),
            ("พลสงคราม", "30160"),
            ("จันอัด", "30160"),
            ("ด่านคล้า", "30160"),
            ("ลำคอหงษ์", "30160"),
            ("เมืองปราสาท", "30160"),
            ("ดอนหวาย", "30160"),
        ],
        "ขามสะแกแสง": [
            ("เมืองนาท", "30290"),
            ("หนองหัวฟาน", "30290"),
        ],
        "บัวใหญ่": [
            ("บัวใหญ่", "30120"),
            ("ห้วยยาง", "30120"),
            ("หนองบัวสะอาด", "30120"),
            ("ด่านช้าง", "30120"),
            ("ขุนทอง", "30120"),
            ("หนองแจ้งใหญ่", "30120"),
        ],
        "ประทาย": [
            ("วังไม้แดง", "30180"),
            ("ตลาดไทร", "30180"),
            ("หนองค่าย", "30180"),
            ("ดอนมัน", "30180"),
        ],
        "ปักธงชัย": [
            ("โคกไทย", "30150"),
            ("สำโรง", "30150"),
            ("นกออก", "30150"),
            ("เกษมทรัพย์", "30150"),
            ("บ่อปลาทอง", "30150"),
        ],
        "พิมาย": [
            ("โบสถ์", "30110"),
            ("กระเบื้องใหญ่", "30110"),
            ("ชีวาน", "30110"),
            ("กระชอน", "30110"),
            ("หนองระเวียง", "30110"),
        ],
        "ห้วยแถลง": [
            ("ทับสวาย", "30240"),
            ("หลุ่งตะเคียน", "30240"),
            ("หินดาด", "30240"),
            ("หลุ่งประดู่", "30240"),
            ("ห้วยแคน", "30240"),
        ],
        "ชุมพวง": [
            ("ประสุข", "30270"),
            ("ตลาดไทร", "30270"),
            ("โนนตูม", "30270"),
        ],
        "สูงเนิน": [
            ("สูงเนิน", "30170"),
            ("เสมา", "30170"),
            ("บุ่งขี้เหล็ก", "30170"),
            ("โนนค่า", "30170"),
            ("โค้งยาง", "30170"),
            ("มะเกลือเก่า", "30170"),
            ("นากลาง", "30380"),
            ("หนองตะไก้", "30380"),
            ("กุดจิก", "30380"),
        ],
        "ขามทะเลสอ": [
            ("โป่งแดง", "30280"),
            ("บึงอ้อ", "30280"),
        ],
        "สีคิ้ว": [
            ("บ้านหัน", "30140"),
            ("ลาดบัวขาว", "30340"),
            ("หนองหญ้าขาว", "30140"),
            ("กุดน้อย", "30140"),
            ("หนองน้ำใส", "30140"),
            ("มิตรภาพ", "30140"),
            ("คลองไผ่", "30140"),
            ("คลองไผ่", "30340"),
            ("ดอนเมือง", "30140"),
        ],
        "ปากช่อง": [
            ("วังกะทะ", "30320"),
            ("หมูสี", "30320"),
            ("หมูสี", "30450"),
            ("หนองสาหร่าย", "30320"),
            ("ขนงพระ", "30320"),
            ("ขนงพระ", "30130"),
            ("ขนงพระ", "30450"),
            ("โป่งตาลอง", "30130"),
            ("คลองม่วง", "30320"),
            ("คลองม่วง", "30130"),
            ("หนองน้ำแดง", "30130"),
            ("หนองน้ำแดง", "30450"),
            ("วังไทร", "30130"),
        ],
        "หนองบุญมาก": [
            ("สารภี", "30410"),
            ("ไทยเจริญ", "30410"),
            ("หนองหัวแรต", "30410"),
            ("ลุงเขว้า", "30410"),
            ("บ้านใหม่", "30410"),
        ],
        "แก้งสนามนาง": [
            ("บึงพะไล", "30440"),
            ("บึงสำโรง", "30440"),
        ],
        "โนนแดง": [
            ("โนนแดง", "30360"),
            ("สำพะเนียง", "30360"),
            ("วังหิน", "30360"),
            ("ดอนยาวใหญ่", "30360"),
        ],
        "วังน้ำเขียว": [
            ("วังน้ำเขียว", "30370"),
            ("ระเริง", "30150"),
            ("อุดมทรัพย์", "30370"),
        ],
        "เทพารักษ์": [
            ("สำนักตะคร้อ", "30210"),
            ("หนองแวง", "30210"),
            ("บึงปรือ", "30210"),
        ],
        "เมืองยาง": [
            ("เมืองยาง", "30270"),
            ("กระเบื้องนอก", "30270"),
            ("ละหานปลาค้าว", "30270"),
            ("โนนอุดม", "30270"),
        ],
        "พระทองคำ": [
            ("สระพระ", "30220"),
            ("พังเทียม", "30220"),
        ],
        "ลำทะเมนชัย": [
            ("บ้านยาง", "30270"),
        ],
        "บัวลาย": [
            ("โนนจาน", "30120"),
            ("บัวลาย", "30120"),
            ("หนองหว้า", "30120"),
        ],
        "สีดา": [
            ("โพนทอง", "30430"),
            ("โนนประดู่", "30430"),
            ("สามเมือง", "30430"),
        ],
        "เฉลิมพระเกียรติ": [
            ("หนองยาง", "30230"),
        ],
        "เมืองนครราชสีมา": [
            ("โพธิ์กลาง", "30000"),
            ("หนองจะบก", "30000"),
            ("โคกสูง", "30310"),
            ("โคกสูง", "30000"),
            ("มะเริง", "30000"),
            ("หมื่นไวย", "30000"),
            ("พลกรัง", "30000"),
            ("หนองไผ่ล้อม", "30000"),
            ("พุดซา", "30000"),
            ("บ้านโพธิ์", "30000"),
            ("โคกกรวด", "30280"),
            ("ไชยมงคล", "30000"),
            ("สีมุม", "30000"),
            ("หนองกระทุ่ม", "30000"),
            ("หนองไข่น้ำ", "30310"),
            ("หนองไข่น้ำ", "30000"),
        ],
        "ครบุรี": [
            ("โคกกระชาย", "30250"),
            ("จระเข้หิน", "30250"),
            ("อรพิมพ์", "30250"),
            ("ลำเพียก", "30250"),
        ],
        "เสิงสาง": [
            ("สระตะเคียน", "30330"),
            ("โนนสมบูรณ์", "30330"),
            ("กุดโบสถ์", "30330"),
        ],
        "คง": [
            ("เมืองคง", "30260"),
            ("คูขาด", "30260"),
            ("เทพาลัย", "30260"),
            ("ตาจั่น", "30260"),
            ("บ้านปรางค์", "30260"),
            ("หนองมะนาว", "30260"),
            ("ดอนใหญ่", "30260"),
            ("ขามสมบูรณ์", "30260"),
        ],
        "บ้านเหลื่อม": [
            ("บ้านเหลื่อม", "30350"),
            ("ช่อระกา", "30350"),
        ],
        "จักราช": [
            ("ทองหลาง", "30230"),
            ("สีสุก", "30230"),
            ("หนองขาม", "30230"),
            ("คลองเมือง", "30230"),
            ("หินโคน", "30230"),
        ],
        "โชคชัย": [
            ("ทุ่งอรุณ", "30190"),
            ("ท่าจะหลุง", "30190"),
            ("ท่าเยี่ยม", "30190"),
            ("โชคชัย", "30190"),
            ("ละลมใหม่พัฒนา", "30190"),
        ],
        "ด่านขุนทด": [
            ("กุดพิมาน", "30210"),
            ("ด่านนอก", "30210"),
            ("ด่านใน", "30210"),
            ("ตะเคียน", "30210"),
            ("บ้านเก่า", "30210"),
            ("พันชนะ", "30210"),
            ("สระจรเข้", "30210"),
            ("หินดาด", "30210"),
            ("ห้วยบง", "30210"),
            ("โนนเมืองพัฒนา", "30210"),
        ],
        "โนนไทย": [
            ("ด่านจาก", "30220"),
            ("สำโรง", "30220"),
            ("ค้างพลู", "30220"),
            ("บ้านวัง", "30220"),
            ("บัลลังก์", "30220"),
            ("สายออ", "30220"),
        ],
        "โนนสูง": [
            ("ใหม่", "30160"),
            ("ดอนชมพู", "30160"),
            ("ขามเฒ่า", "30160"),
            ("ลำมูล", "30160"),
        ],
        "ขามสะแกแสง": [
            ("ขามสะแกแสง", "30290"),
            ("โนนเมือง", "30290"),
            ("ชีวึก", "30290"),
            ("พะงาด", "30290"),
            ("เมืองเกษตร", "30290"),
        ],
        "บัวใหญ่": [
            ("เสมาใหญ่", "30120"),
            ("ดอนตะหนิน", "30120"),
            ("โนนทองหลาง", "30120"),
            ("กุดจอก", "30120"),
        ],
        "ประทาย": [
            ("ประทาย", "30180"),
            ("กระทุ่มราย", "30180"),
            ("หนองพลวง", "30180"),
            ("หันห้วยทราย", "30180"),
            ("นางรำ", "30180"),
            ("โนนเพ็ด", "30180"),
            ("ทุ่งสว่าง", "30180"),
            ("โคกกลาง", "30180"),
            ("เมืองโดน", "30180"),
        ],
        "ปักธงชัย": [
            ("เมืองปัก", "30150"),
            ("ตะคุ", "30150"),
            ("ตะขบ", "30150"),
            ("ดอน", "30150"),
            ("ตูม", "30150"),
            ("งิ้ว", "30150"),
            ("สะแกราช", "30150"),
            ("ลำนางแก้ว", "30150"),
            ("ภูหลวง", "30150"),
            ("ธงชัยเหนือ", "30150"),
            ("สุขเกษม", "30150"),
        ],
        "พิมาย": [
            ("ในเมือง", "30110"),
            ("สัมฤทธิ์", "30110"),
            ("ท่าหลวง", "30110"),
            ("รังกาใหญ่", "30110"),
            ("นิคมสร้างตนเอง", "30110"),
            ("ดงใหญ่", "30110"),
            ("ธารละหลอด", "30110"),
        ],
        "ห้วยแถลง": [
            ("ห้วยแถลง", "30240"),
            ("เมืองพลับพลา", "30240"),
            ("งิ้ว", "30240"),
            ("กงรถ", "30240"),
            ("ตะโก", "30240"),
        ],
        "ชุมพวง": [
            ("ชุมพวง", "30270"),
            ("ท่าลาด", "30270"),
            ("สาหร่าย", "30270"),
            ("โนนรัง", "30270"),
            ("หนองหลัก", "30270"),
            ("โนนยอ", "30270"),
        ],
        "สูงเนิน": [
            ("โคราช", "30170"),
            ("มะเกลือใหม่", "30170"),
        ],
        "ขามทะเลสอ": [
            ("ขามทะเลสอ", "30280"),
            ("พันดุง", "30280"),
            ("หนองสรวง", "30280"),
        ],
        "สีคิ้ว": [
            ("สีคิ้ว", "30140"),
            ("กฤษณา", "30140"),
            ("วังโรงใหญ่", "30140"),
            ("หนองบัวน้อย", "30140"),
        ],
        "ปากช่อง": [
            ("ปากช่อง", "30130"),
            ("กลางดง", "30320"),
            ("จันทึก", "30320"),
            ("จันทึก", "30130"),
            ("วังกะทะ", "30130"),
            ("หมูสี", "30130"),
            ("หนองสาหร่าย", "30130"),
            ("โป่งตาลอง", "30320"),
            ("โป่งตาลอง", "30450"),
            ("หนองน้ำแดง", "30320"),
            ("วังไทร", "30320"),
            ("พญาเย็น", "30320"),
        ],
        "หนองบุญมาก": [
            ("หนองบุนนาก", "30410"),
            ("แหลมทอง", "30410"),
            ("หนองตะไก้", "30410"),
            ("หนองไม้ไผ่", "30410"),
        ],
        "แก้งสนามนาง": [
            ("แก้งสนามนาง", "30440"),
            ("โนนสำราญ", "30440"),
            ("สีสุก", "30440"),
        ],
        "โนนแดง": [
            ("โนนตาเถร", "30360"),
        ],
        "วังน้ำเขียว": [
            ("วังหมี", "30370"),
            ("ไทยสามัคคี", "30370"),
        ],
        "เทพารักษ์": [
            ("วังยายทอง", "30210"),
        ],
        "พระทองคำ": [
            ("มาบกราด", "30220"),
            ("ทัพรั้ง", "30220"),
            ("หนองหอย", "30220"),
        ],
        "ลำทะเมนชัย": [
            ("ขุย", "30270"),
            ("ช่องแมว", "30270"),
            ("ไพล", "30270"),
        ],
        "บัวลาย": [
            ("เมืองพะไล", "30120"),
        ],
        "สีดา": [
            ("สีดา", "30430"),
            ("หนองตาดใหญ่", "30430"),
        ],
        "เฉลิมพระเกียรติ": [
            ("ช้างทอง", "30230"),
            ("ท่าช้าง", "30230"),
            ("พระพุทธ", "30230"),
            ("หนองงูเหลือม", "30000"),
        ]},
    "นครศรีธรรมราช": {
        "เมืองนครศรีธรรมราช": [
            ("ในเมือง", "80000"),
            ("ท่าวัง", "80000"),
            ("ท่าไร่", "80000"),
            ("ปากนคร", "80000"),
            ("กำแพงเซา", "80280"),
            ("ไชยมนตรี", "80000"),
            ("นาเคียน", "80000"),
            ("ท่างิ้ว", "80280"),
            ("ปากพูน", "80000"),
            ("ท่าเรือ", "80290"),
        ],
        "พรหมคีรี": [
            ("บ้านเกาะ", "80320"),
            ("อินคีรี", "80320"),
            ("ทอนหงส์", "80320"),
        ],
        "ลานสกา": [
            ("กำโลน", "80230"),
        ],
        "ฉวาง": [
            ("นาแว", "80150"),
            ("ไม้เรียง", "80150"),
            ("นากะชะ", "80150"),
            ("ห้วยปริก", "80260"),
            ("ไสหร้า", "80150"),
            ("นาเขลียง", "80260"),
        ],
        "พิปูน": [
            ("พิปูน", "80270"),
            ("กะทูน", "80270"),
            ("ยางค้อม", "80270"),
        ],
        "เชียรใหญ่": [
            ("บ้านกลาง", "80190"),
            ("บ้านเนิน", "80190"),
            ("เสือหึง", "80190"),
            ("การะเกด", "80190"),
        ],
        "ชะอวด": [
            ("ชะอวด", "80180"),
            ("ท่าประจะ", "80180"),
            ("เคร็ง", "80180"),
            ("วังอ่าง", "80180"),
            ("บ้านตูล", "80180"),
            ("เขาพระทอง", "80180"),
            ("นางหลง", "80180"),
        ],
        "ท่าศาลา": [
            ("ท่าขึ้น", "80160"),
            ("หัวตะพาน", "80160"),
            ("โมคลาน", "80160"),
            ("ไทยบุรี", "80160"),
            ("ตลิ่งชัน", "80160"),
        ],
        "ทุ่งสง": [
            ("ปากแพรก", "80110"),
            ("ชะมาย", "80110"),
            ("หนองหงส์", "80110"),
            ("ควนกรด", "80110"),
            ("กะปาง", "80310"),
            ("ถ้ำใหญ่", "80110"),
            ("นาโพธิ์", "80110"),
        ],
        "นาบอน": [
            ("ทุ่งสง", "80220"),
            ("แก้วแสน", "80220"),
            ("แก้วแสน", "80250"),
        ],
        "ทุ่งใหญ่": [
            ("ท่ายาง", "80240"),
            ("ปริก", "80240"),
            ("กรุงหยัน", "80240"),
        ],
        "ปากพนัง": [
            ("ปากพนัง", "80140"),
            ("คลองน้อย", "80330"),
            ("ชะเมา", "80330"),
            ("คลองกระบือ", "80140"),
            ("บ้านใหม่", "80140"),
            ("แหลมตะลุมพุก", "80140"),
            ("ปากพนังฝั่งตะวันตก", "80370"),
            ("บางศาลา", "80140"),
            ("บางตะพง", "80140"),
            ("ท่าพยา", "80140"),
            ("ขนาบนาก", "80140"),
        ],
        "ร่อนพิบูลย์": [
            ("เสาธง", "80350"),
            ("ควนเกย", "80130"),
            ("ควนพัง", "80130"),
            ("ควนชุม", "80130"),
        ],
        "สิชล": [
            ("สิชล", "80120"),
            ("ทุ่งปรัง", "80120"),
            ("เสาเภา", "80340"),
            ("เปลี่ยน", "80120"),
        ],
        "ขนอม": [
            ("ควนทอง", "80210"),
        ],
        "หัวไทร": [
            ("แหลม", "80170"),
            ("ท่าซอม", "80170"),
            ("ควนชะลิก", "80170"),
        ],
        "บางขัน": [
            ("บางขัน", "80360"),
            ("บ้านลำนาว", "80360"),
            ("วังหิน", "80360"),
        ],
        "ถ้ำพรรณรา": [
            ("ถ้ำพรรณรา", "80260"),
        ],
        "จุฬาภรณ์": [
            ("ควนหนองคว้า", "80130"),
            ("นาหมอบุญ", "80130"),
            ("สามตำบล", "80130"),
        ],
        "พระพรหม": [
            ("นาสาร", "80000"),
        ],
        "นบพิตำ": [
            ("นบพิตำ", "80160"),
            ("นาเหรง", "80160"),
        ],
        "ช้างกลาง": [
            ("หลักช้าง", "80250"),
            ("สวนขัน", "80250"),
        ],
        "เฉลิมพระเกียรติ": [
            ("เชียรเขา", "80190"),
            ("ดอนตรอ", "80290"),
            ("ทางพูน", "80290"),
        ],
        "เมืองนครศรีธรรมราช": [
            ("คลัง", "80000"),
            ("นาทราย", "80280"),
            ("มะม่วงสองต้น", "80000"),
            ("โพธิ์เสด็จ", "80000"),
            ("บางจาก", "80330"),
            ("ท่าซัก", "80000"),
            ("ท่าเรือ", "80000"),
        ],
        "พรหมคีรี": [
            ("พรหมโลก", "80320"),
            ("นาเรียง", "80320"),
        ],
        "ลานสกา": [
            ("เขาแก้ว", "80230"),
            ("ลานสกา", "80230"),
            ("ท่าดี", "80230"),
            ("ขุนทะเล", "80230"),
        ],
        "ฉวาง": [
            ("ฉวาง", "80150"),
            ("ฉวาง", "80250"),
            ("ละอาย", "80250"),
            ("นาแว", "80260"),
            ("ไม้เรียง", "80260"),
            ("กะเปียด", "80260"),
            ("นากะชะ", "80260"),
            ("จันดี", "80250"),
        ],
        "พิปูน": [
            ("เขาพระ", "80270"),
            ("ควนกลาง", "80270"),
        ],
        "เชียรใหญ่": [
            ("เชียรใหญ่", "80190"),
            ("ท่าขนาน", "80190"),
            ("ไสหมาก", "80190"),
            ("ท้องลำเจียก", "80190"),
            ("เขาพระบาท", "80190"),
            ("แม่เจ้าอยู่หัว", "80190"),
        ],
        "ชะอวด": [
            ("ท่าเสม็ด", "80180"),
            ("ขอนหาด", "80180"),
            ("เกาะขันธ์", "80180"),
            ("ควนหนองหงษ์", "80180"),
        ],
        "ท่าศาลา": [
            ("ท่าศาลา", "80160"),
            ("กลาย", "80160"),
            ("สระแก้ว", "80160"),
            ("ดอนตะโก", "80160"),
            ("โพธิ์ทอง", "80160"),
        ],
        "ทุ่งสง": [
            ("นาไม้ไผ่", "80110"),
            ("นาหลวงเสน", "80110"),
            ("เขาโร", "80110"),
            ("เขาโร", "80310"),
            ("ที่วัง", "80110"),
            ("ที่วัง", "80310"),
            ("น้ำตก", "80110"),
            ("เขาขาว", "80110"),
        ],
        "นาบอน": [
            ("นาบอน", "80220"),
        ],
        "ทุ่งใหญ่": [
            ("ทุ่งสัง", "80240"),
            ("ทุ่งใหญ่", "80240"),
            ("กุแหระ", "80240"),
            ("บางรูป", "80240"),
        ],
        "ปากพนัง": [
            ("ป่าระกำ", "80140"),
            ("เกาะทวด", "80330"),
            ("หูล่อง", "80140"),
            ("ปากพนังฝั่งตะวันตก", "80140"),
            ("บางพระ", "80140"),
            ("ปากพนังฝั่งตะวันออก", "80140"),
            ("บ้านเพิง", "80140"),
            ("ปากแพรก", "80140"),
        ],
        "ร่อนพิบูลย์": [
            ("ร่อนพิบูลย์", "80130"),
            ("หินตก", "80350"),
        ],
        "สิชล": [
            ("ฉลอง", "80120"),
            ("สี่ขีด", "80120"),
            ("เทพราช", "80340"),
            ("เขาน้อย", "80120"),
            ("ทุ่งใส", "80120"),
        ],
        "ขนอม": [
            ("ขนอม", "80210"),
            ("ท้องเนียน", "80210"),
        ],
        "หัวไทร": [
            ("หัวไทร", "80170"),
            ("หน้าสตน", "80170"),
            ("ทรายขาว", "80170"),
            ("เขาพังไกร", "80170"),
            ("บ้านราม", "80170"),
            ("บางนบ", "80170"),
            ("รามแก้ว", "80170"),
            ("เกาะเพชร", "80170"),
        ],
        "บางขัน": [
            ("บ้านนิคม", "80360"),
        ],
        "ถ้ำพรรณรา": [
            ("คลองเส", "80260"),
            ("ดุสิต", "80260"),
        ],
        "จุฬาภรณ์": [
            ("บ้านควนมุด", "80180"),
            ("บ้านชะอวด", "80180"),
            ("ทุ่งโพธิ์", "80130"),
        ],
        "พระพรหม": [
            ("นาพรุ", "80000"),
            ("ท้ายสำเภา", "80000"),
            ("ช้างซ้าย", "80000"),
        ],
        "นบพิตำ": [
            ("กรุงชิง", "80160"),
            ("กะหรอ", "80160"),
        ],
        "ช้างกลาง": [
            ("ช้างกลาง", "80250"),
        ],
        "เฉลิมพระเกียรติ": [
            ("สวนหลวง", "80190"),
            ("ทางพูน", "80190"),
        ]},
    "นครสวรรค์": {
        "เมืองนครสวรรค์": [
            ("ปากน้ำโพ", "60000"),
            ("ตะเคียนเลื่อน", "60000"),
            ("บางพระหลวง", "60000"),
            ("วัดไทร", "60000"),
            ("หนองกระโดน", "60240"),
            ("หนองปลิง", "60000"),
            ("บึงเสนาท", "60000"),
            ("วัดไทรย์", "60000"),
        ],
        "โกรกพระ": [
            ("บางมะฝ่อ", "60170"),
            ("บางประมุง", "60170"),
            ("เนินกว้าว", "60170"),
            ("เนินศาลา", "60170"),
        ],
        "ชุมแสง": [
            ("ชุมแสง", "60120"),
            ("ทับกฤช", "60250"),
            ("เกยไชย", "60120"),
            ("ท่าไม้", "60120"),
            ("หนองกระเจา", "60120"),
            ("พันลาน", "60250"),
            ("โคกหม้อ", "60120"),
            ("ไผ่สิงห์", "60120"),
            ("ฆะมัง", "60120"),
            ("ทับกฤชใต้", "60250"),
        ],
        "หนองบัว": [
            ("หนองกลับ", "60110"),
            ("ธารทหาร", "60110"),
            ("ห้วยร่วม", "60110"),
            ("ทุ่งทอง", "60110"),
            ("วังบ่อ", "60110"),
        ],
        "บรรพตพิสัย": [
            ("บางตาหงาย", "60180"),
            ("หูกวาง", "60180"),
            ("อ่างทอง", "60180"),
            ("บางแก้ว", "60180"),
            ("ตาสัง", "60180"),
            ("ด่านช้าง", "60180"),
            ("หนองตางู", "60180"),
            ("บึงปลาทู", "60180"),
        ],
        "เก้าเลี้ยว": [
            ("มหาโพธิ", "60230"),
            ("เก้าเลี้ยว", "60230"),
            ("เขาดิน", "60230"),
        ],
        "ตาคลี": [
            ("ช่องแค", "60210"),
            ("จันเสน", "60260"),
            ("หนองโพ", "60140"),
            ("หนองหม้อ", "60140"),
        ],
        "ท่าตะโก": [
            ("ท่าตะโก", "60160"),
            ("หัวถนน", "60160"),
            ("สายลำโพง", "60160"),
            ("ทำนบ", "60160"),
        ],
        "ไพศาลี": [
            ("โคกเดื่อ", "60220"),
            ("ตะคร้อ", "60220"),
            ("วังข่อย", "60220"),
            ("นาขอม", "60220"),
            ("ไพศาลี", "60220"),
        ],
        "พยุหะคีรี": [
            ("พยุหะ", "60130"),
            ("เนินมะกอก", "60130"),
            ("นิคมเขาบ่อแก้ว", "60130"),
            ("ยางขาว", "60130"),
            ("เขาทอง", "60130"),
            ("ท่าน้ำอ้อย", "60130"),
            ("น้ำทรง", "60130"),
            ("เขากะลา", "60130"),
        ],
        "ลาดยาว": [
            ("ห้วยน้ำหอม", "60150"),
            ("วังเมือง", "60150"),
            ("มาบแก", "60150"),
            ("หนองยาว", "60150"),
            ("บ้านไร่", "60150"),
            ("เนินขี้เหล็ก", "60150"),
            ("ศาลเจ้าไก่ต่อ", "60150"),
            ("สระแก้ว", "60150"),
        ],
        "ตากฟ้า": [
            ("ตากฟ้า", "60190"),
            ("ลำพยนต์", "60190"),
            ("หนองพิกุล", "60190"),
            ("เขาชายธง", "60190"),
        ],
        "แม่วงก์": [
            ("แม่วงก์", "60150"),
            ("เขาชนกัน", "60150"),
        ],
        "ชุมตาบง": [
            ("ชุมตาบง", "60150"),
            ("ปางสวรรค์", "60150"),
        ],
        "เมืองนครสวรรค์": [
            ("กลางแดด", "60000"),
            ("เกรียงไกร", "60000"),
            ("แควใหญ่", "60000"),
            ("นครสวรรค์ตก", "60000"),
            ("นครสวรรค์ออก", "60000"),
            ("บางม่วง", "60000"),
            ("บ้านมะเกลือ", "60000"),
            ("บ้านแก่ง", "60000"),
            ("พระนอน", "60000"),
            ("หนองกรด", "60240"),
        ],
        "โกรกพระ": [
            ("โกรกพระ", "60170"),
            ("ยางตาล", "60170"),
            ("นากลาง", "60170"),
            ("ศาลาแดง", "60170"),
            ("หาดสูง", "60170"),
        ],
        "ชุมแสง": [
            ("พิกุล", "60120"),
            ("บางเคียน", "60120"),
        ],
        "หนองบัว": [
            ("หนองบัว", "60110"),
            ("ห้วยถั่วใต้", "60110"),
            ("ห้วยถั่วเหนือ", "60110"),
            ("ห้วยใหญ่", "60110"),
        ],
        "บรรพตพิสัย": [
            ("ท่างิ้ว", "60180"),
            ("บ้านแดน", "60180"),
            ("ตาขีด", "60180"),
            ("หนองกรด", "60180"),
            ("เจริญผล", "60180"),
        ],
        "เก้าเลี้ยว": [
            ("หนองเต่า", "60230"),
            ("หัวดง", "60230"),
        ],
        "ตาคลี": [
            ("ตาคลี", "60140"),
            ("ห้วยหอม", "60210"),
            ("หัวหวาย", "60140"),
            ("สร้อยทอง", "60210"),
            ("ลาดทิพรส", "60260"),
            ("พรหมนิมิต", "60210"),
        ],
        "ท่าตะโก": [
            ("พนมรอก", "60160"),
            ("วังมหากร", "60160"),
            ("ดอนคา", "60160"),
            ("วังใหญ่", "60160"),
            ("พนมเศษ", "60160"),
            ("หนองหลวง", "60160"),
        ],
        "ไพศาลี": [
            ("สำโรงชัย", "60220"),
            ("วังน้ำลัด", "60220"),
            ("โพธิ์ประสาท", "60220"),
        ],
        "พยุหะคีรี": [
            ("ม่วงหัก", "60130"),
            ("ย่านมัทรี", "60130"),
            ("สระทะเล", "60130"),
        ],
        "ลาดยาว": [
            ("ลาดยาว", "60150"),
            ("วังม้า", "60150"),
            ("สร้อยละคร", "60150"),
            ("หนองนมวัว", "60150"),
        ],
        "ตากฟ้า": [
            ("สุขสำราญ", "60190"),
            ("พุนกยูง", "60190"),
            ("อุดมธัญญา", "60190"),
        ],
        "แม่วงก์": [
            ("แม่เล่ย์", "60150"),
            ("วังซ่าน", "60150"),
        ],
        "แม่เปิน": [
            ("แม่เปิน", "60150"),
        ]},
    "นนทบุรี": {
        "เมืองนนทบุรี": [
            ("สวนใหญ่", "11000"),
            ("บางกระสอ", "11000"),
            ("ท่าทราย", "11000"),
            ("บางไผ่", "11000"),
            ("บางกร่าง", "11000"),
        ],
        "บางกรวย": [
            ("วัดชลอ", "11130"),
            ("บางกรวย", "11130"),
            ("บางขนุน", "11130"),
            ("บางขุนกอง", "11130"),
            ("มหาสวัสดิ์", "11130"),
            ("ปลายบาง", "11130"),
            ("ศาลากลาง", "11130"),
        ],
        "บางใหญ่": [
            ("บางแม่นาง", "11140"),
            ("บางเลน", "11140"),
        ],
        "บางบัวทอง": [
            ("บางบัวทอง", "11110"),
            ("บางรักใหญ่", "11110"),
            ("บางคูรัด", "11110"),
            ("ละหาร", "11110"),
        ],
        "ไทรน้อย": [
            ("ไทรใหญ่", "11150"),
            ("ขุนศรี", "11150"),
        ],
        "ปากเกร็ด": [
            ("ปากเกร็ด", "11120"),
            ("บ้านใหม่", "11120"),
            ("บางตะไนย์", "11120"),
            ("เกาะเกร็ด", "11120"),
            ("อ้อมเกร็ด", "11120"),
            ("คลองข่อย", "11120"),
            ("บางพลับ", "11120"),
        ],
        "เมืองนนทบุรี": [
            ("ตลาดขวัญ", "11000"),
            ("บางเขน", "11000"),
            ("บางศรีเมือง", "11000"),
            ("ไทรม้า", "11000"),
            ("บางรักน้อย", "11000"),
        ],
        "บางกรวย": [
            ("บางสีทอง", "11130"),
            ("บางคูเวียง", "11130"),
        ],
        "บางใหญ่": [
            ("บางม่วง", "11140"),
            ("เสาธงหิน", "11140"),
            ("บางใหญ่", "11140"),
            ("บ้านใหม่", "11140"),
        ],
        "บางบัวทอง": [
            ("โสนลอย", "11110"),
            ("ลำโพ", "11110"),
            ("พิมลราช", "11110"),
            ("บางรักพัฒนา", "11110"),
        ],
        "ไทรน้อย": [
            ("ไทรน้อย", "11150"),
            ("ราษฎร์นิยม", "11150"),
            ("หนองเพรางาย", "11150"),
            ("คลองขวาง", "11150"),
            ("ทวีวัฒนา", "11150"),
        ],
        "ปากเกร็ด": [
            ("บางตลาด", "11120"),
            ("บางพูด", "11120"),
            ("คลองพระอุดม", "11120"),
            ("ท่าอิฐ", "11120"),
            ("คลองเกลือ", "11120"),
        ]},
    "นราธิวาส": {
        "เมืองนราธิวาส": [
            ("ลำภู", "96000"),
            ("บางปอ", "96000"),
        ],
        "ตากใบ": [
            ("เจ๊ะเห", "96110"),
            ("ไพรวัน", "96110"),
            ("ศาลาใหม่", "96110"),
        ],
        "บาเจาะ": [
            ("ลุโบะสาวอ", "96170"),
            ("กาเยาะมาตี", "96170"),
            ("ปะลุกาสาเมาะ", "96170"),
            ("บาเระเหนือ", "96170"),
        ],
        "ยี่งอ": [
            ("จอเบาะ", "96180"),
            ("ลุโบะบือซา", "96180"),
            ("ตะปอเยาะ", "96180"),
        ],
        "ระแงะ": [
            ("ตันหยงมัส", "96130"),
            ("ตันหยงลิมอ", "96130"),
            ("กาลิซา", "96130"),
            ("เฉลิม", "96130"),
            ("มะรือโบตก", "96130"),
        ],
        "รือเสาะ": [
            ("รือเสาะ", "96150"),
            ("สาวอ", "96150"),
            ("ลาโละ", "96150"),
            ("รือเสาะออก", "96150"),
            ("โคกสะตอ", "96150"),
            ("สุวารี", "96150"),
        ],
        "ศรีสาคร": [
            ("เชิงคีรี", "96210"),
            ("กาหลง", "96210"),
            ("ศรีบรรพต", "96210"),
        ],
        "แว้ง": [
            ("กายูคละ", "96160"),
            ("ฆอเลาะ", "96160"),
            ("แม่ดง", "96160"),
            ("เอราวัณ", "96160"),
        ],
        "สุคิริน": [
            ("มาโมง", "96190"),
            ("ภูเขาทอง", "96190"),
        ],
        "สุไหงโก-ลก": [
            ("สุไหงโก-ลก", "96120"),
            ("มูโนะ", "96120"),
            ("ปูโยะ", "96120"),
        ],
        "สุไหงปาดี": [
            ("สากอ", "96140"),
            ("ริโก๋", "96140"),
            ("กาวะ", "96140"),
        ],
        "เจาะไอร้อง": [
            ("จวบ", "96130"),
            ("บูกิต", "96130"),
            ("มะรือโบออก", "96130"),
        ],
        "เมืองนราธิวาส": [
            ("บางนาค", "96000"),
            ("มะนังตายอ", "96000"),
            ("กะลุวอ", "96000"),
            ("กะลุวอเหนือ", "96000"),
            ("โคกเคียน", "96000"),
        ],
        "ตากใบ": [
            ("พร่อน", "96110"),
            ("บางขุนทอง", "96110"),
            ("เกาะสะท้อน", "96110"),
            ("นานาค", "96110"),
            ("โฆษิต", "96110"),
        ],
        "บาเจาะ": [
            ("บาเจาะ", "96170"),
            ("บาเระใต้", "96170"),
        ],
        "ยี่งอ": [
            ("ยี่งอ", "96180"),
            ("ละหาร", "96180"),
            ("ลุโบะบายะ", "96180"),
        ],
        "ระแงะ": [
            ("บองอ", "96130"),
            ("บองอ", "96220"),
            ("บาโงสะโต", "96130"),
        ],
        "รือเสาะ": [
            ("เรียง", "96150"),
            ("สามัคคี", "96150"),
            ("บาตง", "96150"),
        ],
        "ศรีสาคร": [
            ("ซากอ", "96210"),
            ("ตะมะยูง", "96210"),
            ("ศรีสาคร", "96210"),
        ],
        "แว้ง": [
            ("แว้ง", "96160"),
            ("โละจูด", "96160"),
        ],
        "สุคิริน": [
            ("สุคิริน", "96190"),
            ("เกียร์", "96190"),
            ("ร่มไทร", "96190"),
        ],
        "สุไหงโก-ลก": [
            ("ปาเสมัส", "96120"),
        ],
        "สุไหงปาดี": [
            ("ปะลุรู", "96140"),
            ("สุไหงปาดี", "96140"),
            ("โต๊ะเด็ง", "96140"),
        ],
        "จะแนะ": [
            ("จะแนะ", "96220"),
            ("ดุซงญอ", "96220"),
            ("ผดุงมาตร", "96220"),
            ("ช้างเผือก", "96220"),
        ]},
    "น่าน": {
        "เมืองน่าน": [
            ("บ่อ", "55000"),
            ("ผาสิงห์", "55000"),
            ("ถืมตอง", "55000"),
            ("สวก", "55000"),
            ("บ่อสวก", "55000"),
        ],
        "แม่จริม": [
            ("น้ำปาย", "55170"),
        ],
        "บ้านหลวง": [
            ("บ้านฟ้า", "55190"),
            ("ป่าคาหลวง", "55190"),
            ("สวด", "55190"),
            ("บ้านพี้", "55190"),
        ],
        "นาน้อย": [
            ("นาน้อย", "55150"),
            ("สันทะ", "55150"),
            ("บัวใหญ่", "55150"),
        ],
        "ปัว": [
            ("ปัว", "55120"),
            ("ภูคา", "55120"),
            ("สกาด", "55120"),
            ("ป่ากลาง", "55120"),
        ],
        "ท่าวังผา": [
            ("ริม", "55140"),
            ("ยม", "55140"),
            ("จอมพระ", "55140"),
            ("ท่าวังผา", "55140"),
        ],
        "เวียงสา": [
            ("ไหล่น่าน", "55110"),
            ("นาเหลือง", "55110"),
            ("น้ำมวบ", "55110"),
            ("น้ำปั้ว", "55110"),
            ("อ่ายนาไลย", "55110"),
            ("ส้านนาหนองใหม่", "55110"),
            ("แม่ขะนิง", "55110"),
            ("แม่สาคร", "55110"),
        ],
        "ทุ่งช้าง": [
            ("งอบ", "55130"),
            ("และ", "55130"),
            ("ทุ่งช้าง", "55130"),
        ],
        "เชียงกลาง": [
            ("เชียงคาน", "55160"),
            ("พระธาตุ", "55160"),
            ("พญาแก้ว", "55160"),
            ("พระพุทธบาท", "55160"),
        ],
        "นาหมื่น": [
            ("นาทะนุง", "55180"),
            ("บ่อแก้ว", "55180"),
            ("เมืองลี", "55180"),
            ("ปิงหลวง", "55180"),
        ],
        "บ่อเกลือ": [
            ("ภูฟ้า", "55220"),
        ],
        "สองแคว": [
            ("นาไร่หลวง", "55160"),
            ("ยอด", "55160"),
        ],
        "ภูเพียง": [
            ("ม่วงตึ๊ด", "55000"),
            ("นาปัง", "55000"),
            ("น้ำเกี๋ยน", "55000"),
            ("เมืองจัง", "55000"),
            ("ฝายแก้ว", "55000"),
        ],
        "เมืองน่าน": [
            ("ในเวียง", "55000"),
            ("ไชยสถาน", "55000"),
            ("เรือง", "55000"),
            ("นาซาว", "55000"),
            ("ดู่ใต้", "55000"),
            ("กองควาย", "55000"),
            ("สะเนียน", "55000"),
        ],
        "แม่จริม": [
            ("หนองแดง", "55170"),
            ("หมอเมือง", "55170"),
            ("น้ำพาง", "55170"),
            ("แม่จริม", "55170"),
        ],
        "นาน้อย": [
            ("เชียงของ", "55150"),
            ("ศรีษะเกษ", "55150"),
            ("สถาน", "55150"),
            ("น้ำตก", "55150"),
        ],
        "ปัว": [
            ("แงง", "55120"),
            ("สถาน", "55120"),
            ("ศิลาแลง", "55120"),
            ("ศิลาเพชร", "55120"),
            ("อวน", "55120"),
            ("ไชยวัฒนา", "55120"),
            ("เจดีย์ชัย", "55120"),
            ("วรนคร", "55120"),
        ],
        "ท่าวังผา": [
            ("ป่าคา", "55140"),
            ("ผาตอ", "55140"),
            ("ตาลชุม", "55140"),
            ("ศรีภูมิ", "55140"),
            ("แสนทอง", "55140"),
            ("ผาทอง", "55140"),
        ],
        "เวียงสา": [
            ("กลางเวียง", "55110"),
            ("กลางเวียง", "55000"),
            ("ขึ่ง", "55110"),
            ("ตาลชุม", "55110"),
            ("ส้าน", "55110"),
            ("ยาบหัวนา", "55110"),
            ("ปงสนุก", "55110"),
            ("จอมจันทร์", "55110"),
            ("แม่สา", "55110"),
            ("ทุ่งศรีทอง", "55110"),
        ],
        "ทุ่งช้าง": [
            ("ปอน", "55130"),
        ],
        "เชียงกลาง": [
            ("เชียงกลาง", "55160"),
            ("เปือ", "55160"),
        ],
        "สันติสุข": [
            ("ดู่พงษ์", "55210"),
            ("ป่าแลวหลวง", "55210"),
            ("พงษ์", "55210"),
        ],
        "บ่อเกลือ": [
            ("บ่อเกลือเหนือ", "55220"),
            ("บ่อเกลือใต้", "55220"),
            ("ดงพญา", "55220"),
        ],
        "สองแคว": [
            ("ชนแดน", "55160"),
        ],
        "ภูเพียง": [
            ("น้ำแก่น", "55000"),
            ("ท่าน้าว", "55000"),
        ],
        "เฉลิมพระเกียรติ": [
            ("ห้วยโก๋น", "55130"),
            ("ขุนน่าน", "55130"),
        ]},
    "บึงกาฬ": {
        "เซกา": [
            ("บ้านต้อง", "38150"),
            ("ป่งไฮ", "38150"),
            ("โสกก่าม", "38150"),
            ("หนองทุ่ม", "38150"),
        ],
        "โซ่พิสัย": [
            ("โซ่", "38170"),
            ("บัวตูม", "38170"),
            ("ศรีชมภู", "38170"),
            ("หนองพันทา", "38170"),
        ],
        "เมืองบึงกาฬ": [
            ("โคกก่อง", "38000"),
            ("โนนสมบูรณ์", "38000"),
            ("บึงกาฬ", "38000"),
            ("โป่งเปือย", "38000"),
            ("วิศิษฐ์", "38000"),
            ("หนองเลิง", "38000"),
            ("หอคำ", "38000"),
        ],
        "บึงโขงหลง": [
            ("ดงบัง", "38220"),
            ("ท่าดอกคำ", "38220"),
        ],
        "บุ่งคล้า": [
            ("บุ่งคล้า", "38000"),
        ],
        "ปากคาด": [
            ("นากั้ง", "38190"),
            ("โนนศิลา", "38190"),
            ("สมสนุก", "38190"),
            ("หนองยอง", "38190"),
        ],
        "พรเจริญ": [
            ("ดอนหญ้านาง", "38180"),
            ("ป่าแฝก", "38180"),
            ("ศรีสำราญ", "38180"),
        ],
        "ศรีวิไล": [
            ("นาสะแบง", "38210"),
            ("นาสิงห์", "38210"),
            ("นาแสง", "38210"),
            ("ศรีวิไล", "38210"),
        ],
        "เซกา": [
            ("ซาง", "38150"),
            ("เซกา", "38150"),
            ("ท่ากกแดง", "38150"),
            ("ท่าสะอาด", "38150"),
            ("น้ำจั้น", "38150"),
        ],
        "โซ่พิสัย": [
            ("คำแก้ว", "38170"),
            ("ถ้ำเจริญ", "38170"),
            ("เหล่าทอง", "38170"),
        ],
        "เมืองบึงกาฬ": [
            ("คำนาดี", "38000"),
            ("ไคสี", "38000"),
            ("ชัยพร", "38000"),
            ("นาสวรรค์", "38000"),
            ("หนองเข็ง", "38000"),
            ("โนนสว่าง", "38000"),
        ],
        "บึงโขงหลง": [
            ("บึงโขงหลง", "38220"),
            ("โพธิ์หมากแข้ง", "38220"),
        ],
        "บุ่งคล้า": [
            ("โคกกว้าง", "38000"),
            ("หนองเดิ่น", "38000"),
        ],
        "ปากคาด": [
            ("นาดง", "38190"),
            ("ปากคาด", "38190"),
        ],
        "พรเจริญ": [
            ("พรเจริญ", "38180"),
            ("วังชมภู", "38180"),
            ("ศรีชมภู", "38180"),
            ("หนองหัวช้าง", "38180"),
        ],
        "ศรีวิไล": [
            ("ชุมภูพร", "38210"),
        ]},
    "บุรีรัมย์": {
        "เมืองบุรีรัมย์": [
            ("สวายจีก", "31000"),
            ("พระครู", "31000"),
            ("ถลุงเหล็ก", "31000"),
            ("หนองตาด", "31000"),
            ("ลุมปุ๊ก", "31000"),
            ("สองห้อง", "31000"),
            ("กลันทา", "31000"),
            ("กระสัง", "31000"),
            ("เมืองฝาง", "31000"),
        ],
        "คูเมือง": [
            ("คูเมือง", "31190"),
            ("บ้านแพ", "31190"),
            ("หินเหล็กไฟ", "31190"),
            ("ตูมใหญ่", "31190"),
        ],
        "กระสัง": [
            ("กระสัง", "31190"),
            ("สูงเนิน", "31160"),
            ("เมืองไผ่", "31160"),
            ("ชุมแสง", "31160"),
            ("ห้วยสำราญ", "31160"),
        ],
        "นางรอง": [
            ("นางรอง", "31110"),
            ("สะเดา", "31110"),
            ("ชุมแสง", "31110"),
            ("หนองโบสถ์", "31110"),
            ("หนองกง", "31110"),
            ("ถนนหัก", "31110"),
            ("หนองไทร", "31110"),
            ("บ้านสิงห์", "31110"),
            ("หนองยายพิมพ์", "31110"),
            ("หัวถนน", "31110"),
            ("หนองโสน", "31110"),
        ],
        "หนองกี่": [
            ("หนองกี่", "31210"),
            ("เมืองไผ่", "31210"),
            ("ดอนอะราง", "31210"),
            ("ทุ่งกระตาดพัฒนา", "31210"),
            ("ทุ่งกระเต็น", "31210"),
            ("โคกสูง", "31210"),
            ("บุกระสัง", "31210"),
        ],
        "ละหานทราย": [
            ("สำโรงใหม่", "31170"),
            ("โคกว่าน", "31170"),
        ],
        "ประโคนชัย": [
            ("แสลงโทน", "31140"),
            ("ละเวี้ย", "31140"),
            ("ปังกู", "31140"),
            ("โคกย่าง", "31140"),
            ("โคกม้า", "31140"),
            ("ไพศาล", "31140"),
            ("ตะโกตาพิ", "31140"),
            ("โคกมะขาม", "31140"),
            ("สี่เหลี่ยม", "31140"),
        ],
        "บ้านกรวด": [
            ("บ้านกรวด", "31180"),
            ("โนนเจริญ", "31180"),
            ("ปราสาท", "31180"),
            ("สายตะกู", "31180"),
            ("หินลาด", "31180"),
        ],
        "พุทไธสง": [
            ("บ้านจาน", "31120"),
            ("บ้านเป้า", "31120"),
        ],
        "ลำปลายมาศ": [
            ("หนองคู", "31130"),
            ("แสลงพัน", "31130"),
            ("โคกกลาง", "31130"),
            ("เมืองแฝก", "31130"),
            ("ผไทรินทร์", "31130"),
            ("โคกล่าม", "31130"),
            ("บุโพธิ์", "31130"),
        ],
        "สตึก": [
            ("สตึก", "31150"),
            ("ทุ่งวัง", "31150"),
            ("เมืองแก", "31150"),
            ("หนองใหญ่", "31150"),
            ("สนามชัย", "31150"),
            ("กระสัง", "31150"),
        ],
        "ปะคำ": [
            ("ปะคำ", "31220"),
            ("หนองบัว", "31220"),
        ],
        "นาโพธิ์": [
            ("นาโพธิ์", "31230"),
            ("บ้านดู่", "31230"),
            ("ดอนกอก", "31230"),
            ("ศรีสว่าง", "31230"),
        ],
        "หนองหงส์": [
            ("ไทยสามัคคี", "31240"),
            ("สระทอง", "31240"),
        ],
        "พลับพลาชัย": [
            ("จันดุม", "31250"),
            ("สำโรง", "31250"),
        ],
        "ห้วยราช": [
            ("ห้วยราช", "31000"),
            ("สามแวง", "31000"),
            ("บ้านตะโก", "31000"),
            ("โคกเหล็ก", "31000"),
            ("ห้วยราชา", "31000"),
        ],
        "โนนสุวรรณ": [
            ("ทุ่งจังหัน", "31110"),
            ("โกรกแก้ว", "31110"),
        ],
        "ชำนิ": [
            ("ชำนิ", "31110"),
            ("หนองปล่อง", "31110"),
            ("เมืองยาง", "31110"),
            ("โคกสนวน", "31110"),
        ],
        "บ้านใหม่ไชยพจน์": [
            ("หนองแวง", "31120"),
            ("กู่สวนแตง", "31120"),
        ],
        "โนนดินแดง": [
            ("โนนดินแดง", "31260"),
            ("ส้มป่อย", "31260"),
        ],
        "บ้านด่าน": [
            ("บ้านด่าน", "31000"),
            ("ปราสาท", "31000"),
            ("โนนขวาง", "31000"),
        ],
        "แคนดง": [
            ("ดงพลอง", "31150"),
        ],
        "เฉลิมพระเกียรติ": [
            ("ยายแย้มวัฒนา", "31170"),
        ],
        "เมืองบุรีรัมย์": [
            ("ในเมือง", "31000"),
            ("อิสาณ", "31000"),
            ("เสม็ด", "31000"),
            ("บ้านบัว", "31000"),
            ("สะแกโพรง", "31000"),
            ("บ้านยาง", "31000"),
            ("บัวทอง", "31000"),
            ("ชุมเห็ด", "31000"),
            ("หลักเขต", "31000"),
            ("สะแกซำ", "31000"),
        ],
        "คูเมือง": [
            ("ปะเคียบ", "31190"),
            ("พรสำราญ", "31190"),
            ("หนองขมาร", "31190"),
        ],
        "กระสัง": [
            ("กระสัง", "31160"),
            ("ลำดวน", "31160"),
            ("สองชั้น", "31160"),
            ("หนองเต็ง", "31160"),
            ("บ้านปรือ", "31160"),
            ("กันทรารมย์", "31160"),
            ("ศรีภูมิ", "31160"),
        ],
        "นางรอง": [
            ("ก้านเหลือง", "31110"),
            ("ลำไทรโยง", "31110"),
            ("ทรัพย์พระยา", "31110"),
            ("ทุ่งแสงทอง", "31110"),
        ],
        "หนองกี่": [
            ("เย้ยปราสาท", "31210"),
            ("โคกสว่าง", "31210"),
            ("ท่าโพธิ์ชัย", "31210"),
        ],
        "ละหานทราย": [
            ("ละหานทราย", "31170"),
            ("ตาจง", "31170"),
            ("หนองแวง", "31170"),
            ("หนองตะครอง", "31170"),
        ],
        "ประโคนชัย": [
            ("ประโคนชัย", "31140"),
            ("บ้านไทร", "31140"),
            ("จรเข้มาก", "31140"),
            ("เขาคอก", "31140"),
            ("หนองบอน", "31140"),
            ("โคกตูม", "31140"),
            ("ประทัดบุ", "31140"),
        ],
        "บ้านกรวด": [
            ("หนองไม้งาม", "31180"),
            ("บึงเจริญ", "31180"),
            ("จันทบเพชร", "31180"),
            ("เขาดินเหนือ", "31180"),
        ],
        "พุทไธสง": [
            ("พุทไธสง", "31120"),
            ("มะเฟือง", "31120"),
            ("บ้านแวง", "31120"),
            ("บ้านยาง", "31120"),
            ("หายโศก", "31120"),
        ],
        "ลำปลายมาศ": [
            ("ลำปลายมาศ", "31130"),
            ("ทะเมนชัย", "31130"),
            ("ตลาดโพธิ์", "31130"),
            ("หนองกะทิง", "31130"),
            ("โคกสะอาด", "31130"),
            ("บ้านยาง", "31130"),
            ("หินโคน", "31130"),
            ("หนองบัวโคก", "31130"),
            ("หนองโดน", "31130"),
        ],
        "สตึก": [
            ("นิคม", "31150"),
            ("ร่อนทอง", "31150"),
            ("ดอนมนต์", "31150"),
            ("ชุมแสง", "31150"),
            ("ท่าม่วง", "31150"),
            ("สะแก", "31150"),
        ],
        "ปะคำ": [
            ("ไทยเจริญ", "31220"),
            ("โคกมะม่วง", "31220"),
            ("หูทำนบ", "31220"),
        ],
        "นาโพธิ์": [
            ("บ้านคู", "31230"),
        ],
        "หนองหงส์": [
            ("สระแก้ว", "31240"),
            ("ห้วยหิน", "31240"),
            ("หนองชัยศรี", "31240"),
            ("เสาเดียว", "31240"),
            ("เมืองฝ้าย", "31240"),
        ],
        "พลับพลาชัย": [
            ("โคกขมิ้น", "31250"),
            ("ป่าชัน", "31250"),
            ("สะเดา", "31250"),
        ],
        "ห้วยราช": [
            ("ตาเสา", "31000"),
            ("สนวน", "31000"),
            ("เมืองโพธิ์", "31000"),
        ],
        "โนนสุวรรณ": [
            ("โนนสุวรรณ", "31110"),
            ("ดงอีจาน", "31110"),
        ],
        "ชำนิ": [
            ("ช่อผกา", "31110"),
            ("ละลวด", "31110"),
        ],
        "บ้านใหม่ไชยพจน์": [
            ("ทองหลาง", "31120"),
            ("แดงใหญ่", "31120"),
            ("หนองเยือง", "31120"),
        ],
        "โนนดินแดง": [
            ("ลำนางรอง", "31260"),
        ],
        "บ้านด่าน": [
            ("วังเหนือ", "31000"),
        ],
        "แคนดง": [
            ("แคนดง", "31150"),
            ("สระบัว", "31150"),
            ("หัวฝาย", "31150"),
        ],
        "เฉลิมพระเกียรติ": [
            ("เจริญสุข", "31110"),
            ("ตาเป๊ก", "31110"),
            ("อีสานเขต", "31110"),
            ("ถาวร", "31170"),
        ]},
    "ปทุมธานี": {
        "เมืองปทุมธานี": [
            ("บางคูวัด", "12000"),
            ("บางหลวง", "12000"),
            ("บางเดื่อ", "12000"),
            ("บางพูด", "12000"),
            ("บางพูน", "12000"),
        ],
        "คลองหลวง": [
            ("คลองหนึ่ง", "12120"),
            ("คลองสอง", "12120"),
            ("คลองสาม", "12120"),
            ("คลองหก", "12120"),
            ("คลองหก", "12110"),
        ],
        "ธัญบุรี": [
            ("บึงยี่โถ", "12130"),
            ("รังสิต", "12110"),
            ("บึงสนั่น", "12110"),
            ("บึงน้ำรักษ์", "12110"),
        ],
        "หนองเสือ": [
            ("บึงบอน", "12170"),
            ("บึงกาสาม", "12170"),
            ("ศาลาครุ", "12170"),
        ],
        "ลาดหลุมแก้ว": [
            ("ระแหง", "12140"),
            ("ลาดหลุมแก้ว", "12140"),
            ("คูขวาง", "12140"),
            ("บ่อเงิน", "12140"),
            ("หน้าไม้", "12140"),
        ],
        "ลำลูกกา": [
            ("ลาดสวาย", "12150"),
            ("บึงคำพร้อย", "12150"),
            ("ลำลูกกา", "12150"),
            ("บึงทองหลาง", "12150"),
            ("ลำไทร", "12150"),
            ("บึงคอไห", "12150"),
        ],
        "สามโคก": [
            ("บางเตย", "12160"),
            ("คลองควาย", "12160"),
            ("สามโคก", "12160"),
            ("บางโพธิ์เหนือ", "12160"),
            ("บ้านปทุม", "12160"),
            ("บ้านงิ้ว", "12160"),
            ("ท้ายเกาะ", "12160"),
        ],
        "เมืองปทุมธานี": [
            ("บางปรอก", "12000"),
            ("บ้านใหม่", "12000"),
            ("บ้านกลาง", "12000"),
            ("บ้านฉาง", "12000"),
            ("บ้านกระแชง", "12000"),
            ("บางขะแยง", "12000"),
            ("บางกะดี", "12000"),
            ("สวนพริกไทย", "12000"),
            ("หลักหก", "12000"),
        ],
        "คลองหลวง": [
            ("คลองหนึ่ง", "13180"),
            ("คลองสี่", "12120"),
            ("คลองห้า", "12120"),
            ("คลองห้า", "12110"),
            ("คลองเจ็ด", "12120"),
        ],
        "ธัญบุรี": [
            ("ประชาธิปัตย์", "12130"),
            ("ลำผักกูด", "12110"),
        ],
        "หนองเสือ": [
            ("บึงบา", "12170"),
            ("บึงชำอ้อ", "12170"),
            ("หนองสามวัง", "12170"),
            ("นพรัตน์", "12170"),
        ],
        "ลาดหลุมแก้ว": [
            ("คูบางหลวง", "12140"),
            ("คลองพระอุดม", "12140"),
        ],
        "ลำลูกกา": [
            ("คูคต", "12130"),
            ("พืชอุดม", "12150"),
        ],
        "สามโคก": [
            ("กระแชง", "12160"),
            ("เชียงรากใหญ่", "12160"),
            ("เชียงรากน้อย", "12160"),
            ("บางกระบือ", "12160"),
        ]},
    "ประจวบคีรีขันธ์": {
        "เมืองประจวบคีรีขันธ์": [
            ("อ่าวน้อย", "77000"),
            ("อ่าวน้อย", "77210"),
            ("บ่อนอก", "77210"),
        ],
        "กุยบุรี": [
            ("เขาแดง", "77150"),
            ("ดอนยายหนู", "77150"),
            ("สามกระทาย", "77150"),
            ("หาดขาม", "77150"),
        ],
        "ทับสะแก": [
            ("ทับสะแก", "77130"),
            ("นาหูกวาง", "77130"),
            ("ห้วยยาง", "77130"),
        ],
        "บางสะพาน": [
            ("กำเนิดนพคุณ", "77140"),
            ("ร่อนทอง", "77230"),
            ("ชัยเกษม", "77190"),
            ("แม่รำพึง", "77140"),
        ],
        "บางสะพานน้อย": [
            ("บางสะพาน", "77170"),
            ("ทรายทอง", "77170"),
            ("ช้างแรก", "77170"),
            ("ไชยราช", "77170"),
        ],
        "ปราณบุรี": [
            ("ปราณบุรี", "77120"),
            ("เขาน้อย", "77120"),
            ("ปากน้ำปราณ", "77220"),
        ],
        "หัวหิน": [
            ("หัวหิน", "77110"),
            ("หินเหล็กไฟ", "77110"),
            ("ทับใต้", "77110"),
            ("ห้วยสัตว์ใหญ่", "77110"),
            ("บึงนคร", "77110"),
        ],
        "สามร้อยยอด": [
            ("สามร้อยยอด", "77120"),
            ("ศิลาลอย", "77180"),
            ("ศาลาลัย", "77180"),
            ("ไร่ใหม่", "77180"),
        ],
        "เมืองประจวบคีรีขันธ์": [
            ("ประจวบคีรีขันธ์", "77000"),
            ("เกาะหลัก", "77000"),
            ("คลองวาฬ", "77000"),
            ("ห้วยทราย", "77000"),
        ],
        "กุยบุรี": [
            ("กุยบุรี", "77150"),
            ("กุยเหนือ", "77150"),
        ],
        "ทับสะแก": [
            ("อ่างทอง", "77130"),
            ("เขาล้าน", "77130"),
            ("แสงอรุณ", "77130"),
        ],
        "บางสะพาน": [
            ("พงศ์ประศาสน์", "77140"),
            ("ธงชัย", "77190"),
            ("ทองมงคล", "77230"),
        ],
        "บางสะพานน้อย": [
            ("ปากแพรก", "77170"),
        ],
        "ปราณบุรี": [
            ("เขาน้อย", "77160"),
            ("หนองตาแต้ม", "77120"),
            ("วังก์พง", "77120"),
            ("เขาจ้าว", "77120"),
        ],
        "หัวหิน": [
            ("หนองแก", "77110"),
            ("หนองพลับ", "77110"),
        ],
        "สามร้อยยอด": [
            ("ไร่เก่า", "77180"),
        ]},
    "ปราจีนบุรี": {
        "เมืองปราจีนบุรี": [
            ("หน้าเมือง", "25000"),
            ("วัดโบสถ์", "25000"),
            ("ท่างาม", "25000"),
            ("บางบริบูรณ์", "25000"),
            ("ดงพระราม", "25000"),
            ("โคกไม้ลาย", "25230"),
            ("ไม้เค็ด", "25230"),
            ("เนินหอม", "25230"),
        ],
        "กบินทร์บุรี": [
            ("วังดาล", "25110"),
            ("นนทรี", "25110"),
            ("ย่านรี", "25110"),
            ("บ่อทอง", "25110"),
            ("หนองกี่", "25110"),
            ("เขาไม้แก้ว", "25110"),
            ("วังท่าช้าง", "25110"),
        ],
        "นาดี": [
            ("นาดี", "25220"),
            ("สำพันตา", "25220"),
            ("ทุ่งโพธิ์", "25220"),
            ("แก่งดินสอ", "25220"),
            ("บุพราหมณ์", "25220"),
        ],
        "บ้านสร้าง": [
            ("บางกระเบา", "25150"),
            ("บางยาง", "25150"),
            ("บางแตน", "25150"),
            ("บางพลวง", "25150"),
            ("บางขาม", "25150"),
            ("กระทุ่มแพ้ว", "25150"),
        ],
        "ประจันตคาม": [
            ("ประจันตคาม", "25130"),
            ("เกาะลอย", "25130"),
            ("บ้านหอย", "25130"),
            ("ดงบัง", "25130"),
            ("คำโตนด", "25130"),
            ("บุฝ้าย", "25130"),
            ("โพธิ์งาม", "25130"),
        ],
        "ศรีมหาโพธิ": [
            ("บ้านทาม", "25140"),
            ("ท่าตูม", "25140"),
            ("บางกุ้ง", "25140"),
            ("ดงกระทงยาม", "25140"),
            ("หนองโพรง", "25140"),
            ("หัวหว้า", "25140"),
            ("หาดยาง", "25140"),
        ],
        "ศรีมโหสถ": [
            ("โคกไทย", "25190"),
            ("คู้ลำพัน", "25190"),
            ("ไผ่ชะเลือด", "25190"),
        ],
        "เมืองปราจีนบุรี": [
            ("รอบเมือง", "25000"),
            ("บางเดชะ", "25000"),
            ("บ้านพระ", "25230"),
            ("ดงขี้เหล็ก", "25000"),
            ("โนนห้อม", "25000"),
        ],
        "กบินทร์บุรี": [
            ("กบินทร์", "25110"),
            ("เมืองเก่า", "25240"),
            ("วังตะเคียน", "25110"),
            ("หาดนางแก้ว", "25110"),
            ("ลาดตะเคียน", "25110"),
            ("บ้านนา", "25110"),
            ("นาแขม", "25110"),
        ],
        "นาดี": [
            ("สะพานหิน", "25220"),
        ],
        "บ้านสร้าง": [
            ("บ้านสร้าง", "25150"),
            ("บางเตย", "25150"),
            ("บางปลาร้า", "25150"),
        ],
        "ประจันตคาม": [
            ("หนองแสง", "25130"),
            ("หนองแก้ว", "25130"),
        ],
        "ศรีมหาโพธิ": [
            ("ศรีมหาโพธิ", "25140"),
            ("สัมพันธ์", "25140"),
            ("กรอกสมบูรณ์", "25140"),
        ],
        "ศรีมโหสถ": [
            ("โคกปีบ", "25190"),
        ]},
    "ปัตตานี": {
        "เมืองปัตตานี": [
            ("อาเนาะรู", "94000"),
            ("จะบังติกอ", "94000"),
            ("บานา", "94000"),
            ("คลองมานิง", "94000"),
            ("บาราโหม", "94000"),
            ("ปุยุด", "94000"),
        ],
        "โคกโพธิ์": [
            ("โคกโพธิ์", "94120"),
            ("มะกรูด", "94120"),
            ("บางโกระ", "94120"),
            ("ทรายขาว", "94120"),
            ("นาประดู่", "94180"),
            ("ทุ่งพลา", "94180"),
            ("ท่าเรือ", "94120"),
        ],
        "หนองจิก": [
            ("เกาะเปาะ", "94170"),
            ("คอลอตันหยง", "94170"),
            ("ดอนรัก", "94170"),
            ("ดาโต๊ะ", "94170"),
            ("ลิปะสะโง", "94170"),
        ],
        "ปะนาเระ": [
            ("ท่าข้าม", "94130"),
            ("บ้านนอก", "94130"),
            ("ท่าน้ำ", "94130"),
            ("คอกกระบือ", "94130"),
            ("บ้านกลาง", "94130"),
        ],
        "มายอ": [
            ("มายอ", "94140"),
            ("ถนน", "94140"),
            ("สาคอใต้", "94140"),
            ("ปานัน", "94140"),
        ],
        "ทุ่งยางแดง": [
            ("ตะโละแมะนา", "94140"),
            ("พิเทน", "94140"),
            ("น้ำดำ", "94140"),
            ("ปากู", "94140"),
        ],
        "สายบุรี": [
            ("ตะลุบัน", "94110"),
            ("ปะเสยะวอ", "94110"),
            ("เตราะบอน", "94110"),
            ("แป้น", "94110"),
            ("ทุ่งคล้า", "94190"),
        ],
        "ไม้แก่น": [
            ("ไม้แก่น", "94220"),
        ],
        "ยะหริ่ง": [
            ("ตะโละ", "94150"),
            ("ตาลีอายร์", "94150"),
            ("ยามู", "94150"),
            ("บางปู", "94150"),
            ("หนองแรต", "94150"),
            ("บาโลย", "94190"),
            ("จะรัง", "94150"),
        ],
        "ยะรัง": [
            ("ยะรัง", "94160"),
            ("สะดาวา", "94160"),
            ("ระแว้ง", "94160"),
            ("ปิตูมุดี", "94160"),
            ("เมาะมาวี", "94160"),
            ("กอลำ", "94160"),
        ],
        "กะพ้อ": [
            ("กะรุบี", "94230"),
        ],
        "แม่ลาน": [
            ("ม่วงเตี้ย", "94180"),
        ],
        "เมืองปัตตานี": [
            ("สะบารัง", "94000"),
            ("ตันหยงลุโละ", "94000"),
            ("กะมิยอ", "94000"),
            ("ปะกาฮะรัง", "94000"),
            ("รูสะมิแล", "94000"),
            ("ตะลุโบะ", "94000"),
            ("บาราเฮาะ", "94000"),
        ],
        "โคกโพธิ์": [
            ("ป่าบอน", "94120"),
            ("ปากล่อ", "94180"),
            ("นาเกตุ", "94120"),
            ("ควนโนรี", "94180"),
            ("ช้างให้ตก", "94120"),
        ],
        "หนองจิก": [
            ("ตุยง", "94170"),
            ("ท่ากำชำ", "94170"),
            ("บ่อทอง", "94170"),
            ("บางเขา", "94170"),
            ("บางตาวา", "94170"),
            ("ปุโละปุโย", "94170"),
            ("ยาบี", "94170"),
        ],
        "ปะนาเระ": [
            ("ปะนาเระ", "94130"),
            ("ดอน", "94130"),
            ("ดอน", "94190"),
            ("ควน", "94190"),
            ("พ่อมิ่ง", "94130"),
            ("บ้านน้ำบ่อ", "94130"),
        ],
        "มายอ": [
            ("ตรัง", "94140"),
            ("กระหวะ", "94140"),
            ("กระหวะ", "94190"),
            ("ลุโบะยิไร", "94140"),
            ("ลางา", "94190"),
            ("กระเสาะ", "94140"),
            ("เกาะจัน", "94140"),
            ("ปะโด", "94140"),
            ("สาคอบน", "94140"),
            ("สะกำ", "94140"),
        ],
        "สายบุรี": [
            ("ตะบิ้ง", "94110"),
            ("บางเก่า", "94110"),
            ("บือเระ", "94110"),
            ("กะดุนง", "94110"),
            ("ละหาร", "94110"),
            ("มะนังดาลำ", "94110"),
        ],
        "ไม้แก่น": [
            ("ไทรทอง", "94220"),
            ("ตะโละไกรทอง", "94220"),
            ("ดอนทราย", "94220"),
        ],
        "ยะหริ่ง": [
            ("ตะโละกาโปร์", "94150"),
            ("ตันหยงดาลอ", "94150"),
            ("ตันหยงจึงงา", "94150"),
            ("ตันหยงจึงงา", "94190"),
            ("ตอหลัง", "94150"),
            ("ตาแกะ", "94150"),
            ("ปิยามุมัง", "94150"),
            ("ปุลากง", "94150"),
            ("สาบัน", "94150"),
            ("มะนังยง", "94150"),
            ("ราตาปันยัง", "94150"),
            ("แหลมโพธิ์", "94150"),
        ],
        "ยะรัง": [
            ("ประจัน", "94160"),
            ("สะนอ", "94160"),
            ("วัด", "94160"),
            ("กระโด", "94160"),
            ("คลองใหม่", "94160"),
            ("เขาตูม", "94160"),
        ],
        "กะพ้อ": [
            ("ตะโละดือรามัน", "94230"),
            ("ปล่องหอย", "94230"),
        ],
        "แม่ลาน": [
            ("แม่ลาน", "94180"),
            ("ป่าไร่", "94180"),
        ]},
    "พระนครศรีอยุธยา": {
        "พระนครศรีอยุธยา": [
            ("หอรัตนไชย", "13000"),
            ("หัวรอ", "13000"),
            ("ไผ่ลิง", "13000"),
            ("สำเภาล่ม", "13000"),
            ("คลองตะเคียน", "13000"),
            ("หันตรา", "13000"),
            ("บ้านเกาะ", "13000"),
            ("คลองสวนพลู", "13000"),
            ("บ้านรุน", "13000"),
        ],
        "ท่าเรือ": [
            ("จำปา", "13130"),
            ("ท่าหลวง", "13130"),
            ("ศาลาลอย", "13130"),
            ("หนองขนาก", "13130"),
        ],
        "นครหลวง": [
            ("บ่อโพง", "13260"),
            ("บางระกำ", "13260"),
            ("บางพระครู", "13260"),
            ("แม่ลา", "13260"),
            ("หนองปลิง", "13260"),
            ("คลองสะแก", "13260"),
            ("สามไถ", "13260"),
        ],
        "บางไทร": [
            ("บางพลี", "13190"),
            ("สนามชัย", "13190"),
            ("บ้านแป้ง", "13190"),
            ("หน้าไม้", "13190"),
            ("บางยี่โท", "13190"),
            ("ช่างเหล็ก", "13190"),
            ("กระแชง", "13190"),
            ("ช้างน้อย", "13190"),
            ("ห่อหมก", "13190"),
            ("กกแก้วบูรพา", "13190"),
            ("บ้านม้า", "13190"),
            ("บ้านเกาะ", "13190"),
            ("ช้างใหญ่", "13290"),
            ("เชียงรากน้อย", "13290"),
            ("โคกช้าง", "13190"),
        ],
        "บางบาล": [
            ("มหาพราหมณ์", "13250"),
            ("กบเจา", "13250"),
            ("บ้านคลัง", "13250"),
            ("พระขาว", "13250"),
            ("น้ำเต้า", "13250"),
            ("วัดตะกู", "13250"),
            ("บางหลวง", "13250"),
            ("บางหลวงโดด", "13250"),
        ],
        "บางปะอิน": [
            ("บ้านกรด", "13160"),
            ("คลองจิก", "13160"),
            ("วัดยม", "13160"),
            ("บางประแดง", "13160"),
            ("สามเรือน", "13160"),
            ("เกาะเกิด", "13160"),
            ("บ้านพลับ", "13160"),
            ("ตลิ่งชัน", "13160"),
            ("บ้านสร้าง", "13170"),
            ("ขนอนหลวง", "13160"),
        ],
        "บางปะหัน": [
            ("บางปะหัน", "13220"),
            ("เสาธง", "13220"),
            ("ทางกลาง", "13220"),
            ("บางเพลิง", "13220"),
            ("หันสัง", "13220"),
            ("บางนางร้า", "13220"),
            ("บ้านม้า", "13220"),
            ("ขวัญเมือง", "13220"),
            ("บ้านลี่", "13220"),
            ("บ้านขล้อ", "13220"),
        ],
        "ผักไห่": [
            ("ผักไห่", "13120"),
            ("อมฤต", "13120"),
            ("ลาดน้ำเค็ม", "13120"),
            ("ตาลาน", "13120"),
            ("ดอนลาน", "13280"),
            ("นาคู", "13280"),
            ("ลำตะเคียน", "13280"),
            ("โคกช้าง", "13120"),
            ("จักราช", "13280"),
            ("หนองน้ำใหญ่", "13280"),
            ("หน้าโคก", "13120"),
            ("บ้านใหญ่", "13120"),
        ],
        "ภาชี": [
            ("ภาชี", "13140"),
            ("ระโสม", "13140"),
            ("หนองน้ำใส", "13140"),
            ("ดอนหญ้านาง", "13140"),
        ],
        "ลาดบัวหลวง": [
            ("หลักชัย", "13230"),
            ("พระยาบันลือ", "13230"),
            ("คู้สลอด", "13230"),
            ("คลองพระยาบันลือ", "13230"),
        ],
        "วังน้อย": [
            ("ลำตาเสา", "13170"),
            ("บ่อตาโล่", "13170"),
            ("วังน้อย", "13170"),
            ("ลำไทร", "13170"),
            ("สนับทึบ", "13170"),
            ("พยอม", "13180"),
            ("หันตะเภา", "13170"),
            ("วังจุฬา", "13170"),
            ("ข้าวงาม", "13170"),
        ],
        "เสนา": [
            ("บ้านแพน", "13110"),
            ("สามกอ", "13110"),
            ("บางนมโค", "13110"),
            ("หัวเวียง", "13110"),
            ("มารวิชัย", "13110"),
            ("บ้านกระทุ่ม", "13110"),
            ("บ้านแถว", "13110"),
            ("ดอนทอง", "13110"),
            ("เจ้าเสด็จ", "13110"),
        ],
        "บางซ้าย": [
            ("เต่าเล่า", "13270"),
            ("เทพมงคล", "13270"),
        ],
        "อุทัย": [
            ("คานหาม", "13210"),
            ("สามบัณฑิต", "13210"),
            ("บ้านหีบ", "13210"),
            ("อุทัย", "13210"),
            ("เสนา", "13210"),
            ("หนองน้ำส้ม", "13210"),
            ("ธนู", "13210"),
            ("ธนู", "13000"),
        ],
        "มหาราช": [
            ("หัวไผ่", "13150"),
            ("มหาราช", "13150"),
            ("น้ำเต้า", "13150"),
            ("บางนา", "13150"),
            ("เจ้าปลุก", "13150"),
            ("พิตเพียน", "13150"),
            ("บ้านนา", "13150"),
            ("บ้านขวาง", "13150"),
            ("ท่าตอ", "13150"),
        ],
        "บ้านแพรก": [
            ("บ้านแพรก", "13240"),
            ("บ้านใหม่", "13240"),
            ("คลองน้อย", "13240"),
            ("สองห้อง", "13240"),
        ],
        "พระนครศรีอยุธยา": [
            ("ประตูชัย", "13000"),
            ("กะมัง", "13000"),
            ("ท่าวาสุกรี", "13000"),
            ("ปากกราน", "13000"),
            ("ภูเขาทอง", "13000"),
            ("สวนพริก", "13000"),
            ("วัดตูม", "13000"),
            ("ลุมพลี", "13000"),
            ("บ้านใหม่", "13000"),
            ("คลองสระบัว", "13000"),
            ("เกาะเรียน", "13000"),
            ("บ้านป้อม", "13000"),
        ],
        "ท่าเรือ": [
            ("ท่าเรือ", "13130"),
            ("ท่าหลวง", "18270"),
            ("บ้านร่อม", "13130"),
            ("วังแดง", "13130"),
            ("โพธิ์เอน", "13130"),
            ("ปากท่า", "13130"),
            ("ท่าเจ้าสนุก", "13130"),
        ],
        "นครหลวง": [
            ("นครหลวง", "13260"),
            ("ท่าช้าง", "13260"),
            ("บ้านชุ้ง", "13260"),
            ("ปากจั่น", "13260"),
            ("พระนอน", "13260"),
        ],
        "บางไทร": [
            ("บางไทร", "13190"),
            ("แคออก", "13190"),
            ("แคตก", "13190"),
            ("บ้านกลึง", "13190"),
            ("ไผ่พระ", "13190"),
            ("ไม้ตรา", "13190"),
            ("ราชคราม", "13290"),
            ("โพแตง", "13290"),
        ],
        "บางบาล": [
            ("บางบาล", "13250"),
            ("วัดยม", "13250"),
            ("ไทรน้อย", "13250"),
            ("สะพานไทย", "13250"),
            ("ทางช้าง", "13250"),
            ("บางหัก", "13250"),
            ("บางชะนี", "13250"),
            ("บ้านกุ่ม", "13250"),
        ],
        "บางปะอิน": [
            ("บ้านเลน", "13160"),
            ("เชียงรากน้อย", "13160"),
            ("เชียงรากน้อย", "13180"),
            ("บ้านโพ", "13160"),
            ("บางกระสั้น", "13160"),
            ("บ้านหว้า", "13160"),
            ("บ้านแป้ง", "13160"),
            ("คุ้งลาน", "13160"),
            ("ตลาดเกรียบ", "13160"),
        ],
        "บางปะหัน": [
            ("ขยาย", "13220"),
            ("บางเดื่อ", "13220"),
            ("ตานิม", "13220"),
            ("ทับน้ำ", "13220"),
            ("โพธิ์สามต้น", "13220"),
            ("พุทเลา", "13220"),
            ("ตาลเอน", "13220"),
        ],
        "ผักไห่": [
            ("บ้านแค", "13120"),
            ("ท่าดินแดง", "13120"),
            ("กุฎี", "13120"),
            ("ลาดชิด", "13120"),
        ],
        "ภาชี": [
            ("โคกม่วง", "13140"),
            ("ไผ่ล้อม", "13140"),
            ("กระจิว", "13140"),
            ("พระแก้ว", "13140"),
        ],
        "ลาดบัวหลวง": [
            ("ลาดบัวหลวง", "13230"),
            ("สามเมือง", "13230"),
            ("สิงหนาท", "13230"),
        ],
        "วังน้อย": [
            ("พยอม", "13170"),
            ("ชะแมบ", "13170"),
        ],
        "เสนา": [
            ("เสนา", "13110"),
            ("เจ้าเจ็ด", "13110"),
            ("บ้านโพธิ์", "13110"),
            ("รางจรเข้", "13110"),
            ("ชายนา", "13110"),
            ("สามตุ่ม", "13110"),
            ("ลาดงา", "13110"),
            ("บ้านหลวง", "13110"),
        ],
        "บางซ้าย": [
            ("บางซ้าย", "13270"),
            ("แก้วฟ้า", "13270"),
            ("ปลายกลัด", "13270"),
            ("วังพัฒนา", "13270"),
        ],
        "อุทัย": [
            ("บ้านช้าง", "13210"),
            ("หนองไม้ซุง", "13210"),
            ("โพสาวหาญ", "13210"),
            ("ข้าวเม่า", "13210"),
        ],
        "มหาราช": [
            ("กะทุ่ม", "13150"),
            ("โรงช้าง", "13150"),
            ("บ้านใหม่", "13150"),
        ],
        "บ้านแพรก": [
            ("สำพะเนียง", "13240"),
        ]},
    "พะเยา": {
        "เมืองพะเยา": [
            ("เวียง", "56000"),
            ("แม่นาเรือ", "56000"),
            ("บ้านตุ่น", "56000"),
            ("บ้านต๊ำ", "56000"),
            ("บ้านใหม่", "56000"),
            ("จำป่าหวาย", "56000"),
            ("ท่าวังทอง", "56000"),
            ("ท่าจำปี", "56000"),
        ],
        "จุน": [
            ("ห้วยข้าวก่ำ", "56150"),
            ("จุน", "56150"),
            ("หงส์หิน", "56150"),
            ("ทุ่งรวงทอง", "56150"),
        ],
        "เชียงคำ": [
            ("เวียง", "56110"),
            ("เจดีย์คำ", "56110"),
            ("เชียงบาน", "56110"),
            ("อ่างทอง", "56110"),
            ("หย่วน", "56110"),
        ],
        "เชียงม่วน": [
            ("สระ", "56160"),
        ],
        "ดอกคำใต้": [
            ("ดอกคำใต้", "56120"),
            ("บ้านถ้ำ", "56120"),
            ("ห้วยลาน", "56120"),
            ("ป่าซาง", "56120"),
            ("หนองหล่ม", "56120"),
            ("ดงสุวรรณ", "56120"),
            ("บุญเกิด", "56120"),
            ("สว่างอารมณ์", "56120"),
            ("คือเวียง", "56120"),
        ],
        "ปง": [
            ("ปง", "56140"),
            ("ควร", "56140"),
            ("ออย", "56140"),
            ("งิม", "56140"),
            ("ผาช้างน้อย", "56140"),
            ("นาปรัง", "56140"),
        ],
        "แม่ใจ": [
            ("ศรีถ้อย", "56130"),
            ("แม่สุก", "56130"),
            ("ป่าแฝก", "56130"),
            ("บ้านเหล่า", "56130"),
        ],
        "ภูซาง": [
            ("ป่าสัก", "56110"),
            ("สบบง", "56110"),
        ],
        "ภูกามยาว": [
            ("ห้วยแก้ว", "56000"),
            ("ดงเจน", "56000"),
            ("แม่อิง", "56000"),
        ],
        "เมืองพะเยา": [
            ("แม่ต๋ำ", "56000"),
            ("บ้านต๋อม", "56000"),
            ("แม่กา", "56000"),
            ("แม่ใส", "56000"),
            ("บ้านสาง", "56000"),
            ("สันป่าม่วง", "56000"),
            ("แม่ปืม", "56000"),
        ],
        "จุน": [
            ("ลอ", "56150"),
            ("ห้วยยางขาม", "56150"),
            ("พระธาตุขิงแกง", "56150"),
        ],
        "เชียงคำ": [
            ("น้ำแวน", "56110"),
            ("ฝายกวาง", "56110"),
            ("ร่มเย็น", "56110"),
            ("แม่ลาว", "56110"),
            ("ทุ่งผาสุข", "56110"),
        ],
        "เชียงม่วน": [
            ("เชียงม่วน", "56160"),
            ("บ้านมาง", "56160"),
        ],
        "ดอกคำใต้": [
            ("ดอนศรีชุม", "56120"),
            ("บ้านปิน", "56120"),
            ("สันโค้ง", "56120"),
        ],
        "ปง": [
            ("ขุนควร", "56140"),
        ],
        "แม่ใจ": [
            ("แม่ใจ", "56130"),
            ("เจริญราษฎร์", "56130"),
        ],
        "ภูซาง": [
            ("ภูซาง", "56110"),
            ("ทุ่งกล้วย", "56110"),
            ("เชียงแรง", "56110"),
        ]},
    "พังงา": {
        "เมืองพังงา": [
            ("ท้ายช้าง", "82000"),
            ("นบปริง", "82000"),
            ("บางเตย", "82000"),
            ("ตากแดด", "82000"),
        ],
        "เกาะยาว": [
            ("เกาะยาวใหญ่", "82160"),
        ],
        "กะปง": [
            ("กะปง", "82170"),
            ("ท่านา", "82170"),
            ("เหล", "82170"),
        ],
        "ตะกั่วทุ่ง": [
            ("ท่าอยู่", "82140"),
            ("คลองเคียน", "82130"),
        ],
        "ตะกั่วป่า": [
            ("ตะกั่วป่า", "82110"),
            ("ตำตัว", "82110"),
            ("โคกเคียน", "82110"),
            ("คึกคัก", "82190"),
            ("เกาะคอเขา", "82190"),
        ],
        "คุระบุรี": [
            ("บางวัน", "82150"),
        ],
        "ทับปุด": [
            ("ทับปุด", "82180"),
            ("มะรุ่ย", "82180"),
            ("บ่อแสน", "82180"),
            ("โคกเจริญ", "82180"),
            ("บางเหรียง", "82180"),
        ],
        "ท้ายเหมือง": [
            ("ท้ายเหมือง", "82120"),
            ("นาเตย", "82120"),
            ("บางทอง", "82120"),
            ("ลำแก่น", "82120"),
        ],
        "เมืองพังงา": [
            ("ถ้ำน้ำผุด", "82000"),
            ("สองแพรก", "82000"),
            ("ทุ่งคาโงก", "82000"),
            ("เกาะปันหยี", "82000"),
            ("ป่ากอ", "82000"),
        ],
        "เกาะยาว": [
            ("เกาะยาวน้อย", "82160"),
            ("พรุใน", "83000"),
        ],
        "กะปง": [
            ("เหมาะ", "82170"),
            ("รมณีย์", "82170"),
        ],
        "ตะกั่วทุ่ง": [
            ("ถ้ำ", "82130"),
            ("กระโสม", "82130"),
            ("กะไหล", "82130"),
            ("ท่าอยู่", "82130"),
            ("หล่อยูง", "82140"),
            ("โคกกลอย", "82140"),
            ("คลองเคียน", "82140"),
        ],
        "ตะกั่วป่า": [
            ("บางนายสี", "82110"),
            ("บางไทร", "82110"),
            ("บางม่วง", "82110"),
            ("บางม่วง", "82190"),
            ("คึกคัก", "82220"),
        ],
        "คุระบุรี": [
            ("คุระ", "82150"),
            ("เกาะพระทอง", "82150"),
            ("แม่นางขาว", "82150"),
        ],
        "ทับปุด": [
            ("ถ้ำทองหลาง", "82180"),
        ],
        "ท้ายเหมือง": [
            ("ทุ่งมะพร้าว", "82120"),
            ("ลำภี", "82120"),
            ("ลำแก่น", "82210"),
        ]},
    "พัทลุง": {
        "เมืองพัทลุง": [
            ("คูหาสวรรค์", "93000"),
            ("เขาเจียก", "93000"),
            ("ท่ามิหรำ", "93000"),
            ("นาท่อม", "93000"),
            ("ตำนาน", "93000"),
            ("ร่มเมือง", "93000"),
            ("ชัยบุรี", "93000"),
            ("พญาขัน", "93000"),
        ],
        "กงหรา": [
            ("กงหรา", "93180"),
            ("คลองเฉลิม", "93180"),
            ("สมหวัง", "93000"),
        ],
        "เขาชัยสน": [
            ("เขาชัยสน", "93130"),
            ("ควนขนุน", "93130"),
        ],
        "ตะโหมด": [
            ("แม่ขรี", "93160"),
            ("คลองใหญ่", "93160"),
        ],
        "ควนขนุน": [
            ("ควนขนุน", "93110"),
            ("พนมวังก์", "93110"),
            ("แหลมโตนด", "93110"),
            ("โตนดด้วน", "93110"),
            ("ดอนทราย", "93110"),
            ("มะกอกเหนือ", "93150"),
            ("แพรกหา", "93110"),
        ],
        "ปากพะยูน": [
            ("ปากพะยูน", "93120"),
            ("ดอนประดู่", "93120"),
            ("เกาะนางคำ", "93120"),
            ("หารเทา", "93120"),
        ],
        "ป่าบอน": [
            ("ป่าบอน", "93170"),
            ("โคกทราย", "93170"),
            ("วังใหม่", "93170"),
        ],
        "บางแก้ว": [
            ("ท่ามะเดื่อ", "93140"),
            ("นาปะขอ", "93140"),
            ("โคกสัก", "93140"),
        ],
        "ป่าพะยอม": [
            ("ป่าพะยอม", "93210"),
            ("ลานข่อย", "93110"),
            ("บ้านพร้าว", "93110"),
            ("บ้านพร้าว", "93210"),
        ],
        "ศรีนครินทร์": [
            ("อ่างทอง", "93000"),
            ("ลำสินธุ์", "93000"),
        ],
        "เมืองพัทลุง": [
            ("โคกชะงาย", "93000"),
            ("ปรางหมู่", "93000"),
            ("ท่าแค", "93000"),
            ("ลำปำ", "93000"),
            ("ควนมะพร้าว", "93000"),
            ("นาโหนด", "93000"),
        ],
        "กงหรา": [
            ("ชะรัด", "93000"),
            ("คลองทรายขาว", "93180"),
        ],
        "เขาชัยสน": [
            ("จองถนน", "93130"),
            ("หานโพธิ์", "93130"),
            ("โคกม่วง", "93130"),
        ],
        "ตะโหมด": [
            ("ตะโหมด", "93160"),
        ],
        "ควนขนุน": [
            ("ทะเลน้อย", "93150"),
            ("นาขยาด", "93110"),
            ("ปันแต", "93110"),
            ("พนางตุง", "93150"),
            ("ชะมวง", "93110"),
        ],
        "ปากพะยูน": [
            ("เกาะหมาก", "93120"),
            ("ฝาละมี", "93120"),
            ("ดอนทราย", "93120"),
        ],
        "ศรีบรรพต": [
            ("เขาย่า", "93190"),
            ("เขาปู่", "93190"),
            ("ตะแพน", "93190"),
        ],
        "ป่าบอน": [
            ("หนองธง", "93170"),
            ("ทุ่งนารี", "93170"),
        ],
        "ป่าพะยอม": [
            ("ป่าพะยอม", "93110"),
            ("ลานข่อย", "93210"),
            ("เกาะเต่า", "93110"),
            ("เกาะเต่า", "93210"),
        ],
        "ศรีนครินทร์": [
            ("ชุมพล", "93000"),
            ("บ้านนา", "93000"),
        ]},
    "พิจิตร": {
        "เมืองพิจิตร": [
            ("ปากทาง", "66000"),
            ("คลองคะเชนทร์", "66000"),
            ("โรงช้าง", "66000"),
            ("ฆะมัง", "66000"),
            ("ฆะมัง", "66170"),
            ("ดงกลาง", "66170"),
        ],
        "วังทรายพูน": [
            ("วังทรายพูน", "66180"),
            ("หนองปลาไหล", "66180"),
            ("หนองพระ", "66180"),
            ("หนองปล้อง", "66180"),
        ],
        "โพธิ์ประทับช้าง": [
            ("โพธิ์ประทับช้าง", "66190"),
            ("ไผ่ท่าโพ", "66190"),
        ],
        "ตะพานหิน": [
            ("งิ้วราย", "66110"),
            ("ห้วยเกตุ", "66110"),
            ("ทุ่งโพธิ์", "66150"),
            ("ดงตะขบ", "66110"),
            ("วังหลุม", "66150"),
            ("ทับหมัน", "66110"),
            ("ไผ่หลวง", "66110"),
        ],
        "บางมูลนาก": [
            ("บางมูลนาก", "66120"),
            ("บางไผ่", "66120"),
            ("หอไกร", "66120"),
            ("วังสำโรง", "66120"),
            ("ห้วยเขน", "66120"),
            ("วังตะกู", "66210"),
        ],
        "โพทะเล": [
            ("โพทะเล", "66130"),
            ("ทะนง", "66130"),
            ("ทุ่งน้อย", "66130"),
            ("ท่าเสา", "66130"),
            ("บ้านน้อย", "66130"),
        ],
        "สามง่าม": [
            ("กำแพงดิน", "66220"),
            ("เนินปอ", "66140"),
        ],
        "ทับคล้อ": [
            ("เขาเจ็ดลูก", "66230"),
            ("ท้ายทุ่ง", "66150"),
        ],
        "สากเหล็ก": [
            ("ท่าเยี่ยม", "66160"),
            ("คลองทราย", "66160"),
            ("วังทับไทร", "66160"),
        ],
        "บึงนาราง": [
            ("ห้วยแก้ว", "66130"),
            ("บางลาย", "66130"),
        ],
        "ดงเจริญ": [
            ("ห้วยร่วม", "66210"),
        ],
        "วชิรบารมี": [
            ("บ้านนา", "66140"),
            ("วังโมกข์", "66140"),
        ],
        "เมืองพิจิตร": [
            ("ในเมือง", "66000"),
            ("ไผ่ขวาง", "66000"),
            ("ย่านยาว", "66000"),
            ("ท่าฬ่อ", "66000"),
            ("เมืองเก่า", "66000"),
            ("ท่าหลวง", "66000"),
            ("บ้านบุ่ง", "66000"),
            ("ดงป่าคำ", "66170"),
            ("หัวดง", "66170"),
            ("ป่ามะคาบ", "66000"),
            ("สายคำโห้", "66000"),
        ],
        "โพธิ์ประทับช้าง": [
            ("วังจิก", "66190"),
            ("ไผ่รอบ", "66190"),
            ("ดงเสือเหลือง", "66190"),
            ("เนินสว่าง", "66190"),
            ("ทุ่งใหญ่", "66190"),
        ],
        "ตะพานหิน": [
            ("ตะพานหิน", "66110"),
            ("ไทรโรงโขน", "66110"),
            ("หนองพยอม", "66110"),
            ("คลองคูณ", "66110"),
            ("วังสำโรง", "66110"),
            ("วังหว้า", "66110"),
        ],
        "บางมูลนาก": [
            ("เนินมะกอก", "66120"),
            ("ภูมิ", "66120"),
            ("วังกรด", "66120"),
            ("ลำประดา", "66120"),
        ],
        "โพทะเล": [
            ("ท้ายน้ำ", "66130"),
            ("ท่าบัว", "66130"),
            ("ท่าขมิ้น", "66130"),
            ("บางคลาน", "66130"),
            ("ท่านั่ง", "66130"),
            ("วัดขวาง", "66130"),
        ],
        "สามง่าม": [
            ("สามง่าม", "66140"),
            ("กำแพงดิน", "66140"),
            ("รังนก", "66140"),
            ("หนองโสน", "66140"),
        ],
        "ทับคล้อ": [
            ("ทับคล้อ", "66150"),
            ("เขาทราย", "66230"),
        ],
        "สากเหล็ก": [
            ("สากเหล็ก", "66160"),
            ("หนองหญ้าไทร", "66160"),
        ],
        "บึงนาราง": [
            ("โพธิ์ไทรงาม", "66130"),
            ("แหลมรัง", "66130"),
            ("บึงนาราง", "66130"),
        ],
        "ดงเจริญ": [
            ("วังงิ้วใต้", "66210"),
            ("วังงิ้ว", "66210"),
            ("ห้วยพุก", "66210"),
            ("สำนักขุนเณร", "66210"),
        ],
        "วชิรบารมี": [
            ("บึงบัว", "66140"),
            ("หนองหลุม", "66220"),
        ]},
    "พิษณุโลก": {
        "เมืองพิษณุโลก": [
            ("ในเมือง", "65000"),
            ("วังน้ำคู้", "65230"),
            ("วัดจันทร์", "65000"),
            ("วัดพริก", "65230"),
            ("ท่าทอง", "65000"),
            ("ท่าโพธิ์", "65000"),
            ("ปากโทก", "65000"),
            ("หัวรอ", "65000"),
            ("บ้านกร่าง", "65000"),
            ("บ้านคลอง", "65000"),
            ("พลายชุมพล", "65000"),
            ("มะขามสูง", "65000"),
            ("บึงพระ", "65000"),
            ("ไผ่ขอดอน", "65000"),
        ],
        "นครไทย": [
            ("นครไทย", "65120"),
            ("บ้านแยง", "65120"),
            ("นาบัว", "65120"),
        ],
        "ชาติตระการ": [
            ("ป่าแดง", "65170"),
            ("ชาติตระการ", "65170"),
            ("บ้านดง", "65170"),
            ("บ่อภาค", "65170"),
            ("ท่าสะแก", "65170"),
        ],
        "บางระกำ": [
            ("ปลักแรด", "65140"),
            ("พันเสา", "65140"),
            ("นิคมพัฒนา", "65140"),
            ("คุยม่วง", "65240"),
        ],
        "บางกระทุ่ม": [
            ("บ้านไร่", "65110"),
            ("ไผ่ล้อม", "65110"),
            ("นครป่าหมาก", "65110"),
            ("เนินกุ่ม", "65210"),
            ("วัดตายม", "65210"),
        ],
        "พรหมพิราม": [
            ("พรหมพิราม", "65150"),
            ("มะตูม", "65150"),
            ("หอกลอง", "65150"),
            ("ศรีภิรมย์", "65180"),
            ("ตลุกเทียม", "65180"),
            ("วังวน", "65150"),
        ],
        "วัดโบสถ์": [
            ("ท่างาม", "65160"),
            ("ท้อแท้", "65160"),
            ("บ้านยาง", "65160"),
            ("หินลาด", "65160"),
        ],
        "วังทอง": [
            ("วังทอง", "65130"),
            ("วังพิกุล", "65130"),
            ("ท่าหมื่นราม", "65130"),
        ],
        "เนินมะปราง": [
            ("ไทรย้อย", "65190"),
            ("วังโพรง", "65190"),
            ("บ้านน้อยซุ้มขี้เหล็ก", "65190"),
            ("เนินมะปราง", "65190"),
        ],
        "เมืองพิษณุโลก": [
            ("สมอแข", "65000"),
            ("ดอนทอง", "65000"),
            ("บ้านป่า", "65000"),
            ("จอมทอง", "65000"),
            ("อรัญญิก", "65000"),
            ("งิ้วงาม", "65230"),
        ],
        "นครไทย": [
            ("หนองกะท้าว", "65120"),
            ("เนินเพิ่ม", "65120"),
            ("นครชุม", "65120"),
            ("น้ำกุ่ม", "65120"),
            ("ยางโกลน", "65120"),
            ("บ่อโพธิ์", "65120"),
            ("บ้านพร้าว", "65120"),
            ("ห้วยเฮี้ย", "65120"),
        ],
        "ชาติตระการ": [
            ("สวนเมี่ยง", "65170"),
        ],
        "บางระกำ": [
            ("บางระกำ", "65140"),
            ("วังอิทก", "65140"),
            ("บึงกอก", "65140"),
            ("หนองกุลา", "65140"),
            ("ชุมแสงสงคราม", "65240"),
            ("บ่อทอง", "65140"),
            ("ท่านางงาม", "65140"),
            ("คุยม่วง", "65140"),
        ],
        "บางกระทุ่ม": [
            ("บางกระทุ่ม", "65110"),
            ("โคกสลุด", "65110"),
            ("สนามคลี", "65110"),
            ("ท่าตาล", "65110"),
        ],
        "พรหมพิราม": [
            ("ท่าช้าง", "65150"),
            ("วงฆ้อง", "65180"),
            ("หนองแขม", "65150"),
            ("มะต้อง", "65180"),
            ("ทับยายเชียง", "65150"),
            ("ดงประคำ", "65180"),
        ],
        "วัดโบสถ์": [
            ("วัดโบสถ์", "65160"),
            ("คันโช้ง", "65160"),
        ],
        "วังทอง": [
            ("พันชาลี", "65130"),
            ("แม่ระกา", "65130"),
            ("บ้านกลาง", "65220"),
            ("แก่งโสภา", "65220"),
            ("วังนกแอ่น", "65130"),
            ("หนองพระ", "65130"),
            ("ชัยนาม", "65130"),
            ("ดินทอง", "65130"),
        ],
        "เนินมะปราง": [
            ("ชมพู", "65190"),
            ("บ้านมุง", "65190"),
            ("วังยาง", "65190"),
        ]},
    "ภูเก็ต": {
        "เมืองภูเก็ต": [
            ("ตลาดเหนือ", "83000"),
            ("เกาะแก้ว", "83000"),
            ("รัษฎา", "83000"),
            ("ฉลอง", "83000"),
            ("กะรน", "83100"),
        ],
        "กะทู้": [
            ("กะทู้", "83150"),
            ("กะทู้", "83120"),
            ("กมลา", "83150"),
        ],
        "ถลาง": [
            ("เชิงทะเล", "83110"),
            ("ป่าคลอก", "83110"),
            ("ไม้ขาว", "83110"),
            ("สาคู", "83110"),
        ],
        "เมืองภูเก็ต": [
            ("ตลาดใหญ่", "83000"),
            ("วิชิต", "83000"),
            ("ฉลอง", "83130"),
            ("ราไวย์", "83130"),
            ("ราไวย์", "83100"),
        ],
        "กะทู้": [
            ("ป่าตอง", "83150"),
            ("กมลา", "83120"),
        ],
        "ถลาง": [
            ("เทพกระษัตรี", "83110"),
            ("ศรีสุนทร", "83110"),
        ],
        "กะทู้": [
            ("ป่าตอง", "83151"),
        ]},
    "มหาสารคาม": {
        "เมืองมหาสารคาม": [
            ("เขวา", "44000"),
            ("โคกก่อ", "44000"),
            ("เกิ้ง", "44000"),
            ("แก่งเลิงจาน", "44000"),
            ("ลาดพัฒนา", "44000"),
            ("หนองปลิง", "44000"),
            ("บัวค้อ", "44000"),
            ("ตลาด", "44000"),
        ],
        "แกดำ": [
            ("แกดำ", "44190"),
            ("วังแสง", "44190"),
            ("มิตรภาพ", "44190"),
            ("โนนภิบาล", "44190"),
        ],
        "โกสุมพิสัย": [
            ("หัวขวาง", "44140"),
            ("ยางน้อย", "44140"),
            ("วังยาว", "44140"),
            ("เขวาไร่", "44140"),
            ("แพง", "44140"),
            ("แก้งแก", "44140"),
            ("หนองบอน", "44140"),
            ("แห่ใต้", "44140"),
            ("หนองกุงสวรรค์", "44140"),
            ("ดอนกลาง", "44140"),
        ],
        "กันทรวิชัย": [
            ("โคกพระ", "44150"),
            ("คันธารราษฎร์", "44150"),
            ("ท่าขอนยาง", "44150"),
            ("นาสีนวน", "44150"),
            ("ขามเฒ่าพัฒนา", "44150"),
        ],
        "เชียงยืน": [
            ("ดอนเงิน", "44160"),
            ("กู่ทอง", "44160"),
            ("โพนทอง", "44160"),
            ("เหล่าบัวบาน", "44160"),
        ],
        "บรบือ": [
            ("บรบือ", "44130"),
            ("บ่อใหญ่", "44130"),
            ("หนองม่วง", "44130"),
            ("โนนแดง", "44130"),
            ("วังใหม่", "44130"),
            ("ยาง", "44130"),
            ("หนองสิม", "44130"),
            ("ดอนงัว", "44130"),
        ],
        "นาเชือก": [
            ("สำโรง", "44170"),
            ("เขวาไร่", "44170"),
            ("หนองโพธิ์", "44170"),
            ("หนองกุง", "44170"),
            ("สันป่าตอง", "44170"),
        ],
        "พยัคฆภูมิพิสัย": [
            ("ปะหลาน", "44110"),
            ("ก้ามปู", "44110"),
            ("เม็กดำ", "44110"),
            ("นาสีนวล", "44110"),
            ("ราษฎร์เจริญ", "44110"),
            ("หนองบัว", "44110"),
            ("เมืองเสือ", "44110"),
        ],
        "วาปีปทุม": [
            ("หนองแสง", "44120"),
            ("ขามป้อม", "44120"),
            ("ดงใหญ่", "44120"),
            ("แคน", "44120"),
            ("นาข่า", "44120"),
            ("บ้านหวาย", "44120"),
            ("หนองไฮ", "44120"),
            ("ประชาพัฒนา", "44120"),
            ("หนองทุ่ม", "44120"),
            ("หนองแสน", "44120"),
            ("โคกสีทองหลาง", "44120"),
        ],
        "นาดูน": [
            ("นาดูน", "44180"),
            ("หนองคู", "44180"),
            ("ดงบัง", "44180"),
            ("หัวดง", "44180"),
            ("กู่สันตรัตน์", "44180"),
        ],
        "ยางสีสุราช": [
            ("ยางสีสุราช", "44210"),
            ("นาภู", "44210"),
            ("แวงดง", "44210"),
            ("บ้านกู่", "44210"),
        ],
        "กุดรัง": [
            ("กุดรัง", "44130"),
            ("เลิงแฝก", "44130"),
            ("ห้วยเตย", "44130"),
        ],
        "ชื่นชม": [
            ("เหล่าดอกไม้", "44160"),
        ],
        "เมืองมหาสารคาม": [
            ("ท่าตูม", "44000"),
            ("แวงน่าง", "44000"),
            ("ดอนหว่าน", "44000"),
            ("ท่าสองคอน", "44000"),
            ("ห้วยแอ่ง", "44000"),
            ("หนองโน", "44000"),
        ],
        "แกดำ": [
            ("หนองกุง", "44190"),
        ],
        "โกสุมพิสัย": [
            ("หนองเหล็ก", "44140"),
            ("หนองบัว", "44140"),
            ("เหล่า", "44140"),
            ("เขื่อน", "44140"),
            ("โพนงาม", "44140"),
            ("ยางท่าแจ้ง", "44140"),
            ("เลิงใต้", "44140"),
        ],
        "กันทรวิชัย": [
            ("มะค่า", "44150"),
            ("ขามเรียง", "44150"),
            ("เขวาใหญ่", "44150"),
            ("ศรีสุข", "44150"),
            ("กุดใส้จ่อ", "44150"),
        ],
        "เชียงยืน": [
            ("เชียงยืน", "44160"),
            ("หนองซอน", "44160"),
            ("นาทอง", "44160"),
            ("เสือเฒ่า", "44160"),
        ],
        "บรบือ": [
            ("วังไชย", "44130"),
            ("กำพี้", "44130"),
            ("โนนราษี", "44130"),
            ("หนองจิก", "44130"),
            ("บัวมาศ", "44130"),
            ("หนองคูขาด", "44130"),
            ("หนองโก", "44130"),
        ],
        "นาเชือก": [
            ("นาเชือก", "44170"),
            ("หนองแดง", "44170"),
            ("ปอพาน", "44170"),
            ("หนองเม็ก", "44170"),
            ("หนองเรือ", "44170"),
        ],
        "พยัคฆภูมิพิสัย": [
            ("เวียงสะอาด", "44110"),
            ("หนองบัวแก้ว", "44110"),
            ("เมืองเตา", "44110"),
            ("ลานสะแก", "44110"),
            ("เวียงชัย", "44110"),
            ("ราษฎร์พัฒนา", "44110"),
            ("ภารแอ่น", "44110"),
        ],
        "วาปีปทุม": [
            ("เสือโก้ก", "44120"),
            ("โพธิ์ชัย", "44120"),
            ("หัวเรือ", "44120"),
            ("งัวบา", "44120"),
        ],
        "นาดูน": [
            ("หนองไผ่", "44180"),
            ("ดงดวน", "44180"),
            ("ดงยาง", "44180"),
            ("พระธาตุ", "44180"),
        ],
        "ยางสีสุราช": [
            ("ดงเมือง", "44210"),
            ("ขามเรียน", "44210"),
            ("หนองบัวสันตุ", "44210"),
            ("สร้างแซ่ง", "44210"),
        ],
        "กุดรัง": [
            ("นาโพธิ์", "44130"),
            ("หนองแวง", "44130"),
        ],
        "ชื่นชม": [
            ("ชื่นชม", "44160"),
            ("กุดปลาดุก", "44160"),
            ("หนองกุง", "44160"),
        ]},
    "มุกดาหาร": {
        "เมืองมุกดาหาร": [
            ("มุกดาหาร", "49000"),
            ("นาโสก", "49000"),
            ("คำป่าหลาย", "49000"),
            ("คำอาฮวน", "49000"),
        ],
        "นิคมคำสร้อย": [
            ("นาอุดม", "49130"),
        ],
        "ดอนตาล": [
            ("ป่าไร่", "49120"),
            ("บ้านบาก", "49120"),
            ("บ้านแก้ง", "49120"),
        ],
        "ดงหลวง": [
            ("หนองบัว", "49140"),
            ("กกตูม", "49140"),
            ("หนองแคน", "49140"),
            ("พังแดง", "49140"),
        ],
        "คำชะอี": [
            ("คำชะอี", "49110"),
            ("หนองเอี่ยน", "49110"),
            ("บ้านเหล่า", "49110"),
        ],
        "หว้านใหญ่": [
            ("บางทรายน้อย", "49150"),
            ("ดงหมู", "49150"),
        ],
        "หนองสูง": [
            ("หนองสูง", "49160"),
            ("โนนยาง", "49160"),
        ],
        "เมืองมุกดาหาร": [
            ("ศรีบุญเรือง", "49000"),
            ("บ้านโคก", "49000"),
            ("บางทรายใหญ่", "49000"),
            ("โพนทราย", "49000"),
            ("ผึ่งแดด", "49000"),
            ("นาสีนวน", "49000"),
            ("ดงเย็น", "49000"),
            ("ดงมอน", "49000"),
            ("กุดแข้", "49000"),
        ],
        "นิคมคำสร้อย": [
            ("นิคมคำสร้อย", "49130"),
            ("นากอก", "49130"),
            ("หนองแวง", "49130"),
            ("กกแดง", "49130"),
            ("โชคชัย", "49130"),
            ("ร่มเกล้า", "49130"),
        ],
        "ดอนตาล": [
            ("ดอนตาล", "49120"),
            ("โพธิ์ไทร", "49120"),
            ("เหล่าหมี", "49120"),
            ("นาสะเม็ง", "49120"),
        ],
        "ดงหลวง": [
            ("ดงหลวง", "49140"),
            ("ชะโนดน้อย", "49140"),
        ],
        "คำชะอี": [
            ("บ้านซ่ง", "49110"),
            ("บ้านค้อ", "49110"),
            ("โพนงาม", "49110"),
            ("เหล่าสร้างถ่อ", "49110"),
            ("คำบก", "49110"),
            ("น้ำเที่ยง", "49110"),
        ],
        "หว้านใหญ่": [
            ("หว้านใหญ่", "49150"),
            ("ป่งขาม", "49150"),
            ("ชะโนด", "49150"),
        ],
        "หนองสูง": [
            ("ภูวง", "49160"),
            ("บ้านเป้า", "49160"),
            ("หนองสูงใต้", "49160"),
            ("หนองสูงเหนือ", "49160"),
        ]},
    "ยะลา": {
        "เมืองยะลา": [
            ("บุดี", "95000"),
            ("ยุโป", "95000"),
            ("ลิดล", "95160"),
            ("ยะลา", "95000"),
            ("หน้าถ้ำ", "95000"),
            ("บันนังสาเรง", "95000"),
        ],
        "เบตง": [
            ("เบตง", "95110"),
            ("อัยเยอร์เวง", "95110"),
        ],
        "บันนังสตา": [
            ("บันนังสตา", "95130"),
            ("ตลิ่งชัน", "95130"),
        ],
        "ธารโต": [
            ("ธารโต", "95150"),
            ("แม่หวาด", "95170"),
            ("คีรีเขต", "95150"),
        ],
        "ยะหา": [
            ("ตาชี", "95120"),
            ("กาตอง", "95120"),
        ],
        "รามัน": [
            ("กายูบอเกาะ", "95140"),
            ("กาลูปัง", "95140"),
            ("กาลอ", "95140"),
            ("โกตาบารู", "95140"),
            ("เกะรอ", "95140"),
            ("จะกว๊ะ", "95140"),
            ("ท่าธง", "95140"),
            ("บาลอ", "95140"),
            ("ยะต๊ะ", "95140"),
            ("วังพญา", "95140"),
            ("ตะโล๊ะหะลอ", "95140"),
        ],
        "กรงปินัง": [
            ("ห้วยกระทิง", "95000"),
        ],
        "เมืองยะลา": [
            ("สะเตง", "95000"),
            ("ท่าสาป", "95000"),
            ("ลำใหม่", "95160"),
            ("ลำพะยา", "95160"),
            ("เปาะเส้ง", "95000"),
            ("พร่อน", "95160"),
            ("สะเตงนอก", "95000"),
            ("ตาเซะ", "95000"),
        ],
        "เบตง": [
            ("ยะรม", "95110"),
            ("ตาเนาะแมเราะ", "95110"),
            ("ธารน้ำทิพย์", "95110"),
        ],
        "บันนังสตา": [
            ("บาเจาะ", "95130"),
            ("ตาเนาะปูเต๊ะ", "95130"),
            ("ถ้ำทะลุ", "95130"),
            ("เขื่อนบางลาง", "95130"),
        ],
        "ธารโต": [
            ("บ้านแหร", "95150"),
        ],
        "ยะหา": [
            ("ยะหา", "95120"),
            ("ละแอ", "95120"),
            ("ปะแต", "95120"),
            ("บาโร๊ะ", "95120"),
            ("บาโงยซิแน", "95120"),
        ],
        "รามัน": [
            ("กอตอตือร๊ะ", "95140"),
            ("เนินงาม", "95140"),
            ("บาโงย", "95140"),
            ("บือมัง", "95140"),
            ("อาซ่อง", "95140"),
        ],
        "กาบัง": [
            ("กาบัง", "95120"),
            ("บาละ", "95120"),
        ],
        "กรงปินัง": [
            ("กรงปินัง", "95000"),
            ("สะเอะ", "95000"),
            ("ปุโรง", "95000"),
        ]},
    "ยโสธร": {
        "เมืองยโสธร": [
            ("ในเมือง", "35000"),
            ("น้ำคำใหญ่", "35000"),
            ("ดู่ทุ่ง", "35000"),
            ("ขั้นไดใหญ่", "35000"),
            ("สิงห์", "35000"),
            ("นาสะไมย์", "35000"),
            ("เขื่องคำ", "35000"),
            ("หนองคู", "35000"),
            ("หนองเรือ", "35000"),
        ],
        "ทรายมูล": [
            ("ทรายมูล", "35170"),
            ("ดู่ลาด", "35170"),
            ("นาเวียง", "35170"),
            ("ไผ่", "35170"),
        ],
        "กุดชุม": [
            ("กุดชุม", "35140"),
            ("กำแมด", "35140"),
            ("ห้วยแก้ง", "35140"),
            ("โพนงาม", "35140"),
            ("คำน้ำสร้าง", "35140"),
            ("หนองแหน", "35140"),
        ],
        "คำเขื่อนแก้ว": [
            ("ลุมพุก", "35110"),
            ("นาคำ", "35180"),
            ("ดงแคนใหญ่", "35180"),
            ("กู่จาน", "35110"),
            ("กุดกุง", "35110"),
            ("เหล่าไฮ", "35110"),
            ("แคนน้อย", "35180"),
            ("ดงเจริญ", "35110"),
        ],
        "ป่าติ้ว": [
            ("โพธิ์ไทร", "35150"),
            ("กระจาย", "35150"),
        ],
        "มหาชนะชัย": [
            ("ฟ้าหยาด", "35130"),
            ("คูเมือง", "35130"),
            ("บากเรือ", "35130"),
            ("ม่วง", "35130"),
        ],
        "เลิงนกทา": [
            ("บุ่งค้า", "35120"),
            ("สวาท", "35120"),
            ("สามัคคี", "35120"),
            ("กุดเชียงหมี", "35120"),
            ("สร้างมิ่ง", "35120"),
            ("ศรีแก้ว", "35120"),
        ],
        "ไทยเจริญ": [
            ("คำเตย", "35120"),
            ("คำไผ่", "35120"),
        ],
        "เมืองยโสธร": [
            ("ตาดทอง", "35000"),
            ("สำราญ", "35000"),
            ("ค้อเหนือ", "35000"),
            ("เดิด", "35000"),
            ("ทุ่งแต้", "35000"),
            ("หนองหิน", "35000"),
            ("ขุมเงิน", "35000"),
            ("ทุ่งนางโอก", "35000"),
            ("หนองเป็ด", "35000"),
        ],
        "ทรายมูล": [
            ("ดงมะไฟ", "35170"),
        ],
        "กุดชุม": [
            ("โนนเปือย", "35140"),
            ("นาโส่", "35140"),
            ("หนองหมี", "35140"),
        ],
        "คำเขื่อนแก้ว": [
            ("ย่อ", "35110"),
            ("สงเปือย", "35110"),
            ("โพนทัน", "35110"),
            ("ทุ่งมน", "35110"),
            ("นาแก", "35180"),
        ],
        "ป่าติ้ว": [
            ("โคกนาโก", "35150"),
            ("เชียงเพ็ง", "35150"),
            ("ศรีฐาน", "35150"),
        ],
        "มหาชนะชัย": [
            ("หัวเมือง", "35130"),
            ("ผือฮี", "35130"),
            ("โนนทราย", "35130"),
            ("บึงแก", "35130"),
            ("พระเสาร์", "35130"),
            ("สงยาง", "35130"),
        ],
        "ค้อวัง": [
            ("ฟ้าห่วน", "35160"),
            ("กุดน้ำใส", "35160"),
            ("น้ำอ้อม", "35160"),
            ("ค้อวัง", "35160"),
        ],
        "เลิงนกทา": [
            ("ห้องแซง", "35120"),
            ("สามแยก", "35120"),
            ("กุดแห่", "35120"),
            ("โคกสำราญ", "35120"),
        ],
        "ไทยเจริญ": [
            ("ไทยเจริญ", "35120"),
            ("น้ำคำ", "35120"),
            ("ส้มผ่อ", "35120"),
        ]},
    "ระนอง": {
        "เมืองระนอง": [
            ("ราชกรูด", "85000"),
            ("หงาว", "85000"),
            ("ทรายแดง", "85130"),
        ],
        "ละอุ่น": [
            ("ละอุ่นใต้", "85130"),
            ("ในวงเหนือ", "85130"),
            ("ในวงใต้", "85130"),
        ],
        "กะเปอร์": [
            ("ม่วงกลวง", "85120"),
            ("กะเปอร์", "85120"),
        ],
        "กระบุรี": [
            ("น้ำจืดน้อย", "85110"),
            ("มะมุ", "85110"),
            ("ปากจั่น", "85110"),
            ("จ.ป.ร.", "85110"),
            ("บางใหญ่", "85110"),
        ],
        "เมืองระนอง": [
            ("เขานิเวศน์", "85000"),
            ("บางริ้น", "85000"),
            ("ปากน้ำ", "85000"),
            ("บางนอน", "85000"),
            ("หาดส้มแป้น", "85000"),
            ("เกาะพยาม", "85000"),
        ],
        "ละอุ่น": [
            ("ละอุ่นเหนือ", "85130"),
            ("บางพระใต้", "85130"),
            ("บางพระเหนือ", "85130"),
            ("บางแก้ว", "85130"),
        ],
        "กะเปอร์": [
            ("เชี่ยวเหลียง", "85120"),
            ("บ้านนา", "85120"),
            ("บางหิน", "85120"),
        ],
        "กระบุรี": [
            ("น้ำจืด", "85110"),
            ("ลำเลียง", "85110"),
        ],
        "สุขสำราญ": [
            ("นาคา", "85120"),
            ("กำพวน", "85120"),
        ]},
    "ระยอง": {
        "เมืองระยอง": [
            ("ท่าประดู่", "21000"),
            ("เชิงเนิน", "21000"),
            ("ตะพง", "21000"),
            ("เพ", "21160"),
            ("แกลง", "21160"),
            ("นาตาขวัญ", "21100"),
            ("กะเฉด", "21100"),
            ("ทับมา", "21000"),
            ("ห้วยโป่ง", "21150"),
            ("มาบตาพุด", "21150"),
        ],
        "บ้านฉาง": [
            ("สำนักท้อน", "21130"),
            ("พลา", "21130"),
        ],
        "แกลง": [
            ("ทางเกวียน", "21110"),
            ("วังหว้า", "21110"),
            ("ชากโดน", "21110"),
            ("กร่ำ", "21190"),
            ("ชากพง", "21190"),
            ("ทุ่งควายกิน", "21110"),
            ("กองดิน", "22160"),
            ("พังราด", "21170"),
            ("ปากน้ำกระแส", "21170"),
            ("สองสลึง", "21110"),
        ],
        "วังจันทร์": [
            ("ป่ายุบใน", "21210"),
            ("พลงตาเอี่ยม", "21210"),
        ],
        "บ้านค่าย": [
            ("ตาขัน", "21120"),
            ("บางบุตร", "21120"),
            ("หนองบัว", "21120"),
            ("ชากบก", "21120"),
        ],
        "ปลวกแดง": [
            ("ปลวกแดง", "21140"),
            ("ตาสิทธิ์", "21140"),
            ("มาบยางพร", "21140"),
        ],
        "เขาชะเมา": [
            ("น้ำเป็น", "21110"),
            ("ห้วยทับมอญ", "21110"),
            ("ชำฆ้อ", "21110"),
        ],
        "นิคมพัฒนา": [
            ("มาบข่า", "21180"),
            ("พนานิคม", "21180"),
            ("มะขามคู่", "21180"),
        ],
        "เมืองระยอง": [
            ("ปากน้ำ", "21000"),
            ("บ้านแลง", "21100"),
            ("บ้านแลง", "21000"),
            ("นาตาขวัญ", "21000"),
            ("เนินพระ", "21150"),
            ("เนินพระ", "21000"),
            ("น้ำคอก", "21000"),
            ("สำนักทอง", "21100"),
        ],
        "บ้านฉาง": [
            ("บ้านฉาง", "21130"),
        ],
        "แกลง": [
            ("เนินฆ้อ", "21110"),
            ("กระแสบน", "21110"),
            ("บ้านนา", "21110"),
            ("คลองปูน", "21170"),
            ("พังราด", "21110"),
            ("ห้วยยาง", "21110"),
        ],
        "วังจันทร์": [
            ("วังจันทร์", "21210"),
            ("ชุมแสง", "21210"),
        ],
        "บ้านค่าย": [
            ("บ้านค่าย", "21120"),
            ("หนองละลอก", "21120"),
            ("หนองตะพาน", "21120"),
        ],
        "ปลวกแดง": [
            ("ละหาร", "21140"),
            ("แม่น้ำคู้", "21140"),
            ("หนองไร่", "21140"),
        ],
        "เขาชะเมา": [
            ("เขาน้อย", "21110"),
        ],
        "นิคมพัฒนา": [
            ("นิคมพัฒนา", "21180"),
        ]},
    "ราชบุรี": {
        "เมืองราชบุรี": [
            ("สามเรือน", "70000"),
            ("น้ำพุ", "70000"),
            ("หินกอง", "70000"),
            ("เกาะพลับพลา", "70000"),
            ("หลุมดิน", "70000"),
            ("บางป่า", "70000"),
            ("พงสวาย", "70000"),
        ],
        "สวนผึ้ง": [
            ("ตะนาวศรี", "70180"),
            ("สวนผึ้ง", "70180"),
        ],
        "ดำเนินสะดวก": [
            ("ดำเนินสะดวก", "70130"),
            ("ดอนกรวย", "70130"),
            ("บัวงาม", "70210"),
            ("บ้านไร่", "70130"),
            ("ท่านัด", "70130"),
        ],
        "บ้านโป่ง": [
            ("ปากแรต", "70110"),
            ("หนองกบ", "70110"),
            ("หนองอ้อ", "70110"),
            ("นครชุมน์", "70110"),
            ("บ้านม่วง", "70110"),
            ("เบิกไพร", "70110"),
            ("ลาดบัวขาว", "70110"),
        ],
        "บางแพ": [
            ("บางแพ", "70160"),
            ("วังเย็น", "70160"),
            ("วัดแก้ว", "70160"),
            ("ดอนใหญ่", "70160"),
            ("ดอนคา", "70160"),
            ("โพหัก", "70160"),
        ],
        "โพธาราม": [
            ("ดอนกระเบื้อง", "70120"),
            ("หนองโพ", "70120"),
            ("บ้านเลือก", "70120"),
            ("คลองตาคต", "70120"),
            ("บ้านสิงห์", "70120"),
            ("ดอนทราย", "70120"),
            ("คลองข่อย", "70120"),
            ("ชำแระ", "70120"),
            ("สร้อยฟ้า", "70120"),
            ("นางแก้ว", "70120"),
            ("ธรรมเสน", "70120"),
            ("หนองกวาง", "70120"),
        ],
        "ปากท่อ": [
            ("ทุ่งหลวง", "70140"),
            ("วังมะนาว", "70140"),
            ("ปากท่อ", "70140"),
            ("อ่างหิน", "70140"),
            ("บ่อกระดาน", "70140"),
        ],
        "บ้านคา": [
            ("หนองพันจันทร์", "70180"),
        ],
        "จอมบึง": [
            ("รางบัว", "70150"),
        ],
        "เมืองราชบุรี": [
            ("หน้าเมือง", "70000"),
            ("เจดีย์หัก", "70000"),
            ("ดอนตะโก", "70000"),
            ("หนองกลางนา", "70000"),
            ("ห้วยไผ่", "70000"),
            ("คุ้งน้ำวน", "70000"),
            ("คุ้งกระถิน", "70000"),
            ("อ่างทอง", "70000"),
            ("โคกหม้อ", "70000"),
            ("พิกุลทอง", "70000"),
            ("ดอนแร่", "70000"),
            ("เขาแร้ง", "70000"),
            ("คูบัว", "70000"),
            ("ท่าราบ", "70000"),
            ("บ้านไร่", "70000"),
        ],
        "สวนผึ้ง": [
            ("ป่าหวาย", "70180"),
            ("ท่าเคย", "70180"),
        ],
        "ดำเนินสะดวก": [
            ("ประสาทสิทธิ์", "70210"),
            ("ศรีสุราษฎร์", "70130"),
            ("ตาหลวง", "70130"),
            ("ดอนคลัง", "70130"),
            ("แพงพวย", "70130"),
            ("สี่หมื่น", "70130"),
            ("ขุนพิทักษ์", "70130"),
            ("ดอนไผ่", "70130"),
        ],
        "บ้านโป่ง": [
            ("บ้านโป่ง", "70110"),
            ("ท่าผา", "70110"),
            ("กรับใหญ่", "70190"),
            ("ดอนกระเบื้อง", "70110"),
            ("สวนกล้วย", "70110"),
            ("คุ้งพยอม", "70110"),
            ("หนองปลาหมอ", "70110"),
            ("เขาขลุง", "70110"),
        ],
        "บางแพ": [
            ("หัวโพ", "70160"),
        ],
        "โพธาราม": [
            ("โพธาราม", "70120"),
            ("บ้านฆ้อง", "70120"),
            ("เจ็ดเสมียน", "70120"),
            ("ท่าชุมพล", "70120"),
            ("บางโตนด", "70120"),
            ("เตาปูน", "70120"),
            ("เขาชะงุ้ม", "70120"),
        ],
        "ปากท่อ": [
            ("ดอนทราย", "70140"),
            ("หนองกระทุ่ม", "70140"),
            ("ป่าไก่", "70140"),
            ("วัดยางงาม", "70140"),
            ("ยางหัก", "70140"),
            ("วันดาว", "70140"),
            ("ห้วยยางโทน", "70140"),
        ],
        "วัดเพลง": [
            ("เกาะศาลพระ", "70170"),
            ("จอมประทัด", "70170"),
            ("วัดเพลง", "70170"),
        ],
        "บ้านคา": [
            ("บ้านคา", "70180"),
            ("บ้านบึง", "70180"),
        ],
        "จอมบึง": [
            ("จอมบึง", "70150"),
            ("ปากช่อง", "70150"),
            ("เบิกไพร", "70150"),
            ("ด่านทับตะโก", "70150"),
            ("แก้มอ้น", "70150"),
        ]},
    "ร้อยเอ็ด": {
        "เมืองร้อยเอ็ด": [
            ("เหนือเมือง", "45000"),
            ("ขอนแก่น", "45000"),
            ("นาโพธิ์", "45000"),
            ("สีแก้ว", "45000"),
            ("ปอภาร (ปอพาน)", "45000"),
            ("หนองแก้ว", "45000"),
            ("แคนใหญ่", "45000"),
        ],
        "เกษตรวิสัย": [
            ("เกษตรวิสัย", "45150"),
            ("เมืองบัว", "45150"),
            ("เหล่าหลวง", "45150"),
            ("สิงห์โคก", "45150"),
            ("บ้านฝาง", "45150"),
            ("หนองแวง", "45150"),
            ("กู่กาสิงห์", "45150"),
            ("น้ำอ้อม", "45150"),
        ],
        "ปทุมรัตน์": [
            ("บัวแดง", "45190"),
            ("ดอกล้ำ", "45190"),
            ("หนองแคน", "45190"),
            ("โพนสูง", "45190"),
            ("โนนสวรรค์", "45190"),
            ("สระบัว", "45190"),
            ("โนนสง่า", "45190"),
        ],
        "จตุรพักตรพิมาน": [
            ("หัวช้าง", "45180"),
            ("หนองผือ", "45180"),
            ("โคกล่าม", "45180"),
            ("น้ำใส", "45180"),
            ("ดงแดง", "45180"),
            ("ป่าสังข์", "45180"),
            ("อีง่อง", "45180"),
            ("ลิ้นฟ้า", "45180"),
            ("ดู่น้อย", "45180"),
        ],
        "ธวัชบุรี": [
            ("ธงธานี", "45170"),
            ("หนองไผ่", "45170"),
            ("ธวัชบุรี", "45170"),
            ("มะอึ", "45170"),
            ("เขวาทุ่ง", "45170"),
            ("ไพศาล", "45170"),
            ("เมืองน้อย", "45170"),
        ],
        "พนมไพร": [
            ("แสนสุข", "45140"),
            ("หนองทัพไทย", "45140"),
            ("โคกสว่าง", "45140"),
            ("นานวล", "45140"),
        ],
        "โพนทอง": [
            ("โคกกกม่วง", "45110"),
            ("หนองใหญ่", "45110"),
            ("โพธิ์ทอง", "45110"),
            ("สระนกแก้ว", "45110"),
        ],
        "โพธิ์ชัย": [
            ("อัคคะคำ", "45230"),
            ("สะอาด", "45230"),
            ("คำพอุง", "45230"),
            ("ดอนโอง", "45230"),
            ("โพธิ์ศรี", "45230"),
        ],
        "หนองพอก": [
            ("บึงงาม", "45210"),
            ("ภูเขาทอง", "45210"),
            ("กกโพธิ์", "45210"),
            ("หนองขุ่นใหญ่", "45210"),
            ("ผาน้ำย้อย", "45210"),
        ],
        "เสลภูมิ": [
            ("กลาง", "45120"),
            ("นางาม", "45120"),
            ("เมืองไพร", "45120"),
            ("นาเมือง", "45120"),
            ("วังหลวง", "45120"),
            ("ท่าม่วง", "45120"),
            ("เกาะแก้ว", "45120"),
            ("บึงเกลือ", "45120"),
        ],
        "สุวรรณภูมิ": [
            ("สระคู", "45130"),
            ("ดอกไม้", "45130"),
            ("เมืองทุ่ง", "45130"),
            ("บ่อพันขัน", "45130"),
            ("ทุ่งหลวง", "45130"),
            ("หัวช้าง", "45130"),
            ("น้ำคำ", "45130"),
            ("ช้างเผือก", "45130"),
            ("ทุ่งศรีเมือง", "45130"),
            ("จำปาขัน", "45130"),
        ],
        "เมืองสรวง": [
            ("คูเมือง", "45220"),
        ],
        "โพนทราย": [
            ("ศรีสว่าง", "45240"),
            ("ยางคำ", "45240"),
        ],
        "อาจสามารถ": [
            ("หน่อม", "45160"),
            ("โหรา", "45160"),
            ("ขี้เหล็ก", "45160"),
        ],
        "เมยวดี": [
            ("ชุมพร", "45250"),
            ("บุ่งเลิศ", "45250"),
            ("ชมสะอาด", "45250"),
        ],
        "ศรีสมเด็จ": [
            ("โพธิ์ทอง", "45000"),
            ("ศรีสมเด็จ", "45000"),
            ("หนองใหญ่", "45000"),
            ("สวนจิก", "45280"),
            ("โพธิ์สัย", "45280"),
            ("หนองแวงควง", "45000"),
        ],
        "จังหาร": [
            ("ม่วงลาด", "45000"),
            ("จังหาร", "45000"),
        ],
        "เชียงขวัญ": [
            ("เชียงขวัญ", "45000"),
            ("พลับพลา", "45170"),
            ("พระธาตุ", "45000"),
            ("บ้านเขือง", "45000"),
        ],
        "หนองฮี": [
            ("สาวแห", "45140"),
            ("ดูกอึ่ง", "45140"),
        ],
        "ทุ่งเขาหลวง": [
            ("บึงงาม", "45170"),
        ],
        "เมืองร้อยเอ็ด": [
            ("ในเมือง", "45000"),
            ("รอบเมือง", "45000"),
            ("สะอาดสมบูรณ์", "45000"),
            ("โนนรัง", "45000"),
            ("หนองแวง", "45000"),
            ("ดงลาน", "45000"),
            ("โนนตาล", "45000"),
            ("เมืองทอง", "45000"),
        ],
        "เกษตรวิสัย": [
            ("ดงครั่งใหญ่", "45150"),
            ("กำแพง", "45150"),
            ("โนนสว่าง", "45150"),
            ("ทุ่งทอง", "45150"),
            ("ดงครั่งน้อย", "45150"),
        ],
        "ปทุมรัตน์": [
            ("ขี้เหล็ก", "45190"),
        ],
        "จตุรพักตรพิมาน": [
            ("เมืองหงส์", "45180"),
            ("ดงกลาง", "45180"),
            ("ศรีโคตร", "45180"),
        ],
        "ธวัชบุรี": [
            ("นิเวศน์", "45170"),
            ("อุ่มเม้า", "45170"),
            ("บึงนคร", "45170"),
            ("ราชธานี", "45170"),
            ("หนองพอก", "45170"),
        ],
        "พนมไพร": [
            ("พนมไพร", "45140"),
            ("กุดน้ำใส", "45140"),
            ("โพธิ์ใหญ่", "45140"),
            ("วารีสวัสดิ์", "45140"),
            ("โพธิ์ชัย", "45140"),
            ("คำไฮ", "45140"),
            ("สระแก้ว", "45140"),
            ("ค้อใหญ่", "45140"),
            ("ชานุวรรณ", "45140"),
        ],
        "โพนทอง": [
            ("แวง", "45110"),
            ("นาอุดม", "45110"),
            ("สว่าง", "45110"),
            ("โนนชัยศรี", "45110"),
            ("โพธิ์ศรีสว่าง", "45110"),
            ("อุ่มเม่า", "45110"),
            ("คำนาดี", "45110"),
            ("พรมสวรรค์", "45110"),
            ("วังสามัคคี", "45110"),
            ("โคกสูง", "45110"),
        ],
        "โพธิ์ชัย": [
            ("เชียงใหม่", "45230"),
            ("บัวคำ", "45230"),
            ("หนองตาไก้", "45230"),
            ("ขามเปี้ย", "45230"),
        ],
        "หนองพอก": [
            ("หนองพอก", "45210"),
            ("โคกสว่าง", "45210"),
            ("รอบเมือง", "45210"),
            ("ท่าสีดา", "45210"),
        ],
        "เสลภูมิ": [
            ("นาแซง", "45120"),
            ("ขวาว", "45120"),
            ("โพธิ์ทอง", "45120"),
            ("ภูเงิน", "45120"),
            ("นาเลิง", "45120"),
            ("เหล่าน้อย", "45120"),
            ("ศรีวิลัย", "45120"),
            ("หนองหลวง", "45120"),
            ("พรสวรรค์", "45120"),
            ("ขวัญเมือง", "45120"),
        ],
        "สุวรรณภูมิ": [
            ("นาใหญ่", "45130"),
            ("หินกอง", "45130"),
            ("หัวโทน", "45130"),
            ("ห้วยหินลาด", "45130"),
            ("ทุ่งกุลา", "45130"),
        ],
        "เมืองสรวง": [
            ("หนองผือ", "45220"),
            ("หนองหิน", "45220"),
            ("กกกุง", "45220"),
            ("เมืองสรวง", "45220"),
        ],
        "โพนทราย": [
            ("โพนทราย", "45240"),
            ("สามขา", "45240"),
            ("ท่าหาดยาว", "45240"),
        ],
        "อาจสามารถ": [
            ("อาจสามารถ", "45160"),
            ("โพนเมือง", "45160"),
            ("บ้านแจ้ง", "45160"),
            ("หนองหมื่นถ่าน", "45160"),
            ("หนองขาม", "45160"),
            ("หนองบัว", "45160"),
            ("บ้านดู่", "45160"),
        ],
        "เมยวดี": [
            ("เมยวดี", "45250"),
        ],
        "ศรีสมเด็จ": [
            ("เมืองเปลือย", "45000"),
            ("บ้านบาก", "45000"),
        ],
        "จังหาร": [
            ("ดินดำ", "45000"),
            ("ปาฝา", "45000"),
            ("ดงสิงห์", "45000"),
            ("ยางใหญ่", "45000"),
            ("ผักแว่น", "45000"),
            ("แสนชาติ", "45000"),
        ],
        "เชียงขวัญ": [
            ("พระเจ้า", "45000"),
            ("หมูม้น", "45170"),
        ],
        "หนองฮี": [
            ("หนองฮี", "45140"),
            ("เด่นราษฎร์", "45140"),
        ],
        "ทุ่งเขาหลวง": [
            ("ทุ่งเขาหลวง", "45170"),
            ("เทอดไทย", "45170"),
            ("มะบ้า", "45170"),
            ("เหล่า", "45170"),
        ]},
    "ลพบุรี": {
        "เมืองลพบุรี": [
            ("ทะเลชุบศร", "15000"),
            ("ท่าหิน", "15000"),
            ("โก่งธนู", "13240"),
            ("เขาสามยอด", "15000"),
            ("โคกกะเทียม", "15000"),
            ("โคกกะเทียม", "15160"),
            ("โคกลำพาน", "15000"),
            ("โคกตูม", "15210"),
            ("งิ้วราย", "15000"),
            ("ตะลุง", "15000"),
            ("ท่าศาลา", "15000"),
            ("นิคมสร้างตนเอง", "15000"),
            ("บางขันหมาก", "15000"),
            ("บ้านข่อย", "15000"),
            ("ท้ายตลาด", "15000"),
            ("ป่าตาล", "15000"),
            ("โพธิ์เก้าต้น", "15000"),
            ("โพธิ์ตรุ", "15000"),
            ("สี่คลอง", "15000"),
            ("ถนนใหญ่", "15000"),
        ],
        "พัฒนานิคม": [
            ("ช่องสาริกา", "15220"),
            ("ดีลัง", "15220"),
            ("โคกสลุง", "15140"),
            ("ชอนน้อย", "15140"),
            ("หนองบัว", "15140"),
            ("ห้วยขุนราม", "18220"),
            ("น้ำสุด", "15140"),
        ],
        "โคกสำโรง": [
            ("โคกสำโรง", "15120"),
            ("ถลุงเหล็ก", "15120"),
            ("หลุมข้าว", "15120"),
            ("ห้วยโป่ง", "15120"),
            ("คลองเกตุ", "15120"),
            ("เพนียด", "15120"),
        ],
        "ชัยบาดาล": [
            ("ชัยนารายณ์", "15130"),
            ("ห้วยหิน", "15130"),
            ("บัวชุม", "15130"),
            ("มะกอกหวาน", "15230"),
            ("นาโสม", "15190"),
            ("หนองยายโต๊ะ", "15130"),
            ("เกาะรัง", "15130"),
            ("นิคมลำนารายณ์", "15130"),
            ("ชัยบาดาล", "15130"),
            ("ชัยบาดาล", "15230"),
        ],
        "ท่าวุ้ง": [
            ("บางลี่", "15150"),
            ("หัวสำโรง", "15150"),
            ("ลาดสาลี่", "15150"),
            ("บ้านเบิก", "15150"),
        ],
        "บ้านหมี่": [
            ("ไผ่ใหญ่", "15110"),
            ("บ้านทราย", "15110"),
            ("บ้านชี", "15180"),
            ("พุคา", "15110"),
            ("หินปัก", "15180"),
            ("หินปัก", "15110"),
            ("บางพึ่ง", "15180"),
            ("บางพึ่ง", "15110"),
            ("หนองทรายขาว", "15110"),
            ("บางกะพี้", "15180"),
            ("หนองเต่า", "15180"),
            ("หนองเต่า", "15110"),
            ("โพนทอง", "15180"),
            ("โพนทอง", "15110"),
            ("ชอนม่วง", "15110"),
            ("หนองกระเบียน", "15110"),
            ("สายห้วยแก้ว", "15110"),
            ("มหาสอน", "15110"),
            ("บ้านหมี่", "15110"),
            ("หนองเมือง", "15110"),
            ("สนามแจง", "15110"),
        ],
        "ท่าหลวง": [
            ("ท่าหลวง", "15230"),
            ("แก่งผักกูด", "15230"),
        ],
        "สระโบสถ์": [
            ("มหาโพธิ", "15240"),
            ("ทุ่งท่าช้าง", "15240"),
            ("ห้วยใหญ่", "15240"),
            ("นิยมชัย", "15240"),
        ],
        "ลำสนธิ": [
            ("ลำสนธิ", "15190"),
            ("กุดตาเพชร", "15190"),
            ("เขารวก", "15190"),
            ("เขาน้อย", "15130"),
        ],
        "หนองม่วง": [
            ("หนองม่วง", "15170"),
            ("ดงดินแดง", "15170"),
            ("ยางโทน", "15170"),
        ],
        "เมืองลพบุรี": [
            ("กกโก", "15000"),
            ("เขาพระงาม", "15000"),
            ("เขาพระงาม", "15160"),
            ("ดอนโพธิ์", "15000"),
            ("ท่าแค", "15000"),
            ("ท่าแค", "15160"),
            ("พรหมมาสตร์", "15000"),
        ],
        "พัฒนานิคม": [
            ("พัฒนานิคม", "15140"),
            ("มะนาวหวาน", "15140"),
        ],
        "โคกสำโรง": [
            ("เกาะแก้ว", "15120"),
            ("สะแกราบ", "15120"),
            ("วังเพลิง", "15120"),
            ("ดงมะรุม", "15120"),
            ("วังขอนขว้าง", "15120"),
            ("วังจั่น", "15120"),
            ("หนองแขม", "15120"),
        ],
        "ชัยบาดาล": [
            ("ลำนารายณ์", "15130"),
            ("ศิลาทิพย์", "15130"),
            ("ม่วงค่อม", "15230"),
            ("ท่าดินดำ", "15130"),
            ("ซับตะเคียน", "15130"),
            ("ท่ามะนาว", "15130"),
            ("บ้านใหม่สามัคคี", "15130"),
            ("เขาแหลม", "15130"),
        ],
        "ท่าวุ้ง": [
            ("ท่าวุ้ง", "15150"),
            ("บางคู้", "15150"),
            ("โพตลาดแก้ว", "15150"),
            ("บางงา", "15150"),
            ("โคกสลุด", "15150"),
            ("เขาสมอคอน", "15180"),
            ("มุจลินท์", "15150"),
        ],
        "บ้านหมี่": [
            ("บ้านกล้วย", "15110"),
            ("ดงพลับ", "15110"),
            ("พุคา", "15180"),
            ("หนองทรายขาว", "15180"),
            ("บางกะพี้", "15110"),
            ("บางขาม", "15180"),
            ("ดอนดึง", "15110"),
            ("เชียงงา", "15110"),
        ],
        "ท่าหลวง": [
            ("ซับจำปา", "15230"),
            ("หนองผักแว่น", "15230"),
            ("ทะเลวังวัด", "15230"),
            ("หัวลำ", "15230"),
        ],
        "สระโบสถ์": [
            ("สระโบสถ์", "15240"),
        ],
        "โคกเจริญ": [
            ("โคกเจริญ", "15250"),
            ("ยางราก", "15250"),
            ("หนองมะค่า", "15250"),
            ("วังทอง", "15250"),
            ("โคกแสมสาร", "15250"),
        ],
        "ลำสนธิ": [
            ("ซับสมบูรณ์", "15190"),
            ("หนองรี", "15190"),
            ("เขาน้อย", "15190"),
        ],
        "หนองม่วง": [
            ("บ่อทอง", "15170"),
            ("ชอนสมบูรณ์", "15170"),
            ("ชอนสารเดช", "15170"),
        ]},
    "ลำปาง": {
        "เมืองลำปาง": [
            ("เวียงเหนือ", "52000"),
            ("สบตุ๋ย", "52100"),
            ("ชมพู", "52100"),
            ("ชมพู", "52000"),
            ("กล้วยแพะ", "52000"),
            ("ทุ่งฝาย", "52000"),
            ("ต้นธงชัย", "52000"),
            ("บุญนาคพัฒนา", "52000"),
        ],
        "แม่เมาะ": [
            ("บ้านดง", "52220"),
            ("นาสัก", "52220"),
            ("จางเหนือ", "52220"),
        ],
        "เกาะคา": [
            ("นาแก้ว", "52130"),
            ("ไหล่หิน", "52130"),
            ("เกาะคา", "52130"),
            ("นาแส่ง", "52130"),
            ("ใหม่พัฒนา", "52130"),
        ],
        "เสริมงาม": [
            ("เสริมขวา", "52210"),
        ],
        "งาว": [
            ("บ้านโป่ง", "52110"),
            ("ปงเตา", "52110"),
            ("แม่ตีบ", "52110"),
        ],
        "แจ้ห่ม": [
            ("แจ้ห่ม", "52120"),
            ("บ้านสา", "52120"),
            ("แม่สุก", "52120"),
            ("เมืองมาย", "52120"),
            ("ทุ่งผึ้ง", "52120"),
        ],
        "วังเหนือ": [
            ("ทุ่งฮั้ว", "52140"),
            ("วังเหนือ", "52140"),
            ("ร่องเคาะ", "52140"),
            ("วังทอง", "52140"),
            ("วังซ้าย", "52140"),
        ],
        "เถิน": [
            ("แม่วะ", "52230"),
            ("แม่ปะ", "52160"),
            ("นาโป่ง", "52160"),
            ("แม่ถอด", "52160"),
        ],
        "แม่พริก": [
            ("แม่ปุ", "52180"),
        ],
        "แม่ทะ": [
            ("นาครัว", "52150"),
            ("ป่าตัน", "52150"),
            ("น้ำโจ้", "52150"),
            ("สันดอนแก้ว", "52150"),
        ],
        "สบปราบ": [
            ("สมัย", "52170"),
        ],
        "ห้างฉัตร": [
            ("ห้างฉัตร", "52190"),
            ("หนองหล่ม", "52190"),
            ("เมืองยาว", "52190"),
            ("เวียงตาล", "52190"),
            ("แม่สัน", "52190"),
        ],
        "เมืองปาน": [
            ("บ้านขอ", "52240"),
            ("ทุ่งกว๋าว", "52240"),
            ("แจ้ซ้อน", "52240"),
            ("หัวเมือง", "52240"),
        ],
        "เมืองลำปาง": [
            ("หัวเวียง", "52000"),
            ("สวนดอก", "52100"),
            ("พระบาท", "52000"),
            ("ปงแสนทอง", "52100"),
            ("บ้านแลง", "52000"),
            ("บ้านเสด็จ", "52000"),
            ("พิชัย", "52000"),
            ("บ้านเอื้อม", "52100"),
            ("บ้านเป้า", "52100"),
            ("บ้านค่า", "52100"),
            ("บ่อแฮ้ว", "52100"),
            ("นิคมพัฒนา", "52000"),
        ],
        "แม่เมาะ": [
            ("แม่เมาะ", "52220"),
            ("สบป้าด", "52220"),
        ],
        "เกาะคา": [
            ("ลำปางหลวง", "52130"),
            ("วังพร้าว", "52130"),
            ("ศาลา", "52130"),
            ("ท่าผา", "52130"),
        ],
        "เสริมงาม": [
            ("ทุ่งงาม", "52210"),
            ("เสริมซ้าย", "52210"),
            ("เสริมกลาง", "52210"),
        ],
        "งาว": [
            ("หลวงเหนือ", "52110"),
            ("หลวงใต้", "52110"),
            ("บ้านร้อง", "52110"),
            ("นาแก", "52110"),
            ("บ้านอ้อน", "52110"),
            ("บ้านแหง", "52110"),
            ("บ้านหวด", "52110"),
        ],
        "แจ้ห่ม": [
            ("ปงดอน", "52120"),
            ("วิเชตนคร", "52120"),
        ],
        "วังเหนือ": [
            ("วังใต้", "52140"),
            ("วังแก้ว", "52140"),
            ("วังทรายคำ", "52140"),
        ],
        "เถิน": [
            ("ล้อมแรด", "52160"),
            ("แม่มอก", "52160"),
            ("เวียงมอก", "52160"),
            ("เถินบุรี", "52160"),
        ],
        "แม่พริก": [
            ("แม่พริก", "52180"),
            ("ผาปัง", "52180"),
            ("พระบาทวังตวง", "52180"),
            ("พระบาทวังตวง", "52230"),
        ],
        "แม่ทะ": [
            ("แม่ทะ", "52150"),
            ("บ้านกิ่ว", "52150"),
            ("บ้านบอม", "52150"),
            ("ดอนไฟ", "52150"),
            ("หัวเสือ", "52150"),
            ("วังเงิน", "52150"),
        ],
        "สบปราบ": [
            ("สบปราบ", "52170"),
            ("แม่กัวะ", "52170"),
            ("นายาง", "52170"),
        ],
        "ห้างฉัตร": [
            ("ปงยางคก", "52190"),
            ("วอแก้ว", "52190"),
        ],
        "เมืองปาน": [
            ("เมืองปาน", "52240"),
        ]},
    "ลำพูน": {
        "เมืองลำพูน": [
            ("เหมืองง่า", "51000"),
            ("อุโมงค์", "51150"),
            ("หนองช้างคืน", "51150"),
            ("ประตูป่า", "51000"),
            ("ต้นธง", "51000"),
            ("เวียงยอง", "51000"),
            ("ศรีบัวบาน", "51000"),
            ("หนองหนาม", "51000"),
        ],
        "แม่ทา": [
            ("ทาปลาดุก", "51140"),
        ],
        "บ้านโฮ่ง": [
            ("บ้านโฮ่ง", "51130"),
        ],
        "ลี้": [
            ("ลี้", "51110"),
            ("นาทราย", "51110"),
            ("ดงดำ", "51110"),
            ("ก้อ", "51110"),
        ],
        "ทุ่งหัวช้าง": [
            ("ทุ่งหัวช้าง", "51160"),
        ],
        "ป่าซาง": [
            ("ปากบ่อง", "51120"),
            ("บ้านเรือน", "51120"),
            ("ท่าตุ้ม", "51120"),
            ("น้ำดิบ", "51120"),
            ("นครเจดีย์", "51120"),
        ],
        "เวียงหนองล่อง": [
            ("วังผาง", "51120"),
        ],
        "เมืองลำพูน": [
            ("ในเมือง", "51000"),
            ("ริมปิง", "51000"),
            ("บ้านแป้น", "51000"),
            ("เหมืองจี้", "51000"),
            ("ป่าสัก", "51000"),
            ("บ้านกลาง", "51000"),
            ("มะเขือแจ้", "51000"),
        ],
        "แม่ทา": [
            ("ทาสบเส้า", "51140"),
            ("ทากาศ", "51170"),
            ("ทาขุมเงิน", "51170"),
            ("ทาทุ่งหลวง", "51170"),
            ("ทาแม่ลอบ", "51170"),
        ],
        "บ้านโฮ่ง": [
            ("ป่าพลู", "51130"),
            ("เหล่ายาว", "51130"),
            ("ศรีเตี้ย", "51130"),
            ("หนองปลาสะวาย", "51130"),
        ],
        "ลี้": [
            ("แม่ตืน", "51110"),
            ("แม่ลาน", "51110"),
            ("ป่าไผ่", "51110"),
            ("ศรีวิชัย", "51110"),
        ],
        "ทุ่งหัวช้าง": [
            ("บ้านปวง", "51160"),
            ("ตะเคียนปม", "51160"),
        ],
        "ป่าซาง": [
            ("ป่าซาง", "51120"),
            ("แม่แรง", "51120"),
            ("ม่วงน้อย", "51120"),
            ("มะกอก", "51120"),
        ],
        "บ้านธิ": [
            ("บ้านธิ", "51180"),
            ("ห้วยยาบ", "51180"),
        ],
        "เวียงหนองล่อง": [
            ("หนองล่อง", "51120"),
            ("หนองยวง", "51120"),
        ]},
    "ศรีสะเกษ": {
        "เมืองศรีสะเกษ": [
            ("เมืองเหนือ", "33000"),
            ("หนองครก", "33000"),
            ("โพนค้อ", "33000"),
            ("หนองแก้ว", "33000"),
            ("หมากเขียบ", "33000"),
        ],
        "ยางชุมน้อย": [
            ("ยางชุมน้อย", "33190"),
            ("ลิ้นฟ้า", "33190"),
        ],
        "กันทรารมย์": [
            ("ดูน", "33130"),
            ("โนนสัง", "33130"),
            ("หนองหัวช้าง", "33130"),
            ("หนองแก้ว", "33130"),
            ("บัวน้อย", "33130"),
            ("ดู่", "33130"),
            ("จาน", "33130"),
            ("คำเนียม", "33130"),
        ],
        "ขุขันธ์": [
            ("กันทรารมย์", "33140"),
            ("ใจดี", "33140"),
            ("ปรือใหญ่", "33140"),
            ("ห้วยเหนือ", "33140"),
            ("โคกเพชร", "33140"),
            ("ปราสาท", "33140"),
            ("กฤษณา", "33140"),
            ("ลมศักดิ์", "33140"),
            ("หนองฉลอง", "33140"),
            ("ศรีสะอาด", "33140"),
        ],
        "ไพรบึง": [
            ("ไพรบึง", "33180"),
            ("ดินแดง", "33180"),
            ("สำโรงพลัน", "33180"),
            ("โนนปูน", "33180"),
        ],
        "ปรางค์กู่": [
            ("พิมาย", "33170"),
            ("หนองเชียงทูน", "33170"),
            ("ตูม", "33170"),
            ("สวาย", "33170"),
            ("พิมายเหนือ", "33170"),
        ],
        "ขุนหาญ": [
            ("สิ", "33150"),
            ("ไพร", "33150"),
            ("ขุนหาญ", "33150"),
            ("โนนสูง", "33150"),
            ("กันทรอม", "33150"),
            ("ภูฝ้าย", "33150"),
            ("ห้วยจันทร์", "33150"),
        ],
        "ราษีไศล": [
            ("จิกสังข์ทอง", "33160"),
            ("ด่าน", "33160"),
            ("ดู่", "33160"),
            ("หนองอึ่ง", "33160"),
            ("บัวหุ่ง", "33160"),
            ("ไผ่", "33160"),
            ("หนองหมี", "33160"),
            ("สร้างปี่", "33160"),
        ],
        "อุทุมพรพิสัย": [
            ("กำแพง", "33120"),
            ("ทุ่งไชย", "33120"),
            ("แขม", "33120"),
            ("หนองไฮ", "33120"),
            ("ขะยูง", "33120"),
            ("แต้", "33120"),
            ("แข้", "33120"),
            ("ปะอาว", "33120"),
            ("หนองห้าง", "33120"),
            ("สระกำแพงใหญ่", "33120"),
            ("โคกหล่าม", "33120"),
            ("โคกจาน", "33120"),
        ],
        "บึงบูรพ์": [
            ("เป๊าะ", "33220"),
            ("บึงบูรพ์", "33220"),
        ],
        "ห้วยทับทัน": [
            ("ห้วยทับทัน", "33210"),
            ("กล้วยกว้าง", "33210"),
            ("ผักไหม", "33210"),
            ("จานแสนไชย", "33210"),
        ],
        "เมืองศรีสะเกษ": [
            ("เมืองใต้", "33000"),
            ("คูซอด", "33000"),
            ("ซำ", "33000"),
            ("จาน", "33000"),
            ("ตะดอบ", "33000"),
            ("โพนข่า", "33000"),
            ("โพนเขวา", "33000"),
            ("หญ้าปล้อง", "33000"),
            ("ทุ่ม", "33000"),
            ("หนองไฮ", "33000"),
            ("น้ำคำ", "33000"),
            ("โพธิ์", "33000"),
            ("หนองไผ่", "33000"),
        ],
        "ยางชุมน้อย": [
            ("คอนกาม", "33190"),
            ("โนนคูณ", "33190"),
            ("กุดเมืองฮาม", "33190"),
            ("บึงบอน", "33190"),
            ("ยางชุมใหญ่", "33190"),
        ],
        "กันทรารมย์": [
            ("ยาง", "33130"),
            ("หนองแวง", "33130"),
            ("ทาม", "33130"),
            ("ละทาย", "33130"),
            ("เมืองน้อย", "33130"),
            ("อีปาด", "33130"),
            ("หนองบัว", "33130"),
            ("ผักแพว", "33130"),
        ],
        "ขุขันธ์": [
            ("จะกง", "33140"),
            ("ดองกำเม็ด", "33140"),
            ("โสน", "33140"),
            ("สะเดาใหญ่", "33140"),
            ("ตาอุด", "33140"),
            ("ห้วยใต้", "33140"),
            ("หัวเสือ", "33140"),
            ("ตะเคียน", "33140"),
            ("นิคมพัฒนา", "33140"),
            ("สำโรงตาเจ็น", "33140"),
            ("ห้วยสำราญ", "33140"),
            ("ศรีตระกูล", "33140"),
        ],
        "ไพรบึง": [
            ("ปราสาทเยอ", "33180"),
            ("สุขสวัสดิ์", "33180"),
        ],
        "ปรางค์กู่": [
            ("กู่", "33170"),
            ("สมอ", "33170"),
            ("โพธิ์ศรี", "33170"),
            ("สำโรงปราสาท", "33170"),
            ("ดู่", "33170"),
        ],
        "ขุนหาญ": [
            ("บักดอง", "33150"),
            ("พราน", "33150"),
            ("โพธิ์วงศ์", "33150"),
            ("กระหวัน", "33150"),
            ("โพธิ์กระสังข์", "33150"),
        ],
        "ราษีไศล": [
            ("เมืองคง", "33160"),
            ("เมืองแคน", "33160"),
            ("หนองแค", "33160"),
            ("ส้มป่อย", "33160"),
            ("หว้านคำ", "33160"),
        ],
        "อุทุมพรพิสัย": [
            ("อี่หล่ำ", "33120"),
            ("ก้านเหลือง", "33120"),
            ("สำโรง", "33120"),
            ("ตาเกษ", "33120"),
            ("หัวช้าง", "33120"),
            ("รังแร้ง", "33120"),
            ("โพธิ์ชัย", "33120"),
        ],
        "ห้วยทับทัน": [
            ("เมืองหลวง", "33210"),
        ],
        "โนนคูณ": [
            ("โนนค้อ", "33250"),
            ("โพธิ์", "33250"),
            ("เหล่ากวาง", "33250"),
        ],
        "ศรีรัตนะ": [
            ("พิงพวย", "33240"),
            ("เสื่องข้าว", "33240"),
            ("สะพุง", "33240"),
        ],
        "น้ำเกลี้ยง": [
            ("เขิน", "33130"),
            ("รุ่งระวี", "33130"),
            ("คูบ", "33130"),
        ],
        "วังหิน": [
            ("ธาตุ", "33270"),
            ("ดวนใหญ่", "33270"),
            ("ทุ่งสว่าง", "33270"),
            ("โพนยาง", "33270"),
        ],
        "ภูสิงห์": [
            ("โคกตาล", "33140"),
            ("ละลม", "33140"),
            ("ดงรัก", "33140"),
        ],
        "เบญจลักษ์": [
            ("เสียว", "33110"),
            ("หนองหว้า", "33110"),
        ],
        "พยุห์": [
            ("พรหมสวัสดิ์", "33230"),
            ("ตำแย", "33230"),
            ("โนนเพ็ก", "33230"),
            ("หนองค้า", "33230"),
        ],
        "โพธิ์ศรีสุวรรณ": [
            ("โดด", "33120"),
            ("เสียว", "33120"),
            ("หนองม้า", "33120"),
            ("ผือใหญ่", "33120"),
            ("อีเซ", "33120"),
        ],
        "ศิลาลาด": [
            ("กุง", "33160"),
            ("คลีกลิ้ง", "33160"),
            ("หนองบัวดง", "33160"),
            ("โจดม่วง", "33160"),
        ],
        "กันทรลักษ์": [
            ("กุดเสลา", "33110"),
            ("ขนุน", "33110"),
            ("ตระกาจ", "33110"),
            ("ทุ่งใหญ่", "33110"),
            ("บึงมะลู", "33110"),
            ("ภูเงิน", "33110"),
            ("รุง", "33110"),
            ("ละลาย", "33110"),
            ("สวนกล้วย", "33110"),
            ("เมือง", "33110"),
            ("เวียงเหนือ", "33110"),
            ("โนนสำราญ", "33110"),
        ],
        "ห้วยทับทัน": [
            ("ปราสาท", "33210"),
        ],
        "โนนคูณ": [
            ("บก", "33250"),
            ("หนองกุง", "33250"),
        ],
        "ศรีรัตนะ": [
            ("ศรีแก้ว", "33240"),
            ("สระเยาว์", "33240"),
            ("ตูม", "33240"),
            ("ศรีโนนงาม", "33240"),
        ],
        "น้ำเกลี้ยง": [
            ("น้ำเกลี้ยง", "33130"),
            ("ละเอาะ", "33130"),
            ("ตองปิด", "33130"),
        ],
        "วังหิน": [
            ("บุสูง", "33270"),
            ("บ่อแก้ว", "33270"),
            ("ศรีสำราญ", "33270"),
            ("วังหิน", "33270"),
        ],
        "ภูสิงห์": [
            ("ห้วยตามอญ", "33140"),
            ("ห้วยตึ๊กชู", "33140"),
            ("ตะเคียนราม", "33140"),
            ("ไพรพัฒนา", "33140"),
        ],
        "เมืองจันทร์": [
            ("เมืองจันทร์", "33120"),
            ("ตาโกน", "33120"),
            ("หนองใหญ่", "33120"),
        ],
        "เบญจลักษ์": [
            ("หนองงูเหลือม", "33110"),
            ("หนองฮาง", "33110"),
            ("ท่าคล้อ", "33110"),
        ],
        "พยุห์": [
            ("พยุห์", "33230"),
        ],
        "กันทรลักษ์": [
            ("กระแชง", "33110"),
            ("จานใหญ่", "33110"),
            ("ชำ", "33110"),
            ("น้ำอ้อม", "33110"),
            ("ภูผาหมอก", "33110"),
            ("สังเม็ก", "33110"),
            ("หนองหญ้าลาด", "33110"),
            ("เสาธงชัย", "33110"),
        ]},
    "สกลนคร": {
        "เมืองสกลนคร": [
            ("งิ้วด่อน", "47000"),
            ("โนนหอม", "47000"),
            ("ท่าแร่", "47000"),
            ("ท่าแร่", "47230"),
            ("ม่วงลาย", "47000"),
            ("ห้วยยาง", "47000"),
            ("ฮางโฮง", "47000"),
            ("โคกก่อง", "47000"),
        ],
        "กุสุมาลย์": [
            ("อุ่มจาน", "47230"),
        ],
        "กุดบาก": [
            ("กุดบาก", "47180"),
            ("นาม่อง", "47180"),
        ],
        "พรรณานิคม": [
            ("วังยาง", "47130"),
            ("พอกน้อย", "47220"),
            ("ไร่", "47130"),
            ("ช้างมิ่ง", "47130"),
            ("นาใน", "47130"),
        ],
        "พังโคน": [
            ("ม่วงไข่", "47160"),
            ("แร่", "47160"),
            ("ไฮหย่อง", "47160"),
            ("ต้นผึ้ง", "47160"),
        ],
        "วาริชภูมิ": [
            ("วาริชภูมิ", "47150"),
            ("ปลาโหล", "47150"),
            ("หนองลาด", "47150"),
        ],
        "นิคมน้ำอูน": [
            ("นิคมน้ำอูน", "47270"),
            ("หนองบัว", "47270"),
        ],
        "วานรนิวาส": [
            ("วานรนิวาส", "47120"),
            ("ขัวก่าย", "47120"),
            ("คูสะคาม", "47120"),
            ("หนองแวง", "47120"),
            ("นาซอ", "47120"),
            ("หนองแวงใต้", "47120"),
        ],
        "คำตากล้า": [
            ("คำตากล้า", "47250"),
            ("หนองบัวสิม", "47250"),
            ("นาแต้", "47250"),
            ("แพด", "47250"),
        ],
        "บ้านม่วง": [
            ("มาย", "47140"),
            ("ดงหม้อทองใต้", "47140"),
            ("บ่อแก้ว", "47140"),
        ],
        "อากาศอำนวย": [
            ("อากาศ", "47170"),
            ("โพนแพง", "47170"),
            ("โพนงาม", "47170"),
            ("ท่าก้อน", "47170"),
            ("นาฮี", "47170"),
            ("สามัคคีพัฒนา", "47170"),
        ],
        "สว่างแดนดิน": [
            ("คำสะอาด", "47110"),
            ("บงเหนือ", "47110"),
            ("โคกสี", "47110"),
            ("หนองหลวง", "47110"),
            ("บงใต้", "47110"),
            ("ค้อใต้", "47110"),
            ("แวง", "47240"),
            ("ทรายมูล", "47110"),
            ("ตาลโกน", "47240"),
            ("ตาลเนิ้ง", "47240"),
            ("ธาตุทอง", "47240"),
        ],
        "ส่องดาว": [
            ("ส่องดาว", "47190"),
            ("ปทุมวาปี", "47190"),
        ],
        "เต่างอย": [
            ("บึงทวาย", "47260"),
            ("นาตาล", "47260"),
        ],
        "โคกศรีสุพรรณ": [
            ("ตองโขบ", "47280"),
            ("ด่านม่วงคำ", "47280"),
        ],
        "เจริญศิลป์": [
            ("บ้านเหล่า", "47290"),
            ("ทุ่งแก", "47290"),
            ("โคกศิลา", "47290"),
        ],
        "โพนนาแก้ว": [
            ("บ้านโพน", "47230"),
            ("นาแก้ว", "47230"),
            ("เชียงสือ", "47230"),
        ],
        "ภูพาน": [
            ("สร้างค้อ", "47180"),
            ("หลุบเลา", "47180"),
            ("โคกภู", "47180"),
            ("กกปลาซิว", "47180"),
        ],
        "เมืองสกลนคร": [
            ("ธาตุเชิงชุม", "47000"),
            ("ขมิ้น", "47220"),
            ("เชียงเครือ", "47000"),
            ("ดงชน", "47000"),
            ("พังขว้าง", "47000"),
            ("ดงมะไฟ", "47000"),
            ("ธาตุนาเวง", "47000"),
            ("เหล่าปอแดง", "47000"),
            ("หนองลาด", "47220"),
        ],
        "กุสุมาลย์": [
            ("กุสุมาลย์", "47210"),
            ("นาโพธิ์", "47210"),
            ("นาเพียง", "47230"),
            ("โพธิไพศาล", "47210"),
        ],
        "กุดบาก": [
            ("กุดไห", "47180"),
        ],
        "พรรณานิคม": [
            ("พรรณา", "47130"),
            ("นาหัวบ่อ", "47220"),
            ("สว่าง", "47130"),
            ("บะฮี", "47130"),
            ("เชิงชุม", "47130"),
        ],
        "พังโคน": [
            ("พังโคน", "47160"),
        ],
        "วาริชภูมิ": [
            ("คำบ่อ", "47150"),
            ("ค้อเขียว", "47150"),
        ],
        "นิคมน้ำอูน": [
            ("หนองปลิง", "47270"),
            ("สุวรรณคาม", "47270"),
        ],
        "วานรนิวาส": [
            ("เดื่อศรีคันไชย", "47120"),
            ("หนองสนม", "47120"),
            ("ธาตุ", "47120"),
            ("ศรีวิชัย", "47120"),
            ("อินทร์แปลง", "47120"),
            ("นาคำ", "47120"),
            ("คอนสวรรค์", "47120"),
            ("กุดเรือคำ", "47120"),
        ],
        "บ้านม่วง": [
            ("ม่วง", "47140"),
            ("ดงหม้อทอง", "47140"),
            ("ดงเหนือ", "47140"),
            ("ห้วยหลัว", "47140"),
            ("โนนสะอาด", "47140"),
            ("หนองกวั่ง", "47140"),
        ],
        "อากาศอำนวย": [
            ("วาใหญ่", "47170"),
            ("บะหว้า", "47170"),
        ],
        "สว่างแดนดิน": [
            ("สว่างแดนดิน", "47110"),
            ("บ้านต้าย", "47110"),
            ("โพนสูง", "47110"),
            ("พันนา", "47240"),
            ("บ้านถ่อน", "47110"),
        ],
        "ส่องดาว": [
            ("ท่าศิลา", "47190"),
            ("วัฒนา", "47190"),
        ],
        "เต่างอย": [
            ("เต่างอย", "47260"),
            ("จันทร์เพ็ญ", "47260"),
        ],
        "โคกศรีสุพรรณ": [
            ("เหล่าโพนค้อ", "47280"),
            ("แมดนาท่ม", "47280"),
        ],
        "เจริญศิลป์": [
            ("เจริญศิลป์", "47290"),
            ("หนองแปน", "47290"),
        ],
        "โพนนาแก้ว": [
            ("นาตงวัฒนา", "47230"),
            ("บ้านแป้น", "47230"),
        ]},
    "สงขลา": {
        "เมืองสงขลา": [
            ("เขารูปช้าง", "90000"),
            ("เกาะยอ", "90100"),
        ],
        "สทิงพระ": [
            ("กระดังงา", "90190"),
            ("สนามชัย", "90190"),
            ("บ่อแดง", "90190"),
        ],
        "จะนะ": [
            ("ป่าชิง", "90130"),
            ("นาทับ", "90130"),
            ("จะโหนง", "90130"),
            ("คลองเปียะ", "90130"),
        ],
        "นาทวี": [
            ("นาทวี", "90160"),
            ("ฉาง", "90160"),
            ("นาหมอศรี", "90160"),
        ],
        "เทพา": [
            ("เทพา", "90150"),
            ("ปากบาง", "90150"),
            ("เกาะสะบ้า", "90150"),
            ("สะกอม", "90150"),
        ],
        "สะบ้าย้อย": [
            ("สะบ้าย้อย", "90210"),
            ("คูหา", "90210"),
            ("เขาแดง", "90210"),
            ("บาโหย", "90210"),
            ("ธารคีรี", "90210"),
        ],
        "ระโนด": [
            ("บ่อตรุ", "90140"),
            ("พังยาง", "90140"),
            ("วัดสน", "90140"),
            ("บ้านขาว", "90140"),
        ],
        "กระแสสินธุ์": [
            ("เกาะใหญ่", "90270"),
            ("โรง", "90270"),
        ],
        "รัตภูมิ": [
            ("ท่าชะมวง", "90180"),
            ("คูหาใต้", "90180"),
            ("ควนรู", "90220"),
            ("เขาพระ", "90180"),
        ],
        "สะเดา": [
            ("พังลา", "90170"),
            ("ท่าโพธิ์", "90170"),
            ("สำนักขาม", "90120"),
        ],
        "หาดใหญ่": [
            ("หาดใหญ่", "90110"),
            ("ควนลัง", "90110"),
            ("คอหงส์", "90110"),
            ("บ้านพรุ", "90250"),
        ],
        "นาหม่อม": [
            ("พิจิตร", "90310"),
            ("ทุ่งขมิ้น", "90310"),
        ],
        "ควนเนียง": [
            ("ห้วยลึก", "90220"),
        ],
        "บางกล่ำ": [
            ("แม่ทอม", "90110"),
            ("บ้านหาร", "90110"),
        ],
        "สิงหนคร": [
            ("สทิงหม้อ", "90280"),
            ("ชะแล้", "90330"),
            ("ป่าขาด", "90330"),
        ],
        "คลองหอยโข่ง": [
            ("คลองหลา", "90115"),
            ("คลองหลา", "90110"),
        ],
        "เมืองสงขลา": [
            ("บ่อยาง", "90000"),
            ("เกาะแต้ว", "90000"),
            ("พะวง", "90100"),
            ("ทุ่งหวัง", "90000"),
        ],
        "สทิงพระ": [
            ("จะทิ้งพระ", "90190"),
            ("ดีหลวง", "90190"),
            ("ชุมพล", "90190"),
            ("คลองรี", "90190"),
            ("คูขุด", "90190"),
            ("ท่าหิน", "90190"),
            ("วัดจันทร์", "90190"),
            ("บ่อดาน", "90190"),
        ],
        "จะนะ": [
            ("บ้านนา", "90130"),
            ("สะพานไม้แก่น", "90130"),
            ("สะกอม", "90130"),
            ("นาหว้า", "90130"),
            ("น้ำขาว", "90130"),
            ("ขุนตัดหวาย", "90130"),
            ("ท่าหมอไทร", "90130"),
            ("คู", "90130"),
            ("แค", "90130"),
            ("ตลิ่งชัน", "90130"),
        ],
        "นาทวี": [
            ("คลองทราย", "90160"),
            ("ปลักหนู", "90160"),
            ("ท่าประดู่", "90160"),
            ("สะท้อน", "90160"),
            ("ทับช้าง", "90160"),
            ("ประกอบ", "90160"),
            ("คลองกวาง", "90160"),
        ],
        "เทพา": [
            ("ลำไพล", "90260"),
            ("ท่าม่วง", "90260"),
            ("ท่าม่วง", "90150"),
            ("วังใหญ่", "90260"),
        ],
        "สะบ้าย้อย": [
            ("ทุ่งพอ", "90210"),
            ("เปียน", "90210"),
            ("บ้านโหนด", "90210"),
            ("จะแหน", "90210"),
        ],
        "ระโนด": [
            ("ระโนด", "90140"),
            ("คลองแดน", "90140"),
            ("ตะเครียะ", "90140"),
            ("ท่าบอน", "90140"),
            ("บ้านใหม่", "90140"),
            ("ปากแตระ", "90140"),
            ("ระวะ", "90140"),
            ("แดนสงวน", "90140"),
        ],
        "กระแสสินธุ์": [
            ("เชิงแส", "90270"),
            ("กระแสสินธุ์", "90270"),
        ],
        "รัตภูมิ": [
            ("กำแพงเพชร", "90180"),
            ("ควนรู", "90180"),
        ],
        "สะเดา": [
            ("สะเดา", "90120"),
            ("ปริก", "90120"),
            ("สำนักแต้ว", "90120"),
            ("ทุ่งหมอ", "90240"),
            ("ปาดังเบซาร์", "90240"),
            ("สำนักขาม", "90320"),
            ("เขามีเกียรติ", "90170"),
        ],
        "หาดใหญ่": [
            ("คูเต่า", "90110"),
            ("คลองแห", "90110"),
            ("คลองอู่ตะเภา", "90110"),
            ("ฉลุง", "90110"),
            ("ทุ่งใหญ่", "90110"),
            ("ทุ่งตำเสา", "90110"),
            ("ท่าข้าม", "90110"),
            ("น้ำน้อย", "90110"),
            ("พะตง", "90230"),
        ],
        "นาหม่อม": [
            ("นาหม่อม", "90310"),
            ("คลองหรัง", "90310"),
        ],
        "ควนเนียง": [
            ("รัตภูมิ", "90220"),
            ("ควนโส", "90220"),
            ("บางเหรียง", "90220"),
        ],
        "บางกล่ำ": [
            ("บางกล่ำ", "90110"),
            ("ท่าช้าง", "90110"),
        ],
        "สิงหนคร": [
            ("ชิงโค", "90280"),
            ("ทำนบ", "90280"),
            ("รำแดง", "90330"),
            ("วัดขนุน", "90330"),
            ("ปากรอ", "90330"),
            ("หัวเขา", "90280"),
            ("บางเขียด", "90330"),
            ("ม่วงงาม", "90330"),
        ],
        "คลองหอยโข่ง": [
            ("คลองหอยโข่ง", "90230"),
            ("ทุ่งลาน", "90230"),
            ("โคกม่วง", "90230"),
            ("โคกม่วง", "90110"),
            ("โคกม่วง", "90115"),
        ]},
    "สตูล": {
        "เมืองสตูล": [
            ("พิมาน", "91000"),
            ("คลองขุด", "91000"),
            ("ควนขัน", "91000"),
            ("ฉลุง", "91140"),
            ("ตันหยงโป", "91000"),
            ("เจ๊ะบิลัง", "91000"),
            ("ตำมะลัง", "91000"),
            ("ควนโพธิ์", "91140"),
            ("เกตรี", "91140"),
        ],
        "ควนโดน": [
            ("ควนโดน", "91160"),
            ("ย่านซื่อ", "91160"),
            ("วังประจัน", "91160"),
        ],
        "ควนกาหลง": [
            ("ควนกาหลง", "91130"),
        ],
        "ท่าแพ": [
            ("ท่าแพ", "91150"),
            ("สาคร", "91150"),
            ("ท่าเรือ", "91150"),
        ],
        "ละงู": [
            ("กำแพง", "91110"),
            ("เขาขาว", "91110"),
            ("น้ำผุด", "91110"),
        ],
        "ทุ่งหว้า": [
            ("ขอนคลาน", "91120"),
            ("ทุ่งบุหลัง", "91120"),
        ],
        "มะนัง": [
            ("ปาล์มพัฒนา", "91130"),
            ("นิคมพัฒนา", "91130"),
        ],
        "เมืองสตูล": [
            ("บ้านควน", "91140"),
            ("เกาะสาหร่าย", "91000"),
            ("ปูยู", "91000"),
        ],
        "ควนโดน": [
            ("ควนสตอ", "91160"),
        ],
        "ควนกาหลง": [
            ("ทุ่งนุ้ย", "91130"),
            ("อุใดเจริญ", "91130"),
        ],
        "ท่าแพ": [
            ("แป-ระ", "91150"),
        ],
        "ละงู": [
            ("ละงู", "91110"),
            ("ปากน้ำ", "91110"),
            ("แหลมสน", "91110"),
        ],
        "ทุ่งหว้า": [
            ("ทุ่งหว้า", "91120"),
            ("นาทอน", "91120"),
            ("ป่าแก่บ่อหิน", "91120"),
        ]},
    "สมุทรปราการ": {
        "เมืองสมุทรปราการ": [
            ("สำโรงเหนือ", "10270"),
            ("ท้ายบ้าน", "10280"),
            ("แพรกษา", "10280"),
            ("บางเมืองใหม่", "10270"),
        ],
        "บางบ่อ": [
            ("บางบ่อ", "10560"),
            ("บางเพรียง", "10560"),
            ("เปร็ง", "10560"),
            ("คลองนิยมยาตรา", "10560"),
        ],
        "บางพลี": [
            ("บางพลีใหญ่", "10570"),
            ("บางแก้ว", "10570"),
            ("บางปลา", "10570"),
            ("บางโฉลง", "10570"),
            ("ราชาเทวะ", "10540"),
            ("ราชาเทวะ", "10570"),
            ("หนองปรือ", "10570"),
        ],
        "พระประแดง": [
            ("ตลาด", "10130"),
            ("บางพึ่ง", "10130"),
            ("บางจาก", "10130"),
            ("บางครุ", "10130"),
            ("สำโรงใต้", "10130"),
            ("บางกอบัว", "10130"),
            ("ทรงคนอง", "10130"),
            ("สำโรง", "10130"),
        ],
        "พระสมุทรเจดีย์": [
            ("บ้านคลองสวน", "10290"),
            ("แหลมฟ้าผ่า", "10290"),
            ("ปากคลองบางปลากด", "10290"),
        ],
        "บางเสาธง": [
            ("บางเสาธง", "10540"),
        ],
        "เมืองสมุทรปราการ": [
            ("ปากน้ำ", "10270"),
            ("บางเมือง", "10270"),
            ("บางปูใหม่", "10280"),
            ("บางโปรง", "10270"),
            ("บางปู", "10270"),
            ("บางปู", "10280"),
            ("บางด้วน", "10270"),
            ("เทพารักษ์", "10270"),
            ("ท้ายบ้านใหม่", "10280"),
            ("แพรกษาใหม่", "10280"),
        ],
        "บางบ่อ": [
            ("บ้านระกาศ", "10560"),
            ("บางพลีน้อย", "10560"),
            ("คลองด่าน", "10560"),
            ("คลองด่าน", "10550"),
            ("คลองสวน", "10560"),
        ],
        "บางพลี": [
            ("บางพลีใหญ่", "10540"),
            ("บางแก้ว", "10540"),
            ("บางแก้ว", "10541"),
            ("บางปลา", "10540"),
            ("บางโฉลง", "10540"),
            ("หนองปรือ", "10540"),
        ],
        "พระประแดง": [
            ("บางหญ้าแพรก", "10130"),
            ("บางหัวเสือ", "10130"),
            ("บางยอ", "10130"),
            ("บางกะเจ้า", "10130"),
            ("บางน้ำผึ้ง", "10130"),
            ("บางกระสอบ", "10130"),
            ("สำโรงกลาง", "10130"),
        ],
        "พระสมุทรเจดีย์": [
            ("นาเกลือ", "10290"),
            ("ในคลองบางปลากด", "10290"),
        ],
        "บางเสาธง": [
            ("บางเสาธง", "10570"),
            ("ศีรษะจรเข้น้อย", "10540"),
            ("ศีรษะจรเข้น้อย", "10570"),
            ("ศีรษะจรเข้ใหญ่", "10540"),
            ("ศีรษะจรเข้ใหญ่", "10570"),
        ]},
    "สมุทรสงคราม": {
        "เมืองสมุทรสงคราม": [
            ("บางขันแตก", "75000"),
            ("บ้านปรก", "75000"),
            ("คลองโคน", "75000"),
            ("นางตะเคียน", "75000"),
        ],
        "บางคนที": [
            ("กระดังงา", "75120"),
            ("บางสะแก", "75120"),
            ("บางยี่รงค์", "75120"),
            ("โรงหีบ", "75120"),
            ("บางคนที", "75120"),
            ("บางพรม", "75120"),
            ("บางกุ้ง", "75120"),
            ("จอมปลวก", "75120"),
            ("บางกระบือ", "75120"),
            ("บ้านปราโมทย์", "75120"),
        ],
        "อัมพวา": [
            ("เหมืองใหม่", "75110"),
            ("ปลายโพงพาง", "75110"),
            ("บางแค", "75110"),
            ("ยี่สาร", "75110"),
        ],
        "เมืองสมุทรสงคราม": [
            ("แม่กลอง", "75000"),
            ("ลาดใหญ่", "75000"),
            ("บางแก้ว", "75000"),
            ("ท้ายหาด", "75000"),
            ("แหลมใหญ่", "75000"),
            ("คลองเขิน", "75000"),
            ("บางจะเกร็ง", "75000"),
        ],
        "บางคนที": [
            ("ดอนมะโนรา", "75120"),
            ("บางนกแขวก", "75120"),
            ("ยายแพง", "75120"),
        ],
        "อัมพวา": [
            ("อัมพวา", "75110"),
            ("สวนหลวง", "75110"),
            ("ท่าคา", "75110"),
            ("วัดประดู่", "75110"),
            ("บางช้าง", "75110"),
            ("แควอ้อม", "75110"),
            ("แพรกหนามแดง", "75110"),
            ("บางนางลี่", "75110"),
        ]},
    "สมุทรสาคร": {
        "เมืองสมุทรสาคร": [
            ("มหาชัย", "74000"),
            ("โกรกกราก", "74000"),
            ("บ้านบ่อ", "74000"),
            ("บางโทรัด", "74000"),
            ("นาโคก", "74000"),
            ("ท่าจีน", "74000"),
            ("นาดี", "74000"),
            ("ท่าทราย", "74000"),
            ("บ้านเกาะ", "74000"),
            ("บางกระเจ้า", "74000"),
            ("บางหญ้าแพรก", "74000"),
            ("ชัยมงคล", "74000"),
        ],
        "กระทุ่มแบน": [
            ("สวนหลวง", "74110"),
            ("ดอนไก่ดี", "74110"),
            ("แคราย", "74110"),
            ("ท่าเสา", "74110"),
        ],
        "บ้านแพ้ว": [
            ("บ้านแพ้ว", "74120"),
            ("หลักสาม", "74120"),
            ("โรงเข้", "70210"),
            ("หนองสองห้อง", "74120"),
            ("หนองบัว", "74120"),
            ("เจ็ดริ้ว", "74120"),
            ("คลองตัน", "74120"),
            ("เกษตรพัฒนา", "74120"),
        ],
        "เมืองสมุทรสาคร": [
            ("ท่าฉลอม", "74000"),
            ("กาหลง", "74000"),
            ("คอกกระบือ", "74000"),
            ("บางน้ำจืด", "74000"),
            ("พันท้ายนรสิงห์", "74000"),
            ("โคกขาม", "74000"),
        ],
        "กระทุ่มแบน": [
            ("ตลาดกระทุ่มแบน", "74110"),
            ("อ้อมน้อย", "74130"),
            ("ท่าไม้", "74110"),
            ("บางยาง", "74110"),
            ("คลองมะเดื่อ", "74110"),
            ("หนองนกไข่", "74110"),
        ],
        "บ้านแพ้ว": [
            ("ยกกระบัตร", "74120"),
            ("โรงเข้", "74120"),
            ("หนองสองห้อง", "70210"),
            ("หลักสอง", "74120"),
            ("อำแพง", "74120"),
            ("สวนส้ม", "74120"),
        ]},
    "สระบุรี": {
        "เมืองสระบุรี": [
            ("ปากเพรียว", "18000"),
            ("หนองโน", "18000"),
            ("ปากข้าวสาร", "18000"),
            ("ตะกุด", "18000"),
        ],
        "แก่งคอย": [
            ("แก่งคอย", "18110"),
            ("ตาลเดี่ยว", "18110"),
            ("บ้านธาตุ", "18110"),
            ("บ้านป่า", "18110"),
            ("สองคอน", "18110"),
            ("เตาปูน", "18110"),
            ("ท่ามะปราง", "18110"),
        ],
        "หนองแค": [
            ("หนองแค", "18140"),
            ("กุ่มหัก", "18140"),
            ("โคกตูม", "18250"),
            ("โคกแย้", "18230"),
            ("บัวลอย", "18230"),
            ("ไผ่ต่ำ", "18140"),
            ("โพนทอง", "18250"),
            ("ห้วยขมิ้น", "18230"),
            ("ห้วยทราย", "18230"),
            ("หนองไข่น้ำ", "18140"),
            ("หนองแขม", "18140"),
            ("หนองจิก", "18230"),
            ("หนองจรเข้", "18140"),
            ("หนองปลิง", "18140"),
        ],
        "วิหารแดง": [
            ("คลองเรือ", "18150"),
            ("วิหารแดง", "18150"),
            ("หนองสรวง", "18150"),
            ("เจริญธรรม", "18150"),
        ],
        "หนองแซง": [
            ("หนองแซง", "18170"),
            ("หนองควายโซ", "18170"),
            ("ไก่เส่า", "18170"),
            ("โคกสะอาด", "18170"),
            ("ม่วงหวาน", "18170"),
        ],
        "บ้านหมอ": [
            ("บ้านหมอ", "18130"),
            ("ตลาดน้อย", "18130"),
            ("บ้านครัว", "18270"),
            ("หนองบัว", "18130"),
        ],
        "ดอนพุด": [
            ("ดอนพุด", "18210"),
        ],
        "หนองโดน": [
            ("บ้านกลับ", "18190"),
        ],
        "พระพุทธบาท": [
            ("ขุนโขลน", "18120"),
            ("นายาว", "18120"),
            ("ห้วยป่าหวาย", "18120"),
        ],
        "เสาไห้": [
            ("บ้านยาง", "18160"),
            ("หัวปลวก", "18160"),
            ("ศาลารีไทย", "18160"),
            ("ท่าช้าง", "18160"),
            ("พระยาทด", "18160"),
            ("สวนดอกไม้", "18160"),
        ],
        "มวกเหล็ก": [
            ("มวกเหล็ก", "18180"),
            ("มิตรภาพ", "18180"),
            ("ลำสมพุง", "30130"),
            ("ลำพญากลาง", "18180"),
        ],
        "เมืองสระบุรี": [
            ("ดาวเรือง", "18000"),
            ("นาโฉง", "18000"),
            ("โคกสว่าง", "18000"),
            ("หนองยาว", "18000"),
            ("หนองปลาไหล", "18000"),
            ("กุดนกเปล้า", "18000"),
            ("ตลิ่งชัน", "18000"),
        ],
        "แก่งคอย": [
            ("ทับกวาง", "18260"),
            ("ห้วยแห้ง", "18110"),
            ("ท่าคล้อ", "18110"),
            ("หินซ้อน", "18110"),
            ("ท่าตูม", "18110"),
            ("ชะอม", "18110"),
            ("ชำผักแพว", "18110"),
        ],
        "หนองแค": [
            ("คชสิทธิ์", "18250"),
            ("หนองนาก", "18230"),
            ("หนองปลาหมอ", "18140"),
            ("หนองโรง", "18140"),
            ("ระโสม", "18250"),
        ],
        "วิหารแดง": [
            ("หนองหมู", "18150"),
            ("บ้านลำ", "18150"),
        ],
        "หนองแซง": [
            ("หนองหัวโพ", "18170"),
            ("หนองสีดา", "18170"),
            ("หนองกบ", "18170"),
            ("เขาดิน", "18170"),
        ],
        "บ้านหมอ": [
            ("บางโขมด", "18130"),
            ("บางโขมด", "18270"),
            ("สร่างโศก", "18130"),
            ("หรเทพ", "18130"),
            ("โคกใหญ่", "18130"),
            ("ไผ่ขวาง", "18130"),
        ],
        "ดอนพุด": [
            ("ไผ่หลิ่ว", "18210"),
            ("บ้านหลวง", "18210"),
            ("ดงตะงาว", "18210"),
        ],
        "หนองโดน": [
            ("หนองโดน", "18190"),
            ("ดอนทอง", "18190"),
            ("บ้านโปร่ง", "18190"),
        ],
        "พระพุทธบาท": [
            ("พระพุทธบาท", "18120"),
            ("ธารเกษม", "18120"),
            ("พุคำจาน", "18120"),
            ("เขาวง", "18120"),
            ("พุกร่าง", "18120"),
            ("หนองแก", "18120"),
        ],
        "เสาไห้": [
            ("เสาไห้", "18160"),
            ("งิ้วงาม", "18160"),
            ("ต้นตาล", "18160"),
            ("ม่วงงาม", "18160"),
            ("เริงราง", "18160"),
            ("เมืองเก่า", "18160"),
        ],
        "มวกเหล็ก": [
            ("หนองย่างเสือ", "18180"),
            ("ลำสมพุง", "18180"),
        ],
        "วังม่วง": [
            ("วังม่วง", "18220"),
        ],
        "เฉลิมพระเกียรติ": [
            ("เขาดินพัฒนา", "18000"),
            ("ผึ้งรวง", "18000"),
            ("พุแค", "18240"),
        ],
        "มวกเหล็ก": [
            ("ลำพญากลาง", "30130"),
            ("ซับสนุ่น", "18220"),
        ],
        "วังม่วง": [
            ("แสลงพัน", "18220"),
            ("คำพราน", "18220"),
        ],
        "เฉลิมพระเกียรติ": [
            ("บ้านแก้ง", "18000"),
            ("ห้วยบง", "18000"),
            ("หน้าพระลาน", "18240"),
        ]},
    "สระแก้ว": {
        "เมืองสระแก้ว": [
            ("บ้านแก้ง", "27000"),
            ("ท่าแยก", "27000"),
        ],
        "คลองหาด": [
            ("คลองหาด", "27260"),
            ("ไทรเดี่ยว", "27260"),
            ("คลองไก่เถื่อน", "27260"),
            ("คลองไก่เถื่อน", "27250"),
            ("เบญจขร", "27260"),
            ("ไทรทอง", "27260"),
        ],
        "ตาพระยา": [
            ("ตาพระยา", "27180"),
            ("ทัพราช", "27180"),
            ("ทัพไทย", "27180"),
        ],
        "วังน้ำเย็น": [
            ("คลองหินปูน", "27210"),
        ],
        "วัฒนานคร": [
            ("วัฒนานคร", "27160"),
            ("ท่าเกวียน", "27160"),
            ("โนนหมากเค็ง", "27160"),
            ("หนองน้ำใส", "27160"),
            ("ช่องกุ่ม", "27160"),
            ("หนองแวง", "27160"),
        ],
        "อรัญประเทศ": [
            ("อรัญประเทศ", "27120"),
            ("เมืองไผ่", "27120"),
            ("ท่าข้าม", "27120"),
            ("บ้านใหม่หนองไทร", "27120"),
            ("ผ่านศึก", "27120"),
            ("คลองทับจันทร์", "27120"),
        ],
        "เขาฉกรรจ์": [
            ("หนองหว้า", "27000"),
            ("เขาสามสิบ", "27000"),
        ],
        "วังสมบูรณ์": [
            ("วังใหม่", "27210"),
            ("วังทอง", "27250"),
        ],
        "เมืองสระแก้ว": [
            ("สระแก้ว", "27000"),
            ("ศาลาลำดวน", "27000"),
            ("โคกปี่ฆ้อง", "27000"),
            ("ท่าเกษม", "27000"),
            ("สระขวัญ", "27000"),
            ("หนองบอน", "27000"),
        ],
        "คลองหาด": [
            ("คลองหาด", "27250"),
            ("ไทยอุดม", "27260"),
            ("ซับมะกรูด", "27260"),
        ],
        "ตาพระยา": [
            ("ทัพเสด็จ", "27180"),
            ("โคคลาน", "27180"),
        ],
        "วังน้ำเย็น": [
            ("วังน้ำเย็น", "27210"),
            ("ตาหลังใน", "27210"),
            ("ทุ่งมหาเจริญ", "27210"),
        ],
        "วัฒนานคร": [
            ("ผักขะ", "27160"),
            ("แซร์ออ", "27160"),
            ("หนองหมากฝ้าย", "27160"),
            ("หนองตะเคียนบอน", "27160"),
            ("ห้วยโจด", "27160"),
        ],
        "อรัญประเทศ": [
            ("หันทราย", "27120"),
            ("คลองน้ำใส", "27120"),
            ("ป่าไร่", "27120"),
            ("ทับพริก", "27120"),
            ("หนองสังข์", "27120"),
            ("ฟากห้วย", "27120"),
            ("บ้านด่าน", "27120"),
        ],
        "เขาฉกรรจ์": [
            ("เขาฉกรรจ์", "27000"),
            ("พระเพลิง", "27000"),
        ],
        "โคกสูง": [
            ("โคกสูง", "27120"),
            ("หนองม่วง", "27180"),
            ("หนองแวง", "27180"),
            ("หนองแวง", "27120"),
            ("โนนหมากมุ่น", "27120"),
        ],
        "วังสมบูรณ์": [
            ("วังสมบูรณ์", "27250"),
            ("วังใหม่", "27250"),
        ]},
    "สิงห์บุรี": {
        "เมืองสิงห์บุรี": [
            ("บางพุทรา", "16000"),
            ("บางมัญ", "16000"),
            ("โพกรวม", "16000"),
            ("จักรสีห์", "16000"),
        ],
        "บางระจัน": [
            ("บ้านจ่า", "16130"),
            ("สระแจง", "16130"),
        ],
        "ค่ายบางระจัน": [
            ("โพทะเล", "16150"),
            ("ท่าข้าม", "16150"),
        ],
        "พรหมบุรี": [
            ("พระงาม", "16120"),
            ("บางน้ำเชี่ยว", "16120"),
            ("บ้านหม้อ", "16120"),
            ("โรงช้าง", "16120"),
        ],
        "ท่าช้าง": [
            ("พิกุลทอง", "16140"),
        ],
        "อินทร์บุรี": [
            ("ทับยา", "16110"),
            ("งิ้วราย", "16110"),
            ("ชีน้ำร้าย", "16110"),
            ("น้ำตาล", "16110"),
            ("ทองเอน", "16110"),
            ("ห้วยชัน", "16110"),
        ],
        "เมืองสิงห์บุรี": [
            ("ม่วงหมู่", "16000"),
            ("หัวไผ่", "16000"),
            ("ต้นโพธิ์", "16000"),
            ("บางกระบือ", "16000"),
        ],
        "บางระจัน": [
            ("สิงห์", "16130"),
            ("ไม้ดัด", "16130"),
            ("เชิงกลัด", "16130"),
            ("โพชนไก่", "16130"),
            ("แม่ลา", "16130"),
            ("พักทัน", "16130"),
        ],
        "ค่ายบางระจัน": [
            ("บางระจัน", "16150"),
            ("โพสังโฆ", "16150"),
            ("คอทราย", "16150"),
            ("หนองกระทุ่ม", "16150"),
        ],
        "พรหมบุรี": [
            ("พรหมบุรี", "16160"),
            ("บ้านแป้ง", "16120"),
            ("หัวป่า", "16120"),
        ],
        "ท่าช้าง": [
            ("ถอนสมอ", "16140"),
            ("โพประจักษ์", "16140"),
            ("วิหารขาว", "16140"),
        ],
        "อินทร์บุรี": [
            ("อินทร์บุรี", "16110"),
            ("ประศุก", "16110"),
            ("ท่างาม", "16110"),
            ("โพธิ์ชัย", "16110"),
        ]},
    "สุพรรณบุรี": {
        "เมืองสุพรรณบุรี": [
            ("ท่าพี่เลี้ยง", "72000"),
            ("รั้วใหญ่", "72000"),
            ("ทับตีเหล็ก", "72000"),
            ("ท่าระหัด", "72000"),
            ("ไผ่ขวาง", "72000"),
            ("โคกโคเฒ่า", "72000"),
            ("พิหารแดง", "72000"),
            ("บ้านโพธิ์", "72000"),
            ("สระแก้ว", "72230"),
            ("ตลิ่งชัน", "72230"),
            ("บางกุ้ง", "72210"),
            ("ศาลาขาว", "72210"),
            ("สวนแตง", "72210"),
        ],
        "เดิมบางนางบวช": [
            ("เขาพระ", "72120"),
            ("เดิมบาง", "72120"),
            ("นางบวช", "72120"),
            ("เขาดิน", "72120"),
            ("ปากน้ำ", "72120"),
            ("ทุ่งคลี", "72120"),
            ("โคกช้าง", "72120"),
            ("หัวนา", "72120"),
            ("ยางนอน", "72120"),
            ("หนองกระทุ่ม", "72120"),
        ],
        "ด่านช้าง": [
            ("หนองมะค่าโมง", "72180"),
            ("ด่านช้าง", "72180"),
            ("ห้วยขมิ้น", "72180"),
            ("องค์พระ", "72180"),
            ("วังคัน", "72180"),
        ],
        "บางปลาม้า": [
            ("โคกคราม", "72150"),
            ("บางปลาม้า", "72150"),
            ("ตะค่า", "72150"),
            ("ไผ่กองดิน", "72150"),
            ("องครักษ์", "72150"),
        ],
        "ศรีประจันต์": [
            ("ศรีประจันต์", "72140"),
            ("บ้านกร่าง", "72140"),
            ("มดแดง", "72140"),
            ("บางงาม", "72140"),
            ("ดอนปรู", "72140"),
            ("ปลายนา", "72140"),
            ("วังหว้า", "72140"),
            ("วังยาง", "72140"),
        ],
        "ดอนเจดีย์": [
            ("สระกระโจม", "72250"),
            ("ทะเลบก", "72250"),
        ],
        "สองพี่น้อง": [
            ("สองพี่น้อง", "72110"),
            ("หัวโพธิ์", "72110"),
            ("บางพลับ", "72110"),
            ("เนินพระปรางค์", "72110"),
            ("บ้านช้าง", "72110"),
            ("ต้นตาล", "72110"),
            ("ศรีสำราญ", "72190"),
            ("ทุ่งคอก", "72190"),
            ("หนองบ่อ", "72110"),
            ("หนองบ่อ", "71170"),
            ("บ่อสุพรรณ", "72190"),
        ],
        "สามชุก": [
            ("วังลึก", "72130"),
            ("หนองผักนาก", "72130"),
            ("บ้านสระ", "72130"),
        ],
        "อู่ทอง": [
            ("อู่ทอง", "72160"),
            ("จรเข้สามพัน", "72160"),
            ("จรเข้สามพัน", "71170"),
            ("บ้านดอน", "72160"),
            ("บ้านโข้ง", "72160"),
            ("เจดีย์", "72160"),
            ("สระพังลาน", "72220"),
        ],
        "หนองหญ้าไซ": [
            ("หนองโพธิ์", "72240"),
        ],
        "เมืองสุพรรณบุรี": [
            ("ดอนตาล", "72000"),
            ("ดอนมะสังข์", "72000"),
            ("ดอนกำยาน", "72000"),
            ("ดอนโพธิ์ทอง", "72000"),
            ("สนามชัย", "72000"),
            ("โพธิ์พระยา", "72000"),
            ("สนามคลี", "72230"),
        ],
        "เดิมบางนางบวช": [
            ("หัวเขา", "72120"),
            ("บ่อกรุ", "72120"),
            ("วังศรีราช", "72120"),
            ("ป่าสะแก", "72120"),
        ],
        "ด่านช้าง": [
            ("นิคมกระเสียว", "72180"),
            ("วังยาว", "72180"),
        ],
        "บางปลาม้า": [
            ("บางใหญ่", "72150"),
            ("กฤษณา", "72150"),
            ("สาลี", "72150"),
            ("จรเข้ใหญ่", "72150"),
            ("บ้านแหลม", "72150"),
            ("มะขามล้ม", "72150"),
            ("วังน้ำเย็น", "72150"),
            ("วัดโบสถ์", "72150"),
            ("วัดดาว", "72150"),
        ],
        "ศรีประจันต์": [
            ("วังน้ำซับ", "72140"),
        ],
        "ดอนเจดีย์": [
            ("ดอนเจดีย์", "72170"),
            ("หนองสาหร่าย", "72170"),
            ("ไร่รถ", "72170"),
            ("ทะเลบก", "72170"),
        ],
        "สองพี่น้อง": [
            ("บางเลน", "72110"),
            ("บางตาเถร", "72110"),
            ("บางตะเคียน", "72110"),
            ("บ้านกุ่ม", "72110"),
            ("ศรีสำราญ", "72110"),
            ("ทุ่งคอก", "72110"),
            ("หนองบ่อ", "72190"),
            ("ดอนมะนาว", "72110"),
        ],
        "สามชุก": [
            ("ย่านยาว", "72130"),
            ("สามชุก", "72130"),
            ("หนองสะเดา", "72130"),
            ("กระเสียว", "72130"),
        ],
        "อู่ทอง": [
            ("สระยายโสม", "72220"),
            ("ยุ้งทะลาย", "72160"),
            ("ดอนมะเกลือ", "72220"),
            ("หนองโอ่ง", "72160"),
            ("ดอนคา", "72160"),
            ("พลับพลาไชย", "72160"),
            ("กระจัน", "72160"),
        ],
        "หนองหญ้าไซ": [
            ("หนองหญ้าไซ", "72240"),
            ("หนองราชวัตร", "72240"),
            ("แจงงาม", "72240"),
            ("หนองขาม", "72240"),
            ("ทัพหลวง", "72240"),
        ]},
    "สุราษฎร์ธานี": {
        "เมืองสุราษฎร์ธานี": [
            ("มะขามเตี้ย", "84000"),
            ("วัดประดู่", "84000"),
            ("บางใบไม้", "84000"),
            ("คลองน้อย", "84000"),
            ("บางโพธิ์", "84000"),
            ("คลองฉนาก", "84000"),
        ],
        "กาญจนดิษฐ์": [
            ("ท่าทองใหม่", "84290"),
            ("กะแดะ", "84160"),
            ("ช้างซ้าย", "84160"),
            ("พลายวาส", "84160"),
            ("ป่าร่อน", "84160"),
        ],
        "ดอนสัก": [
            ("ดอนสัก", "84220"),
            ("ปากแพรก", "84340"),
        ],
        "เกาะสมุย": [
            ("อ่างทอง", "84140"),
            ("อ่างทอง", "84220"),
            ("ลิปะน้อย", "84140"),
            ("ตลิ่งงาม", "84140"),
            ("มะเร็ต", "84310"),
        ],
        "เกาะพะงัน": [
            ("เกาะพะงัน", "84280"),
            ("บ้านใต้", "84280"),
        ],
        "ไชยา": [
            ("ตลาดไชยา", "84110"),
            ("ทุ่ง", "84110"),
            ("โมถ่าย", "84110"),
        ],
        "ท่าชนะ": [
            ("ประสงค์", "84170"),
            ("คันธุลี", "84170"),
        ],
        "คีรีรัฐนิคม": [
            ("บ้านยาง", "84180"),
            ("ย่านยาว", "84180"),
            ("ถ้ำสิงขร", "84180"),
        ],
        "บ้านตาขุน": [
            ("เขาพัง", "84230"),
        ],
        "พนม": [
            ("คลองชะอุ่น", "84250"),
        ],
        "ท่าฉาง": [
            ("ท่าฉาง", "84150"),
            ("ท่าเคย", "84150"),
            ("คลองไทร", "84150"),
            ("เสวียด", "84150"),
            ("ปากฉลุย", "84150"),
        ],
        "บ้านนาสาร": [
            ("ทุ่งเตา", "84120"),
            ("ลำพูน", "84120"),
            ("ท่าชี", "84120"),
            ("ควนศรี", "84270"),
            ("คลองปราบ", "84120"),
            ("เพิ่มพูนทรัพย์", "84120"),
        ],
        "บ้านนาเดิม": [
            ("ท่าเรือ", "84240"),
        ],
        "เคียนซา": [
            ("เคียนซา", "84260"),
        ],
        "เวียงสระ": [
            ("บ้านส้อง", "84190"),
            ("ทุ่งหลวง", "84190"),
        ],
        "พระแสง": [
            ("สินปุน", "84210"),
            ("สาคู", "84210"),
        ],
        "พุนพิน": [
            ("ท่าข้าม", "84130"),
            ("ท่าสะท้อน", "84130"),
            ("ลีเล็ด", "84130"),
            ("บางเดือน", "84130"),
            ("พุนพิน", "84130"),
            ("ศรีวิชัย", "84130"),
            ("มะลวน", "84130"),
            ("หัวเตย", "84130"),
        ],
        "ชัยบุรี": [
            ("คลองน้อย", "84350"),
        ],
        "วิภาวดี": [
            ("ตะกุกใต้", "84180"),
            ("ตะกุกเหนือ", "84370"),
        ],
        "เมืองสุราษฎร์ธานี": [
            ("ตลาด", "84000"),
            ("ขุนทะเล", "84100"),
            ("บางชนะ", "84000"),
            ("บางไทร", "84000"),
            ("บางกุ้ง", "84000"),
        ],
        "กาญจนดิษฐ์": [
            ("ท่าทอง", "84160"),
            ("ทุ่งกง", "84290"),
            ("กรูด", "84160"),
            ("ตะเคียนทอง", "84160"),
            ("ช้างขวา", "84160"),
            ("ท่าอุแท", "84160"),
            ("ท่าอุแท", "84340"),
            ("ทุ่งรัง", "84290"),
            ("คลองสระ", "84160"),
        ],
        "ดอนสัก": [
            ("ชลคราม", "84160"),
            ("ไชยคราม", "84220"),
        ],
        "เกาะสมุย": [
            ("หน้าเมือง", "84140"),
            ("บ่อผุด", "84320"),
            ("แม่น้ำ", "84330"),
        ],
        "เกาะพะงัน": [
            ("เกาะเต่า", "84360"),
        ],
        "ไชยา": [
            ("พุมเรียง", "84110"),
            ("เลม็ด", "84110"),
            ("เวียง", "84110"),
            ("ป่าเว", "84110"),
            ("ตะกรบ", "84110"),
            ("ปากหมาก", "84110"),
        ],
        "ท่าชนะ": [
            ("ท่าชนะ", "84170"),
            ("สมอทอง", "84170"),
            ("วัง", "84170"),
            ("คลองพา", "84170"),
        ],
        "คีรีรัฐนิคม": [
            ("ท่าขนอน", "84180"),
            ("น้ำหัก", "84180"),
            ("กะเปา", "84180"),
            ("ท่ากระดาน", "84180"),
            ("บ้านทำเนียบ", "84180"),
        ],
        "บ้านตาขุน": [
            ("เขาวง", "84230"),
            ("พะแสง", "84230"),
            ("พรุไทย", "84230"),
        ],
        "พนม": [
            ("พนม", "84250"),
            ("ต้นยวน", "84250"),
            ("คลองศก", "84250"),
            ("พลูเถื่อน", "84250"),
            ("พังกาญจน์", "84250"),
        ],
        "ท่าฉาง": [
            ("เขาถ่าน", "84150"),
        ],
        "บ้านนาสาร": [
            ("นาสาร", "84120"),
            ("พรุพี", "84270"),
            ("ควนสุบรรณ", "84120"),
            ("น้ำพุ", "84120"),
            ("ทุ่งเตาใหม่", "84120"),
        ],
        "บ้านนาเดิม": [
            ("บ้านนา", "84240"),
            ("ทรัพย์ทวี", "84240"),
            ("นาใต้", "84240"),
        ],
        "เคียนซา": [
            ("พ่วงพรมคร", "84210"),
            ("เขาตอก", "84260"),
            ("อรัญคามวารี", "84260"),
            ("บ้านเสด็จ", "84260"),
        ],
        "เวียงสระ": [
            ("เวียงสระ", "84190"),
            ("คลองฉนวน", "84190"),
            ("เขานิพันธ์", "84190"),
        ],
        "พระแสง": [
            ("อิปัน", "84210"),
            ("บางสวรรค์", "84210"),
            ("ไทรขึง", "84210"),
            ("สินเจริญ", "84210"),
            ("ไทรโสภา", "84210"),
        ],
        "พุนพิน": [
            ("บางมะเดื่อ", "84130"),
            ("ท่าโรงช้าง", "84130"),
            ("กรูด", "84130"),
            ("บางงอน", "84130"),
            ("น้ำรอบ", "84130"),
            ("หนองไทร", "84130"),
            ("เขาหัวควาย", "84130"),
            ("ตะปาน", "84130"),
        ],
        "ชัยบุรี": [
            ("สองแพรก", "84350"),
            ("ชัยบุรี", "84350"),
            ("ไทรทอง", "84350"),
        ],
        "วิภาวดี": [
            ("ตะกุกใต้", "84370"),
            ("ตะกุกเหนือ", "84180"),
        ]},
    "สุรินทร์": {
        "เมืองสุรินทร์": [
            ("ในเมือง", "32000"),
            ("ตั้งใจ", "32000"),
            ("สลักได", "32000"),
            ("ตาอ็อง", "32000"),
            ("นอกเมือง", "32000"),
            ("สวาย", "32000"),
            ("เฉนียง", "32000"),
            ("เทนมีย์", "32000"),
            ("เมืองที", "32000"),
            ("บุฤาษี", "32000"),
            ("ตระแสง", "32000"),
            ("กาเกาะ", "32000"),
        ],
        "ชุมพลบุรี": [
            ("ชุมพลบุรี", "32190"),
            ("ไพรขลา", "32190"),
            ("ศรีณรงค์", "32190"),
            ("เมืองบัว", "32190"),
            ("สระขุด", "32190"),
        ],
        "ท่าตูม": [
            ("ท่าตูม", "32120"),
            ("กระโพ", "32120"),
            ("พรมเทพ", "32120"),
            ("โพนครก", "32120"),
            ("บะ", "32120"),
            ("หนองเมธี", "32120"),
            ("ทุ่งกุลา", "32120"),
        ],
        "จอมพระ": [
            ("เมืองลีง", "32180"),
            ("หนองสนิท", "32180"),
            ("ลุ่มระวี", "32180"),
            ("ชุมแสง", "32180"),
            ("เป็นสุข", "32180"),
        ],
        "ปราสาท": [
            ("ไพล", "32140"),
            ("ปรือ", "32140"),
            ("ทุ่งมน", "32140"),
            ("โคกยาง", "32140"),
            ("โคกสะอาด", "32140"),
            ("ปราสาททนง", "32140"),
            ("บ้านพลวง", "32140"),
            ("กันตวจระมวล", "32140"),
            ("ประทัดบุ", "32140"),
        ],
        "กาบเชิง": [
            ("ด่าน", "32210"),
            ("โคกตะเคียน", "32210"),
        ],
        "รัตนบุรี": [
            ("ธาตุ", "32130"),
            ("หนองบัวบาน", "32130"),
            ("ทับใหญ่", "32130"),
        ],
        "สนม": [
            ("สนม", "32160"),
            ("หนองระฆัง", "32160"),
            ("นานวน", "32160"),
            ("หัวงัว", "32160"),
        ],
        "ศีขรภูมิ": [
            ("จารพัต", "32110"),
            ("แตล", "32110"),
            ("หนองบัว", "32110"),
            ("กุดหวาย", "32110"),
            ("นารุ่ง", "32110"),
            ("ตรมไพร", "32110"),
            ("ผักไหม", "32110"),
        ],
        "สังขะ": [
            ("สังขะ", "32150"),
            ("พระแก้ว", "32150"),
            ("กระเทียม", "32150"),
            ("สะกาด", "32150"),
            ("ตาตุม", "32150"),
            ("ทับทัน", "32150"),
            ("เทพรักษา", "32150"),
        ],
        "ลำดวน": [
            ("ลำดวน", "32220"),
            ("โชคเหนือ", "32220"),
            ("อู่โลก", "32220"),
            ("ตรำดม", "32220"),
            ("ตระเปียงเตีย", "32220"),
        ],
        "สำโรงทาบ": [
            ("หนองไผ่ล้อม", "32170"),
            ("หนองฮะ", "32170"),
            ("ศรีสุข", "32170"),
            ("สะโน", "32170"),
        ],
        "บัวเชด": [
            ("บัวเชด", "32230"),
            ("จรัส", "32230"),
            ("ตาวัง", "32230"),
            ("อาโพน", "32230"),
            ("สำเภาลูน", "32230"),
        ],
        "พนมดงรัก": [
            ("บักได", "32140"),
            ("โคกกลาง", "32140"),
            ("จีกแดก", "32140"),
        ],
        "ศรีณรงค์": [
            ("ณรงค์", "32150"),
            ("แจนแวน", "32150"),
            ("หนองแวง", "32150"),
            ("ศรีสุข", "32150"),
        ],
        "เขวาสินรินทร์": [
            ("เขวาสินรินทร์", "32000"),
            ("ตากูก", "32000"),
        ],
        "โนนนารายณ์": [
            ("คำผง", "32130"),
            ("โนน", "32130"),
            ("ระเวียง", "32130"),
        ],
        "เมืองสุรินทร์": [
            ("เพี้ยราม", "32000"),
            ("นาดี", "32000"),
            ("ท่าสว่าง", "32000"),
            ("สำโรง", "32000"),
            ("แกใหญ่", "32000"),
            ("คอโค", "32000"),
            ("นาบัว", "32000"),
            ("ราม", "32000"),
            ("แสลงพันธ์", "32000"),
        ],
        "ชุมพลบุรี": [
            ("นาหนองไผ่", "32190"),
            ("ยะวึก", "32190"),
            ("กระเบื้อง", "32190"),
            ("หนองเรือ", "32190"),
        ],
        "ท่าตูม": [
            ("เมืองแก", "32120"),
            ("หนองบัว", "32120"),
            ("บัวโคก", "32120"),
        ],
        "จอมพระ": [
            ("จอมพระ", "32180"),
            ("กระหาด", "32180"),
            ("บุแกรง", "32180"),
            ("บ้านผือ", "32180"),
        ],
        "ปราสาท": [
            ("กังแอน", "32140"),
            ("ทมอ", "32140"),
            ("ตาเบา", "32140"),
            ("หนองใหญ่", "32140"),
            ("บ้านไทร", "32140"),
            ("โชคนาสาม", "32140"),
            ("เชื้อเพลิง", "32140"),
            ("ตานี", "32140"),
            ("สมุด", "32140"),
        ],
        "กาบเชิง": [
            ("กาบเชิง", "32210"),
            ("คูตัน", "32210"),
            ("แนงมุด", "32210"),
            ("ตะเคียน", "32210"),
        ],
        "รัตนบุรี": [
            ("รัตนบุรี", "32130"),
            ("แก", "32130"),
            ("ดอนแรด", "32130"),
            ("หนองบัวทอง", "32130"),
            ("ไผ่", "32130"),
            ("เบิด", "32130"),
            ("น้ำเขียว", "32130"),
            ("กุดขาคีม", "32130"),
            ("ยางสว่าง", "32130"),
        ],
        "สนม": [
            ("โพนโก", "32160"),
            ("แคน", "32160"),
            ("หนองอียอ", "32160"),
        ],
        "ศีขรภูมิ": [
            ("ระแงง", "32110"),
            ("ตรึม", "32110"),
            ("ยาง", "32110"),
            ("คาละแมะ", "32110"),
            ("หนองเหล็ก", "32110"),
            ("หนองขวาว", "32110"),
            ("ช่างปี่", "32110"),
            ("ขวาวใหญ่", "32110"),
        ],
        "สังขะ": [
            ("ขอนแตก", "32150"),
            ("ดม", "32150"),
            ("บ้านจารย์", "32150"),
            ("ตาคง", "32150"),
            ("บ้านชบ", "32150"),
        ],
        "สำโรงทาบ": [
            ("สำโรงทาบ", "32170"),
            ("กระออม", "32170"),
            ("เกาะแก้ว", "32170"),
            ("หมื่นศรี", "32170"),
            ("เสม็จ", "32170"),
            ("ประดู่", "32170"),
        ],
        "บัวเชด": [
            ("สะเดา", "32230"),
        ],
        "พนมดงรัก": [
            ("ตาเมียง", "32140"),
        ],
        "ศรีณรงค์": [
            ("ตรวจ", "32150"),
        ],
        "เขวาสินรินทร์": [
            ("บึง", "32000"),
            ("ปราสาททอง", "32000"),
            ("บ้านแร่", "32000"),
        ],
        "โนนนารายณ์": [
            ("หนองหลวง", "32130"),
            ("หนองเทพ", "32130"),
        ]},
    "สุโขทัย": {
        "เมืองสุโขทัย": [
            ("ธานี", "64000"),
            ("ปากแคว", "64000"),
            ("ยางซ้าย", "64000"),
            ("บ้านกล้วย", "64210"),
            ("บ้านหลุม", "64000"),
            ("วังทองแดง", "64210"),
        ],
        "บ้านด่านลานหอย": [
            ("ลานหอย", "64140"),
            ("บ้านด่าน", "64140"),
            ("วังน้ำขาว", "64140"),
            ("หนองหญ้าปล้อง", "64140"),
        ],
        "คีรีมาศ": [
            ("โตนด", "64160"),
            ("ทุ่งหลวง", "64160"),
            ("บ้านป้อม", "64160"),
            ("สามพวง", "64160"),
            ("หนองจิก", "64160"),
            ("หนองกระดิ่ง", "64160"),
            ("บ้านน้ำพุ", "64160"),
            ("ทุ่งยางเมือง", "64160"),
        ],
        "กงไกรลาศ": [
            ("กง", "64170"),
            ("บ้านกร่าง", "64170"),
            ("ไกรนอก", "64170"),
            ("ไกรกลาง", "64170"),
            ("ไกรใน", "64170"),
            ("ดงเดือย", "64170"),
            ("หนองตูม", "64170"),
            ("บ้านใหม่สุขเกษม", "64170"),
        ],
        "ศรีสัชนาลัย": [
            ("หาดเสี้ยว", "64130"),
            ("ป่างิ้ว", "64130"),
            ("สารจิตร", "64130"),
        ],
        "ศรีสำโรง": [
            ("คลองตาล", "64120"),
            ("วังลึก", "64120"),
            ("บ้านนา", "64120"),
            ("นาขุนไกร", "64120"),
            ("ทับผึ้ง", "64120"),
            ("บ้านซ่าน", "64120"),
            ("วังใหญ่", "64120"),
        ],
        "สวรรคโลก": [
            ("คลองกระจง", "64110"),
            ("วังไม้ขอน", "64110"),
            ("เมืองบางยม", "64110"),
            ("ท่าทอง", "64110"),
            ("ปากน้ำ", "64110"),
        ],
        "ศรีนคร": [
            ("ศรีนคร", "64180"),
            ("คลองมะพลับ", "64180"),
        ],
        "ทุ่งเสลี่ยม": [
            ("บ้านใหม่ไชยมงคล", "64230"),
            ("ทุ่งเสลี่ยม", "64150"),
        ],
        "เมืองสุโขทัย": [
            ("บ้านสวน", "64220"),
            ("เมืองเก่า", "64210"),
            ("บ้านกล้วย", "64000"),
            ("ตาลเตี้ย", "64220"),
            ("ปากพระ", "64000"),
        ],
        "บ้านด่านลานหอย": [
            ("วังตะคร้อ", "64140"),
            ("ตลิ่งชัน", "64140"),
            ("วังลึก", "64140"),
        ],
        "คีรีมาศ": [
            ("ศรีคีรีมาศ", "64160"),
            ("นาเชิงคีรี", "64160"),
        ],
        "กงไกรลาศ": [
            ("ป่าแฝก", "64170"),
            ("กกแรต", "64170"),
            ("ท่าฉนวน", "64170"),
        ],
        "ศรีสัชนาลัย": [
            ("แม่สำ", "64130"),
            ("แม่สิน", "64130"),
            ("บ้านตึก", "64130"),
            ("หนองอ้อ", "64130"),
            ("ท่าชัย", "64190"),
            ("ศรีสัชนาลัย", "64190"),
            ("ดงคู่", "64130"),
            ("บ้านแก่ง", "64130"),
        ],
        "ศรีสำโรง": [
            ("สามเรือน", "64120"),
            ("วังทอง", "64120"),
            ("เกาะตาเลี้ยง", "64120"),
            ("วัดเกาะ", "64120"),
            ("บ้านไร่", "64120"),
            ("ราวต้นจันทร์", "64120"),
        ],
        "สวรรคโลก": [
            ("เมืองสวรรคโลก", "64110"),
            ("ในเมือง", "64110"),
            ("วังพิณพาทย์", "64110"),
            ("ย่านยาว", "64110"),
            ("นาทุ่ง", "64110"),
            ("คลองยาง", "64110"),
            ("ป่ากุมเกาะ", "64110"),
            ("เมืองบางขลัง", "64110"),
            ("หนองกลับ", "64110"),
        ],
        "ศรีนคร": [
            ("นครเดิฐ", "64180"),
            ("น้ำขุม", "64180"),
            ("หนองบัว", "64180"),
        ],
        "ทุ่งเสลี่ยม": [
            ("ไทยชนะศึก", "64150"),
            ("กลางดง", "64150"),
            ("เขาแก้วศรีสมบูรณ์", "64230"),
        ]},
    "หนองคาย": {
        "ท่าบ่อ": [
            ("ท่าบ่อ", "43110"),
            ("นาข่า", "43110"),
            ("บ้านถ่อน", "43110"),
            ("หนองนาง", "43110"),
        ],
        "เฝ้าไร่": [
            ("เฝ้าไร่", "43120"),
            ("วังหลวง", "43120"),
            ("หนองหลวง", "43120"),
            ("อุดมพร", "43120"),
        ],
        "โพธิ์ตาก": [
            ("ด่านศรีสุข", "43130"),
            ("โพนทอง", "43130"),
        ],
        "โพนพิสัย": [
            ("กุดบง", "43120"),
            ("เซิม", "43120"),
            ("ทุ่งหลวง", "43120"),
            ("นาหนัง", "43120"),
            ("บ้านผือ", "43120"),
            ("วัดหลวง", "43120"),
        ],
        "เมืองหนองคาย": [
            ("ในเมือง", "43000"),
            ("ปะโค", "43000"),
            ("มีชัย", "43000"),
            ("เวียงคุก", "43000"),
            ("หนองกอมเกาะ", "43000"),
            ("หาดคำ", "43000"),
        ],
        "รัตนวาปี": [
            ("นาทับไฮ", "43120"),
            ("โพนแพง", "43120"),
        ],
        "ศรีเชียงใหม่": [
            ("บ้านหม้อ", "43130"),
        ],
        "สระใคร": [
            ("คอกช้าง", "43100"),
            ("สระใคร", "43100"),
        ],
        "สังคม": [
            ("แก้งไก่", "43160"),
            ("นางิ้ว", "43160"),
        ],
        "ท่าบ่อ": [
            ("กองนาง", "43110"),
            ("โคกคอน", "43110"),
            ("น้ำโมง", "43110"),
            ("บ้านเดื่อ", "43110"),
            ("บ้านว่าน", "43110"),
            ("โพนสา", "43110"),
        ],
        "เฝ้าไร่": [
            ("นาดี", "43120"),
        ],
        "โพธิ์ตาก": [
            ("โพธิ์ตาก", "43130"),
        ],
        "โพนพิสัย": [
            ("จุมพล", "43120"),
            ("ชุมช้าง", "43120"),
            ("บ้านโพธิ์", "43120"),
            ("สร้างนางขาว", "43120"),
            ("เหล่าต่างคำ", "43120"),
        ],
        "เมืองหนองคาย": [
            ("กวนวัน", "43000"),
            ("ค่ายบกหวาน", "43100"),
            ("บ้านเดื่อ", "43000"),
            ("พระธาตุบังพวน", "43100"),
            ("โพธิ์ชัย", "43000"),
            ("เมืองหมี", "43000"),
            ("วัดธาตุ", "43000"),
            ("สองห้อง", "43100"),
            ("สีกาย", "43000"),
            ("หินโงม", "43000"),
            ("โพนสว่าง", "43100"),
        ],
        "รัตนวาปี": [
            ("บ้านต้อน", "43120"),
            ("พระบาทนาสิงห์", "43120"),
            ("รัตนวาปี", "43120"),
        ],
        "ศรีเชียงใหม่": [
            ("พระพุทธบาท", "43130"),
            ("พานพร้าว", "43130"),
            ("หนองปลาปาก", "43130"),
        ],
        "สระใคร": [
            ("บ้านฝาง", "43100"),
        ],
        "สังคม": [
            ("บ้านม่วง", "43160"),
            ("ผาตั้ง", "43160"),
            ("สังคม", "43160"),
        ],
        "เฝ้าไร่": [
            ("วังหลวง", "43230"),
        ]},
    "หนองบัวลำภู": {
        "เมืองหนองบัวลำภู": [
            ("หนองสวรรค์", "39000"),
            ("หัวนา", "39000"),
            ("โนนขมิ้น", "39000"),
            ("ลำภู", "39000"),
            ("กุดจิก", "39000"),
        ],
        "นากลาง": [
            ("นากลาง", "39170"),
            ("ด่านช้าง", "39170"),
            ("ฝั่งแดง", "39170"),
            ("เก่ากลอย", "39350"),
            ("ดงสวรรค์", "39350"),
            ("กุดแห่", "39170"),
        ],
        "โนนสัง": [
            ("โนนสัง", "39140"),
            ("บ้านถิ่น", "39140"),
            ("กุดดู่", "39140"),
            ("โคกม่วง", "39140"),
        ],
        "ศรีบุญเรือง": [
            ("เมืองใหม่", "39180"),
            ("กุดสะเทียน", "39180"),
            ("นากอก", "39180"),
            ("โนนม่วง", "39180"),
            ("หนองแก", "39180"),
            ("ทรายทอง", "39180"),
        ],
        "สุวรรณคูหา": [
            ("นาสี", "39270"),
            ("นาดี", "39270"),
            ("สุวรรณคูหา", "39270"),
            ("บุญทัน", "39270"),
        ],
        "นาวัง": [
            ("นาแก", "39170"),
            ("วังปลาป้อม", "39170"),
        ],
        "เมืองหนองบัวลำภู": [
            ("หนองบัว", "39000"),
            ("หนองภัยศูนย์", "39000"),
            ("โพธิ์ชัย", "39000"),
            ("บ้านขาม", "39000"),
            ("นามะเฟือง", "39000"),
            ("บ้านพร้าว", "39000"),
            ("โนนทัน", "39000"),
            ("นาคำไฮ", "39000"),
            ("ป่าไม้งาม", "39000"),
            ("หนองหว้า", "39000"),
        ],
        "นากลาง": [
            ("กุดดินจี่", "39350"),
            ("โนนเมือง", "39170"),
            ("อุทัยสวรรค์", "39170"),
        ],
        "โนนสัง": [
            ("หนองเรือ", "39140"),
            ("บ้านค้อ", "39140"),
            ("โนนเมือง", "39140"),
            ("โคกใหญ่", "39140"),
            ("นิคมพัฒนา", "39140"),
            ("ปางกู่", "39140"),
        ],
        "ศรีบุญเรือง": [
            ("ศรีบุญเรือง", "39180"),
            ("หนองบัวใต้", "39180"),
            ("โนนสะอาด", "39180"),
            ("ยางหล่อ", "39180"),
            ("หนองกุงแก้ว", "39180"),
            ("หันนางาม", "39180"),
        ],
        "สุวรรณคูหา": [
            ("บ้านโคก", "39270"),
            ("นาด่าน", "39270"),
            ("ดงมะไฟ", "39270"),
            ("กุดผึ้ง", "39270"),
        ],
        "นาวัง": [
            ("นาเหล่า", "39170"),
            ("วังทอง", "39170"),
            ("เทพคีรี", "39170"),
        ]},
    "อำนาจเจริญ": {
        "เมืองอำนาจเจริญ": [
            ("ปลาค้าว", "37000"),
            ("คึมใหญ่", "37000"),
            ("นาผือ", "37000"),
            ("น้ำปลีก", "37000"),
            ("นาหมอม้า", "37000"),
            ("โนนโพธิ์", "37000"),
            ("โนนหนามแท่ง", "37000"),
            ("ห้วยไร่", "37000"),
            ("กุดปลาดุก", "37000"),
            ("นายม", "37000"),
        ],
        "ชานุมาน": [
            ("โคกสาร", "37210"),
            ("คำเขื่อนแก้ว", "37210"),
            ("โคกก่ง", "37210"),
        ],
        "ปทุมราชวงศา": [
            ("หนองข่า", "37110"),
            ("นาหว้า", "37110"),
            ("นาป่าแซง", "37110"),
        ],
        "พนา": [
            ("จานลาน", "37180"),
        ],
        "เสนางคนิคม": [
            ("เสนางคนิคม", "37290"),
            ("โพนทอง", "37290"),
        ],
        "หัวตะพาน": [
            ("หนองแก้ว", "37240"),
            ("สร้างถ่อน้อย", "37240"),
            ("รัตนวารี", "37240"),
        ],
        "ลืออำนาจ": [
            ("อำนาจ", "37000"),
            ("ดงมะยาง", "37000"),
            ("ไร่ขี", "37000"),
            ("ไร่ขี", "37120"),
            ("แมด", "37120"),
        ],
        "เมืองอำนาจเจริญ": [
            ("บุ่ง", "37000"),
            ("ไก่คำ", "37000"),
            ("นาจิก", "37000"),
            ("เหล่าพรวน", "37000"),
            ("สร้างนกทา", "37000"),
            ("นาวัง", "37000"),
            ("หนองมะแซว", "37000"),
            ("ดอนเมย", "37000"),
            ("นาแต้", "37000"),
        ],
        "ชานุมาน": [
            ("ชานุมาน", "37210"),
            ("ป่าก่อ", "37210"),
        ],
        "ปทุมราชวงศา": [
            ("คำโพน", "37110"),
            ("ลือ", "37110"),
            ("ห้วย", "37110"),
            ("โนนงาม", "37110"),
        ],
        "พนา": [
            ("พนา", "37180"),
            ("ไม้กลอน", "37180"),
            ("พระเหลา", "37180"),
        ],
        "เสนางคนิคม": [
            ("ไร่สีสุก", "37290"),
            ("นาเวียง", "37290"),
            ("หนองไฮ", "37290"),
            ("หนองสามสี", "37290"),
        ],
        "หัวตะพาน": [
            ("หัวตะพาน", "37240"),
            ("คำพระ", "37240"),
            ("เค็งใหญ่", "37240"),
            ("โพนเมืองน้อย", "37240"),
            ("จิกดู่", "37240"),
        ],
        "ลืออำนาจ": [
            ("อำนาจ", "37120"),
            ("ดงมะยาง", "37120"),
            ("เปือย", "37000"),
            ("เปือย", "37120"),
            ("ดงบัง", "37000"),
            ("ดงบัง", "37120"),
            ("แมด", "37000"),
            ("โคกกลาง", "37000"),
            ("โคกกลาง", "37120"),
        ]},
    "อุดรธานี": {
        "เมืองอุดรธานี": [
            ("นิคมสงเคราะห์", "41000"),
            ("บ้านขาว", "41000"),
            ("บ้านตาด", "41000"),
            ("โนนสูง", "41330"),
            ("เชียงยืน", "41000"),
            ("หนองนาคำ", "41000"),
            ("กุดสระ", "41000"),
            ("เชียงพิณ", "41000"),
            ("สามพร้าว", "41000"),
            ("หนองไฮ", "41000"),
            ("บ้านจั่น", "41000"),
            ("หนองขอนกว้าง", "41000"),
            ("โคกสะอาด", "41000"),
            ("นากว้าง", "41000"),
        ],
        "กุดจับ": [
            ("กุดจับ", "41250"),
            ("ขอนยูง", "41250"),
            ("เชียงเพ็ง", "41250"),
            ("เมืองเพีย", "41250"),
        ],
        "หนองวัวซอ": [
            ("หนองอ้อ", "41220"),
            ("น้ำพ่น", "41360"),
            ("หนองบัวบาน", "41360"),
            ("โนนหวาย", "41220"),
            ("หนองวัวซอ", "41360"),
        ],
        "กุมภวาปี": [
            ("ตูมใต้", "41110"),
            ("แชแล", "41110"),
            ("ปะโค", "41370"),
            ("ผาสุก", "41370"),
            ("หนองหว้า", "41110"),
        ],
        "โนนสะอาด": [
            ("โพธิ์ศรีสำราญ", "41240"),
            ("ทมนางาม", "41240"),
        ],
        "หนองหาน": [
            ("หนองหาน", "41130"),
            ("หนองเม็ก", "41130"),
            ("พังงู", "41130"),
            ("สะแบง", "41130"),
            ("สร้อยพร้าว", "41130"),
            ("บ้านเชียง", "41320"),
            ("โพนงาม", "41130"),
            ("ผักตบ", "41130"),
            ("หนองไผ่", "41130"),
            ("หนองสระปลา", "41320"),
        ],
        "ทุ่งฝน": [
            ("ทุ่งฝน", "41310"),
        ],
        "ไชยวาน": [
            ("หนองหลัก", "41290"),
            ("คำเลาะ", "41290"),
        ],
        "ศรีธาตุ": [
            ("ศรีธาตุ", "41230"),
            ("จำปี", "41230"),
            ("หัวนาคำ", "41230"),
            ("ตาดทอง", "41230"),
        ],
        "วังสามหมอ": [
            ("หนองกุงทับม้า", "41280"),
            ("บะยาว", "41280"),
            ("ผาสุก", "41280"),
        ],
        "บ้านดุง": [
            ("ศรีสุทโธ", "41190"),
            ("อ้อมกอ", "41190"),
            ("บ้านจันทน์", "41190"),
            ("นาไหม", "41190"),
            ("วังทอง", "41190"),
            ("นาคำ", "41190"),
        ],
        "บ้านผือ": [
            ("บ้านผือ", "41160"),
            ("หายโศก", "41160"),
            ("เขือน้ำ", "41160"),
            ("คำบง", "41160"),
            ("โนนทอง", "41160"),
            ("จำปาโมง", "41160"),
            ("เมืองพาน", "41160"),
            ("คำด้วง", "41160"),
            ("บ้านค้อ", "41160"),
            ("หนองแวง", "41160"),
        ],
        "น้ำโสม": [
            ("นางัว", "41210"),
            ("ศรีสำราญ", "41210"),
        ],
        "เพ็ญ": [
            ("เพ็ญ", "41150"),
            ("บ้านธาตุ", "41150"),
        ],
        "เมืองอุดรธานี": [
            ("หมากแข้ง", "41000"),
            ("หนองบัว", "41000"),
            ("หมูม่น", "41000"),
            ("นาดี", "41000"),
            ("บ้านเลื่อม", "41000"),
            ("นาข่า", "41000"),
            ("หนองไผ่", "41330"),
        ],
        "กุดจับ": [
            ("ปะโค", "41250"),
            ("สร้างก่อ", "41250"),
            ("ตาลเลียน", "41250"),
        ],
        "หนองวัวซอ": [
            ("หมากหญ้า", "41360"),
            ("อูบมุง", "41220"),
            ("กุดหมากไฟ", "41220"),
        ],
        "กุมภวาปี": [
            ("พันดอน", "41370"),
            ("เวียงคำ", "41110"),
            ("เชียงแหว", "41110"),
            ("ห้วยเกิ้ง", "41110"),
            ("เสอเพลอ", "41370"),
            ("สีออ", "41110"),
            ("ท่าลี่", "41110"),
            ("กุมภวาปี", "41110"),
        ],
        "โนนสะอาด": [
            ("โนนสะอาด", "41240"),
            ("บุ่งแก้ว", "41240"),
            ("หนองกุงศรี", "41240"),
            ("โคกกลาง", "41240"),
        ],
        "หนองหาน": [
            ("บ้านยา", "41320"),
            ("ดอนหายโศก", "41130"),
        ],
        "ทุ่งฝน": [
            ("ทุ่งใหญ่", "41310"),
            ("นาชุมแสง", "41310"),
            ("นาทม", "41310"),
        ],
        "ไชยวาน": [
            ("ไชยวาน", "41290"),
            ("โพนสูง", "41290"),
        ],
        "ศรีธาตุ": [
            ("บ้านโปร่ง", "41230"),
            ("หนองนกเขียน", "41230"),
            ("นายูง", "41230"),
        ],
        "วังสามหมอ": [
            ("หนองหญ้าไซ", "41280"),
            ("คำโคกสูง", "41280"),
            ("วังสามหมอ", "41280"),
        ],
        "บ้านดุง": [
            ("บ้านดุง", "41190"),
            ("ดงเย็น", "41190"),
            ("โพนสูง", "41190"),
            ("บ้านชัย", "41190"),
            ("ถ่อนนาลับ", "41190"),
            ("บ้านม่วง", "41190"),
            ("บ้านตาด", "41190"),
        ],
        "บ้านผือ": [
            ("ข้าวสาร", "41160"),
            ("กลางใหญ่", "41160"),
            ("หนองหัวคู", "41160"),
        ],
        "น้ำโสม": [
            ("น้ำโสม", "41210"),
            ("หนองแวง", "41210"),
            ("บ้านหยวก", "41210"),
            ("โสมเยี่ยม", "41210"),
            ("สามัคคี", "41210"),
        ],
        "เพ็ญ": [
            ("นาพู่", "41150"),
            ("เชียงหวาง", "41150"),
            ("สุมเส้า", "41150"),
            ("จอมศรี", "41150"),
            ("เตาไห", "41150"),
        ],
        "สร้างคอม": [
            ("บ้านยวด", "41260"),
            ("นาสะอาด", "41260"),
            ("บ้านหินโงม", "41260"),
        ],
        "หนองแสง": [
            ("หนองแสง", "41340"),
            ("นาดี", "41340"),
            ("ทับกุง", "41340"),
        ],
        "พิบูลย์รักษ์": [
            ("บ้านแดง", "41130"),
            ("ดอนกลอย", "41130"),
        ],
        "กู่แก้ว": [
            ("คอนสาย", "41130"),
            ("บ้านจีต", "41130"),
            ("โนนทองอินทร์", "41130"),
        ],
        "ประจักษ์ศิลปาคม": [
            ("ห้วยสามพาด", "41110"),
            ("อุ่มจาน", "41110"),
        ],
        "เพ็ญ": [
            ("นาบัว", "41150"),
            ("บ้านเหล่า", "41150"),
            ("โคกกลาง", "41150"),
            ("สร้างแป้น", "41150"),
        ],
        "สร้างคอม": [
            ("สร้างคอม", "41260"),
            ("เชียงดา", "41260"),
            ("บ้านโคก", "41260"),
        ],
        "หนองแสง": [
            ("แสงสว่าง", "41340"),
        ],
        "นายูง": [
            ("นายูง", "41380"),
            ("บ้านก้อง", "41380"),
            ("นาแค", "41380"),
            ("โนนทอง", "41380"),
        ],
        "พิบูลย์รักษ์": [
            ("นาทราย", "41130"),
        ],
        "กู่แก้ว": [
            ("ค้อใหญ่", "41130"),
        ],
        "ประจักษ์ศิลปาคม": [
            ("นาม่วง", "41110"),
        ]},
    "อุตรดิตถ์": {
        "เมืองอุตรดิตถ์": [
            ("ท่าอิฐ", "53000"),
            ("หาดกรวด", "53000"),
            ("น้ำริด", "53000"),
            ("บ้านด่านนาขาม", "53000"),
            ("ผาจุก", "53000"),
            ("วังดิน", "53000"),
            ("ถ้ำฉลอง", "53000"),
        ],
        "ท่าปลา": [
            ("หาดล้า", "53150"),
            ("หาดล้า", "53190"),
            ("ร่วมจิต", "53190"),
        ],
        "น้ำปาด": [
            ("น้ำไผ่", "53110"),
        ],
        "ฟากท่า": [
            ("สองคอน", "53160"),
            ("บ้านเสี้ยว", "53160"),
            ("สองห้อง", "53160"),
        ],
        "บ้านโคก": [
            ("ม่วงเจ็ดต้น", "53180"),
            ("บ่อเบี้ย", "53180"),
        ],
        "พิชัย": [
            ("ในเมือง", "53120"),
            ("คอรุม", "53120"),
            ("ท่ามะเฟือง", "53120"),
            ("บ้านโคน", "53120"),
        ],
        "ลับแล": [
            ("นานกกก", "53130"),
            ("ฝายหลวง", "53130"),
            ("ด่านแม่คำมัน", "53210"),
        ],
        "ทองแสนขัน": [
            ("ผักขวง", "53230"),
            ("ป่าคาย", "53230"),
            ("น้ำพี้", "53230"),
        ],
        "เมืองอุตรดิตถ์": [
            ("ท่าเสา", "53000"),
            ("บ้านเกาะ", "53000"),
            ("บ้านเกาะ", "53170"),
            ("ป่าเซ่า", "53000"),
            ("คุ้งตะเภา", "53000"),
            ("วังกะพี้", "53170"),
            ("งิ้วงาม", "53000"),
            ("บ้านด่าน", "53000"),
            ("แสนตอ", "53000"),
            ("หาดงิ้ว", "53000"),
            ("ขุนฝาง", "53000"),
        ],
        "ตรอน": [
            ("วังแดง", "53140"),
            ("บ้านแก่ง", "53140"),
            ("หาดสองแคว", "53140"),
            ("น้ำอ่าง", "53140"),
            ("ข่อยสูง", "53140"),
        ],
        "ท่าปลา": [
            ("ท่าปลา", "53150"),
            ("ผาเลือด", "53190"),
            ("จริม", "53110"),
            ("จริม", "53150"),
            ("น้ำหมัน", "53110"),
            ("น้ำหมัน", "53150"),
        ],
        "น้ำปาด": [
            ("ท่าแฝก", "53110"),
        ],
        "ท่าปลา": [
            ("นางพญา", "53150"),
        ],
        "น้ำปาด": [
            ("แสนตอ", "53110"),
            ("บ้านฝาย", "53110"),
            ("เด่นเหล็ก", "53110"),
            ("น้ำไคร้", "53110"),
            ("ห้วยมุ่น", "53110"),
        ],
        "ฟากท่า": [
            ("ฟากท่า", "53160"),
        ],
        "บ้านโคก": [
            ("บ้านโคก", "53180"),
            ("นาขุม", "53180"),
        ],
        "พิชัย": [
            ("บ้านดารา", "53220"),
            ("ไร่อ้อย", "53120"),
            ("ท่าสัก", "53220"),
            ("บ้านหม้อ", "53120"),
            ("พญาแมน", "53120"),
            ("นาอิน", "53120"),
            ("นายาง", "53120"),
        ],
        "ลับแล": [
            ("ศรีพนมมาศ", "53130"),
            ("แม่พูล", "53130"),
            ("ชัยจุมพล", "53130"),
            ("ไผ่ล้อม", "53210"),
            ("ทุ่งยั้ง", "53210"),
        ],
        "ทองแสนขัน": [
            ("บ่อทอง", "53230"),
        ]},
    "อุทัยธานี": {
        "เมืองอุทัยธานี": [
            ("อุทัยใหม่", "61000"),
            ("น้ำซึม", "61000"),
            ("ดอนขวาง", "61000"),
            ("เกาะเทโพ", "61000"),
            ("ท่าซุง", "61000"),
            ("โนนเหล็ก", "61000"),
            ("หนองไผ่แบน", "61000"),
            ("หนองเต่า", "61000"),
            ("หาดทนง", "61000"),
        ],
        "ทัพทัน": [
            ("เขาขี้ฝอย", "61120"),
            ("โคกหม้อ", "61120"),
            ("หนองกระทุ่ม", "61120"),
            ("หนองสระ", "61120"),
        ],
        "สว่างอารมณ์": [
            ("สว่างอารมณ์", "61150"),
        ],
        "หนองฉาง": [
            ("หนองฉาง", "61110"),
            ("หนองยาง", "61110"),
            ("หนองนางนวล", "61110"),
            ("บ้านเก่า", "61110"),
            ("ทุ่งโพ", "61110"),
            ("เขาบางแกรก", "61170"),
        ],
        "หนองขาหย่าง": [
            ("หนองขาหย่าง", "61130"),
            ("หนองไผ่", "61130"),
            ("ห้วยรอบ", "61130"),
            ("ท่าโพ", "61130"),
            ("หมกแถว", "61130"),
            ("ดงขวาง", "61130"),
        ],
        "บ้านไร่": [
            ("บ้านไร่", "61140"),
            ("คอกควาย", "61140"),
            ("แก่นมะกรูด", "61180"),
            ("แก่นมะกรูด", "61140"),
            ("บ้านบึง", "61140"),
            ("บ้านใหม่คลองเคียน", "61180"),
            ("หนองบ่มกล้วย", "61180"),
            ("เจ้าวัด", "61140"),
        ],
        "ลานสัก": [
            ("ลานสัก", "61160"),
            ("ประดู่ยืน", "61160"),
            ("ป่าอ้อ", "61160"),
        ],
        "ห้วยคต": [
            ("สุขฤทัย", "61170"),
            ("ทองหลาง", "61170"),
        ],
        "เมืองอุทัยธานี": [
            ("สะแกกรัง", "61000"),
            ("หนองแก", "61000"),
            ("หนองพังค่า", "61000"),
            ("ทุ่งใหญ่", "61000"),
            ("เนินแจง", "61000"),
        ],
        "ทัพทัน": [
            ("ทัพทัน", "61120"),
            ("ทุ่งนาไทย", "61120"),
            ("หนองหญ้าปล้อง", "61120"),
            ("หนองยายดา", "61120"),
            ("หนองกลางดง", "61120"),
            ("ตลุกดู่", "61120"),
        ],
        "สว่างอารมณ์": [
            ("หนองหลวง", "61150"),
            ("พลวงสองนาง", "61150"),
            ("ไผ่เขียว", "61150"),
            ("บ่อยาง", "61150"),
        ],
        "หนองฉาง": [
            ("หนองสรวง", "61110"),
            ("อุทัยเก่า", "61110"),
            ("ทุ่งพง", "61110"),
            ("เขากวางทอง", "61110"),
        ],
        "หนองขาหย่าง": [
            ("ดอนกลอย", "61130"),
            ("ทุ่งพึ่ง", "61130"),
            ("หลุมเข้า", "61130"),
        ],
        "บ้านไร่": [
            ("ทัพหลวง", "61140"),
            ("ห้วยแห้ง", "61140"),
            ("วังหิน", "61180"),
            ("เมืองการุ้ง", "61180"),
            ("หนองจอก", "61180"),
            ("หูช้าง", "61180"),
        ],
        "ลานสัก": [
            ("ระบำ", "61160"),
            ("น้ำรอบ", "61160"),
            ("ทุ่งนางาม", "61160"),
        ],
        "ห้วยคต": [
            ("ห้วยคต", "61170"),
        ]},
    "อุบลราชธานี": {
        "เมืองอุบลราชธานี": [
            ("ในเมือง", "34000"),
            ("ในเมือง", "34002"),
            ("หนองขอน", "34000"),
            ("ปทุม", "34000"),
            ("ไร่น้อย", "34000"),
            ("กระโสบ", "34000"),
            ("ปะอาว", "34000"),
        ],
        "ศรีเมืองใหม่": [
            ("นาคำ", "34250"),
            ("วาริน", "34250"),
            ("คำไหล", "34250"),
            ("หนามแท่ง", "34250"),
            ("ดอนใหญ่", "34250"),
        ],
        "โขงเจียม": [
            ("ห้วยยาง", "34220"),
            ("ห้วยไผ่", "34220"),
        ],
        "เขื่องใน": [
            ("เขื่องใน", "34150"),
            ("ก่อเอ้", "34150"),
            ("หัวดอน", "34150"),
            ("ท่าไห", "34150"),
            ("แดงหม้อ", "34150"),
            ("บ้านไทย", "34320"),
            ("โนนรัง", "34320"),
            ("สหธาตุ", "34150"),
        ],
        "เขมราฐ": [
            ("เขมราฐ", "34170"),
            ("เจียด", "34170"),
            ("หนองผือ", "34170"),
            ("นาแวง", "34170"),
            ("แก้งเหนือ", "34170"),
            ("หนองสิม", "34170"),
        ],
        "เดชอุดม": [
            ("เมืองเดช", "34160"),
            ("นาเจริญ", "34160"),
            ("ทุ่งเทิง", "34160"),
            ("ตบหู", "34160"),
            ("บัวงาม", "34160"),
            ("โพนงาม", "34160"),
        ],
        "นาจะหลวย": [
            ("นาจะหลวย", "34280"),
            ("โนนสมบูรณ์", "34280"),
            ("พรสวรรค์", "34280"),
            ("โสกแสง", "34280"),
            ("โนนสวรรค์", "34280"),
        ],
        "น้ำยืน": [
            ("สีวิเชียร", "34260"),
            ("ยางใหญ่", "34260"),
            ("เก่าขาม", "34260"),
        ],
        "บุณฑริก": [
            ("คอแลน", "34230"),
            ("นาโพธิ์", "34230"),
            ("หนองสะโน", "34230"),
            ("บัวงาม", "34230"),
        ],
        "ตระการพืชผล": [
            ("ขุหลุ", "34130"),
            ("กระเดียน", "34130"),
            ("เกษม", "34130"),
            ("คอนสาย", "34130"),
            ("โคกจาน", "34130"),
            ("นาพิน", "34130"),
            ("โนนกุง", "34130"),
            ("ตระการ", "34130"),
            ("ตากแดด", "34130"),
            ("ไหล่ทุ่ง", "34130"),
            ("หนองเต่า", "34130"),
            ("ถ้ำแข้", "34130"),
            ("ท่าหลวง", "34130"),
            ("ห้วยฝ้ายพัฒนา", "34130"),
            ("กุดยาลวน", "34130"),
            ("บ้านแดง", "34130"),
        ],
        "กุดข้าวปุ้น": [
            ("โนนสวาง", "34270"),
            ("แก่งเค็ง", "34270"),
            ("กาบิน", "34270"),
            ("หนองทันน้ำ", "34270"),
        ],
        "ม่วงสามสิบ": [
            ("ดุมใหญ่", "34140"),
            ("เตย", "34140"),
            ("ยางสักกระโพหลุ่ม", "34140"),
            ("หนองเหล่า", "34140"),
            ("ยางโยภาพ", "34140"),
            ("นาเลิง", "34140"),
            ("โพนแพง", "34140"),
        ],
        "วารินชำราบ": [
            ("วารินชำราบ", "34190"),
            ("ธาตุ", "34190"),
            ("โนนโหนน", "34190"),
            ("คูเมือง", "34190"),
            ("สระสมิง", "34190"),
            ("คำขวาง", "34190"),
            ("หนองกินเพล", "34190"),
            ("โนนผึ้ง", "34190"),
            ("เมืองศรีไค", "34190"),
            ("ห้วยขะยุง", "34310"),
            ("บุ่งไหม", "34190"),
        ],
        "พิบูลมังสาหาร": [
            ("พิบูล", "34110"),
            ("นาโพธิ์", "34110"),
            ("โนนกลาง", "34110"),
            ("โนนกาหลง", "34110"),
        ],
        "ตาลสุม": [
            ("สำโรง", "34330"),
            ("นาคาย", "34330"),
            ("คำหว้า", "34330"),
        ],
        "โพธิ์ไทร": [
            ("โพธิ์ไทร", "34340"),
            ("สำโรง", "34340"),
            ("สองคอน", "34340"),
        ],
        "สำโรง": [
            ("สำโรง", "34360"),
            ("ค้อน้อย", "34360"),
            ("โนนกาเล็น", "34360"),
            ("โนนกลาง", "34360"),
            ("ขามป้อม", "34360"),
        ],
        "ดอนมดแดง": [
            ("เหล่าแดง", "34000"),
            ("ท่าเมือง", "34000"),
        ],
        "สิรินธร": [
            ("คันไร่", "34350"),
            ("โนนก่อ", "34350"),
            ("คำเขื่อนแก้ว", "34350"),
            ("นิคมสร้างตนเองลำโดมน้อย", "34350"),
        ],
        "ทุ่งศรีอุดม": [
            ("โคกชำแระ", "34160"),
            ("นาห่อม", "34160"),
        ],
        "นาตาล": [
            ("นาตาล", "34170"),
        ],
        "เหล่าเสือโก้ก": [
            ("เหล่าเสือโก้ก", "34000"),
        ],
        "สว่างวีระวงศ์": [
            ("แก่งโดม", "34190"),
            ("บุ่งมะแลง", "34190"),
            ("สว่าง", "34190"),
        ],
        "น้ำขุ่น": [
            ("ตาเกา", "34260"),
            ("ไพบูลย์", "34260"),
            ("ขี้เหล็ก", "34260"),
        ],
        "เมืองอุบลราชธานี": [
            ("หัวเรือ", "34000"),
            ("ขามใหญ่", "34000"),
            ("แจระแม", "34000"),
            ("หนองบ่อ", "34000"),
            ("กุดลาด", "34000"),
            ("ขี้เหล็ก", "34000"),
        ],
        "ศรีเมืองใหม่": [
            ("แก้งกอก", "34250"),
            ("เอือดใหญ่", "34250"),
            ("ลาดควาย", "34250"),
            ("สงยาง", "34250"),
            ("ตะบ่าย", "34250"),
            ("นาเลิน", "34250"),
        ],
        "โขงเจียม": [
            ("โขงเจียม", "34220"),
            ("นาโพธิ์กลาง", "34220"),
            ("หนองแสงใหญ่", "34220"),
        ],
        "เขื่องใน": [
            ("สร้างถ่อ", "34150"),
            ("ค้อทอง", "34150"),
            ("ชีทวน", "34150"),
            ("นาคำใหญ่", "34150"),
            ("ธาตุน้อย", "34150"),
            ("บ้านกอก", "34320"),
            ("กลางใหญ่", "34320"),
            ("ยางขี้นก", "34150"),
            ("ศรีสุข", "34150"),
            ("หนองเหล่า", "34150"),
        ],
        "เขมราฐ": [
            ("ขามป้อม", "34170"),
            ("หนองนกทา", "34170"),
            ("หัวนา", "34170"),
        ],
        "เดชอุดม": [
            ("นาส่วง", "34160"),
            ("สมสะอาด", "34160"),
            ("กุดประทาย", "34160"),
            ("กลาง", "34160"),
            ("แก้ง", "34160"),
            ("ท่าโพธิ์ศรี", "34160"),
            ("คำครั่ง", "34160"),
            ("นากระแซง", "34160"),
            ("ป่าโมง", "34160"),
            ("โนนสมบูรณ์", "34160"),
        ],
        "นาจะหลวย": [
            ("บ้านตูม", "34280"),
        ],
        "น้ำยืน": [
            ("โซง", "34260"),
            ("ยาง", "34260"),
            ("โดมประดิษฐ์", "34260"),
            ("บุเปือย", "34260"),
        ],
        "บุณฑริก": [
            ("โพนงาม", "34230"),
            ("ห้วยข่า", "34230"),
            ("โนนค้อ", "34230"),
            ("บ้านแมด", "34230"),
        ],
        "ตระการพืชผล": [
            ("กุศกร", "34130"),
            ("ขามเปี้ย", "34130"),
            ("นาสะไม", "34130"),
            ("เป้า", "34130"),
            ("เซเป็ด", "34130"),
            ("สะพือ", "34130"),
            ("คำเจริญ", "34130"),
        ],
        "กุดข้าวปุ้น": [
            ("ข้าวปุ้น", "34270"),
        ],
        "ม่วงสามสิบ": [
            ("ม่วงสามสิบ", "34140"),
            ("เหล่าบก", "34140"),
            ("หนองช้างใหญ่", "34140"),
            ("หนองเมือง", "34140"),
            ("หนองไข่นก", "34140"),
            ("หนองฮาง", "34140"),
            ("ไผ่ใหญ่", "34140"),
        ],
        "วารินชำราบ": [
            ("ท่าลาด", "34310"),
            ("คำน้ำแซบ", "34190"),
            ("บุ่งหวาย", "34310"),
            ("โพธิ์ใหญ่", "34190"),
            ("แสนสุข", "34190"),
        ],
        "พิบูลมังสาหาร": [
            ("กุดชมภู", "34110"),
            ("ดอนจิก", "34110"),
            ("ทรายมูล", "34110"),
            ("โพธิ์ไทร", "34110"),
            ("โพธิ์ศรี", "34110"),
            ("ระเว", "34110"),
            ("ไร่ใต้", "34110"),
            ("หนองบัวฮี", "34110"),
            ("อ่างศิลา", "34110"),
            ("บ้านแขม", "34110"),
        ],
        "ตาลสุม": [
            ("ตาลสุม", "34330"),
            ("จิกเทิง", "34330"),
            ("หนองกุง", "34330"),
        ],
        "โพธิ์ไทร": [
            ("ม่วงใหญ่", "34340"),
            ("สารภี", "34340"),
            ("เหล่างาม", "34340"),
        ],
        "สำโรง": [
            ("โคกก่อง", "34360"),
            ("หนองไฮ", "34360"),
            ("โคกสว่าง", "34360"),
            ("บอน", "34360"),
        ],
        "ดอนมดแดง": [
            ("ดอนมดแดง", "34000"),
            ("คำไฮใหญ่", "34000"),
        ],
        "สิรินธร": [
            ("ช่องเม็ก", "34350"),
            ("นิคมลำโดมน้อย", "34350"),
            ("ฝางคำ", "34350"),
        ],
        "ทุ่งศรีอุดม": [
            ("หนองอ้ม", "34160"),
            ("นาเกษม", "34160"),
            ("กุดเรือ", "34160"),
        ],
        "นาเยีย": [
            ("นาเยีย", "34160"),
            ("นาดี", "34160"),
            ("นาเรือง", "34160"),
        ],
        "นาตาล": [
            ("พะลาน", "34170"),
            ("กองโพน", "34170"),
            ("พังเคน", "34170"),
        ],
        "เหล่าเสือโก้ก": [
            ("โพนเมือง", "34000"),
            ("แพงใหญ่", "34000"),
            ("หนองบก", "34000"),
        ],
        "สว่างวีระวงศ์": [
            ("ท่าช้าง", "34190"),
        ],
        "น้ำขุ่น": [
            ("โคกสะอาด", "34260"),
        ]},
    "อ่างทอง": {
        "เมืองอ่างทอง": [
            ("บางแก้ว", "14000"),
            ("บ้านแห", "14000"),
            ("ตลาดกรวด", "14000"),
            ("จำปาหล่อ", "14000"),
            ("คลองวัว", "14000"),
            ("ย่านซื่อ", "14000"),
        ],
        "ไชโย": [
            ("ชัยฤทธิ์", "14140"),
            ("เทวราช", "14140"),
            ("ราชสถิตย์", "14140"),
        ],
        "ป่าโมก": [
            ("บางปลากด", "14130"),
            ("ป่าโมก", "14130"),
            ("โรงช้าง", "14130"),
            ("บางเสด็จ", "14130"),
            ("นรสิงห์", "14130"),
            ("เอกราช", "14130"),
            ("โผงเผง", "14130"),
        ],
        "โพธิ์ทอง": [
            ("อ่างแก้ว", "14120"),
            ("หนองแม่ไก่", "14120"),
            ("รำมะสัก", "14120"),
            ("บางระกำ", "14120"),
            ("โพธิ์รังนก", "14120"),
            ("องครักษ์", "14120"),
            ("โคกพุทรา", "14120"),
            ("ทางพระ", "14120"),
        ],
        "แสวงหา": [
            ("แสวงหา", "14150"),
            ("วังน้ำเย็น", "14150"),
            ("จำลอง", "14150"),
        ],
        "วิเศษชัยชาญ": [
            ("ศาลเจ้าโรงทอง", "14110"),
            ("ไผ่ดำพัฒนา", "14110"),
            ("ยี่ล้น", "14110"),
            ("หัวตะพาน", "14110"),
            ("ไผ่จำศีล", "14110"),
        ],
        "สามโก้": [
            ("สามโก้", "14160"),
            ("ราษฎรพัฒนา", "14160"),
            ("โพธิ์ม่วงพันธ์", "14160"),
        ],
        "เมืองอ่างทอง": [
            ("ตลาดหลวง", "14000"),
            ("ศาลาแดง", "14000"),
            ("ป่างิ้ว", "14000"),
            ("มหาดไทย", "14000"),
            ("บ้านอิฐ", "14000"),
            ("หัวไผ่", "14000"),
            ("โพสะ", "14000"),
            ("บ้านรี", "14000"),
        ],
        "ไชโย": [
            ("จรเข้ร้อง", "14140"),
            ("ไชยภูมิ", "14140"),
            ("ไชโย", "14140"),
            ("หลักฟ้า", "14140"),
            ("ชะไว", "14140"),
            ("ตรีณรงค์", "14140"),
        ],
        "ป่าโมก": [
            ("สายทอง", "14130"),
        ],
        "โพธิ์ทอง": [
            ("อินทประมูล", "14120"),
            ("บางพลับ", "14120"),
            ("ยางช้าย", "14120"),
            ("บ่อแร่", "14120"),
            ("สามง่าม", "14120"),
            ("บางเจ้าฉ่า", "14120"),
            ("คำหยาด", "14120"),
        ],
        "แสวงหา": [
            ("ศรีพราน", "14150"),
            ("บ้านพราน", "14150"),
            ("สีบัวทอง", "14150"),
            ("ห้วยไผ่", "14150"),
        ],
        "วิเศษชัยชาญ": [
            ("สาวร้องไห้", "14110"),
            ("ท่าช้าง", "14110"),
            ("บางจัก", "14110"),
            ("ห้วยคันแหลน", "14110"),
            ("คลองขนาก", "14110"),
            ("ไผ่วง", "14110"),
            ("สี่ร้อย", "14110"),
            ("ม่วงเตี้ย", "14110"),
            ("หลักแก้ว", "14110"),
            ("ตลาดใหม่", "14110"),
        ],
        "สามโก้": [
            ("อบทม", "14160"),
            ("มงคลธรรมนิมิต", "14160"),
        ]},
    "เชียงราย": {
        "เมืองเชียงราย": [
            ("เวียง", "57000"),
            ("รอบเวียง", "57000"),
            ("นางแล", "57100"),
            ("ริมกก", "57100"),
            ("ท่าสาย", "57000"),
            ("ท่าสุด", "57100"),
        ],
        "เวียงชัย": [
            ("เวียงชัย", "57210"),
        ],
        "เชียงของ": [
            ("บุญเรือง", "57140"),
            ("ริมโขง", "57140"),
        ],
        "เทิง": [
            ("งิ้ว", "57160"),
            ("ตับเต่า", "57160"),
            ("หงาว", "57160"),
            ("ศรีดอนไชย", "57160"),
            ("หนองแรด", "57230"),
        ],
        "พาน": [
            ("แม่อ้อ", "57120"),
            ("ธารทอง", "57250"),
            ("สันติสุข", "57120"),
            ("หัวง้ม", "57120"),
            ("ป่าหุ่ง", "57120"),
            ("ทรายขาว", "57120"),
            ("สันกลาง", "57120"),
            ("เวียงห้าว", "57120"),
        ],
        "ป่าแดด": [
            ("ป่าแดด", "57190"),
            ("ป่าแงะ", "57190"),
            ("โรงช้าง", "57190"),
        ],
        "แม่จัน": [
            ("แม่จัน", "57110"),
            ("จันจว้า", "57270"),
            ("แม่คำ", "57240"),
            ("ป่าซาง", "57110"),
            ("สันทราย", "57110"),
            ("ป่าตึง", "57110"),
        ],
        "เชียงแสน": [
            ("เวียง", "57150"),
            ("ศรีดอนมูล", "57150"),
            ("แม่เงิน", "57150"),
            ("โยนก", "57150"),
        ],
        "แม่สาย": [
            ("แม่สาย", "57130"),
            ("ห้วยไคร้", "57220"),
            ("เกาะช้าง", "57130"),
            ("ศรีเมืองชุม", "57130"),
            ("บ้านด้าย", "57220"),
        ],
        "แม่สรวย": [
            ("แม่สรวย", "57180"),
        ],
        "เวียงป่าเป้า": [
            ("เวียง", "57170"),
            ("บ้านโป่ง", "57170"),
            ("ป่างิ้ว", "57170"),
            ("แม่เจดีย์ใหม่", "57260"),
        ],
        "พญาเม็งราย": [
            ("เม็งราย", "57290"),
        ],
        "เวียงแก่น": [
            ("ปอ", "57310"),
            ("หล่ายงาว", "57310"),
            ("ท่าข้าม", "57310"),
        ],
        "ขุนตาล": [
            ("ต้า", "57340"),
            ("ป่าตาล", "57340"),
            ("ยางฮอม", "57340"),
        ],
        "แม่ฟ้าหลวง": [
            ("เทอดไทย", "57240"),
            ("แม่สลองใน", "57110"),
        ],
        "แม่ลาว": [
            ("ดงมะดะ", "57250"),
        ],
        "เวียงเชียงรุ้ง": [
            ("ทุ่งก่อ", "57210"),
            ("ดงมหาวัน", "57210"),
        ],
        "ดอยหลวง": [
            ("ปงน้อย", "57110"),
            ("โชคชัย", "57110"),
        ],
        "เมืองเชียงราย": [
            ("บ้านดู่", "57100"),
            ("แม่ข้าวต้ม", "57100"),
            ("แม่ยาว", "57100"),
            ("สันทราย", "57000"),
            ("แม่กรณ์", "57000"),
            ("ห้วยชมภู", "57000"),
            ("ห้วยสัก", "57000"),
            ("ดอยลาน", "57000"),
            ("ป่าอ้อดอนชัย", "57000"),
            ("ดอยฮาง", "57000"),
        ],
        "เวียงชัย": [
            ("ผางาม", "57210"),
            ("เวียงเหนือ", "57210"),
            ("ดอนศิลา", "57210"),
            ("เมืองชุม", "57210"),
        ],
        "เชียงของ": [
            ("เวียง", "57140"),
            ("สถาน", "57140"),
            ("ครึ่ง", "57140"),
            ("ห้วยซ้อ", "57140"),
            ("ศรีดอนชัย", "57230"),
            ("ศรีดอนชัย", "57140"),
        ],
        "เทิง": [
            ("เวียง", "57160"),
            ("งิ้ว", "57230"),
            ("ปล้อง", "57230"),
            ("แม่ลอย", "57230"),
            ("เชียงเคี่ยน", "57230"),
            ("สันทรายงาม", "57160"),
            ("ศรีดอนไชย", "57230"),
            ("หนองแรด", "57160"),
        ],
        "พาน": [
            ("สันมะเค็ด", "57120"),
            ("ดอยงาม", "57120"),
            ("เจริญเมือง", "57120"),
            ("ม่วงคำ", "57120"),
            ("แม่เย็น", "57280"),
            ("เมืองพาน", "57120"),
            ("ทานตะวัน", "57280"),
        ],
        "ป่าแดด": [
            ("สันมะค่า", "57190"),
            ("ศรีโพธิ์เงิน", "57190"),
        ],
        "แม่จัน": [
            ("ท่าข้าวเปลือก", "57110"),
            ("แม่ไร่", "57240"),
            ("ศรีค้ำ", "57110"),
            ("จันจว้าใต้", "57270"),
            ("จอมสวรรค์", "57110"),
        ],
        "เชียงแสน": [
            ("ป่าสัก", "57150"),
            ("บ้านแซว", "57150"),
            ("โยนก", "57130"),
        ],
        "แม่สาย": [
            ("โป่งผา", "57130"),
            ("เวียงพางคำ", "57130"),
            ("โป่งงาม", "57130"),
        ],
        "แม่สรวย": [
            ("ป่าแดด", "57180"),
            ("แม่พริก", "57180"),
            ("ศรีถ้อย", "57180"),
            ("ท่าก๊อ", "57180"),
            ("วาวี", "57180"),
            ("เจดีย์หลวง", "57180"),
        ],
        "เวียงป่าเป้า": [
            ("สันสลี", "57170"),
            ("เวียงกาหลง", "57260"),
            ("แม่เจดีย์", "57260"),
        ],
        "พญาเม็งราย": [
            ("แม่เปา", "57290"),
            ("แม่ต๋ำ", "57290"),
            ("ไม้ยา", "57290"),
            ("ตาดควัน", "57290"),
        ],
        "เวียงแก่น": [
            ("ม่วงยาย", "57310"),
        ],
        "แม่ฟ้าหลวง": [
            ("แม่สลองนอก", "57110"),
            ("แม่ฟ้าหลวง", "57240"),
        ],
        "แม่ลาว": [
            ("จอมหมอกแก้ว", "57250"),
            ("บัวสลี", "57250"),
            ("ป่าก่อดำ", "57250"),
            ("โป่งแพร่", "57000"),
        ],
        "เวียงเชียงรุ้ง": [
            ("ป่าซาง", "57210"),
        ],
        "ดอยหลวง": [
            ("หนองป่าก่อ", "57110"),
        ]},
    "เชียงใหม่": {
        "เมืองเชียงใหม่": [
            ("ช้างม่อย", "50300"),
            ("วัดเกต", "50000"),
            ("ช้างเผือก", "50300"),
            ("หนองหอย", "50000"),
            ("ฟ้าฮ่าม", "50000"),
            ("ป่าตัน", "50300"),
            ("สันผีเสื้อ", "50290"),
            ("พระสิงห์", "50000"),
            ("หายยา", "50000"),
            ("หายยา", "50100"),
        ],
        "จอมทอง": [
            ("ข่วงเปา", "50160"),
            ("สบเตี๊ยะ", "50160"),
            ("ดอยแก้ว", "50160"),
            ("แม่สอย", "50240"),
            ("แม่สอย", "50160"),
        ],
        "แม่แจ่ม": [
            ("ช่างเคิ่ง", "50270"),
            ("บ้านทับ", "50270"),
            ("แม่ศึก", "50270"),
        ],
        "เชียงดาว": [
            ("เชียงดาว", "50170"),
            ("เมืองนะ", "50170"),
            ("เมืองงาย", "50170"),
            ("แม่นะ", "50170"),
            ("เมืองคอง", "50170"),
        ],
        "ดอยสะเก็ด": [
            ("เชิงดอย", "50220"),
            ("สันปูเลย", "50220"),
            ("ป่าป้อง", "50220"),
            ("ป่าลาน", "50220"),
            ("ตลาดขวัญ", "50220"),
            ("แม่โป่ง", "50220"),
            ("เทพเสด็จ", "50220"),
        ],
        "แม่แตง": [
            ("แม่แตง", "50150"),
            ("ช่อแล", "50150"),
            ("แม่หอพระ", "50150"),
            ("สบเปิง", "50330"),
            ("บ้านเป้า", "50150"),
            ("เมืองก๋าย", "50150"),
        ],
        "แม่ริม": [
            ("ริมใต้", "50180"),
        ],
        "เมืองเชียงใหม่": [
            ("ช้างคลาน", "50100"),
            ("สุเทพ", "50200"),
            ("แม่เหียะ", "50100"),
            ("ป่าแดด", "50100"),
            ("ท่าศาลา", "50000"),
            ("หนองป่าครั่ง", "50000"),
            ("สันผีเสื้อ", "50300"),
            ("พระสิงห์", "50200"),
            ("ศรีภูมิ", "50200"),
        ],
        "จอมทอง": [
            ("บ้านหลวง", "50160"),
            ("บ้านแปะ", "50240"),
        ],
        "แม่แจ่ม": [
            ("ท่าผา", "50270"),
            ("แม่นาจร", "50270"),
            ("ปางหินฝน", "50270"),
            ("กองแขก", "50270"),
        ],
        "เชียงดาว": [
            ("ปิงโค้ง", "50170"),
            ("ทุ่งข้าวพวง", "50170"),
        ],
        "ดอยสะเก็ด": [
            ("ลวงเหนือ", "50220"),
            ("สง่าบ้าน", "50220"),
            ("สำราญราษฎร์", "50220"),
            ("แม่คือ", "50220"),
            ("ตลาดใหญ่", "50220"),
            ("แม่ฮ้อยเงิน", "50220"),
            ("ป่าเมี่ยง", "50220"),
        ],
        "แม่แตง": [
            ("สันมหาพน", "50150"),
            ("ขี้เหล็ก", "50150"),
            ("สบเปิง", "50150"),
            ("สันป่ายาง", "50330"),
            ("ป่าแป๋", "50150"),
            ("บ้านช้าง", "50150"),
            ("กื้ดช้าง", "50150"),
            ("อินทขิล", "50150"),
        ],
        "แม่ริม": [
            ("ริมเหนือ", "50180"),
            ("สันโป่ง", "50180"),
            ("ขี้เหล็ก", "50180"),
            ("สะลวง", "50330"),
            ("ห้วยทราย", "50180"),
            ("เหมืองแก้ว", "50180"),
        ],
        "สะเมิง": [
            ("สะเมิงเหนือ", "50250"),
            ("ยั้งเมิน", "50250"),
        ],
        "ฝาง": [
            ("แม่งอน", "50320"),
            ("แม่สูน", "50110"),
            ("แม่คะ", "50110"),
            ("แม่ข่า", "50320"),
            ("โป่งน้ำร้อน", "50110"),
            ("เวียง", "50110"),
        ],
        "แม่อาย": [
            ("แม่อาย", "50280"),
            ("ท่าตอน", "50280"),
        ],
        "พร้าว": [
            ("เวียง", "50190"),
            ("สันทราย", "50190"),
            ("บ้านโป่ง", "50190"),
            ("แม่แวน", "50190"),
            ("แม่ปั๋ง", "50190"),
        ],
        "สันป่าตอง": [
            ("สันกลาง", "50120"),
            ("แม่ก๊า", "50120"),
            ("บ้านแม", "50120"),
        ],
        "สันกำแพง": [
            ("สันกำแพง", "50130"),
            ("ทรายมูล", "50130"),
            ("ร้องวัวแดง", "50130"),
            ("บวกค้าง", "50130"),
            ("แช่ช้าง", "50130"),
            ("แม่ปูคา", "50130"),
            ("สันกลาง", "50130"),
        ],
        "สันทราย": [
            ("สันทรายหลวง", "50210"),
            ("สันทรายน้อย", "50210"),
            ("สันนาเม็ง", "50210"),
            ("หนองจ๊อม", "50210"),
            ("แม่แฝกใหม่", "50290"),
            ("เมืองเล็น", "50210"),
        ],
        "หางดง": [
            ("หางดง", "50230"),
            ("หารแก้ว", "50230"),
            ("หนองตอง", "50340"),
            ("สบแม่ข่า", "50230"),
            ("สันผักหวาน", "50230"),
            ("หนองควาย", "50230"),
            ("บ้านปง", "50230"),
            ("น้ำแพร่", "50230"),
        ],
        "ฮอด": [
            ("หางดง", "50240"),
            ("ฮอด", "50240"),
            ("บ้านตาล", "50240"),
            ("บ่อสลี", "50240"),
            ("นาคอเรือ", "50240"),
        ],
        "ดอยเต่า": [
            ("ดอยเต่า", "50260"),
            ("บงตัน", "50260"),
            ("โปงทุ่ง", "50260"),
        ],
        "อมก๋อย": [
            ("ยางเปียง", "50310"),
        ],
        "สารภี": [
            ("ยางเนิ้ง", "50140"),
            ("สารภี", "50140"),
            ("ไชยสถาน", "50140"),
            ("หนองแฝก", "50140"),
            ("ท่ากว้าง", "50140"),
            ("ดอนแก้ว", "50140"),
            ("สันทราย", "50140"),
            ("ป่าบง", "50140"),
        ],
        "เวียงแหง": [
            ("แสนไห", "50350"),
        ],
        "ไชยปราการ": [
            ("ปงตำ", "50320"),
            ("ศรีดงเย็น", "50320"),
            ("หนองบัว", "50320"),
        ],
        "แม่วาง": [
            ("บ้านกาด", "50360"),
            ("แม่วิน", "50360"),
            ("ดอนเปา", "50360"),
        ],
        "แม่ออน": [
            ("ออนเหนือ", "50130"),
            ("แม่ทา", "50130"),
        ],
        "ดอยหล่อ": [
            ("ดอยหล่อ", "50160"),
            ("ยางคราม", "50160"),
        ],
        "กัลยาณิวัฒนา": [
            ("แม่แดด", "58130"),
        ],
        "แม่ริม": [
            ("แม่แรม", "50180"),
            ("โป่งแยง", "50180"),
            ("แม่สา", "50180"),
            ("ดอนแก้ว", "50180"),
        ],
        "สะเมิง": [
            ("สะเมิงใต้", "50250"),
            ("แม่สาบ", "50250"),
            ("บ่อแก้ว", "50250"),
        ],
        "ฝาง": [
            ("ม่อนปิ่น", "50110"),
            ("สันทราย", "50110"),
        ],
        "แม่อาย": [
            ("แม่สาว", "50280"),
            ("สันต้นหมื้อ", "50280"),
            ("แม่นาวาง", "50280"),
            ("บ้านหลวง", "50280"),
            ("มะลิกา", "50280"),
        ],
        "พร้าว": [
            ("ทุ่งหลวง", "50190"),
            ("ป่าตุ้ม", "50190"),
            ("ป่าไหน่", "50190"),
            ("น้ำแพร่", "50190"),
            ("เขื่อนผาก", "50190"),
            ("โหล่งขอด", "50190"),
        ],
        "สันป่าตอง": [
            ("ยุหว่า", "50120"),
            ("ท่าวังพร้าว", "50120"),
            ("มะขามหลวง", "50120"),
            ("บ้านกลาง", "50120"),
            ("ทุ่งสะโตก", "50120"),
            ("ทุ่งต้อม", "50120"),
            ("น้ำบ่อหลวง", "50120"),
            ("มะขุนหวาน", "50120"),
        ],
        "สันกำแพง": [
            ("ออนใต้", "50130"),
            ("ห้วยทราย", "50130"),
            ("ต้นเปา", "50130"),
        ],
        "สันทราย": [
            ("สันพระเนตร", "50210"),
            ("สันป่าเปา", "50210"),
            ("หนองแหย่ง", "50210"),
            ("หนองจ๊อม", "50290"),
            ("หนองหาร", "50290"),
            ("แม่แฝก", "50290"),
            ("ป่าไผ่", "50210"),
        ],
        "หางดง": [
            ("หนองแก๋ว", "50230"),
            ("ขุนคง", "50230"),
            ("บ้านแหวน", "50230"),
        ],
        "ฮอด": [
            ("บ่อหลวง", "50240"),
        ],
        "ดอยเต่า": [
            ("ท่าเดื่อ", "50260"),
            ("มืดกา", "50260"),
            ("บ้านแอ่น", "50260"),
        ],
        "อมก๋อย": [
            ("อมก๋อย", "50310"),
            ("แม่ตื่น", "50310"),
            ("ม่อนจอง", "50310"),
            ("สบโขง", "50310"),
            ("นาเกียน", "50310"),
        ],
        "สารภี": [
            ("ชมภู", "50140"),
            ("ขัวมุง", "50140"),
            ("หนองผึ้ง", "50140"),
            ("ท่าวังตาล", "50140"),
        ],
        "เวียงแหง": [
            ("เมืองแหง", "50350"),
            ("เปียงหลวง", "50350"),
        ],
        "ไชยปราการ": [
            ("แม่ทะลบ", "50320"),
        ],
        "แม่วาง": [
            ("ทุ่งปี้", "50360"),
            ("ทุ่งรวงทอง", "50360"),
        ],
        "แม่ออน": [
            ("ออนกลาง", "50130"),
            ("บ้านสหกรณ์", "50130"),
            ("ห้วยแก้ว", "50130"),
            ("ทาเหนือ", "50130"),
        ],
        "ดอยหล่อ": [
            ("สองแคว", "50160"),
            ("สันติสุข", "50160"),
        ],
        "กัลยาณิวัฒนา": [
            ("บ้านจันทร์", "58130"),
            ("แจ่มหลวง", "58130"),
        ],
        "อมก๋อย": [
            ("แม่หลอง", "50310"),
        ]},
    "เพชรบุรี": {
        "เมืองเพชรบุรี": [
            ("นาพันสาม", "76000"),
            ("ธงชัย", "76000"),
            ("หนองโสน", "76000"),
            ("บางจาก", "76000"),
            ("บ้านหม้อ", "76000"),
            ("นาวุ้ง", "76000"),
            ("สำมะโรง", "76000"),
            ("หัวสะพาน", "76000"),
            ("โพไร่หวาน", "76000"),
            ("หนองพลับ", "76000"),
        ],
        "เขาย้อย": [
            ("สระพัง", "76140"),
            ("ทับคาง", "76140"),
            ("หนองปรง", "76140"),
            ("ห้วยโรง", "76140"),
            ("ห้วยท่าช้าง", "76140"),
        ],
        "หนองหญ้าปล้อง": [
            ("หนองหญ้าปล้อง", "76160"),
            ("ยางน้ำกลัดใต้", "76160"),
        ],
        "ชะอำ": [
            ("ชะอำ", "76120"),
            ("เขาใหญ่", "76120"),
            ("หนองศาลา", "76120"),
            ("สามพระยา", "76120"),
        ],
        "ท่ายาง": [
            ("ท่ายาง", "76130"),
            ("ท่าคอย", "76130"),
            ("ยางหย่อง", "76130"),
            ("หนองจอก", "76130"),
            ("วังไคร้", "76130"),
            ("กลัดหลวง", "76130"),
            ("ปึกเตียน", "76130"),
            ("บ้านในดง", "76130"),
        ],
        "บ้านลาด": [
            ("บ้านหาด", "76150"),
            ("ตำหรุ", "76150"),
            ("สมอพลือ", "76150"),
            ("หนองกระเจ็ด", "76150"),
            ("หนองกะปุ", "76150"),
            ("สะพานไกร", "76150"),
            ("ไร่โคก", "76150"),
            ("โรงเข้", "76150"),
            ("ท่าช้าง", "76150"),
        ],
        "บ้านแหลม": [
            ("บ้านแหลม", "76110"),
            ("บางตะบูน", "76110"),
            ("บางตะบูนออก", "76110"),
            ("ท่าแร้ง", "76110"),
        ],
        "แก่งกระจาน": [
            ("แก่งกระจาน", "76170"),
            ("ห้วยแม่เพรียง", "76170"),
        ],
        "เมืองเพชรบุรี": [
            ("ท่าราบ", "76000"),
            ("คลองกระแชง", "76000"),
            ("บางจาน", "76000"),
            ("บ้านกุ่ม", "76000"),
            ("ไร่ส้ม", "76000"),
            ("เวียงคอย", "76000"),
            ("ต้นมะม่วง", "76000"),
            ("ช่องสะแก", "76000"),
            ("โพพระ", "76000"),
            ("หาดเจ้าสำราญ", "76100"),
            ("ต้นมะพร้าว", "76000"),
            ("วังตะโก", "76000"),
            ("ดอนยาง", "76000"),
            ("หนองขนาน", "76000"),
            ("หนองขนาน", "76100"),
        ],
        "เขาย้อย": [
            ("เขาย้อย", "76140"),
            ("บางเค็ม", "76140"),
            ("หนองปลาไหล", "76140"),
            ("หนองชุมพล", "76140"),
            ("หนองชุมพลเหนือ", "76140"),
        ],
        "หนองหญ้าปล้อง": [
            ("ยางน้ำกลัดเหนือ", "76160"),
            ("ท่าตะคร้อ", "76160"),
        ],
        "ชะอำ": [
            ("บางเก่า", "76120"),
            ("นายาง", "76120"),
            ("ห้วยทรายเหนือ", "76120"),
            ("ไร่ใหม่พัฒนา", "76120"),
            ("ดอนขุนห้วย", "76120"),
        ],
        "ท่ายาง": [
            ("มาบปลาเค้า", "76130"),
            ("ท่าไม้รวก", "76130"),
            ("เขากระปุก", "76130"),
            ("ท่าแลง", "76130"),
        ],
        "บ้านลาด": [
            ("บ้านลาด", "76150"),
            ("บ้านทาน", "76150"),
            ("ไร่มะขาม", "76150"),
            ("ท่าเสน", "76150"),
            ("ลาดโพธิ์", "76150"),
            ("ไร่สะท้อน", "76150"),
            ("ห้วยข้อง", "76150"),
            ("ถ้ำรงค์", "76150"),
            ("ห้วยลึก", "76150"),
        ],
        "บ้านแหลม": [
            ("บางขุนไทร", "76110"),
            ("ปากทะเล", "76110"),
            ("บางแก้ว", "76110"),
            ("แหลมผักเบี้ย", "76100"),
            ("บางครก", "76110"),
            ("ท่าแร้งออก", "76110"),
        ],
        "แก่งกระจาน": [
            ("สองพี่น้อง", "76170"),
            ("วังจันทร์", "76170"),
            ("ป่าเด็ง", "76170"),
            ("พุสวรรค์", "76170"),
        ]},
    "เพชรบูรณ์": {
        "เมืองเพชรบูรณ์": [
            ("ในเมือง", "67000"),
            ("ป่าเลา", "67000"),
            ("บ้านโคก", "67000"),
            ("ชอนไพร", "67000"),
            ("นาป่า", "67000"),
            ("นายม", "67210"),
            ("ห้วยสะแก", "67210"),
        ],
        "ชนแดน": [
            ("ดงขุย", "67190"),
            ("ท่าข้าม", "67150"),
            ("พุทธบาท", "67150"),
            ("บ้านกล้วย", "67190"),
            ("ศาลาลาย", "67150"),
        ],
        "หล่มสัก": [
            ("ตาลเดี่ยว", "67110"),
            ("หนองสว่าง", "67110"),
            ("น้ำเฮี้ย", "67110"),
            ("สักหลง", "67110"),
            ("ท่าอิบุญ", "67110"),
            ("บ้านโสก", "67110"),
            ("บ้านติ้ว", "67110"),
            ("หนองไขว่", "67110"),
            ("บ้านไร่", "67110"),
            ("บ้านหวาย", "67110"),
        ],
        "หล่มเก่า": [
            ("บ้านเนิน", "67120"),
            ("ศิลา", "67120"),
            ("นาแซง", "67120"),
            ("วังบาล", "67120"),
            ("นาเกาะ", "67120"),
        ],
        "วิเชียรบุรี": [
            ("ท่าโรง", "67130"),
            ("โคกปรง", "67130"),
            ("น้ำร้อน", "67130"),
            ("บ่อรัง", "67130"),
            ("พุขาม", "67180"),
            ("ซับสมบูรณ์", "67180"),
            ("บึงกระจับ", "67130"),
            ("วังใหญ่", "67180"),
            ("ยางสาว", "67130"),
        ],
        "ศรีเทพ": [
            ("ศรีเทพ", "67170"),
            ("สระกรวด", "67170"),
            ("หนองย่างทอย", "67170"),
            ("ประดู่งาม", "67170"),
        ],
        "หนองไผ่": [
            ("กองทูล", "67140"),
            ("บ่อไทย", "67140"),
            ("ห้วยโป่ง", "67220"),
        ],
        "บึงสามพัน": [
            ("ซับสมอทอด", "67160"),
            ("กันจุ", "67160"),
            ("สระแก้ว", "67160"),
            ("บึงสามพัน", "67160"),
        ],
        "น้ำหนาว": [
            ("น้ำหนาว", "67260"),
            ("หลักด่าน", "67260"),
            ("โคกมน", "67260"),
        ],
        "วังโป่ง": [
            ("ซับเปิบ", "67240"),
            ("วังหิน", "67240"),
        ],
        "เขาค้อ": [
            ("ริมสีม่วง", "67270"),
            ("สะเดาะพง", "67270"),
            ("เข็กน้อย", "67280"),
        ],
        "เมืองเพชรบูรณ์": [
            ("ตะเบาะ", "67000"),
            ("บ้านโตก", "67000"),
            ("สะเดียง", "67000"),
            ("นางั่ว", "67000"),
            ("ท่าพล", "67250"),
            ("ดงมูลเหล็ก", "67000"),
            ("วังชมภู", "67210"),
            ("น้ำร้อน", "67000"),
            ("ห้วยใหญ่", "67000"),
            ("ระวิง", "67210"),
        ],
        "ชนแดน": [
            ("ชนแดน", "67150"),
            ("ลาดแค", "67150"),
            ("ซับพุทรา", "67150"),
            ("ตะกุดไร", "67190"),
        ],
        "หล่มสัก": [
            ("หล่มสัก", "67110"),
            ("วัดป่า", "67110"),
            ("ฝายนาแซง", "67110"),
            ("ห้วยไร่", "67110"),
            ("น้ำก้อ", "67110"),
            ("ปากช่อง", "67110"),
            ("น้ำชุน", "67110"),
            ("ลานบ่า", "67110"),
            ("บุ่งคล้า", "67110"),
            ("บุ่งน้ำเต้า", "67110"),
            ("บ้านกลาง", "67110"),
            ("ช้างตะลูด", "67110"),
            ("ปากดุก", "67110"),
        ],
        "หล่มเก่า": [
            ("หล่มเก่า", "67120"),
            ("นาซำ", "67120"),
            ("หินฮาว", "67120"),
            ("ตาดกลอย", "67120"),
        ],
        "วิเชียรบุรี": [
            ("สระประดู่", "67130"),
            ("สามแยก", "67130"),
            ("พุเตย", "67180"),
            ("ภูน้ำหยด", "67180"),
            ("ซับน้อย", "67180"),
        ],
        "ศรีเทพ": [
            ("คลองกระจัง", "67170"),
            ("นาสนุ่น", "67170"),
            ("โคกสะอาด", "67170"),
        ],
        "หนองไผ่": [
            ("นาเฉลียง", "67220"),
            ("บ้านโภชน์", "67140"),
            ("ท่าแดง", "67140"),
            ("เพชรละคร", "67140"),
            ("วังท่าดี", "67140"),
            ("บัววัฒนา", "67140"),
            ("หนองไผ่", "67140"),
            ("วังโบสถ์", "67140"),
            ("ยางงาม", "67220"),
            ("ท่าด้วง", "67140"),
        ],
        "บึงสามพัน": [
            ("ซับไม้แดง", "67160"),
            ("หนองแจง", "67160"),
            ("วังพิกุล", "67230"),
            ("พญาวัง", "67160"),
            ("ศรีมงคล", "67160"),
        ],
        "น้ำหนาว": [
            ("วังกวาง", "67260"),
        ],
        "วังโป่ง": [
            ("วังโป่ง", "67240"),
            ("ท้ายดง", "67240"),
            ("วังศาล", "67240"),
        ],
        "เขาค้อ": [
            ("ทุ่งสมอ", "67270"),
            ("แคมป์สน", "67280"),
            ("เขาค้อ", "67270"),
            ("หนองแม่นา", "67270"),
        ]},
    "เลย": {
        "เมืองเลย": [
            ("กุดป่อง", "42000"),
            ("นาอ้อ", "42100"),
            ("กกดู่", "42000"),
            ("นาโป่ง", "42000"),
            ("ชัยพฤกษ์", "42000"),
            ("นาแขม", "42000"),
        ],
        "นาด้วง": [
            ("ท่าสะอาด", "42210"),
        ],
        "เชียงคาน": [
            ("เชียงคาน", "42110"),
            ("ธาตุ", "42110"),
            ("นาซ่าว", "42110"),
            ("เขาแก้ว", "42110"),
            ("หาดทรายขาว", "42110"),
        ],
        "ปากชม": [
            ("เชียงกลม", "42150"),
            ("หาดคัมภีร์", "42150"),
            ("ห้วยบ่อซืน", "42150"),
        ],
        "ด่านซ้าย": [
            ("ด่านซ้าย", "42120"),
            ("ปากหมัน", "42120"),
        ],
        "นาแห้ว": [
            ("นาแห้ว", "42170"),
            ("แสงภา", "42170"),
            ("เหล่ากอหก", "42170"),
        ],
        "ภูเรือ": [
            ("หนองบัว", "42160"),
            ("ลาดค่าง", "42160"),
        ],
        "ท่าลี่": [
            ("ท่าลี่", "42140"),
            ("น้ำแคม", "42140"),
            ("น้ำทูน", "42140"),
        ],
        "วังสะพุง": [
            ("วังสะพุง", "42130"),
            ("ทรายขาว", "42130"),
            ("หนองงิ้ว", "42130"),
            ("ปากปวน", "42130"),
            ("เขาหลวง", "42130"),
            ("โคกขมิ้น", "42130"),
            ("ศรีสงคราม", "42130"),
        ],
        "ภูหลวง": [
            ("ภูหอ", "42230"),
            ("หนองคัน", "42230"),
            ("แก่งศรีภูมิ", "42230"),
        ],
        "ผาขาว": [
            ("ผาขาว", "42240"),
            ("โนนปอแดง", "42240"),
            ("บ้านเพิ่ม", "42240"),
        ],
        "เอราวัณ": [
            ("เอราวัณ", "42220"),
            ("ผาอินทร์แปลง", "42220"),
            ("ผาสามยอด", "42220"),
        ],
        "เมืองเลย": [
            ("เมือง", "42000"),
            ("น้ำหมาน", "42000"),
            ("เสี้ยว", "42000"),
            ("นาอาน", "42000"),
            ("นาดินดำ", "42000"),
            ("น้ำสวย", "42000"),
            ("ศรีสองรัก", "42100"),
            ("กกทอง", "42000"),
        ],
        "นาด้วง": [
            ("นาด้วง", "42210"),
            ("นาดอกคำ", "42210"),
            ("ท่าสวรรค์", "42210"),
        ],
        "เชียงคาน": [
            ("ปากตม", "42110"),
            ("บุฮม", "42110"),
            ("จอมศรี", "42110"),
        ],
        "ปากชม": [
            ("ปากชม", "42150"),
            ("ห้วยพิชัย", "42150"),
            ("ชมเจริญ", "42150"),
        ],
        "ด่านซ้าย": [
            ("นาดี", "42120"),
            ("โคกงาม", "42120"),
            ("โพนสูง", "42120"),
            ("อิปุ่ม", "42120"),
            ("กกสะทอน", "42120"),
            ("โป่ง", "42120"),
            ("วังยาว", "42120"),
            ("นาหอ", "42120"),
        ],
        "นาแห้ว": [
            ("นาพึง", "42170"),
            ("นามาลา", "42170"),
        ],
        "ภูเรือ": [
            ("ท่าศาลา", "42160"),
            ("ร่องจิก", "42160"),
            ("ปลาบ่า", "42160"),
            ("สานตม", "42160"),
        ],
        "ท่าลี่": [
            ("หนองผือ", "42140"),
            ("อาฮี", "42140"),
            ("โคกใหญ่", "42140"),
        ],
        "วังสะพุง": [
            ("หนองหญ้าปล้อง", "42130"),
            ("ผาน้อย", "42130"),
            ("ผาบิ้ง", "42130"),
        ],
        "ภูกระดึง": [
            ("ศรีฐาน", "42180"),
            ("ผานกเค้า", "42180"),
            ("ภูกระดึง", "42180"),
            ("ห้วยส้ม", "42180"),
        ],
        "ภูหลวง": [
            ("ห้วยสีเสียด", "42230"),
            ("เลยวังไสย์", "42230"),
        ],
        "ผาขาว": [
            ("ท่าช้างคล้อง", "42240"),
            ("โนนป่าซาง", "42240"),
        ],
        "เอราวัณ": [
            ("ทรัพย์ไพวัลย์", "42220"),
        ],
        "หนองหิน": [
            ("ตาดข่า", "42190"),
            ("หนองหิน", "42190"),
            ("ปวนพุ", "42190"),
        ]},
    "แพร่": {
        "เมืองแพร่": [
            ("น้ำชำ", "54000"),
            ("ป่าแดง", "54000"),
            ("เหมืองหม้อ", "54000"),
            ("แม่หล่าย", "54000"),
            ("ป่าแมต", "54000"),
            ("สวนเขื่อน", "54000"),
            ("แม่คำมี", "54000"),
            ("ทุ่งกวาว", "54000"),
            ("ช่อแฮ", "54000"),
        ],
        "ร้องกวาง": [
            ("ร้องเข็ม", "54140"),
            ("ทุ่งศรี", "54140"),
            ("แม่ยางฮ่อ", "54140"),
            ("ไผ่โทน", "54140"),
            ("ห้วยโรง", "54140"),
            ("แม่ทราย", "54140"),
            ("แม่ยางร้อง", "54140"),
        ],
        "ลอง": [
            ("ห้วยอ้อ", "54150"),
            ("บ้านปิน", "54150"),
            ("ต้าผามอก", "54150"),
            ("ปากกาง", "54150"),
        ],
        "สูงเม่น": [
            ("สูงเม่น", "54130"),
            ("หัวฝาย", "54130"),
            ("บ้านเหล่า", "54130"),
            ("บ้านกาศ", "54130"),
            ("ร่องกาศ", "54130"),
            ("สบสาย", "54130"),
            ("เวียงทอง", "54000"),
        ],
        "เด่นชัย": [
            ("เด่นชัย", "54110"),
            ("ห้วยไร่", "54110"),
        ],
        "สอง": [
            ("เตาปูน", "54120"),
            ("หัวเมือง", "54120"),
            ("แดนชุมพล", "54120"),
        ],
        "วังชิ้น": [
            ("วังชิ้น", "54160"),
            ("แม่ป้าก", "54160"),
            ("นาพูน", "54160"),
            ("แม่พุง", "54160"),
        ],
        "หนองม่วงไข่": [
            ("แม่คำมี", "54170"),
            ("น้ำรัด", "54170"),
            ("วังหลวง", "54170"),
            ("ตำหนักธรรม", "54170"),
            ("ทุ่งแค้ว", "54170"),
        ],
        "เมืองแพร่": [
            ("ในเวียง", "54000"),
            ("นาจักร", "54000"),
            ("ทุ่งโฮ้ง", "54000"),
            ("วังธง", "54000"),
            ("ห้วยม้า", "54000"),
            ("บ้านถิ่น", "54000"),
            ("วังหงษ์", "54000"),
            ("ท่าข้าม", "54000"),
            ("แม่ยม", "54000"),
            ("ร่องฟอง", "54000"),
            ("กาญจนา", "54000"),
        ],
        "ร้องกวาง": [
            ("ร้องกวาง", "54140"),
            ("น้ำเลา", "54140"),
            ("บ้านเวียง", "54140"),
            ("แม่ยางตาล", "54140"),
        ],
        "ลอง": [
            ("เวียงต้า", "54150"),
            ("หัวทุ่ง", "54150"),
            ("ทุ่งแล้ง", "54150"),
            ("บ่อเหล็กลอง", "54150"),
            ("แม่ปาน", "54150"),
        ],
        "สูงเม่น": [
            ("น้ำชำ", "54130"),
            ("ดอนมูล", "54130"),
            ("บ้านกวาง", "54130"),
            ("บ้านปง", "54130"),
            ("พระหลวง", "54130"),
        ],
        "เด่นชัย": [
            ("แม่จั๊วะ", "54110"),
            ("ไทรย้อย", "54110"),
            ("ปงป่าหวาย", "54110"),
        ],
        "สอง": [
            ("บ้านหนุน", "54120"),
            ("บ้านกลาง", "54120"),
            ("ห้วยหม้าย", "54120"),
            ("สะเอียบ", "54120"),
            ("ทุ่งน้าว", "54120"),
        ],
        "วังชิ้น": [
            ("สรอย", "54160"),
            ("ป่าสัก", "54160"),
            ("แม่เกิ๋ง", "54160"),
        ],
        "หนองม่วงไข่": [
            ("หนองม่วงไข่", "54170"),
        ]},
    "แม่ฮ่องสอน": {
        "เมืองแม่ฮ่องสอน": [
            ("ห้วยผา", "58000"),
        ],
        "ขุนยวม": [
            ("ขุนยวม", "58140"),
            ("เมืองปอน", "58140"),
        ],
        "ปาย": [
            ("เวียงเหนือ", "58130"),
            ("แม่ฮี้", "58130"),
            ("ทุ่งยาว", "58130"),
        ],
        "แม่สะเรียง": [
            ("แม่คง", "58110"),
            ("แม่ยวม", "58110"),
        ],
        "แม่ลาน้อย": [
            ("ห้วยห้อม", "58120"),
            ("แม่นาจาง", "58120"),
            ("ขุนแม่ลาน้อย", "58120"),
        ],
        "สบเมย": [
            ("ป่าโปง", "58110"),
            ("แม่สามแลบ", "58110"),
        ],
        "ปางมะผ้า": [
            ("สบป่อง", "58150"),
            ("นาปู่ป้อม", "58150"),
        ],
        "เมืองแม่ฮ่องสอน": [
            ("จองคำ", "58000"),
            ("ห้วยโป่ง", "58000"),
            ("ผาบ่อง", "58000"),
            ("ปางหมู", "58000"),
            ("หมอกจำแป่", "58000"),
            ("ห้วยปูลิง", "58000"),
        ],
        "ขุนยวม": [
            ("แม่เงา", "58140"),
            ("แม่ยวมน้อย", "58140"),
            ("แม่กิ๊", "58140"),
            ("แม่อูคอ", "58140"),
        ],
        "ปาย": [
            ("เวียงใต้", "58130"),
            ("แม่นาเติง", "58130"),
            ("เมืองแปง", "58130"),
            ("โป่งสา", "58130"),
        ],
        "แม่สะเรียง": [
            ("บ้านกาศ", "58110"),
            ("แม่สะเรียง", "58110"),
            ("แม่เหาะ", "58110"),
            ("เสาหิน", "58110"),
            ("ป่าแป๋", "58110"),
        ],
        "แม่ลาน้อย": [
            ("แม่ลาน้อย", "58120"),
            ("แม่ลาหลวง", "58120"),
            ("ท่าผาปุ้ม", "58120"),
            ("แม่โถ", "58120"),
            ("สันติคีรี", "58120"),
        ],
        "สบเมย": [
            ("สบเมย", "58110"),
            ("แม่คะตวน", "58110"),
            ("กองก๋อย", "58110"),
            ("แม่สวด", "58110"),
        ],
        "ปางมะผ้า": [
            ("ปางมะผ้า", "58150"),
            ("ถ้ำลอด", "58150"),
        ]}
}

# %% [markdown]
# # Tagging

# %%
from pythainlp import word_tokenize, Tokenizer
from pythainlp.util import dict_trie

text = "21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100"
print(f"Text: {text}")

custom_words_list = set(list(hashmap.keys()))
# print(f"Custom words list: {custom_words_list}")

trie = dict_trie(dict_source=custom_words_list)

custom_tokenizer = Tokenizer(custom_dict=trie, engine='newmm')

tokenized_text = custom_tokenizer.word_tokenize(text)

print("Custom tokenization: ", tokenized_text)

data = []
for token in tokenized_text:
    # print(token)
    if token in list(hashmap.keys()):
        data.append((token, hashmap[token]))

print(f"NER: {data}")
# Out:
# Text: 21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100
# Custom tokenization:  ['21', '-', '29', ' ', 'ถ', '.', 'นาคราช', ' ', 'แขวง', 'คลองมหานาค', ' ', 'เขต', 'ป้อมปราบศัตรูพ่าย', ' ', 'จ', '.', 'กรุงเทพ', ' ', '10100']
# NER: [('คลองมหานาค', 'DISTRICT'), ('ป้อมปราบศัตรูพ่าย', 'AMPHOE'), ('กรุงเทพ', 'PROVINCE'), ('10100', 'ZIPCODE')]

# %%
# !python -m pip uninstall pythainlp -y
# Out:
# Found existing installation: pythainlp 5.0.3
# Uninstalling pythainlp-5.0.3:
#   Successfully uninstalled pythainlp-5.0.3

# %%
# !pip install pythainlp==4.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 23.6 MB/s eta 0:00:00
# ...

# %%
import pythainlp
pythainlp.__version__
# Out:
# '4.0.0'

# %% [markdown]
# version 4.0.0

# %%
from pythainlp.tokenize import Tokenizer
from pythainlp.corpus.common import thai_words
from pythainlp.util import dict_trie

custom_words_list = set(thai_words())
custom_words_list.add('อะเฟเซีย')
custom_words_list.add('Aphasia')
trie = dict_trie(dict_source=custom_words_list)

text = "อะเฟเซีย (Aphasia*) เป็นอาการผิดปกติของการพูด"
_tokenizer = Tokenizer(custom_dict=trie, engine='newmm')
_tokenizer.word_tokenize(text)
# output: ['อะเฟเซีย', ' ', '(', 'Aphasia', ')', ' ', 'เป็น', 'อาการ',
# 'ผิดปกติ', 'ของ', 'การ', 'พูด']
# Out:
# ['อะเฟเซีย',
#  ' ',
#  '(',
#  'Aphasia',
#  '*)',
#  ' ',
#  'เป็น',
#  'อาการ',
#  'ผิดปกติ',
#  'ของ',
#  'การ',
#  'พูด']

# %% [markdown]
# version 5.0.3

# %%
from pythainlp.tokenize import Tokenizer
from pythainlp.corpus.common import thai_words
from pythainlp.util import dict_trie

custom_words_list = set(thai_words())
custom_words_list.add('อะเฟเซีย')
custom_words_list.add('Aphasia')
trie = dict_trie(dict_source=custom_words_list)

text = "อะเฟเซีย (Aphasia*) เป็นอาการผิดปกติของการพูด"
_tokenizer = Tokenizer(custom_dict=trie, engine='newmm')
_tokenizer.word_tokenize(text)
# output: ['อะเฟเซีย', ' ', '(', 'Aphasia', ')', ' ', 'เป็น', 'อาการ',
# 'ผิดปกติ', 'ของ', 'การ', 'พูด']
# Out:
# ['อะเฟเซีย',
#  ' ',
#  '(Aphasia*)',
#  ' ',
#  'เป็น',
#  'อาการ',
#  'ผิดปกติ',
#  'ของ',
#  'การ',
#  'พูด']

# %% [markdown]
# # Spellcheck

# %%
from pythainlp.util import dict_trie
custom_words_list = set(list(hashmap.keys()))
# print(f"Custom words list: {custom_words_list}")

trie = dict_trie(dict_source=custom_words_list)

# %%
max(len(w) for w in hashmap.keys())
# Out:
# 23

# %%
min(len(w) for w in hashmap.keys())
# Out:
# 2

# %%
from pythainlp.spell import NorvigSpellChecker
checker = NorvigSpellChecker(custom_dict=trie, min_freq=1, min_len=2, max_len=30)
len(checker.dictionary())
# Out:
# 6193

# %%
print(checker.correct("ปอมปาบศัตรูพ่าย"))
# Out:
# ป้อมปราบศัตรูพ่าย

# %%
print(checker.spell("ปอมปาบศัตรูพ่าย"))
# Out:
# ['ป้อมปราบศัตรูพ่าย']

# %%
print(checker.spell("ปอมปาบศ"))
# Out:
# ['ปอมปาบศ']

# %%
from pythainlp.corpus import ttc
thaicheck = NorvigSpellChecker(custom_dict=ttc.word_freqs(), min_freq=1, min_len=2, max_len=15)

# %%
thaicheck.correct("กุงเทพ")
# Out:
# 'กรุงเทพ'

# %%
thaicheck.freq("กรุงเทพ")
# Out:
# 218

# %%
thaicheck.known("กก")
# Out:
# []

# %%
thaicheck.spell("เจียง")
# Out:
# ['เสียง',
#  'เพียง',
#  'เรียง',
#  'เตียง',
#  'เถียง',
#  'เอียง',
#  'เคียง',
#  'เวียง',
#  'เฉียง',
#  'เจียว',
#  'เขียง',
#  'เจียม',
#  'เชียง',
#  'เจียน',
#  'เมียง',
#  'เลียง',
#  'เจียก',
#  'เจียด',
#  'เจียร',
#  'เจีย',
#  'เหียง',
#  'เจียงๆ',
#  'เนียง',
#  'เกียง',
#  'เทียง']

# %%
thaicheck.correct("ปอมปราบศัตรุพ่าย")
# Out:
# 'ปอมปราบศัตรุพ่าย'

# %%
thaicheck.spell("กวาา")
# Out:
# ['กว่า', 'กวาง', 'กวาด', 'กว้า', 'กวา']

# %% [markdown]
# # Address Tagging

# %% [markdown]
# import library

# %%
from pythainlp import word_tokenize, Tokenizer
from pythainlp.util import dict_trie
from pythainlp.spell import NorvigSpellChecker

# %% [markdown]
# create bag of words

# %%
custom_word_list = set(list(hashmap.keys()))
addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
custom_word_list.update(addtexts)
ctrie = dict_trie(dict_source=custom_word_list)
custom_tokenizer = Tokenizer(custom_dict=trie ,engine="newmm", join_broken_num=False)

# %% [markdown]
# tokenize texts

# %%
text = "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547"
tokenize_texts = custom_tokenizer.word_tokenize(text)
tokenize_texts
# Out:
# ['55',
#  ')30-12-62',
#  'นายเชิดชัยสมห',
#  'มาย',
#  '107',
#  '/1',
#  'หมู่',
#  '6',
#  'ซ.',
#  'หมู่',
#  'บ้าน',
#  'โรง',
#  'กุลี',
#  'ซอย',
#  '10',
#  'ถนน',
#  'มิตรภาพ',
#  'ต.',
#  'กลางดง',
#  'อำเภอ',
#  '/',
#  'ตำบล',
#  ':',
#  'ปากช่อง',
#  'จังหวัด',
#  ':',
#  'นครราชสีมา',
#  '30320',
#  'Tel',
#  '091',
#  '-',
#  '2719547']

# %% [markdown]
# spellchecker

# %%
checker = NorvigSpellChecker(custom_dict=ctrie, min_freq=1, min_len=5, max_len=30)
checker.correct("ปอปราบ")
# Out:
# 'สบปราบ'

# %%
checker.correct("ป้อปราบ")
# Out:
# 'ป้อมปราบ'

# %%
words = [checker.correct(token) for token in tokenize_texts if token not in addtexts]
words
# Out:
# ['55',
#  ')30-12-62',
#  'นายเชิดชัยสมห',
#  'ชะมาย',
#  '107',
#  '/1',
#  '6',
#  'บ้านชี',
#  'ปุโรง',
#  'กุลี',
#  '10',
#  'มิตรภาพ',
#  'กลางดง',
#  '/',
#  ':',
#  'ปากช่อง',
#  ':',
#  'นครราชสีมา',
#  '30320',
#  'Tel',
#  '091',
#  '-',
#  '2719547']

# %%
data = [(word, hashmap[word]) for word in words if word in list(hashmap.keys())]
data
# Out:
# [('ชะมาย', 'DISTRICT'),
#  ('บ้านชี', 'DISTRICT'),
#  ('ปุโรง', 'DISTRICT'),
#  ('มิตรภาพ', 'DISTRICT'),
#  ('กลางดง', 'DISTRICT'),
#  ('ปากช่อง', 'AMPHOE'),
#  ('นครราชสีมา', 'PROVINCE'),
#  ('30320', 'ZIPCODE')]

# %%
data = [(word, hashmap[word]) for word in words if word in list(hashmap.keys())]
data
# Out:
# [('ชะมาย', 'DISTRICT'),
#  ('บ้านชี', 'DISTRICT'),
#  ('ปุโรง', 'DISTRICT'),
#  ('มิตรภาพ', 'DISTRICT'),
#  ('กลางดง', 'DISTRICT'),
#  ('ปากช่อง', 'AMPHOE'),
#  ('นครราชสีมา', 'PROVINCE'),
#  ('30320', 'ZIPCODE')]

# %% [markdown]
# text = "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547"
# answer = (กลางดง, DISTRICT) (ปากช่อง, AMPHOE) (นครราชสีมา, PROVINCE) (30320, ZIPCODE)

# %%
province = []
amphoe = []
district = []
zipcode = []

for w, entity in data:
  if entity == "PROVINCE":
    province.append(w)
  elif entity == "AMPHOE":
    amphoe.append(w)
  elif entity == "DISTRICT":
    district.append(w)
  elif entity == "ZIPCODE":
    zipcode.append(w)

print(f"Province: {province}\nAmphoe: {amphoe}\nDistrict: {district}\nZipcode: {zipcode}")
# Out:
# Province: ['นครราชสีมา']
# Amphoe: ['ปากช่อง']
# District: ['ชะมาย', 'บ้านชี', 'ปุโรง', 'มิตรภาพ', 'กลางดง']
# Zipcode: ['30320']

# %%
checker.correct('กรุงเทพมหานคร')
# Out:
# 'กรุงเทพมหานคร'

# %%
import requests

url = 'http://localhost:5000/address/match'
data = {
    "province": "ชลบุรี",
    "amphoe": "เมืองชลบุรี",
    "district": "aa",
    "zipcode": "20130"
}

x = requests.get(url, json=data)
print(x.text)

# %%
from pythainlp import spell

# %%
spell("ป้อoปราบ")
# Out:
# ['ป้อoปราบ']

# %% [markdown]
# # Playground

# %%
pip install thaiaddress --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 17.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.2/216.2 kB 22.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 21.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.0 MB/s eta 0:00:00
# ...

# %%
import thaiaddress
thaiaddress.parse("คุณมานะ คงวุฒิปัญญา 123/676 087.442-5664 บางอค กทม ติดต่อ 9:00 - 15:00")
# Out:
# 3/3 [==============================] - 1s 17ms/step
# {'text': 'คุณมานะ คงวุฒิปัญญา 123/676 087.442-5664 บางอค กทม ติดต่อ 9:00 - 15:00',
#  'name': 'คุณมานะ คงวุฒิปัญญา',
#  'address': '123/676',
#  'location': 'บางอค กทม ติดต่อ 9:00',
#  'subdistrict': 'ศาลเจ้าพ่อเสือ',
#  'district': 'ดุสิต',
#  'province': 'กรุงเทพมหานคร',
#  'postal_code': '',
#  'phone_number': '0874425664',
#  'email': '15:00'}

# %%
import thaiaddress
thaiaddress.parse("นายปรายุ้ด จันทร์กะเพรา 099-999-9999 25/25 ถ.พุทธมณฑล สาย 4 ต. ศาลายา อ.พุทธมณฑล จ.นครปฐม 73170")
# Out:
# 3/3 [==============================] - 1s 24ms/step
# {'text': 'นายปรายุ้ด จันทร์กะเพรา 099-999-9999 25/25 ถ.พุทธมณฑล สาย 4 ต. ศาลายา อ.พุทธมณฑล จ.นครปฐม 73170',
#  'name': 'นายปรายุ้ด จันทร์กะเพรา',
#  'address': '25/25 ถ.พุทธมณฑล สาย 4',
#  'location': 'ต. ศาลายา อ.พุทธมณฑล จ.นครปฐม',
#  'subdistrict': 'ศาลายา',
#  'district': 'พุทธมณฑล',
#  'province': 'นครปฐม',
#  'postal_code': '73170',
#  'phone_number': '0999999999',
#  'email': ''}

# %%
thaiaddress.parse("55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547")
# Out:
# 5/5 [==============================] - 0s 21ms/step
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# {'text': '5530-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547',
#  'name': '',
#  'address': '5530-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพ',
#  'location': 'ต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด',
#  'subdistrict': 'กลางดง',
#  'district': 'ปากช่อง',
#  'province': 'กรุงเทพมหานคร',
#  'postal_code': '30320',
#  'phone_number': '0912719547',
#  'email': ''}

# %%
thaiaddress.parse("55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547")
# Out:
# 5/5 [==============================] - 0s 25ms/step
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# {'text': '5530-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547',
#  'name': '',
#  'address': '5530-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพ',
#  'location': 'ต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด',
#  'subdistrict': 'บางมด',
#  'district': 'ดุสิต',
#  'province': 'กรุงเทพมหานคร',
#  'postal_code': '',
#  'phone_number': '303200912719547',
#  'email': ''}

# %%
thaiaddress.parse("21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100")
# Out:
# 3/3 [==============================] - 0s 10ms/step
# {'text': '21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100',
#  'name': '',
#  'address': '',
#  'location': 'ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ',
#  'subdistrict': 'คลองมหานาค',
#  'district': 'ป้อมปราบศัตรูพ่าย',
#  'province': 'กรุงเทพมหานคร',
#  'postal_code': '10100',
#  'phone_number': '',
#  'email': ''}

# %%
thaiaddress.parse("21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบ จ.กรุงเทพ 10100")
# Out:
# 2/2 [==============================] - 0s 13ms/step
# {'text': '21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบ จ.กรุงเทพ 10100',
#  'name': '',
#  'address': '',
#  'location': 'ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบ จ.กรุงเทพ',
#  'subdistrict': 'คลองมหานาค',
#  'district': 'ป้อมปราบศัตรูพ่าย',
#  'province': 'กรุงเทพมหานคร',
#  'postal_code': '10100',
#  'phone_number': '',
#  'email': ''}

# %%
thaiaddress.parse("21-29 ถ.นาคราช แขวงป้อมปราบ เขตบางนา จ.กรุงเทพ")
# Out:
# 2/2 [==============================] - 0s 11ms/step
# {'text': '21-29 ถ.นาคราช แขวงป้อมปราบ เขตบางนา จ.กรุงเทพ',
#  'name': '',
#  'address': '',
#  'location': 'ถ.นาคราช แขวงป้อมปราบ เขตบางนา จ.กรุงเทพ',
#  'subdistrict': 'ป้อมปราบ',
#  'district': 'บางนา',
#  'province': 'กรุงเทพมหานคร',
#  'postal_code': '',
#  'phone_number': '',
#  'email': ''}

# %%
thaiaddress.parse("680 ถ.สุขมุวิท ต.บางปลาสร้อย อ.เมือง จ.ชลบุรี 20000")
# Out:
# 2/2 [==============================] - 0s 18ms/step
# {'text': '680 ถ.สุขมุวิท ต.บางปลาสร้อย อ.เมือง จ.ชลบุรี 20000',
#  'name': '680 ถ.สุขมุวิท',
#  'address': '',
#  'location': 'ต.บางปลาสร้อย อ.เมือง จ.ชลบุรี',
#  'subdistrict': 'บางปลาสร้อย',
#  'district': 'เมืองชลบุรี',
#  'province': 'ชลบุรี',
#  'postal_code': '20000',
#  'phone_number': '',
#  'email': ''}

# %%
province_list = [
  'กระบี่',
  'กรุงเทพ',
  'กาญจนบุรี',
  'กาฬสินธุ์',
  'กำแพงเพชร',
  'ขอนแก่น',
  'จันทบุรี',
  'ฉะเชิงเทรา',
  'ชลบุรี',
  'ชัยนาท',
  'ชัยภูมิ',
  'ชุมพร',
  'ตรัง',
  'ตราด',
  'ตาก',
  'นครนายก',
  'นครปฐม',
  'นครพนม',
  'นครราชสีมา',
  'นครศรีธรรมราช',
  'นครสวรรค์',
  'นนทบุรี',
  'นราธิวาส',
  'น่าน',
  'บึงกาฬ',
  'บุรีรัมย์',
  'ปทุมธานี',
  'ประจวบคีรีขันธ์',
  'ปราจีนบุรี',
  'ปัตตานี',
  'พระนครศรีอยุธยา',
  'พะเยา',
  'พังงา',
  'พัทลุง',
  'พิจิตร',
  'พิษณุโลก',
  'ภูเก็ต',
  'มหาสารคาม',
  'มุกดาหาร',
  'ยะลา',
  'ยโสธร',
  'ระนอง',
  'ระยอง',
  'ราชบุรี',
  'ร้อยเอ็ด',
  'ลพบุรี',
  'ลำปาง',
  'ลำพูน',
  'ศรีสะเกษ',
  'สกลนคร',
  'สงขลา',
  'สตูล',
  'สมุทรปราการ',
  'สมุทรสงคราม',
  'สมุทรสาคร',
  'สระบุรี',
  'สระแก้ว',
  'สิงห์บุรี',
  'สุพรรณบุรี',
  'สุราษฎร์ธานี',
  'สุรินทร์',
  'สุโขทัย',
  'หนองคาย',
  'หนองบัวลำภู',
  'อำนาจเจริญ',
  'อุดรธานี',
  'อุตรดิตถ์',
  'อุทัยธานี',
  'อุบลราชธานี',
  'อ่างทอง',
  'เชียงราย',
  'เชียงใหม่',
  'เพชรบุรี',
  'เพชรบูรณ์',
  'เลย',
  'แพร่',
  'แม่ฮ่องสอน'
]


amphoe_list = [
  'กงหรา',
  'กงไกรลาศ',
  'กบินทร์บุรี',
  'กมลาไสย',
  'กรงปินัง',
  'กระทุ่มแบน',
  'กระนวน',
  'กระบุรี',
  'กระสัง',
  'กระแสสินธุ์',
  'กะทู้',
  'กะปง',
  'กะพ้อ',
  'กะเปอร์',
  'กันตัง',
  'กันทรลักษ์',
  'กันทรวิชัย',
  'กันทรารมย์',
  'กัลยาณิวัฒนา',
  'กาญจนดิษฐ์',
  'กาบัง',
  'กาบเชิง',
  'กำแพงแสน',
  'กุฉินารายณ์',
  'กุดข้าวปุ้น',
  'กุดจับ',
  'กุดชุม',
  'กุดบาก',
  'กุดรัง',
  'กุมภวาปี',
  'กุยบุรี',
  'กุสุมาลย์',
  'กู่แก้ว',
  'ขนอม',
  'ขลุง',
  'ขาณุวรลักษบุรี',
  'ขามทะเลสอ',
  'ขามสะแกแสง',
  'ขุขันธ์',
  'ขุนตาล',
  'ขุนยวม',
  'ขุนหาญ',
  'คง',
  'ครบุรี',
  'คลองขลุง',
  'คลองท่อม',
  'คลองลาน',
  'คลองสาน',
  'คลองสามวา',
  'คลองหลวง',
  'คลองหอยโข่ง',
  'คลองหาด',
  'คลองเขื่อน',
  'คลองเตย',
  'คลองใหญ่',
  'ควนกาหลง',
  'ควนขนุน',
  'ควนเนียง',
  'ควนโดน',
  'คอนสวรรค์',
  'คอนสาร',
  'คันนายาว',
  'คำชะอี',
  'คำตากล้า',
  'คำม่วง',
  'คำเขื่อนแก้ว',
  'คีรีมาศ',
  'คีรีรัฐนิคม',
  'คุระบุรี',
  'คูเมือง',
  'ค่ายบางระจัน',
  'ค้อวัง',
  'ฆ้องชัย',
  'งาว',
  'จตุจักร',
  'จตุรพักตรพิมาน',
  'จอมทอง',
  'จอมบึง',
  'จอมพระ',
  'จะนะ',
  'จะแนะ',
  'จักราช',
  'จังหาร',
  'จัตุรัส',
  'จุน',
  'จุฬาภรณ์',
  'ฉวาง',
  'ชนบท',
  'ชนแดน',
  'ชะอวด',
  'ชะอำ',
  'ชัยบาดาล',
  'ชัยบุรี',
  'ชาติตระการ',
  'ชานุมาน',
  'ชำนิ',
  'ชื่นชม',
  'ชุมตาบง',
  'ชุมพลบุรี',
  'ชุมพวง',
  'ชุมแพ',
  'ชุมแสง',
  'ช้างกลาง',
  'ซับใหญ่',
  'ซำสูง',
  'ดงหลวง',
  'ดงเจริญ',
  'ดอกคำใต้',
  'ดอนจาน',
  'ดอนตาล',
  'ดอนตูม',
  'ดอนพุด',
  'ดอนมดแดง',
  'ดอนสัก',
  'ดอนเจดีย์',
  'ดอนเมือง',
  'ดอยสะเก็ด',
  'ดอยหลวง',
  'ดอยหล่อ',
  'ดอยเต่า',
  'ดำเนินสะดวก',
  'ดินแดง',
  'ดุสิต',
  'ด่านขุนทด',
  'ด่านช้าง',
  'ด่านซ้าย',
  'ด่านมะขามเตี้ย',
  'ตรอน',
  'ตระการพืชผล',
  'ตลิ่งชัน',
  'ตะกั่วทุ่ง',
  'ตะกั่วป่า',
  'ตะพานหิน',
  'ตะโหมด',
  'ตากฟ้า',
  'ตากใบ',
  'ตาคลี',
  'ตาพระยา',
  'ตาลสุม',
  'ถลาง',
  'ถ้ำพรรณรา',
  'ทรายทองวัฒนา',
  'ทรายมูล',
  'ทวีวัฒนา',
  'ทองผาภูมิ',
  'ทองแสนขัน',
  'ทับคล้อ',
  'ทับปุด',
  'ทับสะแก',
  'ทัพทัน',
  'ทุ่งครุ',
  'ทุ่งช้าง',
  'ทุ่งตะโก',
  'ทุ่งฝน',
  'ทุ่งยางแดง',
  'ทุ่งศรีอุดม',
  'ทุ่งสง',
  'ทุ่งหว้า',
  'ทุ่งหัวช้าง',
  'ทุ่งเขาหลวง',
  'ทุ่งเสลี่ยม',
  'ทุ่งใหญ่',
  'ท่าคันโท',
  'ท่าฉาง',
  'ท่าชนะ',
  'ท่าช้าง',
  'ท่าตะเกียบ',
  'ท่าตะโก',
  'ท่าตูม',
  'ท่าบ่อ',
  'ท่าปลา',
  'ท่ามะกา',
  'ท่าม่วง',
  'ท่ายาง',
  'ท่าลี่',
  'ท่าวังผา',
  'ท่าวุ้ง',
  'ท่าศาลา',
  'ท่าสองยาง',
  'ท่าหลวง',
  'ท่าอุเทน',
  'ท่าเรือ',
  'ท่าแซะ',
  'ท่าแพ',
  'ท่าใหม่',
  'ท้ายเหมือง',
  'ธนบุรี',
  'ธวัชบุรี',
  'ธัญบุรี',
  'ธาตุพนม',
  'ธารโต',
  'นครชัยศรี',
  'นครหลวง',
  'นครไทย',
  'นบพิตำ',
  'นากลาง',
  'นาคู',
  'นางรอง',
  'นาจะหลวย',
  'นาดี',
  'นาดูน',
  'นาด้วง',
  'นาตาล',
  'นาทม',
  'นาทวี',
  'นาน้อย',
  'นาบอน',
  'นามน',
  'นายายอาม',
  'นายูง',
  'นาวัง',
  'นาหมื่น',
  'นาหม่อม',
  'นาหว้า',
  'นาเชือก',
  'นาเยีย',
  'นาแก',
  'นาแห้ว',
  'นาโพธิ์',
  'นาโยง',
  'นิคมคำสร้อย',
  'นิคมน้ำอูน',
  'นิคมพัฒนา',
  'น้ำขุ่น',
  'น้ำปาด',
  'น้ำพอง',
  'น้ำยืน',
  'น้ำหนาว',
  'น้ำเกลี้ยง',
  'น้ำโสม',
  'บรบือ',
  'บรรพตพิสัย',
  'บันนังสตา',
  'บัวลาย',
  'บัวเชด',
  'บัวใหญ่',
  'บางกรวย',
  'บางกระทุ่ม',
  'บางกล่ำ',
  'บางกอกน้อย',
  'บางกอกใหญ่',
  'บางกะปิ',
  'บางขัน',
  'บางขุนเทียน',
  'บางคนที',
  'บางคล้า',
  'บางคอแหลม',
  'บางซื่อ',
  'บางซ้าย',
  'บางนา',
  'บางน้ำเปรี้ยว',
  'บางบอน',
  'บางบัวทอง',
  'บางบาล',
  'บางบ่อ',
  'บางปลาม้า',
  'บางปะกง',
  'บางปะหัน',
  'บางปะอิน',
  'บางพลัด',
  'บางพลี',
  'บางมูลนาก',
  'บางระกำ',
  'บางระจัน',
  'บางรัก',
  'บางละมุง',
  'บางสะพาน',
  'บางสะพานน้อย',
  'บางเขน',
  'บางเลน',
  'บางเสาธง',
  'บางแก้ว',
  'บางแค',
  'บางแพ',
  'บางใหญ่',
  'บางไทร',
  'บาเจาะ',
  'บำเหน็จณรงค์',
  'บึงกุ่ม',
  'บึงนาราง',
  'บึงบูรพ์',
  'บึงสามพัน',
  'บึงสามัคคี',
  'บึงโขงหลง',
  'บุณฑริก',
  'บุ่งคล้า',
  'บ่อทอง',
  'บ่อพลอย',
  'บ่อเกลือ',
  'บ่อไร่',
  'บ้านกรวด',
  'บ้านคา',
  'บ้านค่าย',
  'บ้านฉาง',
  'บ้านดุง',
  'บ้านด่าน',
  'บ้านด่านลานหอย',
  'บ้านตาก',
  'บ้านตาขุน',
  'บ้านธิ',
  'บ้านนา',
  'บ้านนาสาร',
  'บ้านนาเดิม',
  'บ้านบึง',
  'บ้านผือ',
  'บ้านฝาง',
  'บ้านม่วง',
  'บ้านลาด',
  'บ้านสร้าง',
  'บ้านหมอ',
  'บ้านหมี่',
  'บ้านหลวง',
  'บ้านเขว้า',
  'บ้านเหลื่อม',
  'บ้านแท่น',
  'บ้านแพง',
  'บ้านแพรก',
  'บ้านแพ้ว',
  'บ้านแหลม',
  'บ้านแฮด',
  'บ้านโคก',
  'บ้านโป่ง',
  'บ้านโพธิ์',
  'บ้านโฮ่ง',
  'บ้านใหม่ไชยพจน์',
  'บ้านไผ่',
  'บ้านไร่',
  'ปง',
  'ปทุมรัตน์',
  'ปทุมราชวงศา',
  'ปทุมวัน',
  'ประจักษ์ศิลปาคม',
  'ประจันตคาม',
  'ประทาย',
  'ประเวศ',
  'ประโคนชัย',
  'ปรางค์กู่',
  'ปราณบุรี',
  'ปราสาท',
  'ปลวกแดง',
  'ปลาปาก',
  'ปลายพระยา',
  'ปะคำ',
  'ปะทิว',
  'ปะนาเระ',
  'ปะเหลียน',
  'ปักธงชัย',
  'ปัว',
  'ปากคาด',
  'ปากชม',
  'ปากช่อง',
  'ปากท่อ',
  'ปากพนัง',
  'ปากพลี',
  'ปากพะยูน',
  'ปากเกร็ด',
  'ปางมะผ้า',
  'ปางศิลาทอง',
  'ปาย',
  'ป่าซาง',
  'ป่าติ้ว',
  'ป่าบอน',
  'ป่าพะยอม',
  'ป่าแดด',
  'ป่าโมก',
  'ป้อมปราบศัตรูพ่าย',
  'ผักไห่',
  'ผาขาว',
  'ฝาง',
  'พญาเม็งราย',
  'พญาไท',
  'พนม',
  'พนมดงรัก',
  'พนมทวน',
  'พนมสารคาม',
  'พนมไพร',
  'พนัสนิคม',
  'พนา',
  'พบพระ',
  'พยัคฆภูมิพิสัย',
  'พยุหะคีรี',
  'พยุห์',
  'พรรณานิคม',
  'พรหมคีรี',
  'พรหมบุรี',
  'พรหมพิราม',
  'พระทองคำ',
  'พระนคร',
  'พระนครศรีอยุธยา',
  'พระประแดง',
  'พระพรหม',
  'พระพุทธบาท',
  'พระยืน',
  'พระสมุทรเจดีย์',
  'พระแสง',
  'พระโขนง',
  'พรานกระต่าย',
  'พรเจริญ',
  'พร้าว',
  'พล',
  'พลับพลาชัย',
  'พะโต๊ะ',
  'พังโคน',
  'พัฒนานิคม',
  'พาน',
  'พานทอง',
  'พิชัย',
  'พิบูลมังสาหาร',
  'พิบูลย์รักษ์',
  'พิปูน',
  'พิมาย',
  'พุทธมณฑล',
  'พุทไธสง',
  'พุนพิน',
  'ฟากท่า',
  'ภักดีชุมพล',
  'ภาชี',
  'ภาษีเจริญ',
  'ภูกระดึง',
  'ภูกามยาว',
  'ภูซาง',
  'ภูผาม่าน',
  'ภูพาน',
  'ภูสิงห์',
  'ภูหลวง',
  'ภูเขียว',
  'ภูเพียง',
  'ภูเรือ',
  'ภูเวียง',
  'มวกเหล็ก',
  'มหาชนะชัย',
  'มหาราช',
  'มะขาม',
  'มะนัง',
  'มัญจาคีรี',
  'มายอ',
  'มีนบุรี',
  'มโนรมย์',
  'ม่วงสามสิบ',
  'ยะรัง',
  'ยะหริ่ง',
  'ยะหา',
  'ยางชุมน้อย',
  'ยางตลาด',
  'ยางสีสุราช',
  'ยานนาวา',
  'ยี่งอ',
  'ย่านตาขาว',
  'ระแงะ',
  'ระโนด',
  'รัตนบุรี',
  'รัตนวาปี',
  'รัตภูมิ',
  'รัษฎา',
  'ราชสาส์น',
  'ราชเทวี',
  'รามัน',
  'ราษฎร์บูรณะ',
  'ราษีไศล',
  'รือเสาะ',
  'ร่องคำ',
  'ร่อนพิบูลย์',
  'ร้องกวาง',
  'ลอง',
  'ละงู',
  'ละหานทราย',
  'ละอุ่น',
  'ละแม',
  'ลับแล',
  'ลาดกระบัง',
  'ลาดบัวหลวง',
  'ลาดพร้าว',
  'ลาดยาว',
  'ลาดหลุมแก้ว',
  'ลานกระบือ',
  'ลานสกา',
  'ลานสัก',
  'ลำดวน',
  'ลำทะเมนชัย',
  'ลำทับ',
  'ลำปลายมาศ',
  'ลำลูกกา',
  'ลำสนธิ',
  'ลี้',
  'ลืออำนาจ',
  'วชิรบารมี',
  'วังจันทร์',
  'วังชิ้น',
  'วังทรายพูน',
  'วังทอง',
  'วังทองหลาง',
  'วังน้อย',
  'วังน้ำเขียว',
  'วังน้ำเย็น',
  'วังม่วง',
  'วังยาง',
  'วังวิเศษ',
  'วังสมบูรณ์',
  'วังสะพุง',
  'วังสามหมอ',
  'วังหิน',
  'วังเจ้า',
  'วังเหนือ',
  'วังโป่ง',
  'วัฒนา',
  'วัฒนานคร',
  'วัดสิงห์',
  'วัดเพลง',
  'วัดโบสถ์',
  'วานรนิวาส',
  'วาปีปทุม',
  'วาริชภูมิ',
  'วารินชำราบ',
  'วิภาวดี',
  'วิหารแดง',
  'วิเชียรบุรี',
  'วิเศษชัยชาญ',
  'ศรีณรงค์',
  'ศรีธาตุ',
  'ศรีนคร',
  'ศรีนครินทร์',
  'ศรีบรรพต',
  'ศรีบุญเรือง',
  'ศรีประจันต์',
  'ศรีมหาโพธิ',
  'ศรีมโหสถ',
  'ศรีรัตนะ',
  'ศรีราชา',
  'ศรีวิไล',
  'ศรีสงคราม',
  'ศรีสมเด็จ',
  'ศรีสวัสดิ์',
  'ศรีสัชนาลัย',
  'ศรีสาคร',
  'ศรีสำโรง',
  'ศรีเชียงใหม่',
  'ศรีเทพ',
  'ศรีเมืองใหม่',
  'ศิลาลาด',
  'ศีขรภูมิ',
  'สตึก',
  'สทิงพระ',
  'สนม',
  'สนามชัยเขต',
  'สบปราบ',
  'สบเมย',
  'สมเด็จ',
  'สรรคบุรี',
  'สรรพยา',
  'สระโบสถ์',
  'สระใคร',
  'สร้างคอม',
  'สวนผึ้ง',
  'สวนหลวง',
  'สวรรคโลก',
  'สวี',
  'สว่างวีระวงศ์',
  'สว่างอารมณ์',
  'สว่างแดนดิน',
  'สหัสขันธ์',
  'สอง',
  'สองพี่น้อง',
  'สองแคว',
  'สอยดาว',
  'สะบ้าย้อย',
  'สะพานสูง',
  'สะเดา',
  'สะเมิง',
  'สังขละบุรี',
  'สังขะ',
  'สังคม',
  'สัตหีบ',
  'สันกำแพง',
  'สันติสุข',
  'สันทราย',
  'สันป่าตอง',
  'สัมพันธวงศ์',
  'สากเหล็ก',
  'สาทร',
  'สามง่าม',
  'สามชัย',
  'สามชุก',
  'สามพราน',
  'สามร้อยยอด',
  'สามเงา',
  'สามโก้',
  'สามโคก',
  'สายบุรี',
  'สายไหม',
  'สารภี',
  'สำโรง',
  'สำโรงทาบ',
  'สิงหนคร',
  'สิชล',
  'สิรินธร',
  'สิเกา',
  'สีคิ้ว',
  'สีชมพู',
  'สีดา',
  'สุขสำราญ',
  'สุคิริน',
  'สุวรรณคูหา',
  'สุวรรณภูมิ',
  'สุไหงปาดี',
  'สุไหงโก-ลก',
  'สูงเนิน',
  'สูงเม่น',
  'ส่องดาว',
  'หนองกี่',
  'หนองกุงศรี',
  'หนองขาหย่าง',
  'หนองจอก',
  'หนองจิก',
  'หนองฉาง',
  'หนองนาคำ',
  'หนองบัว',
  'หนองบัวระเหว',
  'หนองบัวแดง',
  'หนองบุญมาก',
  'หนองปรือ',
  'หนองพอก',
  'หนองมะโมง',
  'หนองม่วง',
  'หนองม่วงไข่',
  'หนองวัวซอ',
  'หนองสองห้อง',
  'หนองสูง',
  'หนองหงส์',
  'หนองหญ้าปล้อง',
  'หนองหญ้าไซ',
  'หนองหาน',
  'หนองหิน',
  'หนองฮี',
  'หนองเรือ',
  'หนองเสือ',
  'หนองแขม',
  'หนองแค',
  'หนองแซง',
  'หนองแสง',
  'หนองโดน',
  'หนองใหญ่',
  'หนองไผ่',
  'หลักสี่',
  'หลังสวน',
  'หล่มสัก',
  'หล่มเก่า',
  'หว้านใหญ่',
  'หันคา',
  'หัวตะพาน',
  'หัวหิน',
  'หัวไทร',
  'หางดง',
  'หาดสำราญ',
  'หาดใหญ่',
  'ห้วยกระเจา',
  'ห้วยขวาง',
  'ห้วยคต',
  'ห้วยทับทัน',
  'ห้วยผึ้ง',
  'ห้วยยอด',
  'ห้วยราช',
  'ห้วยเม็ก',
  'ห้วยแถลง',
  'ห้างฉัตร',
  'องครักษ์',
  'อมก๋อย',
  'อรัญประเทศ',
  'อัมพวา',
  'อากาศอำนวย',
  'อาจสามารถ',
  'อินทร์บุรี',
  'อุทัย',
  'อุทุมพรพิสัย',
  'อุบลรัตน์',
  'อุ้มผาง',
  'อู่ทอง',
  'อ่าวลึก',
  'ฮอด',
  'เกษตรวิสัย',
  'เกษตรสมบูรณ์',
  'เกาะกูด',
  'เกาะคา',
  'เกาะจันทร์',
  'เกาะช้าง',
  'เกาะพะงัน',
  'เกาะยาว',
  'เกาะลันตา',
  'เกาะสมุย',
  'เกาะสีชัง',
  'เก้าเลี้ยว',
  'เขมราฐ',
  'เขวาสินรินทร์',
  'เขาคิชฌกูฏ',
  'เขาค้อ',
  'เขาฉกรรจ์',
  'เขาชะเมา',
  'เขาชัยสน',
  'เขาพนม',
  'เขาย้อย',
  'เขาวง',
  'เขาสมิง',
  'เขาสวนกวาง',
  'เขื่องใน',
  'เคียนซา',
  'เจริญศิลป์',
  'เจาะไอร้อง',
  'เฉลิมพระเกียรติ',
  'เชียงกลาง',
  'เชียงขวัญ',
  'เชียงของ',
  'เชียงคาน',
  'เชียงคำ',
  'เชียงดาว',
  'เชียงม่วน',
  'เชียงยืน',
  'เชียงแสน',
  'เชียรใหญ่',
  'เซกา',
  'เดชอุดม',
  'เดิมบางนางบวช',
  'เด่นชัย',
  'เต่างอย',
  'เถิน',
  'เทพสถิต',
  'เทพา',
  'เทพารักษ์',
  'เทิง',
  'เนินขาม',
  'เนินมะปราง',
  'เนินสง่า',
  'เบญจลักษ์',
  'เบตง',
  'เปือยน้อย',
  'เฝ้าไร่',
  'เพ็ญ',
  'เมยวดี',
  'เมือง',
  'เมืองกระบี่',
  'เมืองกาญจนบุรี',
  'เมืองกาฬสินธุ์',
  'เมืองกำแพงเพชร',
  'เมืองขอนแก่น',
  'เมืองจันทบุรี',
  'เมืองจันทร์',
  'เมืองฉะเชิงเทรา',
  'เมืองชลบุรี',
  'เมืองชัยนาท',
  'เมืองชัยภูมิ',
  'เมืองชุมพร',
  'เมืองตรัง',
  'เมืองตราด',
  'เมืองตาก',
  'เมืองนครนายก',
  'เมืองนครปฐม',
  'เมืองนครพนม',
  'เมืองนครราชสีมา',
  'เมืองนครศรีธรรมราช',
  'เมืองนครสวรรค์',
  'เมืองนนทบุรี',
  'เมืองนราธิวาส',
  'เมืองน่าน',
  'เมืองบึงกาฬ',
  'เมืองบุรีรัมย์',
  'เมืองปทุมธานี',
  'เมืองประจวบคีรีขันธ์',
  'เมืองปราจีนบุรี',
  'เมืองปัตตานี',
  'เมืองปาน',
  'เมืองพะเยา',
  'เมืองพังงา',
  'เมืองพัทลุง',
  'เมืองพิจิตร',
  'เมืองพิษณุโลก',
  'เมืองภูเก็ต',
  'เมืองมหาสารคาม',
  'เมืองมุกดาหาร',
  'เมืองยะลา',
  'เมืองยาง',
  'เมืองยโสธร',
  'เมืองระนอง',
  'เมืองระยอง',
  'เมืองราชบุรี',
  'เมืองร้อยเอ็ด',
  'เมืองลพบุรี',
  'เมืองลำปาง',
  'เมืองลำพูน',
  'เมืองศรีสะเกษ',
  'เมืองสกลนคร',
  'เมืองสงขลา',
  'เมืองสตูล',
  'เมืองสมุทรปราการ',
  'เมืองสมุทรสงคราม',
  'เมืองสมุทรสาคร',
  'เมืองสรวง',
  'เมืองสระบุรี',
  'เมืองสระแก้ว',
  'เมืองสิงห์บุรี',
  'เมืองสุพรรณบุรี',
  'เมืองสุราษฎร์ธานี',
  'เมืองสุรินทร์',
  'เมืองสุโขทัย',
  'เมืองหนองคาย',
  'เมืองหนองบัวลำภู',
  'เมืองอำนาจเจริญ',
  'เมืองอุดรธานี',
  'เมืองอุตรดิตถ์',
  'เมืองอุทัยธานี',
  'เมืองอุบลราชธานี',
  'เมืองอ่างทอง',
  'เมืองเชียงราย',
  'เมืองเชียงใหม่',
  'เมืองเพชรบุรี',
  'เมืองเพชรบูรณ์',
  'เมืองเลย',
  'เมืองแพร่',
  'เมืองแม่ฮ่องสอน',
  'เรณูนคร',
  'เลาขวัญ',
  'เลิงนกทา',
  'เวียงชัย',
  'เวียงป่าเป้า',
  'เวียงสระ',
  'เวียงสา',
  'เวียงหนองล่อง',
  'เวียงเก่า',
  'เวียงเชียงรุ้ง',
  'เวียงแก่น',
  'เวียงแหง',
  'เสนา',
  'เสนางคนิคม',
  'เสริมงาม',
  'เสลภูมิ',
  'เสาไห้',
  'เสิงสาง',
  'เหนือคลอง',
  'เหล่าเสือโก้ก',
  'เอราวัณ',
  'แกดำ',
  'แกลง',
  'แก่งกระจาน',
  'แก่งคอย',
  'แก่งหางแมว',
  'แก้งคร้อ',
  'แก้งสนามนาง',
  'แคนดง',
  'แจ้ห่ม',
  'แปลงยาว',
  'แม่จริม',
  'แม่จัน',
  'แม่ทะ',
  'แม่ทา',
  'แม่พริก',
  'แม่ฟ้าหลวง',
  'แม่ระมาด',
  'แม่ริม',
  'แม่ลาน',
  'แม่ลาน้อย',
  'แม่ลาว',
  'แม่วงก์',
  'แม่วาง',
  'แม่สรวย',
  'แม่สอด',
  'แม่สะเรียง',
  'แม่สาย',
  'แม่ออน',
  'แม่อาย',
  'แม่เปิน',
  'แม่เมาะ',
  'แม่แจ่ม',
  'แม่แตง',
  'แม่ใจ',
  'แวงน้อย',
  'แวงใหญ่',
  'แว้ง',
  'แสวงหา',
  'แหลมงอบ',
  'แหลมสิงห์',
  'โกรกพระ',
  'โกสัมพีนคร',
  'โกสุมพิสัย',
  'โขงเจียม',
  'โคกศรีสุพรรณ',
  'โคกสำโรง',
  'โคกสูง',
  'โคกเจริญ',
  'โคกโพธิ์',
  'โคกโพธิ์ไชย',
  'โชคชัย',
  'โซ่พิสัย',
  'โนนคูณ',
  'โนนดินแดง',
  'โนนนารายณ์',
  'โนนศิลา',
  'โนนสะอาด',
  'โนนสัง',
  'โนนสุวรรณ',
  'โนนสูง',
  'โนนแดง',
  'โนนไทย',
  'โป่งน้ำร้อน',
  'โพทะเล',
  'โพธาราม',
  'โพธิ์ชัย',
  'โพธิ์ตาก',
  'โพธิ์ทอง',
  'โพธิ์ประทับช้าง',
  'โพธิ์ศรีสุวรรณ',
  'โพธิ์ไทร',
  'โพนทราย',
  'โพนทอง',
  'โพนนาแก้ว',
  'โพนพิสัย',
  'โพนสวรรค์',
  'ไชยปราการ',
  'ไชยวาน',
  'ไชยา',
  'ไชโย',
  'ไทยเจริญ',
  'ไทรงาม',
  'ไทรน้อย',
  'ไทรโยค',
  'ไพรบึง',
  'ไพศาลี',
  'ไม้แก่น'
]


tambol_list = [
  'กกกุง',
  'กกดู่',
  'กกตูม',
  'กกทอง',
  'กกปลาซิว',
  'กกสะทอน',
  'กกแก้วบูรพา',
  'กกแดง',
  'กกแรต',
  'กกโก',
  'กกโพธิ์',
  'กง',
  'กงรถ',
  'กงหรา',
  'กบินทร์',
  'กบเจา',
  'กมลา',
  'กมลาไสย',
  'กรงปินัง',
  'กรอกสมบูรณ์',
  'กระจัน',
  'กระจาย',
  'กระจิว',
  'กระชอน',
  'กระดังงา',
  'กระตีบ',
  'กระทุ่มราย',
  'กระทุ่มล้ม',
  'กระทุ่มแพ้ว',
  'กระนวน',
  'กระบี่น้อย',
  'กระบี่ใหญ่',
  'กระสัง',
  'กระหวะ',
  'กระหวัน',
  'กระหาด',
  'กระออม',
  'กระเดียน',
  'กระเทียม',
  'กระเบื้อง',
  'กระเบื้องนอก',
  'กระเบื้องใหญ่',
  'กระเสาะ',
  'กระเสียว',
  'กระแจะ',
  'กระแชง',
  'กระแสบน',
  'กระแสสินธุ์',
  'กระโด',
  'กระโทก',
  'กระโพ',
  'กระโสบ',
  'กระโสม',
  'กรับใหญ่',
  'กรุงชิง',
  'กรุงหยัน',
  'กรูด',
  'กร่ำ',
  'กฤษณา',
  'กลอนโด',
  'กลัดหลวง',
  'กลันทา',
  'กลาง',
  'กลางดง',
  'กลางหมื่น',
  'กลางเวียง',
  'กลางแดด',
  'กลางใหญ่',
  'กลาย',
  'กล้วยกว้าง',
  'กล้วยแพะ',
  'กวนวัน',
  'กวางโจน',
  'กองก๋อย',
  'กองควาย',
  'กองดิน',
  'กองทูล',
  'กองนาง',
  'กองแขก',
  'กองโพน',
  'กอตอตือร๊ะ',
  'กอลำ',
  'กะดุนง',
  'กะทุ่ม',
  'กะทูน',
  'กะทู้',
  'กะบกเตี้ย',
  'กะปง',
  'กะปาง',
  'กะมัง',
  'กะมิยอ',
  'กะรน',
  'กะรุบี',
  'กะลาเส',
  'กะลุวอ',
  'กะลุวอเหนือ',
  'กะหรอ',
  'กะฮาด',
  'กะเฉด',
  'กะเปอร์',
  'กะเปา',
  'กะเปียด',
  'กะแดะ',
  'กะไหล',
  'กังแอน',
  'กันจุ',
  'กันตวจระมวล',
  'กันตัง',
  'กันตังใต้',
  'กันทรอม',
  'กันทรารมย์',
  'กาญจนา',
  'กาตอง',
  'กาบัง',
  'กาบิน',
  'กาบเชิง',
  'กายูคละ',
  'กายูบอเกาะ',
  'การะเกด',
  'กาลอ',
  'กาลิซา',
  'กาลูปัง',
  'กาวะ',
  'กาหลง',
  'กาฬสินธุ์',
  'กาเกาะ',
  'กาเยาะมาตี',
  'กำปัง',
  'กำพวน',
  'กำพี้',
  'กำเนิดนพคุณ',
  'กำแพง',
  'กำแพงดิน',
  'กำแพงเซา',
  'กำแพงเพชร',
  'กำแพงแสน',
  'กำแมด',
  'กำโลน',
  'กื้ดช้าง',
  'กุง',
  'กุงเก่า',
  'กุฎี',
  'กุฎโง้ง',
  'กุดกว้าง',
  'กุดกุง',
  'กุดขอนแก่น',
  'กุดขาคีม',
  'กุดค้าว',
  'กุดจอก',
  'กุดจับ',
  'กุดจิก',
  'กุดฉิม',
  'กุดชมภู',
  'กุดชุม',
  'กุดชุมแสง',
  'กุดดินจี่',
  'กุดดู่',
  'กุดตาเพชร',
  'กุดตุ้ม',
  'กุดธาตุ',
  'กุดนกเปล้า',
  'กุดน้อย',
  'กุดน้ำใส',
  'กุดบง',
  'กุดบาก',
  'กุดประทาย',
  'กุดปลาค้าว',
  'กุดปลาดุก',
  'กุดป่อง',
  'กุดผึ้ง',
  'กุดพิมาน',
  'กุดยม',
  'กุดยาลวน',
  'กุดรัง',
  'กุดลาด',
  'กุดสระ',
  'กุดสะเทียน',
  'กุดสิมคุ้มใหม่',
  'กุดหมากไฟ',
  'กุดหวาย',
  'กุดหว้า',
  'กุดเค้า',
  'กุดเชียงหมี',
  'กุดเพียขอม',
  'กุดเมืองฮาม',
  'กุดเรือ',
  'กุดเรือคำ',
  'กุดเลาะ',
  'กุดเสลา',
  'กุดแข้',
  'กุดแห่',
  'กุดโดน',
  'กุดโบสถ์',
  'กุดใส้จ่อ',
  'กุดไห',
  'กุตาไก้',
  'กุมภวาปี',
  'กุยบุรี',
  'กุยเหนือ',
  'กุรุคุ',
  'กุศกร',
  'กุสุมาลย์',
  'กุแหระ',
  'กุ่มหัก',
  'กู่',
  'กู่กาสิงห์',
  'กู่จาน',
  'กู่ทอง',
  'กู่สวนแตง',
  'กู่สันตรัตน์',
  'ก่อเอ้',
  'ก้อ',
  'ก้อนแก้ว',
  'ก้านเหลือง',
  'ก้ามปู',
  'ขนงพระ',
  'ขนวน',
  'ขนอนหลวง',
  'ขนอม',
  'ขนาบนาก',
  'ขนุน',
  'ขมิ้น',
  'ขยาย',
  'ขลุง',
  'ขวัญเมือง',
  'ขวาว',
  'ขวาวใหญ่',
  'ขอนคลาน',
  'ขอนยูง',
  'ขอนหาด',
  'ขอนแก่น',
  'ขอนแตก',
  'ขะยูง',
  'ขะเนจื้อ',
  'ขันเงิน',
  'ขัวก่าย',
  'ขัวมุง',
  'ขัวเรียง',
  'ขั้นไดใหญ่',
  'ขามทะเลสอ',
  'ขามป้อม',
  'ขามสมบูรณ์',
  'ขามสะแกแสง',
  'ขามเฒ่า',
  'ขามเฒ่าพัฒนา',
  'ขามเปี้ย',
  'ขามเรียง',
  'ขามเรียน',
  'ขามใหญ่',
  'ขี้เหล็ก',
  'ขึ่ง',
  'ขุนกระทิง',
  'ขุนคง',
  'ขุนควร',
  'ขุนซ่อง',
  'ขุนตัดหวาย',
  'ขุนทอง',
  'ขุนทะเล',
  'ขุนน่าน',
  'ขุนฝาง',
  'ขุนพิทักษ์',
  'ขุนยวม',
  'ขุนศรี',
  'ขุนหาญ',
  'ขุนแก้ว',
  'ขุนแม่ลาน้อย',
  'ขุนโขลน',
  'ขุมทอง',
  'ขุมเงิน',
  'ขุย',
  'ขุหลุ',
  'ข่วงเปา',
  'ข่อยสูง',
  'ข้าวงาม',
  'ข้าวปุ้น',
  'ข้าวสาร',
  'ข้าวเม่า',
  'คชสิทธิ์',
  'คณฑี',
  'คมบาง',
  'ครน',
  'ครบุรี',
  'ครบุรีใต้',
  'ครึ่ง',
  'คลองกระจง',
  'คลองกระจัง',
  'คลองกระบือ',
  'คลองกระแชง',
  'คลองกวาง',
  'คลองกิ่ว',
  'คลองกุ่ม',
  'คลองขนาก',
  'คลองขนาน',
  'คลองขลุง',
  'คลองขวาง',
  'คลองขาม',
  'คลองขุด',
  'คลองข่อย',
  'คลองควาย',
  'คลองคะเชนทร์',
  'คลองคูณ',
  'คลองจั่น',
  'คลองจิก',
  'คลองจินดา',
  'คลองจุกกระเฌอ',
  'คลองฉนวน',
  'คลองฉนาก',
  'คลองชะอุ่น',
  'คลองชักพระ',
  'คลองชีล้อม',
  'คลองด่าน',
  'คลองตะเกรา',
  'คลองตะเคียน',
  'คลองตัน',
  'คลองตันเหนือ',
  'คลองตาคต',
  'คลองตาล',
  'คลองตำหรุ',
  'คลองต้นไทร',
  'คลองถนน',
  'คลองทราย',
  'คลองทรายขาว',
  'คลองทับจันทร์',
  'คลองท่อมเหนือ',
  'คลองท่อมใต้',
  'คลองนกกระทุง',
  'คลองนครเนื่องเขต',
  'คลองนา',
  'คลองนารายณ์',
  'คลองนิยมยาตรา',
  'คลองน้อย',
  'คลองน้ำเค็ม',
  'คลองน้ำใส',
  'คลองน้ำไหล',
  'คลองบางบอน',
  'คลองบางพราน',
  'คลองบ้านโพธิ์',
  'คลองประสงค์',
  'คลองประเวศ',
  'คลองปราบ',
  'คลองปาง',
  'คลองปูน',
  'คลองพน',
  'คลองพระยาบันลือ',
  'คลองพระอุดม',
  'คลองพลู',
  'คลองพา',
  'คลองพิไกร',
  'คลองมหานาค',
  'คลองมะพลับ',
  'คลองมะเดื่อ',
  'คลองมานิง',
  'คลองม่วง',
  'คลองยา',
  'คลองยาง',
  'คลองรี',
  'คลองลานพัฒนา',
  'คลองลุ',
  'คลองวัว',
  'คลองวาฬ',
  'คลองศก',
  'คลองสมบูรณ์',
  'คลองสระ',
  'คลองสระบัว',
  'คลองสวน',
  'คลองสวนพลู',
  'คลองสอง',
  'คลองสองต้นนุ่น',
  'คลองสะแก',
  'คลองสาน',
  'คลองสาม',
  'คลองสามประเวศ',
  'คลองสิบ',
  'คลองสิบสอง',
  'คลองสี่',
  'คลองหก',
  'คลองหนึ่ง',
  'คลองหรัง',
  'คลองหลวงแพ่ง',
  'คลองหลา',
  'คลองหอยโข่ง',
  'คลองหาด',
  'คลองหิน',
  'คลองหินปูน',
  'คลองห้า',
  'คลองอุดมชลจร',
  'คลองอู่ตะเภา',
  'คลองเกตุ',
  'คลองเกลือ',
  'คลองเขม้า',
  'คลองเขิน',
  'คลองเขื่อน',
  'คลองเคียน',
  'คลองเจ็ด',
  'คลองเจ้าคุณสิงห์',
  'คลองเฉลิม',
  'คลองเตย',
  'คลองเตยเหนือ',
  'คลองเปรง',
  'คลองเปียะ',
  'คลองเมือง',
  'คลองเรือ',
  'คลองเส',
  'คลองแดน',
  'คลองแม่ลาย',
  'คลองแห',
  'คลองโคน',
  'คลองโยง',
  'คลองใหญ่',
  'คลองใหม่',
  'คลองไก่เถื่อน',
  'คลองไทร',
  'คลองไผ่',
  'คลัง',
  'คลีกลิ้ง',
  'ควน',
  'ควนกรด',
  'ควนกลาง',
  'ควนกาหลง',
  'ควนขนุน',
  'ควนขัน',
  'ควนชะลิก',
  'ควนชุม',
  'ควนทอง',
  'ควนธานี',
  'ควนปริง',
  'ควนพัง',
  'ควนมะพร้าว',
  'ควนรู',
  'ควนลัง',
  'ควนศรี',
  'ควนสตอ',
  'ควนสุบรรณ',
  'ควนหนองคว้า',
  'ควนหนองหงษ์',
  'ควนเกย',
  'ควนเมา',
  'ควนโดน',
  'ควนโนรี',
  'ควนโพธิ์',
  'ควนโส',
  'ควร',
  'คอกกระบือ',
  'คอกควาย',
  'คอกช้าง',
  'คอทราย',
  'คอนกาม',
  'คอนฉิม',
  'คอนสวรรค์',
  'คอนสาย',
  'คอนสาร',
  'คอรุม',
  'คอลอตันหยง',
  'คอหงส์',
  'คอแลน',
  'คอโค',
  'คันธารราษฎร์',
  'คันธุลี',
  'คันนายาว',
  'คันโช้ง',
  'คันไร่',
  'คานหาม',
  'คาละแมะ',
  'คำขวาง',
  'คำครั่ง',
  'คำชะอี',
  'คำด้วง',
  'คำตากล้า',
  'คำนาดี',
  'คำน้ำสร้าง',
  'คำน้ำแซบ',
  'คำบก',
  'คำบง',
  'คำบ่อ',
  'คำป่าหลาย',
  'คำผง',
  'คำพระ',
  'คำพราน',
  'คำพอุง',
  'คำพี้',
  'คำม่วง',
  'คำสร้างเที่ยง',
  'คำสะอาด',
  'คำหยาด',
  'คำหว้า',
  'คำอาฮวน',
  'คำเขื่อนแก้ว',
  'คำเจริญ',
  'คำเตย',
  'คำเนียม',
  'คำเลาะ',
  'คำเหมือดแก้ว',
  'คำแก้ว',
  'คำแคน',
  'คำแมด',
  'คำโคกสูง',
  'คำโตนด',
  'คำโพน',
  'คำใหญ่',
  'คำไผ่',
  'คำไหล',
  'คำไฮ',
  'คำไฮใหญ่',
  'คีรีราษฎร์',
  'คีรีวง',
  'คีรีเขต',
  'คึกคัก',
  'คึมชาด',
  'คึมใหญ่',
  'คือเวียง',
  'คุยบ้านโอง',
  'คุยม่วง',
  'คุระ',
  'คุริง',
  'คุ้งกระถิน',
  'คุ้งตะเภา',
  'คุ้งน้ำวน',
  'คุ้งพยอม',
  'คุ้งลาน',
  'คุ้งสำเภา',
  'คุ้มเก่า',
  'คู',
  'คูขวาง',
  'คูขาด',
  'คูขุด',
  'คูคต',
  'คูคำ',
  'คูซอด',
  'คูตัน',
  'คูบ',
  'คูบัว',
  'คูบางหลวง',
  'คูสะคาม',
  'คูหา',
  'คูหาสวรรค์',
  'คูหาใต้',
  'คูเต่า',
  'คูเมือง',
  'คู้ฝั่งเหนือ',
  'คู้ยายหมี',
  'คู้ลำพัน',
  'คู้สลอด',
  'ค่ายบกหวาน',
  'ค้อทอง',
  'ค้อน้อย',
  'ค้อวัง',
  'ค้อเขียว',
  'ค้อเหนือ',
  'ค้อใต้',
  'ค้อใหญ่',
  'ค้างพลู',
  'ฆอเลาะ',
  'ฆะมัง',
  'ฆ้องชัยพัฒนา',
  'งอบ',
  'งัวบา',
  'งิม',
  'งิ้ว',
  'งิ้วงาม',
  'งิ้วด่อน',
  'งิ้วราย',
  'จ.ป.ร.',
  'จตุจักร',
  'จระเข้',
  'จระเข้หิน',
  'จรัส',
  'จริม',
  'จรเข้บัว',
  'จรเข้มาก',
  'จรเข้ร้อง',
  'จรเข้สามพัน',
  'จรเข้เผือก',
  'จรเข้ใหญ่',
  'จวบ',
  'จองคำ',
  'จองถนน',
  'จอมจันทร์',
  'จอมทอง',
  'จอมบึง',
  'จอมประทัด',
  'จอมปลวก',
  'จอมพระ',
  'จอมพล',
  'จอมศรี',
  'จอมสวรรค์',
  'จอมหมอกแก้ว',
  'จอหอ',
  'จอเบาะ',
  'จะกง',
  'จะกว๊ะ',
  'จะทิ้งพระ',
  'จะบังติกอ',
  'จะรัง',
  'จะแนะ',
  'จะแหน',
  'จะโหนง',
  'จักรวรรดิ์',
  'จักรสีห์',
  'จักราช',
  'จังหาร',
  'จันจว้า',
  'จันจว้าใต้',
  'จันดี',
  'จันดุม',
  'จันทนิมิต',
  'จันทบเพชร',
  'จันทรเกษม',
  'จันทร์เพ็ญ',
  'จันทิมา',
  'จันทึก',
  'จันทเขลม',
  'จันอัด',
  'จันเสน',
  'จางเหนือ',
  'จาน',
  'จานลาน',
  'จานแสนไชย',
  'จานใหญ่',
  'จารพัต',
  'จำปา',
  'จำปาขัน',
  'จำปาหล่อ',
  'จำปาโมง',
  'จำปี',
  'จำป่าหวาย',
  'จำลอง',
  'จิกดู่',
  'จิกสังข์ทอง',
  'จิกเทิง',
  'จีกแดก',
  'จุน',
  'จุมจัง',
  'จุมพล',
  'ฉมัน',
  'ฉลอง',
  'ฉลุง',
  'ฉวาง',
  'ฉาง',
  'ฉิมพลี',
  'ชนบท',
  'ชนะสงคราม',
  'ชนแดน',
  'ชมพู',
  'ชมภู',
  'ชมสะอาด',
  'ชมเจริญ',
  'ชลคราม',
  'ชอนน้อย',
  'ชอนม่วง',
  'ชอนสมบูรณ์',
  'ชอนสารเดช',
  'ชอนไพร',
  'ชะมวง',
  'ชะมาย',
  'ชะรัด',
  'ชะอม',
  'ชะอวด',
  'ชะอำ',
  'ชะเมา',
  'ชะแมบ',
  'ชะแล',
  'ชะแล้',
  'ชะโนด',
  'ชะโนดน้อย',
  'ชะไว',
  'ชัยจุมพล',
  'ชัยนาท',
  'ชัยนาม',
  'ชัยนารายณ์',
  'ชัยบาดาล',
  'ชัยบุรี',
  'ชัยพร',
  'ชัยพฤกษ์',
  'ชัยมงคล',
  'ชัยฤทธิ์',
  'ชัยเกษม',
  'ชากบก',
  'ชากพง',
  'ชากโดน',
  'ชากไทย',
  'ชาติตระการ',
  'ชานุมาน',
  'ชานุวรรณ',
  'ชายนา',
  'ชำ',
  'ชำฆ้อ',
  'ชำนิ',
  'ชำผักแพว',
  'ชำราก',
  'ชำแระ',
  'ชิงโค',
  'ชีทวน',
  'ชีน้ำร้าย',
  'ชีบน',
  'ชีลอง',
  'ชีวาน',
  'ชีวึก',
  'ชื่นชม',
  'ชุมช้าง',
  'ชุมตาบง',
  'ชุมพร',
  'ชุมพล',
  'ชุมพลบุรี',
  'ชุมพวง',
  'ชุมภูพร',
  'ชุมเห็ด',
  'ชุมแพ',
  'ชุมแสง',
  'ชุมแสงสงคราม',
  'ชุมโค',
  'ช่อง',
  'ช่องกุ่ม',
  'ช่องด่าน',
  'ช่องนนทรี',
  'ช่องลม',
  'ช่องสะเดา',
  'ช่องสะแก',
  'ช่องสามหมอ',
  'ช่องสาริกา',
  'ช่องเม็ก',
  'ช่องแค',
  'ช่องแคบ',
  'ช่องแมว',
  'ช่องไม้แก้ว',
  'ช่อผกา',
  'ช่อระกา',
  'ช่อแล',
  'ช่อแฮ',
  'ช่างปี่',
  'ช่างเคิ่ง',
  'ช่างเหล็ก',
  'ช้างกลาง',
  'ช้างขวา',
  'ช้างข้าม',
  'ช้างคลาน',
  'ช้างซ้าย',
  'ช้างตะลูด',
  'ช้างทอง',
  'ช้างทูน',
  'ช้างน้อย',
  'ช้างมิ่ง',
  'ช้างม่อย',
  'ช้างเผือก',
  'ช้างแรก',
  'ช้างใหญ่',
  'ช้างให้ตก',
  'ซับจำปา',
  'ซับตะเคียน',
  'ซับน้อย',
  'ซับพุทรา',
  'ซับมะกรูด',
  'ซับสนุ่น',
  'ซับสมบูรณ์',
  'ซับสมอทอด',
  'ซับสีทอง',
  'ซับเปิบ',
  'ซับใหญ่',
  'ซับไม้แดง',
  'ซากอ',
  'ซาง',
  'ซำ',
  'ซำยาง',
  'ซึ้ง',
  'ณรงค์',
  'ดงกระทงยาม',
  'ดงกลาง',
  'ดงขวาง',
  'ดงขี้เหล็ก',
  'ดงขุย',
  'ดงครั่งน้อย',
  'ดงครั่งใหญ่',
  'ดงคอน',
  'ดงคู่',
  'ดงชน',
  'ดงดวน',
  'ดงดำ',
  'ดงดินแดง',
  'ดงตะขบ',
  'ดงตะงาว',
  'ดงน้อย',
  'ดงบัง',
  'ดงประคำ',
  'ดงป่าคำ',
  'ดงพญา',
  'ดงพยุง',
  'ดงพระราม',
  'ดงพลอง',
  'ดงพลับ',
  'ดงมหาวัน',
  'ดงมอน',
  'ดงมะดะ',
  'ดงมะยาง',
  'ดงมะรุม',
  'ดงมะไฟ',
  'ดงมูล',
  'ดงมูลเหล็ก',
  'ดงยาง',
  'ดงรัก',
  'ดงละคร',
  'ดงลาน',
  'ดงลิง',
  'ดงสมบูรณ์',
  'ดงสวรรค์',
  'ดงสิงห์',
  'ดงสุวรรณ',
  'ดงหมู',
  'ดงหม้อทอง',
  'ดงหม้อทองใต้',
  'ดงหลวง',
  'ดงอีจาน',
  'ดงเค็ง',
  'ดงเจน',
  'ดงเจริญ',
  'ดงเดือย',
  'ดงเมือง',
  'ดงเมืองแอม',
  'ดงเย็น',
  'ดงเสือเหลือง',
  'ดงเหนือ',
  'ดงแคนใหญ่',
  'ดงแดง',
  'ดงใหญ่',
  'ดม',
  'ดวนใหญ่',
  'ดอกคำใต้',
  'ดอกล้ำ',
  'ดอกไม้',
  'ดองกำเม็ด',
  'ดอน',
  'ดอนกรวย',
  'ดอนกระเบื้อง',
  'ดอนกลอย',
  'ดอนกลาง',
  'ดอนกอก',
  'ดอนกำ',
  'ดอนกำยาน',
  'ดอนขมิ้น',
  'ดอนขวาง',
  'ดอนขุนห้วย',
  'ดอนข่อย',
  'ดอนคลัง',
  'ดอนคา',
  'ดอนงัว',
  'ดอนจาน',
  'ดอนจิก',
  'ดอนฉิมพลี',
  'ดอนชมพู',
  'ดอนชะเอม',
  'ดอนช้าง',
  'ดอนดั่ง',
  'ดอนดึง',
  'ดอนดู่',
  'ดอนตรอ',
  'ดอนตะหนิน',
  'ดอนตะโก',
  'ดอนตาล',
  'ดอนตาเพชร',
  'ดอนตูม',
  'ดอนทราย',
  'ดอนทอง',
  'ดอนนางหงส์',
  'ดอนประดู่',
  'ดอนปรู',
  'ดอนพุด',
  'ดอนพุทรา',
  'ดอนมดแดง',
  'ดอนมนต์',
  'ดอนมะนาว',
  'ดอนมะสังข์',
  'ดอนมะเกลือ',
  'ดอนมะโนรา',
  'ดอนมัน',
  'ดอนมูล',
  'ดอนยอ',
  'ดอนยาง',
  'ดอนยายหนู',
  'ดอนยายหอม',
  'ดอนยาวใหญ่',
  'ดอนรวก',
  'ดอนรัก',
  'ดอนลาน',
  'ดอนศรีชุม',
  'ดอนศิลา',
  'ดอนสมบูรณ์',
  'ดอนสัก',
  'ดอนหญ้านาง',
  'ดอนหวาย',
  'ดอนหว่าน',
  'ดอนหัน',
  'ดอนหัวฬ่อ',
  'ดอนหายโศก',
  'ดอนอะราง',
  'ดอนเกาะกา',
  'ดอนเงิน',
  'ดอนเจดีย์',
  'ดอนเตย',
  'ดอนเปา',
  'ดอนเมย',
  'ดอนเมือง',
  'ดอนแก้ว',
  'ดอนแตง',
  'ดอนแฝก',
  'ดอนแรด',
  'ดอนแร่',
  'ดอนแสลบ',
  'ดอนโพธิ์',
  'ดอนโพธิ์ทอง',
  'ดอนโอง',
  'ดอนใหญ่',
  'ดอนไก่ดี',
  'ดอนไผ่',
  'ดอนไฟ',
  'ดอยงาม',
  'ดอยลาน',
  'ดอยหล่อ',
  'ดอยฮาง',
  'ดอยเต่า',
  'ดอยแก้ว',
  'ดาวคะนอง',
  'ดาวเรือง',
  'ดาโต๊ะ',
  'ดำเนินสะดวก',
  'ดินจี่',
  'ดินดำ',
  'ดินทอง',
  'ดินอุดม',
  'ดินแดง',
  'ดีลัง',
  'ดีหลวง',
  'ดุซงญอ',
  'ดุมใหญ่',
  'ดุสิต',
  'ดูกอึ่ง',
  'ดูน',
  'ดูนสาด',
  'ดู่',
  'ดู่ทุ่ง',
  'ดู่น้อย',
  'ดู่พงษ์',
  'ดู่ลาด',
  'ดู่ใต้',
  'ด่าน',
  'ด่านขุนทด',
  'ด่านคล้า',
  'ด่านจาก',
  'ด่านชุมพล',
  'ด่านช้าง',
  'ด่านซ้าย',
  'ด่านทับตะโก',
  'ด่านนอก',
  'ด่านมะขามเตี้ย',
  'ด่านม่วงคำ',
  'ด่านศรีสุข',
  'ด่านสวี',
  'ด่านเกวียน',
  'ด่านแม่คำมัน',
  'ด่านแม่ละเมา',
  'ด่านแม่แฉลบ',
  'ด่านใน',
  'ตกพรม',
  'ตบหู',
  'ตรมไพร',
  'ตรวจ',
  'ตรอกนอง',
  'ตระกาจ',
  'ตระการ',
  'ตระเปียงเตีย',
  'ตระแสง',
  'ตรัง',
  'ตรำดม',
  'ตรีณรงค์',
  'ตรึม',
  'ตลาด',
  'ตลาดกรวด',
  'ตลาดกระทุ่มแบน',
  'ตลาดขวัญ',
  'ตลาดจินดา',
  'ตลาดน้อย',
  'ตลาดบางเขน',
  'ตลาดพลู',
  'ตลาดยอด',
  'ตลาดหลวง',
  'ตลาดเกรียบ',
  'ตลาดเหนือ',
  'ตลาดแร้ง',
  'ตลาดโพธิ์',
  'ตลาดใหญ่',
  'ตลาดใหม่',
  'ตลาดไชยา',
  'ตลาดไทร',
  'ตลิ่งงาม',
  'ตลิ่งชัน',
  'ตลุก',
  'ตลุกกลางทุ่ง',
  'ตลุกดู่',
  'ตลุกเทียม',
  'ตองปิด',
  'ตองโขบ',
  'ตอหลัง',
  'ตะกรบ',
  'ตะกั่วป่า',
  'ตะกาง',
  'ตะกาดเง้า',
  'ตะกุกเหนือ',
  'ตะกุกใต้',
  'ตะกุด',
  'ตะกุดไร',
  'ตะขบ',
  'ตะคร้อ',
  'ตะคร้ำเอน',
  'ตะคุ',
  'ตะค่า',
  'ตะดอบ',
  'ตะนาวศรี',
  'ตะบิ้ง',
  'ตะบ่าย',
  'ตะปอน',
  'ตะปอเยาะ',
  'ตะปาน',
  'ตะพง',
  'ตะพานหิน',
  'ตะมะยูง',
  'ตะลุง',
  'ตะลุบัน',
  'ตะลุโบะ',
  'ตะเครียะ',
  'ตะเคียน',
  'ตะเคียนทอง',
  'ตะเคียนปม',
  'ตะเคียนราม',
  'ตะเคียนเตี้ย',
  'ตะเคียนเลื่อน',
  'ตะเบาะ',
  'ตะเสะ',
  'ตะแบกบาน',
  'ตะแพน',
  'ตะโก',
  'ตะโกตาพิ',
  'ตะโกทอง',
  'ตะโละ',
  'ตะโละกาโปร์',
  'ตะโละดือรามัน',
  'ตะโละแมะนา',
  'ตะโละไกรทอง',
  'ตะโล๊ะหะลอ',
  'ตะโหมด',
  'ตันหยงจึงงา',
  'ตันหยงดาลอ',
  'ตันหยงมัส',
  'ตันหยงลิมอ',
  'ตันหยงลุโละ',
  'ตันหยงโป',
  'ตับเต่า',
  'ตั้งใจ',
  'ตากตก',
  'ตากฟ้า',
  'ตากออก',
  'ตากูก',
  'ตากแดด',
  'ตาก้อง',
  'ตาขัน',
  'ตาขีด',
  'ตาคง',
  'ตาคลี',
  'ตาจง',
  'ตาจั่น',
  'ตาชี',
  'ตาดกลอย',
  'ตาดข่า',
  'ตาดควัน',
  'ตาดทอง',
  'ตาตุม',
  'ตานิม',
  'ตานี',
  'ตาพระยา',
  'ตาลชุม',
  'ตาลสุม',
  'ตาลาน',
  'ตาลีอายร์',
  'ตาลเดี่ยว',
  'ตาลเตี้ย',
  'ตาลเนิ้ง',
  'ตาลเลียน',
  'ตาลเอน',
  'ตาลโกน',
  'ตาวัง',
  'ตาสัง',
  'ตาสิทธิ์',
  'ตาหลวง',
  'ตาหลังใน',
  'ตาอุด',
  'ตาอ็อง',
  'ตาเกษ',
  'ตาเกา',
  'ตาเซะ',
  'ตาเนาะปูเต๊ะ',
  'ตาเนาะแมเราะ',
  'ตาเนิน',
  'ตาเบา',
  'ตาเป๊ก',
  'ตาเมียง',
  'ตาเสา',
  'ตาแกะ',
  'ตาโกน',
  'ตำตัว',
  'ตำนาน',
  'ตำมะลัง',
  'ตำหนักธรรม',
  'ตำหรุ',
  'ตำแย',
  'ตุยง',
  'ตูม',
  'ตูมใต้',
  'ตูมใหญ่',
  'ต้นตาล',
  'ต้นธง',
  'ต้นธงชัย',
  'ต้นผึ้ง',
  'ต้นมะพร้าว',
  'ต้นมะม่วง',
  'ต้นยวน',
  'ต้นเปา',
  'ต้นโพธิ์',
  'ต้า',
  'ต้าผามอก',
  'ถนน',
  'ถนนขาด',
  'ถนนนครไชยศรี',
  'ถนนพญาไท',
  'ถนนหัก',
  'ถนนเพชรบุรี',
  'ถนนโพธิ์',
  'ถนนใหญ่',
  'ถลุงเหล็ก',
  'ถอนสมอ',
  'ถาวร',
  'ถาวรวัฒนา',
  'ถืมตอง',
  'ถ่อนนาลับ',
  'ถ้ำ',
  'ถ้ำกระต่ายทอง',
  'ถ้ำฉลอง',
  'ถ้ำทองหลาง',
  'ถ้ำทะลุ',
  'ถ้ำน้ำผุด',
  'ถ้ำพรรณรา',
  'ถ้ำรงค์',
  'ถ้ำลอด',
  'ถ้ำวัวแดง',
  'ถ้ำสิงขร',
  'ถ้ำสิงห์',
  'ถ้ำเจริญ',
  'ถ้ำแข้',
  'ถ้ำใหญ่',
  'ทมนางาม',
  'ทมอ',
  'ทรงคนอง',
  'ทรงธรรม',
  'ทรัพย์ทวี',
  'ทรัพย์พระยา',
  'ทรัพย์อนันต์',
  'ทรัพย์ไพวัลย์',
  'ทรายกองดิน',
  'ทรายกองดินใต้',
  'ทรายขาว',
  'ทรายทอง',
  'ทรายมูล',
  'ทรายแดง',
  'ทวีวัฒนา',
  'ทองมงคล',
  'ทองหลาง',
  'ทองเอน',
  'ทอนหงส์',
  'ทะนง',
  'ทะเมนชัย',
  'ทะเลชุบศร',
  'ทะเลทรัพย์',
  'ทะเลน้อย',
  'ทะเลบก',
  'ทะเลวังวัด',
  'ทับกฤช',
  'ทับกฤชใต้',
  'ทับกวาง',
  'ทับกุง',
  'ทับคล้อ',
  'ทับคาง',
  'ทับช้าง',
  'ทับตีเหล็ก',
  'ทับทัน',
  'ทับน้ำ',
  'ทับปริก',
  'ทับปุด',
  'ทับผึ้ง',
  'ทับพริก',
  'ทับมา',
  'ทับยา',
  'ทับยายเชียง',
  'ทับยาว',
  'ทับสวาย',
  'ทับสะแก',
  'ทับหมัน',
  'ทับเที่ยง',
  'ทับใต้',
  'ทับใหญ่',
  'ทับไทร',
  'ทัพทัน',
  'ทัพรั้ง',
  'ทัพราช',
  'ทัพหลวง',
  'ทัพเสด็จ',
  'ทัพไทย',
  'ทากาศ',
  'ทาขุมเงิน',
  'ทางกลาง',
  'ทางขวาง',
  'ทางช้าง',
  'ทางพระ',
  'ทางพูน',
  'ทางเกวียน',
  'ทาทุ่งหลวง',
  'ทานตะวัน',
  'ทาปลาดุก',
  'ทาม',
  'ทาสบเส้า',
  'ทาเหนือ',
  'ทาแม่ลอบ',
  'ทำนบ',
  'ที่วัง',
  'ทุ่ง',
  'ทุ่งกง',
  'ทุ่งกระตาดพัฒนา',
  'ทุ่งกระบือ',
  'ทุ่งกระบ่ำ',
  'ทุ่งกระพังโหม',
  'ทุ่งกระเชาะ',
  'ทุ่งกระเต็น',
  'ทุ่งกล้วย',
  'ทุ่งกวาว',
  'ทุ่งกว๋าว',
  'ทุ่งกุลา',
  'ทุ่งก่อ',
  'ทุ่งขนาน',
  'ทุ่งขมิ้น',
  'ทุ่งขวาง',
  'ทุ่งข้าวพวง',
  'ทุ่งครุ',
  'ทุ่งคลอง',
  'ทุ่งคลี',
  'ทุ่งคล้า',
  'ทุ่งควายกิน',
  'ทุ่งคอก',
  'ทุ่งคา',
  'ทุ่งคาวัด',
  'ทุ่งคาโงก',
  'ทุ่งค่าย',
  'ทุ่งงาม',
  'ทุ่งจังหัน',
  'ทุ่งชมพู',
  'ทุ่งช้าง',
  'ทุ่งตะไคร',
  'ทุ่งตำเสา',
  'ทุ่งต่อ',
  'ทุ่งต้อม',
  'ทุ่งทราย',
  'ทุ่งทอง',
  'ทุ่งท่าช้าง',
  'ทุ่งนนทรี',
  'ทุ่งนางาม',
  'ทุ่งนางโอก',
  'ทุ่งนารี',
  'ทุ่งนาเลา',
  'ทุ่งนาไทย',
  'ทุ่งนุ้ย',
  'ทุ่งน้อย',
  'ทุ่งน้าว',
  'ทุ่งบัว',
  'ทุ่งบุหลัง',
  'ทุ่งปรัง',
  'ทุ่งปี้',
  'ทุ่งผาสุข',
  'ทุ่งผึ้ง',
  'ทุ่งฝน',
  'ทุ่งฝาย',
  'ทุ่งพง',
  'ทุ่งพญาไท',
  'ทุ่งพระ',
  'ทุ่งพระยา',
  'ทุ่งพลา',
  'ทุ่งพอ',
  'ทุ่งพึ่ง',
  'ทุ่งมน',
  'ทุ่งมหาเจริญ',
  'ทุ่งมหาเมฆ',
  'ทุ่งมะพร้าว',
  'ทุ่งยั้ง',
  'ทุ่งยางเมือง',
  'ทุ่งยาว',
  'ทุ่งรวงทอง',
  'ทุ่งระยะ',
  'ทุ่งรัง',
  'ทุ่งลาน',
  'ทุ่งลุยลาย',
  'ทุ่งลูกนก',
  'ทุ่งวัง',
  'ทุ่งวัดดอน',
  'ทุ่งศรี',
  'ทุ่งศรีทอง',
  'ทุ่งศรีเมือง',
  'ทุ่งสง',
  'ทุ่งสมอ',
  'ทุ่งสว่าง',
  'ทุ่งสองห้อง',
  'ทุ่งสะโตก',
  'ทุ่งสัง',
  'ทุ่งสุขลา',
  'ทุ่งหมอ',
  'ทุ่งหลวง',
  'ทุ่งหวัง',
  'ทุ่งหว้า',
  'ทุ่งหัวช้าง',
  'ทุ่งอรุณ',
  'ทุ่งฮั้ว',
  'ทุ่งเขาหลวง',
  'ทุ่งเตา',
  'ทุ่งเตาใหม่',
  'ทุ่งเทิง',
  'ทุ่งเบญจา',
  'ทุ่งเสลี่ยม',
  'ทุ่งแก',
  'ทุ่งแค้ว',
  'ทุ่งแต้',
  'ทุ่งแล้ง',
  'ทุ่งแสงทอง',
  'ทุ่งโป่ง',
  'ทุ่งโพ',
  'ทุ่งโพธิ์',
  'ทุ่งโฮ้ง',
  'ทุ่งใส',
  'ทุ่งใหญ่',
  'ทุ่งไชย',
  'ทุ่งไทรทอง',
  'ทุ่ม',
  'ท่ากกแดง',
  'ท่ากระชับ',
  'ท่ากระดาน',
  'ท่ากระเสริม',
  'ท่ากว้าง',
  'ท่ากำชำ',
  'ท่ากุ่ม',
  'ท่ากูบ',
  'ท่าก้อน',
  'ท่าก๊อ',
  'ท่าขนอน',
  'ท่าขนาน',
  'ท่าขนุน',
  'ท่าขมิ้น',
  'ท่าขอนยาง',
  'ท่าขึ้น',
  'ท่าขุนราม',
  'ท่าข้าม',
  'ท่าข้าวเปลือก',
  'ท่าคล้อ',
  'ท่าคอย',
  'ท่าคันโท',
  'ท่าคา',
  'ท่าค้อ',
  'ท่างาม',
  'ท่างิ้ว',
  'ท่าจะหลุง',
  'ท่าจำปา',
  'ท่าจำปี',
  'ท่าจีน',
  'ท่าฉนวน',
  'ท่าฉลอม',
  'ท่าฉาง',
  'ท่าชนะ',
  'ท่าชะมวง',
  'ท่าชัย',
  'ท่าชี',
  'ท่าชุมพล',
  'ท่าช้าง',
  'ท่าช้างคล้อง',
  'ท่าซอม',
  'ท่าซัก',
  'ท่าซุง',
  'ท่าดอกคำ',
  'ท่าดินดำ',
  'ท่าดินแดง',
  'ท่าดี',
  'ท่าด้วง',
  'ท่าตลาด',
  'ท่าตอ',
  'ท่าตอน',
  'ท่าตะคร้อ',
  'ท่าตะเกียบ',
  'ท่าตะเภา',
  'ท่าตะโก',
  'ท่าตาล',
  'ท่าตำหนัก',
  'ท่าตุ้ม',
  'ท่าตูม',
  'ท่าถ่าน',
  'ท่าทราย',
  'ท่าทอง',
  'ท่าทองหลาง',
  'ท่าทองใหม่',
  'ท่าธง',
  'ท่านัด',
  'ท่านั่ง',
  'ท่านา',
  'ท่านางงาม',
  'ท่านางแนว',
  'ท่าน้าว',
  'ท่าน้ำ',
  'ท่าน้ำอ้อย',
  'ท่าบอน',
  'ท่าบัว',
  'ท่าบุญมี',
  'ท่าบ่อ',
  'ท่าบ่อสงคราม',
  'ท่าประจะ',
  'ท่าประดู่',
  'ท่าปลา',
  'ท่าผา',
  'ท่าผาปุ้ม',
  'ท่าพญา',
  'ท่าพยา',
  'ท่าพระ',
  'ท่าพระยา',
  'ท่าพริก',
  'ท่าพล',
  'ท่าพลับ',
  'ท่าพี่เลี้ยง',
  'ท่าพุทรา',
  'ท่ามะกา',
  'ท่ามะขาม',
  'ท่ามะนาว',
  'ท่ามะปราง',
  'ท่ามะพลา',
  'ท่ามะเขือ',
  'ท่ามะเดื่อ',
  'ท่ามะเฟือง',
  'ท่ามะไฟหวาน',
  'ท่ามิหรำ',
  'ท่าม่วง',
  'ท่ายาง',
  'ท่าระหัด',
  'ท่าราบ',
  'ท่าลาด',
  'ท่าลาดขาว',
  'ท่าลี่',
  'ท่าล้อ',
  'ท่าวัง',
  'ท่าวังตาล',
  'ท่าวังทอง',
  'ท่าวังผา',
  'ท่าวังพร้าว',
  'ท่าวัด',
  'ท่าวาสุกรี',
  'ท่าวุ้ง',
  'ท่าศาลา',
  'ท่าศิลา',
  'ท่าสวรรค์',
  'ท่าสว่าง',
  'ท่าสองคอน',
  'ท่าสองยาง',
  'ท่าสะท้อน',
  'ท่าสะบ้า',
  'ท่าสะอาด',
  'ท่าสะอ้าน',
  'ท่าสะแก',
  'ท่าสัก',
  'ท่าสาป',
  'ท่าสาย',
  'ท่าสายลวด',
  'ท่าสีดา',
  'ท่าสุด',
  'ท่าหมอไทร',
  'ท่าหมื่นราม',
  'ท่าหลวง',
  'ท่าหาดยาว',
  'ท่าหิน',
  'ท่าหินโงม',
  'ท่าฬ่อ',
  'ท่าอยู่',
  'ท่าอิฐ',
  'ท่าอิบุญ',
  'ท่าอุเทน',
  'ท่าอุแท',
  'ท่าอ่าง',
  'ท่าเกวียน',
  'ท่าเกษม',
  'ท่าเคย',
  'ท่าเจ้าสนุก',
  'ท่าเดื่อ',
  'ท่าเทววงษ์',
  'ท่าเมือง',
  'ท่าเยี่ยม',
  'ท่าเรือ',
  'ท่าเสน',
  'ท่าเสม็ด',
  'ท่าเสา',
  'ท่าแค',
  'ท่าแซะ',
  'ท่าแดง',
  'ท่าแฝก',
  'ท่าแพ',
  'ท่าแยก',
  'ท่าแร่',
  'ท่าแร้ง',
  'ท่าแร้งออก',
  'ท่าแลง',
  'ท่าโพ',
  'ท่าโพธิ์',
  'ท่าโพธิ์ชัย',
  'ท่าโพธิ์ศรี',
  'ท่าโรง',
  'ท่าโรงช้าง',
  'ท่าโสม',
  'ท่าใหญ่',
  'ท่าใหม่',
  'ท่าไข่',
  'ท่าไม้',
  'ท่าไม้รวก',
  'ท่าไร่',
  'ท่าไห',
  'ท้องฟ้า',
  'ท้องลำเจียก',
  'ท้องเนียน',
  'ท้อแท้',
  'ท้ายช้าง',
  'ท้ายดง',
  'ท้ายตลาด',
  'ท้ายทุ่ง',
  'ท้ายน้ำ',
  'ท้ายบ้าน',
  'ท้ายบ้านใหม่',
  'ท้ายสำเภา',
  'ท้ายหาด',
  'ท้ายเกาะ',
  'ท้ายเหมือง',
  'ธงชัย',
  'ธงชัยเหนือ',
  'ธงธานี',
  'ธนู',
  'ธรรมศาลา',
  'ธรรมามูล',
  'ธรรมเสน',
  'ธวัชบุรี',
  'ธัญญา',
  'ธาตุ',
  'ธาตุทอง',
  'ธาตุนาเวง',
  'ธาตุน้อย',
  'ธาตุพนม',
  'ธาตุพนมเหนือ',
  'ธาตุเชิงชุม',
  'ธานี',
  'ธารคีรี',
  'ธารทหาร',
  'ธารทอง',
  'ธารน้ำทิพย์',
  'ธารปราสาท',
  'ธารละหลอด',
  'ธารเกษม',
  'ธารโต',
  'ธำมรงค์',
  'นกออก',
  'นครชัยศรี',
  'นครชุม',
  'นครชุมน์',
  'นครนายก',
  'นครปฐม',
  'นครป่าหมาก',
  'นครสวรรค์ตก',
  'นครสวรรค์ออก',
  'นครหลวง',
  'นครเจดีย์',
  'นครเดิฐ',
  'นครไทย',
  'นนทรี',
  'นนทรีย์',
  'นบปริง',
  'นบพิตำ',
  'นพรัตน์',
  'นรสิงห์',
  'นราภิรมย์',
  'นวมินทร์',
  'นวลจันทร์',
  'นอกเมือง',
  'นากระตาม',
  'นากระแซง',
  'นากลาง',
  'นากว้าง',
  'นากอก',
  'นากะชะ',
  'นากั้ง',
  'นาขมิ้น',
  'นาขยาด',
  'นาขอม',
  'นาขา',
  'นาขาม',
  'นาขุนไกร',
  'นาขุม',
  'นาข่า',
  'นาข้าวเสีย',
  'นาครัว',
  'นาคอเรือ',
  'นาคา',
  'นาคาย',
  'นาคำ',
  'นาคำใหญ่',
  'นาคำไฮ',
  'นาคู',
  'นาคูณใหญ่',
  'นาคู่',
  'นางตะเคียน',
  'นางบวช',
  'นางพญา',
  'นางรอง',
  'นางรำ',
  'นางลือ',
  'นางหลง',
  'นางัว',
  'นางั่ว',
  'นางาม',
  'นางิ้ว',
  'นางแก้ว',
  'นางแดด',
  'นางแล',
  'นาจอมเทียน',
  'นาจะหลวย',
  'นาจักร',
  'นาจาน',
  'นาจารย์',
  'นาจำปา',
  'นาจิก',
  'นาชะอัง',
  'นาชุมเห็ด',
  'นาชุมแสง',
  'นาซอ',
  'นาซาว',
  'นาซำ',
  'นาซ่าว',
  'นาดง',
  'นาดอกคำ',
  'นาดินดำ',
  'นาดี',
  'นาดูน',
  'นาด่าน',
  'นาด้วง',
  'นาตงวัฒนา',
  'นาตาขวัญ',
  'นาตาล',
  'นาตาล่วง',
  'นาถ่อน',
  'นาทม',
  'นาทราย',
  'นาทวี',
  'นาทอง',
  'นาทอน',
  'นาทะนุง',
  'นาทัน',
  'นาทับ',
  'นาทับไฮ',
  'นาทุ่ง',
  'นาท่อม',
  'นาท่ามเหนือ',
  'นาท่ามใต้',
  'นานกกก',
  'นานวน',
  'นานวล',
  'นานาค',
  'นาน้อย',
  'นาบอน',
  'นาบัว',
  'นาบินหลา',
  'นาบ่อคำ',
  'นาประดู่',
  'นาปรัง',
  'นาปะขอ',
  'นาปัง',
  'นาปู่ป้อม',
  'นาป่า',
  'นาป่าแซง',
  'นาผือ',
  'นาฝาย',
  'นาพญา',
  'นาพรุ',
  'นาพละ',
  'นาพันสาม',
  'นาพิน',
  'นาพึง',
  'นาพูน',
  'นาพู่',
  'นาภู',
  'นามน',
  'นามะตูม',
  'นามะเขือ',
  'นามะเฟือง',
  'นามาลา',
  'นาม่วง',
  'นาม่อง',
  'นายม',
  'นายาง',
  'นายางกลัก',
  'นายายอาม',
  'นายาว',
  'นายูง',
  'นาราชควาย',
  'นารุ่ง',
  'นาวง',
  'นาวัง',
  'นาวังหิน',
  'นาวุ้ง',
  'นาสนุ่น',
  'นาสวน',
  'นาสวรรค์',
  'นาสะอาด',
  'นาสะเม็ง',
  'นาสะแบง',
  'นาสะไม',
  'นาสะไมย์',
  'นาสัก',
  'นาสาร',
  'นาสิงห์',
  'นาสี',
  'นาสีนวน',
  'นาสีนวล',
  'นาส่วง',
  'นาหนองทุ่ม',
  'นาหนองไผ่',
  'นาหนัง',
  'นาหนาด',
  'นาหมอบุญ',
  'นาหมอม้า',
  'นาหมอศรี',
  'นาหมื่นศรี',
  'นาหม่อม',
  'นาหลวงเสน',
  'นาหว้า',
  'นาหอ',
  'นาหัวบ่อ',
  'นาหินลาด',
  'นาหูกวาง',
  'นาห่อม',
  'นาอาน',
  'นาอิน',
  'นาอุดม',
  'นาอ้อ',
  'นาฮี',
  'นาเกตุ',
  'นาเกลือ',
  'นาเกษม',
  'นาเกาะ',
  'นาเกียน',
  'นาเข',
  'นาเขลียง',
  'นาเคียน',
  'นาเจริญ',
  'นาเฉลียง',
  'นาเชิงคีรี',
  'นาเชือก',
  'นาเดื่อ',
  'นาเตย',
  'นาเพียง',
  'นาเมือง',
  'นาเมืองเพชร',
  'นาเยีย',
  'นาเริก',
  'นาเรียง',
  'นาเรือง',
  'นาเลิง',
  'นาเลิน',
  'นาเลียง',
  'นาเวียง',
  'นาเสียว',
  'นาเหนือ',
  'นาเหรง',
  'นาเหลือง',
  'นาเหล่า',
  'นาแก',
  'นาแก้ว',
  'นาแขม',
  'นาแค',
  'นาแซง',
  'นาแต้',
  'นาแพง',
  'นาแว',
  'นาแวง',
  'นาแสง',
  'นาแส่ง',
  'นาแห้ว',
  'นาโก',
  'นาโคก',
  'นาโฉง',
  'นาโต๊ะหมิง',
  'นาโบสถ์',
  'นาโป่ง',
  'นาโพธิ์',
  'นาโพธิ์กลาง',
  'นาโยงเหนือ',
  'นาโยงใต้',
  'นาโสก',
  'นาโสม',
  'นาโส่',
  'นาโหนด',
  'นาใต้',
  'นาใน',
  'นาใหญ่',
  'นาไม้ไผ่',
  'นาไร่หลวง',
  'นาไหม',
  'นิคม',
  'นิคมกระเสียว',
  'นิคมคำสร้อย',
  'นิคมทุ่งโพธิ์ทะเล',
  'นิคมน้ำอูน',
  'นิคมพัฒนา',
  'นิคมลำนารายณ์',
  'นิคมลำโดมน้อย',
  'นิคมสงเคราะห์',
  'นิคมสร้างตนเอง',
  'นิคมสร้างตนเองลำโดมน้อย',
  'นิคมห้วยผึ้ง',
  'นิคมเขาบ่อแก้ว',
  'นิยมชัย',
  'นิลเพชร',
  'นิเวศน์',
  'น้ำกุ่ม',
  'น้ำก่ำ',
  'น้ำก้อ',
  'น้ำขาว',
  'น้ำขุม',
  'น้ำคอก',
  'น้ำคำ',
  'น้ำคำใหญ่',
  'น้ำจั้น',
  'น้ำจืด',
  'น้ำจืดน้อย',
  'น้ำชำ',
  'น้ำชุน',
  'น้ำซึม',
  'น้ำดำ',
  'น้ำดิบ',
  'น้ำตก',
  'น้ำตาล',
  'น้ำทรง',
  'น้ำทูน',
  'น้ำน้อย',
  'น้ำบ่อหลวง',
  'น้ำปลีก',
  'น้ำปั้ว',
  'น้ำปาย',
  'น้ำผุด',
  'น้ำพอง',
  'น้ำพาง',
  'น้ำพี้',
  'น้ำพุ',
  'น้ำพ่น',
  'น้ำมวบ',
  'น้ำรอบ',
  'น้ำรัด',
  'น้ำริด',
  'น้ำรึม',
  'น้ำร้อน',
  'น้ำสวย',
  'น้ำสุด',
  'น้ำหนาว',
  'น้ำหมัน',
  'น้ำหมาน',
  'น้ำหัก',
  'น้ำอ่าง',
  'น้ำอ้อม',
  'น้ำเกลี้ยง',
  'น้ำเกี๋ยน',
  'น้ำเขียว',
  'น้ำเชี่ยว',
  'น้ำเต้า',
  'น้ำเที่ยง',
  'น้ำเป็น',
  'น้ำเลา',
  'น้ำเฮี้ย',
  'น้ำแก่น',
  'น้ำแคม',
  'น้ำแพร่',
  'น้ำแวน',
  'น้ำโจ้',
  'น้ำโมง',
  'น้ำโสม',
  'น้ำใส',
  'น้ำไคร้',
  'น้ำไผ่',
  'บก',
  'บงตัน',
  'บงเหนือ',
  'บงใต้',
  'บรบือ',
  'บริบูรณ์',
  'บวกค้าง',
  'บวรนิเวศ',
  'บองอ',
  'บอน',
  'บะ',
  'บะยาว',
  'บะหว้า',
  'บะฮี',
  'บักดอง',
  'บักได',
  'บันนังสตา',
  'บันนังสาเรง',
  'บัลลังก์',
  'บัวขาว',
  'บัวคำ',
  'บัวค้อ',
  'บัวงาม',
  'บัวชุม',
  'บัวตูม',
  'บัวทอง',
  'บัวน้อย',
  'บัวบาน',
  'บัวปากท่า',
  'บัวมาศ',
  'บัวลอย',
  'บัวลาย',
  'บัววัฒนา',
  'บัวสลี',
  'บัวหุ่ง',
  'บัวเงิน',
  'บัวเชด',
  'บัวแดง',
  'บัวโคก',
  'บัวใหญ่',
  'บากเรือ',
  'บางกรวย',
  'บางกระทึก',
  'บางกระทุ่ม',
  'บางกระบือ',
  'บางกระสอ',
  'บางกระสอบ',
  'บางกระสั้น',
  'บางกระเจ็ด',
  'บางกระเจ้า',
  'บางกระเบา',
  'บางกรูด',
  'บางกร่าง',
  'บางกล่ำ',
  'บางกอบัว',
  'บางกะจะ',
  'บางกะดี',
  'บางกะปิ',
  'บางกะพี้',
  'บางกะเจ้า',
  'บางกะไชย',
  'บางกะไห',
  'บางกุ้ง',
  'บางขนาก',
  'บางขนุน',
  'บางขวัญ',
  'บางขะแยง',
  'บางขัน',
  'บางขันหมาก',
  'บางขันแตก',
  'บางขาม',
  'บางขุด',
  'บางขุนกอง',
  'บางขุนทอง',
  'บางขุนนนท์',
  'บางขุนพรหม',
  'บางขุนศรี',
  'บางขุนเทียน',
  'บางขุนไทร',
  'บางคนที',
  'บางครก',
  'บางครุ',
  'บางคลาน',
  'บางคล้า',
  'บางคอแหลม',
  'บางคา',
  'บางคูรัด',
  'บางคูวัด',
  'บางคูเวียง',
  'บางคู้',
  'บางค้อ',
  'บางงอน',
  'บางงา',
  'บางงาม',
  'บางจะเกร็ง',
  'บางจัก',
  'บางจาก',
  'บางจาน',
  'บางชนะ',
  'บางชะนี',
  'บางชัน',
  'บางช้าง',
  'บางซื่อ',
  'บางซ่อน',
  'บางซ้าย',
  'บางดี',
  'บางด้วน',
  'บางตลาด',
  'บางตะบูน',
  'บางตะบูนออก',
  'บางตะพง',
  'บางตะเคียน',
  'บางตะไนย์',
  'บางตาวา',
  'บางตาหงาย',
  'บางตาเถร',
  'บางตีนเป็ด',
  'บางทราย',
  'บางทรายน้อย',
  'บางทรายใหญ่',
  'บางทอง',
  'บางนกแขวก',
  'บางนบ',
  'บางนมโค',
  'บางนอน',
  'บางนา',
  'บางนาค',
  'บางนาง',
  'บางนางร้า',
  'บางนางลี่',
  'บางนายสี',
  'บางนาเหนือ',
  'บางนาใต้',
  'บางน้ำจืด',
  'บางน้ำผึ้ง',
  'บางน้ำเชี่ยว',
  'บางน้ำเปรี้ยว',
  'บางบริบูรณ์',
  'บางบอน',
  'บางบอนเหนือ',
  'บางบอนใต้',
  'บางบัวทอง',
  'บางบาล',
  'บางบำหรุ',
  'บางบุตร',
  'บางบ่อ',
  'บางปรอก',
  'บางประมุง',
  'บางประแดง',
  'บางปลา',
  'บางปลากด',
  'บางปลาม้า',
  'บางปลาร้า',
  'บางปลาสร้อย',
  'บางปอ',
  'บางปะกง',
  'บางปะกอก',
  'บางปะหัน',
  'บางปิด',
  'บางปู',
  'บางปูใหม่',
  'บางป่า',
  'บางผึ้ง',
  'บางพรม',
  'บางพระ',
  'บางพระครู',
  'บางพระหลวง',
  'บางพระเหนือ',
  'บางพระใต้',
  'บางพลวง',
  'บางพลัด',
  'บางพลับ',
  'บางพลี',
  'บางพลีน้อย',
  'บางพลีใหญ่',
  'บางพึ่ง',
  'บางพุทรา',
  'บางพูด',
  'บางพูน',
  'บางภาษี',
  'บางมด',
  'บางมะฝ่อ',
  'บางมะพร้าว',
  'บางมะเดื่อ',
  'บางมัญ',
  'บางมูลนาก',
  'บางม่วง',
  'บางยอ',
  'บางยาง',
  'บางยี่ขัน',
  'บางยี่รงค์',
  'บางยี่เรือ',
  'บางยี่โท',
  'บางระกำ',
  'บางระจัน',
  'บางระมาด',
  'บางรัก',
  'บางรักน้อย',
  'บางรักพัฒนา',
  'บางรักใหญ่',
  'บางริ้น',
  'บางรูป',
  'บางละมุง',
  'บางลาย',
  'บางลำภูล่าง',
  'บางลี่',
  'บางลึก',
  'บางลูกเสือ',
  'บางวัน',
  'บางวัว',
  'บางศรีเมือง',
  'บางศาลา',
  'บางสน',
  'บางสมบูรณ์',
  'บางสมัคร',
  'บางสระเก้า',
  'บางสวน',
  'บางสวรรค์',
  'บางสะพาน',
  'บางสะแก',
  'บางสัก',
  'บางสีทอง',
  'บางหญ้าแพรก',
  'บางหมาก',
  'บางหลวง',
  'บางหลวงโดด',
  'บางหว้า',
  'บางหัก',
  'บางหัวเสือ',
  'บางหิน',
  'บางอ้อ',
  'บางเกลือ',
  'บางเก่า',
  'บางเขน',
  'บางเขา',
  'บางเขียด',
  'บางเคียน',
  'บางเค็ม',
  'บางเจ้าฉ่า',
  'บางเชือกหนัง',
  'บางเดชะ',
  'บางเดือน',
  'บางเดื่อ',
  'บางเตย',
  'บางเป้า',
  'บางเพรียง',
  'บางเพลิง',
  'บางเมือง',
  'บางเมืองใหม่',
  'บางเลน',
  'บางเล่า',
  'บางเสด็จ',
  'บางเสร่',
  'บางเสาธง',
  'บางเหรียง',
  'บางแก้ว',
  'บางแก้วฟ้า',
  'บางแขม',
  'บางแค',
  'บางแคเหนือ',
  'บางแตน',
  'บางแพ',
  'บางแม่นาง',
  'บางแวก',
  'บางโกระ',
  'บางโขมด',
  'บางโคล่',
  'บางโฉลง',
  'บางโตนด',
  'บางโทรัด',
  'บางโปรง',
  'บางโพงพาง',
  'บางโพธิ์',
  'บางโพธิ์เหนือ',
  'บางโรง',
  'บางใบไม้',
  'บางใหญ่',
  'บางไทร',
  'บางไทรป่า',
  'บางไผ่',
  'บาตง',
  'บานา',
  'บาราเฮาะ',
  'บาราโหม',
  'บาลอ',
  'บาละ',
  'บาเจาะ',
  'บาเระเหนือ',
  'บาเระใต้',
  'บาโงย',
  'บาโงยซิแน',
  'บาโงสะโต',
  'บาโร๊ะ',
  'บาโลย',
  'บาโหย',
  'บิง',
  'บึง',
  'บึงกระจับ',
  'บึงกอก',
  'บึงกาสาม',
  'บึงกาฬ',
  'บึงคอไห',
  'บึงคำพร้อย',
  'บึงงาม',
  'บึงชำอ้อ',
  'บึงทวาย',
  'บึงทองหลาง',
  'บึงทับแรต',
  'บึงนคร',
  'บึงนาราง',
  'บึงนาเรียง',
  'บึงน้ำรักษ์',
  'บึงบอน',
  'บึงบัว',
  'บึงบา',
  'บึงบูรพ์',
  'บึงปรือ',
  'บึงปลาทู',
  'บึงพระ',
  'บึงพะไล',
  'บึงมะลู',
  'บึงยี่โถ',
  'บึงวิชัย',
  'บึงศาล',
  'บึงสนั่น',
  'บึงสามพัน',
  'บึงสามัคคี',
  'บึงสำโรง',
  'บึงอ้อ',
  'บึงเกลือ',
  'บึงเจริญ',
  'บึงเนียม',
  'บึงเสนาท',
  'บึงแก',
  'บึงโขงหลง',
  'บือมัง',
  'บือเระ',
  'บุกระสัง',
  'บุคคโล',
  'บุญทัน',
  'บุญนาคพัฒนา',
  'บุญเกิด',
  'บุญเรือง',
  'บุดี',
  'บุฝ้าย',
  'บุพราหมณ์',
  'บุฤาษี',
  'บุสูง',
  'บุฮม',
  'บุเปือย',
  'บุแกรง',
  'บุโพธิ์',
  'บุ่ง',
  'บุ่งขี้เหล็ก',
  'บุ่งคล้า',
  'บุ่งค้า',
  'บุ่งน้ำเต้า',
  'บุ่งมะแลง',
  'บุ่งหวาย',
  'บุ่งเลิศ',
  'บุ่งแก้ว',
  'บุ่งไหม',
  'บูกิต',
  'บ่อ',
  'บ่อกระดาน',
  'บ่อกรุ',
  'บ่อกวางทอง',
  'บ่อดาน',
  'บ่อตรุ',
  'บ่อตาโล่',
  'บ่อถ้ำ',
  'บ่อทอง',
  'บ่อนอก',
  'บ่อน้ำร้อน',
  'บ่อปลาทอง',
  'บ่อผุด',
  'บ่อพลอย',
  'บ่อพลับ',
  'บ่อพันขัน',
  'บ่อพุ',
  'บ่อภาค',
  'บ่อยาง',
  'บ่อรัง',
  'บ่อวิน',
  'บ่อสลี',
  'บ่อสวก',
  'บ่อสุพรรณ',
  'บ่อหลวง',
  'บ่อหิน',
  'บ่อเกลือเหนือ',
  'บ่อเกลือใต้',
  'บ่อเงิน',
  'บ่อเบี้ย',
  'บ่อเวฬุ',
  'บ่อเหล็กลอง',
  'บ่อแก้ว',
  'บ่อแดง',
  'บ่อแร่',
  'บ่อแสน',
  'บ่อแฮ้ว',
  'บ่อโพง',
  'บ่อโพธิ์',
  'บ่อใหญ่',
  'บ่อไทย',
  'บ้องตี้',
  'บ้านกง',
  'บ้านกรด',
  'บ้านกรวด',
  'บ้านกระทุ่ม',
  'บ้านกระแชง',
  'บ้านกร่าง',
  'บ้านกลับ',
  'บ้านกลาง',
  'บ้านกลึง',
  'บ้านกล้วย',
  'บ้านกวาง',
  'บ้านกอก',
  'บ้านกาด',
  'บ้านกาศ',
  'บ้านกิ่ว',
  'บ้านกุ่ม',
  'บ้านกู่',
  'บ้านก้อง',
  'บ้านขล้อ',
  'บ้านขวาง',
  'บ้านขอ',
  'บ้านขาม',
  'บ้านขาว',
  'บ้านข่อย',
  'บ้านข่า',
  'บ้านครัว',
  'บ้านคลอง',
  'บ้านคลองสวน',
  'บ้านคลัง',
  'บ้านควน',
  'บ้านควนมุด',
  'บ้านคา',
  'บ้านคู',
  'บ้านค่า',
  'บ้านค่าย',
  'บ้านค้อ',
  'บ้านฆ้อง',
  'บ้านงิ้ว',
  'บ้านจันทน์',
  'บ้านจันทร์',
  'บ้านจั่น',
  'บ้านจาน',
  'บ้านจารย์',
  'บ้านจีต',
  'บ้านจ่า',
  'บ้านฉาง',
  'บ้านชบ',
  'บ้านชวน',
  'บ้านชะอวด',
  'บ้านชัย',
  'บ้านชี',
  'บ้านชุ้ง',
  'บ้านช่างหล่อ',
  'บ้านช้าง',
  'บ้านซ่ง',
  'บ้านซ่อง',
  'บ้านซ่าน',
  'บ้านดง',
  'บ้านดอน',
  'บ้านดารา',
  'บ้านดุง',
  'บ้านดู่',
  'บ้านด่าน',
  'บ้านด่านนาขาม',
  'บ้านด้าย',
  'บ้านตะโก',
  'บ้านตาด',
  'บ้านตาล',
  'บ้านติ้ว',
  'บ้านตึก',
  'บ้านตุ่น',
  'บ้านตูม',
  'บ้านตูล',
  'บ้านต้อง',
  'บ้านต้อน',
  'บ้านต้าย',
  'บ้านต๊ำ',
  'บ้านต๋อม',
  'บ้านถิ่น',
  'บ้านถ่อน',
  'บ้านถ้ำ',
  'บ้านทราย',
  'บ้านทับ',
  'บ้านทาน',
  'บ้านทาม',
  'บ้านทำเนียบ',
  'บ้านทุ่ม',
  'บ้านธาตุ',
  'บ้านธิ',
  'บ้านนอก',
  'บ้านนา',
  'บ้านนิคม',
  'บ้านน้อย',
  'บ้านน้อยซุ้มขี้เหล็ก',
  'บ้านน้ำบ่อ',
  'บ้านน้ำพุ',
  'บ้านบอม',
  'บ้านบัว',
  'บ้านบาก',
  'บ้านบาตร',
  'บ้านบึง',
  'บ้านบุ่ง',
  'บ้านบ่อ',
  'บ้านปง',
  'บ้านปทุม',
  'บ้านปรก',
  'บ้านปรางค์',
  'บ้านปราโมทย์',
  'บ้านปรือ',
  'บ้านปวง',
  'บ้านปิน',
  'บ้านปึก',
  'บ้านป่า',
  'บ้านป้อม',
  'บ้านผึ้ง',
  'บ้านผือ',
  'บ้านฝาง',
  'บ้านฝาย',
  'บ้านพระ',
  'บ้านพราน',
  'บ้านพริก',
  'บ้านพรุ',
  'บ้านพร้าว',
  'บ้านพลวง',
  'บ้านพลับ',
  'บ้านพานถม',
  'บ้านพี้',
  'บ้านฟ้า',
  'บ้านมะเกลือ',
  'บ้านมาง',
  'บ้านมุง',
  'บ้านม่วง',
  'บ้านม้า',
  'บ้านยวด',
  'บ้านยา',
  'บ้านยาง',
  'บ้านระกาศ',
  'บ้านราม',
  'บ้านราษฎร์',
  'บ้านรี',
  'บ้านรุน',
  'บ้านร่อม',
  'บ้านร้อง',
  'บ้านลาด',
  'บ้านลาน',
  'บ้านลำ',
  'บ้านลำนาว',
  'บ้านลี่',
  'บ้านวัง',
  'บ้านว่าน',
  'บ้านสระ',
  'บ้านสร้าง',
  'บ้านสวน',
  'บ้านสหกรณ์',
  'บ้านสา',
  'บ้านสาง',
  'บ้านสิงห์',
  'บ้านส้อง',
  'บ้านหนุน',
  'บ้านหมอ',
  'บ้านหมี่',
  'บ้านหม้อ',
  'บ้านหยวก',
  'บ้านหลวง',
  'บ้านหลุม',
  'บ้านหวด',
  'บ้านหวาย',
  'บ้านหว้า',
  'บ้านหอย',
  'บ้านหัน',
  'บ้านหาด',
  'บ้านหาร',
  'บ้านหินโงม',
  'บ้านหีบ',
  'บ้านอิฐ',
  'บ้านอ้อน',
  'บ้านเกาะ',
  'บ้านเก่า',
  'บ้านเขว้า',
  'บ้านเขือง',
  'บ้านเจียง',
  'บ้านเชียง',
  'บ้านเชี่ยน',
  'บ้านเซิด',
  'บ้านเดื่อ',
  'บ้านเต่า',
  'บ้านเนิน',
  'บ้านเบิก',
  'บ้านเป็ด',
  'บ้านเป้า',
  'บ้านเพชร',
  'บ้านเพิง',
  'บ้านเพิ่ม',
  'บ้านเม็ง',
  'บ้านเรือ',
  'บ้านเรือน',
  'บ้านเลน',
  'บ้านเลือก',
  'บ้านเลื่อม',
  'บ้านเล่า',
  'บ้านเวียง',
  'บ้านเสด็จ',
  'บ้านเสียว',
  'บ้านเสี้ยว',
  'บ้านเหนือ',
  'บ้านเหลื่อม',
  'บ้านเหล่า',
  'บ้านเอื้อง',
  'บ้านเอื้อม',
  'บ้านแก่ง',
  'บ้านแก้ง',
  'บ้านแขม',
  'บ้านแค',
  'บ้านแจ้ง',
  'บ้านแซว',
  'บ้านแดง',
  'บ้านแดน',
  'บ้านแถว',
  'บ้านแท่น',
  'บ้านแปรง',
  'บ้านแปะ',
  'บ้านแป้ง',
  'บ้านแป้น',
  'บ้านแพ',
  'บ้านแพง',
  'บ้านแพน',
  'บ้านแพรก',
  'บ้านแพ้ว',
  'บ้านแม',
  'บ้านแมด',
  'บ้านแยง',
  'บ้านแร่',
  'บ้านแลง',
  'บ้านแวง',
  'บ้านแห',
  'บ้านแหง',
  'บ้านแหร',
  'บ้านแหลม',
  'บ้านแหวน',
  'บ้านแอ่น',
  'บ้านแฮด',
  'บ้านโขด',
  'บ้านโข้ง',
  'บ้านโคก',
  'บ้านโคน',
  'บ้านโตก',
  'บ้านโต้น',
  'บ้านโนน',
  'บ้านโปร่ง',
  'บ้านโป่ง',
  'บ้านโพ',
  'บ้านโพธิ์',
  'บ้านโพน',
  'บ้านโภชน์',
  'บ้านโสก',
  'บ้านโหนด',
  'บ้านโฮ่ง',
  'บ้านใต้',
  'บ้านในดง',
  'บ้านใหญ่',
  'บ้านใหม่',
  'บ้านใหม่คลองเคียน',
  'บ้านใหม่สามัคคี',
  'บ้านใหม่สุขเกษม',
  'บ้านใหม่หนองไทร',
  'บ้านใหม่ไชยมงคล',
  'บ้านไทย',
  'บ้านไทร',
  'บ้านไผ่',
  'บ้านไร่',
  'บ้าหวี',
  'ปกาสัย',
  'ปง',
  'ปงดอน',
  'ปงตำ',
  'ปงน้อย',
  'ปงป่าหวาย',
  'ปงยางคก',
  'ปงสนุก',
  'ปงเตา',
  'ปงแสนทอง',
  'ปทุม',
  'ปทุมวัน',
  'ปทุมวาปี',
  'ประกอบ',
  'ประจวบคีรีขันธ์',
  'ประจัน',
  'ประจันตคาม',
  'ประชาธิปัตย์',
  'ประชาพัฒนา',
  'ประชาสุขสันต์',
  'ประณีต',
  'ประดาง',
  'ประดู่',
  'ประดู่งาม',
  'ประดู่ยืน',
  'ประตูชัย',
  'ประตูป่า',
  'ประทัดบุ',
  'ประทาย',
  'ประศุก',
  'ประสงค์',
  'ประสาทสิทธิ์',
  'ประสุข',
  'ประเวศ',
  'ประโคนชัย',
  'ปรังเผล',
  'ปรางหมู่',
  'ปราณบุรี',
  'ปราสาท',
  'ปราสาททนง',
  'ปราสาททอง',
  'ปราสาทเยอ',
  'ปริก',
  'ปรือ',
  'ปรือใหญ่',
  'ปรุใหญ่',
  'ปลวกแดง',
  'ปลักหนู',
  'ปลักแรด',
  'ปลาค้าว',
  'ปลาบ่า',
  'ปลาปาก',
  'ปลายกลัด',
  'ปลายนา',
  'ปลายบาง',
  'ปลายพระยา',
  'ปลายโพงพาง',
  'ปลาโหล',
  'ปล่องหอย',
  'ปล้อง',
  'ปวนพุ',
  'ปอ',
  'ปอน',
  'ปอพาน',
  'ปอภาร (ปอพาน)',
  'ปอแดง',
  'ปะกาฮะรัง',
  'ปะคำ',
  'ปะตง',
  'ปะนาเระ',
  'ปะลุกาสาเมาะ',
  'ปะลุรู',
  'ปะหลาน',
  'ปะอาว',
  'ปะเคียบ',
  'ปะเสยะวอ',
  'ปะเหลียน',
  'ปะแต',
  'ปะโค',
  'ปะโด',
  'ปังกู',
  'ปังหวาน',
  'ปัถวี',
  'ปันแต',
  'ปัว',
  'ปากกราน',
  'ปากกาง',
  'ปากข้าวสาร',
  'ปากคม',
  'ปากคลอง',
  'ปากคลองบางปลากด',
  'ปากคลองภาษีเจริญ',
  'ปากคาด',
  'ปากจั่น',
  'ปากฉลุย',
  'ปากชม',
  'ปากช่อง',
  'ปากดุก',
  'ปากตม',
  'ปากตะโก',
  'ปากทรง',
  'ปากทะเล',
  'ปากทาง',
  'ปากท่อ',
  'ปากท่า',
  'ปากนคร',
  'ปากน้ำ',
  'ปากน้ำกระแส',
  'ปากน้ำปราณ',
  'ปากน้ำแหลมสิงห์',
  'ปากน้ำโพ',
  'ปากบาง',
  'ปากบ่อง',
  'ปากปวน',
  'ปากพนัง',
  'ปากพนังฝั่งตะวันตก',
  'ปากพนังฝั่งตะวันออก',
  'ปากพระ',
  'ปากพลี',
  'ปากพะยูน',
  'ปากพูน',
  'ปากรอ',
  'ปากล่อ',
  'ปากหมัน',
  'ปากหมาก',
  'ปากู',
  'ปากเกร็ด',
  'ปากเพรียว',
  'ปากแคว',
  'ปากแจ่ม',
  'ปากแตระ',
  'ปากแพรก',
  'ปากแรต',
  'ปากโทก',
  'ปางกู่',
  'ปางตาไว',
  'ปางมะค่า',
  'ปางมะผ้า',
  'ปางสวรรค์',
  'ปางหมู',
  'ปางหินฝน',
  'ปาดังเบซาร์',
  'ปานัน',
  'ปาฝา',
  'ปาล์มพัฒนา',
  'ปาเสมัส',
  'ปิงหลวง',
  'ปิงโค้ง',
  'ปิตูมุดี',
  'ปิยามุมัง',
  'ปิล๊อก',
  'ปึกเตียน',
  'ปุยุด',
  'ปุลากง',
  'ปุโรง',
  'ปุโละปุโย',
  'ปูยู',
  'ปูโยะ',
  'ป่งขาม',
  'ป่งไฮ',
  'ป่ากลาง',
  'ป่ากอ',
  'ป่ากุมเกาะ',
  'ป่าก่อ',
  'ป่าก่อดำ',
  'ป่าขะ',
  'ป่าขาด',
  'ป่าคลอก',
  'ป่าคา',
  'ป่าคาย',
  'ป่าคาหลวง',
  'ป่างิ้ว',
  'ป่าชัน',
  'ป่าชิง',
  'ป่าซาง',
  'ป่าตอง',
  'ป่าตัน',
  'ป่าตาล',
  'ป่าตึง',
  'ป่าตุ้ม',
  'ป่าบง',
  'ป่าบอน',
  'ป่าปอ',
  'ป่าป้อง',
  'ป่าพลู',
  'ป่าพะยอม',
  'ป่าพุทรา',
  'ป่ามะคาบ',
  'ป่ามะนาว',
  'ป่ามะม่วง',
  'ป่ายุบใน',
  'ป่าระกำ',
  'ป่าร่อน',
  'ป่าลาน',
  'ป่าสะแก',
  'ป่าสัก',
  'ป่าสังข์',
  'ป่าหวาย',
  'ป่าหวายนั่ง',
  'ป่าหุ่ง',
  'ป่าอ้อ',
  'ป่าอ้อดอนชัย',
  'ป่าเซ่า',
  'ป่าเด็ง',
  'ป่าเมี่ยง',
  'ป่าเลา',
  'ป่าเว',
  'ป่าแก่บ่อหิน',
  'ป่าแงะ',
  'ป่าแดง',
  'ป่าแดด',
  'ป่าแป๋',
  'ป่าแฝก',
  'ป่าแมต',
  'ป่าแลวหลวง',
  'ป่าโปง',
  'ป่าโมก',
  'ป่าโมง',
  'ป่าไก่',
  'ป่าไผ่',
  'ป่าไม้งาม',
  'ป่าไร่',
  'ป่าไหน่',
  'ป้อมปราบ',
  'ผดุงมาตร',
  'ผักขวง',
  'ผักขะ',
  'ผักตบ',
  'ผักปัง',
  'ผักแพว',
  'ผักแว่น',
  'ผักไหม',
  'ผักไห่',
  'ผาขาว',
  'ผางาม',
  'ผาจุก',
  'ผาช้างน้อย',
  'ผาตอ',
  'ผาตั้ง',
  'ผาทอง',
  'ผานกเค้า',
  'ผาน้อย',
  'ผาน้ำย้อย',
  'ผาบิ้ง',
  'ผาบ่อง',
  'ผาปัง',
  'ผาสามยอด',
  'ผาสิงห์',
  'ผาสุก',
  'ผาอินทร์แปลง',
  'ผาเลือด',
  'ผาเสวย',
  'ผึ่งแดด',
  'ผึ้งรวง',
  'ผือฮี',
  'ผือใหญ่',
  'ผไทรินทร์',
  'ผ่านศึก',
  'ฝั่งแดง',
  'ฝางคำ',
  'ฝายกวาง',
  'ฝายนาแซง',
  'ฝายหลวง',
  'ฝายแก้ว',
  'ฝาละมี',
  'พงตึก',
  'พงศ์ประศาสน์',
  'พงษ์',
  'พงสวาย',
  'พญาขัน',
  'พญาวัง',
  'พญาเย็น',
  'พญาแก้ว',
  'พญาแมน',
  'พญาไท',
  'พนม',
  'พนมทวน',
  'พนมรอก',
  'พนมวังก์',
  'พนมสารคาม',
  'พนมเศษ',
  'พนมไพร',
  'พนอม',
  'พนัสนิคม',
  'พนา',
  'พนางตุง',
  'พนานิคม',
  'พบพระ',
  'พยอม',
  'พยุหะ',
  'พยุห์',
  'พรมสวรรค์',
  'พรมเทพ',
  'พรรณา',
  'พรสวรรค์',
  'พรสำราญ',
  'พรหมณี',
  'พรหมนิมิต',
  'พรหมบุรี',
  'พรหมพิราม',
  'พรหมมาสตร์',
  'พรหมสวัสดิ์',
  'พรหมโลก',
  'พระกลางทุ่ง',
  'พระขาว',
  'พระครู',
  'พระงาม',
  'พระซอง',
  'พระธาตุ',
  'พระธาตุขิงแกง',
  'พระธาตุบังพวน',
  'พระธาตุผาแดง',
  'พระนอน',
  'พระบรมมหาราชวัง',
  'พระบาท',
  'พระบาทนาสิงห์',
  'พระบาทวังตวง',
  'พระบุ',
  'พระปฐมเจดีย์',
  'พระประโทน',
  'พระพุทธ',
  'พระพุทธบาท',
  'พระยาทด',
  'พระยาบันลือ',
  'พระยืน',
  'พระรักษ์',
  'พระลับ',
  'พระสิงห์',
  'พระหลวง',
  'พระอาจารย์',
  'พระเจ้า',
  'พระเพลิง',
  'พระเสาร์',
  'พระเหลา',
  'พระแก้ว',
  'พระแท่น',
  'พระโขนง',
  'พระโขนงเหนือ',
  'พราน',
  'พรานกระต่าย',
  'พรุดินนา',
  'พรุพี',
  'พรุเตียว',
  'พรุใน',
  'พรุไทย',
  'พรเจริญ',
  'พร่อน',
  'พลกรัง',
  'พลงตาเอี่ยม',
  'พลวง',
  'พลวงทอง',
  'พลวงสองนาง',
  'พลสงคราม',
  'พลอยแหวน',
  'พลับพลา',
  'พลับพลาไชย',
  'พลา',
  'พลายชุมพล',
  'พลายวาส',
  'พลิ้ว',
  'พลูตาหลวง',
  'พลูเถื่อน',
  'พวา',
  'พอกน้อย',
  'พะงาด',
  'พะตง',
  'พะทาย',
  'พะลาน',
  'พะวง',
  'พะวอ',
  'พะเนา',
  'พะเนียด',
  'พะแสง',
  'พะโต๊ะ',
  'พักทัน',
  'พังกาญจน์',
  'พังขว้าง',
  'พังงู',
  'พังตรุ',
  'พังทุย',
  'พังยาง',
  'พังราด',
  'พังลา',
  'พังเคน',
  'พังเทียม',
  'พังแดง',
  'พังโคน',
  'พัฒนาการ',
  'พัฒนานิคม',
  'พันชนะ',
  'พันชาลี',
  'พันดอน',
  'พันดุง',
  'พันท้ายนรสิงห์',
  'พันนา',
  'พันลาน',
  'พันเสา',
  'พานทอง',
  'พานพร้าว',
  'พิกุล',
  'พิกุลทอง',
  'พิกุลออก',
  'พิงพวย',
  'พิจิตร',
  'พิชัย',
  'พิตเพียน',
  'พิบูล',
  'พิปูน',
  'พิมพา',
  'พิมลราช',
  'พิมาน',
  'พิมาย',
  'พิมายเหนือ',
  'พิมูล',
  'พิหารแดง',
  'พิเทน',
  'พืชอุดม',
  'พุกร่าง',
  'พุขาม',
  'พุคา',
  'พุคำจาน',
  'พุดซา',
  'พุทธบาท',
  'พุทเลา',
  'พุทไธสง',
  'พุนกยูง',
  'พุนพิน',
  'พุมเรียง',
  'พุสวรรค์',
  'พุเตย',
  'พุแค',
  'พุ่มแก',
  'พ่วงพรมคร',
  'พ่อมิ่ง',
  'พ้อแดง',
  'ฟากท่า',
  'ฟากห้วย',
  'ฟ้าหยาด',
  'ฟ้าห่วน',
  'ฟ้าฮ่าม',
  'ภาชี',
  'ภารแอ่น',
  'ภูกระดึง',
  'ภูคา',
  'ภูซาง',
  'ภูดิน',
  'ภูน้ำหยด',
  'ภูปอ',
  'ภูผาม่าน',
  'ภูผาหมอก',
  'ภูฝ้าย',
  'ภูฟ้า',
  'ภูมิ',
  'ภูวง',
  'ภูสิงห์',
  'ภูหลวง',
  'ภูหอ',
  'ภูห่าน',
  'ภูเขาทอง',
  'ภูเงิน',
  'ภูเวียง',
  'ภูเหล็ก',
  'ภูแลนคา',
  'ภูแล่นช้าง',
  'มงคลธรรมนิมิต',
  'มดแดง',
  'มวกเหล็ก',
  'มหาชัย',
  'มหาดไทย',
  'มหาพราหมณ์',
  'มหาพฤฒาราม',
  'มหาราช',
  'มหาวัน',
  'มหาสวัสดิ์',
  'มหาสอน',
  'มหาโพธิ',
  'มหาไชย',
  'มะกรูด',
  'มะกอก',
  'มะกอกหวาน',
  'มะกอกเหนือ',
  'มะขาม',
  'มะขามคู่',
  'มะขามล้ม',
  'มะขามสูง',
  'มะขามหย่ง',
  'มะขามหลวง',
  'มะขามเฒ่า',
  'มะขามเตี้ย',
  'มะขุนหวาน',
  'มะค่า',
  'มะตูม',
  'มะต้อง',
  'มะนังดาลำ',
  'มะนังตายอ',
  'มะนังยง',
  'มะนาวหวาน',
  'มะบ้า',
  'มะมุ',
  'มะม่วงสองต้น',
  'มะรือโบตก',
  'มะรือโบออก',
  'มะรุ่ย',
  'มะลวน',
  'มะลิกา',
  'มะอึ',
  'มะเกลือเก่า',
  'มะเกลือใหม่',
  'มะเขือแจ้',
  'มะเฟือง',
  'มะเริง',
  'มะเร็ต',
  'มักกะสัน',
  'มาบกราด',
  'มาบข่า',
  'มาบตะโกเอน',
  'มาบตาพุด',
  'มาบปลาเค้า',
  'มาบยางพร',
  'มาบแก',
  'มาบแค',
  'มาบโป่ง',
  'มาบไผ่',
  'มาบไพ',
  'มาย',
  'มายอ',
  'มารวิชัย',
  'มาโมง',
  'มิตรภาพ',
  'มีชัย',
  'มีนบุรี',
  'มืดกา',
  'มุกดาหาร',
  'มุจลินท์',
  'มูโนะ',
  'ม่วง',
  'ม่วงกลวง',
  'ม่วงคำ',
  'ม่วงค่อม',
  'ม่วงงาม',
  'ม่วงชุม',
  'ม่วงตึ๊ด',
  'ม่วงนา',
  'ม่วงน้อย',
  'ม่วงยาย',
  'ม่วงลาด',
  'ม่วงลาย',
  'ม่วงสามสิบ',
  'ม่วงหมู่',
  'ม่วงหวาน',
  'ม่วงหัก',
  'ม่วงเจ็ดต้น',
  'ม่วงเตี้ย',
  'ม่วงใหญ่',
  'ม่วงไข่',
  'ม่อนจอง',
  'ม่อนปิ่น',
  'ยกกระบัตร',
  'ยม',
  'ยอด',
  'ยอดชาด',
  'ยอดแกง',
  'ยะต๊ะ',
  'ยะรม',
  'ยะรัง',
  'ยะลา',
  'ยะวึก',
  'ยะหา',
  'ยั้งเมิน',
  'ยาง',
  'ยางขาว',
  'ยางขี้นก',
  'ยางคราม',
  'ยางคำ',
  'ยางค้อม',
  'ยางงาม',
  'ยางชุมน้อย',
  'ยางชุมใหญ่',
  'ยางช้าย',
  'ยางซ้าย',
  'ยางตลาด',
  'ยางตาล',
  'ยางท่าแจ้ง',
  'ยางนอน',
  'ยางน้อย',
  'ยางน้ำกลัดเหนือ',
  'ยางน้ำกลัดใต้',
  'ยางม่วง',
  'ยางราก',
  'ยางสว่าง',
  'ยางสักกระโพหลุ่ม',
  'ยางสาว',
  'ยางสีสุราช',
  'ยางสูง',
  'ยางหย่อง',
  'ยางหล่อ',
  'ยางหวาย',
  'ยางหัก',
  'ยางอู้ม',
  'ยางฮอม',
  'ยางเนิ้ง',
  'ยางเปียง',
  'ยางโกลน',
  'ยางโทน',
  'ยางโยภาพ',
  'ยางใหญ่',
  'ยานนาวา',
  'ยาบหัวนา',
  'ยาบี',
  'ยามู',
  'ยายชา',
  'ยายร้า',
  'ยายแพง',
  'ยายแย้มวัฒนา',
  'ยี่งอ',
  'ยี่ล้น',
  'ยี่สาร',
  'ยุหว่า',
  'ยุโป',
  'ยุ้งทะลาย',
  'ย่อ',
  'ย่านซื่อ',
  'ย่านตาขาว',
  'ย่านมัทรี',
  'ย่านยาว',
  'ย่านรี',
  'รมณีย์',
  'รวมไทยพัฒนา',
  'รองเมือง',
  'รอบเมือง',
  'รอบเวียง',
  'ระบำ',
  'ระวะ',
  'ระวิง',
  'ระหาน',
  'ระเริง',
  'ระเว',
  'ระเวียง',
  'ระแงง',
  'ระแว้ง',
  'ระแหง',
  'ระโนด',
  'ระโสม',
  'รังกาใหญ่',
  'รังงาม',
  'รังนก',
  'รังสิต',
  'รังแร้ง',
  'รัชดาภิเษก',
  'รัตนบุรี',
  'รัตนวาปี',
  'รัตนวารี',
  'รัตภูมิ',
  'รับร่อ',
  'รัษฎา',
  'รั้วใหญ่',
  'รางจรเข้',
  'รางบัว',
  'รางพิกุล',
  'รางสาลี่',
  'รางหวาย',
  'ราชกรูด',
  'ราชคราม',
  'ราชธานี',
  'ราชสถิตย์',
  'ราชาเทวะ',
  'ราตาปันยัง',
  'ราม',
  'รามราช',
  'รามอินทรา',
  'รามแก้ว',
  'ราวต้นจันทร์',
  'ราษฎรพัฒนา',
  'ราษฎร์นิยม',
  'ราษฎร์บูรณะ',
  'ราษฎร์พัฒนา',
  'ราษฎร์เจริญ',
  'ราไวย์',
  'รำพัน',
  'รำมะสัก',
  'รำแดง',
  'ริม',
  'ริมกก',
  'ริมปิง',
  'ริมสีม่วง',
  'ริมเหนือ',
  'ริมโขง',
  'ริมใต้',
  'ริโก๋',
  'รือเสาะ',
  'รือเสาะออก',
  'รุง',
  'รุ่งระวี',
  'รูสะมิแล',
  'ร่มเกล้า',
  'ร่มเมือง',
  'ร่มเย็น',
  'ร่มไทร',
  'ร่วมจิต',
  'ร่องกาศ',
  'ร่องคำ',
  'ร่องจิก',
  'ร่องฟอง',
  'ร่องเคาะ',
  'ร่อนทอง',
  'ร่อนพิบูลย์',
  'ร้องกวาง',
  'ร้องวัวแดง',
  'ร้องเข็ม',
  'ลมศักดิ์',
  'ลวงเหนือ',
  'ลอ',
  'ลอมคอม',
  'ละงู',
  'ละทาย',
  'ละมอ',
  'ละลม',
  'ละลมใหม่พัฒนา',
  'ละลวด',
  'ละลาย',
  'ละหาน',
  'ละหานทราย',
  'ละหานนา',
  'ละหานปลาค้าว',
  'ละหาร',
  'ละอาย',
  'ละอุ่นเหนือ',
  'ละอุ่นใต้',
  'ละเวี้ย',
  'ละเอาะ',
  'ละแม',
  'ละแอ',
  'ลางา',
  'ลาดกระทิง',
  'ลาดกระบัง',
  'ลาดขวาง',
  'ลาดควาย',
  'ลาดค่าง',
  'ลาดงา',
  'ลาดชิด',
  'ลาดตะเคียน',
  'ลาดทิพรส',
  'ลาดน้ำเค็ม',
  'ลาดบัวขาว',
  'ลาดบัวหลวง',
  'ลาดพร้าว',
  'ลาดพัฒนา',
  'ลาดยาว',
  'ลาดสวาย',
  'ลาดสาลี่',
  'ลาดหญ้า',
  'ลาดหลุมแก้ว',
  'ลาดแค',
  'ลาดโพธิ์',
  'ลาดใหญ่',
  'ลานกระบือ',
  'ลานข่อย',
  'ลานดอกไม้',
  'ลานดอกไม้ตก',
  'ลานตากฟ้า',
  'ลานบ่า',
  'ลานสกา',
  'ลานสะแก',
  'ลานสัก',
  'ลานหอย',
  'ลาโละ',
  'ลำคลอง',
  'ลำคอหงษ์',
  'ลำชี',
  'ลำดวน',
  'ลำตะเคียน',
  'ลำตาเสา',
  'ลำต้อยติ่ง',
  'ลำทับ',
  'ลำนางรอง',
  'ลำนางแก้ว',
  'ลำนารายณ์',
  'ลำประดา',
  'ลำปลาทิว',
  'ลำปลายมาศ',
  'ลำปางหลวง',
  'ลำปาว',
  'ลำปำ',
  'ลำผักกูด',
  'ลำผักชี',
  'ลำพญา',
  'ลำพญากลาง',
  'ลำพยนต์',
  'ลำพยา',
  'ลำพะยา',
  'ลำพาน',
  'ลำพูน',
  'ลำภี',
  'ลำภู',
  'ลำภูรา',
  'ลำมูล',
  'ลำลูกกา',
  'ลำลูกบัว',
  'ลำสนธิ',
  'ลำสมพุง',
  'ลำสินธุ์',
  'ลำหนองแสน',
  'ลำห้วยหลัว',
  'ลำเพียก',
  'ลำเลียง',
  'ลำเหย',
  'ลำแก่น',
  'ลำโพ',
  'ลำใหม่',
  'ลำไทร',
  'ลำไทรโยง',
  'ลำไพล',
  'ลิดล',
  'ลิปะน้อย',
  'ลิปะสะโง',
  'ลิพัง',
  'ลิ่นถิ่น',
  'ลิ้นฟ้า',
  'ลีเล็ด',
  'ลี้',
  'ลือ',
  'ลุงเขว้า',
  'ลุมปุ๊ก',
  'ลุมพลี',
  'ลุมพินี',
  'ลุมพุก',
  'ลุโบะบายะ',
  'ลุโบะบือซา',
  'ลุโบะยิไร',
  'ลุโบะสาวอ',
  'ลุ่มระวี',
  'ลุ่มลำชี',
  'ลุ่มสุ่ม',
  'ล้อมแรด',
  'วงฆ้อง',
  'วงศ์สว่าง',
  'วชิรพยาบาล',
  'วรนคร',
  'วอแก้ว',
  'วะตะแบก',
  'วัง',
  'วังกรด',
  'วังกระแจะ',
  'วังกระโจม',
  'วังกวาง',
  'วังกะทะ',
  'วังกะพี้',
  'วังก์พง',
  'วังขนาย',
  'วังขอนขว้าง',
  'วังข่อย',
  'วังควง',
  'วังคัน',
  'วังคีรี',
  'วังงิ้ว',
  'วังงิ้วใต้',
  'วังจันทร์',
  'วังจั่น',
  'วังจิก',
  'วังจุฬา',
  'วังชมภู',
  'วังชะพลู',
  'วังชะโอน',
  'วังชัย',
  'วังชิ้น',
  'วังซ่าน',
  'วังซ้าย',
  'วังดาล',
  'วังดิน',
  'วังด้ง',
  'วังตะกอ',
  'วังตะกู',
  'วังตะคร้อ',
  'วังตะเคียน',
  'วังตะเฆ่',
  'วังตะแบก',
  'วังตะโก',
  'วังตามัว',
  'วังทรายคำ',
  'วังทรายพูน',
  'วังทอง',
  'วังทองหลาง',
  'วังทองแดง',
  'วังทับไทร',
  'วังท่าช้าง',
  'วังท่าดี',
  'วังธง',
  'วังนกแอ่น',
  'วังน้อย',
  'วังน้ำขาว',
  'วังน้ำคู้',
  'วังน้ำซับ',
  'วังน้ำลัด',
  'วังน้ำเขียว',
  'วังน้ำเย็น',
  'วังบัว',
  'วังบาล',
  'วังบูรพาภิรมย์',
  'วังบ่อ',
  'วังประจบ',
  'วังประจัน',
  'วังปลาป้อม',
  'วังผาง',
  'วังพญา',
  'วังพร้าว',
  'วังพัฒนา',
  'วังพิกุล',
  'วังพิณพาทย์',
  'วังมหากร',
  'วังมะนาว',
  'วังมะปราง',
  'วังมะปรางเหนือ',
  'วังม่วง',
  'วังม้า',
  'วังยาง',
  'วังยายทอง',
  'วังยาว',
  'วังลึก',
  'วังวน',
  'วังศรีราช',
  'วังศาล',
  'วังศาลา',
  'วังสมบูรณ์',
  'วังสรรพรส',
  'วังสวาบ',
  'วังสะพุง',
  'วังสามหมอ',
  'วังสามัคคี',
  'วังสำโรง',
  'วังหงษ์',
  'วังหมัน',
  'วังหมี',
  'วังหลวง',
  'วังหลุม',
  'วังหว้า',
  'วังหามแห',
  'วังหิน',
  'วังหินลาด',
  'วังอิทก',
  'วังอ่าง',
  'วังเงิน',
  'วังเพลิง',
  'วังเพิ่ม',
  'วังเมือง',
  'วังเย็น',
  'วังเหนือ',
  'วังแก้ว',
  'วังแขม',
  'วังแซ้ม',
  'วังแดง',
  'วังแสง',
  'วังโตนด',
  'วังโบสถ์',
  'วังโป่ง',
  'วังโพธิ์',
  'วังโพรง',
  'วังโมกข์',
  'วังโรงใหญ่',
  'วังใต้',
  'วังใหญ่',
  'วังใหม่',
  'วังไก่เถื่อน',
  'วังไคร้',
  'วังไชย',
  'วังไทร',
  'วังไผ่',
  'วังไม้ขอน',
  'วังไม้แดง',
  'วัฒนา',
  'วัฒนานคร',
  'วัด',
  'วัดกัลยาณ์',
  'วัดขนุน',
  'วัดขวาง',
  'วัดจันทร์',
  'วัดชลอ',
  'วัดดาว',
  'วัดตะกู',
  'วัดตายม',
  'วัดตูม',
  'วัดท่าพระ',
  'วัดธาตุ',
  'วัดประดู่',
  'วัดป่า',
  'วัดพระยาไกร',
  'วัดพริก',
  'วัดยม',
  'วัดยางงาม',
  'วัดราชบพิธ',
  'วัดละมุด',
  'วัดสน',
  'วัดสามพระยา',
  'วัดสำโรง',
  'วัดสิงห์',
  'วัดสุวรรณ',
  'วัดหลวง',
  'วัดอรุณ',
  'วัดเกต',
  'วัดเกาะ',
  'วัดเทพศิรินทร์',
  'วัดเพลง',
  'วัดแก้ว',
  'วัดแค',
  'วัดโคก',
  'วัดโบสถ์',
  'วัดโสมนัส',
  'วัดใหม่',
  'วัดไทร',
  'วัดไทรย์',
  'วันดาว',
  'วันยาว',
  'วานรนิวาส',
  'วาริชภูมิ',
  'วาริน',
  'วารินชำราบ',
  'วารีสวัสดิ์',
  'วาวี',
  'วาเล่ย์',
  'วาใหญ่',
  'วิชิต',
  'วิศิษฐ์',
  'วิสัยเหนือ',
  'วิสัยใต้',
  'วิหารขาว',
  'วิหารแดง',
  'วิเชตนคร',
  'ศรีกะอาง',
  'ศรีคีรีมาศ',
  'ศรีค้ำ',
  'ศรีจุฬา',
  'ศรีชมภู',
  'ศรีฐาน',
  'ศรีณรงค์',
  'ศรีดงเย็น',
  'ศรีดอนชัย',
  'ศรีดอนมูล',
  'ศรีดอนไชย',
  'ศรีตระกูล',
  'ศรีถ้อย',
  'ศรีธาตุ',
  'ศรีนคร',
  'ศรีนาวา',
  'ศรีบรรพต',
  'ศรีบัวบาน',
  'ศรีบุญเรือง',
  'ศรีประจันต์',
  'ศรีพนมมาศ',
  'ศรีพราน',
  'ศรีภิรมย์',
  'ศรีภูมิ',
  'ศรีมงคล',
  'ศรีมหาโพธิ',
  'ศรีมหาโพธิ์',
  'ศรีราชา',
  'ศรีละกอ',
  'ศรีวิชัย',
  'ศรีวิลัย',
  'ศรีวิไล',
  'ศรีษะทอง',
  'ศรีษะเกษ',
  'ศรีสงคราม',
  'ศรีสมเด็จ',
  'ศรีสว่าง',
  'ศรีสองรัก',
  'ศรีสะอาด',
  'ศรีสัชนาลัย',
  'ศรีสาคร',
  'ศรีสำราญ',
  'ศรีสุข',
  'ศรีสุขสำราญ',
  'ศรีสุทโธ',
  'ศรีสุนทร',
  'ศรีสุราษฎร์',
  'ศรีเตี้ย',
  'ศรีเทพ',
  'ศรีเมืองชุม',
  'ศรีแก้ว',
  'ศรีโคตร',
  'ศรีโนนงาม',
  'ศรีโพธิ์เงิน',
  'ศาลา',
  'ศาลากลาง',
  'ศาลาขาว',
  'ศาลาครุ',
  'ศาลาด่าน',
  'ศาลาธรรมสพน์',
  'ศาลายา',
  'ศาลารีไทย',
  'ศาลาลอย',
  'ศาลาลัย',
  'ศาลาลาย',
  'ศาลาลำดวน',
  'ศาลาแดง',
  'ศาลาใหม่',
  'ศาลเจ้าพ่อเสือ',
  'ศาลเจ้าโรงทอง',
  'ศาลเจ้าไก่ต่อ',
  'ศิริราช',
  'ศิลา',
  'ศิลาดาน',
  'ศิลาทิพย์',
  'ศิลาลอย',
  'ศิลาเพชร',
  'ศิลาแลง',
  'ศีรษะกระบือ',
  'ศีรษะจรเข้น้อย',
  'ศีรษะจรเข้ใหญ่',
  'สกาด',
  'สงยาง',
  'สงเปลือย',
  'สงเปือย',
  'สง่าบ้าน',
  'สตึก',
  'สถาน',
  'สทิงหม้อ',
  'สนม',
  'สนวน',
  'สนับทึบ',
  'สนามคลี',
  'สนามจันทร์',
  'สนามชัย',
  'สนามบิน',
  'สนามแจง',
  'สนามแย้',
  'สนามไชย',
  'สบตุ๋ย',
  'สบบง',
  'สบปราบ',
  'สบป่อง',
  'สบป้าด',
  'สบสาย',
  'สบเตี๊ยะ',
  'สบเปิง',
  'สบเมย',
  'สบแม่ข่า',
  'สบโขง',
  'สมสนุก',
  'สมสะอาด',
  'สมหวัง',
  'สมอ',
  'สมอทอง',
  'สมอพลือ',
  'สมอแข',
  'สมอโคน',
  'สมัย',
  'สมุด',
  'สมเด็จ',
  'สมเด็จเจริญ',
  'สมเด็จเจ้าพระยา',
  'สรรพยา',
  'สรอย',
  'สระ',
  'สระกรวด',
  'สระกระโจม',
  'สระกะเทียม',
  'สระกำแพงใหญ่',
  'สระขวัญ',
  'สระขุด',
  'สระคู',
  'สระจรเข้',
  'สระตะเคียน',
  'สระทอง',
  'สระทะเล',
  'สระนกแก้ว',
  'สระบัว',
  'สระประดู่',
  'สระพระ',
  'สระพัง',
  'สระพังทอง',
  'สระพังลาน',
  'สระพัฒนา',
  'สระยายโสม',
  'สระลงเรือ',
  'สระว่านพระยา',
  'สระสมิง',
  'สระสี่มุม',
  'สระสี่เหลี่ยม',
  'สระเยาว์',
  'สระแก้ว',
  'สระแจง',
  'สระโบสถ์',
  'สระโพนทอง',
  'สระใคร',
  'สร่างโศก',
  'สร้อยทอง',
  'สร้อยพร้าว',
  'สร้อยฟ้า',
  'สร้อยละคร',
  'สร้างก่อ',
  'สร้างคอม',
  'สร้างค้อ',
  'สร้างถ่อ',
  'สร้างถ่อน้อย',
  'สร้างนกทา',
  'สร้างนางขาว',
  'สร้างปี่',
  'สร้างมิ่ง',
  'สร้างแซ่ง',
  'สร้างแป้น',
  'สลกบาตร',
  'สลักได',
  'สลุย',
  'สวก',
  'สวด',
  'สวนกล้วย',
  'สวนขัน',
  'สวนจิก',
  'สวนจิตรลดา',
  'สวนดอก',
  'สวนดอกไม้',
  'สวนป่าน',
  'สวนผึ้ง',
  'สวนพริก',
  'สวนพริกไทย',
  'สวนส้ม',
  'สวนหม่อน',
  'สวนหลวง',
  'สวนเขื่อน',
  'สวนเมี่ยง',
  'สวนแตง',
  'สวนใหญ่',
  'สวาท',
  'สวาย',
  'สวายจีก',
  'สวี',
  'สว่าง',
  'สว่างอารมณ์',
  'สว่างแดนดิน',
  'สหกรณ์นิคม',
  'สหธาตุ',
  'สหัสขันธ์',
  'สองคลอง',
  'สองคอน',
  'สองชั้น',
  'สองพี่น้อง',
  'สองสลึง',
  'สองห้อง',
  'สองแคว',
  'สองแพรก',
  'สะกอม',
  'สะกาด',
  'สะกำ',
  'สะดาวา',
  'สะตอ',
  'สะตอน',
  'สะท้อน',
  'สะนอ',
  'สะบารัง',
  'สะบ้าย้อย',
  'สะพลี',
  'สะพานสอง',
  'สะพานสูง',
  'สะพานหิน',
  'สะพานไกร',
  'สะพานไทย',
  'สะพานไม้แก่น',
  'สะพือ',
  'สะพุง',
  'สะลวง',
  'สะอาด',
  'สะอาดสมบูรณ์',
  'สะอาดไชยศรี',
  'สะเดา',
  'สะเดาะพง',
  'สะเดาใหญ่',
  'สะเดียง',
  'สะเตง',
  'สะเตงนอก',
  'สะเนียน',
  'สะเมิงเหนือ',
  'สะเมิงใต้',
  'สะเอะ',
  'สะเอียบ',
  'สะแก',
  'สะแกกรัง',
  'สะแกซำ',
  'สะแกราช',
  'สะแกราบ',
  'สะแกโพรง',
  'สะแบง',
  'สะโน',
  'สักงาม',
  'สักหลง',
  'สังขะ',
  'สังคม',
  'สังเม็ก',
  'สัตหีบ',
  'สันกลาง',
  'สันกำแพง',
  'สันดอนแก้ว',
  'สันติคีรี',
  'สันติสุข',
  'สันต้นหมื้อ',
  'สันทราย',
  'สันทรายงาม',
  'สันทรายน้อย',
  'สันทรายหลวง',
  'สันทะ',
  'สันนาเม็ง',
  'สันปูเลย',
  'สันป่าตอง',
  'สันป่าม่วง',
  'สันป่ายาง',
  'สันป่าเปา',
  'สันผักหวาน',
  'สันผีเสื้อ',
  'สันพระเนตร',
  'สันมหาพน',
  'สันมะค่า',
  'สันมะเค็ด',
  'สันสลี',
  'สันโค้ง',
  'สันโป่ง',
  'สัมปทวน',
  'สัมพันธวงศ์',
  'สัมพันธ์',
  'สัมฤทธิ์',
  'สากอ',
  'สากเหล็ก',
  'สาคร',
  'สาคอบน',
  'สาคอใต้',
  'สาคู',
  'สานตม',
  'สาบัน',
  'สามกระทาย',
  'สามกอ',
  'สามขา',
  'สามควายเผือก',
  'สามง่าม',
  'สามง่ามท่าโบสถ์',
  'สามชุก',
  'สามตำบล',
  'สามตุ่ม',
  'สามบัณฑิต',
  'สามผง',
  'สามพระยา',
  'สามพราน',
  'สามพร้าว',
  'สามพวง',
  'สามพี่น้อง',
  'สามร้อยยอด',
  'สามวาตะวันตก',
  'สามวาตะวันออก',
  'สามสวน',
  'สามหมื่น',
  'สามัคคี',
  'สามัคคีพัฒนา',
  'สามเงา',
  'สามเมือง',
  'สามเรือน',
  'สามเสนนอก',
  'สามเสนใน',
  'สามแยก',
  'สามแวง',
  'สามโก้',
  'สามโคก',
  'สามไถ',
  'สายคำโห้',
  'สายตะกู',
  'สายทอง',
  'สายนาวัง',
  'สายลำโพง',
  'สายห้วยแก้ว',
  'สายออ',
  'สายไหม',
  'สารจิตร',
  'สารภี',
  'สาริกา',
  'สาลี',
  'สาวชะโงก',
  'สาวร้องไห้',
  'สาวอ',
  'สาวะถี',
  'สาวแห',
  'สาหร่าย',
  'สำนักขาม',
  'สำนักขุนเณร',
  'สำนักตะคร้อ',
  'สำนักทอง',
  'สำนักท้อน',
  'สำนักบก',
  'สำนักแต้ว',
  'สำพะเนียง',
  'สำพันตา',
  'สำมะโรง',
  'สำราญ',
  'สำราญราษฎร์',
  'สำราญใต้',
  'สำเภาลูน',
  'สำเภาล่ม',
  'สำเหร่',
  'สำโรง',
  'สำโรงกลาง',
  'สำโรงชัย',
  'สำโรงตาเจ็น',
  'สำโรงทาบ',
  'สำโรงปราสาท',
  'สำโรงพลัน',
  'สำโรงเหนือ',
  'สำโรงใต้',
  'สำโรงใหม่',
  'สิ',
  'สิงหนาท',
  'สิงห์',
  'สิงห์โคก',
  'สิงโตทอง',
  'สิชล',
  'สินปุน',
  'สินเจริญ',
  'สิบเอ็ดศอก',
  'สีกัน',
  'สีกาย',
  'สีคิ้ว',
  'สีชมพู',
  'สีดา',
  'สีบัวทอง',
  'สีพยา',
  'สีมุม',
  'สีลม',
  'สีวิเชียร',
  'สีสุก',
  'สีออ',
  'สีแก้ว',
  'สี่ขีด',
  'สี่คลอง',
  'สี่พระยา',
  'สี่ร้อย',
  'สี่หมื่น',
  'สี่เหลี่ยม',
  'สี่แยกมหานาค',
  'สุขฤทัย',
  'สุขสวัสดิ์',
  'สุขสำราญ',
  'สุขเกษม',
  'สุขเดือนห้า',
  'สุขไพบูลย์',
  'สุคิริน',
  'สุมเส้า',
  'สุรนารี',
  'สุรศักดิ์',
  'สุริยวงศ์',
  'สุวรรณคาม',
  'สุวรรณคูหา',
  'สุวารี',
  'สุเทพ',
  'สุโสะ',
  'สุไหงปาดี',
  'สุไหงโก-ลก',
  'สูงเนิน',
  'สูงเม่น',
  'ส่องดาว',
  'ส้มป่อย',
  'ส้มผ่อ',
  'ส้าน',
  'ส้านนาหนองใหม่',
  'หงษ์เจริญ',
  'หงส์หิน',
  'หงาว',
  'หญ้าปล้อง',
  'หนองกง',
  'หนองกบ',
  'หนองกรด',
  'หนองกระดิ่ง',
  'หนองกระทุ่ม',
  'หนองกระเจา',
  'หนองกระเจ็ด',
  'หนองกระเบียน',
  'หนองกระโดน',
  'หนองกราด',
  'หนองกร่าง',
  'หนองกลับ',
  'หนองกลางดง',
  'หนองกลางนา',
  'หนองกวั่ง',
  'หนองกวาง',
  'หนองกอมเกาะ',
  'หนองกะขะ',
  'หนองกะทิง',
  'หนองกะท้าว',
  'หนองกะปุ',
  'หนองกินเพล',
  'หนองกี่',
  'หนองกุง',
  'หนองกุงทับม้า',
  'หนองกุงธนสาร',
  'หนองกุงศรี',
  'หนองกุงสวรรค์',
  'หนองกุงเซิน',
  'หนองกุงแก้ว',
  'หนองกุงใหญ่',
  'หนองกุลา',
  'หนองกุ่ม',
  'หนองขนาก',
  'หนองขนาน',
  'หนองขมาร',
  'หนองขยาด',
  'หนองขวาว',
  'หนองขอน',
  'หนองขอนกว้าง',
  'หนองขาม',
  'หนองขาว',
  'หนองขาหย่าง',
  'หนองขุ่น',
  'หนองขุ่นใหญ่',
  'หนองข่า',
  'หนองข้างคอก',
  'หนองครก',
  'หนองคล้า',
  'หนองควาย',
  'หนองควายโซ',
  'หนองคอนไทย',
  'หนองคัน',
  'หนองคันทรง',
  'หนองคู',
  'หนองคูขาด',
  'หนองค่าย',
  'หนองค้า',
  'หนองค้างพลู',
  'หนองงิ้ว',
  'หนองงูเหลือม',
  'หนองจรเข้',
  'หนองจอก',
  'หนองจะบก',
  'หนองจิก',
  'หนองจ๊อม',
  'หนองฉลอง',
  'หนองฉาง',
  'หนองฉิม',
  'หนองชัยศรี',
  'หนองชาก',
  'หนองชิ่ม',
  'หนองชุมพล',
  'หนองชุมพลเหนือ',
  'หนองช้าง',
  'หนองช้างคืน',
  'หนองช้างแล่น',
  'หนองช้างใหญ่',
  'หนองซน',
  'หนองซอน',
  'หนองซ้ำซาก',
  'หนองญาติ',
  'หนองดินแดง',
  'หนองตรุด',
  'หนองตอกแป้น',
  'หนองตอง',
  'หนองตะครอง',
  'หนองตะพาน',
  'หนองตะเคียนบอน',
  'หนองตะไก้',
  'หนองตากยา',
  'หนองตาคง',
  'หนองตางู',
  'หนองตาด',
  'หนองตาดใหญ่',
  'หนองตาแต้ม',
  'หนองตาไก้',
  'หนองตำลึง',
  'หนองตีนนก',
  'หนองตูม',
  'หนองทรายขาว',
  'หนองทอง',
  'หนองทะเล',
  'หนองทันน้ำ',
  'หนองทัพไทย',
  'หนองทุ่ม',
  'หนองธง',
  'หนองนกทา',
  'หนองนกเขียน',
  'หนองนกแก้ว',
  'หนองนกไข่',
  'หนองนมวัว',
  'หนองนาก',
  'หนองนาคำ',
  'หนองนาง',
  'หนองนางนวล',
  'หนองนาแซง',
  'หนองน้อย',
  'หนองน้ำส้ม',
  'หนองน้ำแดง',
  'หนองน้ำใส',
  'หนองน้ำใหญ่',
  'หนองบก',
  'หนองบอน',
  'หนองบอนแดง',
  'หนองบัว',
  'หนองบัวดง',
  'หนองบัวตะเกียด',
  'หนองบัวทอง',
  'หนองบัวน้อย',
  'หนองบัวบาน',
  'หนองบัวระเหว',
  'หนองบัวละคร',
  'หนองบัวศาลา',
  'หนองบัวสะอาด',
  'หนองบัวสันตุ',
  'หนองบัวสิม',
  'หนองบัวฮี',
  'หนองบัวเหนือ',
  'หนองบัวแก้ว',
  'หนองบัวแดง',
  'หนองบัวโคก',
  'หนองบัวใต้',
  'หนองบัวใหญ่',
  'หนองบุนนาก',
  'หนองบ่มกล้วย',
  'หนองบ่อ',
  'หนองปรง',
  'หนองประดู่',
  'หนองปรือ',
  'หนองปลาปาก',
  'หนองปลาสะวาย',
  'หนองปลาหมอ',
  'หนองปลาไหล',
  'หนองปลิง',
  'หนองปล่อง',
  'หนองปล้อง',
  'หนองปากโลง',
  'หนองป่าก่อ',
  'หนองป่าครั่ง',
  'หนองผักนาก',
  'หนองผักแว่น',
  'หนองผึ้ง',
  'หนองผือ',
  'หนองฝ้าย',
  'หนองพยอม',
  'หนองพระ',
  'หนองพลวง',
  'หนองพลับ',
  'หนองพอก',
  'หนองพังค่า',
  'หนองพันจันทร์',
  'หนองพันทา',
  'หนองพิกุล',
  'หนองภัยศูนย์',
  'หนองมะค่า',
  'หนองมะค่าโมง',
  'หนองมะนาว',
  'หนองมะเขือ',
  'หนองมะแซว',
  'หนองมะโมง',
  'หนองม่วง',
  'หนองม่วงไข่',
  'หนองม้า',
  'หนองยวง',
  'หนองยอง',
  'หนองยาง',
  'หนองยายดา',
  'หนองยายพิมพ์',
  'หนองยายโต๊ะ',
  'หนองยาว',
  'หนองย่างชิ้น',
  'หนองย่างทอย',
  'หนองย่างเสือ',
  'หนองระฆัง',
  'หนองระเวียง',
  'หนองราชวัตร',
  'หนองรี',
  'หนองละลอก',
  'หนองลาด',
  'หนองลาน',
  'หนองลู',
  'หนองล่อง',
  'หนองวัวซอ',
  'หนองศาลา',
  'หนองสนม',
  'หนองสนิท',
  'หนองสรวง',
  'หนองสระ',
  'หนองสระปลา',
  'หนองสวรรค์',
  'หนองสว่าง',
  'หนองสองห้อง',
  'หนองสะเดา',
  'หนองสะโน',
  'หนองสังข์',
  'หนองสามวัง',
  'หนองสามสี',
  'หนองสาหร่าย',
  'หนองสิม',
  'หนองสีดา',
  'หนองสูง',
  'หนองสูงเหนือ',
  'หนองสูงใต้',
  'หนองหงษ์',
  'หนองหงส์',
  'หนองหญ้า',
  'หนองหญ้าขาว',
  'หนองหญ้าปล้อง',
  'หนองหญ้าลาด',
  'หนองหญ้าไซ',
  'หนองหญ้าไทร',
  'หนองหนาม',
  'หนองหมากฝ้าย',
  'หนองหมี',
  'หนองหมื่นถ่าน',
  'หนองหมู',
  'หนองหม้อ',
  'หนองหลวง',
  'หนองหลัก',
  'หนองหลุม',
  'หนองหล่ม',
  'หนองหว้า',
  'หนองหอย',
  'หนองหัวคู',
  'หนองหัวช้าง',
  'หนองหัวฟาน',
  'หนองหัววัว',
  'หนองหัวแรต',
  'หนองหัวโพ',
  'หนองหาน',
  'หนองหาร',
  'หนองหิน',
  'หนองห้าง',
  'หนองอิรุณ',
  'หนองอิเฒ่า',
  'หนองอีบุตร',
  'หนองอียอ',
  'หนองอึ่ง',
  'หนองอ้ม',
  'หนองอ้อ',
  'หนองฮะ',
  'หนองฮาง',
  'หนองฮี',
  'หนองเขียด',
  'หนองเข็ง',
  'หนองเชียงทูน',
  'หนองเดิ่น',
  'หนองเต็ง',
  'หนองเต่า',
  'หนองเทพ',
  'หนองเทา',
  'หนองเทาใหญ่',
  'หนองเป็ด',
  'หนองเพรางาย',
  'หนองเมธี',
  'หนองเมือง',
  'หนองเม็ก',
  'หนองเยือง',
  'หนองเรือ',
  'หนองเลิง',
  'หนองเสม็ด',
  'หนองเสาเล้า',
  'หนองเสือช้าง',
  'หนองเหล็ก',
  'หนองเหล่า',
  'หนองเหียง',
  'หนองเอี่ยน',
  'หนองแก',
  'หนองแก้ว',
  'หนองแก๋ว',
  'หนองแขม',
  'หนองแค',
  'หนองแคน',
  'หนองแจง',
  'หนองแจ้งใหญ่',
  'หนองแซง',
  'หนองแดง',
  'หนองแปน',
  'หนองแฝก',
  'หนองแม่นา',
  'หนองแม่แตง',
  'หนองแม่ไก่',
  'หนองแรด',
  'หนองแรต',
  'หนองแวง',
  'หนองแวงควง',
  'หนองแวงนางเบ้า',
  'หนองแวงโสกพระ',
  'หนองแวงใต้',
  'หนองแสง',
  'หนองแสงใหญ่',
  'หนองแสน',
  'หนองแหน',
  'หนองแหย่ง',
  'หนองโก',
  'หนองโดน',
  'หนองโน',
  'หนองโบสถ์',
  'หนองโพ',
  'หนองโพธิ์',
  'หนองโพนงาม',
  'หนองโพรง',
  'หนองโรง',
  'หนองโสน',
  'หนองโอ่ง',
  'หนองใหญ่',
  'หนองไขว่',
  'หนองไข่นก',
  'หนองไข่น้ำ',
  'หนองไทร',
  'หนองไผ่',
  'หนองไผ่ล้อม',
  'หนองไผ่แก้ว',
  'หนองไผ่แบน',
  'หนองไม้กอง',
  'หนองไม้งาม',
  'หนองไม้ซุง',
  'หนองไม้แก่น',
  'หนองไม้แดง',
  'หนองไม้ไผ่',
  'หนองไร่',
  'หนองไฮ',
  'หนามแดง',
  'หนามแท่ง',
  'หน่อม',
  'หน้าถ้ำ',
  'หน้าประดู่',
  'หน้าพระธาตุ',
  'หน้าพระลาน',
  'หน้าสตน',
  'หน้าเขา',
  'หน้าเมือง',
  'หน้าโคก',
  'หน้าไม้',
  'หมกแถว',
  'หมอกจำแป่',
  'หมอนทอง',
  'หมอนนาง',
  'หมอเมือง',
  'หมากหญ้า',
  'หมากเขียบ',
  'หมากแข้ง',
  'หมื่นศรี',
  'หมื่นไวย',
  'หมูม่น',
  'หมูม้น',
  'หมูสี',
  'หย่วน',
  'หรเทพ',
  'หลวงเหนือ',
  'หลวงใต้',
  'หลักชัย',
  'หลักช้าง',
  'หลักด่าน',
  'หลักฟ้า',
  'หลักสอง',
  'หลักสาม',
  'หลักหก',
  'หลักเขต',
  'หลักเมือง',
  'หลักเหลี่ยม',
  'หลักแก้ว',
  'หลังสวน',
  'หลุบ',
  'หลุบคา',
  'หลุบเลา',
  'หลุมข้าว',
  'หลุมดิน',
  'หลุมรัง',
  'หลุมเข้า',
  'หลุ่งตะเคียน',
  'หลุ่งประดู่',
  'หล่มสัก',
  'หล่มเก่า',
  'หล่อยูง',
  'หล่ายงาว',
  'หวายเหนียว',
  'หว้าทอง',
  'หว้านคำ',
  'หว้านใหญ่',
  'หอกลอง',
  'หอคำ',
  'หอมศีล',
  'หอมเกร็ด',
  'หอรัตนไชย',
  'หอไกร',
  'หันคา',
  'หันตรา',
  'หันตะเภา',
  'หันทราย',
  'หันนางาม',
  'หันสัง',
  'หันห้วยทราย',
  'หันโจด',
  'หัวขวาง',
  'หัวงัว',
  'หัวง้ม',
  'หัวช้าง',
  'หัวดง',
  'หัวดอน',
  'หัวตะพาน',
  'หัวถนน',
  'หัวทะเล',
  'หัวทุ่ง',
  'หัวนา',
  'หัวนาคำ',
  'หัวปลวก',
  'หัวป่า',
  'หัวฝาย',
  'หัวรอ',
  'หัวลำ',
  'หัวสะพาน',
  'หัวสำโรง',
  'หัวหนอง',
  'หัวหมาก',
  'หัวหวาย',
  'หัวหว้า',
  'หัวหิน',
  'หัวเขา',
  'หัวเดียด',
  'หัวเตย',
  'หัวเมือง',
  'หัวเรือ',
  'หัวเวียง',
  'หัวเสือ',
  'หัวโทน',
  'หัวโพ',
  'หัวโพธิ์',
  'หัวไทร',
  'หัวไผ่',
  'หางดง',
  'หางน้ำสาคร',
  'หาดกรวด',
  'หาดขาม',
  'หาดคัมภีร์',
  'หาดคำ',
  'หาดงิ้ว',
  'หาดทนง',
  'หาดทรายขาว',
  'หาดทรายรี',
  'หาดท่าเสา',
  'หาดนางแก้ว',
  'หาดพันไกร',
  'หาดยาง',
  'หาดยาย',
  'หาดล้า',
  'หาดสองแคว',
  'หาดสำราญ',
  'หาดสูง',
  'หาดส้มแป้น',
  'หาดอาษา',
  'หาดเจ้าสำราญ',
  'หาดเล็ก',
  'หาดเสี้ยว',
  'หาดแพง',
  'หาดใหญ่',
  'หานโพธิ์',
  'หายยา',
  'หายโศก',
  'หารเทา',
  'หารแก้ว',
  'หินกอง',
  'หินซ้อน',
  'หินดาด',
  'หินดาต',
  'หินตก',
  'หินตั้ง',
  'หินปัก',
  'หินมูล',
  'หินลาด',
  'หินฮาว',
  'หินเหล็กไฟ',
  'หินแก้ว',
  'หินโคน',
  'หินโงม',
  'หิรัญรูจี',
  'หูกวาง',
  'หูช้าง',
  'หูทำนบ',
  'หูล่อง',
  'ห่อหมก',
  'ห้วงน้ำขาว',
  'ห้วย',
  'ห้วยกรด',
  'ห้วยกรดพัฒนา',
  'ห้วยกระทิง',
  'ห้วยกระเจา',
  'ห้วยกะปิ',
  'ห้วยขมิ้น',
  'ห้วยขวาง',
  'ห้วยขะยุง',
  'ห้วยขุนราม',
  'ห้วยข่า',
  'ห้วยข้อง',
  'ห้วยข้าวก่ำ',
  'ห้วยคต',
  'ห้วยคันแหลน',
  'ห้วยงู',
  'ห้วยจรเข้',
  'ห้วยจันทร์',
  'ห้วยชมภู',
  'ห้วยชัน',
  'ห้วยซ้อ',
  'ห้วยด้วน',
  'ห้วยตามอญ',
  'ห้วยตึ๊กชู',
  'ห้วยต้อน',
  'ห้วยถั่วเหนือ',
  'ห้วยถั่วใต้',
  'ห้วยทราย',
  'ห้วยทรายเหนือ',
  'ห้วยทับทัน',
  'ห้วยทับมอญ',
  'ห้วยท่าช้าง',
  'ห้วยนาง',
  'ห้วยน้ำขาว',
  'ห้วยน้ำหอม',
  'ห้วยบง',
  'ห้วยบ่อซืน',
  'ห้วยปริก',
  'ห้วยปูลิง',
  'ห้วยป่าหวาย',
  'ห้วยผา',
  'ห้วยฝ้ายพัฒนา',
  'ห้วยพระ',
  'ห้วยพลู',
  'ห้วยพิชัย',
  'ห้วยพุก',
  'ห้วยมุ่น',
  'ห้วยม่วง',
  'ห้วยม้า',
  'ห้วยยอด',
  'ห้วยยั้ง',
  'ห้วยยาง',
  'ห้วยยางขาม',
  'ห้วยยางโทน',
  'ห้วยยาบ',
  'ห้วยยายจิ๋ว',
  'ห้วยยูง',
  'ห้วยรอบ',
  'ห้วยราช',
  'ห้วยราชา',
  'ห้วยร่วม',
  'ห้วยลาน',
  'ห้วยลึก',
  'ห้วยสะแก',
  'ห้วยสัก',
  'ห้วยสัตว์ใหญ่',
  'ห้วยสามพาด',
  'ห้วยสำราญ',
  'ห้วยสีเสียด',
  'ห้วยส้ม',
  'ห้วยหมอนทอง',
  'ห้วยหม้าย',
  'ห้วยหลัว',
  'ห้วยหอม',
  'ห้วยหิน',
  'ห้วยหินลาด',
  'ห้วยห้อม',
  'ห้วยอ้อ',
  'ห้วยเกตุ',
  'ห้วยเกิ้ง',
  'ห้วยเขน',
  'ห้วยเขย่ง',
  'ห้วยเตย',
  'ห้วยเม็ก',
  'ห้วยเหนือ',
  'ห้วยเฮี้ย',
  'ห้วยแก',
  'ห้วยแก้ง',
  'ห้วยแก้ว',
  'ห้วยแคน',
  'ห้วยแถลง',
  'ห้วยแม่เพรียง',
  'ห้วยแย้',
  'ห้วยแร้ง',
  'ห้วยแห้ง',
  'ห้วยแอ่ง',
  'ห้วยโก๋น',
  'ห้วยโจด',
  'ห้วยโป่ง',
  'ห้วยโพธิ์',
  'ห้วยโรง',
  'ห้วยใต้',
  'ห้วยใหญ่',
  'ห้วยไคร้',
  'ห้วยไผ่',
  'ห้วยไร่',
  'ห้องแซง',
  'ห้างฉัตร',
  'ห้างสูง',
  'องครักษ์',
  'องค์พระ',
  'อนุสาวรีย์',
  'อบทม',
  'อมก๋อย',
  'อมฤต',
  'อรพิมพ์',
  'อรัญคามวารี',
  'อรัญญิก',
  'อรัญประเทศ',
  'อรุณอมรินทร์',
  'อวน',
  'ออนกลาง',
  'ออนเหนือ',
  'ออนใต้',
  'ออย',
  'ออเงิน',
  'อัคคะคำ',
  'อัมพวา',
  'อัยเยอร์เวง',
  'อากาศ',
  'อาจสามารถ',
  'อาซ่อง',
  'อาษา',
  'อาฮี',
  'อาเนาะรู',
  'อาโพน',
  'อำนาจ',
  'อำแพง',
  'อิตื้อ',
  'อินคีรี',
  'อินทขิล',
  'อินทประมูล',
  'อินทร์บุรี',
  'อินทร์แปลง',
  'อิปัน',
  'อิปุ่ม',
  'อิสาณ',
  'อีง่อง',
  'อีปาด',
  'อีสานเขต',
  'อีเซ',
  'อี่หล่ำ',
  'อุดมทรัพย์',
  'อุดมธัญญา',
  'อุดมพร',
  'อุทัย',
  'อุทัยสวรรค์',
  'อุทัยเก่า',
  'อุทัยใหม่',
  'อุโมงค์',
  'อุโลกสี่หมื่น',
  'อุใดเจริญ',
  'อุ่มจาน',
  'อุ่มเม่า',
  'อุ่มเม้า',
  'อุ่มเหม้า',
  'อุ้มผาง',
  'อูบมุง',
  'อู่ตะเภา',
  'อู่ทอง',
  'อู่โลก',
  'อ่อนนุช',
  'อ่างคีรี',
  'อ่างทอง',
  'อ่างศิลา',
  'อ่างหิน',
  'อ่างแก้ว',
  'อ่ายนาไลย',
  'อ่าวตง',
  'อ่าวนาง',
  'อ่าวน้อย',
  'อ่าวลึกน้อย',
  'อ่าวลึกเหนือ',
  'อ่าวลึกใต้',
  'อ่าวใหญ่',
  'อ้อมกอ',
  'อ้อมน้อย',
  'อ้อมเกร็ด',
  'อ้อมใหญ่',
  'ฮอด',
  'ฮางโฮง',
  'เกตรี',
  'เกยไชย',
  'เกรียงไกร',
  'เกวียนหัก',
  'เกษตรพัฒนา',
  'เกษตรวิสัย',
  'เกษตรสุวรรณ',
  'เกษม',
  'เกษมทรัพย์',
  'เกะรอ',
  'เกาะกลาง',
  'เกาะกูด',
  'เกาะขนุน',
  'เกาะขวาง',
  'เกาะขันธ์',
  'เกาะคอเขา',
  'เกาะคา',
  'เกาะจัน',
  'เกาะจันทร์',
  'เกาะช้าง',
  'เกาะช้างใต้',
  'เกาะตะเภา',
  'เกาะตาล',
  'เกาะตาเลี้ยง',
  'เกาะทวด',
  'เกาะนางคำ',
  'เกาะปันหยี',
  'เกาะพยาม',
  'เกาะพระทอง',
  'เกาะพลับพลา',
  'เกาะพะงัน',
  'เกาะมะนาว',
  'เกาะยอ',
  'เกาะยาวน้อย',
  'เกาะยาวใหญ่',
  'เกาะรัง',
  'เกาะลอย',
  'เกาะลันตาน้อย',
  'เกาะลันตาใหญ่',
  'เกาะลิบง',
  'เกาะศรีบอยา',
  'เกาะศาลพระ',
  'เกาะสะท้อน',
  'เกาะสะบ้า',
  'เกาะสาหร่าย',
  'เกาะสำโรง',
  'เกาะสุกร',
  'เกาะหมาก',
  'เกาะหลัก',
  'เกาะหวาย',
  'เกาะเกร็ด',
  'เกาะเกิด',
  'เกาะเต่า',
  'เกาะเทโพ',
  'เกาะเปริด',
  'เกาะเปาะ',
  'เกาะเปียะ',
  'เกาะเพชร',
  'เกาะเรียน',
  'เกาะแก้ว',
  'เกาะแต้ว',
  'เกาะโพธิ์',
  'เกาะใหญ่',
  'เกาะไร่',
  'เกิ้ง',
  'เกียร์',
  'เก่ากลอย',
  'เก่าขาม',
  'เก่างิ้ว',
  'เก่าย่าดี',
  'เก้าเลี้ยว',
  'เขมราฐ',
  'เขวา',
  'เขวาทุ่ง',
  'เขวาสินรินทร์',
  'เขวาใหญ่',
  'เขวาไร่',
  'เขากระปุก',
  'เขากวางทอง',
  'เขากอบ',
  'เขากะลา',
  'เขาขลุง',
  'เขาขาว',
  'เขาขี้ฝอย',
  'เขาคราม',
  'เขาคอก',
  'เขาคันทรง',
  'เขาคีริส',
  'เขาค่าย',
  'เขาค้อ',
  'เขาจ้าว',
  'เขาฉกรรจ์',
  'เขาชนกัน',
  'เขาชะงุ้ม',
  'เขาชัยสน',
  'เขาชายธง',
  'เขาซก',
  'เขาดิน',
  'เขาดินพัฒนา',
  'เขาดินเหนือ',
  'เขาตอก',
  'เขาตูม',
  'เขาต่อ',
  'เขาถ่าน',
  'เขาทราย',
  'เขาทอง',
  'เขาทะลุ',
  'เขาท่าพระ',
  'เขานิพันธ์',
  'เขานิเวศน์',
  'เขาน้อย',
  'เขาบางแกรก',
  'เขาบายศรี',
  'เขาปูน',
  'เขาปู่',
  'เขาพนม',
  'เขาพระ',
  'เขาพระงาม',
  'เขาพระทอง',
  'เขาพระนอน',
  'เขาพระบาท',
  'เขาพัง',
  'เขาพังไกร',
  'เขามีเกียรติ',
  'เขาย่า',
  'เขาย้อย',
  'เขารวก',
  'เขารูปช้าง',
  'เขาล้าน',
  'เขาวง',
  'เขาวงกต',
  'เขาวัว',
  'เขาวิเศษ',
  'เขาสมอคอน',
  'เขาสมิง',
  'เขาสวนกวาง',
  'เขาสามยอด',
  'เขาสามสิบ',
  'เขาสามสิบหาบ',
  'เขาหลวง',
  'เขาหัวควาย',
  'เขาหินซ้อน',
  'เขาเขน',
  'เขาเจียก',
  'เขาเจ็ดลูก',
  'เขาเพิ่ม',
  'เขาแก้ว',
  'เขาแก้วศรีสมบูรณ์',
  'เขาแดง',
  'เขาแร้ง',
  'เขาแหลม',
  'เขาโจด',
  'เขาโร',
  'เขาใหญ่',
  'เขาไชยราช',
  'เขาไพร',
  'เขาไม้แก้ว',
  'เขิน',
  'เขือน้ำ',
  'เขื่องคำ',
  'เขื่องใน',
  'เขื่อน',
  'เขื่อนบางลาง',
  'เขื่อนผาก',
  'เขื่อนอุบลรัตน์',
  'เข็กน้อย',
  'เคร็ง',
  'เคียนซา',
  'เค็งใหญ่',
  'เจดีย์',
  'เจดีย์คำ',
  'เจดีย์ชัย',
  'เจดีย์หลวง',
  'เจดีย์หัก',
  'เจริญธรรม',
  'เจริญผล',
  'เจริญราษฎร์',
  'เจริญศิลป์',
  'เจริญสุข',
  'เจริญเมือง',
  'เจาทอง',
  'เจียด',
  'เจ็ดริ้ว',
  'เจ็ดเสมียน',
  'เจ้าท่า',
  'เจ้าปลุก',
  'เจ้าวัด',
  'เจ้าเจ็ด',
  'เจ้าเสด็จ',
  'เจ๊ะบิลัง',
  'เจ๊ะเห',
  'เฉนียง',
  'เฉลิม',
  'เฉลียง',
  'เชิงกลัด',
  'เชิงคีรี',
  'เชิงชุม',
  'เชิงดอย',
  'เชิงทะเล',
  'เชิงเนิน',
  'เชิงแส',
  'เชียงกลม',
  'เชียงกลาง',
  'เชียงขวัญ',
  'เชียงของ',
  'เชียงคาน',
  'เชียงงา',
  'เชียงดา',
  'เชียงดาว',
  'เชียงทอง',
  'เชียงบาน',
  'เชียงพิณ',
  'เชียงม่วน',
  'เชียงยืน',
  'เชียงรากน้อย',
  'เชียงรากใหญ่',
  'เชียงสือ',
  'เชียงหวาง',
  'เชียงเครือ',
  'เชียงเคี่ยน',
  'เชียงเงิน',
  'เชียงเพ็ง',
  'เชียงแรง',
  'เชียงแหว',
  'เชียงใหม่',
  'เชียรเขา',
  'เชียรใหญ่',
  'เชี่ยวเหลียง',
  'เชื้อเพลิง',
  'เซกา',
  'เซิม',
  'เซเป็ด',
  'เดิด',
  'เดิมบาง',
  'เดื่อศรีคันไชย',
  'เด่นชัย',
  'เด่นราษฎร์',
  'เด่นเหล็ก',
  'เด่นใหญ่',
  'เตย',
  'เตราะบอน',
  'เตาปูน',
  'เตาไห',
  'เต่างอย',
  'เต่าเล่า',
  'เถินบุรี',
  'เทนมีย์',
  'เทพกระษัตรี',
  'เทพคีรี',
  'เทพนคร',
  'เทพนิมิต',
  'เทพมงคล',
  'เทพรักษา',
  'เทพราช',
  'เทพา',
  'เทพารักษ์',
  'เทพาลัย',
  'เทพเสด็จ',
  'เทวราช',
  'เทอดไทย',
  'เที่ยงแท้',
  'เนินกว้าว',
  'เนินกุ่ม',
  'เนินขาม',
  'เนินขี้เหล็ก',
  'เนินฆ้อ',
  'เนินงาม',
  'เนินทราย',
  'เนินปอ',
  'เนินพระ',
  'เนินพระปรางค์',
  'เนินมะกอก',
  'เนินมะปราง',
  'เนินยาง',
  'เนินศาลา',
  'เนินสว่าง',
  'เนินหอม',
  'เนินเพิ่ม',
  'เนินแจง',
  'เบญจขร',
  'เบตง',
  'เบิกไพร',
  'เบิด',
  'เปร็ง',
  'เปลี่ยน',
  'เปาะเส้ง',
  'เปียงหลวง',
  'เปียน',
  'เปือ',
  'เปือย',
  'เปือยน้อย',
  'เปือยใหญ่',
  'เป็นสุข',
  'เป้า',
  'เป๊าะ',
  'เฝ้าไร่',
  'เพ',
  'เพชรชมภู',
  'เพชรละคร',
  'เพนียด',
  'เพหลา',
  'เพิ่มพูนทรัพย์',
  'เพี้ยราม',
  'เพ็กใหญ่',
  'เพ็ญ',
  'เมยวดี',
  'เมาะมาวี',
  'เมือง',
  'เมืองการุ้ง',
  'เมืองก๋าย',
  'เมืองคง',
  'เมืองคอง',
  'เมืองงาย',
  'เมืองจัง',
  'เมืองจันทร์',
  'เมืองชุม',
  'เมืองทอง',
  'เมืองที',
  'เมืองทุ่ง',
  'เมืองนะ',
  'เมืองนาท',
  'เมืองน้อย',
  'เมืองบัว',
  'เมืองบางขลัง',
  'เมืองบางยม',
  'เมืองปราสาท',
  'เมืองปอน',
  'เมืองปัก',
  'เมืองปาน',
  'เมืองฝาง',
  'เมืองฝ้าย',
  'เมืองพล',
  'เมืองพลับพลา',
  'เมืองพะไล',
  'เมืองพาน',
  'เมืองมาย',
  'เมืองยาง',
  'เมืองยาว',
  'เมืองลี',
  'เมืองลีง',
  'เมืองศรีไค',
  'เมืองสรวง',
  'เมืองสวรรคโลก',
  'เมืองหงส์',
  'เมืองหมี',
  'เมืองหลวง',
  'เมืองเกษตร',
  'เมืองเก่า',
  'เมืองเก่าพัฒนา',
  'เมืองเดช',
  'เมืองเตา',
  'เมืองเปลือย',
  'เมืองเพีย',
  'เมืองเล็น',
  'เมืองเสือ',
  'เมืองเหนือ',
  'เมืองแก',
  'เมืองแคน',
  'เมืองแปง',
  'เมืองแฝก',
  'เมืองแหง',
  'เมืองโดน',
  'เมืองโพธิ์',
  'เมืองใต้',
  'เมืองใหม่',
  'เมืองไผ่',
  'เมืองไพร',
  'เม็กดำ',
  'เม็งราย',
  'เย้ยปราสาท',
  'เรณู',
  'เรณูใต้',
  'เริงราง',
  'เรียง',
  'เรือง',
  'เลม็ด',
  'เลยวังไสย์',
  'เลาขวัญ',
  'เลิงแฝก',
  'เลิงใต้',
  'เวินพระบาท',
  'เวียง',
  'เวียงกาหลง',
  'เวียงคอย',
  'เวียงคำ',
  'เวียงคุก',
  'เวียงชัย',
  'เวียงตาล',
  'เวียงต้า',
  'เวียงทอง',
  'เวียงพางคำ',
  'เวียงมอก',
  'เวียงยอง',
  'เวียงสระ',
  'เวียงสะอาด',
  'เวียงห้าว',
  'เวียงเหนือ',
  'เวียงใต้',
  'เว่อ',
  'เสนา',
  'เสนางคนิคม',
  'เสนานิคม',
  'เสมา',
  'เสมาใหญ่',
  'เสม็จ',
  'เสม็ด',
  'เสม็ดเหนือ',
  'เสม็ดใต้',
  'เสริมกลาง',
  'เสริมขวา',
  'เสริมซ้าย',
  'เสวียด',
  'เสอเพลอ',
  'เสาชิงช้า',
  'เสาธง',
  'เสาธงชัย',
  'เสาธงหิน',
  'เสาหิน',
  'เสาเดียว',
  'เสาเภา',
  'เสาเล้า',
  'เสาไห้',
  'เสิงสาง',
  'เสียว',
  'เสี้ยว',
  'เสือหึง',
  'เสือเฒ่า',
  'เสือโก้ก',
  'เสือโฮก',
  'เสื่องข้าว',
  'เหนือ',
  'เหนือคลอง',
  'เหนือเมือง',
  'เหมาะ',
  'เหมือง',
  'เหมืองง่า',
  'เหมืองจี้',
  'เหมืองหม้อ',
  'เหมืองแก้ว',
  'เหมืองใหม่',
  'เหล',
  'เหล่า',
  'เหล่ากลาง',
  'เหล่ากวาง',
  'เหล่ากอหก',
  'เหล่างาม',
  'เหล่าดอกไม้',
  'เหล่าต่างคำ',
  'เหล่าทอง',
  'เหล่าน้อย',
  'เหล่าบก',
  'เหล่าบัวบาน',
  'เหล่าปอแดง',
  'เหล่าพรวน',
  'เหล่าพัฒนา',
  'เหล่ายาว',
  'เหล่าสร้างถ่อ',
  'เหล่าหมี',
  'เหล่าหลวง',
  'เหล่าอ้อย',
  'เหล่าเสือโก้ก',
  'เหล่าแดง',
  'เหล่าโพนค้อ',
  'เหล่าใหญ่',
  'เหล่าไฮ',
  'เหล่าไฮงาม',
  'เอกราช',
  'เอราวัณ',
  'เอือดใหญ่',
  'แก',
  'แกดำ',
  'แกลง',
  'แกใหญ่',
  'แก่งกระจาน',
  'แก่งคอย',
  'แก่งดินสอ',
  'แก่งผักกูด',
  'แก่งศรีภูมิ',
  'แก่งหางแมว',
  'แก่งเค็ง',
  'แก่งเลิงจาน',
  'แก่งเสี้ยน',
  'แก่งโดม',
  'แก่งโสภา',
  'แก่นมะกรูด',
  'แก้ง',
  'แก้งกอก',
  'แก้งสนามนาง',
  'แก้งเหนือ',
  'แก้งแก',
  'แก้งไก่',
  'แก้มอ้น',
  'แก้วฟ้า',
  'แก้วแสน',
  'แขม',
  'แข้',
  'แค',
  'แคตก',
  'แคน',
  'แคนดง',
  'แคนน้อย',
  'แคนเหนือ',
  'แคนใหญ่',
  'แคมป์สน',
  'แคราย',
  'แควอ้อม',
  'แควใหญ่',
  'แคออก',
  'แงง',
  'แจงงาม',
  'แจนแลน',
  'แจนแวน',
  'แจระแม',
  'แจ่มหลวง',
  'แจ้ซ้อน',
  'แจ้ห่ม',
  'แชะ',
  'แชแล',
  'แช่ช้าง',
  'แซงบาดาล',
  'แซร์ออ',
  'แดงหม้อ',
  'แดงใหญ่',
  'แดนชุมพล',
  'แดนสงวน',
  'แตล',
  'แต้',
  'แนงมุด',
  'แป-ระ',
  'แปลงยาว',
  'แป้น',
  'แพง',
  'แพงพวย',
  'แพงใหญ่',
  'แพด',
  'แพรกศรีราชา',
  'แพรกษา',
  'แพรกษาใหม่',
  'แพรกหนามแดง',
  'แพรกหา',
  'แมด',
  'แมดนาท่ม',
  'แม่กรณ์',
  'แม่กระบุง',
  'แม่กลอง',
  'แม่กัวะ',
  'แม่กา',
  'แม่กาษา',
  'แม่กิ๊',
  'แม่กุ',
  'แม่ก๊า',
  'แม่ขรี',
  'แม่ขะนิง',
  'แม่ข่า',
  'แม่ข้าวต้ม',
  'แม่คง',
  'แม่คะ',
  'แม่คะตวน',
  'แม่คำ',
  'แม่คำมี',
  'แม่คือ',
  'แม่งอน',
  'แม่จริม',
  'แม่จะเรา',
  'แม่จัน',
  'แม่จั๊วะ',
  'แม่ดง',
  'แม่ตาว',
  'แม่ตีบ',
  'แม่ตืน',
  'แม่ตื่น',
  'แม่ต้าน',
  'แม่ต๋ำ',
  'แม่ถอด',
  'แม่ทราย',
  'แม่ทอม',
  'แม่ทะ',
  'แม่ทะลบ',
  'แม่ทา',
  'แม่ท้อ',
  'แม่นะ',
  'แม่นางขาว',
  'แม่นาจร',
  'แม่นาจาง',
  'แม่นาวาง',
  'แม่นาเติง',
  'แม่นาเรือ',
  'แม่น้ำ',
  'แม่น้ำคู้',
  'แม่ปะ',
  'แม่ปั๋ง',
  'แม่ปาน',
  'แม่ปืม',
  'แม่ปุ',
  'แม่ปูคา',
  'แม่ป้าก',
  'แม่พริก',
  'แม่พุง',
  'แม่พูล',
  'แม่ฟ้าหลวง',
  'แม่มอก',
  'แม่ยม',
  'แม่ยวม',
  'แม่ยวมน้อย',
  'แม่ยางตาล',
  'แม่ยางร้อง',
  'แม่ยางฮ่อ',
  'แม่ยาว',
  'แม่ระกา',
  'แม่ระมาด',
  'แม่รำพึง',
  'แม่ลอย',
  'แม่ละมุ้ง',
  'แม่ลา',
  'แม่ลาด',
  'แม่ลาน',
  'แม่ลาน้อย',
  'แม่ลาว',
  'แม่ลาหลวง',
  'แม่วงก์',
  'แม่วะ',
  'แม่วะหลวง',
  'แม่วิน',
  'แม่ศึก',
  'แม่สรวย',
  'แม่สลองนอก',
  'แม่สลองใน',
  'แม่สลิด',
  'แม่สวด',
  'แม่สอง',
  'แม่สอด',
  'แม่สอย',
  'แม่สะเรียง',
  'แม่สัน',
  'แม่สา',
  'แม่สาคร',
  'แม่สาบ',
  'แม่สามแลบ',
  'แม่สาย',
  'แม่สาว',
  'แม่สำ',
  'แม่สิน',
  'แม่สุก',
  'แม่สูน',
  'แม่หลอง',
  'แม่หละ',
  'แม่หล่าย',
  'แม่หวาด',
  'แม่หอพระ',
  'แม่อาย',
  'แม่อิง',
  'แม่อุสุ',
  'แม่อูคอ',
  'แม่อ้อ',
  'แม่ฮี้',
  'แม่ฮ้อยเงิน',
  'แม่เกิ๋ง',
  'แม่เงา',
  'แม่เงิน',
  'แม่เจดีย์',
  'แม่เจดีย์ใหม่',
  'แม่เจ้าอยู่หัว',
  'แม่เปา',
  'แม่เปิน',
  'แม่เมาะ',
  'แม่เย็น',
  'แม่เล่ย์',
  'แม่เหาะ',
  'แม่เหียะ',
  'แม่แดด',
  'แม่แตง',
  'แม่แฝก',
  'แม่แฝกใหม่',
  'แม่แรง',
  'แม่แรม',
  'แม่แวน',
  'แม่โถ',
  'แม่โป่ง',
  'แม่ใจ',
  'แม่ใส',
  'แม่ไร่',
  'แร่',
  'และ',
  'แวง',
  'แวงดง',
  'แวงน่าง',
  'แวงน้อย',
  'แวงใหญ่',
  'แว้ง',
  'แสงภา',
  'แสงสว่าง',
  'แสงอรุณ',
  'แสนชาติ',
  'แสนตอ',
  'แสนตุ้ง',
  'แสนทอง',
  'แสนพัน',
  'แสนภูดาษ',
  'แสนสุข',
  'แสนแสบ',
  'แสนไห',
  'แสมดำ',
  'แสมสาร',
  'แสลง',
  'แสลงพัน',
  'แสลงพันธ์',
  'แสลงโทน',
  'แสวงหา',
  'แหลม',
  'แหลมกลัด',
  'แหลมงอบ',
  'แหลมตะลุมพุก',
  'แหลมทราย',
  'แหลมทอง',
  'แหลมบัว',
  'แหลมประดู่',
  'แหลมผักเบี้ย',
  'แหลมฟ้าผ่า',
  'แหลมรัง',
  'แหลมสน',
  'แหลมสอม',
  'แหลมสัก',
  'แหลมโตนด',
  'แหลมโพธิ์',
  'แหลมใหญ่',
  'แห่ใต้',
  'โกตาบารู',
  'โกรกกราก',
  'โกรกพระ',
  'โกรกแก้ว',
  'โกสัมพี',
  'โก่งธนู',
  'โขงเจียม',
  'โขมง',
  'โคกกกม่วง',
  'โคกกรวด',
  'โคกกระชาย',
  'โคกกระเบื้อง',
  'โคกกลอย',
  'โคกกลาง',
  'โคกกว้าง',
  'โคกกะเทียม',
  'โคกกุง',
  'โคกก่ง',
  'โคกก่อ',
  'โคกก่อง',
  'โคกขมิ้น',
  'โคกขาม',
  'โคกขี้หนอน',
  'โคกคราม',
  'โคกคอน',
  'โคกงาม',
  'โคกจาน',
  'โคกชะงาย',
  'โคกชำแระ',
  'โคกช้าง',
  'โคกตะบอง',
  'โคกตะเคียน',
  'โคกตาล',
  'โคกตูม',
  'โคกทราย',
  'โคกนาโก',
  'โคกปรง',
  'โคกปีบ',
  'โคกปี่ฆ้อง',
  'โคกพระ',
  'โคกพระเจดีย์',
  'โคกพุทรา',
  'โคกภู',
  'โคกมน',
  'โคกมะขาม',
  'โคกมะม่วง',
  'โคกมั่งงอย',
  'โคกม่วง',
  'โคกม้า',
  'โคกยาง',
  'โคกย่าง',
  'โคกลำพาน',
  'โคกล่าม',
  'โคกว่าน',
  'โคกศิลา',
  'โคกสง่า',
  'โคกสนวน',
  'โคกสมบูรณ์',
  'โคกสลุง',
  'โคกสลุด',
  'โคกสว่าง',
  'โคกสะตอ',
  'โคกสะบ้า',
  'โคกสะอาด',
  'โคกสัก',
  'โคกสาร',
  'โคกสำราญ',
  'โคกสำโรง',
  'โคกสี',
  'โคกสีทองหลาง',
  'โคกสูง',
  'โคกหม้อ',
  'โคกหล่อ',
  'โคกหล่าม',
  'โคกหาร',
  'โคกหินแฮ่',
  'โคกเครือ',
  'โคกเคียน',
  'โคกเจริญ',
  'โคกเดื่อ',
  'โคกเพชร',
  'โคกเพชรพัฒนา',
  'โคกเพลาะ',
  'โคกเริงรมย์',
  'โคกเหล็ก',
  'โคกแฝด',
  'โคกแย้',
  'โคกแสมสาร',
  'โคกโคเฒ่า',
  'โคกโพธิ์',
  'โคกใหญ่',
  'โคกไทย',
  'โคกไม้ลาย',
  'โคคลาน',
  'โคราช',
  'โค้งยาง',
  'โค้งไผ่',
  'โฆษิต',
  'โจดม่วง',
  'โจดหนองแก',
  'โชคชัย',
  'โชคนาสาม',
  'โชคเหนือ',
  'โซง',
  'โซ่',
  'โดด',
  'โดมประดิษฐ์',
  'โตนด',
  'โตนดด้วน',
  'โต๊ะเด็ง',
  'โนน',
  'โนนกลาง',
  'โนนกอก',
  'โนนกาหลง',
  'โนนกาเล็น',
  'โนนกุง',
  'โนนก่อ',
  'โนนขมิ้น',
  'โนนขวาง',
  'โนนข่า',
  'โนนคอม',
  'โนนคูณ',
  'โนนค่า',
  'โนนค้อ',
  'โนนฆ้อง',
  'โนนงาม',
  'โนนจาน',
  'โนนชัยศรี',
  'โนนดินแดง',
  'โนนตาล',
  'โนนตาเถร',
  'โนนตูม',
  'โนนทราย',
  'โนนทอง',
  'โนนทองหลาง',
  'โนนทองอินทร์',
  'โนนทัน',
  'โนนท่อน',
  'โนนธาตุ',
  'โนนนาจาน',
  'โนนน้ำเกลี้ยง',
  'โนนบุรี',
  'โนนประดู่',
  'โนนปอแดง',
  'โนนปูน',
  'โนนป่าซาง',
  'โนนผึ้ง',
  'โนนพลวง',
  'โนนพะยอม',
  'โนนภิบาล',
  'โนนม่วง',
  'โนนยอ',
  'โนนยาง',
  'โนนรัง',
  'โนนราษี',
  'โนนศิลา',
  'โนนศิลาเลิง',
  'โนนสง่า',
  'โนนสมบูรณ์',
  'โนนสวรรค์',
  'โนนสวาง',
  'โนนสว่าง',
  'โนนสะอาด',
  'โนนสัง',
  'โนนสำราญ',
  'โนนสุวรรณ',
  'โนนสูง',
  'โนนหนามแท่ง',
  'โนนหมากมุ่น',
  'โนนหมากเค็ง',
  'โนนหวาย',
  'โนนหอม',
  'โนนหัน',
  'โนนห้อม',
  'โนนอุดม',
  'โนนเจริญ',
  'โนนเต็ง',
  'โนนเปือย',
  'โนนเพ็ก',
  'โนนเพ็ด',
  'โนนเมือง',
  'โนนเมืองพัฒนา',
  'โนนเหล็ก',
  'โนนแดง',
  'โนนแหลมทอง',
  'โนนโพธิ์',
  'โนนโหนน',
  'โนนไทย',
  'โบสถ์',
  'โปงทุ่ง',
  'โป่ง',
  'โป่งงาม',
  'โป่งตาลอง',
  'โป่งนก',
  'โป่งน้ำร้อน',
  'โป่งผา',
  'โป่งสา',
  'โป่งเปือย',
  'โป่งแดง',
  'โป่งแพร่',
  'โป่งแยง',
  'โผงเผง',
  'โพกรวม',
  'โพงาม',
  'โพชนไก่',
  'โพตลาดแก้ว',
  'โพทะเล',
  'โพธาราม',
  'โพธิไพศาล',
  'โพธิ์',
  'โพธิ์กระสังข์',
  'โพธิ์กลาง',
  'โพธิ์งาม',
  'โพธิ์ชัย',
  'โพธิ์ตรุ',
  'โพธิ์ตาก',
  'โพธิ์ทอง',
  'โพธิ์ประทับช้าง',
  'โพธิ์ประสาท',
  'โพธิ์พระยา',
  'โพธิ์ม่วงพันธ์',
  'โพธิ์รังนก',
  'โพธิ์วงศ์',
  'โพธิ์ศรี',
  'โพธิ์ศรีสว่าง',
  'โพธิ์ศรีสำราญ',
  'โพธิ์สัย',
  'โพธิ์สามต้น',
  'โพธิ์หมากแข้ง',
  'โพธิ์เก้าต้น',
  'โพธิ์เสด็จ',
  'โพธิ์เอน',
  'โพธิ์แทน',
  'โพธิ์ใหญ่',
  'โพธิ์ไชย',
  'โพธิ์ไทร',
  'โพธิ์ไทรงาม',
  'โพน',
  'โพนข่า',
  'โพนครก',
  'โพนค้อ',
  'โพนงาม',
  'โพนจาน',
  'โพนทราย',
  'โพนทอง',
  'โพนทัน',
  'โพนบก',
  'โพนยาง',
  'โพนสวรรค์',
  'โพนสว่าง',
  'โพนสา',
  'โพนสูง',
  'โพนางดำตก',
  'โพนางดำออก',
  'โพนเขวา',
  'โพนเพ็ก',
  'โพนเมือง',
  'โพนเมืองน้อย',
  'โพนแพง',
  'โพนโก',
  'โพประจักษ์',
  'โพพระ',
  'โพรงจระเข้',
  'โพรงมะเดื่อ',
  'โพรงอากาศ',
  'โพสะ',
  'โพสังโฆ',
  'โพสาวหาญ',
  'โพหัก',
  'โพแตง',
  'โพไร่หวาน',
  'โมคลาน',
  'โมถ่าย',
  'โมโกร',
  'โยธะกา',
  'โยนก',
  'โรง',
  'โรงช้าง',
  'โรงหีบ',
  'โรงเข้',
  'โละจูด',
  'โสกก่าม',
  'โสกนกเต็น',
  'โสกปลาดุก',
  'โสกแสง',
  'โสธร',
  'โสน',
  'โสนลอย',
  'โสมเยี่ยม',
  'โหรา',
  'โหล่งขอด',
  'โอโล',
  'ใจดี',
  'ในคลองบางปลากด',
  'ในควน',
  'ในวงเหนือ',
  'ในวงใต้',
  'ในเตา',
  'ในเมือง',
  'ในเวียง',
  'ใหม่',
  'ใหม่นาเพียง',
  'ใหม่พัฒนา',
  'ไกรกลาง',
  'ไกรนอก',
  'ไกรใน',
  'ไก่คำ',
  'ไก่เส่า',
  'ไคสี',
  'ไค้นุ่น',
  'ไชยคราม',
  'ไชยบุรี',
  'ไชยภูมิ',
  'ไชยมงคล',
  'ไชยมนตรี',
  'ไชยราช',
  'ไชยวัฒนา',
  'ไชยวาน',
  'ไชยสถาน',
  'ไชยสอ',
  'ไชโย',
  'ไตรตรึงษ์',
  'ไทยชนะศึก',
  'ไทยบุรี',
  'ไทยสามัคคี',
  'ไทยอุดม',
  'ไทยาวาส',
  'ไทยเจริญ',
  'ไทรขึง',
  'ไทรงาม',
  'ไทรทอง',
  'ไทรน้อย',
  'ไทรม้า',
  'ไทรย้อย',
  'ไทรเดี่ยว',
  'ไทรโยค',
  'ไทรโรงโขน',
  'ไทรโสภา',
  'ไทรใหญ่',
  'ไผ่',
  'ไผ่กองดิน',
  'ไผ่ขวาง',
  'ไผ่ขอดอน',
  'ไผ่จำศีล',
  'ไผ่ชะเลือด',
  'ไผ่ดำพัฒนา',
  'ไผ่ต่ำ',
  'ไผ่ท่าโพ',
  'ไผ่พระ',
  'ไผ่รอบ',
  'ไผ่ลิง',
  'ไผ่ล้อม',
  'ไผ่วง',
  'ไผ่สิงห์',
  'ไผ่หลวง',
  'ไผ่หลิ่ว',
  'ไผ่หูช้าง',
  'ไผ่เขียว',
  'ไผ่โทน',
  'ไผ่ใหญ่',
  'ไพบูลย์',
  'ไพร',
  'ไพรขลา',
  'ไพรนกยูง',
  'ไพรบึง',
  'ไพรพัฒนา',
  'ไพรวัน',
  'ไพล',
  'ไพศาล',
  'ไพศาลี',
  'ไม้กลอน',
  'ไม้ขาว',
  'ไม้งาม',
  'ไม้ดัด',
  'ไม้ตรา',
  'ไม้ฝาด',
  'ไม้ยา',
  'ไม้รูด',
  'ไม้เค็ด',
  'ไม้เรียง',
  'ไม้แก่น',
  'ไร่',
  'ไร่ขิง',
  'ไร่ขี',
  'ไร่น้อย',
  'ไร่พัฒนา',
  'ไร่มะขาม',
  'ไร่รถ',
  'ไร่สะท้อน',
  'ไร่สีสุก',
  'ไร่ส้ม',
  'ไร่หลักทอง',
  'ไร่อ้อย',
  'ไร่เก่า',
  'ไร่โคก',
  'ไร่ใต้',
  'ไร่ใหม่',
  'ไร่ใหม่พัฒนา',
  'ไล่โว่',
  'ไสหมาก',
  'ไสหร้า',
  'ไสไทย',
  'ไหล่ทุ่ง',
  'ไหล่น่าน',
  'ไหล่หิน',
  'ไฮหย่อง'
]

# %%
address_list.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f688adf50095> in <cell line: 1>()
# ----> 1 address_list.keys()
#
# NameError: name 'address_list' is not defined

# %% [markdown]
# # regx

# %%
def find_province(input_text):
    province = re.findall('จังหวัด\s?([ก-๙]+)', input_text)
    if province:
        return province[0]

    if not province:
        province = re.findall('จ\\.\s?([ก-๙]+)', input_text)
        if province:
            return province[0]

    for p in province_list:
        if p in input_text:
            return p

    return False


def find_amphoe(input_text):
    # amphoe = re.findall('อำเภอ|เขต\s?([ก-๙]+)', input_text)
    amphoe = re.findall('(?:อำเภอ|เขต)\s?([ก-๙]+)', input_text)
    if amphoe:
        return amphoe[0]

    if not amphoe:
        amphoe = re.findall('อ\\.\s?([ก-๙]+)', input_text)
        if amphoe:
            return amphoe[0]

    for a in amphoe_list:
        if a in input_text:
            return a

    return False


def find_tambol(input_text):
    # tambol = re.findall('ตำบล|แขวง\s?([ก-๙]+)', input_text)
    tambol = re.findall('(?:ตำบล|แขวง)\s?([ก-๙]+)', input_text)
    if tambol:
        return tambol[0]

    if not tambol:
        tambol = re.findall('ต\\.\s?([ก-๙]+)', input_text)
        if tambol:
            return tambol[0]

    for t in tambol_list:
        if t in input_text:
            return t

    return False


def find_zipcode(input_text):
    zipcode = re.findall(r'\b\d{5}\b', input_text)
    if zipcode:
        return zipcode[0]
    return False


def extract_address(input_text):
    address_info = {}
    address_info['province'] = find_province(input_text)
    address_info['amphoe'] = find_amphoe(input_text)
    address_info['district'] = find_tambol(input_text)
    address_info['zipcode'] = find_zipcode(input_text)
    return address_info

# %%
import re

# %%
words = [checker.correct(token) for token in tokenize_texts if token not in addtexts]
words

# %%
try:
      input_texts = [
          '182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741',
          'สมพัฒน์ แก้วพิจิตร 66/8 ม.10 ต.เขาแก้ว อ.ท่าใหม่ จ.จันทบุรี 22170',
          'ที่อยู่ 111/1 หมู่ 7 ตำบล แสนสุข อำเภอ เมืองชลบุรี จังหวัด ชลบุรี 20130',
          'ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี ตำบล แสนสุข',
          'ตำบล แสนสุข ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี',
          '680 ถ.สุขมุวิท ต.บางปลาสร้อย อ.เมืองชลบุรี จ.ชลบุรี 20000',
          '259 หมู่11 ถ.สืบศิริ ต.เมืองปัก อ.ปักธงชัย จ.นครราชสีมา 30150',
          '87 ถ.สุขุมวิท ต.ปากน้ำ อ.เมืองสมุทรปราการ จ.สมุทรปราการ 10270',
          '11/1 หมู่ 4 ตำบล นามะตูม อำเภอ พนัสนิคม จังหวัด ชลบุรี 20140',
          '12/13 ถนนเทศบาลพัฒนา ตำบลพนัสนิคม อำเภอพนัสนิคม จังหวัดชลบุรี 20140',
          '21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100',
          '21-29 ถ.นาคราช คลองมหานาค ป้อมปราบ กรุงเทพ 10100'
      ]

      # while True:
      # input_text = input('\ninput ADDRESS : ')
      # data = extract_address(input_text)
      # print(f"{'_'*7}\nresult: {data}\n")
      # match_address(    )

      for input_text in input_texts:
          result = extract_address(input_text)
          print(f"{'_'*7}\nresult: {result}")
          # match_address(result)
except KeyboardInterrupt:
  print('exit')
except Exception as e:
  print('error', e)
# Out:
# _______
# result: {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160'}
# _______
# result: {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170'}
# _______
# result: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# _______
# result: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# _______
# result: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# _______
# result: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บางปลาสร้อย', 'zipcode': '20000'}
# _______
# result: {'province': 'นครราชสีมา', 'amphoe': 'ปักธงชัย', 'district': 'เมืองปัก', 'zipcode': '30150'}
# _______
# result: {'province': 'สมุทรปราการ', 'amphoe': 'เมืองสมุทรปราการ', 'district': 'ปากน้ำ', 'zipcode': '10270'}
# _______
# ...

# %% [markdown]
# # Tokenizes

# %%
import re

def preprocess(text: str) -> str:
    """
    Generalized function to preprocess an input
    """
    text = text.strip()
    text = text.replace("ส่ง ", "")
    text = text.replace("จัดส่ง", "")
    text = text.replace("ชือ.", "")
    text = text.replace("ชื่อ ", "")
    text = text.replace("ผู้รับ", "")
    text = text.replace("ส่งที่ ", " ")
    text = text.replace("ที่อยู่ ", " ")
    text = text.replace("ที้อยุ่ ", " ")
    text = text.replace("ที่อยู่จ้า ", " ")
    text = text.replace("ส่งของที่ ", " ")
    text = text.replace("ส่งมาที่", " ")
    text = text.replace("\n-", " ")
    text = text.replace("\n", " ")
    text = text.replace(": ", " ")
    text = text.replace(":", "")
    text = text.replace("-", "")
    text = text.replace("(", "")
    text = text.replace(")", "")
    text = text.replace('"', "")
    # text = remove_emoji(text)
    text = " ".join([t for t in text.strip().split(" ") if t.strip() != ""])
    return text


def clean_location_text(text: str) -> str:
    """
    Clean location before using fuzzy string match
    """
    text = text.replace("แขวง", " ")
    text = text.replace("เขต", " ")
    text = text.replace("อำเภอ", " ")
    text = text.replace("ตำบล", " ")
    text = text.replace("ต.", " ")
    text = text.replace("ตฺ", "ต.")
    text = text.replace("อ.", " ")
    text = text.replace("จ.", " ")
    text = text.replace("คอหงส์", "คอหงษ์")
    text = text.replace("กทม.", "กรุงเทพ")
    text = text.replace("กทม", "กรุงเทพ")
    return text

def extract_name(text: str) -> str:
    """
    Extracts name from the text.
    """
    name = re.findall(r'(เด็กชาย|เด็กหญิง|ด\.ช\.|ด\.ญ\.|นาย|นาง|นางสาว|น\.ส\.|ดร\.)\s*([ก-๙]+)\s*([ก-๙]+)', text)
    print(name)
    if name:
        full_name = ''.join(name[0])
        text = text.replace(full_name, " ")
        return text, full_name
    return None

def extract_phone(text: str) -> str:
    """
    Extracts phone from the text.
    """
    phone = re.findall(r'(08\d{8}|09\d{8})', text)
    print(phone)
    if phone:
        phone = ''.join(phone[0])
        text = text.replace(phone, " ")
        return text, phone
    return None

# %%
from pythainlp.util import dict_trie
from pythainlp.corpus.common import thai_words

custom_word_lists = set(thai_words())
custom_word_lists.update(list(hashmap.keys()))
addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
custom_word_lists.update(addtexts)

trie = dict_trie(dict_source=custom_word_lists)

# %%
from pythainlp import Tokenizer

custom_tokenize = Tokenizer(custom_dict=trie, join_broken_num=False, keep_whitespace=False, engine='newmm')

text = "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547"
text = preprocess(text)
text = clean_location_text(text)
text, name = extract_name(text)
text, phone = extract_phone(text)
print(name)
print(phone)
print(text)
# Out:
# [('นาย', 'เชิดชัยสมหมา', 'ย')]
# ['0912719547']
# นายเชิดชัยสมหมาย
# 0912719547
# 55301262 107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพ กลางดง / ปากช่องจังหวัดนครราชสีมา30320Tel

# %%
tokenize_texts = custom_tokenize.word_tokenize(text)
tokenize_texts
# Out:
# ['55301262',
#  '107',
#  '/1',
#  'หมู่',
#  '6',
#  'ซ.',
#  'หมู่บ้าน',
#  'โรง',
#  'กุลี',
#  'ซอย',
#  '10',
#  'ถนน',
#  'มิตรภาพ',
#  'กลางดง',
#  '/',
#  'ปากช่อง',
#  'จังหวัด',
#  'นครราชสีมา',
#  '30320',
#  'Tel']

# %%
from pythainlp.spell import NorvigSpellChecker

custom_checker_list = set(list(hashmap.keys()))
addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
custom_checker_list.update(addtexts)
ctrie = dict_trie(dict_source=custom_checker_list)


checker = NorvigSpellChecker(custom_dict=ctrie, min_freq=1, min_len=5, max_len=30)
checker.correct("ปอมปราบ")
# Out:
# 'ป้อมปราบ'

# %%
print(tokenize_texts)
# Out:
# ['55301262', '107', '/1', 'หมู่', '6', 'ซ.', 'หมู่บ้าน', 'โรง', 'กุลี', 'ซอย', '10', 'ถนน', 'มิตรภาพ', 'กลางดง', '/', 'ปากช่อง', 'จังหวัด', 'นครราชสีมา', '30320', 'Tel']

# %%
words = [checker.correct(token) for token in tokenize_texts if token not in addtexts]
words
# Out:
# ['55301262',
#  '107',
#  '/1',
#  '6',
#  'หมู่บ้าน',
#  'ปุโรง',
#  'กุลี',
#  '10',
#  'มิตรภาพ',
#  'กลางดง',
#  '/',
#  'ปากช่อง',
#  'นครราชสีมา',
#  '30320',
#  'Tel']

# %%
text_list = ['ชะมาย', 'บ้านชี', 'ปุโรง', 'ภาษีเจริญ', 'กลางดง', 'บางจาก', 'กรุงเทพ', '10160']

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    for text in text_list:
        for province, districts in address_list.items():
            if text == province:
                best_match['province'] = province
            for district, subdistricts in districts.items():
                if text == district:
                    best_match['amphoe'] = district
                for subdistrict, zipcode in subdistricts:
                    if text == subdistrict:
                        best_match['district'] = subdistrict
                    if text == zipcode:
                        best_match['zipcode'] = zipcode

    result = tuple(filter(None, best_match.values()))
    return result

result = find_best_match(address_list, words)
print(result)
# Out:
# ('นครราชสีมา', 'ปากช่อง', 'ปากช่อง', '30320')

# %%
data = [(word, hashmap[word]) for word in result if word in list(hashmap.keys())]
data
# Out:
# [('นครราชสีมา', 'PROVINCE'),
#  ('ปากช่อง', 'AMPHOE'),
#  ('ปากช่อง', 'AMPHOE'),
#  ('30320', 'ZIPCODE')]

# %%
print(f"Tagging: {data}\nName: {name}\nPhone: {phone}")
# Out:
# Tagging: [('นครราชสีมา', 'PROVINCE'), ('ปากช่อง', 'AMPHOE'), ('ปากช่อง', 'AMPHOE'), ('30320', 'ZIPCODE')]
# Name: นายเชิดชัยสมหมาย
# Phone: 0912719547

# %%
text = "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547"
def extract_address(text: str) -> str:
  clean_text = clean_location_text(preprocess(text))
  tokenize_texts = custom_tokenize.word_tokenize(clean_text)
  words = [checker.correct(token) for token in tokenize_texts if token not in addtexts]
  data = [(word, hashmap[word]) for word in words if word in list(hashmap.keys())]
  print(f"{'_'*10}\nchecker: {words}\nner     : {data}\n")

extract_address(text)
# Out:
# __________
# checker: ['55301262', 'นาคาย', 'เชิด', 'ชัยพร', 'สมหมาย', '107', '/1', '6', 'หมู่บ้าน', 'สำโรง', 'กุลี', '10', 'มิตรภาพ', 'กลางดง', '/', 'ปากช่อง', 'นครราชสีมา', '30320', 'Tel', '0912719547']
# ner     : [('นาคาย', 'DISTRICT'), ('ชัยพร', 'DISTRICT'), ('สำโรง', 'AMPHOE'), ('มิตรภาพ', 'DISTRICT'), ('กลางดง', 'DISTRICT'), ('ปากช่อง', 'AMPHOE'), ('นครราชสีมา', 'PROVINCE'), ('30320', 'ZIPCODE')]

# %%
addresses = [
    '182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ จังหวัดชลบุรี 10160 0877170741',
    'สมพัฒน์ แก้วพิจิตร 66/8 ม.10 ต.เขาแก้ว อ.ท่าใหม่ จ.จันทบุรี 22170',
    'ที่อยู่ 111/1 หมู่ 7 ตำบล แสนสุข อำเภอ เมืองชลบุรี จังหวัด ชลบุรี 20130',
    'ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี ตำบล แสนสุข',
    'ตำบล แสนสุข ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี',
    '680 ถ.สุขมุวิท ต.บางปลาสร้อย อ.เมืองชลบุรี จ.ชลบุรี 20000',
    '259 หมู่11 ถ.สืบศิริ ต.เมืองปัก อ.ปักธงชัย จ.นครราชสีมา 30150',
    '87 ถ.สุขุมวิท ต.ปากน้ำ อ.เมืองสมุทรปราการ จ.สมุทรปราการ 10270',
    '11/1 หมู่ 4 ตำบล นามะตูม อำเภอ พนัสนิคม จังหวัด ชลบุรี 20140',
    '12/13 ถนนเทศบาลพัฒนา ตำบลพนัสนิคม อำเภอพนัสนิคม จังหวัดชลบุรี 20140',
    '21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100',
    "55) 30-12-62 นายเชิดชัย สมหมาย 107/1 หมู่ 6 ซ.หมู่บ้านโรงกุลี ซอย 10 ถนนมิตรภาพ ต.กลางดง อำเภอ / ตำบล : ปากช่อง จังหวัด : นครราชสีมา 30320 Tel 091-2719547",
    "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547",
]
for text in addresses:
  extract_address(text)

# %% [markdown]
# # Checklist Data

# %%
address_list = {
"กระบี่": {
"เมืองกระบี่": [
("กระบี่น้อย", "81000"),
("เขาทอง", "81000"),
("ทับปริก", "81000"),
("อ่าวนาง", "81000"),
("หนองทะเล", "81000"),
("หนองทะเล", "81180"),
],
"เขาพนม": [
("เขาพนม", "81140"),
("พรุเตียว", "81140"),
("หน้าเขา", "81140"),
("โคกหาร", "80240"),
],
"เกาะลันตา": [
("เกาะกลาง", "81120"),
("ศาลาด่าน", "81150"),
],
"คลองท่อม": [
("คลองท่อมเหนือ", "81120"),
("คลองพน", "81170"),
("ห้วยน้ำขาว", "81120"),
("เพหลา", "81120"),
],
"อ่าวลึก": [
("แหลมสัก", "81110"),
("นาเหนือ", "81110"),
],
"ปลายพระยา": [
("ปลายพระยา", "81160"),
("เขาเขน", "81160"),
("เขาต่อ", "81160"),
("คีรีวง", "81160"),
],
"ลำทับ": [
("ลำทับ", "81190"),
("ดินอุดม", "81120"),
("ดินแดง", "81120"),
],
"เหนือคลอง": [
("เหนือคลอง", "81130"),
("คลองเขม้า", "81130"),
("โคกยาง", "81130"),
("ห้วยยูง", "81130"),
],
"เมืองกระบี่": [
("ปากน้ำ", "81000"),
("กระบี่ใหญ่", "81000"),
("เขาคราม", "81000"),
("ไสไทย", "81000"),
("อ่าวนาง", "81180"),
("อ่าวนาง", "81210"),
("คลองประสงค์", "81000"),
],
"เขาพนม": [
("เขาดิน", "81140"),
("สินปุน", "80240"),
("พรุเตียว", "80240"),
("หน้าเขา", "80240"),
],
"เกาะลันตา": [
("เกาะลันตาใหญ่", "81150"),
("เกาะลันตาน้อย", "81150"),
("คลองยาง", "81120"),
],
"คลองท่อม": [
("คลองท่อมใต้", "81120"),
("ทรายขาว", "81170"),
("พรุดินนา", "81120"),
],
"อ่าวลึก": [
("อ่าวลึกใต้", "81110"),
("คลองหิน", "81110"),
("อ่าวลึกน้อย", "81110"),
("อ่าวลึกเหนือ", "81110"),
("เขาใหญ่", "81110"),
("คลองยา", "81110"),
("บ้านกลาง", "81110"),
],
"ลำทับ": [
("ทุ่งไทรทอง", "81120"),
],
"เหนือคลอง": [
("เกาะศรีบอยา", "81130"),
("คลองขนาน", "81130"),
("ตลิ่งชัน", "81130"),
("ปกาสัย", "81130"),
]},
"กรุงเทพ": {
"คลองเตย": [
("คลองเตย", "10110"),
("พระโขนง", "10260"),
],
"คลองสาน": [
("คลองสาน", "10600"),
("บางลำภูล่าง", "10600"),
("สมเด็จเจ้าพระยา", "10600"),
],
"คลองสามวา": [
("ทรายกองดิน", "10510"),
("ทรายกองดินใต้", "10510"),
("บางชัน", "10510"),
("สามวาตะวันตก", "10510"),
("สามวาตะวันออก", "10510"),
],
"คันนายาว": [
("รามอินทรา", "10230"),
],
"จตุจักร": [
("จตุจักร", "10900"),
("จอมพล", "10900"),
("เสนานิคม", "10900"),
],
"จอมทอง": [
("จอมทอง", "10150"),
("บางค้อ", "10150"),
],
"ดอนเมือง": [
("สีกัน", "10210"),
],
"ดินแดง": [
("ดินแดง", "10400"),
("รัชดาภิเษก", "10400"),
],
"ดุสิต": [
("ถนนนครไชยศรี", "10300"),
("สวนจิตรลดา", "10303"),
],
"ตลิ่งชัน": [
("คลองชักพระ", "10170"),
("ฉิมพลี", "10170"),
("ตลิ่งชัน", "10170"),
("บางเชือกหนัง", "10170"),
("บางพรม", "10170"),
],
"ทวีวัฒนา": [
("ทวีวัฒนา", "10170"),
("ศาลาธรรมสพน์", "10170"),
],
"ธนบุรี": [
("บางยี่เรือ", "10600"),
("บุคคโล", "10600"),
],
"บางกอกน้อย": [
("บางขุนนนท์", "10700"),
("บ้านช่างหล่อ", "10700"),
],
"บางกะปิ": [
("คลองจั่น", "10240"),
("หัวหมาก", "10243"),
],
"บางขุนเทียน": [
("แสมดำ", "10150"),
],
"บางเขน": [
("อนุสาวรีย์", "10220"),
],
"บางคอแหลม": [
("บางคอแหลม", "10120"),
],
"บางแค": [
("บางไผ่", "10160"),
("หลักสอง", "10160"),
],
"บางซื่อ": [
("บางซื่อ", "10800"),
],
"บางนา": [
("บางนา", "10260"),
("บางนาใต้", "10260"),
],
"บางบอน": [
("บางบอน", "10150"),
("บางบอนเหนือ", "10150"),
("คลองบางบอน", "10150"),
],
"บางพลัด": [
("บางยี่ขัน", "10700"),
("บางอ้อ", "10700"),
],
"บางรัก": [
("สี่พระยา", "10500"),
("สีลม", "10500"),
("สุริยวงศ์", "10500"),
],
"บึงกุ่ม": [
("คลองกุ่ม", "10240"),
("นวลจันทร์", "10230"),
("นวมินทร์", "10240"),
],
"ปทุมวัน": [
("ปทุมวัน", "10330"),
("วังใหม่", "10120"),
("วังใหม่", "10330"),
("วังใหม่", "10400"),
],
"ประเวศ": [
("ดอกไม้", "10250"),
("ประเวศ", "10250"),
("หนองบอน", "10250"),
],
"ป้อมปราบศัตรูพ่าย": [
("คลองมหานาค", "10100"),
("บ้านบาตร", "10100"),
("วัดเทพศิรินทร์", "10100"),
("วัดโสมนัส", "10100"),
],
"พญาไท": [
("พญาไท", "10400"),
],
"พระนคร": [
("พระบรมมหาราชวัง", "10200"),
("วัดราชบพิธ", "10200"),
("สำราญราษฎร์", "10200"),
],
"ภาษีเจริญ": [
("ปากคลองภาษีเจริญ", "10160"),
],
"มีนบุรี": [
("แสนแสบ", "10510"),
],
"ราชเทวี": [
("ถนนพญาไท", "10400"),
],
"ราษฎร์บูรณะ": [
("ราษฎร์บูรณะ", "10140"),
],
"ลาดกระบัง": [
("ขุมทอง", "10520"),
("คลองสองต้นนุ่น", "10520"),
("ทับยาว", "10520"),
("คลองสามประเวศ", "10520"),
],
"ลาดพร้าว": [
("จรเข้บัว", "10230"),
("ลาดพร้าว", "10230"),
],
"วังทองหลาง": [
("คลองเจ้าคุณสิงห์", "10310"),
("สะพานสอง", "10310"),
],
"วัฒนา": [
("คลองเตยเหนือ", "10110"),
("พระโขนงเหนือ", "10260"),
],
"สวนหลวง": [
("พัฒนาการ", "10250"),
("อ่อนนุช", "10250"),
],
"สะพานสูง": [
("สะพานสูง", "10240"),
("ทับช้าง", "10250"),
],
"สัมพันธวงศ์": [
("จักรวรรดิ์", "10100"),
("ตลาดน้อย", "10100"),
("สัมพันธวงศ์", "10100"),
],
"สาทร": [
("ยานนาวา", "10120"),
],
"สายไหม": [
("ออเงิน", "10220"),
],
"หนองแขม": [
("หนองแขม", "10160"),
],
"หนองจอก": [
("คลองสิบ", "10530"),
("คลองสิบสอง", "10530"),
("คู้ฝั่งเหนือ", "10530"),
("โคกแฝด", "10530"),
("ลำต้อยติ่ง", "10530"),
],
"หลักสี่": [
("ตลาดบางเขน", "10210"),
("ทุ่งสองห้อง", "10020"),
],
"ห้วยขวาง": [
("บางกะปิ", "10310"),
("สามเสนนอก", "10310"),
],
"คลองเตย": [
("คลองตัน", "10110"),
("พระโขนง", "10110"),
],
"คลองสาน": [
("คลองต้นไทร", "10600"),
],
"คันนายาว": [
("คันนายาว", "10230"),
],
"จตุจักร": [
("จันทรเกษม", "10900"),
("ลาดยาว", "10900"),
],
"จอมทอง": [
("บางขุนเทียน", "10150"),
("บางมด", "10150"),
],
"ดอนเมือง": [
("ดอนเมือง", "10210"),
("สนามบิน", "10210"),
],
"ดุสิต": [
("ดุสิต", "10300"),
("วชิรพยาบาล", "10300"),
("สวนจิตรลดา", "10300"),
("สี่แยกมหานาค", "10300"),
],
"ตลิ่งชัน": [
("บางระมาด", "10170"),
],
"ทุ่งครุ": [
("ทุ่งครุ", "10140"),
("บางมด", "10140"),
],
"ธนบุรี": [
("ดาวคะนอง", "10600"),
("ตลาดพลู", "10600"),
("วัดกัลยาณ์", "10600"),
("สำเหร่", "10600"),
("หิรัญรูจี", "10600"),
],
"บางกอกน้อย": [
("บางขุนศรี", "10700"),
("ศิริราช", "10700"),
("ศิริราช", "10702"),
("อรุณอมรินทร์", "10700"),
],
"บางกอกใหญ่": [
("วัดท่าพระ", "10600"),
("วัดอรุณ", "10600"),
],
"บางกะปิ": [
("หัวหมาก", "10240"),
("หัวหมาก", "10250"),
],
"บางขุนเทียน": [
("ท่าข้าม", "10150"),
],
"บางเขน": [
("ท่าแร้ง", "10220"),
("ท่าแร้ง", "10230"),
],
"บางคอแหลม": [
("บางโคล่", "10120"),
("วัดพระยาไกร", "10120"),
],
"บางแค": [
("บางแค", "10160"),
("บางแคเหนือ", "10160"),
],
"บางซื่อ": [
("วงศ์สว่าง", "10800"),
],
"บางนา": [
("บางนาเหนือ", "10260"),
],
"บางบอน": [
("คลองบางพราน", "10150"),
("บางบอนใต้", "10150"),
],
"บางพลัด": [
("บางบำหรุ", "10700"),
("บางพลัด", "10700"),
],
"บางรัก": [
("บางรัก", "10500"),
("บางรัก", "10501"),
("มหาพฤฒาราม", "10500"),
],
"บึงกุ่ม": [
("คลองกุ่ม", "10230"),
("นวมินทร์", "10230"),
],
"ปทุมวัน": [
("รองเมือง", "10330"),
("ลุมพินี", "10330"),
("วังใหม่", "10110"),
("วังใหม่", "10500"),
],
"ป้อมปราบศัตรูพ่าย": [
("ป้อมปราบ", "10100"),
],
"พญาไท": [
("สามเสนใน", "10400"),
],
"พระโขนง": [
("บางจาก", "10260"),
],
"พระนคร": [
("ชนะสงคราม", "10200"),
("ตลาดยอด", "10200"),
("บวรนิเวศ", "10200"),
("บางขุนพรหม", "10200"),
("บ้านพานถม", "10200"),
("วังบูรพาภิรมย์", "10200"),
("วัดสามพระยา", "10200"),
("ศาลเจ้าพ่อเสือ", "10200"),
("เสาชิงช้า", "10200"),
],
"ภาษีเจริญ": [
("คลองขวาง", "10160"),
("คูหาสวรรค์", "10160"),
("บางจาก", "10160"),
("บางด้วน", "10160"),
("บางแวก", "10160"),
("บางหว้า", "10160"),
],
"มีนบุรี": [
("มีนบุรี", "10510"),
],
"ยานนาวา": [
("ช่องนนทรี", "10120"),
("บางโพงพาง", "10120"),
],
"ราชเทวี": [
("ถนนเพชรบุรี", "10400"),
("ทุ่งพญาไท", "10400"),
("มักกะสัน", "10400"),
],
"ราษฎร์บูรณะ": [
("บางปะกอก", "10140"),
],
"ลาดกระบัง": [
("ลาดกระบัง", "10520"),
("ลำปลาทิว", "10520"),
],
"วังทองหลาง": [
("พลับพลา", "10310"),
("วังทองหลาง", "10310"),
],
"วัฒนา": [
("คลองตันเหนือ", "10110"),
("พระโขนงเหนือ", "10110"),
],
"สวนหลวง": [
("สวนหลวง", "10250"),
],
"สะพานสูง": [
("สะพานสูง", "10250"),
("ราษฎร์พัฒนา", "10240"),
],
"สาทร": [
("ทุ่งมหาเมฆ", "10120"),
("ทุ่งวัดดอน", "10120"),
],
"สายไหม": [
("คลองถนน", "10220"),
("สายไหม", "10220"),
],
"หนองแขม": [
("หนองค้างพลู", "10160"),
],
"หนองจอก": [
("กระทุ่มราย", "10530"),
("ลำผักชี", "10530"),
("หนองจอก", "10530"),
],
"หลักสี่": [
("ทุ่งสองห้อง", "10010"),
("ทุ่งสองห้อง", "10210"),
],
"ห้วยขวาง": [
("ห้วยขวาง", "10310"),
("ห้วยขวาง", "10320"),
]},}

# %%
province_list = list(address_list.keys())
province_list
# Out:
# dict_keys(['กระบี่', 'กรุงเทพ'])

# %%
amphoe = list(address_list.values())
amphoe
# Out:
# [{'เมืองกระบี่': [('ปากน้ำ', '81000'),
#    ('กระบี่ใหญ่', '81000'),
#    ('เขาคราม', '81000'),
#    ('ไสไทย', '81000'),
#    ('อ่าวนาง', '81180'),
#    ('อ่าวนาง', '81210'),
#    ('คลองประสงค์', '81000')],
#   'เขาพนม': [('เขาดิน', '81140'),
#    ('สินปุน', '80240'),
#    ('พรุเตียว', '80240'),
#    ('หน้าเขา', '80240')],
#   'เกาะลันตา': [('เกาะลันตาใหญ่', '81150'),
#    ('เกาะลันตาน้อย', '81150'),
#    ('คลองยาง', '81120')],
#   'คลองท่อม': [('คลองท่อมใต้', '81120'),
#    ('ทรายขาว', '81170'),
#    ('พรุดินนา', '81120')],
#   'อ่าวลึก': [('อ่าวลึกใต้', '81110'),
#    ('คลองหิน', '81110'),
#    ('อ่าวลึกน้อย', '81110'),
#    ('อ่าวลึกเหนือ', '81110'),
#    ('เขาใหญ่', '81110'),
#    ('คลองยา', '81110'),
#    ('บ้านกลาง', '81110')],
#   'ปลายพระยา': [('ปลายพระยา', '81160'),
#    ('เขาเขน', '81160'),
#    ('เขาต่อ', '81160'),
#    ('คีรีวง', '81160')],
#   'ลำทับ': [('ทุ่งไทรทอง', '81120')],
#   'เหนือคลอง': [('เกาะศรีบอยา', '81130'),
#    ('คลองขนาน', '81130'),
# ...

# %%
text_list = ['ชะมาย', 'บ้านชี', 'ปุโรง', 'ภาษีเจริญ', 'กลางดง', 'บางจาก', 'กรุงเทพ', '10160']

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    for text in text_list:
        for province, districts in address_list.items():
            if text == province:
                best_match['province'] = province
            for district, subdistricts in districts.items():
                if text == district:
                    best_match['amphoe'] = district
                for subdistrict, zipcode in subdistricts:
                    if text == subdistrict:
                        best_match['district'] = subdistrict
                    if text == zipcode:
                        best_match['zipcode'] = zipcode

    result = tuple(filter(None, best_match.values()))
    return result

result = find_best_match(address_list, text_list)
print(result)
# Out:
# ('กรุงเทพ', 'ภาษีเจริญ', 'บางจาก', '10160')

# %%
address_list.keys()
# Out:
# dict_keys(['กระบี่', 'กรุงเทพ'])

# %%
address_list['กรุงเทพ'].keys()
# Out:
# dict_keys(['คลองเตย', 'คลองสาน', 'คลองสามวา', 'คันนายาว', 'จตุจักร', 'จอมทอง', 'ดอนเมือง', 'ดินแดง', 'ดุสิต', 'ตลิ่งชัน', 'ทวีวัฒนา', 'ธนบุรี', 'บางกอกน้อย', 'บางกะปิ', 'บางขุนเทียน', 'บางเขน', 'บางคอแหลม', 'บางแค', 'บางซื่อ', 'บางนา', 'บางบอน', 'บางพลัด', 'บางรัก', 'บึงกุ่ม', 'ปทุมวัน', 'ประเวศ', 'ป้อมปราบศัตรูพ่าย', 'พญาไท', 'พระนคร', 'ภาษีเจริญ', 'มีนบุรี', 'ราชเทวี', 'ราษฎร์บูรณะ', 'ลาดกระบัง', 'ลาดพร้าว', 'วังทองหลาง', 'วัฒนา', 'สวนหลวง', 'สะพานสูง', 'สัมพันธวงศ์', 'สาทร', 'สายไหม', 'หนองแขม', 'หนองจอก', 'หลักสี่', 'ห้วยขวาง', 'ทุ่งครุ', 'บางกอกใหญ่', 'พระโขนง', 'ยานนาวา'])

# %% [markdown]
# method items() คืนค่า key มาด้วย

# %%
item = list(address_list['กรุงเทพ'].items())

# %%
item[0]
# Out:
# ('คลองเตย', [('คลองตัน', '10110'), ('พระโขนง', '10110')])

# %% [markdown]
# method values() คืนค่า แค่ value

# %%
value = list(address_list['กรุงเทพ'].values())

# %%
value[0]
# Out:
# [('คลองตัน', '10110'), ('พระโขนง', '10110')]

# %%
krabi = list(address_list.values())[0]
krabi
# Out:
# {'เมืองกระบี่': [('ปากน้ำ', '81000'),
#   ('กระบี่ใหญ่', '81000'),
#   ('เขาคราม', '81000'),
#   ('ไสไทย', '81000'),
#   ('อ่าวนาง', '81180'),
#   ('อ่าวนาง', '81210'),
#   ('คลองประสงค์', '81000')],
#  'เขาพนม': [('เขาดิน', '81140'),
#   ('สินปุน', '80240'),
#   ('พรุเตียว', '80240'),
#   ('หน้าเขา', '80240')],
#  'เกาะลันตา': [('เกาะลันตาใหญ่', '81150'),
#   ('เกาะลันตาน้อย', '81150'),
#   ('คลองยาง', '81120')],
#  'คลองท่อม': [('คลองท่อมใต้', '81120'),
#   ('ทรายขาว', '81170'),
#   ('พรุดินนา', '81120')],
#  'อ่าวลึก': [('อ่าวลึกใต้', '81110'),
#   ('คลองหิน', '81110'),
#   ('อ่าวลึกน้อย', '81110'),
#   ('อ่าวลึกเหนือ', '81110'),
#   ('เขาใหญ่', '81110'),
#   ('คลองยา', '81110'),
#   ('บ้านกลาง', '81110')],
#  'ปลายพระยา': [('ปลายพระยา', '81160'),
#   ('เขาเขน', '81160'),
#   ('เขาต่อ', '81160'),
#   ('คีรีวง', '81160')],
#  'ลำทับ': [('ทุ่งไทรทอง', '81120')],
#  'เหนือคลอง': [('เกาะศรีบอยา', '81130'),
#   ('คลองขนาน', '81130'),
#   ('ตลิ่งชัน', '81130'),
# ...

# %%
if 'ปลายพระยา' in krabi:
  print(krabi['ปลายพระยา'])
# Out:
# [('ปลายพระยา', '81160'), ('เขาเขน', '81160'), ('เขาต่อ', '81160'), ('คีรีวง', '81160')]

# %%
print(krabi['ปลายพระยา'][0])
# Out:
# ('ปลายพระยา', '81160')

# %%
"คีรีว" in krabi['ปลายพระยา'][3][0]
# Out:
# True

# %%
krabi.items()
# Out:
# dict_items([('เมืองกระบี่', [('ปากน้ำ', '81000'), ('กระบี่ใหญ่', '81000'), ('เขาคราม', '81000'), ('ไสไทย', '81000'), ('อ่าวนาง', '81180'), ('อ่าวนาง', '81210'), ('คลองประสงค์', '81000')]), ('เขาพนม', [('เขาดิน', '81140'), ('สินปุน', '80240'), ('พรุเตียว', '80240'), ('หน้าเขา', '80240')]), ('เกาะลันตา', [('เกาะลันตาใหญ่', '81150'), ('เกาะลันตาน้อย', '81150'), ('คลองยาง', '81120')]), ('คลองท่อม', [('คลองท่อมใต้', '81120'), ('ทรายขาว', '81170'), ('พรุดินนา', '81120')]), ('อ่าวลึก', [('อ่าวลึกใต้', '81110'), ('คลองหิน', '81110'), ('อ่าวลึกน้อย', '81110'), ('อ่าวลึกเหนือ', '81110'), ('เขาใหญ่', '81110'), ('คลองยา', '81110'), ('บ้านกลาง', '81110')]), ('ปลายพระยา', [('ปลายพระยา', '81160'), ('เขาเขน', '81160'), ('เขาต่อ', '81160'), ('คีรีวง', '81160')]), ('ลำทับ', [('ทุ่งไทรทอง', '81120')]), ('เหนือคลอง', [('เกาะศรีบอยา', '81130'), ('คลองขนาน', '81130'), ('ตลิ่งชัน', '81130'), ('ปกาสัย', '81130')])])

# %%
keyword = "คีรีว"
found = False

# loop ผ่านแต่ละอำเภอและตำบล
for district, subdistricts in krabi.items():
    if any(keyword in subdistrict[0] for subdistrict in subdistricts):
        found = True
        print(f"คำว่า '{keyword}' พบในอำเภอ '{district}'")
        break

if not found:
    print(f"คำว่า '{keyword}' ไม่พบในทุกอำเภอใน krabi")
# Out:
# คำว่า 'คีรีว' พบในอำเภอ 'ปลายพระยา'

# %%
for district, subdistricts in krabi.items():
  print(district, subdistricts)
# Out:
# เมืองกระบี่ [('ปากน้ำ', '81000'), ('กระบี่ใหญ่', '81000'), ('เขาคราม', '81000'), ('ไสไทย', '81000'), ('อ่าวนาง', '81180'), ('อ่าวนาง', '81210'), ('คลองประสงค์', '81000')]
# เขาพนม [('เขาดิน', '81140'), ('สินปุน', '80240'), ('พรุเตียว', '80240'), ('หน้าเขา', '80240')]
# เกาะลันตา [('เกาะลันตาใหญ่', '81150'), ('เกาะลันตาน้อย', '81150'), ('คลองยาง', '81120')]
# คลองท่อม [('คลองท่อมใต้', '81120'), ('ทรายขาว', '81170'), ('พรุดินนา', '81120')]
# อ่าวลึก [('อ่าวลึกใต้', '81110'), ('คลองหิน', '81110'), ('อ่าวลึกน้อย', '81110'), ('อ่าวลึกเหนือ', '81110'), ('เขาใหญ่', '81110'), ('คลองยา', '81110'), ('บ้านกลาง', '81110')]
# ปลายพระยา [('ปลายพระยา', '81160'), ('เขาเขน', '81160'), ('เขาต่อ', '81160'), ('คีรีวง', '81160')]
# ลำทับ [('ทุ่งไทรทอง', '81120')]
# เหนือคลอง [('เกาะศรีบอยา', '81130'), ('คลองขนาน', '81130'), ('ตลิ่งชัน', '81130'), ('ปกาสัย', '81130')]

# %%
test_list = {
"กระบี่": {
"เมืองกระบี่": [
{"กระบี่น้อย": "81000"},
{"เขาทอง": "81000"},
{"ทับปริก": "81000"},
{"อ่าวนาง": "81000"},
{"หนองทะเล": "81000"},
{"หนองทะเล": "81180"},
],}}

print(test_list["กระบี่"])
print(test_list["กระบี่"]["เมืองกระบี่"])
# Out:
# {'เมืองกระบี่': [{'กระบี่น้อย': '81000'}, {'เขาทอง': '81000'}, {'ทับปริก': '81000'}, {'อ่าวนาง': '81000'}, {'หนองทะเล': '81000'}, {'หนองทะเล': '81180'}]}
# [{'กระบี่น้อย': '81000'}, {'เขาทอง': '81000'}, {'ทับปริก': '81000'}, {'อ่าวนาง': '81000'}, {'หนองทะเล': '81000'}, {'หนองทะเล': '81180'}]

# %%
# ต้องการเช็คว่า "หนองทะเล" อยู่ใน list หรือไม่
keyword = "หนองทะเล"
found = False
for subdistrict in test_list["กระบี่"]["เมืองกระบี่"]:
    if keyword in subdistrict:
        found = True
        print(f"พบ '{keyword}' พร้อมรหัสไปรษณีย์: {subdistrict}")
        break

if not found:
    print(f"ไม่พบ '{keyword}' ในข้อมูล")
# Out:
# พบ 'หนองทะเล' พร้อมรหัสไปรษณีย์: {'หนองทะเล': '81000'}

# %% [markdown]
# # demo version 1

# %% [markdown]
# pip install library

# %%
# !pip install pythainlp==5.0.3 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 11.3 MB/s eta 0:00:00

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# import data

# %%
from addresses import address_list

# %% [markdown]
# clean text

# %%
import re

def preprocess(text: str) -> str:
    """
    Generalized function to preprocess an input
    """
    text = text.strip()
    text = text.replace("ส่ง ", "")
    text = text.replace("จัดส่ง", "")
    text = text.replace("ชือ.", "")
    text = text.replace("ชื่อ ", "")
    text = text.replace("ผู้รับ", "")
    text = text.replace("ส่งที่ ", " ")
    text = text.replace("ที่อยู่ ", " ")
    text = text.replace("ที้อยุ่ ", " ")
    text = text.replace("ที่อยู่จ้า ", " ")
    text = text.replace("ส่งของที่ ", " ")
    text = text.replace("ส่งมาที่", " ")
    text = text.replace("\n-", " ")
    text = text.replace("\n", " ")
    text = text.replace(": ", " ")
    text = text.replace(":", "")
    text = text.replace("-", "")
    text = text.replace("(", "")
    text = text.replace(")", "")
    text = text.replace('"', "")
    text = text.replace('.', " ")
    # text = remove_emoji(text)
    text = " ".join([t for t in text.strip().split(" ") if t.strip() != ""])
    return text


def clean_location_text(text: str) -> str:
    """
    Clean location before using fuzzy string match
    """
    text = text.replace("แขวง", " ")
    text = text.replace("เขต", " ")
    text = text.replace("อำเภอ", " ")
    text = text.replace("ตำบล", " ")
    text = text.replace("ต.", " ")
    text = text.replace("ตฺ", "ต.")
    text = text.replace("อ.", " ")
    text = text.replace("จ.", " ")
    text = text.replace("คอหงส์", "คอหงษ์")
    text = text.replace("กทม.", "กรุงเทพ")
    text = text.replace("กทม", "กรุงเทพ")
    text = text.replace("กรุงเทพมหานคร", "กรุงเทพ")
    text = text.replace("(+66)", "0")
    return text

def extract_name(text: str) -> str:
    """
    Extracts name from the text.
    """
    name = re.findall(r'(เด็กชาย|เด็กหญิง|ด\.ช\.|ด\.ญ\.|นาย|นาง|นางสาว|น\.ส\.|ดร\.)([ก-๙]+\s[ก-๙]+)|(เด็กชาย|เด็กหญิง|ด\.ช\.|ด\.ญ\.|นาย|นาง|นางสาว|น\.ส\.|ดร\.)([ก-๙]+\s*[ก-๙]*)', text)
    if name:
        name = ''.join(name[0])
        text = text.replace(name, " ")
        return text, name
    return text, ''

def extract_phone(text: str) -> str:
    """
    Extracts phone from the text.
    """
    phone = re.findall(r'(08\d{8}|09\d{8})', text)
    # print(phone)
    if phone:
        phone = ''.join(phone[0])
        text = text.replace(phone, " ")
        return text, phone
    return text, ''

# %% [markdown]
# tokenize

# %%
from pythainlp.util import dict_trie
from pythainlp.corpus.common import thai_words

custom_word_lists = set(thai_words())
custom_word_lists.update(list(hashmap.keys()))
addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
custom_word_lists.update(addtexts)

trie = dict_trie(dict_source=custom_word_lists)

# %%
from pythainlp import Tokenizer

custom_tokenize = Tokenizer(custom_dict=trie, join_broken_num=False, keep_whitespace=False, engine='newmm')

text = " ที่ว่าการอำเภอเมืองราชบุรี ถนนหน้าอำเภอ ตำบลหน้าเมือง อำเภอเมืองราชบุรี จังหวัดราชบุรี 70000"
text = preprocess(text)
text = clean_location_text(text)
print(text)
text, name = extract_name(text)
text, phone = extract_phone(text)
print(name)
print(phone)
print(text)
# Out:
# ที่ว่าการ เมืองราชบุรี ถนนหน้า   หน้าเมือง  เมืองราชบุรี จังหวัดราชบุรี 70000
#
#
# ที่ว่าการ เมืองราชบุรี ถนนหน้า   หน้าเมือง  เมืองราชบุรี จังหวัดราชบุรี 70000

# %%
tokenize_texts = custom_tokenize.word_tokenize(text)
tokenize_texts
# Out:
# ['ที่ว่าการ',
#  'เมืองราชบุรี',
#  'ถนน',
#  'หน้า',
#  'หน้าเมือง',
#  'เมืองราชบุรี',
#  'จังหวัด',
#  'ราชบุรี',
#  '70000']

# %% [markdown]
# spell check

# %%
from pythainlp.spell import NorvigSpellChecker

custom_checker_list = set(list(hashmap.keys()))
addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
custom_checker_list.update(addtexts)
ctrie = dict_trie(dict_source=custom_checker_list)


checker = NorvigSpellChecker(custom_dict=ctrie, min_freq=1, min_len=5, max_len=30)
# checker.correct("ปอมปราบ")

# %%
words = [checker.correct(token) for token in tokenize_texts if token not in addtexts]
words
# Out:
# ['ที่ว่าการ',
#  'เมืองราชบุรี',
#  'หันคา',
#  'หน้าเมือง',
#  'เมืองราชบุรี',
#  'ราชบุรี',
#  '70000']

# %% [markdown]
# matching address

# %%
# print(address_list['ชลบุรี']['พนัสนิคม'])

# %% [markdown]
# find_best_match 1

# %%
# version 1
from addresses import address_list

# text = ['12', '/13', 'พนัสนิคม', 'พนัสนิคม', 'ชลบุรี', '20140']


def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    for text in text_list:
        for province, districts in address_list.items():
            if text == province:
                best_match['province'] = province
            for district, subdistricts in districts.items():
                if text == district:
                    best_match['amphoe'] = district
                for subdistrict, zipcode in subdistricts:
                    if text == subdistrict:
                        best_match['district'] = subdistrict
                    if text == zipcode:
                        best_match['zipcode'] = zipcode

    # result = tuple(filter(None, best_match.values()))
    return best_match


result = find_best_match(address_list, words)
print(result)
# Out:
# {'province': 'ราชบุรี', 'amphoe': 'เมืองราชบุรี', 'district': 'หน้าเมือง', 'zipcode': '70000'}

# %% [markdown]
# find_best_match 2

# %%
from addresses import address_list

text_list = ['สม',
 'วัฒนา',
 'วอแก้ว',
 'พิจิตร',
 '66',
 '/8',
 '10',
 'เขาแก้ว',
 'ท่าใหม่',
 'จันทบุรี',
 '22170']

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    # ตรวจสอบจังหวัด
    for text in text_list:
        if text in address_list:
            best_match['province'] = text
            break

    if not best_match['province']:
        return best_match

    # ตรวจสอบอำเภอในจังหวัดที่พบ
    for text in text_list:
        if text in address_list[best_match['province']]:
            best_match['amphoe'] = text
            break

    if not best_match['amphoe']:
        return best_match

    # ตรวจสอบตำบลและรหัสไปรษณีย์ในอำเภอที่พบ
    for text in text_list:
        for subdistrict, postcode in address_list[best_match['province']][best_match['amphoe']]:
            if text == subdistrict and best_match['district'] is None:
                best_match['district'] = subdistrict
            if text == postcode and best_match['zipcode'] is None:
                best_match['zipcode'] = postcode

    return best_match

result = find_best_match(address_list, words)
print(result)
# Out:
# {'province': 'ราชบุรี', 'amphoe': 'เมืองราชบุรี', 'district': 'หน้าเมือง', 'zipcode': '70000'}

# %% [markdown]
# find_address_match3

# %%
def find_address_match(address_list, text_list):
  """
  matching address from address_list data
  """
  possible_provinces = []
  best_match = {
      'province': None,
      'amphoe': None,
      'district': None,
      'zipcode': None
  }

  # เก็บรายชื่อจังหวัดที่พบใน text_list
  for text in text_list:
      if text in address_list:
          possible_provinces.append(text)
  # ตรวจสอบจังหวัดที่พบ
  for province in possible_provinces:
      amphoe_found = False
      for text in text_list:
          if text in address_list[province]:
              best_match['amphoe'] = text
              amphoe_found = True
              break
      print(possible_provinces)

      if not amphoe_found:
          continue


      # ตรวจสอบตำบลและรหัสไปรษณีย์ในอำเภอที่พบ
      for text in text_list:
          for subdistrict, postcode in address_list[province][best_match['amphoe']]:
              if text == subdistrict and best_match['district'] is None:
                  best_match['district'] = subdistrict
              if text == postcode and best_match['zipcode'] is None:
                  best_match['zipcode'] = postcode

      # ตรวจสอบว่าข้อมูลที่พบเป็นของจังหวัดไหน
      if best_match['district'] and best_match['zipcode']:
          best_match['province'] = province
          break
  return best_match

result = find_address_match(address_list, words)
print(result)
# Out:
# ['ราชบุรี']
# {'province': 'ราชบุรี', 'amphoe': 'เมืองราชบุรี', 'district': 'หน้าเมือง', 'zipcode': '70000'}

# %%
result.update({'name': name})
result.update({'phone': phone})

# %%
result
# Out:
# {'province': 'ราชบุรี',
#  'amphoe': 'เมืองราชบุรี',
#  'district': 'หน้าเมือง',
#  'zipcode': '70000',
#  'name': '',
#  'phone': ''}

# %%
data = [(word, hashmap[word]) for word in result if word in list(hashmap.keys())]
data
# Out:
# []

# %%
print(f"Tagging: {data}\nName: {name}\nPhone: {phone}")
# Out:
# Tagging: []
# Name:
# Phone:

# %% [markdown]
# # detection

# %%
# !pip install pythainlp==5.0.3 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 27.5 MB/s eta 0:00:00

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  create toolfunctions

# %%
from addresses import address_list
from pythainlp.util import dict_trie
from pythainlp.corpus.common import thai_words
from pythainlp import Tokenizer
from pythainlp.spell import NorvigSpellChecker

import re

def preprocess(text: str) -> str:
    """
    Generalized function to preprocess an input
    """
    text = text.strip()
    text = text.replace("ส่ง ", "")
    text = text.replace("จัดส่ง", "")
    text = text.replace("ชือ.", "")
    text = text.replace("ชื่อ ", "")
    text = text.replace("ผู้รับ", "")
    text = text.replace("ส่งที่ ", " ")
    text = text.replace("ที่อยู่ ", " ")
    text = text.replace("ที้อยุ่ ", " ")
    text = text.replace("ที่อยู่จ้า ", " ")
    text = text.replace("ส่งของที่ ", " ")
    text = text.replace("ส่งมาที่", " ")
    text = text.replace("โทรศัพท์", " ")
    text = text.replace("โทร.", " ")
    text = text.replace("โทร", " ")
    text = text.replace("\n-", " ")
    text = text.replace("\n", " ")
    text = text.replace(": ", " ")
    text = text.replace(":", "")
    text = text.replace("-", "")
    text = text.replace("(", "")
    text = text.replace(")", "")
    text = text.replace('"', "")
    # text = remove_emoji(text)
    text = " ".join([t for t in text.strip().split(" ") if t.strip() != ""])
    return text


def clean_location_text(text: str) -> str:
    """
    Clean location before using fuzzy string match
    """
    text = text.replace("หมู่บ้าน", " ")
    text = text.replace("ซอย", " ")
    text = text.replace("แขวง", " ")
    text = text.replace("เขต", " ")
    text = text.replace("อำเภอ", " ")
    text = text.replace("ตำบล", " ")
    text = text.replace("ถ.", " ")
    text = text.replace("ซ.", " ")
    text = text.replace("ตฺ", "ต.")
    text = text.replace("ต.", " ")
    text = text.replace("อ.", " ")
    text = text.replace("จ.", " ")
    text = text.replace("คอหงส์", "คอหงษ์")
    text = text.replace("กทม.", "กรุงเทพ")
    text = text.replace("กทม", "กรุงเทพ")
    text = text.replace("กรุงเทพมหานคร", "กรุงเทพ")
    text = text.replace(".", "")
    return text

# def extract_name(text: str) -> str:
#     """
#     Extracts name from the text.
#     """
#     name = re.findall(r'(เด็กชาย|เด็กหญิง|ด\.ช\.|ด\.ญ\.|นาย|นาง|นางสาว|น\.ส\.|ดร\.)([ก-๙]+\s[ก-๙]+)|(เด็กชาย|เด็กหญิง|ด\.ช\.|ด\.ญ\.|นาย|นาง|นางสาว|น\.ส\.|ดร\.)([ก-๙]+\s*[ก-๙]*)', text)
#     if name:
#         name = ''.join(name[0])
#         text = text.replace(name, " ")
#         return text, name
#     return text, ''
def extract_name(text: str) -> str:
    """
    Extracts name from the text.
    """
    name = re.search(r'(เด็กชาย|เด็กหญิง|ด\.ช\.|ด\.ญ\.|นาย|นาง|นางสาว|น\.ส\.|ดร\.|คุณ)\s*([ก-๙]+)\s*([ก-๙]+)', text)
    if name:
        full_name = name.group(0)
        text = text.replace(full_name, " ")
        return text, full_name
    return text, ''


def extract_phone(text: str):
    """
    Extracts phone from the text.
    """
    phone_match = re.search(r'(\+66\s?|0)([2-9]\d[\s-]?\d{3}[\s-]?\d{4})', text)
    if phone_match:
        phone = phone_match.group(0)
        # Standardize phone number
        phone_standardized = phone.replace(' ', '').replace('-', '').replace('.', '')
        if phone_standardized.startswith('+66'):
            phone_standardized = '0' + phone_standardized[3:]
        text = text.replace(phone_match.group(0), " ")
        return text.strip(), phone_standardized
    return text.strip(), ''

def find_address_match1(address_list, text_list):
  """
  matching address from address_list data
  """
  possible_provinces = []
  best_match = {
      'province': None,
      'amphoe': None,
      'district': None,
      'zipcode': None
  }

  # เก็บรายชื่อจังหวัดที่พบใน text_list
  for text in text_list:
      if text in address_list:
          possible_provinces.append(text)

  # ตรวจสอบจังหวัดที่พบ
  for province in possible_provinces:
      amphoe_found = False
      for text in text_list:
          if text in address_list[province]:
              best_match['amphoe'] = text
              amphoe_found = True
              break

      if not amphoe_found:
          continue

      # ตรวจสอบตำบลและรหัสไปรษณีย์ในอำเภอที่พบ
      for text in text_list:
          for subdistrict, postcode in address_list[province][best_match['amphoe']]:
              if text == subdistrict and best_match['district'] is None:
                  best_match['district'] = subdistrict
              if text == postcode and best_match['zipcode'] is None:
                  best_match['zipcode'] = postcode

      # ตรวจสอบว่าข้อมูลที่พบเป็นของจังหวัดไหน
      if best_match['district'] and best_match['zipcode']:
          best_match['province'] = province
          break

  return best_match


def find_address_match2(address_list, text_list):
  """
    find address match
    version 2 fix
    แก้อำเภอเมือง
    ตรวจสอบหาจังหวัดน่านได้

  """
  best_match = {
      'province': None,
      'amphoe': None,
      'district': None,
      'zipcode': None
  }

  possible_provinces = []

  # Check province and insert to list
  for text in text_list:
      if text in address_list:
          possible_provinces.append(text)

  # Check and correct for 'เมือง'
  for province in possible_provinces:
      for i, text in enumerate(text_list):
          if text == 'เมือง' and province != 'ศรีสะเกษ':
              text_list[i] = 'เมือง' + province
              break

  # Initialize potential matches
  district_matches = []
  amphoe_matches = []
  zipcode_matches = []

  # Collect all matches first
  for province in possible_provinces:
      for text in text_list:
          for amphoe in address_list[province]:
              for subdistrict, postcode in address_list[province][amphoe]:
                  if text == subdistrict:
                      district_matches.append((province, amphoe, subdistrict))
                  if text == postcode:
                      zipcode_matches.append((province, amphoe, postcode))
              if text == amphoe:
                  amphoe_matches.append((province, amphoe))

  # Determine best matches based on collected data
  # Prioritize the full match with district and zipcode
  for province, amphoe, subdistrict in district_matches:
      for p, a, z in zipcode_matches:
          if province == p and amphoe == a:
              best_match['province'] = province
              best_match['amphoe'] = amphoe
              best_match['district'] = subdistrict
              best_match['zipcode'] = z
              return best_match

  # If full match not found, prioritize district and amphoe
  for province, amphoe, subdistrict in district_matches:
      best_match['province'] = province
      best_match['amphoe'] = amphoe
      best_match['district'] = subdistrict
      break  # Take the first match

  # If no district match, prioritize amphoe and zipcode
  for province, amphoe in amphoe_matches:
      for p, a, z in zipcode_matches:
          if province == p and amphoe == a:
              best_match['province'] = province
              best_match['amphoe'] = amphoe
              best_match['zipcode'] = z
              return best_match

  # If no full match, take first amphoe match
  for province, amphoe in amphoe_matches:
      if not best_match['amphoe']:
          best_match['province'] = province
          best_match['amphoe'] = amphoe
          break  # Take the first match

  # If no amphoe match, take first zipcode match
  for province, amphoe, postcode in zipcode_matches:
      if not best_match['zipcode']:
          best_match['province'] = province
          best_match['amphoe'] = amphoe
          best_match['zipcode'] = postcode
          break  # Take the first match

  return best_match

def initial_nlp_tools(hashmap):
  """
  create pythainlp tools
  word tokenize and spellchecker
  """
  # custom_word_lists = set(thai_words())
  # custom_word_lists.update(list(hashmap.keys()))

  custom_word_lists = set(list(hashmap.keys()))
  addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
  custom_word_lists.update(addtexts)
  # BoW for word tokenize
  trie = dict_trie(dict_source=custom_word_lists)
  # Create Tokenizer
  custom_tokenize = Tokenizer(custom_dict=trie, join_broken_num=False, keep_whitespace=False, engine='newmm')

  custom_checker_list = set(list(hashmap.keys()))
  addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
  custom_checker_list.update(addtexts)
  # BoW for word spellchecker
  ctrie = dict_trie(dict_source=custom_checker_list)
  # Create SpellChecker
  checker = NorvigSpellChecker(custom_dict=ctrie, min_freq=1, min_len=5, max_len=30)
  return custom_tokenize, checker


def extract_address(text, custom_tokenize, checker, address_list):
  # result format
  matching_result = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None,
        'name': None,
        'phone': None
  }

  # text process
  text = preprocess(text)
  text = clean_location_text(text)
  # extract and update matching {name, phone} data
  text, name = extract_name(text)
  text, phone = extract_phone(text)
  if name != None:
    matching_result['name'] = name
  if phone != None:
    matching_result['phone'] = phone

  # tokenize text
  # tokenize_texts = custom_tokenize.word_tokenize(text)
  # spell checker
  # word_lists = [checker.correct(token) for token in tokenize_texts
  #               if token not in ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
  #               and token not in address_list.keys()]
  # tokenize text
  tokenize_texts = custom_tokenize.word_tokenize(text)
  # spell checker
  word_lists = [checker.correct(token) if token not in ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
                and token not in address_list.keys() else token for token in tokenize_texts]
  print(word_lists)
  # print(word_lists)
  result = find_address_match2(address_list, word_lists)
  # print(result)
  #update data
  matching_result.update(result)

  return matching_result

# %%
from addresses import address_list
text_input = [
    "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
              ]
custom_tokenize, checker = initial_nlp_tools(hashmap)
for text in text_input:
  text = preprocess(text)
  text = clean_location_text(text)
  # extract and update matching {name, phone} data
  text, name = extract_name(text)
  text, phone = extract_phone(text)
  ()
  # tokenize text
  tokenize_texts = custom_tokenize.word_tokenize(text)
  # spell checker
  word_lists = [checker.correct(token) if token not in ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
                and token not in address_list.keys() else token for token in tokenize_texts]

  print(tokenize_texts)
  print(word_lists)
# Out:
# ['อนงค์ลักษณ์', '9', '/56', 'ม', '3', 'นฤมลศิริ', '2', 'บุญศิริ', 'สุขุมวิท', 'บางเมือง', 'เมืองสมุทรปราการ', 'สมุทรปนาการ', '10270']
# ['อนงค์ลักษณ์', '9', '/56', 'ม', '3', 'นฤมลศิริ', '2', 'บุญศิริ', 'สุขุมวิท', 'บางเมือง', 'เมืองสมุทรปราการ', 'สมุทรปราการ', '10270']

# %%
# ทดสอบฟังก์ชัน
text_input = [
    "คุณ ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n(+66)83 1348844",
    "คุณตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์ 10100\n083 1348844",
    "นาย ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์ 10100\n0831348844",
]
for text in text_input:
  text = preprocess(text)
  text = clean_location_text(text)
  # extract and update matching {name, phone} data
  text, name = extract_name(text)
  text, phone = extract_phone(text)
  print(text)
  print(name)
# Out:
# 152154 ถนน เยาวราช   จักรวรรดิ์   สัมพันธวงศ์ กรุงเทพ 10100
# คุณ ตรัยวิสข์ บัวขาว
# 152154 ถนน เยาวราช   จักรวรรดิ์   สัมพันธวงศ์ 10100
# คุณตรัยวิสข์ บัวขาว
# 152154 ถนน เยาวราช   จักรวรรดิ์   สัมพันธวงศ์ 10100
# นาย ตรัยวิสข์ บัวขาว

# %%
text_list = [
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "- ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\nถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 แขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ กรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100",
    # "อรวรรณ\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาว\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักร เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง วรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต ตลิ่งชัน\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง ลาดพร้าว เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n(+66)3 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n(+66)83 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10170\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nนนทบุรี 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 134884",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n000 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 1010\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง/เขต ลาดพร้าว\nกรุงเทพ 10230\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง/เขต ลาดพร้าว\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง สัมพันธวงศ์ เขต จักรวรรดิ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง/เขต ลาดพร้าว\nกรุงเทพ 10230\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง-เขต ลาดพร้าว\nกรุงเทพ 10230\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง-เขต ลาดพร้าว\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\nบ้านเลขที่ 152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nจักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขตพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธ\nกรุงเทพ 10100\n083 1348844",
    # "*ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว*\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083-134-8844",
    # "ตรัยวิสข์ บัวขาว 0000831348844\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 101000831348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวงจักรวรรดิ์ เขตสัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n0651348844",
    # "ตรัยวิสข์ บัวขาว\n152*154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n0000831348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พญาไท\nแขวงถนนพญาไท เขตราชเทวี กรุงเทพมหานคร รหัสไปรษณีย์ 10400\n0000831348844",
    # "ตรัยวิสข์ บัวขาว\n152 ตำบลถนนขาด อำเภอเมืองฯ จังหวัดนครปฐม 73000\n0000831348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 เยาวราช\n/ จักรวรรดิ์ สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพฯ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 Yaowarat Road\nChakkrawat, Samphanthawong District\nBangkok 10100\nTel.0000831348844",
    # "ภาณุมาศ ผ่องทรัพย์ โรงงานน้ำแข็ง ก ไก่ 788 ม. 5 ต.ดอนเจดีย์ อ.ดอนเจดีย์ จ.สุพรรณบุรี 72170 0829329986",
    # "9/183 หมู่บ้านกลางเมืองเกษตรนวมินทร์ 2 ซอยลาดปลาเค้า79 ถนนลาดปลาเค้า แขวงอนุสาวรีย์ เขตบางเขน 10220 0822236547",
    # "ศศิดา หินทอง 082-492-2944\n581/91 ซอยช้อยเพ็ง หมู่บ้านพฤกษาวิลล์ 107/5 แขวง ทุ่งครุเขตทุ่งครุ กรุงเทพมหานคร 10140",
    # "นางสาว บุษรีย์ จาแคล่วคล่อง\n27/704 ชั้น14 อาคารG\nคอนโดสวัสดีกรุงเทพ\nซอยหมู่บ้านมิตรภาพ\nหนองบอน,ประเวศ\nกทม 10250\n0800846122\n(ไม่รับสายกรุณาฝากไว้ที่นิติ)",
    # "คุณ นภาพร\nฝ่ายขายและการตลาดไปรษณีย์ด่วนพิเศษ/โลจิสติกส์ ขล. ส่วนบริการลูกค้า e-Commerce บม. บริษัท ไปรษณีย์ไทย จำกัด 111 ถนนแจ้งวัฒนะ\nแขวงทุ่งสองห้อง เขตหลักสี่ กรุงเทพ 10210\nเบอร์โทร : 091-771-8664",
    # "กุ๊กกิ๊ก 0940951159\nเวียงนาราเพลส (ห้อง.110)294 หมู่ 4 (ถนนหมู่บ้านลดาวัลย์ ซอย7-หมู่บ้านสินธานี 1) ต.รอบเวียง อ.เมือง จ.เชียงราย 57000",
    # "ธันยพร 56/5 ม.7 (ซ.5)ต.ซับสมอทอด อ.บึงสามพัน จ.เพชรบูรณ์ 67160 (0962788986) (บ้านอยู่ติดกับสายป่าน อพาร์ทเม้น)",
    "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
    # "ลซ 0986725611\n581/91 ซอยช้อยเพ็ง หมู่บ้านพฤกษาวิลล์ 107/5 แขวง ทุ่งครุ เขตทุ่งครุ กรุงเทพมหานคร 10140",
    "วาสนา วนาอนุรักษ์\n33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079"
]

# %%
text_list = [
    # '182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741',
    # 'สมพัฒน์ แก้วพิจิตร 66/8 ม.10 ต.เขาแก้ว อ.ท่าใหม่ จ.จันทบุรี 22170',
    # 'ที่อยู่ 111/1 หมู่ 7 ตำบล แสนสุข อำเภอ เมืองชลบุรี จังหวัด ชลบุรี 20130',
    # 'ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี ตำบล แสนสุข',
    # 'ตำบล แสนสุข ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี',
    # '680 ถ.สุขมุวิท ต.บางปลาสร้อย อ.เมืองชลบุรี จ.ชลบุรี 20000',
    # '259 หมู่11 ถ.สืบศิริ ต.เมืองปัก อ.ปักธงชัย จ.นครราชสีมา 30150',
    # '87 ถ.สุขุมวิท ต.ปากน้ำ อ.เมืองสมุทรปราการ จ.สมุทรปราการ 10270',
    # '11/1 หมู่ 4 ตำบล นามะตูม อำเภอ พนัสนิคม จังหวัด ชลบุรี 20140',
    # '12/13 ถนนเทศบาลพัฒนา ตำบลพนัสนิคม อำเภอพนัสนิคม จังหวัดชลบุรี 20140',
    # '21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100',
    # "55) 30-12-62 นายเชิดชัย สมหมาย 107/1 หมู่ 6 ซ.หมู่บ้านโรงกุลี ซอย 10 ถนนมิตรภาพ ต.กลางดง อำเภอ / ตำบล : ปากช่อง จังหวัด : นครราชสีมา 30320 Tel 091-2719547",
    # "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547",
    # "55)30-12-62107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547เชิดชัยสมหมายนามะตูม อำเภอ พนัสนิคม",
    # "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547",
    "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547",
    "3นายสมชาย ใจดี 081-234-5678 หรือ 0877170741 110/1 อาคาร Cube space ชั้น 14 ถ.กรุงธนบุรี บางลำภูล่าง คลองสาน กรุงเทพฯ 10600 จ-ศ 10:00-19:000",
    # "คุณมานะ คงวุฒิปัญญา 123/676 087.442-5664 บางอค กทม ติดต่อ 9:00 - 15:00",
    # "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
    "วาสนา วนาอนุรักษ์\n33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079"

]

custom_tokenize, checker = initial_nlp_tools(hashmap)

result_list = []
for text in text_list:
  print(text)
  matching_result = extract_address(text=text, custom_tokenize=custom_tokenize, checker=checker, address_list=address_list)
  print(matching_result, "\n")
  result_list.append(matching_result)
# Out:
# 55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547
# ['55301262', '107', '/1', 'หมู่', '6', 'ปุโรง', 'กุลี', '10', 'ถนน', 'มิตรภาพ', 'กลางดง', '/', 'ปากช่อง', 'จังหวัด', 'นครราชสีมา', '30320']
# {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัยสมหมาย', 'phone': '0912719547'}
#
# 3นายสมชาย ใจดี 081-234-5678 หรือ 0877170741 110/1 อาคาร Cube space ชั้น 14 ถ.กรุงธนบุรี บางลำภูล่าง คลองสาน กรุงเทพฯ 10600 จ-ศ 10:00-19:000
# ['3', 'เหนือ', '0877170741', '110', '/1', 'นาคาย', 'Cube', 'space', 'ชั้น', '14', 'ก', 'รุง', 'ธนบุรี', 'บางลำภูล่าง', 'คลองสาน', 'กรุงเทพ', 'ฯ', '10600', 'จศ', '100019000']
# {'province': 'กรุงเทพ', 'amphoe': 'คลองสาน', 'district': 'บางลำภูล่าง', 'zipcode': '10600', 'name': 'นายสมชาย ใจดี', 'phone': '0812345678'}
#
# วาสนา วนาอนุรักษ์
# 33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079
# ...

# %% [markdown]
# # Update Process

# %%
print('น่าน' in custom_checker_list)
print(custom_checker_list)
# Out:
# True
# ...

# %%
checker.spell('น่าน')
# Out:
# ['ท่านา', 'นาจาน', 'นาอาน', 'นาด่าน']

# %% [markdown]
# จับชื่อ คำนำหน้า เว้น ชื่อ

# %%
import re

def extract_name(text: str) -> str:
    """
    Extracts name from the text.
    """
    name = re.search(r'(เด็กชาย|เด็กหญิง|ด\.ช\.|ด\.ญ\.|นาย|นาง|นางสาว|น\.ส\.|ดร\.|คุณ)\s*([ก-๙]+)\s*([ก-๙]+)', text)
    if name:
        full_name = name.group(0)
        text = text.replace(full_name, " ")
        return text, full_name
    return text, ''
# ทดสอบฟังก์ชัน
text_input = [
    "คุณ ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n(+66)83 1348844",
    "คุณตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์ 10100\n083 1348844",
    "นาย ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์ 10100\n0831348844",
]

for text in text_input:
    clean_text = preprocess(text)
    clean_text = clean_location_text(clean_text)
    # extract and update matching {name, phone} data
    clean_text, name = extract_name(clean_text)
    clean_text, phone = extract_phone(clean_text)
    print(f"Text originl: {text}")
    print(f"Cleaned text: {clean_text}")
    print(f"Extracted name: {name}")
    print(f"Extracted phone: {phone}")
    print("------")
# Out:
# Text originl: คุณ ตรัยวิสข์ บัวขาว
# 152-154 ถนน เยาวราช
# แขวง จักรวรรดิ์ เขต สัมพันธวงศ์
# กรุงเทพ 10100
# (+66)83 1348844
# Cleaned text:   152154 ถนน เยาวราช   จักรวรรดิ์   สัมพันธวงศ์ กรุงเทพ 10100
# Extracted name: คุณ ตรัยวิสข์ บัวขาว
# Extracted phone: 0831348844
# ------
# Text originl: คุณตรัยวิสข์ บัวขาว
# 152-154 ถนน เยาวราช
# แขวง จักรวรรดิ์ เขต สัมพันธวงศ์ 10100
# 083 1348844
# Cleaned text:   152154 ถนน เยาวราช   จักรวรรดิ์   สัมพันธวงศ์ 10100
# Extracted name: คุณตรัยวิสข์ บัวขาว
# Extracted phone: 0831348844
# ------
# Text originl: นาย ตรัยวิสข์ บัวขาว
# 152-154 ถนน เยาวราช
# แขวง จักรวรรดิ์ เขต สัมพันธวงศ์ 10100
# 0831348844
# Cleaned text:   152154 ถนน เยาวราช   จักรวรรดิ์   สัมพันธวงศ์ 10100
# Extracted name: นาย ตรัยวิสข์ บัวขาว
# Extracted phone: 0831348844
# ------

# %% [markdown]
# ver4 แก้ไข อำเภอเมือง

# %%
from addresses import address_list
# address_list = {
#     'ศรีสะเกษ': {'กันทรลักษ์': [('เมือง', '33110')]},
#     'เลย': {'เมืองเลย': [('เมือง', '42000'), ('ศรีสองรัก', '42100')]},
#     'ชลบุรี': {'เมืองชลบุรี': [('แสนสุข', '20130'), ('บ้านปึก', '20130')]}
# }

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    possible_provinces = []
    amphoe_found = False

    # Check province and insert to list
    for text in text_list:
        if text in address_list:
            possible_provinces.append(text)

    # Check and correct for 'เมือง'
    for province in possible_provinces:
        for i, text in enumerate(text_list):
            if text == 'เมือง' and province != 'ศรีสะเกษ':
                text_list[i] = 'เมือง' + province
                break  # case user input อำเภอเมือง จะเติมชื่อจังหวัดให้

    # Check amphoe in province
    for province in possible_provinces:
        for text in text_list:
            if text in address_list[province]:
                best_match['amphoe'] = text
                amphoe_found = True
                break

        if not amphoe_found:
            continue

        # Check subdistrict and zipcode in amphoe found
        for text in text_list:
            if best_match['amphoe'] in address_list[province]:
                for subdistrict, postcode in address_list[province][best_match['amphoe']]:
                    if text == subdistrict:
                        best_match['district'] = subdistrict
                    if text == postcode:
                        best_match['zipcode'] = postcode

        if best_match['district'] and best_match['zipcode']:
            best_match['province'] = province
            break

    return best_match

# Test cases
test_cases = [
    # ['5', '1', 'เมือง', 'กันทรลักษ์','ศรีสะเกษ', '33110'],
    # ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    # ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    # ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    # ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],  # New test case
    # ['ที่ว่าการ', 'เมืองราชบุรี', 'หันคา', 'หน้าเมือง','เมืองราชบุรี','ราชบุรี','70000'],# New test case
    # ["เขาแก้ว", "ท่าใหม่", "จันทบุรี", "22170"],
    ["นาน้อย" ,"นาน้อย" ,"น่าน" "55150"]
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# Case 1: {'province': None, 'amphoe': None, 'district': None, 'zipcode': None}

# %%
from addresses import address_list

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    possible_provinces = []
    amphoe_found = False
    district_found = False
    zipcode_found = False

    # Check province and insert to list
    for text in text_list:
        if text in address_list:
            possible_provinces.append(text)

    # Check and correct for 'เมือง'
    for province in possible_provinces:
        for i, text in enumerate(text_list):
            if text == 'เมือง' and province != 'ศรีสะเกษ':
                text_list[i] = 'เมือง' + province
                break  # case user input อำเภอเมือง จะเติมชื่อจังหวัดให้

    # Check amphoe in province
    for province in possible_provinces:
        for text in text_list:
            if text in address_list[province]:
                best_match['amphoe'] = text
                amphoe_found = True
                break

        if not amphoe_found:
            continue

        # Check subdistrict and zipcode in amphoe found
        for text in text_list:
            if best_match['amphoe'] in address_list[province]:
                for subdistrict, postcode in address_list[province][best_match['amphoe']]:
                    if text == subdistrict and not district_found:
                        best_match['district'] = subdistrict
                        district_found = True
                    if text == postcode and not zipcode_found:
                        best_match['zipcode'] = postcode
                        zipcode_found = True

        if district_found and zipcode_found:
            best_match['province'] = province
            break

    return best_match

# Test cases
test_cases = [
    ['5', '1', 'เมือง', 'กันทรลักษ์','ศรีสะเกษ', '33110'],
    ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],  # New test case
    ['ที่ว่าการ', 'เมืองราชบุรี', 'หันคา', 'หน้าเมือง','เมืองราชบุรี','ราชบุรี','70000'], # New test case
    ["เขาแก้ว", "ท่าใหม่", "จันทบุรี", "22170"],
    ["ในเวียง" ,"เมือง" ,"น่าน", "55000"],
    ["ธนบุรี", "บางลำภูล่าง", "คลองสาน", "กรุงเทพ", "10600"],
    ["กลางดง", "ปากช่อง", "นครราชสีมา", "30320"]
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# Case 1: {'province': 'ศรีสะเกษ', 'amphoe': 'กันทรลักษ์', 'district': 'เมือง', 'zipcode': '33110'}
# Case 2: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 3: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 4: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'ศรีสองรัก', 'zipcode': '42100'}
# Case 5: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บ้านปึก', 'zipcode': '20130'}
# Case 6: {'province': 'ราชบุรี', 'amphoe': 'เมืองราชบุรี', 'district': 'หน้าเมือง', 'zipcode': '70000'}
# Case 7: {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170'}
# Case 8: {'province': 'น่าน', 'amphoe': 'เมืองน่าน', 'district': 'ในเวียง', 'zipcode': '55000'}
# Case 9: {'province': None, 'amphoe': 'ธนบุรี', 'district': None, 'zipcode': '10600'}
# Case 10: {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320'}

# %%
from addresses import address_list

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    possible_provinces = []
    amphoe_found = False

    # Check province and insert to list
    for text in text_list:
        if text in address_list:
            possible_provinces.append(text)

    # Check and correct for 'เมือง'
    for province in possible_provinces:
        for i, text in enumerate(text_list):
            if text == 'เมือง' and province != 'ศรีสะเกษ':
                text_list[i] = 'เมือง' + province
                break  # case user input อำเภอเมือง จะเติมชื่อจังหวัดให้

    # Check amphoe in province
    for province in possible_provinces:
        for text in text_list:
            if text in address_list[province]:
                best_match['amphoe'] = text
                amphoe_found = True
                break

        if not amphoe_found:
            continue

        # Check subdistrict and zipcode in amphoe found
        for text in text_list:
            if best_match['amphoe'] in address_list[province]:
                for subdistrict, postcode in address_list[province][best_match['amphoe']]:
                    if text == subdistrict:
                        best_match['district'] = subdistrict
                    if text == postcode:
                        best_match['zipcode'] = postcode

        if best_match['district'] and best_match['zipcode']:
            best_match['province'] = province
            break

    return best_match

# Test cases
test_cases = [
    ['5', '1', 'เมือง', 'กันทรลักษ์','ศรีสะเกษ', '33110'],
    ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],  # New test case
    ['ที่ว่าการ', 'เมืองราชบุรี', 'หันคา', 'หน้าเมือง','เมืองราชบุรี','ราชบุรี','70000'], # New test case
    ["เขาแก้ว", "ท่าใหม่", "จันทบุรี", "22170"],
    ["ในเวียง" ,"เมือง" ,"น่าน", "55000"],
    ["ธนบุรี", "บางลำภูล่าง", "คลองสาน", "กรุงเทพ", "10600"],
    ["กลางดง", "ปากช่อง", "นครราชสีมา", "30320"]
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# Case 1: {'province': 'ศรีสะเกษ', 'amphoe': 'กันทรลักษ์', 'district': 'เมือง', 'zipcode': '33110'}
# Case 2: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 3: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 4: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'ศรีสองรัก', 'zipcode': '42100'}
# Case 5: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บ้านปึก', 'zipcode': '20130'}
# Case 6: {'province': 'ราชบุรี', 'amphoe': 'เมืองราชบุรี', 'district': 'หน้าเมือง', 'zipcode': '70000'}
# Case 7: {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'ท่าใหม่', 'zipcode': '22170'}
# Case 8: {'province': 'น่าน', 'amphoe': 'เมืองน่าน', 'district': 'ในเวียง', 'zipcode': '55000'}
# Case 9: {'province': None, 'amphoe': 'ธนบุรี', 'district': None, 'zipcode': '10600'}
# Case 10: {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'ปากช่อง', 'zipcode': '30320'}

# %%
from addresses import address_list

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    possible_provinces = []

    # Check province and insert to list
    for text in text_list:
        if text in address_list:
            possible_provinces.append(text)

    # Check and correct for 'เมือง'
    for province in possible_provinces:
        for i, text in enumerate(text_list):
            if text == 'เมือง' and province != 'ศรีสะเกษ':
                text_list[i] = 'เมือง' + province
                break

    # Initialize potential matches
    district_matches = []
    amphoe_matches = []
    zipcode_matches = []

    # Collect all matches first
    for province in possible_provinces:
        for text in text_list:
            for amphoe in address_list[province]:
                for subdistrict, postcode in address_list[province][amphoe]:
                    if text == subdistrict:
                        district_matches.append((province, amphoe, subdistrict))
                    if text == postcode:
                        zipcode_matches.append((province, amphoe, postcode))
                if text == amphoe:
                    amphoe_matches.append((province, amphoe))

    # Determine best matches based on collected data
    # Prioritize the full match with district and zipcode
    for province, amphoe, subdistrict in district_matches:
        for p, a, z in zipcode_matches:
            if province == p and amphoe == a:
                best_match['province'] = province
                best_match['amphoe'] = amphoe
                best_match['district'] = subdistrict
                best_match['zipcode'] = z
                return best_match

    # If full match not found, prioritize district and amphoe
    for province, amphoe, subdistrict in district_matches:
        best_match['province'] = province
        best_match['amphoe'] = amphoe
        best_match['district'] = subdistrict
        break  # Take the first match

    # If no district match, prioritize amphoe and zipcode
    for province, amphoe in amphoe_matches:
        for p, a, z in zipcode_matches:
            if province == p and amphoe == a:
                best_match['province'] = province
                best_match['amphoe'] = amphoe
                best_match['zipcode'] = z
                return best_match

    # If no full match, take first amphoe match
    for province, amphoe in amphoe_matches:
        if not best_match['amphoe']:
            best_match['province'] = province
            best_match['amphoe'] = amphoe
            break  # Take the first match

    # If no amphoe match, take first zipcode match
    for province, amphoe, postcode in zipcode_matches:
        if not best_match['zipcode']:
            best_match['province'] = province
            best_match['amphoe'] = amphoe
            best_match['zipcode'] = postcode
            break  # Take the first match

    return best_match

# Test cases
test_cases = [
    ['5', '1', 'เมือง', 'กันทรลักษ์','ศรีสะเกษ', '33110'],
    ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],  # New test case
    ['ที่ว่าการ', 'เมืองราชบุรี', 'หันคา', 'หน้าเมือง','เมืองราชบุรี','ราชบุรี','70000'], # New test case
    ["เขาแก้ว", "ท่าใหม่", "จันทบุรี", "22170"],
    ["ในเวียง" ,"เมือง" ,"น่าน", "5500"],
    ["ธนบุรี", "บางลำภูล่าง", "คลองสาน", "กรุงเทพ", "10600"],
    ['55301262', '107', '/1', 'หมู่', '6', 'ซ.', 'หมู่', 'บ้านนา', 'ปุโรง', 'กุลี', 'ซอย', '10', 'ถนน', 'มิตรภาพ', 'กลางดง', '/', 'ปากช่อง', 'จังหวัด', 'นครราชสีมา', '30320'],
    ['55301262', '107', '/1', 'หมู่', '6', 'ซ.', 'หมู่', 'บ้านนา', 'ปุโรง', 'กุลี', 'ซอย', '10', 'ถนน', 'มิตรภาพ', 'กลางดง', '/', 'ปากช่อง', 'จังหวัด', 'นครราชสีมา', '30320'],
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# Case 1: {'province': 'ศรีสะเกษ', 'amphoe': 'กันทรลักษ์', 'district': 'เมือง', 'zipcode': '33110'}
# Case 2: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 3: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 4: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'ศรีสองรัก', 'zipcode': '42100'}
# Case 5: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บ้านปึก', 'zipcode': '20130'}
# Case 6: {'province': 'ราชบุรี', 'amphoe': 'เมืองราชบุรี', 'district': 'หน้าเมือง', 'zipcode': '70000'}
# Case 7: {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170'}
# Case 8: {'province': 'น่าน', 'amphoe': 'เมืองน่าน', 'district': 'ในเวียง', 'zipcode': None}
# Case 9: {'province': 'กรุงเทพ', 'amphoe': 'คลองสาน', 'district': 'บางลำภูล่าง', 'zipcode': '10600'}
# Case 10: {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320'}
# ...

# %%
from addresses import address_list
text_input = [
    "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
    "วาสนา วนาอนุรักษ์\n33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079",
             ]
for text in text_input:
  text = preprocess(text)
  text = clean_location_text(text)
  # extract and update matching {name, phone} data
  text, name = extract_name(text)
  text, phone = extract_phone(text)
  ()
  # tokenize text
  tokenize_texts = custom_tokenize.word_tokenize(text)
  # spell checker
  word_lists = [checker.correct(token) if token not in ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
                and token not in address_list.keys() else token for token in tokenize_texts]

  print(tokenize_texts)
  print(word_lists)
# Out:
# ['อนงค์ลักษณ์', '9', '/56', 'ม.', '3', 'หมู่', 'บ้านนฤมลศิริ', 'ซอย', '2', 'ซ.', 'บุญศิริ', 'ถ', '.', 'สุขุมวิท', 'บางเมือง', 'เมืองสมุทรปราการ', 'สมุทรปนาการ', '10270', 'โทร', '.']
# ['อนงค์ลักษณ์', '9', '/56', 'ม.', '3', 'หมู่', 'บ้านนฤมลศิริ', 'ซอย', '2', 'ซ.', 'บุญศิริ', 'ถ', '.', 'สุขุมวิท', 'บางเมือง', 'เมืองสมุทรปราการ', 'สมุทรปราการ', '10270', 'โทร', '.']
# ['วาสนา', 'วนาอนุรักษ์', '33,35', 'ถ', '.', 'อนันตวรฤทธิเดช', 'ในเวียง', 'เมือง', 'น่าน', '5500', 'โทร', '.']
# ['ชายนา', 'วนาอนุรักษ์', '33,35', 'ถ', '.', 'อนันตวรฤทธิเดช', 'ในเวียง', 'เมือง', 'น่าน', '5500', 'โทร', '.']

# %%
from addresses import address_list
text_input = [
    "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
    # "วาสนา วนาอนุรักษ์\n33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079",
    # "คุณมานะ คงวุฒิปัญญา 123/676 087.442-5664 บางอค กทม ติดต่อ 9:00 - 15:00"
             ]
for text in text_input:
  text = preprocess(text)
  text = clean_location_text(text)
  # extract and update matching {name, phone} data
  text, name = extract_name(text)
  text, phone = extract_phone(text)
  ()
  # tokenize text
  tokenize_texts = custom_tokenize.word_tokenize(text)
  # spell checker
  word_lists = [checker.correct(token) if token not in ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
                and token not in address_list.keys() else token for token in tokenize_texts]

  print(tokenize_texts)
  print(word_lists)
# Out:
# ['อนงค์', 'ลักษณ์', '9', '/56', 'ม', '3', 'นฤมล', 'ศิ', 'ริ', '2', 'บุญ', 'ศิ', 'ริ', 'สุขุมวิท', 'บางเมือง', 'เมืองสมุทรปราการ', 'สมุทร', 'ป', 'นา', 'การ', '10270']
# ['ณรงค์', 'ลักษณ์', '9', '/56', 'ม', '3', 'นฤมล', 'ศิ', 'ริ', '2', 'บุญ', 'ศิ', 'ริ', 'สุขุมวิท', 'บางเมือง', 'เมืองสมุทรปราการ', 'สมุทร', 'ป', 'นา', 'การ', '10270']

# %%
checker.spell('ในเวียง')
# Out:
# ['ในเวียง']

# %%
checker.spell('น่าน')
# Out:
# ['นาจาน', 'นาด่าน', 'ท่านา', 'นาอาน']

# %%
checker.spell('นาน')
# Out:
# ['นาดูน',
#  'นาจาน',
#  'นาพิน',
#  'นาบอน',
#  'นาทัน',
#  'นาสวน',
#  'นาอิน',
#  'นานวน',
#  'นานาค',
#  'ตำนาน',
#  'นาพูน',
#  'นาทอน',
#  'นาอาน',
#  'นานวล']

# %% [markdown]
# 2024 6 18 ปรับการเดาคำ

# %% [markdown]
# zipcode fuzzy matching

# %%
address_list.items()
# Out:
# dict_items([('ศรีสะเกษ', {'กันทรลักษ์': [('เมือง', '33110')]}), ('เลย', {'เมืองเลย': [('เมือง', '42000'), ('ศรีสองรัก', '42100')]}), ('ชลบุรี', {'เมืองชลบุรี': [('แสนสุข', '20130'), ('บ้านปึก', '20130')]})])

# %%
address_list['ชลบุรี'].items()
# Out:
# dict_items([('เมืองชลบุรี', [('แสนสุข', '20130'), ('บ้านปึก', '20130')])])

# %%
address_list['ชลบุรี'].items()

# %%
address_list.values()
# Out:
# dict_values([{'กันทรลักษ์': [('เมือง', '33110')]}, {'เมืองเลย': [('เมือง', '42000'), ('ศรีสองรัก', '42100')]}, {'เมืองชลบุรี': [('แสนสุข', '20130'), ('บ้านปึก', '20130')]}])

# %%
# from addresses import address_list
for province, amphoe_dict in address_list.items():
  for amphoe, district_list in amphoe_dict.items():
    print(f"{amphoe} {district_list}", end="")
    # if len(district_list) == 2:
    for district, code in district_list:
      print(f"{district} {code}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ชุมภูพร 38210
# เมืองบุรีรัมย์ [('สวายจีก', '31000'), ('พระครู', '31000'), ('ถลุงเหล็ก', '31000'), ('หนองตาด', '31000'), ('ลุมปุ๊ก', '31000'), ('สองห้อง', '31000'), ('กลันทา', '31000'), ('กระสัง', '31000'), ('เมืองฝาง', '31000'), ('ในเมือง', '31000'), ('อิสาณ', '31000'), ('เสม็ด', '31000'), ('บ้านบัว', '31000'), ('สะแกโพรง', '31000'), ('บ้านยาง', '31000'), ('บัวทอง', '31000'), ('ชุมเห็ด', '31000'), ('หลักเขต', '31000'), ('สะแกซำ', '31000')]สวายจีก 31000
# พระครู 31000
# ถลุงเหล็ก 31000
# หนองตาด 31000
# ลุมปุ๊ก 31000
# สองห้อง 31000
# กลันทา 31000
# กระสัง 31000
# เมืองฝาง 31000
# ในเมือง 31000
# อิสาณ 31000
# เสม็ด 31000
# บ้านบัว 31000
# สะแกโพรง 31000
# บ้านยาง 31000
# บัวทอง 31000
# ชุมเห็ด 31000
# หลักเขต 31000
# สะแกซำ 31000
# คูเมือง [('คูเมือง', '31190'), ('บ้านแพ', '31190'), ('หินเหล็กไฟ', '31190'), ('ตูมใหญ่', '31190'), ('ปะเคียบ', '31190'), ('พรสำราญ', '31190'), ('หนองขมาร', '31190')]คูเมือง 31190
# บ้านแพ 31190
# ...

# %%
from addresses import address_list

# address_list = {
#     'ศรีสะเกษ': {'กันทรลักษ์': [('เมือง', '33110')]},
#     'เลย': {'เมืองเลย': [('เมือง', '42000'), ('ศรีสองรัก', '42100')]},
#     'ชลบุรี': {'เมืองชลบุรี': [('แสนสุข', '20130'), ('บ้านปึก', '20130')]}
# }

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    # Helper functions to search within address_list
    def find_province_by_zipcode(zipcode):
        for province, amphoe_dict in address_list.items():
            for amphoe, district_list in amphoe_dict.items():
              # if len(district_list) == 2:
                for district, code in district_list:
                    if code == zipcode:
                        return province
        return None

    def find_amphoe_by_zipcode(province, zipcode):
        if province:
            for amphoe, district_list in address_list[province].items():
                for district, code in district_list:
                    if code == zipcode:
                        return amphoe
        return None

    def find_district_by_zipcode(province, amphoe, zipcode):
        if province and amphoe:
            for district, code in address_list[province][amphoe]:
                if code == zipcode:
                    return district
        return None

    def find_amphoe_by_district(province, district):
        if province:
            for amphoe, district_list in address_list[province].items():
              # if len(district_list) == 2:
                for dist, code in district_list:
                    if dist == district:
                        return amphoe
        return None

    def find_province_by_amphoe(amphoe):
        for province, amphoe_dict in address_list.items():
            if amphoe in amphoe_dict:
                return province
        return None

    # Step 1: Try to find zipcode
    for text in text_list:
        if text.isdigit() and len(text) == 5:
            best_match['zipcode'] = text
            best_match['province'] = find_province_by_zipcode(text)
            best_match['amphoe'] = find_amphoe_by_zipcode(best_match['province'], text)
            best_match['district'] = find_district_by_zipcode(best_match['province'], best_match['amphoe'], text)
            break

    # Step 2: Try to find province and amphoe if not found from zipcode
    if not best_match['province']:
        for text in text_list:
            if text in address_list:
                best_match['province'] = text
                break

    if not best_match['amphoe']:
        for text in text_list:
            amphoe = find_amphoe_by_district(best_match['province'], text)
            if amphoe:
                best_match['amphoe'] = amphoe
                best_match['district'] = text
                break

    # Step 3: Try to find amphoe from text list directly if still not found
    if not best_match['amphoe'] and best_match['province']:
        for text in text_list:
            if text in address_list[best_match['province']]:
                best_match['amphoe'] = text
                break

    # Step 4: Try to find province from amphoe if still not found
    if not best_match['province'] and best_match['amphoe']:
        best_match['province'] = find_province_by_amphoe(best_match['amphoe'])

    return best_match

# Test cases
test_cases = [
    ['5', '1', 'เมือง', '', 'ศรีสะเกษ', '33110'],
    ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],  # New test case
    ['เมือง', 'เมือง', 'เลย', '42000'],  # No province name in the list
    ['เมือง', 'เมือง', 'เลย'],  # No zipcode in the list
    ["เขาแก้ว", "ท่าใหม่", "จันทบุรี", "22170"],
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# Case 1: {'province': 'ศรีสะเกษ', 'amphoe': 'เบญจลักษ์', 'district': 'เสียว', 'zipcode': '33110'}
# Case 2: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'กุดป่อง', 'zipcode': '42000'}
# Case 3: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 4: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'นาอ้อ', 'zipcode': '42100'}
# Case 5: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 6: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'กุดป่อง', 'zipcode': '42000'}
# Case 7: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': None}
# Case 8: {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'ทุ่งเบญจา', 'zipcode': '22170'}

# %% [markdown]
# ver5 พยายามเดาคำ

# %%
def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    # Helper functions to search within address_list
    def find_province_by_zipcode(zipcode):
        for province, amphoe_dict in address_list.items():
            for amphoe, district_list in amphoe_dict.items():
                for district, code in district_list:
                    if code == zipcode:
                        return province
        return None

    def find_amphoe_by_zipcode(province, zipcode):
        if province:
            for amphoe, district_list in address_list[province].items():
                for district, code in district_list:
                    if code == zipcode:
                        return amphoe
        return None

    def find_district_by_zipcode(province, amphoe, zipcode):
        if province and amphoe:
            for district, code in address_list[province][amphoe]:
                if code == zipcode:
                    return district
        return None

    def find_amphoe_by_district(province, district):
        if province:
            for amphoe, district_list in address_list[province].items():
                for dist, code in district_list:
                    if dist == district:
                        return amphoe
        return None

    def find_province_by_amphoe(amphoe):
        for province, amphoe_dict in address_list.items():
            if amphoe in amphoe_dict:
                return province
        return None

    def find_zipcode_by_amphoe_district(province, amphoe, district):
        if province and amphoe and district:
            for dist, code in address_list[province][amphoe]:
                if dist == district:
                    return code
        return None

    # Step 1: Try to find zipcode
    for text in text_list:
        if text.isdigit() and len(text) == 5:
            best_match['zipcode'] = text
            best_match['province'] = find_province_by_zipcode(text)
            best_match['amphoe'] = find_amphoe_by_zipcode(best_match['province'], text)
            best_match['district'] = find_district_by_zipcode(best_match['province'], best_match['amphoe'], text)
            break

    # Check and correct for 'เมือง'
    if 'เมือง' in text_list and best_match['province']:
        index = text_list.index('เมือง')
        text_list[index] = 'เมือง' + best_match['province']

    # Step 2: Try to find district, amphoe, and province
    if best_match['zipcode'] and best_match['province'] and best_match['amphoe']:
        # If all are found, update the district if 'เมือง' is present
        if 'เมือง' in text_list:
            best_match['district'] = 'เมือง'
    else:
        if not best_match['province']:
            for text in text_list:
                if text in address_list:
                    best_match['province'] = text
                    break

        if not best_match['amphoe']:
            for text in text_list:
                amphoe = find_amphoe_by_district(best_match['province'], text)
                if amphoe:
                    best_match['amphoe'] = amphoe
                    best_match['district'] = text
                    break

        if not best_match['amphoe'] and best_match['province']:
            for text in text_list:
                if text in address_list[best_match['province']]:
                    best_match['amphoe'] = text
                    break

        if not best_match['province'] and best_match['amphoe']:
            best_match['province'] = find_province_by_amphoe(best_match['amphoe'])

    # Step 5: Fill zipcode if it's still None
    if best_match['zipcode'] is None:
        best_match['zipcode'] = find_zipcode_by_amphoe_district(best_match['province'], best_match['amphoe'], best_match['district'])

    return best_match

# Test cases
test_cases = [
    ['5', '1', 'เมือง', '', 'ศรีสะเกษ', '33110'],
    ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],  # New test case
    ['เมือง', 'เมือง', 'เลย', '42000'],  # No province name in the list
    ['เมือง', 'เมือง', 'เลย']  # No zipcode in the list
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# Case 1: {'province': 'ศรีสะเกษ', 'amphoe': 'เบญจลักษ์', 'district': 'เสียว', 'zipcode': '33110'}
# Case 2: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 3: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 4: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'นาอ้อ', 'zipcode': '42100'}
# Case 5: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 6: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 7: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}

# %%
def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    possible_provinces = []
    amphoe_found = False

    # Check province and insert to list
    for text in text_list:
        if text in address_list:
            possible_provinces.append(text)

    # Check and correct for 'เมือง'
    for province in possible_provinces:
        for i, text in enumerate(text_list):
            if text == 'เมือง' and province != 'ศรีสะเกษ':
                text_list[i] = 'เมือง' + province
                break  # case user input อำเภอเมือง จะเติมชื่อจังหวัดให้

    # Check amphoe in province
    for province in possible_provinces:
        for text in text_list:
            if text in address_list[province]:
                best_match['amphoe'] = text
                amphoe_found = True
                break

        if amphoe_found:
            # Check subdistrict and zipcode in amphoe found
            for text in text_list:
                if best_match['amphoe'] in address_list[province]:
                    for item in address_list[province][best_match['amphoe']]:
                        if len(item) == 2:
                            subdistrict, postcode = item
                            if text == subdistrict:
                                best_match['district'] = subdistrict
                            if text == postcode:
                                best_match['zipcode'] = postcode

            best_match['province'] = province
            break

    # Try to find a match with incomplete data
    if not amphoe_found and not possible_provinces:
        for province in address_list:
            for amphoe in address_list[province]:
                for item in address_list[province][amphoe]:
                    if len(item) == 2:
                        subdistrict, postcode = item
                        if subdistrict in text_list or postcode in text_list or province in text_list or amphoe in text_list:
                            best_match['province'] = province
                            best_match['amphoe'] = amphoe
                            if subdistrict in text_list:
                                best_match['district'] = subdistrict
                            if postcode in text_list:
                                best_match['zipcode'] = postcode
                            return best_match

    return best_match

# Test cases
test_cases = [
    ['5', '1', 'เมือง', '', 'ศรีสะเกษ', '33110'],
    ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],  # New test case
    ['เมือง', 'เมือง', 'เลย', '42000'],  # Incomplete data
    ['เมือง', 'เมือง', 'เลย'],  # Incomplete data
    ['ศรีสองรัก']  # Incomplete data
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# Case 1: {'province': None, 'amphoe': None, 'district': None, 'zipcode': None}
# Case 2: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 3: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 4: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'ศรีสองรัก', 'zipcode': '42100'}
# Case 5: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บ้านปึก', 'zipcode': '20130'}
# Case 6: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 7: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': None}
# Case 8: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'ศรีสองรัก', 'zipcode': None}

# %% [markdown]
# เคสมีแค่ตำบล แต่ใช้กับ กรณีคำหายไม่ได้ ['ศรีสองรัก', 'เลย'] เคสนี้ Case 1: {'province': None, 'amphoe': None, 'district': None, 'zipcode': None}

# %%
from addresses import address_list

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    possible_provinces = []
    amphoe_found = False

    # Check province and insert to list
    for text in text_list:
        if text in address_list:
            possible_provinces.append(text)

    # Check and correct for 'เมือง'
    for province in possible_provinces:
        for i, text in enumerate(text_list):
            if text == 'เมือง' and province != 'ศรีสะเกษ':
                text_list[i] = 'เมือง' + province
                break  # case user input อำเภอเมือง จะเติมชื่อจังหวัดให้

    # Check amphoe in province
    for province in possible_provinces:
        for text in text_list:
            if text in address_list[province]:
                best_match['amphoe'] = text
                amphoe_found = True
                break

        if amphoe_found:
            # Check subdistrict and zipcode in amphoe found
            for text in text_list:
                if best_match['amphoe'] in address_list[province]:
                    for subdistrict_postcode in address_list[province][best_match['amphoe']]:
                        if len(subdistrict_postcode) == 2:
                            subdistrict, postcode = subdistrict_postcode
                            if text == subdistrict:
                                best_match['district'] = subdistrict
                            if text == postcode:
                                best_match['zipcode'] = postcode

            best_match['province'] = province
            break

    # Try to find a match with incomplete data
    if not amphoe_found and not possible_provinces:
        for province in address_list:
            for amphoe in address_list[province]:
                for subdistrict_postcode in address_list[province][amphoe]:
                    if len(subdistrict_postcode) == 2:
                        subdistrict, postcode = subdistrict_postcode
                        if subdistrict in text_list or postcode in text_list or province in text_list or amphoe in text_list:
                            best_match['province'] = province
                            best_match['amphoe'] = amphoe
                            if subdistrict in text_list:
                                best_match['district'] = subdistrict
                            if postcode in text_list:
                                best_match['zipcode'] = postcode
                            return best_match

    # If amphoe was found but zipcode is missing, find the correct zipcode
    if best_match['amphoe'] and not best_match['zipcode']:
        for subdistrict_postcode in address_list[best_match['province']][best_match['amphoe']]:
            if len(subdistrict_postcode) == 2:
                subdistrict, postcode = subdistrict_postcode
                if best_match['district'] == subdistrict or not best_match['district']:
                    best_match['zipcode'] = postcode
                    break

    return best_match

# Test cases
test_cases = [
    ['5', '1', 'เมือง', '', 'ศรีสะเกษ', '33110'],
    ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],
    ['เมือง', 'เมือง', 'เลย', '42000'],
    ['เมือง', 'เมือง', 'เลย'],
    ['ศรีสองรัก']
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# Case 1: {'province': None, 'amphoe': None, 'district': None, 'zipcode': None}
# Case 2: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 3: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130'}
# Case 4: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'ศรีสองรัก', 'zipcode': '42100'}
# Case 5: {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บ้านปึก', 'zipcode': '20130'}
# Case 6: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 7: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'เมือง', 'zipcode': '42000'}
# Case 8: {'province': 'เลย', 'amphoe': 'เมืองเลย', 'district': 'ศรีสองรัก', 'zipcode': None}

# %%
from addresses import address_list

def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    possible_provinces = []
    amphoe_found = False

    # Check province and insert to list
    for text in text_list:
        if text in address_list:
            possible_provinces.append(text)

    # Check and correct for 'เมือง'
    for province in possible_provinces:
        for i, text in enumerate(text_list):
            if text == 'เมือง' and province != 'ศรีสะเกษ':
                text_list[i] = 'เมือง' + province
                break  # case user input อำเภอเมือง จะเติมชื่อจังหวัดให้

    # Check amphoe in province
    for province in possible_provinces:
        for text in text_list:
            if text in address_list[province]:
                best_match['amphoe'] = text
                amphoe_found = True
                break

        if amphoe_found:
            # Check subdistrict and zipcode in amphoe found
            for text in text_list:
                if best_match['amphoe'] in address_list[province]:
                    for subdistrict_postcode in address_list[province][best_match['amphoe']]:
                        if len(subdistrict_postcode) == 2:
                            subdistrict, postcode = subdistrict_postcode
                            if text == subdistrict:
                                best_match['district'] = subdistrict
                            if text == postcode:
                                best_match['zipcode'] = postcode

            best_match['province'] = province
            break

    # If no amphoe found, try to find province and subdistrict only
    if not amphoe_found and possible_provinces:
        for province in possible_provinces:
            for text in text_list:
                for amphoe in address_list[province]:
                    for subdistrict_postcode in address_list[province][amphoe]:
                        if len(subdistrict_postcode) == 2:
                            subdistrict, postcode = subdistrict_postcode
                            if text == subdistrict:
                                best_match['district'] = subdistrict
                                best_match['province'] = province
                                best_match['amphoe'] = amphoe
                                if not best_match['zipcode']:
                                    best_match['zipcode'] = postcode
                                break
                if best_match['district']:
                    break
            if best_match['district']:
                break

    # If no province found, try to find amphoe and subdistrict only
    if not best_match['province']:
        for province in address_list:
            for amphoe in address_list[province]:
                for subdistrict_postcode in address_list[province][amphoe]:
                    if len(subdistrict_postcode) == 2:
                        subdistrict, postcode = subdistrict_postcode
                        if subdistrict in text_list or postcode in text_list:
                            best_match['province'] = province
                            best_match['amphoe'] = amphoe
                            best_match['district'] = subdistrict
                            best_match['zipcode'] = postcode
                            return best_match

    # If province and amphoe were found but zipcode is missing, find the correct zipcode
    if best_match['amphoe'] and not best_match['zipcode']:
        for subdistrict_postcode in address_list[best_match['province']][best_match['amphoe']]:
            if len(subdistrict_postcode) == 2:
                subdistrict, postcode = subdistrict_postcode
                if best_match['district'] == subdistrict or not best_match['district']:
                    best_match['zipcode'] = postcode
                    break

    return best_match

# Test cases
test_cases = [
    ['5', '1', 'เมือง', '', 'ศรีสะเกษ', '33110'],
    ['2/13', '442', 'เมือง', 'เมือง', 'เลย', '42000'],
    ['123/4', '8', 'แสนสุข', 'เมือง', 'ชลบุรี', '20130'],
    ['ศรีสองรัก', 'เมือง', 'เลย', '42100'],
    ['บ้านปึก', 'เมือง', 'ชลบุรี', '20130'],
    ['เมือง', 'เมือง', 'เลย', '42000'],
    ['เมือง', 'เมือง', 'เลย'],
    ['ศรีสองรัก', 'เลย'],
    ['บางรัก', 'กรุงเทพมหานคร'],
    ['เมือง', 'กรุงเทพมหานคร'],
    ['หาดใหญ่', 'สงขลา'],
    ['สงขลา', 'หาดใหญ่'],
    ['90110'],
]

for i, test_case in enumerate(test_cases, 1):
    result = find_best_match(address_list, test_case)
    print(f"Case {i}: {result}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-ce1499e1c1ed> in <cell line: 111>()
#     110
#     111 for i, test_case in enumerate(test_cases, 1):
# --> 112     result = find_best_match(address_list, test_case)
#     113     print(f"Case {i}: {result}")
#
# <ipython-input-73-ce1499e1c1ed> in find_best_match(address_list, text_list)
#      53                 for amphoe in address_list[province]:
#      54                     for subdistrict_postcode in address_list[province][amphoe]:
# ---> 55                         if len(subdistrict_postcode) == 2:
#      56                             subdistrict, postcode = subdistrict_postcode
#      57                             if text == subdistrict:
#
# KeyboardInterrupt:

# %%
checker.spell('บางอค')
# Out:
# ['บางแค']

# %% [markdown]
# # Accuracy check

# %%
test_data = [("182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741",
{'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'} ),
("สมพัฒน์ แก้วพิจิตร 66/8 ม.10 ต.เขาแก้ว อ.ท่าใหม่ จ.จันทบุรี 22170",
{'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': 'สมพัฒน์ แก้วพิจิตร', 'phone': ''}) ,
("ที่อยู่ 111/1 หมู่ 7 ตำบล แสนสุข อำเภอ เมืองชลบุรี จังหวัด ชลบุรี 20130",
{'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''} ),
("ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี ตำบล แสนสุข",
{'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''} ),
("ตำบล แสนสุข ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี",
{'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}) ,
("680 ถ.สุขมุวิท ต.บางปลาสร้อย อ.เมืองชลบุรี จ.ชลบุรี 20000",
{'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บางปลาสร้อย', 'zipcode': '20000', 'name': '', 'phone': ''} ),
("259 หมู่11 ถ.สืบศิริ ต.เมืองปัก อ.ปักธงชัย จ.นครราชสีมา 30150",
{'province': 'นครราชสีมา', 'amphoe': 'ปักธงชัย', 'district': 'เมืองปัก', 'zipcode': '30150', 'name': '', 'phone': ''} ),
("87 ถ.สุขุมวิท ต.ปากน้ำ อ.เมืองสมุทรปราการ จ.สมุทรปราการ 10270",
{'province': 'สมุทรปราการ', 'amphoe': 'เมืองสมุทรปราการ', 'district': 'ปากน้ำ', 'zipcode': '10270', 'name': '', 'phone': ''} ),
("11/1 หมู่ 4 ตำบล นามะตูม อำเภอ พนัสนิคม จังหวัด ชลบุรี 20140",
{'province': 'ชลบุรี', 'amphoe': 'พนัสนิคม', 'district': 'นามะตูม', 'zipcode': '20140', 'name': '', 'phone': ''} ),
("12/(13 ถนนเทศบาลพัฒนา ตำบลพนัสนิคม อำเภอพนัสนิคม จังหวัดชลบุรี 20140",
{'province': 'ชลบุรี', 'amphoe': 'พนัสนิคม', 'district': 'พนัสนิคม', 'zipcode': '20140', 'name': '', 'phone': ''} ),
("21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100",
{'province': 'กรุงเทพ', 'amphoe': 'ป้อมปราบศัตรูพ่าย', 'district': 'คลองมหานาค', 'zipcode': '10100', 'name': '', 'phone': ''} ),
("55) 30-12-62 นายเชิดชัย สมหมาย 107/1 หมู่ 6 ซ.หมู่บ้านโรงกุลี ซอย 10 ถนนมิตรภาพ ต.กลางดง อำเภอ / ตำบล : ปากช่อง จังหวัด : นครราชสีมา 30320 Tel 091-2719547",
{'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัย สมหมาย', 'phone': '0912719547'} ),
("55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547",
{'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัยสมหมาย', 'phone': '0912719547'} ),
("55)30-12-62107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547เชิดชัยสมหมายนามะตูม อำเภอ พนัสนิคม",
{'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': '', 'phone': '0912719547'} ),]

# %%
print(result_list)
# Out:
# [{'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}, {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บางปลาสร้อย', 'zipcode': '20000', 'name': '', 'phone': ''}, {'province': 'นครราชสีมา', 'amphoe': 'ปักธงชัย', 'district': 'เมืองปัก', 'zipcode': '30150', 'name': '', 'phone': ''}, {'province': 'สมุทรปราการ', 'amphoe': 'เมืองสมุทรปราการ', 'district': 'ปากน้ำ', 'zipcode': '10270', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'พนัสนิคม
# ...

# %%
custom_tokenize, checker = initial_nlp_tools(hashmap)

result_list = []
for text, expected in test_data:
    # print(text)
    matching_result = extract_address(text=text, custom_tokenize=custom_tokenize, checker=checker, address_list=address_list)
    # print(matching_result, "\n")
    result_list.append(matching_result)

total_accuracy = check_accuracy(test_data, result_list)
print(f'ความแม่นยำรวม: {total_accuracy:.2f}%')
# Out:
# Loop 1:
# คำตอบบอก {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}
# ผลลัพธ์บอก {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}
# ถูกทั้งหมด
# ความแม่นยำของลูปนี้: 100.00%
#
# Loop 2:
# คำตอบบอก {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': 'สมพัฒน์ แก้วพิจิตร', 'phone': ''}
# ผลลัพธ์บอก {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': '', 'phone': ''}
# ผิดที่ name คิดเป็น 5/6
# ความแม่นยำของลูปนี้: 83.33%
#
# Loop 3:
# คำตอบบอก {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}
# ผลลัพธ์บอก {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}
# ถูกทั้งหมด
# ความแม่นยำของลูปนี้: 100.00%
#
# Loop 4:
# ...

# %% [markdown]
# ทดสอบ การ detection address

# %%
def check_accuracy(text_list, result):
    total = len(text_list)
    correct_count = 0

    for i, (text, expected) in enumerate(text_list):
        detected = result[i]

        # Check if all fields match
        if (
            expected['province'] == detected['province'] and
            expected['amphoe'] == detected['amphoe'] and
            expected['district'] == detected['district'] and
            expected['zipcode'] == detected['zipcode'] and
            expected['name'] == detected['name'] and
            expected['phone'] == detected['phone']
        ):
            correct_count += 1

    accuracy = (correct_count / total) * 100
    return accuracy

# Example usage
text_list = [('182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741',
              {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'})]

result = [{'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}]

accuracy = check_accuracy(test_data, result_list)
print(f'Accuracy: {accuracy:.2f}%')
# Out:
# Accuracy: 92.86%

# %%
def check_accuracy(text_list, result):
    total = len(text_list)
    field_names = ['province', 'amphoe', 'district', 'zipcode', 'name', 'phone']
    field_count = len(field_names)

    for i, (text, expected) in enumerate(text_list):
        detected = result[i]
        correct_fields = 0
        incorrect_fields = []

        for field in field_names:
            if expected[field] == detected[field]:
                correct_fields += 1
            else:
                incorrect_fields.append(field)

        accuracy_per_loop = (correct_fields / field_count) * 100

        print(f'Loop {i+1}:')
        print(f'คำตอบบอก {expected}')
        print(f'ผลลัพธ์บอก {detected}')
        if incorrect_fields:
            print(f'ผิดที่ {", ".join(incorrect_fields)} คิดเป็น {correct_fields}/{field_count}')
        else:
            print('ถูกทั้งหมด')
        print(f'ความแม่นยำของลูปนี้: {accuracy_per_loop:.2f}%\n')

    total_correct_fields = sum([
        sum(1 for field in field_names if expected[field] == result[i][field])
        for i, (text, expected) in enumerate(text_list)
    ])
    total_accuracy = (total_correct_fields / (total * field_count)) * 100
    return total_accuracy

# Example usage
text_list = [('182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741',
              {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'})]

result = [{'province': 'กรุงเทพ', 'amphoe': '', 'district': 'บางหว้า', 'zipcode': '', 'name': '', 'phone': '0877170741'}]

total_accuracy = check_accuracy(test_data, result_list)
print(f'ความแม่นยำรวม: {total_accuracy:.2f}%')
# Out:
# Loop 1:
# คำตอบบอก {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}
# ผลลัพธ์บอก {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}
# ถูกทั้งหมด
# ความแม่นยำของลูปนี้: 100.00%
#
# Loop 2:
# คำตอบบอก {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': 'สมพัฒน์ แก้วพิจิตร', 'phone': ''}
# ผลลัพธ์บอก {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': '', 'phone': ''}
# ผิดที่ name คิดเป็น 5/6
# ความแม่นยำของลูปนี้: 83.33%
#
# Loop 3:
# คำตอบบอก {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}
# ผลลัพธ์บอก {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}
# ถูกทั้งหมด
# ความแม่นยำของลูปนี้: 100.00%
#
# Loop 4:
# ...

# %% [markdown]
# # idea

# %%
from addresses import address_list
province_list = address_list.keys()
amphoe_list = [amphoe for province in province_list for amphoe in address_list[province].keys()]
amphoe_list
# Out:
# ['เมืองกระบี่',
#  'เขาพนม',
#  'เกาะลันตา',
#  'คลองท่อม',
#  'อ่าวลึก',
#  'ปลายพระยา',
#  'ลำทับ',
#  'เหนือคลอง',
#  'คลองเตย',
#  'คลองสาน',
#  'คลองสามวา',
#  'คันนายาว',
#  'จตุจักร',
#  'จอมทอง',
#  'ดอนเมือง',
#  'ดินแดง',
#  'ดุสิต',
#  'ตลิ่งชัน',
#  'ทวีวัฒนา',
#  'ธนบุรี',
#  'บางกอกน้อย',
#  'บางกะปิ',
#  'บางขุนเทียน',
#  'บางเขน',
#  'บางคอแหลม',
#  'บางแค',
#  'บางซื่อ',
#  'บางนา',
#  'บางบอน',
#  'บางพลัด',
#  'บางรัก',
#  'บึงกุ่ม',
#  'ปทุมวัน',
#  'ประเวศ',
#  'ป้อมปราบศัตรูพ่าย',
#  'พญาไท',
#  'พระนคร',
#  'ภาษีเจริญ',
#  'มีนบุรี',
#  'ราชเทวี',
#  'ราษฎร์บูรณะ',
#  'ลาดกระบัง',
#  'ลาดพร้าว',
#  'วังทองหลาง',
#  'วัฒนา',
#  'สวนหลวง',
#  'สะพานสูง',
#  'สัมพันธวงศ์',
#  'สาทร',
#  'สายไหม',
#  'หนองแขม',
#  'หนองจอก',
#  'หลักสี่',
#  'ห้วยขวาง',
#  'ทุ่งครุ',
#  'บางกอกใหญ่',
#  'พระโขนง',
#  'ยานนาวา',
#  'ด่านมะขามเตี้ย',
#  'ทองผาภูมิ',
#  'ท่าม่วง',
#  'ท่ามะกา',
#  'ไทรโยค',
#  'บ่อพลอย',
#  'พนมทวน',
#  'เมืองกาญจนบุรี',
#  'เลาขวัญ',
# ...

# %%
print(f"Total addresses in พนัสนิคม: {len(address_list['ชลบุรี']['พนัสนิคม'])}")
# Out:
# Total addresses in พนัสนิคม: 21

# %%
address_list['ชลบุรี']['พนัสนิคม'][0]
# Out:
# ('พนัสนิคม', '20140')

# %%
district_list = [district[0] for province in province_list for amphoe in address_list[province].keys() for
district in address_list[province][amphoe]]
district_list
# Out:
# ['กระบี่น้อย',
#  'เขาทอง',
#  'ทับปริก',
#  'อ่าวนาง',
#  'หนองทะเล',
#  'หนองทะเล',
#  'ปากน้ำ',
#  'กระบี่ใหญ่',
#  'เขาคราม',
#  'ไสไทย',
#  'อ่าวนาง',
#  'อ่าวนาง',
#  'คลองประสงค์',
#  'เขาพนม',
#  'พรุเตียว',
#  'หน้าเขา',
#  'โคกหาร',
#  'เขาดิน',
#  'สินปุน',
#  'พรุเตียว',
#  'หน้าเขา',
#  'เกาะกลาง',
#  'ศาลาด่าน',
#  'เกาะลันตาใหญ่',
#  'เกาะลันตาน้อย',
#  'คลองยาง',
#  'คลองท่อมเหนือ',
#  'คลองพน',
#  'ห้วยน้ำขาว',
#  'เพหลา',
#  'คลองท่อมใต้',
#  'ทรายขาว',
#  'พรุดินนา',
#  'แหลมสัก',
#  'นาเหนือ',
#  'อ่าวลึกใต้',
#  'คลองหิน',
#  'อ่าวลึกน้อย',
#  'อ่าวลึกเหนือ',
#  'เขาใหญ่',
#  'คลองยา',
#  'บ้านกลาง',
#  'ปลายพระยา',
#  'เขาเขน',
#  'เขาต่อ',
#  'คีรีวง',
#  'ลำทับ',
#  'ดินอุดม',
#  'ดินแดง',
#  'ทุ่งไทรทอง',
#  'เหนือคลอง',
#  'คลองเขม้า',
#  'โคกยาง',
#  'ห้วยยูง',
#  'เกาะศรีบอยา',
#  'คลองขนาน',
#  'ตลิ่งชัน',
#  'ปกาสัย',
#  'คลองเตย',
#  'พระโขนง',
#  'คลองตัน',
#  'พระโขนง',
#  'คลองสาน',
#  'บางลำภูล่าง',
#  'สมเด็จเจ้าพระยา',
#  'คลองต้นไทร',
# ...

# %%
for i, y in address_list['กระบี่'].items():
  print(i)
  print(y)
# Out:
# เมืองกระบี่
# [('กระบี่น้อย', '81000'), ('เขาทอง', '81000'), ('ทับปริก', '81000'), ('อ่าวนาง', '81000'), ('หนองทะเล', '81000'), ('หนองทะเล', '81180'), ('ปากน้ำ', '81000'), ('กระบี่ใหญ่', '81000'), ('เขาคราม', '81000'), ('ไสไทย', '81000'), ('อ่าวนาง', '81180'), ('อ่าวนาง', '81210'), ('คลองประสงค์', '81000')]
# เขาพนม
# [('เขาพนม', '81140'), ('พรุเตียว', '81140'), ('หน้าเขา', '81140'), ('โคกหาร', '80240'), ('เขาดิน', '81140'), ('สินปุน', '80240'), ('พรุเตียว', '80240'), ('หน้าเขา', '80240')]
# เกาะลันตา
# [('เกาะกลาง', '81120'), ('ศาลาด่าน', '81150'), ('เกาะลันตาใหญ่', '81150'), ('เกาะลันตาน้อย', '81150'), ('คลองยาง', '81120')]
# คลองท่อม
# [('คลองท่อมเหนือ', '81120'), ('คลองพน', '81170'), ('ห้วยน้ำขาว', '81120'), ('เพหลา', '81120'), ('คลองท่อมใต้', '81120'), ('ทรายขาว', '81170'), ('พรุดินนา', '81120')]
# อ่าวลึก
# ...

# %%
bow = set()
for province in address_list.keys():
  bow.add(province)
  for amphoe, district in address_list[province].items():
    bow.add(amphoe)
    for tambol, zipcode in district:
     bow.update([tambol, zipcode])

# %%
print(bow)
# Out:
# {'ตาวัง', 'ตลุกเทียม', 'บางกะจะ', 'ท่าอุเทน', 'ชุมแพ', 'ไผ่', '48120', 'เจดีย์คำ', 'ตาเนาะแมเราะ', '50240', 'ดอนคา', 'หนองกระทุ่ม', 'นาห่อม', '76110', 'พยัคฆภูมิพิสัย', 'พระทองคำ', 'ไชยมนตรี', 'นาแค', '80190', 'หนองนกไข่', 'เมืองเหนือ', 'หนองเสือช้าง', 'หนองกุงทับม้า', 'ดอนแสลบ', 'บัวค้อ', 'คลองขนาน', 'ธงชัยเหนือ', 'หนองกร่าง', 'แม่คือ', 'แก้งสนามนาง', 'คชสิทธิ์', 'ท่าม่วง', 'นาสี', 'รามัน', 'โบสถ์', 'นาซำ', 'ห้วยน้ำหอม', 'เสือโก้ก', 'สลุย', 'บ้านชัย', 'หนองกวาง', 'หินลาด', 'คำพอุง', 'บ่อผุด', 'ชีบน', 'โพธิ์สามต้น', '94220', 'พระธาตุ', 'ศรีเชียงใหม่', 'นาขุนไกร', 'รามราช', 'วังเหนือ', 'สัตหีบ', 'นาวุ้ง', 'ศรีสุทโธ', 'ตะเคียนทอง', 'หัวโพธิ์', 'นาไม้ไผ่', 'ผาสามยอด', 'ป่าเมี่ยง', 'เกาะมะนาว', 'แสลงโทน', 'บ้านถ่อน', 'ปากบาง', 'เทพารักษ์', 'บางขุนพรหม', 'ทุ่งคอก', 'ลาดสวาย', 'นาใน', 'บางกอกใหญ่', 'หันสัง', 'สาวชะโงก', 'พระธาตุขิงแกง', 'คุระ', 'แสนภูดาษ', 'บางมูลนาก', 'บึงกระจับ', 'ยางโทน', '36130', 'ภูแลนคา', '41190', 'ควน', 'โตนดด้วน', 'ระแหง', 'หนองกลางนา', 'เชิงชุม', 'เฉลิม', 'พิจิตร'
# ...

# %%
address_test = {"ชลบุรี": {
        "เมืองชลบุรี": [
            ("บ้านโขด", "20000"),
            ("แสนสุข", "20130"),
            ("แสนสุข", "20131"),
            ("นาป่า", "20000"),
            ("ดอนหัวฬ่อ", "20000"),
            ("เหมือง", "20130"),
            ("ห้วยกะปิ", "20130"),
            ("เสม็ด", "20130"),
            ("เสม็ด", "20000"),
            ("สำนักบก", "20000"),
        ],
        "พนัสนิคม": [
            ("พนัสนิคม", "20140"),
            ("บ้านเซิด", "20140"),
            ("นาเริก", "20140"),
            ("หมอนนาง", "20140"),
            ("วัดโบสถ์", "20140"),
            ("หนองปรือ", "20140"),
            ("บ้านช้าง", "20140"),
            ("โคกเพลาะ", "20140"),
            ("ไร่หลักทอง", "20140"),
            ("นามะตูม", "20140"),
        ],
        "ศรีราชา": [
            ("ทุ่งสุขลา", "20230"),
            ("หนองขาม", "20110"),
            ("หนองขาม", "20230"),
            ("บางพระ", "20110"),
            ("บ่อวิน", "20230"),
        ],}}
print(address_test)
print(address_test['ชลบุรี']['พนัสนิคม'])
# Out:
# {'ชลบุรี': {'เมืองชลบุรี': [('บ้านโขด', '20000'), ('แสนสุข', '20130'), ('แสนสุข', '20131'), ('นาป่า', '20000'), ('ดอนหัวฬ่อ', '20000'), ('เหมือง', '20130'), ('ห้วยกะปิ', '20130'), ('เสม็ด', '20130'), ('เสม็ด', '20000'), ('สำนักบก', '20000')], 'พนัสนิคม': [('พนัสนิคม', '20140'), ('บ้านเซิด', '20140'), ('นาเริก', '20140'), ('หมอนนาง', '20140'), ('วัดโบสถ์', '20140'), ('หนองปรือ', '20140'), ('บ้านช้าง', '20140'), ('โคกเพลาะ', '20140'), ('ไร่หลักทอง', '20140'), ('นามะตูม', '20140')], 'ศรีราชา': [('ทุ่งสุขลา', '20230'), ('หนองขาม', '20110'), ('หนองขาม', '20230'), ('บางพระ', '20110'), ('บ่อวิน', '20230')]}}
# [('พนัสนิคม', '20140'), ('บ้านเซิด', '20140'), ('นาเริก', '20140'), ('หมอนนาง', '20140'), ('วัดโบสถ์', '20140'), ('หนองปรือ', '20140'), ('บ้านช้าง', '20140'), ('โคกเพลาะ', '20140'), ('ไร่หลักทอง', '20140'), ('นามะตูม', '20140')]

# %% [markdown]
# v2 address

# %%
def find_best_match(address_list, text_list):
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    # ตรวจสอบจังหวัด
    for text in text_list:
        if text in address_list:
            best_match['province'] = text
            break

    if not best_match['province']:
        return best_match

    # ตรวจสอบอำเภอในจังหวัดที่พบ
    for text in text_list:
        if text in address_list[best_match['province']]:
            best_match['amphoe'] = text
            break

    if not best_match['amphoe']:
        return best_match

    # ตรวจสอบตำบลและรหัสไปรษณีย์ในอำเภอที่พบ
    for text in text_list:
        for subdistrict, postcode in address_list[best_match['province']][best_match['amphoe']]:
            if text == subdistrict and best_match['district'] is None:
                best_match['district'] = subdistrict
            if text == postcode and best_match['zipcode'] is None:
                best_match['zipcode'] = postcode

    return best_match

# %% [markdown]
# new v3 check address

# %%
from addresses import address_list

text_list = ['สม', 'วัฒนา', 'วอแก้ว', 'พิจิตร', '66', '/8', '10', 'เขาแก้ว', 'ท่าใหม่', 'จันทบุรี', '22170']

def find_best_match(address_list, text_list):
    possible_provinces = []
    best_match = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None
    }

    # เก็บรายชื่อจังหวัดที่พบใน text_list
    for text in text_list:
        if text in address_list:
            possible_provinces.append(text)

    # ตรวจสอบจังหวัดที่พบ
    for province in possible_provinces:
        amphoe_found = False
        for text in text_list:
            if text in address_list[province]:
                best_match['amphoe'] = text
                amphoe_found = True
                break

        if not amphoe_found:
            continue

        # ตรวจสอบตำบลและรหัสไปรษณีย์ในอำเภอที่พบ
        for text in text_list:
            for subdistrict, postcode in address_list[province][best_match['amphoe']]:
                if text == subdistrict and best_match['district'] is None:
                    best_match['district'] = subdistrict
                if text == postcode and best_match['zipcode'] is None:
                    best_match['zipcode'] = postcode

        # ตรวจสอบว่าข้อมูลที่พบเป็นของจังหวัดไหน
        if best_match['district'] and best_match['zipcode']:
            best_match['province'] = province
            break

    return best_match

result = find_best_match(address_list, text_list)
print(result)
# Out:
# {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170'}

# %% [markdown]
# # detection2

# %%
# !wget https://raw.githubusercontent.com/ffe111/thaiAddressTag/main/addresses.py
# Out:
# --2024-06-24 03:33:56--  https://raw.githubusercontent.com/ffe111/thaiAddressTag/main/addresses.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 316497 (309K) [text/plain]
# Saving to: ‘addresses.py’
#
# addresses.py        100%[===================>] 309.08K  --.-KB/s    in 0.05s
#
# 2024-06-24 03:33:56 (6.19 MB/s) - ‘addresses.py’ saved [316497/316497]

# %%
# !pip install pythainlp==5.0.3 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 13.4 MB/s eta 0:00:00

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from addresses import address_list
from pythainlp.util import dict_trie
from pythainlp.corpus.common import thai_words
from pythainlp import Tokenizer
from pythainlp.spell import NorvigSpellChecker

import re

def preprocess(text: str) -> str:
    """
    Generalized function to preprocess an input
    """
    text = text.strip()
    text = text.replace("ส่ง ", "")
    text = text.replace("จัดส่ง", "")
    text = text.replace("ชือ.", "")
    text = text.replace("ชื่อ ", "")
    text = text.replace("ผู้รับ", "")
    text = text.replace("ส่งที่ ", " ")
    text = text.replace("ที่อยู่ ", " ")
    text = text.replace("ที้อยุ่ ", " ")
    text = text.replace("ที่อยู่จ้า ", " ")
    text = text.replace("ส่งของที่ ", " ")
    text = text.replace("ส่งมาที่", " ")
    text = text.replace("โทรศัพท์", " ")
    text = text.replace("โทร.", " ")
    text = text.replace("โทร", " ")
    text = text.replace("\n-", " ")
    text = text.replace("\n", " ")
    text = text.replace(": ", " ")
    text = text.replace(":", "")
    text = text.replace("-", "")
    text = text.replace("(", "")
    text = text.replace(")", "")
    text = text.replace('"', "")
    # text = remove_emoji(text)
    text = " ".join([t for t in text.strip().split(" ") if t.strip() != ""])
    return text


def clean_location_text(text: str) -> str:
    """
    Clean location before using fuzzy string match
    """
    text = text.replace("หมู่บ้าน", " ")
    text = text.replace("ซอย", " ")
    text = text.replace("แขวง", " ")
    text = text.replace("เขต", " ")
    text = text.replace("อำเภอ", " ")
    text = text.replace("ตำบล", " ")
    text = text.replace("ถ.", " ")
    text = text.replace("ซ.", " ")
    text = text.replace("ตฺ", "ต.")
    text = text.replace("ต.", " ")
    text = text.replace("อ.", " ")
    text = text.replace("จ.", " ")
    text = text.replace("คอหงส์", "คอหงษ์")
    text = text.replace("กทม.", "กรุงเทพ")
    text = text.replace("กทม", "กรุงเทพ")
    text = text.replace("กรุงเทพมหานคร", "กรุงเทพ")
    text = text.replace(".", "")
    return text

def extract_name(text: str) -> str:
    """
    Extracts name from the text.
    update
     - คำว่า คุณ
     - คำนำหน้า เว้น ชื่อ
    """
    name = re.search(r'(เด็กชาย|เด็กหญิง|ด\.ช\.|ด\.ญ\.|นาย|นาง|นางสาว|น\.ส\.|ดร\.|คุณ)\s*([ก-๙]+)\s*([ก-๙]+)', text)
    if name:
        full_name = name.group(0)
        text = text.replace(full_name, " ")
        return text, full_name
    return text, ''


def extract_phone(text: str):
    """
    Extracts phone from the text.
    update
     - เบอร์ +66
     - เบอร์ 08 เว้น \dเลขเบอร์
     - เบอร์มี - .
    """
    phone_match = re.search(r'(\+66\s?|0)([2-9]\d[\s-]?\d{3}[\s-]?\d{4})', text)
    if phone_match:
        phone = phone_match.group(0)
        # Standardize phone number
        phone_standardized = phone.replace(' ', '').replace('-', '').replace('.', '')
        if phone_standardized.startswith('+66'):
            phone_standardized = '0' + phone_standardized[3:]
        text = text.replace(phone_match.group(0), " ")
        return text.strip(), phone_standardized
    return text.strip(), ''


def find_address_match(address_list, text_list):
  """
    find address match
    update
     - แก้อำเภอเมือง
     - ตรวจสอบหาจังหวัดน่านได้

  """
  best_match = {
      'province': None,
      'amphoe': None,
      'district': None,
      'zipcode': None
  }

  possible_provinces = []

  # Check province and insert to list
  for text in text_list:
      if text in address_list:
          possible_provinces.append(text)

  # Check and correct for 'เมือง'
  for province in possible_provinces:
      for i, text in enumerate(text_list):
          if text == 'เมือง' and province != 'ศรีสะเกษ':
              text_list[i] = 'เมือง' + province
              break

  # Initialize potential matches
  district_matches = []
  amphoe_matches = []
  zipcode_matches = []

  # Collect all matches first
  for province in possible_provinces:
      for text in text_list:
          for amphoe in address_list[province]:
              for subdistrict, postcode in address_list[province][amphoe]:
                  if text == subdistrict:
                      district_matches.append((province, amphoe, subdistrict))
                  if text == postcode:
                      zipcode_matches.append((province, amphoe, postcode))
              if text == amphoe:
                  amphoe_matches.append((province, amphoe))

  # Determine best matches based on collected data
  # Prioritize the full match with district and zipcode
  for province, amphoe, subdistrict in district_matches:
      for p, a, z in zipcode_matches:
          if province == p and amphoe == a:
              best_match['province'] = province
              best_match['amphoe'] = amphoe
              best_match['district'] = subdistrict
              best_match['zipcode'] = z
              return best_match

  # If full match not found, prioritize district and amphoe
  for province, amphoe, subdistrict in district_matches:
      best_match['province'] = province
      best_match['amphoe'] = amphoe
      best_match['district'] = subdistrict
      break  # Take the first match

  # If no district match, prioritize amphoe and zipcode
  for province, amphoe in amphoe_matches:
      for p, a, z in zipcode_matches:
          if province == p and amphoe == a:
              best_match['province'] = province
              best_match['amphoe'] = amphoe
              best_match['zipcode'] = z
              return best_match

  # If no full match, take first amphoe match
  for province, amphoe in amphoe_matches:
      if not best_match['amphoe']:
          best_match['province'] = province
          best_match['amphoe'] = amphoe
          break  # Take the first match

  # If no amphoe match, take first zipcode match
  for province, amphoe, postcode in zipcode_matches:
      if not best_match['zipcode']:
          best_match['province'] = province
          best_match['amphoe'] = amphoe
          best_match['zipcode'] = postcode
          break  # Take the first match

  return best_match

def initial_nlp_tools(hashmap):
  """
  create pythainlp tools
  word tokenize and spellchecker
  """
  # custom_word_lists = set(thai_words())
  # custom_word_lists.update(list(hashmap.keys()))

  custom_word_lists = set(list(hashmap.keys()))
  addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
  custom_word_lists.update(addtexts)
  # BoW for word tokenize
  trie = dict_trie(dict_source=custom_word_lists)
  # Create Tokenizer
  custom_tokenize = Tokenizer(custom_dict=trie, join_broken_num=False, keep_whitespace=False, engine='newmm')

  custom_checker_list = set(list(hashmap.keys()))
  addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
  custom_checker_list.update(addtexts)
  # BoW for word spellchecker
  ctrie = dict_trie(dict_source=custom_checker_list)
  # Create SpellChecker
  checker = NorvigSpellChecker(custom_dict=ctrie, min_freq=1, min_len=5, max_len=30)
  return custom_tokenize, checker


def extract_address(text, custom_tokenize, checker, address_list):
  """
  extract address
  update
   - แก้คำผิด จะไม่แก้พวกชื่อจังหวัด เนื่องจาก เคสชื่อจังหวัดน่าน ผิด
  """
  # result format
  matching_result = {
        'province': None,
        'amphoe': None,
        'district': None,
        'zipcode': None,
        'name': None,
        'phone': None
  }

  # text process
  text = preprocess(text)
  text = clean_location_text(text)
  # extract and update matching {name, phone} data
  text, name = extract_name(text)
  text, phone = extract_phone(text)
  if name != None:
    matching_result['name'] = name
  if phone != None:
    matching_result['phone'] = phone

  # tokenize text
  # tokenize_texts = custom_tokenize.word_tokenize(text)
  # spell checker
  # word_lists = [checker.correct(token) for token in tokenize_texts
  #               if token not in ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
  #               and token not in address_list.keys()]
  # tokenize text
  tokenize_texts = custom_tokenize.word_tokenize(text)
  # spell checker
  word_lists = [checker.correct(token) if token not in ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
                and token not in address_list.keys() else token for token in tokenize_texts]
  # print(word_lists)
  result = find_address_match2(address_list, word_lists)
  # print(result)
  #update data
  matching_result.update(result)

  return matching_result

# %%
from addresses import address_list
custom_tokenize, checker = initial_nlp_tools(hashmap)
text_input = [
    "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
              ]
for text in text_input:
  text = preprocess(text)
  text = clean_location_text(text)
  # extract and update matching {name, phone} data
  text, name = extract_name(text)
  text, phone = extract_phone(text)
  ()
  # tokenize text
  tokenize_texts = custom_tokenize.word_tokenize(text)
  # spell checker
  word_lists = [checker.correct(token) if token not in ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
                and token not in address_list.keys() else token for token in tokenize_texts]

  print(tokenize_texts)
  print(word_lists)
# Out:
# ['อนงค์ลักษณ์', '9', '/56', 'ม', '3', 'นฤมลศิริ', '2', 'บุญศิริ', 'สุขุมวิท', 'บางเมือง', 'เมืองสมุทรปราการ', 'สมุทรปนาการ', '10270']
# ['อนงค์ลักษณ์', '9', '/56', 'ม', '3', 'นฤมลศิริ', '2', 'บุญศิริ', 'สุขุมวิท', 'บางเมือง', 'เมืองสมุทรปราการ', 'สมุทรปราการ', '10270']

# %%
def initial_nlp_tools(hashmap):
  """
  create pythainlp tools
  word tokenize and spellchecker
  """
  # custom_word_lists = set(thai_words())
  # custom_word_lists.update(list(hashmap.keys()))
  custom_word_lists = set(list(hashmap.keys()))
  addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
  custom_word_lists.update(addtexts)
  # BoW for word tokenize
  trie = dict_trie(dict_source=custom_word_lists)
  # Create Tokenizer
  custom_tokenize = Tokenizer(custom_dict=trie, join_broken_num=False, keep_whitespace=False, engine='newmm')

  custom_checker_list = set(list(hashmap.keys()))
  custom_checker_list.update('น่าน')
  addtexts = ["หมู่", "ม.", "ถนน", "ซอย", "ซ.", "ตำบล", "ต.", "อำเภอ", "อ.", "จ.", "จังหวัด"]
  custom_checker_list.update(addtexts)
  # BoW for word spellchecker
  ctrie = dict_trie(dict_source=custom_checker_list)
  # Create SpellChecker
  checker = NorvigSpellChecker(custom_dict=ctrie, min_freq=1, min_len=5, max_len=30)
  return custom_tokenize, checker

# %%
text_list = [
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "- ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\nถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 แขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ กรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100",
    # "อรวรรณ\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาว\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักร เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง วรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต ตลิ่งชัน\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง ลาดพร้าว เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n(+66)3 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n(+66)83 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10170\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nนนทบุรี 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 134884",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n000 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 1010\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง/เขต ลาดพร้าว\nกรุงเทพ 10230\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง/เขต ลาดพร้าว\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง สัมพันธวงศ์ เขต จักรวรรดิ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง/เขต ลาดพร้าว\nกรุงเทพ 10230\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง-เขต ลาดพร้าว\nกรุงเทพ 10230\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พหลโยธิน\nแขวง-เขต ลาดพร้าว\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\nบ้านเลขที่ 152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nจักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขตพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธ\nกรุงเทพ 10100\n083 1348844",
    # "*ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว*\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083-134-8844",
    # "ตรัยวิสข์ บัวขาว 0000831348844\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 101000831348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวงจักรวรรดิ์ เขตสัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n0651348844",
    # "ตรัยวิสข์ บัวขาว\n152*154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพ 10100\n0000831348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน พญาไท\nแขวงถนนพญาไท เขตราชเทวี กรุงเทพมหานคร รหัสไปรษณีย์ 10400\n0000831348844",
    # "ตรัยวิสข์ บัวขาว\n152 ตำบลถนนขาด อำเภอเมืองฯ จังหวัดนครปฐม 73000\n0000831348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 เยาวราช\n/ จักรวรรดิ์ สัมพันธวงศ์\nกรุงเทพ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 ถนน เยาวราช\nแขวง จักรวรรดิ์ เขต สัมพันธวงศ์\nกรุงเทพฯ 10100\n083 1348844",
    # "ตรัยวิสข์ บัวขาว\n152-154 Yaowarat Road\nChakkrawat, Samphanthawong District\nBangkok 10100\nTel.0000831348844",
    # "ภาณุมาศ ผ่องทรัพย์ โรงงานน้ำแข็ง ก ไก่ 788 ม. 5 ต.ดอนเจดีย์ อ.ดอนเจดีย์ จ.สุพรรณบุรี 72170 0829329986",
    # "9/183 หมู่บ้านกลางเมืองเกษตรนวมินทร์ 2 ซอยลาดปลาเค้า79 ถนนลาดปลาเค้า แขวงอนุสาวรีย์ เขตบางเขน 10220 0822236547",
    # "ศศิดา หินทอง 082-492-2944\n581/91 ซอยช้อยเพ็ง หมู่บ้านพฤกษาวิลล์ 107/5 แขวง ทุ่งครุเขตทุ่งครุ กรุงเทพมหานคร 10140",
    # "นางสาว บุษรีย์ จาแคล่วคล่อง\n27/704 ชั้น14 อาคารG\nคอนโดสวัสดีกรุงเทพ\nซอยหมู่บ้านมิตรภาพ\nหนองบอน,ประเวศ\nกทม 10250\n0800846122\n(ไม่รับสายกรุณาฝากไว้ที่นิติ)",
    # "คุณ นภาพร\nฝ่ายขายและการตลาดไปรษณีย์ด่วนพิเศษ/โลจิสติกส์ ขล. ส่วนบริการลูกค้า e-Commerce บม. บริษัท ไปรษณีย์ไทย จำกัด 111 ถนนแจ้งวัฒนะ\nแขวงทุ่งสองห้อง เขตหลักสี่ กรุงเทพ 10210\nเบอร์โทร : 091-771-8664",
    # "กุ๊กกิ๊ก 0940951159\nเวียงนาราเพลส (ห้อง.110)294 หมู่ 4 (ถนนหมู่บ้านลดาวัลย์ ซอย7-หมู่บ้านสินธานี 1) ต.รอบเวียง อ.เมือง จ.เชียงราย 57000",
    # "ธันยพร 56/5 ม.7 (ซ.5)ต.ซับสมอทอด อ.บึงสามพัน จ.เพชรบูรณ์ 67160 (0962788986) (บ้านอยู่ติดกับสายป่าน อพาร์ทเม้น)",
    "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
    # "ลซ 0986725611\n581/91 ซอยช้อยเพ็ง หมู่บ้านพฤกษาวิลล์ 107/5 แขวง ทุ่งครุ เขตทุ่งครุ กรุงเทพมหานคร 10140",
    "วาสนา วนาอนุรักษ์\n33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079"
]

# %% [markdown]
# extract address

# %%
text_list = [
    # '182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741',
    # 'สมพัฒน์ แก้วพิจิตร 66/8 ม.10 ต.เขาแก้ว อ.ท่าใหม่ จ.จันทบุรี 22170',
    # 'ที่อยู่ 111/1 หมู่ 7 ตำบล แสนสุข อำเภอ เมืองชลบุรี จังหวัด ชลบุรี 20130',
    # 'ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี ตำบล แสนสุข',
    # 'ตำบล แสนสุข ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี',
    # '680 ถ.สุขมุวิท ต.บางปลาสร้อย อ.เมืองชลบุรี จ.ชลบุรี 20000',
    # '259 หมู่11 ถ.สืบศิริ ต.เมืองปัก อ.ปักธงชัย จ.นครราชสีมา 30150',
    # '87 ถ.สุขุมวิท ต.ปากน้ำ อ.เมืองสมุทรปราการ จ.สมุทรปราการ 10270',
    # '11/1 หมู่ 4 ตำบล นามะตูม อำเภอ พนัสนิคม จังหวัด ชลบุรี 20140',
    # '12/13 ถนนเทศบาลพัฒนา ตำบลพนัสนิคม อำเภอพนัสนิคม จังหวัดชลบุรี 20140',
    # '21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100',
    # "55) 30-12-62 นายเชิดชัย สมหมาย 107/1 หมู่ 6 ซ.หมู่บ้านโรงกุลี ซอย 10 ถนนมิตรภาพ ต.กลางดง อำเภอ / ตำบล : ปากช่อง จังหวัด : นครราชสีมา 30320 Tel 091-2719547",
    # "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547",
    # "55)30-12-62107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547เชิดชัยสมหมายนามะตูม อำเภอ พนัสนิคม",
    # "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547",
    "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547",
    "3นายสมชาย ใจดี 081-234-5678 หรือ 0877170741 110/1 อาคาร Cube space ชั้น 14 ถ.กรุงธนบุรี บางลำภูล่าง คลองสาน กรุงเทพฯ 10600 จ-ศ 10:00-19:000",
    # "คุณมานะ คงวุฒิปัญญา 123/676 087.442-5664 บางอค กทม ติดต่อ 9:00 - 15:00",
    # "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
    "วาสนา วนาอนุรักษ์\n33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079"

]

custom_tokenize, checker = initial_nlp_tools(hashmap)

result_list = []
for text in text_list:
  print(text)
  matching_result = extract_address(text=text, custom_tokenize=custom_tokenize, checker=checker, address_list=address_list)
  print(matching_result, "\n")
  result_list.append(matching_result)
# Out:
# 55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547
# {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัยสมหมาย', 'phone': '0912719547'}
#
# 3นายสมชาย ใจดี 081-234-5678 หรือ 0877170741 110/1 อาคาร Cube space ชั้น 14 ถ.กรุงธนบุรี บางลำภูล่าง คลองสาน กรุงเทพฯ 10600 จ-ศ 10:00-19:000
# {'province': 'กรุงเทพ', 'amphoe': 'คลองสาน', 'district': 'บางลำภูล่าง', 'zipcode': '10600', 'name': 'นายสมชาย ใจดี', 'phone': '0812345678'}
#
# วาสนา วนาอนุรักษ์
# 33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079
# {'province': 'น่าน', 'amphoe': 'เมืองน่าน', 'district': 'ในเวียง', 'zipcode': None, 'name': '', 'phone': '0884076079'}

# %%
text_list = [
    "55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547",
    "3นายสมชาย ใจดี 081-234-5678 หรือ 0877170741 110/1 อาคาร Cube space ชั้น 14 ถ.กรุงธนบุรี บางลำภูล่าง คลองสาน กรุงเทพฯ 10600 จ-ศ 10:00-19:000",
    "คุณมานะ คงวุฒิปัญญา 123/676 087.442-5664 บางอค กทม ติดต่อ 9:00 - 15:00",
    "อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655",
    "วาสนา วนาอนุรักษ์\n33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079"

]

custom_tokenize, checker = initial_nlp_tools(hashmap)

result_list = []
for text in text_list:
  print(text)
  matching_result = extract_address(text=text, custom_tokenize=custom_tokenize, checker=checker, address_list=address_list)
  print(matching_result, "\n")
  result_list.append(matching_result)
# Out:
# 55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547
# {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัยสมหมาย', 'phone': '0912719547'}
#
# 3นายสมชาย ใจดี 081-234-5678 หรือ 0877170741 110/1 อาคาร Cube space ชั้น 14 ถ.กรุงธนบุรี บางลำภูล่าง คลองสาน กรุงเทพฯ 10600 จ-ศ 10:00-19:000
# {'province': 'กรุงเทพ', 'amphoe': 'คลองสาน', 'district': 'บางลำภูล่าง', 'zipcode': '10600', 'name': 'นายสมชาย ใจดี', 'phone': '0812345678'}
#
# คุณมานะ คงวุฒิปัญญา 123/676 087.442-5664 บางอค กทม ติดต่อ 9:00 - 15:00
# {'province': None, 'amphoe': None, 'district': None, 'zipcode': None, 'name': 'คุณมานะ คงวุฒิปัญญา', 'phone': '0874425664'}
#
# อนงค์ลักษณ์
# 9/56 ม.3
# หมู่บ้านนฤมลศิริ(ซอย2)
# ซ.บุญศิริ ถ.สุขุมวิท
# ต.บางเมือง
# อ.เมืองสมุทรปราการ
# จ.สมุทรปนาการ
# 10270
# โทร.0956029655
# ...

# %% [markdown]
# ตรวจสอบการ tag

# %%
test_data = [
    ("182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741", {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}),
    ("สมพัฒน์ แก้วพิจิตร 66/8 ม.10 ต.เขาแก้ว อ.ท่าใหม่ จ.จันทบุรี 22170", {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': 'สมพัฒน์ แก้วพิจิตร', 'phone': ''}),
    ("ที่อยู่ 111/1 หมู่ 7 ตำบล แสนสุข อำเภอ เมืองชลบุรี จังหวัด ชลบุรี 20130", {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}),
    ("ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี ตำบล แสนสุข", {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}),
    ("ตำบล แสนสุข ที่อยู่ 111/1 20130 หมู่ 7 อำเภอ เมืองชลบุรี จังหวัด ชลบุรี", {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}),
    ("680 ถ.สุขมุวิท ต.บางปลาสร้อย อ.เมืองชลบุรี จ.ชลบุรี 20000", {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บางปลาสร้อย', 'zipcode': '20000', 'name': '', 'phone': ''}),
    ("259 หมู่11 ถ.สืบศิริ ต.เมืองปัก อ.ปักธงชัย จ.นครราชสีมา 30150", {'province': 'นครราชสีมา', 'amphoe': 'ปักธงชัย', 'district': 'เมืองปัก', 'zipcode': '30150', 'name': '', 'phone': ''}),
    ("87 ถ.สุขุมวิท ต.ปากน้ำ อ.เมืองสมุทรปราการ จ.สมุทรปราการ 10270", {'province': 'สมุทรปราการ', 'amphoe': 'เมืองสมุทรปราการ', 'district': 'ปากน้ำ', 'zipcode': '10270', 'name': '', 'phone': ''}),
    ("11/1 หมู่ 4 ตำบล นามะตูม อำเภอ พนัสนิคม จังหวัด ชลบุรี 20140", {'province': 'ชลบุรี', 'amphoe': 'พนัสนิคม', 'district': 'นามะตูม', 'zipcode': '20140', 'name': '', 'phone': ''}),
    ("12/(13 ถนนเทศบาลพัฒนา ตำบลพนัสนิคม อำเภอพนัสนิคม จังหวัดชลบุรี 20140", {'province': 'ชลบุรี', 'amphoe': 'พนัสนิคม', 'district': 'พนัสนิคม', 'zipcode': '20140', 'name': '', 'phone': ''}),
    ("21-29 ถ.นาคราช แขวงคลองมหานาค เขตป้อมปราบศัตรูพ่าย จ.กรุงเทพ 10100", {'province': 'กรุงเทพ', 'amphoe': 'ป้อมปราบศัตรูพ่าย', 'district': 'คลองมหานาค', 'zipcode': '10100', 'name': '', 'phone': ''}),
    ("55) 30-12-62 นายเชิดชัย สมหมาย 107/1 หมู่ 6 ซ.หมู่บ้านโรงกุลี ซอย 10 ถนนมิตรภาพ ต.กลางดง อำเภอ / ตำบล : ปากช่อง จังหวัด : นครราชสีมา 30320 Tel 091-2719547", {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัย สมหมาย', 'phone': '0912719547'}),
    ("55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547", {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัยสมหมาย', 'phone': '0912719547'}),
    ("55)30-12-62107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547เชิดชัยสมหมายนามะตูม อำเภอ พนัสนิคม", {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': '', 'phone': '0912719547'}),
    ("55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320Tel091-2719547", {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัยสมหมาย', 'phone': '0912719547'}),
    ("55)30-12-62นายเชิดชัยสมหมาย107/1หมู่6ซ.หมู่บ้านโรงกุลีซอย10ถนนมิตรภาพต.กลางดงอำเภอ/ตำบล:ปากช่องจังหวัด:นครราชสีมา30320 091-2719547", {'province': 'นครราชสีมา', 'amphoe': 'ปากช่อง', 'district': 'กลางดง', 'zipcode': '30320', 'name': 'นายเชิดชัยสมหมาย', 'phone': '0912719547'}),
    ("3นายสมชาย ใจดี 081-234-5678 หรือ 0877170741 110/1 อาคาร Cube space ชั้น 14 ถ.กรุงธนบุรี บางลำภูล่าง คลองสาน กรุงเทพฯ 10600 จ-ศ 10:00-19:000", {'province': 'กรุงเทพ', 'amphoe': 'คลองสาน', 'district': 'บางลำภูล่าง', 'zipcode': '10600', 'name': 'นายสมชาย ใจดี', 'phone': '0812345678'}),
    ("คุณมานะ คงวุฒิปัญญา 123/676 087.442-5664 บางอค กทม ติดต่อ 9:00 - 15:00", {'province': 'กรุงเทพ', 'amphoe': 'ไม่ระบุ', 'district': 'บางอค', 'zipcode': '', 'name': 'คุณมานะ คงวุฒิปัญญา', 'phone': '0874425664'}),
    ("อนงค์ลักษณ์\n9/56 ม.3\nหมู่บ้านนฤมลศิริ(ซอย2)\nซ.บุญศิริ ถ.สุขุมวิท\nต.บางเมือง\nอ.เมืองสมุทรปราการ\nจ.สมุทรปนาการ\n10270\nโทร.0956029655", {'province': 'สมุทรปราการ', 'amphoe': 'เมืองสมุทรปราการ', 'district': 'บางเมือง', 'zipcode': '10270', 'name': 'อนงค์ลักษณ์', 'phone': '0956029655'}),
    ("วาสนา วนาอนุรักษ์\n33,35 ถ.อนันตวรฤทธิเดช ต.ในเวียง อ.เมือง จ.น่าน 5500 โทร. 088 407 6079", {'province': 'น่าน', 'amphoe': 'เมืองน่าน', 'district': 'ในเวียง', 'zipcode': '5500', 'name': 'วาสนา วนาอนุรักษ์', 'phone': '0884076079'}),
    ]

# %%
result_list = []
for text in test_data:
  print(text)
  matching_result = extract_address(text=text[0], custom_tokenize=custom_tokenize, checker=checker, address_list=address_list)
  print(matching_result, "\n")
  result_list.append(matching_result)
# Out:
# ('182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741', {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'})
# {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}
#
# ('สมพัฒน์ แก้วพิจิตร 66/8 ม.10 ต.เขาแก้ว อ.ท่าใหม่ จ.จันทบุรี 22170', {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': 'สมพัฒน์ แก้วพิจิตร', 'phone': ''})
# {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': '', 'phone': ''}
#
# ('ที่อยู่ 111/1 หมู่ 7 ตำบล แสนสุข อำเภอ เมืองชลบุรี จังหวัด ชลบุรี 20130', {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''})
# {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}
#
# ...

# %%
test_data[0][0]
# Out:
# '182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741'

# %%
def check_accuracy(text_list, result_list):
    total = len(text_list)
    field_names = ['province', 'amphoe', 'district', 'zipcode', 'name', 'phone']
    field_count = len(field_names)

    total_correct_fields = 0

    for i, (text, expected) in enumerate(text_list):
        detected = result_list[i]
        correct_fields = 0
        incorrect_fields = []

        for field in field_names:
            if expected[field] == detected[field]:
                correct_fields += 1
            else:
                incorrect_fields.append(field)

        accuracy_per_loop = (correct_fields / field_count) * 100
        total_correct_fields += correct_fields

        print(f'Loop {i+1}:')
        print(f'คำตอบบอก {expected}')
        print(f'ผลลัพธ์บอก {detected}')
        if incorrect_fields:
            print(f'ผิดที่ {", ".join(incorrect_fields)} คิดเป็น {correct_fields}/{field_count}')
        else:
            print('ถูกทั้งหมด')
        print(f'ความแม่นยำของลูปนี้: {accuracy_per_loop:.2f}%\n')

    total_accuracy = (total_correct_fields / (total * field_count)) * 100
    return total_accuracy

# Example usage
text_list = [
    (
        '182/89 Metro park ถนนกัลปพฤกษ์ แยก 2 แขวงบางหว้า เขตภาษีเจริญ จังหวัดกรุงเทพ 10160 0877170741',
        {
            'province': 'กรุงเทพ',
            'amphoe': 'ภาษีเจริญ',
            'district': 'บางหว้า',
            'zipcode': '10160',
            'name': '',
            'phone': '0877170741'
        }
    )
]

result_list = [
    {
        'province': 'กรุงเทพ',
        'amphoe': '',
        'district': 'บางหว้า',
        'zipcode': '',
        'name': '',
        'phone': '0877170741'
    }
]

total_accuracy = check_accuracy(text_list, result_list)
print(f'ความแม่นยำรวม: {total_accuracy:.2f}%')
# Out:
# Loop 1:
# คำตอบบอก {'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}
# ผลลัพธ์บอก {'province': 'กรุงเทพ', 'amphoe': '', 'district': 'บางหว้า', 'zipcode': '', 'name': '', 'phone': '0877170741'}
# ผิดที่ amphoe, zipcode คิดเป็น 4/6
# ความแม่นยำของลูปนี้: 66.67%
#
# ความแม่นยำรวม: 66.67%

# %%
result_list = []
for text in test_data:
  # print(text)
  matching_result = extract_address(text=text[0], custom_tokenize=custom_tokenize, checker=checker, address_list=address_list)
  # print(matching_result, "\n")
  result_list.append(matching_result)
print(result_list)
total_accuracy = check_accuracy(test_data, result_list)
print(f'ความแม่นยำรวม: {total_accuracy:.2f}%')
# Out:
# [{'province': 'กรุงเทพ', 'amphoe': 'ภาษีเจริญ', 'district': 'บางหว้า', 'zipcode': '10160', 'name': '', 'phone': '0877170741'}, {'province': 'จันทบุรี', 'amphoe': 'ท่าใหม่', 'district': 'เขาแก้ว', 'zipcode': '22170', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'แสนสุข', 'zipcode': '20130', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'เมืองชลบุรี', 'district': 'บางปลาสร้อย', 'zipcode': '20000', 'name': '', 'phone': ''}, {'province': 'นครราชสีมา', 'amphoe': 'ปักธงชัย', 'district': 'เมืองปัก', 'zipcode': '30150', 'name': '', 'phone': ''}, {'province': 'สมุทรปราการ', 'amphoe': 'เมืองสมุทรปราการ', 'district': 'ปากน้ำ', 'zipcode': '10270', 'name': '', 'phone': ''}, {'province': 'ชลบุรี', 'amphoe': 'พนัสนิคม
# ...

# %%
checker.spell('น่าน')
# Out:
# ['ท่านา', 'นาจาน', 'นาอาน', 'นาด่าน']

# %%
checker.correct('น่าน')
# Out:
# 'ท่านา'
